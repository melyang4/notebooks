# %%
from Bio import Phylo
from cStringIO import StringIO
import matplotlib.pyplot as plt
treedata="(PolarBear:0.071912,(Xiaoshuijin:0.131717,((Shaanxi_QIN:0.0346877,(((Sichuan_QIO:0.00070366,Sichuan_XXL:0.100565):0.0025752,(Sichuan_MIN:0.00743899,Gansu_MIN:0.141988):0.0379069):0.00266399,(Sichuan_LS:0.178433,Sichuan_DXL:0.10188):0.00279482):0.0155235):0.00943904,Cizhutuo:0.126923):0.00143247):0.071912);"
handle = StringIO(treedata)
tree = Phylo.read(handle, "newick")
#fig = plt.figure(figsize=(20,35))

tree.root.color = "black"
tree.id
czt = tree.common_ancestor({"name": "Cizhutuo"})
czt.color = "red"
Phylo.draw(tree)

# %%
from ete3 import Tree
t = Tree("(PolarBear:0.071912,(Xiaoshuijin:0.131717,((Shaanxi_QIN:0.0346877,(((Sichuan_QIO:0.00070366,Sichuan_XXL:0.100565):0.0025752,(Sichuan_MIN:0.00743899,Gansu_MIN:0.141988):0.0379069):0.00266399,(Sichuan_LS:0.178433,Sichuan_DXL:0.10188):0.00279482):0.0155235):0.00943904,Cizhutuo:0.126923):0.00143247):0.071912)" )

print t
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-093bdceda4aa> in <module>()
# ----> 1 from ete3 import Tree
#       2 t = Tree("(PolarBear:0.071912,(Xiaoshuijin:0.131717,((Shaanxi_QIN:0.0346877,(((Sichuan_QIO:0.00070366,Sichuan_XXL:0.100565):0.0025752,(Sichuan_MIN:0.00743899,Gansu_MIN:0.141988):0.0379069):0.00266399,(Sichuan_LS:0.178433,Sichuan_DXL:0.10188):0.00279482):0.0155235):0.00943904,Cizhutuo:0.126923):0.00143247):0.071912)" )
#       3
#       4 print t
#
# ImportError: No module named ete3

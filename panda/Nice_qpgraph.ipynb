# %%
# %%writefile /mnt/solexa/mel_yang/panda/qpgraph/FigS8a_rev.dot
#
# digraph G {
# size = "7.5,10" ;
# labelloc = "t" ;
#
#    polarbear  [ label = "Polar Bear" , style="filled" ,fillcolor="#fbfbfb",fontname="Helvetica"] ;
#          CZT  [ label = "Cizhutuo" , style="filled" ,fillcolor="#fafeff",fontname="Helvetica"] ;
#          XSJ  [ label = "Xiaoshuijin" , style="filled" ,fillcolor="#dffadf",fontname="Helvetica"] ;
#   Sichuan_LS  [ label = "Liangshan" , style="filled" ,fillcolor="#ebe1f3",fontname="Helvetica"] ;
#  Shaanxi_QIN  [ label = "Qinling" , style="filled" ,fillcolor="#ebe1f3",fontname="Helvetica"] ;
#          MIN  [ label = "Minshan" , style="filled" ,fillcolor="#ebe1f3",fontname="Helvetica"] ;
#
#     n1e4r  [ style=invis ] ;
#     n1e4r -> n1e4 [ style=invis ];
#
#     XSJr  [ style=invis ] ;
#     XSJr -> XSJ[ style=invis ];
#
# R -> polarbear [  label = "236" ,fontcolor="gray66",arrowhead="none",penwidth=2] ;
# R -> nW1e0 [  label = "236" ,fontcolor="gray66",arrowhead="none",penwidth=2] ;
# R [ fillcolor="black" ,color="black", style="filled", label="", width=0.05,height=0.05]
# nW1e0 [ fillcolor="black" ,color="black", style="filled", label="", width=0.05,height=0.05]
#
# ##CZT
# nW1e0 -> W [  label = "19" ,color="#00a8c4",fontcolor="gray66",penwidth=3 ,arrowhead="none" ] ;
# W -> nW1W1 [  label = "20" ,color="#00a8c4",fontcolor="gray66",penwidth=3 ,arrowhead="none" ] ;
# nW1W1 -> CZT [  label = "3" ,color="#00a8c4",fontcolor="gray66",penwidth=3 ,arrowhead="none" ] ;
# nW1W1 -> nW1e3 [  label = "2" ,color="#00a8c4",fontcolor="gray66",penwidth=3 ,arrowhead="none" ] ;
# nW1e3 -> nW1e4 [ style=dotted,  label = "55%" ,color="#00a8c4", penwidth=2] ;
# W [ fillcolor="#00a8c4" ,color="#00a8c4", style="filled", label="", width=0.05,height=0.05]
# nW1W1 [ fillcolor="#00a8c4" ,color="#00a8c4", style="filled", label="", width=0.05,height=0.05]
# nW1e3 [ fillcolor="#00a8c4" ,color="#00a8c4", style="filled", label="", width=0.05,height=0.05]
#
# ##XSJ
# nW1e0 -> nW1e2 [  label = "1" ,color="#178f17",fontcolor="gray66",arrowhead="none",penwidth=3] ;
# nW1e4 -> nY1Y1 [  label = "6" ,color="#178f17",fontcolor="gray66",arrowhead="none",penwidth=3] ;
# nY1Y1 -> n1e0 [  label = "4" ,color="#178f17",fontcolor="gray66",arrowhead="none",penwidth=3] ;
# nY1Y1 -> nY1e3 [  label = "13" ,color="#178f17",fontcolor="gray66",arrowhead="none",penwidth=3] ;
# n1e0 -> XSJ [  label = "477" ,color="#178f17",fontcolor="gray66",arrowhead="none",penwidth=3] ;
# n1e0 -> n1e2 [  label = "103" ,color="#178f17",fontcolor="gray66",arrowhead="none",penwidth=3] ;
#
# nW1e2 -> nW1e4 [ style=dotted,  label = "45%" ,color="#178f17", penwidth=2] ;
# n1e2 -> n1e4 [ style=dotted,  label = "73%" ,color="#178f17", penwidth=2] ;
# nY1e3 -> nY1e4 [ style=dotted,  label = "48%" ,color="#178f17", penwidth=2] ;
# nW1e2 [ fillcolor="#178f17" ,color="#178f17", style="filled", label="", width=0.05,height=0.05]
# nW1e4 [ fillcolor="#178f17" ,color="#178f17", style="filled", label="", width=0.05,height=0.05]
# nY1Y1 [ fillcolor="#178f17" ,color="#178f17", style="filled", label="", width=0.05,height=0.05]
# nY1e3 [ fillcolor="#178f17" ,color="#178f17", style="filled", label="", width=0.05,height=0.05]
# n1e2 [ fillcolor="#178f17" ,color="#178f17", style="filled", label="", width=0.05,height=0.05]
# n1e0 [ fillcolor="#178f17" ,color="#178f17", style="filled", label="", width=0.05,height=0.05]
#
# ##PDP
# W -> nY1e0 [  label = "88" ,color="#a173c7",fontcolor="gray66",penwidth=3 ,arrowhead="none" ] ;
# nY1e0 -> Shaanxi_QIN [  label = "69" ,color="#a173c7",fontcolor="gray66",penwidth=3 ,arrowhead="none"] ;
# nY1e4 -> MIN [  label = "55" ,color="#a173c7",fontcolor="gray66",arrowhead="none",penwidth=3] ;
#
# nY1e0 -> n1e1 [  label = "161" ,color="#a173c7",fontcolor="gray66",penwidth=3 ,arrowhead="none"] ;
# n1e1 -> nY1e2 [  label = "15" ,color="#a173c7",fontcolor="gray66",penwidth=3 ,arrowhead="none"] ;
# n1e1 -> n1e3 [  label = "14" ,color="#a173c7",fontcolor="gray66",penwidth=3 ,arrowhead="none"] ;
# nY1e2 -> nY1e4 [ style=dotted,  label = "52%" ,color="#a173c7", penwidth=2] ;
# n1e3 -> n1e4 [ style=dotted,  label = "27%" ,color="#a173c7", penwidth=2] ;
# n1e4 -> Sichuan_LS [  label = "193" ,color="#a173c7",fontcolor="gray66",arrowhead="none",penwidth=3] ;
# nY1e0 [ fillcolor="#a173c7" ,color="#a173c7", style="filled", label="", width=0.05,height=0.05]
# n1e1 [ fillcolor="#a173c7" ,color="#a173c7", style="filled", label="", width=0.05,height=0.05]
# nY1e2 [ fillcolor="#a173c7" ,color="#a173c7", style="filled", label="", width=0.05,height=0.05]
# n1e3 [ fillcolor="#a173c7" ,color="#a173c7", style="filled", label="", width=0.05,height=0.05]
# nY1e4 [ fillcolor="#a173c7" ,color="#a173c7", style="filled", label="", width=0.05,height=0.05]
# n1e4 [ fillcolor="#a173c7" ,color="#a173c7", style="filled", label="", width=0.05,height=0.05]
# }
# Out:
# Overwriting /mnt/solexa/mel_yang/panda/qpgraph/FigS8a_rev.dot

# %%
# %%writefile /mnt/solexa/mel_yang/panda/qpgraph/FigS8c_rev.dot
#
# digraph G {
# size = "7.5,10" ;
# labelloc = "t" ;
#
#    polarbear  [ label = "Polar Bear" , style="filled" ,fillcolor="#fbfbfb",fontname="Helvetica"] ;
#          CZT  [ label = "Cizhutuo" , style="filled" ,fillcolor="#fafeff",fontname="Helvetica"] ;
#          XSJ  [ label = "Xiaoshuijin" , style="filled" ,fillcolor="#dffadf",fontname="Helvetica"] ;
#   Sichuan_LS  [ label = "Liangshan" , style="filled" ,fillcolor="#ebe1f3",fontname="Helvetica"] ;
#  Shaanxi_QIN  [ label = "Qinling" , style="filled" ,fillcolor="#ebe1f3",fontname="Helvetica"] ;
#          MIN  [ label = "Minshan" , style="filled" ,fillcolor="#ebe1f3",fontname="Helvetica"] ;
#
#     XSJr  [ style=invis ] ;
#     XSJr -> XSJ[ style=invis ];
#     nW1e4r  [ style=invis ] ;
#     nW1e4r -> nW1e4[ style=invis ];
#
# R -> polarbear [  label = "233" ,fontcolor="gray66",arrowhead="none",penwidth=2] ;
# R -> nW1e0 [  label = "233" ,fontcolor="gray66",arrowhead="none",penwidth=2] ;
# R [ fillcolor="black" ,color="black", style="filled", label="", width=0.05,height=0.05]
# nW1e0 [ fillcolor="black" ,color="black", style="filled", label="", width=0.05,height=0.05]
#
# ##CZT
# nW1e0 -> W [  label = "28" ,color="#00a8c4",fontcolor="gray66",penwidth=3 ,arrowhead="none"] ;
# W -> n1e0 [  label = "2" ,color="#00a8c4",fontcolor="gray66",penwidth=3 ,arrowhead="none"] ;
# n1e0 -> nW1W1 [  label = "12" ,color="#00a8c4",fontcolor="gray66",penwidth=3 ,arrowhead="none"] ;
# n1e0 -> n1e2 [  label = "8" ,color="#00a8c4",fontcolor="gray66",penwidth=3 ,arrowhead="none"] ;
# nW1W1 -> CZT [  label = "6" ,color="#00a8c4",fontcolor="gray66",penwidth=3 ,arrowhead="none"] ;
# nW1W1 -> nW1e3 [  label = "26" ,color="#00a8c4",fontcolor="gray66",penwidth=3 ,arrowhead="none"] ;
# n1e2 -> n1e4 [ style=dotted,  label = "39%" ,color="#00a8c4", penwidth=2] ;
# nW1e3 -> nW1e4 [ style=dotted,  label = "60%" ,color="#00a8c4", penwidth=2] ;
# W [ fillcolor="#00a8c4" ,color="#00a8c4", style="filled", label="", width=0.05,height=0.05]
# n1e0 [ fillcolor="#00a8c4" ,color="#00a8c4", style="filled", label="", width=0.05,height=0.05]
# nW1W1 [ fillcolor="#00a8c4" ,color="#00a8c4", style="filled", label="", width=0.05,height=0.05]
# nW1e3 [ fillcolor="#00a8c4" ,color="#00a8c4", style="filled", label="", width=0.05,height=0.05]
# n1e2 [ fillcolor="#00a8c4" ,color="#00a8c4", style="filled", label="", width=0.05,height=0.05]
#
# ##PDP
# nW1e0 -> nW1e2 [  label = "12" ,color="#a173c7",fontcolor="gray66",penwidth=3 ,arrowhead="none"] ;
# nY1Y1 -> n1e1 [  label = "107" ,color="#a173c7",fontcolor="gray66",penwidth=3 ,arrowhead="none"] ;
# nW1e4 -> nY1Y1 [  label = "72" ,color="#a173c7",fontcolor="gray66",penwidth=3 ,arrowhead="none"] ;
# nY1Y1 -> Shaanxi_QIN [  label = "83" ,color="#a173c7",fontcolor="gray66",penwidth=3 ,arrowhead="none"] ;
# nY1e4 -> Sichuan_LS [  label = "203" ,color="#a173c7",fontcolor="gray66",penwidth=3 ,arrowhead="none"] ;
# n1e1 -> nY1e3 [  label = "20" ,color="#a173c7",fontcolor="gray66",penwidth=3 ,arrowhead="none"] ;
# n1e1 -> n1e3 [  label = "20" ,color="#a173c7",fontcolor="gray66",penwidth=3 ,arrowhead="none"] ;
# n1e4 -> MIN [  label = "53" ,color="#a173c7",fontcolor="gray66",penwidth=3 ,arrowhead="none"] ;
# nY1e3 -> nY1e4 [ style=dotted,  label = "31%" ,color="#a173c7", penwidth=2] ;
# n1e3 -> n1e4 [ style=dotted,  label = "61%" ,color="#a173c7", penwidth=2] ;
# nW1e2 -> nW1e4 [ style=dotted,  label = "40%" ,color="#a173c7", penwidth=2] ;
# nW1e2 [ fillcolor="#a173c7" ,color="#a173c7", style="filled", label="", width=0.05,height=0.05]
# nY1Y1 [ fillcolor="#a173c7" ,color="#a173c7", style="filled", label="", width=0.05,height=0.05]
# n1e1 [ fillcolor="#a173c7" ,color="#a173c7", style="filled", label="", width=0.05,height=0.05]
# nY1e3 [ fillcolor="#a173c7" ,color="#a173c7", style="filled", label="", width=0.05,height=0.05]
# n1e3 [ fillcolor="#a173c7" ,color="#a173c7", style="filled", label="", width=0.05,height=0.05]
# n1e4 [ fillcolor="#a173c7" ,color="#a173c7", style="filled", label="", width=0.05,height=0.05]
# nY1e4 [ fillcolor="#a173c7" ,color="#a173c7", style="filled", label="", width=0.05,height=0.05]
# nW1e4 [ fillcolor="#a173c7" ,color="#a173c7", style="filled", label="", width=0.05,height=0.05]
#
# ##XSJ
# W -> nY1e0 [  label = "2" ,color="#178f17",fontcolor="gray66",arrowhead="none",penwidth=3] ;
# nY1e0 -> XSJ [  label = "476" ,color="#178f17",fontcolor="gray66",arrowhead="none",penwidth=3] ;
# nY1e0 -> nY1e2 [  label = "95" ,color="#178f17",fontcolor="gray66",arrowhead="none",penwidth=3] ;
# nY1e2 -> nY1e4 [ style=dotted,  label = "69%" ,color="#178f17", penwidth=2] ;
# nY1e0 [ fillcolor="#178f17" ,color="#178f17", style="filled", label="", width=0.05,height=0.05]
# nY1e2 [ fillcolor="#178f17" ,color="#178f17", style="filled", label="", width=0.05,height=0.05]
# }
# Out:
# Overwriting /mnt/solexa/mel_yang/panda/qpgraph/FigS8c_rev.dot

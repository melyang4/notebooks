# %%
import numpy as np
import plateaumodules as pm
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import rcParams

rcParams['font.family'] = 'Helvetica-Normal'

pD="/mnt/solexa/mel_yang/panda/"
#pp = PdfPages(pD+'Fig2A.pdf')
fhall="F4.list.all"
fhtv="F4.list.alltv"
out,out2=("polarbear","polarbear")

pdp=["Shaanxi_QIN","MIN","Sichuan_QIO",
     "Sichuan_DXL","Sichuan_XXL","Sichuan_LS"]
mynames=["QIN","MIN","QIO","DXL","XXL","LS"]
pdp=["Shaanxi_QIN","MIN","Sichuan_QIO",
     "Sichuan_DXL","Sichuan_XXL","Sichuan_LS","CZT_c","XSJ"]
mynames=["QIN","MIN","QIO","DXL","XXL","LS","CZT","XSJ"]
mycombo=pdp

wantedcolors=["blue"]*len(mycombo)
lines=[2.5,6.5,7.5]
myxmin=[-0.07]*len(mycombo)
myxmax=[0.03]*len(mycombo)

fig = plt.figure(figsize=(8,8))
#newfile=open(pD+"Fig2a_dat.txt",'w')
##Liangshan D(Polar Bear, XSJ; CZT, X)
#newfile.write("EA vs Tibetan\n")
ax1=fig.add_subplot(2,2,1)
myind="Shaanxi_QIN"
varypop="CZT_c"
ypops=mycombo
mytuples=[(0,2),(1,3)]
mypops2=[out,[varypop],myind,ypops]

Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall=Daryall/Zaryall 
mynewpops2=[out2]+mypops2[1:]
Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv=Darytv/Zarytv
xlabel="D(%s,%s;%s,X)" % (mypops2[0],mypops2[1][0],"QIN")#(mypops2[0],mypops2[1][0],mypops2[2][0])
mylabel="CZT-connection\n%s                           %s" % ("Low","High") #mypops2[1][0],mypops2[0])
mec="black"
print Darytv
for ind,i in enumerate(ypops):
    wantedcolors="#84cdeb"#"#c9e9f6" #"blue"
    ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
    ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall[0][ind],ind,'.')
    
myys = np.array(range(len(mynames)))
ax1.set_yticks(myys)
ax1.set_ylabel("X",fontsize=16,rotation=90)
ax1.set_yticklabels(mynames,fontsize=14)#,fontsize=12)

ax1.set_ylim(-1,len(mynames))
ax1.set_xlim(myxmin[0],myxmax[0])
xlabel = ax1.get_xticks().tolist()
ax1.set_title(mylabel,fontsize=15) #weight='bold')
ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
for myline in lines:
    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)
ax1.tick_params(length=2,labelsize=14)
ax1.set_xlabel("D",fontsize=14)


##XSJ connections
ax1=fig.add_subplot(2,2,2)
myind="Shaanxi_QIN"
varypop="XSJ"
ypops=mycombo
mytuples=[(0,2),(1,3)]
mypops2=[out,[varypop],myind,ypops]

Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall=Daryall/Zaryall 
mynewpops2=[out2]+mypops2[1:]
Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv=Darytv/Zarytv
xlabel="D(%s,%s;%s,X)" % (mypops2[0],mypops2[1][0],"QIN")#(mypops2[0],mypops2[1][0],mypops2[2][0])
mylabel="XSJ-connection\n%s                           %s" % ("Low","High") #mypops2[1][0],mypops2[0])
mec="black"
print Darytv
for ind,i in enumerate(ypops):
    wantedcolors="#84cdeb"#"#c9e9f6" #"blue"
    ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
    ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall[0][ind],ind,'.')
myys = np.array(range(len(mynames)))
ax1.set_yticks(myys)
ax1.set_yticklabels(['']*(len(mynames)),fontsize=0.1)
ax1.set_ylim(-1,len(mynames))
ax1.set_xlim(myxmin[0],myxmax[0])
xlabel = ax1.get_xticks().tolist()
ax1.set_yticklabels(['']*(len(mynames)),fontsize=0.1)
ax1.set_title(mylabel,fontsize=15) #weight='bold')
ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
for myline in lines:
    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)
ax1.tick_params(length=2,labelsize=14)
ax1.set_xlabel("D",fontsize=14)


##LS

myxmin=[-0.03]*len(mycombo)
myxmax=[0.25]*len(mycombo)

ax1=fig.add_subplot(2,2,3)
myind="XSJ"
varypop="Sichuan_LS"
ypops=mycombo
mytuples=[(0,2),(1,3)]
mypops2=[out,[varypop],myind,ypops]

Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall=Daryall/Zaryall 
mynewpops2=[out2]+mypops2[1:]
Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv=Darytv/Zarytv
xlabel="D(%s,%s;%s,X)" % (mypops2[0],mypops2[1][0],"XSJ")#(mypops2[0],mypops2[1][0],mypops2[2][0])
mylabel="LS-connection\n%s                           %s" % ("Low","High") #mypops2[1][0],mypops2[0])
mec="black"
print Darytv
for ind,i in enumerate(ypops):
    wantedcolors="#84cdeb"#"#c9e9f6" #"blue"
    ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
    ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall[0][ind],ind,'.')
myys = np.array(range(len(mynames)))
ax1.set_yticks(myys)
ax1.set_ylabel("X",fontsize=16,rotation=90)
ax1.set_yticklabels(mynames,fontsize=14)#,fontsize=12)

ax1.set_ylim(-1,len(mynames))
ax1.set_xlim(myxmin[0],myxmax[0])
xlabel = ax1.get_xticks().tolist()
ax1.set_title(mylabel,fontsize=15) #weight='bold')
ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
for myline in lines:
    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)
ax1.tick_params(length=2,labelsize=14)
ax1.set_xlabel("D",fontsize=14)

##QIN
ax1=fig.add_subplot(2,2,4)
myind="Sichuan_LS"
varypop="Shaanxi_QIN"
ypops=mycombo
mytuples=[(0,2),(1,3)]
mypops2=[out,[varypop],myind,ypops]

Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall=Daryall/Zaryall 
mynewpops2=[out2]+mypops2[1:]
Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv=Darytv/Zarytv
xlabel="D(%s,%s;%s,X)" % (mypops2[0],mypops2[1][0],"LS")#(mypops2[0],mypops2[1][0],mypops2[2][0])
mylabel="QIN-connection\n%s                           %s" % ("Low","High") #mypops2[1][0],mypops2[0])
mec="black"
print Darytv
for ind,i in enumerate(ypops):
    wantedcolors="#84cdeb"#"#c9e9f6" #"blue"
    ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
    ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall[0][ind],ind,'.')
myys = np.array(range(len(mynames)))
ax1.set_yticks(myys)
ax1.set_yticklabels(['']*(len(mynames)),fontsize=0.1)
ax1.set_ylim(-1,len(mynames))
ax1.set_xlim(myxmin[0],myxmax[0])
xlabel = ax1.get_xticks().tolist()
ax1.set_yticklabels(['']*(len(mynames)),fontsize=0.1)
ax1.set_title(mylabel,fontsize=15) #weight='bold')
ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
for myline in lines:
    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)
ax1.tick_params(length=2,labelsize=14)
ax1.set_xlabel("D",fontsize=14)

plt.tight_layout()
plt.show()
# Out:
# [[    nan  0.0067  0.0082  0.009   0.0007  0.0017     nan -0.0173]]
# [[   nan 0.0146 0.0183 0.0111 0.0215 0.021  0.0147    nan]]
# [[0.0639 0.1129 0.1609 0.1668 0.1563    nan 0.008     nan]]
# [[    nan  0.0893  0.0548  0.048   0.0638     nan -0.0465 -0.0848]]

# %%
import numpy as np
import plateaumodules as pm
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import rcParams

rcParams['font.family'] = 'Helvetica-Normal'

pD="/public/adna/qiaomei_fu/panda/geno/F4.mask0.9_random_25K8K_noO_2ind/"
#pp = PdfPages(pD+'Fig2A.pdf')
fhall="F4.list.all"
fhtv="F4.list.alltv"
out,out2=("polarbear","polarbear")

pdp=["Shaanxi_QIN","Gansu_MIN","Sichuan_MIN","Sichuan_QIO",
     "Sichuan_DXL","Sichuan_XXL","Sichuan_LS"]
mynames=["QIN","MIN_G","MIN_S","QIO","DXL","XXL","LS"]
pdp=["Shaanxi_QIN","Gansu_MIN","Sichuan_MIN","Sichuan_QIO",
     "Sichuan_DXL","Sichuan_XXL","Sichuan_LS","25K","8K"]
mynames=["QIN","MIN_G","MIN_S","QIO","DXL","XXL","LS","CZT","XSJ"]
mycombo=pdp

wantedcolors=["blue"]*len(mycombo)
lines=[2.5,6.5,7.5]
myxmin=[-0.035]*len(mycombo)
myxmax=[0.035]*len(mycombo)

fig = plt.figure(figsize=(8,8))
#newfile=open(pD+"Fig2a_dat.txt",'w')
##Liangshan D(Polar Bear, XSJ; CZT, X)
#newfile.write("EA vs Tibetan\n")
ax1=fig.add_subplot(2,2,1)
myind="Shaanxi_QIN"
varypop="25K"
ypops=mycombo
mytuples=[(0,2),(1,3)]
mypops2=[out,[varypop],myind,ypops]

Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall=Daryall/Zaryall 
mynewpops2=[out2]+mypops2[1:]
Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv=Darytv/Zarytv
xlabel="D(%s,%s;%s,X)" % (mypops2[0],mypops2[1][0],"QIN")#(mypops2[0],mypops2[1][0],mypops2[2][0])
mylabel="CZT-connection\n%s                           %s" % ("Low","High") #mypops2[1][0],mypops2[0])
mec="black"
print Darytv
for ind,i in enumerate(ypops):
    wantedcolors="#84cdeb"#"#c9e9f6" #"blue"
    ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
    ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall[0][ind],ind,'.')
    
myys = np.array(range(len(mynames)))
ax1.set_yticks(myys)
ax1.set_ylabel("X",fontsize=16,rotation=90)
ax1.set_yticklabels(mynames,fontsize=14)#,fontsize=12)

ax1.set_ylim(-1,len(mynames))
ax1.set_xlim(myxmin[0],myxmax[0])
xlabel = ax1.get_xticks().tolist()
ax1.set_title(mylabel,fontsize=15) #weight='bold')
ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
for myline in lines:
    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)
ax1.tick_params(length=2,labelsize=14)
ax1.set_xlabel("D",fontsize=14)


##XSJ connections
ax1=fig.add_subplot(2,2,2)
myind="Shaanxi_QIN"
varypop="8K"
ypops=mycombo
mytuples=[(0,2),(1,3)]
mypops2=[out,[varypop],myind,ypops]

Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall=Daryall/Zaryall 
mynewpops2=[out2]+mypops2[1:]
Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv=Darytv/Zarytv
xlabel="D(%s,%s;%s,X)" % (mypops2[0],mypops2[1][0],"QIN")#(mypops2[0],mypops2[1][0],mypops2[2][0])
mylabel="XSJ-connection\n%s                           %s" % ("Low","High") #mypops2[1][0],mypops2[0])
mec="black"
print Darytv
for ind,i in enumerate(ypops):
    wantedcolors="#84cdeb"#"#c9e9f6" #"blue"
    ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
    ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall[0][ind],ind,'.')
myys = np.array(range(len(mynames)))
ax1.set_yticks(myys)
ax1.set_yticklabels(['']*(len(mynames)),fontsize=0.1)
ax1.set_ylim(-1,len(mynames))
ax1.set_xlim(myxmin[0],myxmax[0])
xlabel = ax1.get_xticks().tolist()
ax1.set_yticklabels(['']*(len(mynames)),fontsize=0.1)
ax1.set_title(mylabel,fontsize=15) #weight='bold')
ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
for myline in lines:
    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)
ax1.tick_params(length=2,labelsize=14)
ax1.set_xlabel("D",fontsize=14)


##LS

myxmin=[-0.07]*len(mycombo)
myxmax=[0.13]*len(mycombo)

ax1=fig.add_subplot(2,2,3)
myind="8K"
varypop="Sichuan_LS"
ypops=mycombo
mytuples=[(0,2),(1,3)]
mypops2=[out,[varypop],myind,ypops]

Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall=Daryall/Zaryall 
mynewpops2=[out2]+mypops2[1:]
Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv=Darytv/Zarytv
xlabel="D(%s,%s;%s,X)" % (mypops2[0],mypops2[1][0],"XSJ")#(mypops2[0],mypops2[1][0],mypops2[2][0])
mylabel="LS-connection\n%s                           %s" % ("Low","High") #mypops2[1][0],mypops2[0])
mec="black"
print Darytv
for ind,i in enumerate(ypops):
    wantedcolors="#84cdeb"#"#c9e9f6" #"blue"
    ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
    ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall[0][ind],ind,'.')
myys = np.array(range(len(mynames)))
ax1.set_yticks(myys)
ax1.set_ylabel("X",fontsize=16,rotation=90)
ax1.set_yticklabels(mynames,fontsize=14)#,fontsize=12)

ax1.set_ylim(-1,len(mynames))
ax1.set_xlim(myxmin[0],myxmax[0])
xlabel = ax1.get_xticks().tolist()
ax1.set_title(mylabel,fontsize=15) #weight='bold')
ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
for myline in lines:
    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)
ax1.tick_params(length=2,labelsize=14)
ax1.set_xlabel("D",fontsize=14)

##QIN
ax1=fig.add_subplot(2,2,4)
myind="Sichuan_LS"
varypop="Shaanxi_QIN"
ypops=mycombo
mytuples=[(0,2),(1,3)]
mypops2=[out,[varypop],myind,ypops]

Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall=Daryall/Zaryall 
mynewpops2=[out2]+mypops2[1:]
Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv=Darytv/Zarytv
xlabel="D(%s,%s;%s,X)" % (mypops2[0],mypops2[1][0],"LS")#(mypops2[0],mypops2[1][0],mypops2[2][0])
mylabel="QIN-connection\n%s                           %s" % ("Low","High") #mypops2[1][0],mypops2[0])
mec="black"
print Darytv
for ind,i in enumerate(ypops):
    wantedcolors="#84cdeb"#"#c9e9f6" #"blue"
    ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
    ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall[0][ind],ind,'.')
myys = np.array(range(len(mynames)))
ax1.set_yticks(myys)
ax1.set_yticklabels(['']*(len(mynames)),fontsize=0.1)
ax1.set_ylim(-1,len(mynames))
ax1.set_xlim(myxmin[0],myxmax[0])
xlabel = ax1.get_xticks().tolist()
ax1.set_yticklabels(['']*(len(mynames)),fontsize=0.1)
ax1.set_title(mylabel,fontsize=15) #weight='bold')
ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
for myline in lines:
    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)
ax1.tick_params(length=2,labelsize=14)
ax1.set_xlabel("D",fontsize=14)

plt.tight_layout()
plt.show()
# Out:
# [[    nan  0.0074  0.0026  0.0038  0.0017 -0.0023  0.0038     nan -0.0025]]
# [[   nan 0.013  0.0144 0.0164 0.0093 0.0178 0.026  0.0203    nan]]
# [[ 0.0406  0.0731  0.0936  0.1396  0.1456  0.1325     nan -0.0004     nan]]
# [[    nan  0.0997  0.0845  0.0492  0.0423  0.0567     nan -0.0444 -0.0665]]

# %%
##CZT and PDP form a clade relative to XSJ

import numpy as np
import plateaumodules as pm
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import rcParams

rcParams['font.family'] = 'Helvetica-Normal'

pD="/public/adna/qiaomei_fu/panda/geno/F4.mask0.9_random_25K8K_noO_2ind/"
pD=""
pp = PdfPages('/mnt/solexa/mel_yang/panda/Fig3_Dstat.pdf')
fhall="F4.list.all"
fhtv="F4.list.alltv"
out,out2=("polarbear","polarbear")

pdp=["Shaanxi_QIN","Gansu_MIN","Sichuan_MIN","Sichuan_QIO",
     "Sichuan_DXL","Sichuan_XXL","Sichuan_LS","25K","8K"][:-2]
mynames=["QIN","MIN_G","MIN_S","QIO","DXL","XXL","LS","CZT","XSJ"][:-2]
mycombo=pdp

wantedcolors=["blue"]*len(mycombo)
lines=[2.5]
myxmin=[-0.035]*len(mycombo)
myxmax=[0.035]*len(mycombo)

fig = plt.figure(figsize=(4,9))
#newfile=open(pD+"Fig2a_dat.txt",'w')
##Liangshan D(Polar Bear, XSJ; CZT, X)
#newfile.write("EA vs Tibetan\n")
ax1=fig.add_subplot(3,1,1)
myind="8K"
varypop="25K"
ypops=mycombo
mytuples=[(0,2),(1,3)]
mypops2=[out,[varypop],myind,ypops]

Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall=Daryall/Zaryall 
mynewpops2=[out2]+mypops2[1:]
Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv=Darytv/Zarytv
xlabel="D(%s,%s;%s,X)" % (mypops2[0],mypops2[1][0],"QIN")#(mypops2[0],mypops2[1][0],mypops2[2][0])
mylabel=""
mec="black"

myind="8K"
varypop="25K"
ypops=mycombo
mytuples=[(0,3),(1,2)]
mypops2=[out,ypops,[varypop],myind]

Zaryall1 = np.transpose(pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z'))
Daryall1 = np.transpose(pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D'))
SEaryall1=Daryall1/Zaryall1 
mynewpops2=[out2]+mypops2[1:]
Zarytv1 = np.transpose(pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z'))
Darytv1 = np.transpose(pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D'))
SEarytv1=Darytv1/Zarytv1

for ind,i in enumerate(ypops):
    if ind!=6:
        ax1.plot([Daryall1[0][ind]+2*SEaryall1[0][ind],Daryall[0][ind]-2*SEaryall1[0][ind]],[ind,ind],'--',color='black',linewidth=0.5)
        
    wantedcolors1="yellow"#"#c9e9f6" #"blue"
    #ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    #ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    #ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=2*SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall1[0][ind],ind,'.')
    
    wantedcolors="yellow"
    ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall[0][ind],ind,'.')

        
myys = np.array(range(len(mynames)))
ax1.set_yticks(myys)
ax1.set_ylabel("X",fontsize=16,rotation=0)
ax1.set_yticklabels(mynames,fontsize=14)#,fontsize=12)

ax1.set_ylim(-1,len(mynames))
ax1.set_xlim(myxmin[0],myxmax[0])
xlabel = ax1.get_xticks().tolist()
ax1.set_title(mylabel,fontsize=15) #weight='bold')
ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
for myline in lines:
    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)
ax1.tick_params(length=2,labelsize=14)
#ax1.set_xlabel("D",fontsize=14)
ax1.text(myxmax[0]+0.035,len(mynames)-6.5,"Dashed line\nindicates significant\ncladal relationship\nbetween X and\nCizhutuo relative\nto Xiaoshuijin",
         fontsize=18,horizontalalignment='center')

##LIANGSHAN CONNECTION TO XSJ
pdp=["Shaanxi_QIN","Gansu_MIN","Sichuan_MIN","Sichuan_QIO",
     "Sichuan_DXL","Sichuan_XXL","Sichuan_LS","25K","8K"][:-3]
mynames=["QIN","MIN_G","MIN_S","QIO","DXL","XXL","LS","CZT","XSJ"][:-3]
mycombo=pdp
myxmin=[-0.01]*len(mycombo)
myxmax=[0.035]*len(mycombo)

ax1=fig.add_subplot(3,1,2)
myind="Sichuan_LS"
varypop="25K"
ypops=mycombo
mytuples=[(0,3),(1,2)]
mypops2=[out,[varypop],ypops,myind]

Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall=Daryall/Zaryall 
mynewpops2=[out2]+mypops2[1:]
Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv=Darytv/Zarytv
xlabel="D(%s,%s;%s,X)" % (mypops2[0],mypops2[1][0],"QIN")#(mypops2[0],mypops2[1][0],mypops2[2][0])
mylabel=""
mec="black"

myind="Sichuan_LS"
varypop="8K"
ypops=mycombo
mytuples=[(0,3),(1,2)]
mypops2=[out,[varypop],ypops,myind]

Zaryall1 = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall1 = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall1=Daryall1/Zaryall1 
mynewpops2=[out2]+mypops2[1:]
Zarytv1 = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv1 = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv1=Darytv1/Zarytv1

for ind,i in enumerate(ypops):
    #if ind!=6:
    #    ax1.plot([Daryall1[0][ind]+2*SEaryall1[0][ind],Daryall[0][ind]-2*SEaryall1[0][ind]],[ind,ind],'--',color='black',linewidth=0.5)
        
    wantedcolors1="#178f17"#"#c9e9f6" #"blue"
    #ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    #ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    #ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=2*SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall1[0][ind],ind,'.')
    
    wantedcolors="#00a8c4"
    ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall[0][ind],ind,'.')

        
myys = np.array(range(len(mynames)))
ax1.set_yticks(myys)
ax1.set_ylabel("X",fontsize=16,rotation=0)
ax1.set_yticklabels(mynames,fontsize=14)#,fontsize=12)

ax1.set_ylim(-1,len(mynames))
ax1.set_xlim(myxmin[0],myxmax[0])
xlabel = ax1.get_xticks().tolist()
ax1.set_title(mylabel,fontsize=15) #weight='bold')
ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
for myline in lines:
    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)
ax1.tick_params(length=2,labelsize=14)
#ax1.set_xlabel("D",fontsize=14)
ax1.text(myxmax[0]+0.025,len(mynames)-5.5,"Xiaoshuijin (green)\nshows connection to\nLiangshan pandas\nnot observed for\nCizhutuo (blue)",
         fontsize=18,horizontalalignment='center')    

##QINLING NO CONNECTION TO XSJ
pdp=["Shaanxi_QIN","Gansu_MIN","Sichuan_MIN","Sichuan_QIO",
     "Sichuan_DXL","Sichuan_XXL","Sichuan_LS","25K","8K"][1:-2]
mynames=["QIN","MIN_G","MIN_S","QIO","DXL","XXL","LS","CZT","XSJ"][1:-2]
mycombo=pdp
lines=[1.5]
myxmin=[-0.035]*len(mycombo)
myxmax=[0.01]*len(mycombo)

ax1=fig.add_subplot(3,1,3)
myind="Shaanxi_QIN"
varypop="25K"
ypops=mycombo
mytuples=[(0,3),(1,2)]
mypops2=[out,[varypop],ypops,myind]

Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall=Daryall/Zaryall 
mynewpops2=[out2]+mypops2[1:]
Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv=Darytv/Zarytv
xlabel="D(%s,%s;%s,X)" % (mypops2[0],mypops2[1][0],"QIN")#(mypops2[0],mypops2[1][0],mypops2[2][0])
mylabel=""
mec="black"

myind="Shaanxi_QIN"
varypop="8K"
ypops=mycombo
mytuples=[(0,3),(1,2)]
mypops2=[out,[varypop],ypops,myind]

Zaryall1 = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall1 = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall1=Daryall1/Zaryall1 
mynewpops2=[out2]+mypops2[1:]
Zarytv1 = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv1 = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv1=Darytv1/Zarytv1

for ind,i in enumerate(ypops):
    #if ind!=6:
    #    ax1.plot([Daryall1[0][ind]+2*SEaryall1[0][ind],Daryall[0][ind]-2*SEaryall1[0][ind]],[ind,ind],'--',color='black',linewidth=0.5)
        
    wantedcolors1="#178f17"#"#c9e9f6" #"blue"
    #ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    #ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    #ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=2*SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall1[0][ind],ind,'.')
    
    wantedcolors="#00a8c4"
    ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall[0][ind],ind,'.')

        
myys = np.array(range(len(mynames)))
ax1.set_yticks(myys)
ax1.set_ylabel("X",fontsize=16,rotation=0)
ax1.set_yticklabels(mynames,fontsize=14)#,fontsize=12)

ax1.set_ylim(-1,len(mynames))
ax1.set_xlim(myxmin[0],myxmax[0])
xlabel = ax1.get_xticks().tolist()
ax1.set_title(mylabel,fontsize=15) #weight='bold')
ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
for myline in lines:
    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)
ax1.tick_params(length=2,labelsize=14)
ax1.set_xlabel("D",fontsize=14)
ax1.text(myxmax[0]+0.025,len(mynames)-5.5,"Most present-day\npandas show\nconnection to\nXiaoshuijin relative\nto Qinling pandas",
         fontsize=18,horizontalalignment='center')    

plt.tight_layout()
plt.subplots_adjust(wspace=0.05)
#plt.show()
 

pp.savefig(bbox_inches = "tight")
pp.close()

# %%
##CZT and PDP form a clade relative to XSJ

import numpy as np
import plateaumodules as pm
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import rcParams

rcParams['font.family'] = 'Helvetica-Normal'

pD="/public/adna/qiaomei_fu/panda/geno/F4.mask0.9_random_25K8K_noO_2ind/"
pD="/mnt/solexa/mel_yang/panda/"
pp = PdfPages('/mnt/solexa/mel_yang/panda/Fig3_Dstat_updated.pdf')
fhall="F4.list.all"
fhtv="F4.list.alltv"
out,out2=("polarbear","polarbear")

pdp=["Shaanxi_QIN","MIN","Sichuan_QIO",
     "Sichuan_DXL","Sichuan_XXL","Sichuan_LS","CZT_c","XSJ"][:-2]
mynames=["QIN","MIN","QIO","DXL","XXL","LS","CZT","XSJ"][:-2]
mycombo=pdp

wantedcolors=["blue"]*len(mycombo)
lines=[2.5]
myxmin=[-0.1]*len(mycombo)
myxmax=[0.1]*len(mycombo)

fig = plt.figure(figsize=(4,9))
#newfile=open(pD+"Fig2a_dat.txt",'w')
##Liangshan D(Polar Bear, XSJ; CZT, X)
#newfile.write("EA vs Tibetan\n")
ax1=fig.add_subplot(3,1,1)
myind="XSJ"
varypop="CZT_c"
ypops=mycombo
mytuples=[(0,2),(1,3)]
mypops2=[out,[varypop],myind,ypops]

Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall=Daryall/Zaryall 
mynewpops2=[out2]+mypops2[1:]
Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv=Darytv/Zarytv
xlabel="D(%s,%s;%s,X)" % (mypops2[0],mypops2[1][0],"QIN")#(mypops2[0],mypops2[1][0],mypops2[2][0])
mylabel=""
mec="black"

myind="XSJ"
varypop="CZT_c"
ypops=mycombo
mytuples=[(0,3),(1,2)]
mypops2=[out,ypops,[varypop],myind]

Zaryall1 = np.transpose(pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z'))
Daryall1 = np.transpose(pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D'))
SEaryall1=Daryall1/Zaryall1 
mynewpops2=[out2]+mypops2[1:]
Zarytv1 = np.transpose(pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z'))
Darytv1 = np.transpose(pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D'))
SEarytv1=Darytv1/Zarytv1

for ind,i in enumerate(ypops):
    ax1.plot([Daryall1[0][ind]+2*SEaryall1[0][ind],Daryall[0][ind]-2*SEaryall1[0][ind]],[ind,ind],'--',color='black',linewidth=0.5)
        
    wantedcolors1="yellow"#"#c9e9f6" #"blue"
    #ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    #ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    #ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=2*SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall1[0][ind],ind,'.')
    
    wantedcolors="yellow"
    ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall[0][ind],ind,'.')

        
myys = np.array(range(len(mynames)))
ax1.set_yticks(myys)
ax1.set_ylabel("X  ",fontsize=16,rotation=0)
ax1.set_yticklabels(mynames,fontsize=14)#,fontsize=12)

ax1.set_ylim(-1,len(mynames))
ax1.set_xlim(myxmin[0],myxmax[0])
xlabel = ax1.get_xticks().tolist()
ax1.set_title(mylabel,fontsize=15) #weight='bold')
ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
for myline in lines:
    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)
ax1.tick_params(length=2,labelsize=14)
#ax1.set_xlabel("D",fontsize=14)
ax1.text(myxmax[0]+0.09,len(mynames)-5.5,"Dashed line\nindicates significant\ncladal relationship\nbetween X and\nCizhutuo relative\nto Xiaoshuijin",
         fontsize=18,horizontalalignment='center')

##LIANGSHAN CONNECTION TO XSJ
pdp=["Shaanxi_QIN","MIN","Sichuan_QIO",
     "Sichuan_DXL","Sichuan_XXL","Sichuan_LS","CZT_c","XSJ"][:-3]
mynames=["QIN","MIN","QIO","DXL","XXL","LS","CZT","XSJ"][:-3]
mycombo=pdp
myxmin=[-0.025]*len(mycombo)
myxmax=[0.03]*len(mycombo)

ax1=fig.add_subplot(3,1,2)
myind="Sichuan_LS"
varypop="CZT_c"
ypops=mycombo
mytuples=[(0,3),(1,2)]
mypops2=[out,[varypop],ypops,myind]

Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall=Daryall/Zaryall 
mynewpops2=[out2]+mypops2[1:]
Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv=Darytv/Zarytv
xlabel="D(%s,%s;%s,X)" % (mypops2[0],mypops2[1][0],"QIN")#(mypops2[0],mypops2[1][0],mypops2[2][0])
mylabel=""
mec="black"

myind="Sichuan_LS"
varypop="XSJ"
ypops=mycombo
mytuples=[(0,3),(1,2)]
mypops2=[out,[varypop],ypops,myind]

Zaryall1 = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall1 = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall1=Daryall1/Zaryall1 
mynewpops2=[out2]+mypops2[1:]
Zarytv1 = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv1 = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv1=Darytv1/Zarytv1

for ind,i in enumerate(ypops):
    #if ind!=6:
    #    ax1.plot([Daryall1[0][ind]+2*SEaryall1[0][ind],Daryall[0][ind]-2*SEaryall1[0][ind]],[ind,ind],'--',color='black',linewidth=0.5)
        
    wantedcolors1="#178f17"#"#c9e9f6" #"blue"
    #ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    #ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    #ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=2*SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall1[0][ind],ind,'.')
    
    wantedcolors="#00a8c4"
    ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall[0][ind],ind,'.')

        
myys = np.array(range(len(mynames)))
ax1.set_yticks(myys)
ax1.set_ylabel("X  ",fontsize=16,rotation=0)
ax1.set_yticklabels(mynames,fontsize=14)#,fontsize=12)

ax1.set_ylim(-1,len(mynames))
ax1.set_xlim(myxmin[0],myxmax[0])
xlabel = ax1.get_xticks().tolist()
ax1.set_title(mylabel,fontsize=15) #weight='bold')
ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
for myline in lines:
    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)
ax1.tick_params(length=2,labelsize=14)
#ax1.set_xlabel("D",fontsize=14)
ax1.text(myxmax[0]+0.025,len(mynames)-4.3,"Xiaoshuijin (green)\nshows connection to\nLiangshan pandas\nnot observed for\nCizhutuo (blue)",
         fontsize=18,horizontalalignment='center')    

##QINLING NO CONNECTION TO XSJ
pdp=["Shaanxi_QIN","MIN","Sichuan_QIO",
     "Sichuan_DXL","Sichuan_XXL","Sichuan_LS","CZT_c","XSJ"][1:-2]
mynames=["QIN","MIN","QIO","DXL","XXL","LS","CZT","XSJ"][1:-2]
mycombo=pdp
lines=[1.5]
myxmin=[-0.03]*len(mycombo)
myxmax=[0.01]*len(mycombo)

ax1=fig.add_subplot(3,1,3)
myind="Shaanxi_QIN"
varypop="CZT_c"
ypops=mycombo
mytuples=[(0,3),(1,2)]
mypops2=[out,[varypop],ypops,myind]

Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall=Daryall/Zaryall 
mynewpops2=[out2]+mypops2[1:]
Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv=Darytv/Zarytv
xlabel="D(%s,%s;%s,X)" % (mypops2[0],mypops2[1][0],"QIN")#(mypops2[0],mypops2[1][0],mypops2[2][0])
mylabel=""
mec="black"

myind="Shaanxi_QIN"
varypop="XSJ"
ypops=mycombo
mytuples=[(0,3),(1,2)]
mypops2=[out,[varypop],ypops,myind]

Zaryall1 = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall1 = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall1=Daryall1/Zaryall1 
mynewpops2=[out2]+mypops2[1:]
Zarytv1 = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv1 = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv1=Darytv1/Zarytv1

for ind,i in enumerate(ypops):
    #if ind!=6:
    #    ax1.plot([Daryall1[0][ind]+2*SEaryall1[0][ind],Daryall[0][ind]-2*SEaryall1[0][ind]],[ind,ind],'--',color='black',linewidth=0.5)
        
    wantedcolors1="#178f17"#"#c9e9f6" #"blue"
    #ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    #ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    #ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=2*SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall1[0][ind],ind,'.')
    
    wantedcolors="#00a8c4"
    ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall[0][ind],ind,'.')

        
myys = np.array(range(len(mynames)))
ax1.set_yticks(myys)
ax1.set_ylabel("X  ",fontsize=16,rotation=0)
ax1.set_yticklabels(mynames,fontsize=14)#,fontsize=12)

ax1.set_ylim(-1,len(mynames))
ax1.set_xlim(myxmin[0],myxmax[0])
xlabel = ax1.get_xticks().tolist()
ax1.set_title(mylabel,fontsize=15) #weight='bold')
ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
for myline in lines:
    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)
ax1.tick_params(length=2,labelsize=14)
ax1.set_xlabel("D",fontsize=14)
ax1.text(myxmax[0]+0.018,len(mynames)-4.3,"Most present-day\npandas show\nconnection to\nXiaoshuijin relative\nto Qinling pandas",
         fontsize=18,horizontalalignment='center')    

plt.tight_layout()
plt.subplots_adjust(wspace=0.05)
#plt.show()
 

pp.savefig(bbox_inches = "tight")
pp.close()

##UPDATED DEC 20##

# %%
ax1.text?

# %%
##CZT and PDP form a clade relative to XSJ

import numpy as np
import plateaumodules as pm
#from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import rcParams

rcParams['font.family'] = 'Helvetica-Normal'

pD="/public/adna/qiaomei_fu/panda/geno/F4.mask0.9_random_25K8K_noO_2ind/"
#pp = PdfPages('/mnt/solexa/mel_yang/panda/Fig3_Dstat.pdf')
fhall="F4.list.all"
fhtv="F4.list.alltv"
out,out2=("polarbear","polarbear")

pdp=["Shaanxi_QIN","Gansu_MIN","Sichuan_MIN","Sichuan_QIO",
     "Sichuan_DXL","Sichuan_XXL","Sichuan_LS","25K","8K"][:-2]
mynames=["QIN","MIN_G","MIN_S","QIO","DXL","XXL","LS","CZT","XSJ"][:-2]
mycombo=pdp

wantedcolors=["blue"]*len(mycombo)
lines=[2.5]
myxmin=[-0.035]*len(mycombo)
myxmax=[0.035]*len(mycombo)

fig = plt.figure(figsize=(4,12))
#newfile=open(pD+"Fig2a_dat.txt",'w')
##Liangshan D(Polar Bear, XSJ; CZT, X)
#newfile.write("EA vs Tibetan\n")
ax1=fig.add_subplot(4,1,1)
myind="8K"
varypop="25K"
ypops=mycombo
mytuples=[(0,2),(1,3)]
mypops2=[out,[varypop],myind,ypops]

Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall=Daryall/Zaryall 
mynewpops2=[out2]+mypops2[1:]
Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv=Darytv/Zarytv
xlabel="D(%s,%s;%s,X)" % (mypops2[0],mypops2[1][0],"QIN")#(mypops2[0],mypops2[1][0],mypops2[2][0])
mylabel=""
mec="black"

myind="8K"
varypop="25K"
ypops=mycombo
mytuples=[(0,3),(1,2)]
mypops2=[out,ypops,[varypop],myind]

Zaryall1 = np.transpose(pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z'))
Daryall1 = np.transpose(pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D'))
SEaryall1=Daryall1/Zaryall1 
mynewpops2=[out2]+mypops2[1:]
Zarytv1 = np.transpose(pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z'))
Darytv1 = np.transpose(pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D'))
SEarytv1=Darytv1/Zarytv1

for ind,i in enumerate(ypops):
    if ind!=6:
        ax1.plot([Daryall1[0][ind]+2*SEaryall1[0][ind],Daryall[0][ind]-2*SEaryall1[0][ind]],[ind,ind],'--',color='black',linewidth=0.5)
        
    wantedcolors1="yellow"#"#c9e9f6" #"blue"
    #ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    #ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    #ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=2*SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall1[0][ind],ind,'.')
    
    wantedcolors="yellow"
    ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall[0][ind],ind,'.')

        
myys = np.array(range(len(mynames)))
ax1.set_yticks(myys)
ax1.set_ylabel("X",fontsize=16,rotation=0)
ax1.set_yticklabels(mynames,fontsize=14)#,fontsize=12)

ax1.set_ylim(-1,len(mynames))
ax1.set_xlim(myxmin[0],myxmax[0])
xlabel = ax1.get_xticks().tolist()
ax1.set_title(mylabel,fontsize=15) #weight='bold')
ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
for myline in lines:
    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)
ax1.tick_params(length=2,labelsize=14)
#ax1.set_xlabel("D",fontsize=14)
ax1.text(myxmax[0]+0.035,len(mynames)-6.5,"Dashed line\nindicates significant\ncladal relationship\nbetween X and\nCizhutuo relative\nto Xiaoshuijin",
         fontsize=18,horizontalalignment='center')

##LIANGSHAN CONNECTION TO XSJ
pdp=["Shaanxi_QIN","Gansu_MIN","Sichuan_MIN","Sichuan_QIO",
     "Sichuan_DXL","Sichuan_XXL","Sichuan_LS","25K","8K"][:-3]
mynames=["QIN","MIN_G","MIN_S","QIO","DXL","XXL","LS","CZT","XSJ"][:-3]
mycombo=pdp
myxmin=[-0.01]*len(mycombo)
myxmax=[0.035]*len(mycombo)

ax1=fig.add_subplot(4,1,2)
myind="Sichuan_LS"
varypop="25K"
ypops=mycombo
mytuples=[(0,3),(1,2)]
mypops2=[out,[varypop],ypops,myind]

Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall=Daryall/Zaryall 
mynewpops2=[out2]+mypops2[1:]
Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv=Darytv/Zarytv
xlabel="D(%s,%s;%s,X)" % (mypops2[0],mypops2[1][0],"QIN")#(mypops2[0],mypops2[1][0],mypops2[2][0])
mylabel=""
mec="black"

myind="Sichuan_LS"
varypop="8K"
ypops=mycombo
mytuples=[(0,3),(1,2)]
mypops2=[out,[varypop],ypops,myind]

Zaryall1 = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall1 = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall1=Daryall1/Zaryall1 
mynewpops2=[out2]+mypops2[1:]
Zarytv1 = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv1 = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv1=Darytv1/Zarytv1

for ind,i in enumerate(ypops):
    #if ind!=6:
    #    ax1.plot([Daryall1[0][ind]+2*SEaryall1[0][ind],Daryall[0][ind]-2*SEaryall1[0][ind]],[ind,ind],'--',color='black',linewidth=0.5)
        
    wantedcolors1="#178f17"#"#c9e9f6" #"blue"
    #ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    #ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    #ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=2*SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall1[0][ind],ind,'.')
    
    wantedcolors="#00a8c4"
    ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall[0][ind],ind,'.')

        
myys = np.array(range(len(mynames)))
ax1.set_yticks(myys)
ax1.set_ylabel("X",fontsize=16,rotation=0)
ax1.set_yticklabels(mynames,fontsize=14)#,fontsize=12)

ax1.set_ylim(-1,len(mynames))
ax1.set_xlim(myxmin[0],myxmax[0])
xlabel = ax1.get_xticks().tolist()
ax1.set_title(mylabel,fontsize=15) #weight='bold')
ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
for myline in lines:
    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)
ax1.tick_params(length=2,labelsize=14)
#ax1.set_xlabel("D",fontsize=14)
ax1.text(myxmax[0]+0.025,len(mynames)-5.5,"Xiaoshuijin (green)\nshows connection to\nLiangshan pandas\nnot observed for\nCizhutuo (blue)",
         fontsize=18,horizontalalignment='center')    

##LIANGSHAN CONNECTION TO XSJ NOT DIRECT FROM LIANGSHAN
pdp=["Shaanxi_QIN","Gansu_MIN","Sichuan_MIN","Sichuan_QIO",
     "Sichuan_DXL","Sichuan_XXL","Sichuan_LS","25K","8K"][:-3]
mynames=["QIN","MIN_G","MIN_S","QIO","DXL","XXL","LS","CZT","XSJ"][:-3]
mycombo=pdp
myxmin=[-0.01]*len(mycombo)
myxmax=[0.15]*len(mycombo)

ax1=fig.add_subplot(4,1,3)
myind="Shaanxi_QIN"
varypop="Sichuan_LS"
ypops=mycombo
mytuples=[(0,2),(1,3)]
mypops2=[out,[varypop],myind,ypops]

Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall=Daryall/Zaryall 
mynewpops2=[out2]+mypops2[1:]
Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv=Darytv/Zarytv
xlabel="D(%s,%s;%s,X)" % (mypops2[0],mypops2[1][0],"QIN")#(mypops2[0],mypops2[1][0],mypops2[2][0])
mylabel=""
mec="black"

myind="Sichuan_LS"
varypop="8K"
ypops=mycombo
mytuples=[(0,3),(1,2)]
mypops2=[out,[varypop],ypops,myind]

Zaryall1 = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall1 = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall1=Daryall1/Zaryall1 
mynewpops2=[out2]+mypops2[1:]
Zarytv1 = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv1 = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv1=Darytv1/Zarytv1

for ind,i in enumerate(ypops):
    #if ind!=6:
    #    ax1.plot([Daryall1[0][ind]+2*SEaryall1[0][ind],Daryall[0][ind]-2*SEaryall1[0][ind]],[ind,ind],'--',color='black',linewidth=0.5)
        
    wantedcolors1="#178f17"#"#c9e9f6" #"blue"
    #ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    #ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    #ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=2*SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall1[0][ind],ind,'.')
    
    wantedcolors="#00a8c4"
    ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall[0][ind],ind,'.')
print Daryall
        
myys = np.array(range(len(mynames)))
ax1.set_yticks(myys)
ax1.set_ylabel("X",fontsize=16,rotation=0)
ax1.set_yticklabels(mynames,fontsize=14)#,fontsize=12)

ax1.set_ylim(-1,len(mynames))
ax1.set_xlim(myxmin[0],myxmax[0])
xlabel = ax1.get_xticks().tolist()
ax1.set_title(mylabel,fontsize=15) #weight='bold')
ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
for myline in lines:
    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)
ax1.tick_params(length=2,labelsize=14)
#ax1.set_xlabel("D",fontsize=14)
ax1.text(myxmax[0]+0.025,len(mynames)-5.5,"Correlation between\nXiaoshuijin connection\nand connection to\nLiangshan pandas",
         fontsize=18,horizontalalignment='center')


##QINLING NO CONNECTION TO XSJ
pdp=["Shaanxi_QIN","Gansu_MIN","Sichuan_MIN","Sichuan_QIO",
     "Sichuan_DXL","Sichuan_XXL","Sichuan_LS","25K","8K"][1:-2]
mynames=["QIN","MIN_G","MIN_S","QIO","DXL","XXL","LS","CZT","XSJ"][1:-2]
mycombo=pdp
lines=[1.5]
myxmin=[-0.035]*len(mycombo)
myxmax=[0.01]*len(mycombo)

ax1=fig.add_subplot(4,1,4)
myind="Shaanxi_QIN"
varypop="25K"
ypops=mycombo
mytuples=[(0,3),(1,2)]
mypops2=[out,[varypop],ypops,myind]

Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall=Daryall/Zaryall 
mynewpops2=[out2]+mypops2[1:]
Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv=Darytv/Zarytv
xlabel="D(%s,%s;%s,X)" % (mypops2[0],mypops2[1][0],"QIN")#(mypops2[0],mypops2[1][0],mypops2[2][0])
mylabel=""
mec="black"

myind="Shaanxi_QIN"
varypop="8K"
ypops=mycombo
mytuples=[(0,3),(1,2)]
mypops2=[out,[varypop],ypops,myind]

Zaryall1 = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
Daryall1 = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
SEaryall1=Daryall1/Zaryall1 
mynewpops2=[out2]+mypops2[1:]
Zarytv1 = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
Darytv1 = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
SEarytv1=Darytv1/Zarytv1

for ind,i in enumerate(ypops):
    #if ind!=6:
    #    ax1.plot([Daryall1[0][ind]+2*SEaryall1[0][ind],Daryall[0][ind]-2*SEaryall1[0][ind]],[ind,ind],'--',color='black',linewidth=0.5)
        
    wantedcolors1="#178f17"#"#c9e9f6" #"blue"
    #ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    #ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    #ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall1[0][ind],ind,xerr=2*SEaryall1[0][ind],color=wantedcolors1,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall1[0][ind],ind,'.')
    
    wantedcolors="#00a8c4"
    ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
    ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
    ax1.plot(Daryall[0][ind],ind,'.')

        
myys = np.array(range(len(mynames)))
ax1.set_yticks(myys)
ax1.set_ylabel("X",fontsize=16,rotation=0)
ax1.set_yticklabels(mynames,fontsize=14)#,fontsize=12)

ax1.set_ylim(-1,len(mynames))
ax1.set_xlim(myxmin[0],myxmax[0])
xlabel = ax1.get_xticks().tolist()
ax1.set_title(mylabel,fontsize=15) #weight='bold')
ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
for myline in lines:
    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)
ax1.tick_params(length=2,labelsize=14)
ax1.set_xlabel("D",fontsize=14)
ax1.text(myxmax[0]+0.025,len(mynames)-5.5,"Most present-day\npandas show\nconnection to\nXiaoshuijin relative\nto Qinling pandas",
         fontsize=18,horizontalalignment='center')    

plt.tight_layout()
plt.subplots_adjust(wspace=0.05)
plt.show()
 

#pp.savefig(bbox_inches = "tight")
#pp.close()
# Out:
# [[   nan 0.0384 0.0549 0.1024 0.1086 0.0979]]

# %% [markdown]
# ## qpWave results looking at which N. Asn ancient popns can be considered as from the same ancestral source.
# Populations considered include:
#
# Tianyuan
# Boisman
# HDYM1
# Boshan
# Linzi
# Ulchi
# Han_NChina

# %%
# %%writefile /home/mel_yang/projects/neolithic/qpwave_bois_nopdEAS.py
import projmodules as pm
from multiprocessing import Pool
import itertools


outs=[["Yoruba","Ju_hoan_North","Dinka","Mbuti"], #0
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge"], #1
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Kostenki14"], #2
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Kostenki14","UstIshim"], #3
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Kostenki14","Vestonice16","UstIshim"], #4
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Papuan","Kostenki14","Vestonice16","UstIshim"], #5
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","UstIshim"], #6
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Kostenki14","Vestonice16","UstIshim"], #7
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Kostenki14","Vestonice16"], #8
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Papuan","Kostenki14","Vestonice16","UstIshim"], #9
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Papuan","Onge"], #10
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Papuan","Onge","UstIshim"]] #11
def dowork(mytup):
    out,outid=mytup
    pD="/mnt/solexa/mel_yang/bronzeage/data/"
    fh="ind_A_v13_TBH5"
    
    #left=[["Ulchi","Boisman_MN"], ##nosubset
    #       ["Ulchi","Boisman_MN","Han_HGDP"],
    #       ["Ulchi","Boisman_MN","HDYM1"],
    #       ["Ulchi","Boisman_MN","HDYM1","Boshan"],
    #       ["Ulchi","Boisman_MN","HDYM1""Boshan","Linzi"],
    #       ["Ulchi","Boisman_MN","HDYM1""Boshan","Linzi","Tianyuan"],
    #       ["Ulchi","Boisman_MN","HDYM1","Tianyuan"], #6
    #       ["Ulchi","Boisman_MN","HDYM1","Boshan","Tianyuan"]]
    #left=[["Boisman_MN","HDYM1"], ##nopdEAS subset
    #      ["Boisman_MN","Boshan"],
    #      ["Boisman_MN","Linzi"],
    #      ["Boisman_MN","Tianyuan"],
    #      ["Boisman_MN","Tianyuan","HDYM1"], ##4
    #      ["Boisman_MN","Tianyuan","Boshan"],
    #      ["Boisman_MN","HDYM1","Boshan"],
    #      ["Boisman_MN","HDYM1""Boshan","Linzi"],
    #      ["Boisman_MN","HDYM1""Boshan","Linzi","Tianyuan"],
    #      ["Boisman_MN","HDYM1","Boshan","Tianyuan"]]
    
    left=[["Ulchi","HDYM1"], ##addBbdong subset
          ["Han_NChina","HDYM1"],
          ["HDYM1","Tianyuan"],
          ["Boisman_MN","Bbdong"],
          ["HDYM1","Bbdong"],
          ["HDYM1","Boisman_MN","Bbdong"],
          ["Boshan","Bbdong"],
          ["Boisman_MN","HDYM1","Boshan","Linzi"],
          ["Boisman_MN","HDYM1","Boshan","Linzi","Tianyuan"],
          ["Boisman_MN","HDYM1","Boshan","Tianyuan"]]
    #left=[["Han_NChina","Boisman_MN"], ##Han_NChina subset
    #       ["Han_NChina","Boisman_MN","Han_HGDP"],
    #       ["Han_NChina","Boisman_MN","HDYM1"],
    #       ["Han_NChina","Boisman_MN","HDYM1","Boshan"],
    #       ["Han_NChina","Boisman_MN","HDYM1""Boshan","Linzi"],
    #       ["Han_NChina","Boisman_MN","HDYM1""Boshan","Linzi","Tianyuan"],
    #       ["Han_NChina","Boisman_MN","HDYM1","Tianyuan"],
    #       ["Han_NChina","Boisman_MN","HDYM1","Boshan","Tianyuan"]]
    
    for ind,myleft in enumerate(left):
        #if ind==0: continue
        bck = 'addBbdong_Bois%i_out%i' % (ind,outid) ##nopdEAS
        pm.wave_run(myleft, out, pD, fh, bck)
 
myinputs=[(out,ind) for ind,out in enumerate(outs) if ind in [4,5,8,11]]

mypool = Pool(4)
results = mypool.map(dowork, myinputs)
# Out:
# Overwriting /home/mel_yang/projects/neolithic/qpwave_bois_nopdEAS.py

# %% [markdown]
# ## Add qpAdm, which populations can be explained as a mixture of others?
#
# Focus on Boisman_MN, HDYM1, Tianyuan, and think about whether Ulchi is mixture of Boisman_MN and other.
#
# The first version (top) parallelizes based on outgroup and second version (bottom) parallelizes based on leftpop.

# %%
# %%writefile /home/mel_yang/projects/neolithic/qpwave_bois_TY_aff.py
import projmodules as pm
from multiprocessing import Pool
import itertools


outs=[["Yoruba","Ju_hoan_North","Dinka","Mbuti"], #0
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge"], #1
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Kostenki14"], #2
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Kostenki14","UstIshim"], #3
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Kostenki14","Vestonice16","UstIshim"], #4
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Papuan","Kostenki14","Vestonice16","UstIshim"], #5
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","UstIshim"], #6
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Kostenki14","Vestonice16","UstIshim"], #7
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Kostenki14","Vestonice16"], #8
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Papuan","Kostenki14","Vestonice16","UstIshim"], #9
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Papuan","Onge"], #10
      ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Papuan","Onge","UstIshim"]] #11
def dowork(mytup):
    out,outid=mytup
    pD="/mnt/solexa/mel_yang/bronzeage/data/"
    fh="ind_A_v13_TBH5"
    
    #left=[["Boisman_MN","Tianyuan","Ulchi"],##TYaff
    #      ["HDYM1","Tianyuan","Ulchi"],
    #      ["Boshan","Tianyuan","Ulchi"],
    #      ["Linzi","Tianyuan","Ulchi"],
    #      ["Boisman_MN","Tianyuan","Han_NChina"],
    #      ["HDYM1","Tianyuan","Han_NChina"],
    #      ["Boshan","Tianyuan","Han_NChina"],
    #      ["Linzi","Tianyuan","Han_NChina"]]
    left=[["Tianyuan","Boisman_MN","Ulchi"], ##TYaffA
          ["Tianyuan","HDYM1","Ulchi"],
          ["Tianyuan","Boisman_MN","Han_NChina"],
          ["Tianyuan","HDYM1","Han_NChina"],
          ["Ulchi","Tianyuan","Boisman_MN"],
          ["Ulchi","Han_NChina","Boisman_MN"],
          ["Ulchi","Han_NChina","Boisman_MN"],
          ["HDYM1","Boisman_MN","Tianyuan"], #7
          ["Boisman_MN","HDYM1","Tianyuan"], #8
          ["Tianyuan","Boisman_MN","HDYM1"], #9
          ["Boisman_MN","Tianyuan","Boshan"],
          ["HDYM1","Tianyuan","Boshan"]]
    left=[["Boisman_MN","HDYM1","Tianyuan","Ulchi"], ##TYaffB
          ["Ulchi","HDYM1","Tianyuan","Boisman_MN"],
          ["Tianyuan","HDYM1","Ulchi","Boisman_MN"],
          ["HDYM1","Ulchi","Tianyuan","Boisman_MN"],
          ["HDYM1","Ulchi","Tianyuan","Boisman_MN"],
          ##["Boisman_MN","HDYM1","Tianyuan"]] In TYaffA8
          ##["HDYM1","Tianyuan","Boisman_MN"]] In TYaffA7
          ##["Tianyuan","HDYM1","Boisman_MN"]] In TYaffA9
    
    for ind,myleft in enumerate(left):
        bck = 'TYaffB_EAS_%i_out%i' % (ind,outid)
        pm.wave_run(myleft, out, pD, fh, bck)
        pm.wave_adm_run(myleft, out, pD, fh, bck)
myinputs=[(out,ind) for ind,out in enumerate(outs) if ind in [3,4,5,7,9]]
print myinputs
mypool = Pool(5)
results = mypool.map(dowork, myinputs)
# Out:
# Overwriting /home/mel_yang/projects/neolithic/qpwave_bois_TY_aff.py

# %%
# %%writefile /home/mel_yang/projects/neolithic/qpwave_bois_TY_aff.py
import projmodules as pm
from multiprocessing import Pool
import itertools

left=[["Tianyuan","Boisman_MN","Ulchi"], ##TYaffA
      ["Tianyuan","HDYM1","Ulchi"],
      ["Tianyuan","Boisman_MN","Han_NChina"],
      ["Tianyuan","HDYM1","Han_NChina"],
      ["Ulchi","Tianyuan","Boisman_MN"],
      ["Ulchi","Han_NChina","Boisman_MN"],
      ["Ulchi","Han_NChina","Boisman_MN"],
      ["HDYM1","Boisman_MN","Tianyuan"],
      ["Boisman_MN","HDYM1","Tianyuan"],
      ["Tianyuan","Boisman_MN","HDYM1"],
      ["Boisman_MN","Tianyuan","Boshan"],
      ["HDYM1","Tianyuan","Boshan"]]
left=[["Boisman_MN","HDYM1","Tianyuan","Ulchi"], ##TYaffB
      ["Ulchi","HDYM1","Tianyuan","Boisman_MN"],
      ["Tianyuan","HDYM1","Ulchi","Boisman_MN"],
      ["HDYM1","Ulchi","Tianyuan","Boisman_MN"],
      ["HDYM1","Ulchi","Tianyuan","Boisman_MN"], ##repeat!
      ["HDYM1","Ulchi","Tianyuan","Boisman_MN"], ##repeat!
      ["Boisman_MN","Han_NChina","Tianyuan"], #6
      ["Boisman_MN","Ulchi","Tianyuan"],
      ["HDYM1","Ulchi","Tianyuan"],
      ["HDYM1","Han_NChina","Tianyuan"],
      ["Boisman_MN","HDYM1","Tianyuan","Ulchi","Han_NChina"],
      ["HDYM1","Boisman_MN","Tianyuan","Ulchi","Han_NChina"],
      ["Ulchi","HDYM1","Boisman_MN","Tianyuan","Han_NChina"]]  

left=[["Boisman_MN","HDYM1","Japanese","Ulchi"], ##Boshan
      ["Boisman_MN","HDYM1","Han_NChina","Ulchi"],
      ["Boisman_MN","HDYM1","Maonan","Ulchi"],
      ["Boisman_MN","HDYM1","Boshan"],
      ["HDYM1","Boisman_MN","Boshan"],
      ["Boshan","Boisman_MN","HDYM1"],
      ["Boshan","Boisman_MN","HDYM1","Bbdong","Tianyuan"],
      ["Boisman_MN","Boshan","HDYM1","Bbdong","Tianyuan"],
      ["Bbdong","Boisman_MN","Boshan","HDYM1","Tianyuan"],
      ["HDYM1","Bbdong","Boisman_MN","Boshan","Tianyuan"],
      ["Boshan","Boisman_MN","HDYM1","Ulchi"],
      ["Boshan","Boisman_MN","HDYM1","Han_NChina"],
      ["Boshan","Boisman_MN","HDYM1","Maonan"],
      ["Boshan","Boisman_MN","HDYM1","Japanese"]]   

def dowork(mytup):
    myleft,myleftid=mytup
    pD="/mnt/solexa/mel_yang/bronzeage/data/"
    fh="ind_A_v13_TBH5"
    
    outs=[["Yoruba","Ju_hoan_North","Dinka","Mbuti"], #0
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge"], #1
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Kostenki14"], #2
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Kostenki14","UstIshim"], #3
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Kostenki14","Vestonice16","UstIshim"], #4
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Papuan","Kostenki14","Vestonice16","UstIshim"], #5
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","UstIshim"], #6
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Kostenki14","Vestonice16","UstIshim"], #7
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Kostenki14","Vestonice16"], #8
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Papuan","Kostenki14","Vestonice16","UstIshim"], #9
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Papuan","Onge"], #10
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Papuan","Onge","UstIshim"]] #11
    
    #left=[["Boisman_MN","Tianyuan","Ulchi"],
    #      ["HDYM1","Tianyuan","Ulchi"],
    #      ["Boshan","Tianyuan","Ulchi"],
    #      ["Linzi","Tianyuan","Ulchi"],
    #      ["Boisman_MN","Tianyuan","Han_NChina"],
    #      ["HDYM1","Tianyuan","Han_NChina"],
    #      ["Boshan","Tianyuan","Han_NChina"],
    #      ["Linzi","Tianyuan","Han_NChina"]]


    for outid,out in enumerate(outs):
        if outid not in [3,4,5,8,9,11]: continue
        bck = 'Boshan_EAS_%i_out%i' % (myleftid,outid)
        pm.wave_run(myleft, out, pD, fh, bck)
        pm.wave_adm_run(myleft, out, pD, fh, bck)
myinputs=[(myleft,ind) for ind,myleft in enumerate(left)] 
print myinputs
mypool = Pool(14)
results = mypool.map(dowork, myinputs)
# Out:
# Overwriting /home/mel_yang/projects/neolithic/qpwave_bois_TY_aff.py

# %% [markdown]
# ## Bash script
# This is a good script to copy/paste into terminal to grab relevant information from qpAdm.

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/bronzeage/data/"
# for i in 10 11 12; do
#     myf="${pd}ind_A_v13_TBH5.adm.TYaffB_EAS_${i}_out5.log" ;
#     echo "";
#     echo "----------------"${myf}"--------------------";
#     myind=$(grep -n "Jackknife mean:" ${myf} | cut -d":" -f1);
#     #step=15;   ##3 popns
#     #step=22;   ##4 popns
#     step=32;    ##5 popns
#     myind2=$(echo $((${myind}+${step})));
#     #head -n ${myind2} ${myf} | tail -n16; ##3 popns
#     #head -n ${myind2} ${myf} | tail -n23;  ##4 popns
#     head -n ${myind2} ${myf} | tail -n33; ##5 popns
#     done
# Out:
# ----------------/mnt/solexa/mel_yang/bronzeage/data/ind_A_v13_TBH5.adm.TYaffB_EAS_10_out5.log--------------------
# Jackknife mean:      0.229411011     0.133404806     1.217129790    -0.579945608
#       std. errors:     0.407     0.208     1.535     1.322
#
# error covariance (* 1000000)
#     165750     -32586    -196083      62919
#     -32586      43218    -180882     170250
#    -196083    -180882    2357306   -1980340
#      62919     170250   -1980340    1747171
#
#
# summ: Boisman_MN    4      0.612645     0.229     0.133     1.217    -0.580 165750 -32586 -196083 62919 43218 -180882 170250 2357306 -1980340 1747171
#
#     fixed pat  wt  dof     chisq       tail prob
#          0000  0     5     3.571        0.612645     0.173     0.041     2.208    -1.422  infeasible
#          0001  1     6     7.760         0.25623     0.173     0.041     2.208    -1.422  infeasible
#          0010  1     6     9.933        0.127487     0.443     0.149     0.000     0.407
# ...

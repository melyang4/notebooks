# %% [markdown]
# ## qpAdm for comparing LiangDao to Europeans
#
# Combinations I want to consider are: (X, S1, S2)
#
# 1. LiangDao; S. Asns+LL+TY, Europeans
# 2. Europeans;

# %%
# %%writefile /mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/qpwave_inLD.py
import projmodules as pm
from multiprocessing import Pool
import itertools

weas=['Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha','Zongri', 'Chokhopani', 'Mebrak', 'Samdzong']
neas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Daur','Hezhen','Mongola','Ulchi','Xibo']
seas=['Japanese','Korean','Han_NChina','Han_Shandong','Han_HGDP','Dai','Li','Maonan','Miao','She',
       'Zhuang','Ami_Stoneking','Atayal_Stoneking','Kinh_Vietnam_KHV']
seas=seas[::-1]
pubanceas=['Longlin', 'LiangDao']

#left=[[i, j, "Longlin"] for i in seas for j in neas if i != j] #neas+weas+seas+["LiangDao"]
left=[["LiangDao",i, "ElMiron"] for i in ["Tianyuan","Longlin"]+seas+neas+weas]
#left=[["ElMiron","Kostenki14", i] for i in ["LiangDao","Tianyuan","Longlin"]+seas+neas+weas]
left+=[["Longlin",i, "ElMiron"] for i in ["Tianyuan","LiangDao"]+seas+neas+weas]

left=[["LiangDao",i, j] for i in ["Tianyuan","Longlin"]+seas for j in ["Vestonice16","Ostuni1","Villabruna","Loschbour"]]
left=[["Boshan",i, j] for i in ["Tianyuan","Longlin"]+seas for j in ["ElMiron","Vestonice16","Ostuni1","Villabruna","Loschbour"]]
left=[["Linzi",i, j] for i in ["Tianyuan","Longlin"]+seas for j in ["ElMiron","Vestonice16"]]

left=[["Daur",i, j] for i in ["Tianyuan","Longlin"]+seas for j in ["ElMiron","Vestonice16"]]
left=[[j,i, "French"] for i in ["Tianyuan","Longlin","LiangDao"]+seas for j in neas+weas+seas if j !=i ]

def dowork(mytup):
    myleft,myleftid=mytup
    outpD="/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/"
    pD="/mnt/solexa/mel_yang/bronzeage/data/"
    fh="ind_A_v13_TBH5"
    
    outs=[["Yoruba","Ju_hoan_North","Dinka","Mbuti"], #0
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge"], #1
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Kostenki14"], #2
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Kostenki14","UstIshim"], #3
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Kostenki14","Vestonice16","UstIshim"], #4
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Papuan","Kostenki14","Vestonice16","UstIshim"], #5
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","UstIshim"], #6
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Kostenki14","Vestonice16","UstIshim"], #7
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Kostenki14","Vestonice16"], #8
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Papuan","Kostenki14","Vestonice16","UstIshim"], #9
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Papuan","Onge"], #10
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Papuan","Onge","UstIshim"], #11
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Papuan","Kostenki14","Vestonice16","UstIshim","Tianyuan"], #12
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Kostenki14","Vestonice16","UstIshim","Tianyuan"], #13
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Papuan","Kostenki14","Vestonice16","UstIshim","Malta1"], #14
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Papuan","Kostenki14","UstIshim"], #15
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Papuan","Oase1","UstIshim"]] #16
          

    for outid,out in enumerate(outs):
        if outid not in [15,16]: continue #[5,7,12,13]: continue
        bck = 'X_%s_S1_%s_S2_%s_out%i' % tuple(myleft+[outid])
        pm.wave_run(myleft, out, pD, fh, bck, outpd=outpD)
        pm.wave_adm_run(myleft, out, pD, fh, bck, outpd=outpD)
myinputs=[(myleft,ind,) for ind,myleft in enumerate(left)] 
print len(myinputs)
mypool = Pool(14)
results = mypool.map(dowork, myinputs)
# Out:
# Overwriting /mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/qpwave_inLD.py

# %% [markdown]
# Expand to more populations:
# 1. Switch Atayal, LL, LD, BS each in turn as target, others as reference - basically all look same as each other? (need 2 pops to explain 4)

# %% [markdown]
# ## Switch so think about NAsn having something extra that is NOT in Longlin/LiangDao/SAsns (bringing SAsns closer to Longlin/LD)

# %% [markdown]
# ## See results for qpWave

# %%
pd="/mnt/solexa/mel_yang/bronzeage/data/"
pd="/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/"
seas=['Japanese','Korean','Han_NChina','Han_Shandong','Han_HGDP','Dai','Li','Maonan','Miao','She',
       'Zhuang','Ami_Stoneking','Atayal_Stoneking','Kinh_Vietnam_KHV']
#seas=['Han_NChina','Han_Shandong','Han_HGDP','Dai','Li','Maonan','Miao','She',
seas=['Zhuang','Ami_Stoneking','Atayal_Stoneking','Kinh_Vietnam_KHV']
myeas=["Longlin","LiangDao","Atayal_Stoneking","Japanese","Daur"]
neas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Daur','Hezhen','Mongola','Ulchi','Xibo']
weas=['Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha','Zongri', 'Chokhopani', 'Mebrak', 'Samdzong']
X="Boshan"
S1="Daur"
S2="ElMiron"

outids=[5,7,12,13]
outid=11

for S1 in seas:
    print '------------%s--------------' % S1
    myfile=open(pd+"ind_A_v13_TBH5.wave.X_%s_S1_%s_S2_%s_out%i.log" % (X,S1,S2,outid),'r')
    for line in myfile:
        if 'f4rank' not in line: continue
        x=line.split()
        print ' '.join([x[ind] for ind in [0,1,6,7]])
# Out:
# ------------Zhuang--------------
# f4rank: 0 tail: 4.17218537e-66
# f4rank: 1 tail: 0.887586119
# f4rank: 2 tail: 1
# ------------Ami_Stoneking--------------
# f4rank: 0 tail: 7.14205176e-66
# f4rank: 1 tail: 0.818965588
# f4rank: 2 tail: 1
# ------------Atayal_Stoneking--------------
# f4rank: 0 tail: 9.69636726e-60
# f4rank: 1 tail: 0.826873795
# f4rank: 2 tail: 1
# ------------Kinh_Vietnam_KHV--------------
# f4rank: 0 tail: 3.83345637e-63
# f4rank: 1 tail: 0.818730038
# f4rank: 2 tail: 1

# %% [markdown]
# ## Bash script
# This is a good script to copy/paste into terminal to grab relevant information from qpAdm.

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/bronzeage/data/"
# pd="/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/"
# X="Daur"
# S1="Daur"
# S2="French"
# myeas="Daur Japanese Atayal_Stoneking Longlin LiangDao Tianyuan"
# #myeas="Atayal_Stoneking Japanese Daur"
# neas="HDYM1 Boisman_MN Bbdong Boshan Linzi Daur Hezhen Mongola Ulchi Xibo"
# seas="Han_NChina Han_Shandong Han_HGDP Dai Li Maonan Miao She Zhuang Ami_Stoneking Atayal_Stoneking Kinh_Vietnam_KHV Tianyuan Longlin"
# #seas="Zhuang Ami_Stoneking Atayal_Stoneking Kinh_Vietnam_KHV Tianyuan Longlin"
# ##Japanese Korean
# outid=16
# for S1 in ${seas}; do
#     myf="${pd}ind_A_v13_TBH5.adm.X_${X}_S1_${S1}_S2_${S2}_out${outid}.log" ;
#     echo "";
#     echo "--------"${myf}"--------";
#     myind=$(grep -n "Jackknife mean:" ${myf} | cut -d":" -f1);
#     step=15;   ##3 popns
#     #step=22;   ##4 popns
#     #step=32;    ##5 popns
#     myind2=$(echo $((${myind}+${step})));
#     head -n ${myind2} ${myf} | tail -n16; ##3 popns
#     #head -n ${myind2} ${myf} | tail -n23;  ##4 popns
#     #head -n ${myind2} ${myf} | tail -n33; ##5 popns
#     done
# Out:
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Han_NChina_S2_French_out16.log--------
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Han_Shandong_S2_French_out16.log--------
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Han_HGDP_S2_French_out16.log--------
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Dai_S2_French_out16.log--------
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Li_S2_French_out16.log--------
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Maonan_S2_French_out16.log--------
# Jackknife mean:      0.983831341     0.016168659
#       std. errors:     0.004     0.004
#
# error covariance (* 1000000)
#         15        -15
#        -15         15
#
#
# summ: Daur    2      0.367917     0.984     0.016    15   -15    15
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     6     6.516        0.367917     0.984     0.016
#            01  1     7    25.724     0.000564234     1.000    -0.000
#            10  1     7   797.999               0     0.000     1.000
# best pat:           00         0.367917              -  -
# best pat:           01      0.000564234  chi(nested):    19.208 p-value for nested model:     1.17248e-05
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Miao_S2_French_out16.log--------
# Jackknife mean:      0.986993787     0.013006213
#       std. errors:     0.004     0.004
#
# error covariance (* 1000000)
#         16        -16
#        -16         16
#
#
# summ: Daur    2      0.824481     0.987     0.013    16   -16    16
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     6     2.874        0.824481     0.987     0.013
#            01  1     7    13.669       0.0573959     1.000    -0.000
#            10  1     7   798.273               0     0.000     1.000
# best pat:           00         0.824481              -  -
# best pat:           01        0.0573959  chi(nested):    10.795 p-value for nested model:      0.00101789
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_She_S2_French_out16.log--------
# Jackknife mean:      0.990721418     0.009278582
#       std. errors:     0.004     0.004
#
# error covariance (* 1000000)
#         15        -15
#        -15         15
#
#
# summ: Daur    2      0.400909     0.991     0.009    15   -15    15
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     6     6.202        0.400909     0.991     0.009
#            01  1     7    12.298       0.0911748     1.000    -0.000
#            10  1     7   798.273               0     0.000     1.000
# best pat:           00         0.400909              -  -
# best pat:           01        0.0911748  chi(nested):     6.096 p-value for nested model:       0.0135514
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Zhuang_S2_French_out16.log--------
# Jackknife mean:      0.983071440     0.016928560
#       std. errors:     0.004     0.004
#
# error covariance (* 1000000)
#         14        -14
#        -14         14
#
#
# summ: Daur    2      0.360596     0.983     0.017    14   -14    14
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     6     6.588        0.360596     0.983     0.017
#            01  1     7    28.162     0.000205547     1.000    -0.000
#            10  1     7   797.999               0     0.000     1.000
# best pat:           00         0.360596              -  -
# best pat:           01      0.000205547  chi(nested):    21.573 p-value for nested model:     3.40572e-06
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Ami_Stoneking_S2_French_out16.log--------
# Jackknife mean:      0.983032199     0.016967801
#       std. errors:     0.005     0.005
#
# error covariance (* 1000000)
#         22        -22
#        -22         22
#
#
# summ: Daur    2      0.366081     0.983     0.017    22   -22    22
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     6     6.534        0.366081     0.983     0.017
#            01  1     7    20.933      0.00387055     1.000    -0.000
#            10  1     7   798.273               0     0.000     1.000
# best pat:           00         0.366081              -  -
# best pat:           01       0.00387055  chi(nested):    14.399 p-value for nested model:     0.000147891
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Atayal_Stoneking_S2_French_out16.log--------
# Jackknife mean:      0.983356623     0.016643377
#       std. errors:     0.005     0.005
#
# error covariance (* 1000000)
#         26        -26
#        -26         26
#
#
# summ: Daur    2      0.884993     0.983     0.017    26   -26    26
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     6     2.349        0.884993     0.983     0.017
#            01  1     7    13.147       0.0686045     1.000    -0.000
#            10  1     7   798.273               0     0.000     1.000
# best pat:           00         0.884993              -  -
# best pat:           01        0.0686045  chi(nested):    10.798 p-value for nested model:      0.00101593
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Kinh_Vietnam_KHV_S2_French_out16.log--------
# Jackknife mean:      0.988677287     0.011322713
#       std. errors:     0.004     0.004
#
# error covariance (* 1000000)
#         19        -19
#        -19         19
#
#
# summ: Daur    2      0.419612     0.989     0.011    19   -19    19
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     6     6.032        0.419612     0.989     0.011
#            01  1     7    13.142       0.0687218     1.000    -0.000
#            10  1     7   798.273               0     0.000     1.000
# best pat:           00         0.419612              -  -
# best pat:           01        0.0687218  chi(nested):     7.110 p-value for nested model:      0.00766536
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Tianyuan_S2_French_out16.log--------
# Jackknife mean:      1.060470220    -0.060470220
#       std. errors:     0.015     0.015
#
# error covariance (* 1000000)
#        226       -226
#       -226        226
#
#
# summ: Daur    2      0.004235     1.060    -0.060   226  -226   226
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     6    18.958      0.00423501     1.061    -0.061  infeasible
#            01  1     7    37.423     3.89902e-06     1.000    -0.000
#            10  1     7   773.083               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01      3.89902e-06  chi(nested):    18.465 p-value for nested model:     1.73017e-05
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Longlin_S2_French_out16.log--------
# Jackknife mean:      1.008923612    -0.008923612
#       std. errors:     0.032     0.032
#
# error covariance (* 1000000)
#       1027      -1027
#      -1027       1027
#
#
# summ: Daur    2      0.171170     1.009    -0.009  1027 -1027  1027
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     6     9.043         0.17117     1.010    -0.010  infeasible
#            01  1     7     9.139        0.242845     1.000    -0.000
#            10  1     7   284.983               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01         0.242845  chi(nested):     0.096 p-value for nested model:        0.757041
# grep: /mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Han_NChina_S2_French_out16.log: No such file or directory
# head: cannot open ‘/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Han_NChina_S2_French_out16.log’ for reading: No such file or directory
# grep: /mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Han_Shandong_S2_French_out16.log: No such file or directory
# head: cannot open ‘/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Han_Shandong_S2_French_out16.log’ for reading: No such file or directory
# grep: /mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Han_HGDP_S2_French_out16.log: No such file or directory
# head: cannot open ‘/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Han_HGDP_S2_French_out16.log’ for reading: No such file or directory
# grep: /mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Dai_S2_French_out16.log: No such file or directory
# head: cannot open ‘/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Dai_S2_French_out16.log’ for reading: No such file or directory
# grep: /mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Li_S2_French_out16.log: No such file or directory
# head: cannot open ‘/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Daur_S1_Li_S2_French_out16.log’ for reading: No such file or directory

# %%
seas=['Japanese','Korean','Han_NChina','Han_Shandong','Han_HGDP','Dai','Li','Maonan','Miao','She',
       'Zhuang','Ami_Stoneking','Atayal_Stoneking','Kinh_Vietnam_KHV']
neas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Daur','Hezhen','Mongola','Ulchi','Xibo']
print ', '.join(neas)

# %% [markdown]
# ## Make table of qpAdm results

# %%
import projmodules as pm

seas=['Japanese','Korean','Han_NChina','Han_Shandong','Han_HGDP','Dai','Li','Maonan','Miao','She',
       'Zhuang','Ami_Stoneking','Atayal_Stoneking','Kinh_Vietnam_KHV']
myeas=["Longlin","LiangDao","Atayal_Stoneking","Japanese","Daur"]
neas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Daur','Hezhen','Mongola','Ulchi','Xibo']
weas=['Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha','Zongri', 'Chokhopani', 'Mebrak', 'Samdzong']

ty=["Tianyuan"]
ll=["Longlin"]
namer=["Mixe"]
#pD="/mnt/solexa/mel_yang/bronzeage/data/"
pD="/mnt/solexa/mel_yang/neolithic/qpwaveadm/"
fh="ind_A_v13_TBH5"

outs = [5]
comboswanted = ['00','10']
header = 'S1\tS2\tTarget\trank1\t%s_p\t%s_f1\t%s_f2\t%s_pnest\t%s_p\t%s_f1\t%s_f2\t%s_pnest\tse\n' % tuple(comboswanted[0:1]*4+comboswanted[1:2]*4)
rankswanted = ['1']
for outnum in outs:
    alldata = ""
    for ind1, i1 in enumerate(myeas):
        for ind2,i2 in enumerate(["Chukchi"]):
            for ind3,i3 in enumerate(neas+weas+seas):
                if i1==i2 or i2==i3 or i1==i3: continue
                s1,s2,target = (i1,i2,i3)
                #s1,s2,target = (i1,i2,i3)
                subset = 'X_%s_S1_%s_S2_%s_out%i' % (target,s1,s2,outnum)
                myinfo = pm.wave_extractAdmdata(pD,fh,subset,(s1,s2),target)
                if myinfo == 'NOFILE': continue              
                ranksprint = '\t'.join([str(myinfo['f4rank'][i]) for i in rankswanted])
                pvalsprint = '\t'.join(['%s\t%s\t%s\t%s' % tuple(myinfo['admix'][i]+myinfo['nestp'][i]) if i in myinfo['nestp'] else '%s\t%s\t%s\tNA' % tuple(myinfo['admix'][i]) for i in comboswanted])
                allprint = ranksprint+'\t'+pvalsprint+'\t'+myinfo['se'][-1]
                
                alldata+='\t'.join([s1,s2,target])+'\t'+allprint+'\n'
    #newname = 'adm_inSEASoutNWEASoutLL_out' + str(outnum)
    #newname = 'adm_inSEASoutNEASoutLD_out' + str(outnum)
    #newname = 'adm_inLLoutNEASoutLD_out' + str(outnum)
    #newname = 'adm_inLLoutWNSCEASoutTY_out' + str(outnum)
    #newname = 'adm_inLLoutSCEASoutDaur_out' + str(outnum)
    #newname = 'adm_inNSCEASoutNSCEASoutMixe_out' + str(outnum)
    #newname = 'adm_inLLoutSEASoutWNEAS_out' + str(outnum)
    newname = 'adm_inWNEASoutSEASoutSurui_out' + str(outnum)
    #newname = 'adm_inNCSEASoutLLoutLos_out' + str(outnum)
    newname = 'adm_inWNEASoutSEASoutLos_out' + str(outnum)
    newname = 'adm_inWNEASoutSEASoutChukchi_out' + str(outnum)
    
    newfile = open(pD+fh+'.'+newname+'.tab','w')
    newfile.writelines(header+alldata)
    newfile.close()

# %%
import projmodules as pm

seas=['Japanese','Korean','Han_NChina','Han_Shandong','Han_HGDP','Dai','Li','Maonan','Miao','She',
       'Zhuang','Ami_Stoneking','Atayal_Stoneking','Kinh_Vietnam_KHV']
myeas=["Longlin","LiangDao","Atayal_Stoneking","Japanese","Daur"]
neas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Daur','Hezhen','Mongola','Ulchi','Xibo']
weas=['Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha','Zongri', 'Chokhopani', 'Mebrak', 'Samdzong']
anceur=["Vestonice16","Ostuni1","Villabruna","Loschbour"] #"ElMiron",
ty=["Tianyuan"]
ll=["Longlin"]
namer=["Mixe"]
#pD="/mnt/solexa/mel_yang/bronzeage/data/"
pD="/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/"
fh="ind_A_v13_TBH5"

outs = [15,16]
comboswanted = ['00','01']
header = 'S1\tS2\tTarget\trank1\t%s_p\t%s_f1\t%s_f2\t%s_pnest\t%s_p\t%s_f1\t%s_f2\t%s_pnest\tse\n' % tuple(comboswanted[0:1]*4+comboswanted[1:2]*4)
rankswanted = ['1']
for outnum in outs:
    alldata = ""
    for ind1, i1 in enumerate(["Tianyuan","Longlin"]+seas):
        for ind2,i2 in enumerate(anceur):
            for ind3,i3 in enumerate(["Boshan"]):
                if i1==i2 or i2==i3 or i1==i3: continue
                s1,s2,target = (i1,i2,i3)
                #s1,s2,target = (i1,i2,i3)
                subset = 'X_%s_S1_%s_S2_%s_out%i' % (target,s1,s2,outnum)
                myinfo = pm.wave_extractAdmdata(pD,fh,subset,(s1,s2),target)
                if myinfo == 'NOFILE': continue              
                ranksprint = '\t'.join([str(myinfo['f4rank'][i]) for i in rankswanted])
                pvalsprint = '\t'.join(['%s\t%s\t%s\t%s' % tuple(myinfo['admix'][i]+myinfo['nestp'][i]) if i in myinfo['nestp'] else '%s\t%s\t%s\tNA' % tuple(myinfo['admix'][i]) for i in comboswanted])
                allprint = ranksprint+'\t'+pvalsprint+'\t'+myinfo['se'][-1]
                
                alldata+='\t'.join([s1,s2,target])+'\t'+allprint+'\n'
    #newname = 'adm_inLDoutNWCSEASoutElM_out' + str(outnum)
    #newname = 'adm_inLLoutNWCSEASoutElM_out' + str(outnum)
    newname = 'adm_inLZoutSEASoutEUR_out' + str(outnum)
    newname = 'adm_inBSoutSEASoutEUR_out' + str(outnum)
    #newname = 'adm_inLDoutSEASoutEUR_out' + str(outnum)
    
    newfile = open(pD+fh+'.'+newname+'.tab','w')
    newfile.writelines(header+alldata)
    newfile.close()

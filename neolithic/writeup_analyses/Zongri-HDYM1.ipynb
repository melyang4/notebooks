# %% [markdown]
# ## Investigating the connection between Zongri and HDYM1
# 1. D(HDYM1, LiangDao; Tibetans, Mbuti) and D(HDYM1, Boisman; Tibetans, Mbuti)
# 2. qpAdm of (S1,S2; Target)=(AncNorth, Tibetans; HDYM1) or (Tibetans, AncNorth; Zongri)
# 3. Treemix Analysis
# 4. f4-ratio

# %% [markdown]
# ### 1. D(HDYM1, LiangDao; Tibetans, Mbuti) and D(HDYM1, Boisman; Tibetans, Mbuti)

# %%
##Copy/pasted into bionc12  -- /home/melinda_yang/projects/neolithic/D_HDYM1.py

import plotting_funcs as pf
#import HOdata

#pD="/mnt/solexa/mel_yang/bronzeage/data/" #ivpp
#outpd="/mnt/solexa/mel_yang/bronzeage/Dstats/D_ShangZhou_merged/" #ivpp
pD="/home/melinda_yang/data/HO_bronzeage/" #mpi
outpd="/home/melinda_yang/projects/neolithic/D_WEur/" #mpi

anceas=["Tianyuan","Longlin","LiangDao","Taosi","Xinyi",'HDYM1','Boisman_MN',"Boshan","Bbdong",
        "Linzi","XianShang","Xiaoshuangqiao","Guandimiao","Zhougongmiao","Yaojia","Tonglin",
        'Chokhopani','Mebrak','Samdzong',"Zongri","Pukagongma","Redilong","Butaxiongqu","Gelintang", ##'DevilsGate1','DevilsGate2',
        "Yingpanshan","Mougou","Sanheyi","Yusu","Jinchankou","Jomon",    
        "Donghuigou","Balikun","Huoshaogou","Wuba","Shengedaliang",
        "Muzhuzhuliang","Xinhua","Wuzhuangguo","Shimao","Dashuitian","HQSDW"]

ancnorth=['HDYM1','Boisman_MN',"Boshan","Bbdong","Linzi"]

fh="ind_A_v13_TBH5"
outs=["Mbuti"]

bsf,bsfsubset=(pD+fh+".transi.snp",'transv')
bsf,bsfsubset=(0,'all')

p2s=["LiangDao",'Boisman_MN',"Boshan","Bbdong","Linzi","HDYM1"]
p2s=["HQSDW"]
for myp2 in p2s:
    for myp4 in outs:
        ##D(X, Y; LL, Mbuti)
        p1,p2,p3,p4 = (ancnorth,myp2,anceas,myp4)
        subset = bsfsubset+'.'+"ANCNORTH"+'_'+p2+'_'+"ANCEAS"+'_'+p4
        mytups = [(i,p2,j,p4,'p2_'+i) for ind,i in enumerate(p1) for j in p3 if i != j and p2!=i and p2!=j]
        pf.runD(p3,p1,mytups,pD,fh,subset,(2,0),(0,),fixed=(0,p2,0,p4),badsnpfile=bsf,outpd=outpd) 
        
        p1,p2,p3,p4 = (anceas,myp2,ancnorth,myp4)
        subset = bsfsubset+'.'+"ANCEAS"+'_'+p2+'_'+"ANCNORTH"+'_'+p4
        mytups = [(i,p2,j,p4,'p2_'+i) for ind,i in enumerate(p1) for j in p3 if i != j and p2!=i and p2!=j]
        pf.runD(p1,p3,mytups,pD,fh,subset,(0,2),(0,),fixed=(0,p2,0,p4),badsnpfile=bsf,outpd=outpd) 
        
        p1,p2,p3,p4 = (anceas,ancnorth,myp2,myp4)
        subset = bsfsubset+'.'+"ANCEAS"+'_'+"ANCNORTH"+'_'+p3+'_'+p4
        mytups = [(i,j,p3,p4,'p2_'+i) for ind,i in enumerate(p1) for j in p2 if i != j and p3!=i and p3!=j]
        pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),fixed=(0,0,p3,p4),badsnpfile=bsf,outpd=outpd)

# %%
##Copy/pasted into bionc12  -- /home/melinda_yang/projects/neolithic/D_ANCNORTH_ANCWEST.py

import plotting_funcs as pf
#import HOdata

#pD="/mnt/solexa/mel_yang/bronzeage/data/" #ivpp
#outpd="/mnt/solexa/mel_yang/bronzeage/Dstats/D_ShangZhou_merged/" #ivpp
pD="/home/melinda_yang/data/HO_bronzeage/" #mpi
outpd="/home/melinda_yang/projects/neolithic/D_NWASNS/" #mpi

anceas=['HDYM1','Boisman_MN',"Boshan","Bbdong","Linzi","HQSDW","Tonglin",
        "Guandimiao","Xiaoshuangqiao","XianShang","Zhougongmiao","Yaojia"]

pdeas=['Daur','Hezhen','Mongola','Ulchi','Xibo','Japanese','Korean','Han_NChina','Han_Shandong', 
       'Han_HGDP','Dai','Li','Maonan','Miao','She','Zhuang','Ami_Stoneking','Atayal_Stoneking',
       'Kinh_Vietnam_KHV','Yi','Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha']

fh="ind_A_v13_TBH5"
outs=["Mbuti"]

bsf,bsfsubset=(pD+fh+".transi.snp",'transv')
bsf,bsfsubset=(0,'all')

p2s=["Zongri","Pukagongma","Yingpanshan","Redilong","Butaxiongqu","Gelintang",'Chokhopani','Mebrak','Samdzong',
     'Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha',"LiangDao"]
for myp2 in p2s:
    for myp4 in outs:
        ##D(X, Y; LL, Mbuti)
        p1,p2,p3,p4 = (pdeas,myp2,anceas,myp4)
        subset = bsfsubset+'.'+"PDEAS"+'_'+p2+'_'+"ANCNORTH"+'_'+p4
        mytups = [(i,p2,j,p4,'p2_'+i) for ind,i in enumerate(p1) for j in p3 if i != j and p2!=i and p2!=j]
        pf.runD(p1,p3,mytups,pD,fh,subset,(0,2),(0,),fixed=(0,p2,0,p4),badsnpfile=bsf,outpd=outpd) 
        
        p1,p2,p3,p4 = (anceas,myp2,pdeas,myp4)
        subset = bsfsubset+'.'+"ANCNORTH"+'_'+p2+'_'+"PDEAS"+'_'+p4
        mytups = [(i,p2,j,p4,'p2_'+i) for ind,i in enumerate(p1) for j in p3 if i != j and p2!=i and p2!=j]
        pf.runD(p3,p1,mytups,pD,fh,subset,(2,0),(0,),fixed=(0,p2,0,p4),badsnpfile=bsf,outpd=outpd) 
        
        p1,p2,p3,p4 = (pdeas,anceas,myp2,myp4)
        subset = bsfsubset+'.'+"PDEAS"+'_'+"ANCNORTH"+'_'+p3+'_'+p4
        mytups = [(i,j,p3,p4,'p2_'+i) for ind,i in enumerate(p1) for j in p2 if i != j and p3!=i and p3!=j]
        pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),fixed=(0,0,p3,p4),badsnpfile=bsf,outpd=outpd)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches
import plotting_funcs as pf



pD = "/mnt/solexa/mel_yang/neolithic/Dstats/D_ANCASN/"
outs = ['Mbuti']

aeas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi']
neas=['Chokhopani', 'Mebrak', 'Samdzong','Zongri', "Pukagongma","Redilong","Butaxiongqu","Gelintang"]
myasn="LiangDao"
pdeas=neas
wantedpops = [i for i in pdeas[::-1] if i not in ["Xinyi","Vietnam_Pre_Neolithic","Vietnam_Neolithic","Vietnam_BA"]] 
wantedpops = [i for i in wantedpops if i not in [myasn]] 
mynames=wantedpops[:]


fh="ind_A_v13_TBH5"
mytwoeurs = [aeas]
for myindex,myeurs in enumerate(mytwoeurs):
    for out in outs:
        fig = plt.figure(figsize=(22,5))
        colors = ['red','blue','brown','black','orange','purple']
        
        myxmins = [-0.05]*len(myeurs)
        myxmaxs = [0.05]*len(myeurs)
        mylabel = ['A','B','C','D','E']
        mylabellocation = [-0.11]*len(myeurs)

        for mysubplot,myeur in enumerate(myeurs):
            ax1=fig.add_subplot(1,6,mysubplot+1)
            
            #myylabel,mytitle,legendadd = labels[mysubplot]
            myset = "all.ANCNORTH_%s_ANCEAS_%s" % (myasn,out)
            #myset = "all.ANCEAS_%s_ANCNORTH_%s" % (myasn,out)
            #myset = "all.ANCEAS_ANCNORTH_%s_%s" % (myasn,out)
            mycond = True if 'tp' in myset else False
            myZary,mypops1,mypops2 = pf.mkDZary(pD+fh+".D."+myset+'.Zmat',mycond)
            myDary,mypops1,mypops2 = pf.mkDZary(pD+fh+".D."+myset+'.Dmat',mycond)
            mySEary=myDary/myZary
            goodpops2 = [mypops2.index(i) for i in wantedpops]
            #getsmaller = [5,5,5]

            goodpops1 = mypops1.index(myeur)
            myys = np.array(range(len(goodpops2)))
            tyD = myDary[goodpops2,goodpops1]
            tySE = mySEary[goodpops2,goodpops1]
            ax1.errorbar(tyD,myys,xerr=tySE, color='darkgrey',fmt='o',capthick=0,linewidth=7)
            ax1.errorbar(tyD,myys,xerr=2*tySE, color='darkgrey',fmt='o',capthick=0,linewidth=4)
            ax1.plot(tyD,myys,'o',markersize=10,color=colors[mysubplot])
            
            ax1.set_yticks(myys) #,rotation=45)
            if mysubplot==0:
                ax1.set_yticklabels(mynames,fontsize=17)
                #ax1.set_ylabel("P3",fontsize=20)
                ax1.text(-0.075,8.5,'X',rotation = 0, fontsize=25)
            elif mysubplot == len(myeurs)-1:
                print mysubplot
                ax1.set_yticklabels(['']*len(wantedpops),fontsize=17)
                ax2=ax1.twinx()
                ax2.set_ylim(-1,len(goodpops2)) #,rotation=45)
                ax2.set_yticks( myys )
                ax2.set_yticklabels(['']*len(wantedpops),fontsize=17)
                #ax1.text(0.06,20.5,'Vestonice16',rotation = 270, fontsize=20)
                #ax1.text(0.08,16.5,'X',rotation = 0, fontsize=25)
                ax1.text(-0.28,-3,"D(Y,%s;X,Mbuti)" % myasn,fontsize=25)
                #ax1.text(-0.28,-3,"D(X,%s;Y,Mbuti)" % myasn,fontsize=25)
                #ax1.text(-0.28,-3,"D(X,Y;%s,Mbuti)" % myasn,fontsize=25)
            else: 
                ax1.set_yticklabels(['']*len(wantedpops),fontsize=15)
                
                
            ax1.set_ylim(-1,len(goodpops2))
            ax1.set_xlim(myxmins[mysubplot],myxmaxs[mysubplot])
    
            xlabel = ax1.get_xticks().tolist()
            ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)
            
            ax1.set_title("Y="+myeur,fontsize=21)
            #ax1.axvline(x=0, ls='solid', c='gray',alpha=0.3)
            #for i in [1.5,5.5,10.5,18.5,25.5,28.5]: ax1.axhline(y=i, ls='solid', c='black',alpha=0.5) ##Using non-north
            #for i in [2.5,6.5,10.5,18.5,25.5,28.5]: ax1.axhline(y=i, ls='solid', c='black',alpha=0.5) ##Using north
            ax1.axvline(x=0, ls='dashed', c='black')

        fig.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.01, hspace=None)
        plt.tight_layout()
        plt.savefig(pD+fh+'.'+myasn+'.Dfig%i.png' % myindex, bbox_inches='tight')
# Out:
# 4

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches
import plotting_funcs as pf



pD = "/mnt/solexa/mel_yang/neolithic/Dstats/D_ANCASN/"
out = 'Mbuti'

aeas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi']
neas=['Chokhopani', 'Mebrak', 'Samdzong','Zongri', "Pukagongma","Redilong","Butaxiongqu","Gelintang"]
myasn="LiangDao"
pdeas=neas
wantedpops = [i for i in pdeas[::-1] if i not in ["Xinyi","Vietnam_Pre_Neolithic","Vietnam_Neolithic","Vietnam_BA"]] 
wantedpops = [i for i in wantedpops if i not in [myasn]] 
mynames=wantedpops[:]
mytuples=[(i,j) for ind1,i in enumerate(aeas) for ind2,j in enumerate(aeas) if ind1>ind2]
print mytuples
mycolors=['black','purple','blue','green','yellow','orange','brown','pink','red']
fh="ind_A_v13_TBH5"
fig = plt.figure(figsize=(20,8))
num=1
for pop1,pop2 in mytuples:
    myset = "all.ANCNORTH_%s_ANCEAS_%s" % (myasn,out)
    #myset = "all.ANCEAS_%s_ANCNORTH_%s" % (myasn,out)
    #myset = "all.ANCEAS_ANCNORTH_%s_%s" % (myasn,out)
    myDary,colnames,rownames = pf.mkDZary(pD+fh+".D."+myset+'.Dmat',False)
    rowswanted=[rownames.index(i) for i in wantedpops]
    mysubDary1=myDary[:,colnames.index(pop1)][rowswanted]
    mysubDary2=myDary[:,colnames.index(pop2)][rowswanted]

    ax1=fig.add_subplot(2,5,num)
    num+=1
    for ind,dot in enumerate(mysubDary1):
        ax1.scatter(mysubDary1[ind],mysubDary2[ind],s=70,label="X="+rownames[rowswanted[ind]],c=mycolors[ind])
        ax1.plot(mysubDary1[ind],mysubDary2[ind],'o',markersize=10,color=mycolors[ind])
    #ax1.plot(mysubDary1,mysubDary2,'o',markersize=10,color=colors[mysubplot])
    
    linexs=[min(mysubDary1),min(mysubDary2),max(mysubDary1),max(mysubDary2)]
    lineys=[min(mysubDary1),min(mysubDary2),max(mysubDary1),max(mysubDary2)]
    offset=0.005
    ax1.plot(linexs,lineys,'-b')
    xlabel = ax1.get_xticks().tolist()
    ax1.set_xticklabels(xlabel,rotation=45,fontsize=17)
    ylabel = ax1.get_yticks().tolist()
    ax1.set_yticklabels(ylabel,rotation=0,fontsize=17)
    ax1.set_ylim((min(lineys)-offset,max(lineys)+offset))
    ax1.set_xlim((min(linexs)-offset,max(linexs)+offset))
    ax1.set_title("D(%s,%s; %s,%s)" % ("Y",myasn,"X",out),fontsize=17)
    #ax1.set_title("D(%s,%s; %s,%s)" % ("X",myasn,"Y",out),fontsize=13)
    #ax1.set_title("D(%s,%s; %s,%s)" % ("X","Y",myasn,out),fontsize=13)

    ax1.set_ylabel(pop2,fontsize=17)
    ax1.set_xlabel(pop1,fontsize=17) 
ax1.legend(fontsize=17,bbox_to_anchor=(-0.2, -0.4),ncol=4, fancybox=True, shadow=True)
plt.tight_layout()
# Out:
# [('Boisman_MN', 'HDYM1'), ('Bbdong', 'HDYM1'), ('Bbdong', 'Boisman_MN'), ('Boshan', 'HDYM1'), ('Boshan', 'Boisman_MN'), ('Boshan', 'Bbdong'), ('Linzi', 'HDYM1'), ('Linzi', 'Boisman_MN'), ('Linzi', 'Bbdong'), ('Linzi', 'Boshan')]

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches
import plotting_funcs as pf



pD = "/mnt/solexa/mel_yang/neolithic/Dstats/D_ANCASN/"
out = 'Mbuti'

aeas=['HDYM1','Boisman_MN','Boshan','Bbdong']
neas=['Chokhopani', 'Mebrak', 'Samdzong','Zongri', "Pukagongma","Redilong","Butaxiongqu","Gelintang"]
myasn="LiangDao"
pdeas=neas
wantedpops = [i for i in pdeas[::-1] if i not in ["Xinyi","Vietnam_Pre_Neolithic","Vietnam_Neolithic","Vietnam_BA"]] 
wantedpops = [i for i in wantedpops if i not in [myasn]] 
mynames=wantedpops[:]
mytuples=[(i,j) for ind1,i in enumerate(aeas) for ind2,j in enumerate(aeas) if ind1>ind2]
print mytuples
mycolors=['black','purple','blue','green','yellow','orange','brown','pink','red']
fh="ind_A_v13_TBH5"
fig = plt.figure(figsize=(12,8))
num=1
for pop1,pop2 in mytuples:
    myset = "all.ANCNORTH_%s_ANCEAS_%s" % (myasn,out)
    #myset = "all.ANCEAS_%s_ANCNORTH_%s" % (myasn,out)
    #myset = "all.ANCEAS_ANCNORTH_%s_%s" % (myasn,out)
    myDary,colnames,rownames = pf.mkDZary(pD+fh+".D."+myset+'.Dmat',False)
    rowswanted=[rownames.index(i) for i in wantedpops]
    mysubDary1=myDary[:,colnames.index(pop1)][rowswanted]
    mysubDary2=myDary[:,colnames.index(pop2)][rowswanted]

    ax1=fig.add_subplot(2,3,num)
    num+=1
    for ind,dot in enumerate(mysubDary1):
        ax1.scatter(mysubDary1[ind],mysubDary2[ind],s=70,label="X="+rownames[rowswanted[ind]],c=mycolors[ind])
        ax1.plot(mysubDary1[ind],mysubDary2[ind],'o',markersize=10,color=mycolors[ind])
    #ax1.plot(mysubDary1,mysubDary2,'o',markersize=10,color=colors[mysubplot])
    
    linexs=[min(mysubDary1),min(mysubDary2),max(mysubDary1),max(mysubDary2)]
    lineys=[min(mysubDary1),min(mysubDary2),max(mysubDary1),max(mysubDary2)]
    offset=0.005
    ax1.plot(linexs,lineys,'-b')
    xlabel = ax1.get_xticks().tolist()
    ax1.set_xticklabels(xlabel,rotation=45,fontsize=13)
    ylabel = ax1.get_yticks().tolist()
    ax1.set_yticklabels(ylabel,rotation=0,fontsize=13)
    ax1.set_ylim((min(lineys)-offset,max(lineys)+offset))
    ax1.set_xlim((min(linexs)-offset,max(linexs)+offset))
    if num==3:
        ax1.set_title("D(%s,%s; %s,%s)\n" % ("Y",myasn,"X",out),fontsize=17)
        #ax1.set_title("D(%s,%s; %s,%s)\n" % ("X",myasn,"Y",out),fontsize=17)
        #ax1.set_title("D(%s,%s; %s,%s)\n" % ("X","Y",myasn,out),fontsize=17)

    ax1.set_ylabel(pop2,fontsize=17)
    ax1.set_xlabel(pop1,fontsize=17) 
ax1.legend(fontsize=17,bbox_to_anchor=(1.2, -0.4),ncol=4, fancybox=True, shadow=True)
plt.tight_layout()
# Out:
# [('Boisman_MN', 'HDYM1'), ('Boshan', 'HDYM1'), ('Boshan', 'Boisman_MN'), ('Bbdong', 'HDYM1'), ('Bbdong', 'Boisman_MN'), ('Bbdong', 'Boshan')]

# %% [markdown]
# ### 2. qpAdm of (S1,S2; Target)=(AncNorth, Tibetans; HDYM1) or (Tibetans, AncNorth; Zongri)

# %%
# %%writefile /mnt/solexa/mel_yang/neolithic/qpwaveadm/HDYM1_Zongri/qpwave_HDYM1_Zongri.py
import projmodules as pm
from multiprocessing import Pool
import itertools

weas=['Zongri','Pukagongma','Gelintang','Chokhopani','Mebrak','Samdzong','Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha']
neas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Daur','Hezhen','Mongola','Ulchi','Xibo']

#left=[["HDYM1",i, j] for i in weas for j in neas+["LiangDao"] if j != "HDYM1"] 
#left+=[["Boisman_MN",i, j] for i in weas for j in neas+["LiangDao"] if j != "Boisman_MN"]

left=[["Zongri",i, j] for j in weas+["LiangDao"] for i in neas if i != "Zongri"] 
left+=[["Pukagongma",i, j] for j in weas+["LiangDao"] for i in neas if i != "Pukagongma"]

#left=[["Zongri",i, j] for i in ["LiangDao"] for j in neas if i != "Zongri"] 

def dowork(mytup):
    myleft,myleftid=mytup
    outpD="/mnt/solexa/mel_yang/neolithic/qpwaveadm/HDYM1_Zongri/"
    pD="/mnt/solexa/mel_yang/bronzeage/data/"
    fh="ind_A_v13_TBH5"
    
    outs=[["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Papuan","Kostenki14","Vestonice16","UstIshim"],#0
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Papuan","UstIshim"], #1
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Papuan","Kostenki14"], #2
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Papuan"],] #3

    for outid,out in enumerate(outs):
        if outid in [0]: continue 
        bck = 'X_%s_S1_%s_S2_%s_out%i' % tuple(myleft+[outid])
        #pm.wave_run(myleft, out, pD, fh, bck, outpd=outpD)
        pm.wave_adm_run(myleft, out, pD, fh, bck, outpd=outpD)
myinputs=[(myleft,ind,) for ind,myleft in enumerate(left)] 
print len(myinputs)
mypool = Pool(14)
results = mypool.map(dowork, myinputs)
# Out:
# Overwriting /mnt/solexa/mel_yang/neolithic/qpwaveadm/HDYM1_Zongri/qpwave_HDYM1_Zongri.py

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/bronzeage/data/"
# pd="/mnt/solexa/mel_yang/neolithic/qpwaveadm/HDYM1_Zongri/"
# X="Pukagongma"
# S1="HDYM1"
# S2="Zongri"
# myeas="Daur Japanese Atayal_Stoneking Longlin LiangDao Tianyuan"
# #myeas="Atayal_Stoneking Japanese Daur"
# neas="HDYM1 Boisman_MN Bbdong Boshan Linzi Daur Hezhen Mongola Ulchi Xibo"
# weas="Zongri Pukagongma Gelintang Chokhopani Mebrak Samdzong Tibetan_Shannan Tibetan_Chamdo Tibetan_Gangcha"
# outid=1
# #for S1 in ${neas}; do
# for outid in 1 2 3; do
#     myf="${pd}ind_A_v13_TBH5.adm.X_${X}_S1_${S1}_S2_${S2}_out${outid}.log" ;
#     echo "";
#     echo "--------"${myf}"--------";
#     myind=$(grep -n "Jackknife mean:" ${myf} | cut -d":" -f1);
#     step=15;   ##3 popns
#     #step=22;   ##4 popns
#     #step=32;    ##5 popns
#     myind2=$(echo $((${myind}+${step})));
#     head -n ${myind2} ${myf} | tail -n16; ##3 popns
#     #head -n ${myind2} ${myf} | tail -n23;  ##4 popns
#     #head -n ${myind2} ${myf} | tail -n33; ##5 popns
#     done
# Out:
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/HDYM1_Zongri/ind_A_v13_TBH5.adm.X_Pukagongma_S1_HDYM1_S2_Zongri_out1.log--------
# Jackknife mean:    -54.236557757    55.236557757
#       std. errors:    18.183    18.183
#
# error covariance (* 1000000)
#  330630527 -330630527
# -330630527  330630527
#
#
# summ: Pukagongma    2      0.374745   -54.237    55.237 330630527 -330630527 330630527
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     5     5.349        0.374745     2.138    -1.138  infeasible
#            01  1     6     5.535        0.477226     1.000     0.000
#            10  1     6     6.209        0.400223     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01         0.477226  chi(nested):     0.186 p-value for nested model:        0.666507
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/HDYM1_Zongri/ind_A_v13_TBH5.adm.X_Pukagongma_S1_HDYM1_S2_Zongri_out2.log--------
# ...

# %%
import projmodules as pm

weas=['Zongri','Pukagongma','Gelintang','Chokhopani','Mebrak','Samdzong','Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha']
neas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Daur','Hezhen','Mongola','Ulchi','Xibo']

ty=["Tianyuan"]
ll=["Longlin"]
namer=["Mixe"]
#pD="/mnt/solexa/mel_yang/bronzeage/data/"
pD="/mnt/solexa/mel_yang/neolithic/qpwaveadm/"
fh="ind_A_v13_TBH5"


#left=[["Zongri",i, j] for i in weas for j in neas+["LiangDao"] if i != "Zongri"] 
#left+=[["Pukagongma",i, j] for j in weas+["LiangDao"] for i in neas if i != "Pukagongma"]

outs = [0]
comboswanted = ['00','01']
header = 'S1\tS2\tTarget\trank1\t%s_p\t%s_f1\t%s_f2\t%s_pnest\t%s_p\t%s_f1\t%s_f2\t%s_pnest\tse\n' % tuple(comboswanted[0:1]*4+comboswanted[1:2]*4)
rankswanted = ['1']
for outnum in outs:
    alldata = ""
    for ind1, i1 in enumerate(neas):
        for ind2,i2 in enumerate(weas+["LiangDao"]):
            for ind3,i3 in enumerate(["Pukagongma"]): #["HDYM1","Boisman_MN"]
                if i1==i2 or i2==i3 or i1==i3: continue
                s1,s2,target = (i1,i2,i3)
                #s1,s2,target = (i1,i2,i3)
                subset = 'X_%s_S1_%s_S2_%s_out%i' % (target,s1,s2,outnum)
                myinfo = pm.wave_extractAdmdata(pD,fh,subset,(s1,s2),target)
                if myinfo == 'NOFILE': continue              
                ranksprint = '\t'.join([str(myinfo['f4rank'][i]) for i in rankswanted])
                pvalsprint = '\t'.join(['%s\t%s\t%s\t%s' % tuple(myinfo['admix'][i]+myinfo['nestp'][i]) if i in myinfo['nestp'] else '%s\t%s\t%s\tNA' % tuple(myinfo['admix'][i]) for i in comboswanted])
                allprint = ranksprint+'\t'+pvalsprint+'\t'+myinfo['se'][-1]
                
                alldata+='\t'.join([s1,s2,target])+'\t'+allprint+'\n'

    newname = 'adm_inHDBoisEASoutWEASoutNEASLD_out' + str(outnum)
    newname = 'adm_inZRoutWEASoutNEASLD_out' + str(outnum)
    newname = 'adm_inPKoutNEASoutWEASLD_out' + str(outnum)
    
    newfile = open(pD+fh+'.'+newname+'.tab','w')
    newfile.writelines(header+alldata)
    newfile.close()

# %% [markdown]
# ### 3. Treemix Analysis

# %%
# %%writefile /mnt/solexa/mel_yang/neolithic/treemix/ANCASN/maketreemixfile_ANCASN.py
from projmodules import treemix_mkinput

pd="/mnt/solexa/mel_yang/bronzeage/data/"
#outpD="/mnt/solexa/mel_yang/neolithic/qpwaveadm/"
fh="ind_A_v13_TBH5"
subset='ANCASN'

setstotry=[['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','HDYM1','Zongri','Pukagongma','Boshan','Boisman',
            'Daur','Hezhen','Ulchi','Oroqen',
            'Japanese','Han_NChina','She','Miao','Dai','Li',
            'Ami_Stoneking','Atayal_Stoneking','Maonan','Paiwan','Rukai','Tao'], ##0 NORTH AND SOUTH AND CENTRAL + ANC
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'Daur','Hezhen','Ulchi','Oroqen',
            'Japanese','Han_NChina','She','Miao','Dai','Li',
            'Ami_Stoneking','Atayal_Stoneking','Maonan','Paiwan','Rukai','Tao'], ##1 NORTH AND SOUTH AND CENTRAL noANC
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','HDYM1','Zongri','Pukagongma','Boshan','Boisman'],        ##2 ANC ONLY
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','HDYM1','Zongri','Pukagongma','Boshan','Boisman',
            'Japanese','Han_NChina','She','Miao','Dai','Li',
            'Ami_Stoneking','Atayal_Stoneking','Maonan','Paiwan','Rukai','Tao'], ##3 SOUTH AND CENTRAL + ANC
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','HDYM1','Zongri','Pukagongma','Boshan','Boisman',
            'Ami_Stoneking','Atayal_Stoneking','Maonan','Paiwan','Rukai','Tao'], ##4 SOUTH + ANC
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','HDYM1','Zongri','Pukagongma','Boshan','Boisman',
            'Japanese','Han_NChina','She','Miao','Dai','Li'],                    ##5 CENTRAL + ANC
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','HDYM1','Zongri','Pukagongma','Boshan','Boisman',
            'Daur','Hezhen','Ulchi','Oroqen'],                                   ##6 NORTH + ANC
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','HDYM1','Zongri','Pukagongma','Boshan','Boisman',
            'Daur','Hezhen','Japanese','Han_NChina','Dai',
            'Atayal_Stoneking','Maonan'],                                        ##7 subset NORTH AND SOUTH AND CENTRAL + ANC
          ] 
for ind,i in enumerate(setstotry):
    print ind,i
    if ind not in [0]: continue
    treemix_mkinput(pd,fh,subset+str(ind),setstotry[ind],indfilename=fh+'.sepBois')
# Out:
# Overwriting /mnt/solexa/mel_yang/neolithic/treemix/ANCASN/maketreemixfile_ANCASN.py

# %%
# %%writefile /mnt/solexa/mel_yang/neolithic/treemix/ANCASN/maketreemixfile_ANCASN_rd.py
from projmodules import treemix_mkinput

pd="/mnt/solexa/mel_yang/bronzeage/data/"
#outpD="/mnt/solexa/mel_yang/neolithic/qpwaveadm/"
fh="ind_A_v13_TBH5"
subset='ANCASN_rd'

setstotry=[['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','HDYM1','Zongri','Pukagongma','Boshan','Boisman_MN',
            'Daur','Hezhen','Ulchi','Oroqen',
            'Japanese','Han_NChina','She','Miao','Dai','Li',
            'Ami_Stoneking','Atayal_Stoneking','Maonan','Paiwan','Rukai','Tao'], ##0 NORTH AND SOUTH AND CENTRAL + ANC
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'Daur','Hezhen','Ulchi','Oroqen',
            'Japanese','Han_NChina','She','Miao','Dai','Li',
            'Ami_Stoneking','Atayal_Stoneking','Maonan','Paiwan','Rukai','Tao'], ##1 NORTH AND SOUTH AND CENTRAL noANC
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','HDYM1','Zongri','Pukagongma','Boshan','Boisman_MN'],        ##2 ANC ONLY
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','HDYM1','Zongri','Pukagongma','Boshan','Boisman_MN',
            'Japanese','Han_NChina','She','Miao','Dai','Li',
            'Ami_Stoneking','Atayal_Stoneking','Maonan','Paiwan','Rukai','Tao'], ##3 SOUTH AND CENTRAL + ANC
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','HDYM1','Zongri','Pukagongma','Boshan','Boisman_MN',
            'Ami_Stoneking','Atayal_Stoneking','Maonan','Paiwan','Rukai','Tao'], ##4 SOUTH + ANC
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','HDYM1','Zongri','Pukagongma','Boshan','Boisman_MN',
            'Japanese','Han_NChina','She','Miao','Dai','Li'],                    ##5 CENTRAL + ANC
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','HDYM1','Zongri','Pukagongma','Boshan','Boisman_MN',
            'Daur','Hezhen','Ulchi','Oroqen'],                                   ##6 NORTH + ANC
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','HDYM1','Zongri','Pukagongma','Boshan','Boisman_MN',
            'Daur','Hezhen','Japanese','Han_NChina','Dai',
            'Atayal_Stoneking','Maonan'],                                        ##7 subset NORTH AND SOUTH AND CENTRAL + ANC
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','HDYM1','Zongri','Pukagongma','Chokhopani','Samdzong','Boshan','Boisman_MN',
            'Daur','Hezhen','Ulchi','Oroqen',
            'Japanese','Han_NChina','She','Miao','Dai','Li',
            'Ami_Stoneking','Atayal_Stoneking','Maonan','Paiwan','Rukai','Tao'], ##8 NORTH AND SOUTH AND CENTRAL + ANC +MORE TIB
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','HDYM1','Zongri','Pukagongma','Chokhopani','Samdzong','Boshan','Boisman_MN',
            'Japanese','Han_NChina','She','Miao','Dai','Li'],                    ##9 CENTRAL + ANC +MORE TIB
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','HDYM1','Zongri','Pukagongma','Chokhopani','Samdzong',
            'Boshan','Boisman_MN'],                                             ##10 ANC ONLY +MORE TIB
           ['Mbuti','Tianyuan','UstIshim','Kostenki14',
            'LiangDao','HDYM1','Zongri','Pukagongma','Chokhopani','Samdzong','Boshan','Boisman_MN',
            'Daur','Hezhen','Ulchi','Oroqen',
            'Japanese','Han_NChina','She','Miao','Dai','Li',
            'Ami_Stoneking','Atayal_Stoneking','Maonan','Paiwan','Rukai','Tao'], ##11 NORTH AND SOUTH AND CENTRAL + ANC +MORE TIB, NOEUR
           ['Mbuti','Tianyuan','UstIshim','Kostenki14',
            'LiangDao','HDYM1','Zongri','Pukagongma','Chokhopani','Samdzong','Boshan','Boisman_MN',
            'Japanese','Han_NChina','She','Miao','Dai','Li'],                    ##12 CENTRAL + ANC +MORE TIB, NOEUR
           ['Mbuti','Tianyuan','UstIshim','Kostenki14',
            'LiangDao','HDYM1','Zongri','Pukagongma','Chokhopani','Samdzong',
            'Boshan','Boisman_MN'],                                             ##13 ANC ONLY +MORE TIB, NOEUR
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','HDYM1','Zongri','Pukagongma','Chokhopani','Samdzong','Boshan','Boisman_MN',
            'Japanese','Han_NChina','She','Miao','Dai','Li',
            'Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha'], ##14 CENTRAL + ANC +MORE TIB + PDTIB
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','HDYM1','Zongri','Pukagongma','Chokhopani','Samdzong','Boshan','Boisman_MN',
            'Daur','Hezhen','Ulchi','Oroqen',
            'Japanese','Han_NChina','She','Miao','Dai','Li',
            'Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha'], ##15 NORTH+CENTRAL + ANC +MORE TIB + PDTIB

          ] 
for ind,i in enumerate(setstotry):
    print ind,i
    if ind not in [14,15]: continue
    treemix_mkinput(pd,fh,subset+str(ind),setstotry[ind],includemissing=True)
# Out:
# Overwriting /mnt/solexa/mel_yang/neolithic/treemix/ANCASN/maketreemixfile_ANCASN_rd.py

# %%
# %%writefile /mnt/solexa/mel_yang/neolithic/treemix/ANCASN/maketreemixgraphANCASN.sh
# pd="/mnt/solexa/mel_yang/neolithic/treemix/ANCASN/"
# tv=""
# fh="ind_A_v13_TBH5"
# #fh="UPA_all6"
# k="500"
# myk="_k"${k}
# for j in 14 15; do #`seq 11 13`; do #`seq 0 9`; do
#     subset="ANCASN_rd"${j}
#     #subset="LLLD_NAmer"${j}
#     gzip ${pd}${fh}.${subset}.treemix.txt
#     for i in `seq 0 5`; do
#         treemix -i ${pd}${fh}.${subset}.treemix.txt.gz -root Mbuti -o ${pd}${tv}${subset}_m${i}${myk} -k ${k} -m ${i} > \
#             ${pd}${tv}${subset}_m${i}${myk}.log
#     done
# done
#
# ##R CMD BATCH Rcode.R
# Out:
# Overwriting /mnt/solexa/mel_yang/neolithic/treemix/ANCASN/maketreemixgraphANCASN.sh

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/neolithic/treemix/ANCASN/"
# subset="ANCASN_rd"
# #subset="UPANAmer"
# #subset="LLLD_NAmer"
# for id in 11 12 13; do
#     for mig in 0 1 2 3 4 5; do
#         Rscript ${pd}Rcodeimage.R ${pd} ${subset} ${id} ${mig}
#     done
# done
# Out:
#      V1               V2       V3      V4      V5   V6   V7 V8   V9 V10
# 1     0             <NA> NOT_ROOT NOT_MIG NOT_TIP   76   52 18   15   1
# 2     1              Dai NOT_ROOT NOT_MIG     TIP   16   NA NA   NA  NA
# 3     2             <NA> NOT_ROOT NOT_MIG NOT_TIP 1504  752  3  172   6
# 4     3           Maonan NOT_ROOT NOT_MIG     TIP   16   NA NA   NA  NA
# 5     4 Atayal_Stoneking NOT_ROOT NOT_MIG     TIP  304   NA NA   NA  NA
# 6    15           Boshan NOT_ROOT NOT_MIG     TIP    0   NA NA   NA  NA
# 7    16             <NA> NOT_ROOT NOT_MIG NOT_TIP  752    1  1    3   1
# 8    31             Daur NOT_ROOT NOT_MIG     TIP  256   NA NA   NA  NA
# 9    51            HDYM1 NOT_ROOT NOT_MIG     TIP  412   NA NA   NA  NA
# 10   52             <NA> NOT_ROOT NOT_MIG NOT_TIP    0  832 13  256   5
# 11   75         Tianyuan NOT_ROOT NOT_MIG     TIP  212   NA NA   NA  NA
# 12   76             <NA> NOT_ROOT NOT_MIG NOT_TIP  212  104  5    0  19
# ...

# %%
from IPython.display import Image
pD="/mnt/solexa/mel_yang/neolithic/treemix/ANCASN/imagefiles/"
outname="ANCASN_rd3_m2_k500"

Image(filename=pD+outname+'.png')

# %%
# %%writefile /mnt/solexa/mel_yang/neolithic/treemix/ANCASN/bootstrap.ANCASN_rd13_m0.sh
# ##BOOTSTRAP
# pd="/mnt/solexa/mel_yang/neolithic/treemix/ANCASN/"
# tv=""
# fh="ind_A_v13_TBH5"
# #fh="UPA_all6"
#
# subset="ANCASN_rd13";oldsubset="ANCASN_rd13"
# mig=0
#
# reps=1000
# newdir=${tv}${subset}_m${mig}_reps/
#
# mkdir ${pd}${newdir}
# myk=500
# for rep in `seq 1 ${reps}`; do
#     #echo ${rep}
#     treemix -i ${pd}${fh}.${oldsubset}.treemix.txt.gz -root Mbuti -bootstrap -k ${myk} -q -o ${pd}${newdir}${tv}${subset}_m${mig}_k${myk}_rep${rep} -m ${mig} > \
#             ${pd}${newdir}${tv}${subset}_m${mig}_k${myk}_rep${rep}.log
# done
# Out:
# Writing /mnt/solexa/mel_yang/neolithic/treemix/ANCASN/bootstrap.ANCASN_rd13_m0.sh

# %%
# %%bash
# ##BOOTSTRAP
# pd="/mnt/solexa/mel_yang/neolithic/treemix/ANCASN/"
# tv="transv."
# tv=""
# subset="ANCASN_rd13"
# #subset="UPANAmer2"
# myk="500"
# for mig in 0 1 2 3; do
#     reps=1000
#     newdir=${tv}${subset}_m${mig}_reps/
#
#     ##zcat ${pd}${tv}${subset}_m${mig}.treeout.gz | head -n1 > ${pd}${newdir}${tv}${subset}_m${mig}.trees
#     echo "" > ${pd}${newdir}${tv}${subset}_m${mig}_k${myk}.trees
#     for rep in `seq 1 ${reps}`; do
#         zcat ${pd}${newdir}${tv}${subset}_m${mig}_k${myk}_rep${rep}.treeout.gz | head -n1 >> \
#                 ${pd}${newdir}${tv}${subset}_m${mig}_k${myk}.trees
#     done
# done

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/neolithic/treemix/ANCASN/"
# myid="ANCASN_rd10_m3"
# addk="_k500"
# tv="transv."
# tv=""
# newdir=${tv}${myid}_reps/
# myfile=${pd}${newdir}${tv}${myid}${addk}".trees"
# if test -e outfile; then rm outfile; fi
# if test -e outtree; then rm outfile; fi
# cp ${myfile} intree
# outfile=${pd}${newdir}${tv}"BSTree_"${myid}${addk}
# echo "R" > ${pd}${newdir}${tv}"PhylipInputfile"
# echo "Y" >> ${pd}${newdir}${tv}"PhylipInputfile"
#
# phylip consense < ${pd}${newdir}${tv}"PhylipInputfile" > ${outfile}
#
# mv outfile ${pd}${newdir}${tv}outfile_${myid}${addk}
# mv outtree ${pd}${newdir}${tv}outtree_${myid}${addk}
# #echo ${pd}${newdir}${tv}outfile_${myid}${addk}
# #tail -n50 ${pd}${newdir}${tv}outfile_${myid}${addk}

# %% [markdown]
# ### 4. f4-ratio

# %%
# %%writefile /mnt/solexa/mel_yang/neolithic/f4ratio/calcf4_HDYM1.py
import plotting_funcs as pf
import projmodules as pm
from subprocess import Popen, PIPE

#outpd = '/mnt/solexa/mel_yang/neolithic/f4ratio/' ##ivpp
#pD ='/mnt/solexa/mel_yang/bronzeage/data/'   ##ivpp
pD = '/home/melinda_yang/data/HO_bronzeage/' ##mpi
outpd= '/home/melinda_yang/projects/neolithic/f4ratio/'  ##mpi

fh = 'ind_A_v13_TBH5'

subset = 'targetHDYM1_fTib_Bois'
Xs = ['HDYM1']
ABCs = [('Boshan','Boisman_MN',i) for i in ["Zongri","Chokhopani","Pukagongma"]]

subset = 'targetHDYM1_fBois_Tib'
Xs = ['HDYM1']
ABCs = [('Chokhopani','Pukagongma',i) for i in ['Boshan','Boisman_MN','Bbdong','Linzi']]

subset = 'targetPuka_fTib_HD'
Xs = ['Pukagongma']
ABCs = [(j,'HDYM1',i) for i in ["Zongri","Chokhopani"] for j in ["Boisman_MN","Boshan"]]

subset = 'targetPuka_fHD_Tib'
Xs = ['Pukagongma']
ABCs = [('Chokhopani','Zongri',i) for i in ['HDYM1','Boshan','Boisman_MN','Bbdong','Linzi']]

out = ['Chimp','Mbuti','Onge','Vestonice16','Kostenki14','Tianyuan']
pm.f4runitall(ABCs, Xs, out, pD, fh, subset,outpd=outpd)
# Out:
# Overwriting /mnt/solexa/mel_yang/neolithic/f4ratio/calcf4_HDYM1.py

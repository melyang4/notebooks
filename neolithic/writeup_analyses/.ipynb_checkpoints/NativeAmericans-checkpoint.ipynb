# %% [markdown]
# ## Explore Native American connections
# 1. Are LiangDao and Longlin outside of Native American-MA1 connection?
# 2. Is it affected by south vs. north Asians?
# 3. Surui-Mixe connection

# %%
### Treemix analysis
from projmodules import treemix_mkinput
treemix_mkinput?

# %%
# %%writefile /mnt/solexa/mel_yang/neolithic/treemix/maketreemixfile_NAmer_rd.py
from projmodules import treemix_mkinput

pd="/mnt/solexa/mel_yang/bronzeage/data/"
#outpD="/mnt/solexa/mel_yang/neolithic/qpwaveadm/"
fh="ind_A_v13_TBH5"
subset='LLLD_NAmer'
subset='NAmer_rd'
setstotry=[['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','Mixe','Surui','Pima','Xavante','Karitiana',
            'Daur','Hezhen','Boshan','Boisman_MN','Ulchi','Oroqen',
            'Ami_Stoneking','Atayal_Stoneking','Maonan','Paiwan','Rukai','Tao'], ##0 NORTH AND SOUTH
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','Mixe','Surui','Pima','Xavante','Karitiana',
            'Daur','Hezhen','Boshan','Boisman_MN','Ulchi','Oroqen'],  ##1 NORTH
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','Mixe','Surui','Pima','Xavante','Karitiana',
            'Ami_Stoneking','Atayal_Stoneking','Maonan','Paiwan','Rukai','Tao'], ##2 SOUTH
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','Mixe','Surui','Pima','Xavante','Karitiana',
            'Daur','Boshan','Boisman_MN','Ami_Stoneking','Atayal_Stoneking','Maonan'], ##3 NORTH AND SOUTH, smaller set
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','Mixe','Surui','Pima','Xavante','Karitiana',
            'Daur','Hezhen','Boshan','Boisman_MN','Ulchi','Oroqen',
            'Japanese','Han_NChina','She','Miao','Dai','Li',
            'Ami_Stoneking','Atayal_Stoneking','Maonan','Paiwan','Rukai','Tao'], ##4 NORTH AND SOUTH AND CENTRAL
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','Mixe','Surui','Pima','Xavante','Karitiana',
            'Japanese','Han_NChina','She','Miao','Dai','Li',
            'Ami_Stoneking','Atayal_Stoneking','Maonan','Paiwan','Rukai','Tao'], ##5 SOUTH AND CENTRAL
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','Mixe','Surui','Pima','Xavante','Karitiana',
            'Japanese','Han_NChina','She','Miao','Dai','Li',
            'Daur','Hezhen','Boshan','Boisman_MN','Ulchi','Oroqen'], ##6 NORTH AND CENTRAL
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','Mixe','Surui','Pima','Xavante','Karitiana',
            'Japanese','Han_NChina','She','Miao','Dai','Li'], ##7 CENTRAL
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','Mixe','Surui','Pima','Xavante','Karitiana',
            'Boshan','Boisman_MN'], ##8 ANCNORTH
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'Mixe','Surui','Pima','Xavante','Karitiana',
            'Daur','Hezhen','Boshan','Boisman_MN','Ulchi','Oroqen',
            'Japanese','Han_NChina','She','Miao','Dai','Li',
            'Ami_Stoneking','Atayal_Stoneking','Maonan','Paiwan','Rukai','Tao'], ##9 noLiangDao
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'Mixe','Surui','Pima','Xavante','Karitiana',
            'Daur','Hezhen','Ulchi','Oroqen',
            'Japanese','Han_NChina','She','Miao','Dai','Li',
            'Ami_Stoneking','Atayal_Stoneking','Maonan','Paiwan','Rukai','Tao'], ##10 noANC
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'Mixe','Surui','Pima','Xavante','Karitiana',
            'Japanese','Han_NChina','She','Miao','Dai','Li',
            'Ami_Stoneking','Atayal_Stoneking','Maonan','Paiwan','Rukai','Tao'], ##11 noANC, Central and Southern
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'Mixe','Surui','Pima','Xavante','Karitiana',
            'Ami_Stoneking','Atayal_Stoneking','Maonan','Paiwan','Rukai','Tao'], ##12 noANC, southern only
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'Mixe','Surui','Pima','Xavante','Karitiana',
            'Ami_Stoneking','Atayal_Stoneking','Paiwan','Rukai','Tao'], ##13 noANC, Taiwan only
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','Mixe','Surui','Pima','Xavante','Karitiana',
            'Ami_Stoneking','Atayal_Stoneking','Paiwan','Rukai','Tao'], ##14 Taiwan only
          ] 
for ind,i in enumerate(setstotry):
    print ind,i
    #if ind not in [11,12,13,14]: continue
    treemix_mkinput(pd,fh,subset+str(ind),setstotry[ind],includemissing=True) #,indfilename=fh+'.sepBois')
# Out:
# Writing /mnt/solexa/mel_yang/neolithic/treemix/maketreemixfile_NAmer_rd.py

# %% [markdown]
# ## DO UPA version!

# %%
# %%writefile /mnt/solexa/mel_yang/neolithic/treemix/maketreemixfile_UPA_NAmer.py
from projmodules import treemix_mkinput

pd="/mnt/solexa/mel_yang/allTYstuff/data/"
#outpD="/mnt/solexa/mel_yang/neolithic/qpwaveadm/"
fh="UPA_all6"
subset='NAmer'
setstotry=[['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','Mixe','Surui','Pima','Karitiana',
            'Daur','Hezhen','Boshan','Boisman','Ulchi','Oroqen',
            'Ami','Atayal'], ##0 NORTH AND SOUTH
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','Mixe','Surui','Pima','Karitiana',
            'Daur','Hezhen','Boshan','Boisman','Ulchi','Oroqen'],  ##1 NO SOUTH
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','Mixe','Surui','Pima','Karitiana',
            'Ami','Atayal'], ##2 NO NORTH
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','Mixe','Surui','Pima','Karitiana',
            'Boshan','Boisman','Ami','Atayal'], ##3 NORTH AND SOUTH, smaller set
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','Mixe','Surui','Pima','Karitiana',
            'Daur','Hezhen','Boshan','Boisman','Ulchi','Oroqen',
            'Japanese','Han','She','Miao','Dai',
            'Ami','Atayal'], ##4 NORTH AND SOUTH AND CENTRAL
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','Mixe','Surui','Pima','Karitiana',
            'Japanese','Han','She','Miao','Dai',
            'Ami','Atayal'], ##5 SOUTH AND CENTRAL
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','Mixe','Surui','Pima','Karitiana',
            'Japanese','Han','She','Miao','Dai',
            'Daur','Hezhen','Boshan','Boisman','Ulchi','Oroqen'], ##6 NORTH AND CENTRAL
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','Mixe','Surui','Pima','Karitiana',
            'Japanese','Han','She','Miao','Dai'], ##7 CENTRAL
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'LiangDao','Mixe','Surui','Pima','Karitiana',
            'Boshan','Boisman'], ##8 ANCNORTH
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'Mixe','Surui','Pima','Karitiana',
            'Daur','Hezhen','Boshan','Boisman','Ulchi','Oroqen',
            'Japanese','Han','She','Miao','Dai',
            'Ami','Atayal'], ##9 no LiangDao
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'Mixe','Surui','Pima','Karitiana',
            'Daur','Hezhen','Ulchi','Oroqen',
            'Japanese','Han','She','Miao','Dai',
            'Ami','Atayal'], ##10 noANC
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'Mixe','Surui','Pima','Karitiana',
            'Japanese','Han','She','Miao','Dai',
            'Ami','Atayal'], ##11 noANC
           ['Mbuti','Tianyuan','UstIshim','Kostenki14','Vestonice16','Malta1',
            'Mixe','Surui','Pima','Karitiana',
            'Ami','Atayal'], ##12 noANC, southern only
          ] 


for ind,i in enumerate(setstotry):
    print ind,i
    if ind not in [9,10,11,12]: continue
    treemix_mkinput(pd,fh,subset+str(ind),setstotry[ind],indfilename=fh+'.sepBois')
# Out:
# Overwriting /mnt/solexa/mel_yang/neolithic/treemix/maketreemixfile_UPA_NAmer.py

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/neolithic/treemix/"
# tv=""
# fh="ind_A_v13_TBH5"
# fh="UPA_all6"
# k="500"
# myk="_k"${k}
# for j in 4 5 6 7 8; do #`seq 0 5`; do
#     subset="NAmer"${j}
#     subsetnew="UPANAmer"${j}
#     zcat ${pd}${fh}.${subset}.treemix.txt.gz | head -n1 | tr ' ' '\n' > ${pd}${tv}${subsetnew}.popns.txt
# done
# Out:
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe
#
# gzip: stdout: Broken pipe

# %%
# %%writefile /mnt/solexa/mel_yang/neolithic/treemix/NAmer/maketreemixgraphNAmer.sh
# pd="/mnt/solexa/mel_yang/neolithic/treemix/NAmer/"
#
# #%%writefile /mnt/solexa/mel_yang/neolithic/treemix/maketreemixgraphNAmer.sh
# #pd="/mnt/solexa/mel_yang/neolithic/treemix/"
# tv=""
# fh="ind_A_v13_TBH5"
# #fh="UPA_all6"
# k="500"
# myk="_k"${k}
# for j in `seq 0 14`; do #`seq 0 9`; do
#     subset="NAmer_rd"${j}
#     #subset="LLLD_NAmer"${j}
#     gzip ${pd}${fh}.${subset}.treemix.txt
#     for i in `seq 0 5`; do
#         treemix -i ${pd}${fh}.${subset}.treemix.txt.gz -root Mbuti -o ${pd}${tv}${subset}_m${i}${myk} -k ${k} -m ${i} > \
#             ${pd}${tv}${subset}_m${i}${myk}.log
#     done
# done
#
# ##R CMD BATCH Rcode.R
# Out:
# Overwriting /mnt/solexa/mel_yang/neolithic/treemix/NAmer/maketreemixgraphNAmer.sh

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/neolithic/treemix/NAmer/"
# subset="NAmer_rd"
# #subset="UPANAmer"
# #subset="LLLD_NAmer"
# for id in `seq 0 14`; do
#     for mig in 0 1 2 3 4 5; do
#         Rscript ${pd}Rcodeimage.R ${pd} ${subset} ${id} ${mig}
#     done
# done
# Out:
# Fatal error: cannot open file '/mnt/solexa/mel_yang/neolithic/treemix/NAmer/Rcodeimage.R': No such file or directory
# Fatal error: cannot open file '/mnt/solexa/mel_yang/neolithic/treemix/NAmer/Rcodeimage.R': No such file or directory
# Fatal error: cannot open file '/mnt/solexa/mel_yang/neolithic/treemix/NAmer/Rcodeimage.R': No such file or directory
# Fatal error: cannot open file '/mnt/solexa/mel_yang/neolithic/treemix/NAmer/Rcodeimage.R': No such file or directory
# Fatal error: cannot open file '/mnt/solexa/mel_yang/neolithic/treemix/NAmer/Rcodeimage.R': No such file or directory
# Fatal error: cannot open file '/mnt/solexa/mel_yang/neolithic/treemix/NAmer/Rcodeimage.R': No such file or directory
# Fatal error: cannot open file '/mnt/solexa/mel_yang/neolithic/treemix/NAmer/Rcodeimage.R': No such file or directory
# Fatal error: cannot open file '/mnt/solexa/mel_yang/neolithic/treemix/NAmer/Rcodeimage.R': No such file or directory
# ...

# %%
from IPython.display import Image
pD="/mnt/solexa/mel_yang/neolithic/treemix/imagefiles/NAmer/"
outname="NAmer0_m2_k500"
outname="NAmer_rd0_m2_k500"
#outname="UPANAmer7_m5_k500"
#outname="LLLD_NAmer5_m5_k500"
Image(filename=pD+outname+'.png')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-7b23c3659f69> in <module>()
#       5 #outname="UPANAmer7_m5_k500"
#       6 #outname="LLLD_NAmer5_m5_k500"
# ----> 7 Image(filename=pD+outname+'.png')
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/display.pyc in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     755         self.unconfined = unconfined
#     756         self.metadata = metadata
# --> 757         super(Image, self).__init__(data=data, url=url, filename=filename)
#     758
#     759         if retina:
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/display.pyc in __init__(self, data, url, filename)
#     392         self.filename = None if filename is None else unicode_type(filename)
#     393
# --> 394         self.reload()
#     395         self._check_data()
#     396
#
# ...

# %%
# %%writefile /mnt/solexa/mel_yang/neolithic/treemix/bootstrap.NAmer12_m3.sh
# ##BOOTSTRAP
# pd="/mnt/solexa/mel_yang/neolithic/treemix/"
# tv=""
# fh="ind_A_v13_TBH5"
# #fh="UPA_all6"
#
# subset="NAmer12";oldsubset="NAmer12"
# #subset="UPANAmer5";oldsubset="NAmer5"
# mig=3
#
# reps=1000
# newdir=${tv}${subset}_m${mig}_reps/
#
# mkdir ${pd}${newdir}
# myk=500
# for rep in `seq 1 ${reps}`; do
#     #echo ${rep}
#     treemix -i ${pd}${fh}.${oldsubset}.treemix.txt.gz -root Mbuti -bootstrap -k ${myk} -q -o ${pd}${newdir}${tv}${subset}_m${mig}_k${myk}_rep${rep} -m ${mig} > \
#             ${pd}${newdir}${tv}${subset}_m${mig}_k${myk}_rep${rep}.log
# done
# Out:
# Writing /mnt/solexa/mel_yang/neolithic/treemix/bootstrap.NAmer12_m3.sh

# %% [markdown]
# ### Bootstrap analysis

# %%
# %%bash
# ##BOOTSTRAP
# pd="/mnt/solexa/mel_yang/neolithic/treemix/"
# tv="transv."
# tv=""
# subset="NAmer4"
# #subset="UPANAmer2"
# myk="500"
# for mig in 0 1 2 3; do
#     reps=1000
#     newdir=${tv}${subset}_m${mig}_reps/
#
#     ##zcat ${pd}${tv}${subset}_m${mig}.treeout.gz | head -n1 > ${pd}${newdir}${tv}${subset}_m${mig}.trees
#     echo "" > ${pd}${newdir}${tv}${subset}_m${mig}_k${myk}.trees
#     for rep in `seq 1 ${reps}`; do
#         zcat ${pd}${newdir}${tv}${subset}_m${mig}_k${myk}_rep${rep}.treeout.gz | head -n1 >> \
#                 ${pd}${newdir}${tv}${subset}_m${mig}_k${myk}.trees
#     done
# done

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/neolithic/treemix/"
# myid="UPANAmer2_m0"
# myid="NAmer4_m3"
# addk="_k500"
# tv="transv."
# tv=""
# newdir=${tv}${myid}_reps/
# myfile=${pd}${newdir}${tv}${myid}${addk}".trees"
# if test -e outfile; then rm outfile; fi
# if test -e outtree; then rm outfile; fi
# cp ${myfile} intree
# outfile=${pd}${newdir}${tv}"BSTree_"${myid}${addk}
# echo "R" > ${pd}${newdir}${tv}"PhylipInputfile"
# echo "Y" >> ${pd}${newdir}${tv}"PhylipInputfile"
#
# phylip consense < ${pd}${newdir}${tv}"PhylipInputfile" > ${outfile}
#
# mv outfile ${pd}${newdir}${tv}outfile_${myid}${addk}
# mv outtree ${pd}${newdir}${tv}outtree_${myid}${addk}
# #echo ${pd}${newdir}${tv}outfile_${myid}${addk}
# #tail -n50 ${pd}${newdir}${tv}outfile_${myid}${addk}

# %% [markdown]
# ## D(EAS,NAMER,LD,Mbuti)

# %%
import plotting_funcs as pf
#import HOdata

#pD="/mnt/solexa/mel_yang/bronzeage/data/" #ivpp
#outpd="/mnt/solexa/mel_yang/bronzeage/Dstats/D_ShangZhou_merged/" #ivpp
pD="/home/melinda_yang/data/HO_bronzeage/" #mpi
outpd="/home/melinda_yang/projects/neolithic/D_NAmer/" #mpi

pdeas=['Daur','Hezhen','Mongola','Ulchi','Xibo','Japanese','Korean','Han_NChina','Han_Shandong', 
       'Han_HGDP','Dai','Li','Maonan','Miao','She','Zhuang','Ami_Stoneking','Atayal_Stoneking',
       'Kinh_Vietnam_KHV','Yi','Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha']
pubanceas=['Tianyuan', 'Longlin', 'LiangDao1', 'LiangDao2', 'HDYM1', 'Boisman_MN', 'Bbdong', 'Boshan', 'Linzi', 
        'Yankovsky_IA','Heshui_Mohe_Early_Medieval','Ainu',
        'Zongri', 'Chokhopani', 'Mebrak', 'Samdzong']
anceur=["UstIshim","Kostenki14","GoyetQ116-1","Vestonice16","Malta1","ElMiron",
        "Villabruna","Loschbour","Stuttgart","Sardinian","French","Onge","Papuan",
        "Surui","Karitiana","Mixe"]
namer=["Chipewyan","Chilote","Ojibwa","Algonquin","Cree","Guarani","Zoro","Xavante",
       "Surui","Piapoco","Karitiana","Cabecar","Apalai","Arara",
      "Ticuna","Chane","Wayuu","Aymara","Bolivian","Quechua","Kaqchikel","Mixe","Pima",
      "Mayan","Inga","Mixtec","Zapotec","Guarani_KW","Guarani_GN","Clovis.SG","Saqqaq.SG"]

fh="ind_A_v13_TBH5"
outs=["Mbuti"]

bsf,bsfsubset=(0,'all')
indfilename="ind_A_v13_TBH5.sepLD"

p1s=["LiangDao1","LiangDao2"]
for myp1 in p1s:
    for myp4 in outs:
        p1,p2,p3,p4 = (myp1,pdeas,namer,myp4)
        subset = bsfsubset+'.'+p1+'_'+"PDEAS"+'_'+"NAMER"+'_'+p4
        mytups = [(p1,i,j,p4,'p2_'+i) for ind,i in enumerate(p2) for j in p3 if i != j and p1!=i and p1!=j]
        pf.runD(p2,p3,mytups,pD,fh,subset,(1,2),(0,),fixed=(p1,0,0,p4),badsnpfile=bsf,outpd=outpd,indfilename=indfilename) 
        
        p1,p2,p3,p4 = (myp1,pubanceas,namer,myp4)
        subset = bsfsubset+'.'+p1+'_'+"ANCEAS"+'_'+"NAMER"+'_'+p4
        mytups = [(p1,i,j,p4,'p2_'+i) for ind,i in enumerate(p2) for j in p3 if i != j and p1!=i and p1!=j]
        pf.runD(p2,p3,mytups,pD,fh,subset,(1,2),(0,),fixed=(p1,0,0,p4),badsnpfile=bsf,outpd=outpd,indfilename=indfilename)

# %% [markdown]
# ## Surui-Mixe connection observed in any non-TY ancient Asians?

# %% [markdown]
# ## D(Surui, Mixe; ASN, Mbuti)
# Also consider .DG Surui and Mixe

# %%
##Copy/pasted into bionc12  -- /home/melinda_yang/projects/neolithic/D_SuruiMixe_vs_EAS.py

import plotting_funcs as pf
#import HOdata

#pD="/mnt/solexa/mel_yang/bronzeage/data/" #ivpp
#outpd="/mnt/solexa/mel_yang/bronzeage/Dstats/D_ShangZhou_merged/" #ivpp
pD="/home/melinda_yang/data/HO_bronzeage/" #mpi
outpd="/home/melinda_yang/projects/neolithic/D_NAmer/" #mpi

pdeas=['Daur','Hezhen','Mongola','Ulchi','Xibo','Japanese','Korean','Han_NChina','Han_Shandong', 
       'Han_HGDP','Dai','Li','Maonan','Miao','She','Zhuang','Ami_Stoneking','Atayal_Stoneking',
       'Kinh_Vietnam_KHV','Yi','Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha']
pubanceas=['Tianyuan', 'Longlin', "Xinyi", 
           "Vietnam_Neolithic","Vietnam_BA","Vietnam_Pre_Neolithic", 'LiangDao', 
           'HDYM1', 'Boisman_MN', 'Bbdong', 'Boshan', 'Linzi', 
        'Yankovsky_IA','Heshui_Mohe_Early_Medieval','Ainu',
        'Zongri', 'Chokhopani', 'Mebrak', 'Samdzong']
anceur=["UstIshim","Kostenki14","GoyetQ116-1","Vestonice16","Malta1","ElMiron",
        "Villabruna","Loschbour","Stuttgart","Sardinian","French","Onge","Papuan",
        "Surui","Karitiana","Mixe"]
namers=["Surui","Karitiana","Chane","Xavante","Pima","Surui.DG","Karitiana.DG","Chane.DG"]
fh="ind_A_v13_TBH5"
outs=["Mbuti"]

bsf,bsfsubset=(0,'all')

p1s=["Longlin","Longlin_d","LiangDao","Bbdong","Boshan","HDYM1","Boisman_MN","Linzi"]
p1s=["Linzi_d","Zongri","Zongri_d"]
p1s=["Pukagongma"]
p1s=["Xinyi","Xinyi_d"] 
p1s=["Vietnam_Neolithic","Vietnam_BA","Vietnam_Pre_Neolithic"]
p1s = ["Mixe","Mixe.DG"]
for myp1 in p1s:
    for myp4 in outs:
        ##D(Surui, Mixe; EAS, Mbuti)
        p1,p2,p3,p4 = (myp1,namers,pdeas,myp4)
        pxname, pyname=("SAMER","PDEAS")
        subset = bsfsubset+'.'+p1+'_'+pxname+'_'+pyname+'_'+p4
        mytups = [(p1,i,j,p4,'p2_'+i) for ind,i in enumerate(p2) for j in p3 if i != j and p1!=i and p1!=j]
        pf.runD(p2,p3,mytups,pD,fh,subset,(1,2),(0,),fixed=(p1,0,0,p4),badsnpfile=bsf,outpd=outpd) 

        p1,p2,p3,p4 = (myp1,namers,pubanceas,myp4)
        pxname, pyname=("SAMER","ANCEAS")
        subset = bsfsubset+'.'+p1+'_'+pxname+'_'+pyname+'_'+p4
        mytups = [(p1,i,j,p4,'p2_'+i) for ind,i in enumerate(p2) for j in p3 if i != j and p1!=i and p1!=j]
        pf.runD(p2,p3,mytups,pD,fh,subset,(1,2),(0,),fixed=(p1,0,0,p4),badsnpfile=bsf,outpd=outpd)

# %%
print len(['Han_Chongqing', 'Han_Fujian', 'Han_Guandong', 'Han_Shanghai','Han_Zhejiang', 
          'Tujia','Dong', 'Gelao', 'Lahu', 'Mulam','Cambodian', 'Thai', 'Malay', 'Malayan', 
          'Bunun', 'Tao', 'Burmese', 'Vietnamese', 'Paiwan', 'Rukai', 'Hakka', 'Minnan', 
          'Pingpu', 'Atayal_Coriell', 'Ami_Coriell', 'Bonan'])
# Out:
# 26

# %% [markdown]
# ## Do analysis for omitted pdEAS (PDOEAS)

# %% [markdown]
# ## Look more closely at southern pdEAS and Longlin
# Do D(PDEAS, North; Longlin, Mbuti) and then plot on map

# %%
##Copy/pasted into bionc12  -- /home/melinda_yang/projects/neolithic/D_Longlin_vs_ALLEAS_NEAS.py

import plotting_funcs as pf
#import HOdata

#pD="/mnt/solexa/mel_yang/bronzeage/data/" #ivpp
#outpd="/mnt/solexa/mel_yang/bronzeage/Dstats/D_ShangZhou_merged/" #ivpp
pD="/home/melinda_yang/data/HO_bronzeage/" #mpi
outpd="/home/melinda_yang/projects/neolithic/D_Longlin/" #mpi

allids=['Daur', 'Hezhen', 'Mongola', 'Naxi', 'Oroqen', 'Ulchi', 'Xibo', 'Dai', 'Dong', 
     'Gelao', 'Lahu', 'Li', 'Maonan', 'Miao', 'Mulam', 'She', 'Tujia', 'Yi', 'Zhuang', 
     'Cambodian', 'Han_Chongqing', 'Han_Fujian', 'Han_Guandong', 'Han_Henan', 'Han_HGDP', 
     'Han_Hubei', 'Han_Jiangsu', 'Han_NChina', 'Han_Shandong', 'Han_Shanghai', 'Han_Shanxi', 
     'Han_Sichuan', 'Han_Zhejiang', 'Kinh_Vietnam_KHV', 'Korean', 'Thai', 'Qiang_Horpa', 
     'Tibetan_Chamdo', 'Tibetan_Gangcha', 'Tibetan_Gannan', 'Tibetan_Lhasa', 'Tibetan_Nagqu', 
     'Tibetan_Shannan', 'Tibetan_Shigatse', 'Tibetan_Xinlong', 'Tibetan_Xunhua', 
     'Tibetan_Yajiang', 'Japanese', 'Ami_Stoneking', 'Atayal_Stoneking', 'Tu', 'Dongxiang', 
     'Kyrgyz_China', 'Kyrgyz', 'Kazakh_China', 'Kazakh', 'Uygur', 'Mongol', 'Tibetan_Yunnan', 
     'Bunun', 'Tao', 'Burmese', 'Vietnamese', 'Paiwan', 'Rukai', 'Hakka', 'Minnan', 'Pingpu', 
     'Atayal_Coriell', 'Ami_Coriell', 'Bonan', 'Yugur_Eastern', 'Yugur_Western', 'Salar', 
     'Malay', 'Malayan', 'Chokhopani', 'Mebrak', 'Samdzong', 'Boisman_MN', 'Tianyuan', 
     'Boshan', 'Donghuigou', 'Balikun', 'Zhougongmiao', 'Yaojia', 'Linzi', 'XianShang', 
     'Zongri', 'Huoshaogou', 'Wuba', 'Xiaoshuangqiao', 'Guandimiao', 'Shengedaliang', 
     'Muzhuzhuliang', 'Xinhua', 'Wuzhuangguo', 'Shimao', 'Tonglin', 'Dashuitian', 'Longlin', 
     'Bbdong', 'Taosi', 'Xinyi', 'Pukagongma', 'Redilong', 'Butaxiongqu', 'Gelintang', 
     'Yingpanshan', 'Mougou', 'Sanheyi', 'Yusu', 'Jinchankou', 'Jomon', 'HDYM1', 'HQSDW', 'LiangDao']
neas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Daur','Hezhen','Mongola','Ulchi','Xibo']
anceur=["UstIshim","Kostenki14","GoyetQ116-1","Vestonice16","Malta1","ElMiron",
        "Villabruna","Loschbour","Stuttgart","Sardinian","French","Onge","Papuan",
        "Surui","Karitiana","Mixe"]

fh="ind_A_v13_TBH5"
outs=["Mbuti"]

bsf,bsfsubset=(0,'all')

p1s=["Longlin"]
for myp1 in p1s:
    for myp4 in outs:
        ##D(X, Y; LL, Mbuti)
        p1,p2,p3,p4 = (allids,neas,myp1,myp4)
        subset = bsfsubset+'.'+"ALLEAS"+'_'+"NEAS"+'_'+p3+'_'+p4
        mytups = [(i,j,p3,p4,'p2_'+i) for ind,i in enumerate(p1) for j in p2 if i != j and p3!=i and p3!=j]
        pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),fixed=(0,0,p3,p4),badsnpfile=bsf,outpd=outpd)

# %% [markdown]
# ## Take log file of D and put D together with lat/long

# %%
##GET LATLONGS
lpd="/mnt/solexa/mel_yang/bronzeage/Dstats/"
fh="ind_A_v13_TBH5"
ancind="Boshan"
p4="Mbuti"
dir1="D_ANC_EAS_EAS_P4/"
latlongs={}
latlongfile=open("%s%s%s.pd.D_%s_Tianyuan_EAS_%s.map" % (lpd,dir1,fh,ancind,p4),'r')
for line in latlongfile: 
    x=line.split()
    latlongs[x[0]]=(float(x[1]),float(x[2]))
#latlongs["LiangDao"]=(26,121) ##Put just above Atayal
#latlongs["Xinyi"]=(23,105.3) ##Put just below Longlin
Dpd="/mnt/solexa/mel_yang/neolithic/Dstats/"   
subset="ALLEAS_NEAS_Longlin_Mbuti"
north="Boshan"

neas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Daur','Hezhen','Mongola','Ulchi','Xibo']
for north in neas:
    newmapfile=open("%s%s.D.all.%s.north_%s.map" % (Dpd,fh,subset,north),'w')
    Dfile=open("%s%s.D.all.%s.log" % (Dpd,fh,subset),'r')
    for line in Dfile:
        if "result" not in line: continue
        x=line.split()
        if x[2] != north: continue
        if x[1] not in latlongs.keys(): continue
        D=float(x[5])
        Z=float(x[7])
        if Z<0: continue ##Place Z cutoff of 2
        ancpd="anc" if x[1] in ["LiangDao","Xinyi"] else "pd"
        newmapfile.write("%s\t%s\t%s\t%.4f\t%s\t%.4f\n" % (x[1], latlongs[x[1]][0], latlongs[x[1]][1], D, ancpd, Z))
    newmapfile.close()

    newreffile=open("%s%s.D.all.%s.north_%s.ref" % (Dpd,fh,subset,north),'w')
    newreffile.write("%s\t%s\t%s\t%.4f\n" % ("Longlin", 24.8, 105.3, -5))
    newreffile.close()

# %%
# %%bash
# pD="/mnt/solexa/mel_yang/bronzeage/Dstats/D_ANC_EAS_EAS_P4/"
# Dpd="/mnt/solexa/mel_yang/neolithic/Dstats/"
# fh="ind_A_v13_TBH5"
# subset="ALLEAS_NEAS_Longlin_Mbuti"
# for north in HDYM1 Boisman_MN Bbdong Boshan Linzi Daur Hezhen Mongola Ulchi Xibo; do
#     outname="${fh}.D.all.${subset}.north_${north}"
#     Rscript ${pD}heatmap_ancchina_D.R ${Dpd}${outname} "D(EAS, ${north}; Longlin, Mbuti)"
# done
# Out:
# null device
#           1
# null device
#           1
# null device
#           1
# null device
#           1
# null device
#           1
# null device
#           1
# null device
#           1
# null device
#           1
# null device
#           1
# null device
#           1
# Loading required package: methods
# Loading required package: spam
# Loading required package: grid
# Spam version 1.3-0 (2015-10-24) is loaded.
# Type 'help( Spam)' or 'demo( spam)' for a short introduction
# and overview of this package.
# Help for individual functions is also obtained by adding the
# suffix '.spam' to the function name, e.g. 'help( chol.spam)'.
#
# Attaching package: ‘spam’
#
# The following objects are masked from ‘package:base’:
#
#     backsolve, forwardsolve
#
# Loading required package: maps
# Warning message:
# In `levels<-`(`*tmp*`, value = if (nl == nL) as.character(labels) else paste0(labels,  :
#   duplicated levels in factors are deprecated
# Loading required package: sp
# ...

# %%
from IPython.display import Image

neas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Daur','Hezhen','Mongola','Ulchi','Xibo']
neas=['HDYM1','Boshan','Daur','Hezhen','Mongola','Ulchi','Xibo']
Dpd="/mnt/solexa/mel_yang/neolithic/Dstats/"
fh="ind_A_v13_TBH5"
north="Daur"
subset="ALLEAS_NEAS_Longlin_Mbuti"
outname="%s%s.D.all.%s.north_%s" % (Dpd,fh,subset,north)
Image(filename=outname+'.png',width=1000,height=1000)

# %% [markdown]
# ## Plotting D against lat or long

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import math

Dpd="/mnt/solexa/mel_yang/neolithic/Dstats/"
fh="ind_A_v13_TBH5"
north="Daur"
subset="ALLEAS_NEAS_Longlin_Mbuti"
outname="%s%s.D.all.%s.north_%s" % (Dpd,fh,subset,north)
myfile=open(outname+".map","r")
pops,lats,longs,Ds,Zs=[],[],[],[],[]
for line in myfile:
    x=line.split()
    if x[0]=="Xinyi": continue
    pops.append(x[0])
    lats.append(float(x[1]))
    longs.append(float(x[2]))
    Ds.append(float(x[3]))
    Zs.append(float(x[5]))
mytuple=zip(longs,lats,pops,Ds,Zs)
cutoff=sorted(Ds)[::-1][:40][-1]
cutoffinds=[i[2] for i in mytuple if i[3] < cutoff]

maxDind=Ds.index(max(Ds))
centerlong=mytuple[maxDind][0]
centerlat=mytuple[maxDind][1]

inds = [p for (o,a,p,d,z) in sorted(mytuple) if p not in cutoffinds]
ys1 = [d for (o,a,p,d,z) in sorted(mytuple) if p not in cutoffinds]
newlongs = [o for (o,a,p,d,z) in sorted(mytuple) if p not in cutoffinds]
newlats = [a for (o,a,p,d,z) in sorted(mytuple) if p not in cutoffinds]
se = [1.96*(d/z) for (o,a,p,d,z) in sorted(mytuple) if p not in cutoffinds]    
dists=[math.sqrt(abs(o-centerlong)**2 +abs(a-centerlat)**2) for (o,a,p,d,z) in sorted(mytuple) if p not in cutoffinds]    
dists=[i/max(dists) for i in dists]
xs1=dists

LDind=inds.index("LiangDao")

fig = plt.figure(figsize=(17,4))
titles=["D vs Distance from LD, Normalized", "D vs Longitude", "D vs Latitude"]
#for ind1,i in enumerate(xs1): print xs1[ind1],inds[ind1], ys1[ind1]

for plotind,xs1 in enumerate([dists,newlongs,newlats]):
    ax1=fig.add_subplot(1,3,plotind+1)
    #ax1.plot(xs1,ys1,'ro',alpha=0.5)
    ax1.errorbar(xs1, ys1, yerr=se, fmt='ro')
    #ax1.plot(xs1[,ys1,'bo',alpha=0.5)
    ax1.errorbar(xs1[LDind], ys1[LDind], yerr=se[LDind], fmt='bo')
    ax1.set_ylim(-0.01,0.04)
    #ax1.set_xlim(-2500,48000)
    #ax1.set_xlim(48000,-2500)
    ax1.set_xlabel('Longitude')
    ax1.set_ylabel("D")
    #ax1.text(50000,-0.03,labels[ind],fontsize=17)
    plt.title(titles[plotind])
    ax1.axhline(y=0, ls='solid', c='grey',alpha=0.3)
    #ax1.axhline(y=cutoff[ind], ls='dashed', c='grey',alpha=0.3)
    #ax1.axhline(y=maxcutoff[ind], ls='dashed', c='grey',alpha=0.3)
    print

# %%
import numpy as np
import seaborn as sns
data = [1.5]*7 + [2.5]*2 + [3.5]*8 + [4.5]*3 + [5.5]*1 + [6.5]*8
sns.set_style('whitegrid')
sns.kdeplot(np.array(data), bw=0.5)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-e8a33c476d9a> in <module>()
#       1 import numpy as np
# ----> 2 import seaborn as sns
#       3 data = [1.5]*7 + [2.5]*2 + [3.5]*8 + [4.5]*3 + [5.5]*1 + [6.5]*8
#       4 sns.set_style('whitegrid')
#       5 sns.kdeplot(np.array(data), bw=0.5)
#
# ImportError: No module named seaborn

# %%
import math
math.sqrt(4)
# Out:
# 2.0

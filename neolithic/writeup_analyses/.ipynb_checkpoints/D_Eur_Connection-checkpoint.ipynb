# %% [markdown]
# ## D-stats exploring relationship of other Eurasians to Asians
# 1. D(EAS, EAS, EUR, Mbuti)

# %%
##Copy/pasted into bionc12  -- /home/melinda_yang/projects/neolithic/D_Eur_vsALLEAS.py

import plotting_funcs as pf
#import HOdata

#pD="/mnt/solexa/mel_yang/bronzeage/data/" #ivpp
#outpd="/mnt/solexa/mel_yang/bronzeage/Dstats/D_ShangZhou_merged/" #ivpp
pD="/home/melinda_yang/data/HO_bronzeage/" #mpi
outpd="/home/melinda_yang/projects/neolithic/D_WEur/" #mpi

weas=['Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha','Zongri', 'Chokhopani', 'Mebrak', 'Samdzong']
neas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Daur','Hezhen','Mongola','Ulchi','Xibo']
seas=['LiangDao','Longlin','Xinyi',"Vietnam_Pre_Neolithic","Vietnam_Neolithic","Vietnam_BA",
      'Japanese','Korean','Han_NChina','Han_Shandong','Han_HGDP','Dai','Li','Maonan','Miao','She',
      'Zhuang','Ami_Stoneking','Atayal_Stoneking','Kinh_Vietnam_KHV','Yi']

pdeas=neas+weas+seas
west=['UstIshim',"Kostenki14","Vestonice16","GoyetQ116-1",'Pavlov1','KremsWA3','Ostuni1','HohleFels49',
      "ElMiron","Malta1","Villabruna",'Bichon','Rochedane','Ranchot88',
      "Loschbour",'LaBrana1','Koros_Hungary_EN_HG.SG','Motala_HG','Karelia_HG','LaRochette',
      "Stuttgart","Satsurblia","Kotias","Sardinian","French"]
fh="ind_A_v13_TBH5"
outs=["Mbuti"]

bsf,bsfsubset=(pD+fh+".transi.snp",'transv')
bsf,bsfsubset=(0,'all')

p1s=west
for myp1 in p1s:
    for myp4 in outs:
        ##D(X, Y; LL, Mbuti)
        p1,p2,p3,p4 = (pdeas,pdeas,myp1,myp4)
        subset = bsfsubset+'.'+"ALLEAS"+'_'+"ALLEAS"+'_'+p3+'_'+p4
        mytups = [(i,j,p3,p4,'p2_'+i) for ind,i in enumerate(p1) for j in p2 if i != j and p3!=i and p3!=j]
        pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),fixed=(0,0,p3,p4),badsnpfile=bsf,outpd=outpd)

# %%
##Copy/pasted into bionc12  -- /home/melinda_yang/projects/neolithic/D_Eur_vs_ALLEUR.py

import plotting_funcs as pf
#import HOdata

#pD="/mnt/solexa/mel_yang/bronzeage/data/" #ivpp
#outpd="/mnt/solexa/mel_yang/bronzeage/Dstats/D_ShangZhou_merged/" #ivpp
pD="/home/melinda_yang/data/HO_bronzeage/" #mpi
outpd="/home/melinda_yang/projects/neolithic/D_WEur/" #mpi

weas=['Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha','Zongri', 'Chokhopani', 'Mebrak', 'Samdzong']
neas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Daur','Hezhen','Mongola','Ulchi','Xibo']
seas=['LiangDao','Longlin','Xinyi',"Vietnam_Pre_Neolithic","Vietnam_Neolithic","Vietnam_BA",
      'Japanese','Korean','Han_NChina','Han_Shandong','Han_HGDP','Dai','Li','Maonan','Miao','She',
      'Zhuang','Ami_Stoneking','Atayal_Stoneking','Kinh_Vietnam_KHV','Yi']

pdeas=neas+weas+seas
west=['UstIshim',"Kostenki14","Vestonice16","GoyetQ116-1",'Pavlov1','KremsWA3','Ostuni1','HohleFels49',
      "ElMiron","Malta1","Villabruna",'Bichon','Rochedane','Ranchot88',
      "Loschbour",'LaBrana1','Koros_Hungary_EN_HG.SG','Motala_HG','Karelia_HG','LaRochette',
      "Stuttgart","Satsurblia","Kotias","Sardinian","French"]
fh="ind_A_v13_TBH5"
outs=["Mbuti"]

bsf,bsfsubset=(pD+fh+".transi.snp",'transv')
bsf,bsfsubset=(0,'all')

p1,p2,p3,p4 = (pdeas,"Tianyuan",west,"Mbuti")
subset = bsfsubset+'.'+"ALLEAS"+'_'+p2+'_'+"ALLEUR"+'_'+p4
mytups = [(i,p2,j,p4,'p2_'+i) for ind,i in enumerate(p1) for j in p3 if i != j and p2!=i and p2!=j]
pf.runD(p1,p3,mytups,pD,fh,subset,(0,2),(0,),fixed=(0,p2,0,p4),badsnpfile=bsf,outpd=outpd) 

p1s=pdeas
for myp1 in p1s:
    for myp4 in outs:
        ##D(X, Y; LL, Mbuti)
        p1,p2,p3,p4 = (west,west,myp1,myp4)
        subset = bsfsubset+'.'+"ALLEUR"+'_'+"ALLEUR"+'_'+p3+'_'+p4
        mytups = [(i,j,p3,p4,'p2_'+i) for ind,i in enumerate(p1) for j in p2 if i != j and p3!=i and p3!=j]
        pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),fixed=(0,0,p3,p4),badsnpfile=bsf,outpd=outpd)

# %%
##Copy/pasted into bionc12  -- /home/melinda_yang/projects/neolithic/D_Eur_vs_ALLEUR.py

import plotting_funcs as pf
#import HOdata

#pD="/mnt/solexa/mel_yang/bronzeage/data/" #ivpp
#outpd="/mnt/solexa/mel_yang/bronzeage/Dstats/D_ShangZhou_merged/" #ivpp
pD="/home/melinda_yang/data/HO_bronzeage/" #mpi
outpd="/home/melinda_yang/projects/neolithic/D_WEur/" #mpi

weas=['Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha','Zongri', 'Chokhopani', 'Mebrak', 'Samdzong']
neas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Daur','Hezhen','Mongola','Ulchi','Xibo']
seas=['Tianyuan','LiangDao','Longlin','Xinyi',"Vietnam_Pre_Neolithic","Vietnam_Neolithic","Vietnam_BA",
      'Japanese','Korean','Han_NChina','Han_Shandong','Han_HGDP','Dai','Li','Maonan','Miao','She',
      'Zhuang','Ami_Stoneking','Atayal_Stoneking','Kinh_Vietnam_KHV','Yi']

ancset=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi',
        'LiangDao','Longlin','Xinyi',"Vietnam_Pre_Neolithic","Vietnam_Neolithic","Vietnam_BA"]

pdeas=neas+weas+seas
west=['UstIshim',"Kostenki14","Vestonice16","GoyetQ116-1",'Pavlov1','KremsWA3','Ostuni1','HohleFels49',
      "ElMiron","Malta1","Villabruna",'Bichon','Rochedane','Ranchot88',
      "Loschbour",'LaBrana1','Koros_Hungary_EN_HG.SG','Motala_HG','Karelia_HG','LaRochette',
      "Stuttgart","Satsurblia","Kotias","Sardinian","French"]
fh="ind_A_v13_TBH5"
outs=["Mbuti"]

bsf,bsfsubset=(pD+fh+".transi.snp",'transv')
bsf,bsfsubset=(0,'all')

for myp2 in ancset:
    p1,p2,p3,p4 = (pdeas,myp2,west,"Mbuti")
    subset = bsfsubset+'.'+"ALLEAS"+'_'+p2+'_'+"ALLEUR"+'_'+p4
    mytups = [(i,p2,j,p4,'p2_'+i) for ind,i in enumerate(p1) for j in p3 if i != j and p2!=i and p2!=j]
    pf.runD(p1,p3,mytups,pD,fh,subset,(0,2),(0,),fixed=(0,p2,0,p4),badsnpfile=bsf,outpd=outpd)

# %% [markdown]
# ## Visualize D
# 1. Plot D(LD, EAS; EUR, Mbuti)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches
import plotting_funcs as pf



pD = "/mnt/solexa/mel_yang/neolithic/Dstats/D_WEur/"
outs = ['Mbuti']

aeas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Zongri', 'Chokhopani', 'Mebrak', 'Samdzong',
      'LiangDao','Longlin','Xinyi',"Vietnam_Pre_Neolithic","Vietnam_Neolithic","Vietnam_BA"]
neas=['Daur','Hezhen','Mongola','Ulchi','Xibo','Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha']
seas=['Japanese','Korean','Han_NChina','Han_Shandong','Han_HGDP','Miao','She','Dai','Li','Maonan',
      'Zhuang','Ami_Stoneking','Atayal_Stoneking','Kinh_Vietnam_KHV','Yi']

pdeas=neas+seas+aeas
wantedpops = [i for i in pdeas[::-1] if i not in ["Xinyi","Vietnam_Pre_Neolithic","Vietnam_Neolithic","Vietnam_BA"]] 
mynames=wantedpops[:]
mynames[mynames.index('Tibetan_Shannan')]='Tib_Shannan'
mynames[mynames.index('Tibetan_Chamdo')]='Tib_Chamdo'
mynames[mynames.index('Tibetan_Gangcha')]='Tib_Gangcha'
#mynames[mynames.index('Vietnam_Neolithic')]='Vietnam_Neo'
#mynames[mynames.index('Vietnam_Pre_Neolithic')]='Vietnam_Pre'
mynames[mynames.index('Ami_Stoneking')]='Ami'
mynames[mynames.index('Atayal_Stoneking')]='Atayal'
mynames[mynames.index('Kinh_Vietnam_KHV')]='Kinh'
mynames[mynames.index('Boisman_MN')]='Boisman'
myasn="LiangDao"
fh="ind_A_v13_TBH5"
mytwoeurs = [['GoyetQ116-1','Vestonice16','Malta1','Villabruna','Loschbour','Stuttgart']]
for myeurs in mytwoeurs:
    for out in outs:
        fig = plt.figure(figsize=(22,10))
        colors = ['red','blue','brown','black','orange','purple']
        
        myxmins = [-0.05]*len(myeurs)
        myxmaxs = [0.05]*len(myeurs)
        mylabel = ['A','B','C','D','E']
        if 'Karelia' in myeurs: mylabel = ['F','G','H','I','J']
        mylabellocation = [-0.11]*len(myeurs)

        for mysubplot,myeur in enumerate(myeurs):
            ax1=fig.add_subplot(1,6,mysubplot+1)
            
            #myylabel,mytitle,legendadd = labels[mysubplot]
            myset = "all.ALLEAS_ALLEAS_%s_%s" % (myeur,out)
            mycond = True if 'tp' in myset else False
            myZary,mypops1,mypops2 = pf.mkDZary(pD+fh+".D."+myset+'.Zmat',mycond)
            myDary,mypops1,mypops2 = pf.mkDZary(pD+fh+".D."+myset+'.Dmat',mycond)
            mySEary=myDary/myZary
            goodpops2 = [mypops2.index(i) for i in wantedpops]
            #getsmaller = [5,5,5]

            goodpops1 = mypops1.index(myasn)
            myys = np.array(range(len(goodpops2)))
            tyD = myDary[goodpops1,goodpops2]
            tySE = mySEary[goodpops1,goodpops2]
            ax1.errorbar(tyD,myys,xerr=tySE, color='darkgrey',fmt='o',capthick=0,linewidth=7)
            ax1.errorbar(tyD,myys,xerr=2*tySE, color='darkgrey',fmt='o',capthick=0,linewidth=4)
            ax1.plot(tyD,myys,'o',markersize=10,color=colors[mysubplot])
            
            ax1.set_yticks(myys) #,rotation=45)
            if mysubplot==0:
                ax1.set_yticklabels(mynames,fontsize=17)
                #ax1.set_ylabel("P3",fontsize=20)
                ax1.text(-0.13,16.5,'X',rotation = 0, fontsize=25)
                #ax1.text(-0.195,26.5,'East/Southeast Asians',rotation = 90, fontsize=20)
                #ax1.text(-0.2,6.5,'Native',rotation = 90, fontsize=20)
                #ax1.text(-0.19,7.5,'Americans',rotation = 90, fontsize=20)
            elif mysubplot == len(myeurs)-1:
                print mysubplot
                ax1.set_yticklabels(['']*len(wantedpops),fontsize=17)
                ax2=ax1.twinx()
                ax2.set_ylim(-1,len(goodpops2)) #,rotation=45)
                ax2.set_yticks( myys )
                ax2.set_yticklabels(['']*len(wantedpops),fontsize=17)
                #ax1.text(0.06,20.5,'Vestonice16',rotation = 270, fontsize=20)
                #ax1.text(0.08,16.5,'X',rotation = 0, fontsize=25)
                ax1.text(-0.38,-6,"D(%s,X;P3,Mbuti)" % myasn,fontsize=25)
            else: 
                ax1.set_yticklabels(['']*len(wantedpops),fontsize=15)
                
                
            ax1.set_ylim(-1,len(goodpops2))
            ax1.set_xlim(myxmins[mysubplot],myxmaxs[mysubplot])
    
            xlabel = ax1.get_xticks().tolist()
            ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)
            
            ax1.set_title("P3="+myeur,fontsize=21)
            #ax1.axvline(x=0, ls='solid', c='gray',alpha=0.3)
            ax1.axvline(x=0, ls='dashed', c='black')
            ax1.axhline(y=28.5, ls='solid', c='black',alpha=0.5)
            ax1.axhline(y=25.5, ls='solid', c='black',alpha=0.5)
            ax1.axhline(y=18.5, ls='solid', c='black',alpha=0.5)
            ax1.axhline(y=1.5, ls='solid', c='black',alpha=0.5)
            ax1.axhline(y=5.5, ls='solid', c='black',alpha=0.5)
            ax1.axhline(y=10.5, ls='solid', c='black',alpha=0.5)

        fig.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.01, hspace=None)
        plt.tight_layout()
        plt.savefig(pD+fh+'.Dfig.'+'.png',bbox_inches='tight')
# Out:
# 5

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches
import plotting_funcs as pf



pD = "/mnt/solexa/mel_yang/neolithic/Dstats/D_WEur/"
outs = ['Mbuti']

aeas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Zongri', 'Chokhopani', 'Mebrak', 'Samdzong',
      'Tianyuan','LiangDao','Longlin','Xinyi',"Vietnam_Pre_Neolithic","Vietnam_Neolithic","Vietnam_BA"]
neas=['Daur','Hezhen','Mongola','Ulchi','Xibo','Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha']
seas=['Japanese','Korean','Han_NChina','Han_Shandong','Han_HGDP','Miao','She','Dai','Li','Maonan',
      'Zhuang','Ami_Stoneking','Atayal_Stoneking','Kinh_Vietnam_KHV','Yi']
myasn="LiangDao"
pdeas=neas+seas+aeas
wantedpops = [i for i in pdeas[::-1] if i not in ["Xinyi","Vietnam_Pre_Neolithic","Vietnam_Neolithic","Vietnam_BA"]] 
wantedpops = [i for i in wantedpops if i not in [myasn]] 
mynames=wantedpops[:]
mynames[mynames.index('Tibetan_Shannan')]='Tib_Shannan'
mynames[mynames.index('Tibetan_Chamdo')]='Tib_Chamdo'
mynames[mynames.index('Tibetan_Gangcha')]='Tib_Gangcha'
#mynames[mynames.index('Vietnam_Neolithic')]='Vietnam_Neo'
#mynames[mynames.index('Vietnam_Pre_Neolithic')]='Vietnam_Pre'
mynames[mynames.index('Ami_Stoneking')]='Ami'
mynames[mynames.index('Atayal_Stoneking')]='Atayal'
mynames[mynames.index('Kinh_Vietnam_KHV')]='Kinh'
mynames[mynames.index('Boisman_MN')]='Boisman'

fh="ind_A_v13_TBH5"
mytwoeurs = [['GoyetQ116-1','Vestonice16','Malta1','Villabruna','Loschbour'],
             ['Karelia_HG','Stuttgart','Satsurblia','French','Sardinian']]
for myeurs in mytwoeurs:
    for out in outs:
        fig = plt.figure(figsize=(22,10))
        colors = ['red','blue','brown','black','orange','purple']
        
        myxmins = [-0.05]*len(myeurs)
        myxmaxs = [0.05]*len(myeurs)
        mylabel = ['A','B','C','D','E']
        if 'Karelia' in myeurs: mylabel = ['F','G','H','I','J']
        mylabellocation = [-0.11]*len(myeurs)

        for mysubplot,myeur in enumerate(myeurs):
            ax1=fig.add_subplot(1,6,mysubplot+1)
            
            #myylabel,mytitle,legendadd = labels[mysubplot]
            myset = "all.ALLEAS_%s_ALLEUR_%s" % (myasn,out)
            mycond = True if 'tp' in myset else False
            myZary,mypops1,mypops2 = pf.mkDZary(pD+fh+".D."+myset+'.Zmat',mycond)
            myDary,mypops1,mypops2 = pf.mkDZary(pD+fh+".D."+myset+'.Dmat',mycond)
            mySEary=myDary/myZary
            goodpops2 = [mypops2.index(i) for i in wantedpops]
            #getsmaller = [5,5,5]

            goodpops1 = mypops1.index(myeur)
            myys = np.array(range(len(goodpops2)))
            tyD = myDary[goodpops2,goodpops1]
            tySE = mySEary[goodpops2,goodpops1]
            ax1.errorbar(tyD,myys,xerr=tySE, color='darkgrey',fmt='o',capthick=0,linewidth=7)
            ax1.errorbar(tyD,myys,xerr=2*tySE, color='darkgrey',fmt='o',capthick=0,linewidth=4)
            ax1.plot(tyD,myys,'o',markersize=10,color=colors[mysubplot])
            
            ax1.set_yticks(myys) #,rotation=45)
            if mysubplot==0:
                ax1.set_yticklabels(mynames,fontsize=17)
                #ax1.set_ylabel("P3",fontsize=20)
                ax1.text(-0.13,16.5,'X',rotation = 0, fontsize=25)
            elif mysubplot == len(myeurs)-1:
                print mysubplot
                ax1.set_yticklabels(['']*len(wantedpops),fontsize=17)
                ax2=ax1.twinx()
                ax2.set_ylim(-1,len(goodpops2)) #,rotation=45)
                ax2.set_yticks( myys )
                ax2.set_yticklabels(['']*len(wantedpops),fontsize=17)
                #ax1.text(0.06,20.5,'Vestonice16',rotation = 270, fontsize=20)
                #ax1.text(0.08,16.5,'X',rotation = 0, fontsize=25)
                ax1.text(-0.38,-6,"D(X,%s;P3,Mbuti)" % myasn,fontsize=25)
            else: 
                ax1.set_yticklabels(['']*len(wantedpops),fontsize=15)
                
                
            ax1.set_ylim(-1,len(goodpops2))
            ax1.set_xlim(myxmins[mysubplot],myxmaxs[mysubplot])
    
            xlabel = ax1.get_xticks().tolist()
            ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)
            
            ax1.set_title("P3="+myeur,fontsize=21)
            #ax1.axvline(x=0, ls='solid', c='gray',alpha=0.3)
            ax1.axvline(x=0, ls='dashed', c='black')
            ax1.axhline(y=28.5, ls='solid', c='black',alpha=0.5)
            ax1.axhline(y=25.5, ls='solid', c='black',alpha=0.5)
            ax1.axhline(y=18.5, ls='solid', c='black',alpha=0.5)
            ax1.axhline(y=1.5, ls='solid', c='black',alpha=0.5)
            ax1.axhline(y=5.5, ls='solid', c='black',alpha=0.5)
            ax1.axhline(y=10.5, ls='solid', c='black',alpha=0.5)

        fig.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.01, hspace=None)
        plt.tight_layout()
        plt.savefig(pD+fh+'.Dfig.'+'.png',bbox_inches='tight')

# %%
print hi

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches
import plotting_funcs as pf

pD = "/mnt/solexa/mel_yang/neolithic/Dstats/D_WEur/"
outs = ['Mbuti']

aeas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Zongri', 'Chokhopani', 'Mebrak', 'Samdzong',
      'LiangDao','Longlin','Xinyi',"Vietnam_Pre_Neolithic","Vietnam_Neolithic","Vietnam_BA"]
neas=['Daur','Hezhen','Mongola','Ulchi','Xibo','Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha']
seas=['Japanese','Korean','Han_NChina','Han_Shandong','Han_HGDP','Miao','She','Dai','Li','Maonan',
      'Zhuang','Ami_Stoneking','Atayal_Stoneking','Kinh_Vietnam_KHV','Yi']

west=['UstIshim',"Kostenki14","Vestonice16","GoyetQ116-1",'Pavlov1','KremsWA3','Ostuni1','HohleFels49',
      "ElMiron","Malta1","Villabruna",'Bichon','Rochedane','Ranchot88',
      "Loschbour",'LaBrana1','Koros_Hungary_EN_HG.SG','Motala_HG','Karelia_HG','LaRochette',
      "Stuttgart","Satsurblia","Kotias","Sardinian","French"]
west=['UstIshim',"Kostenki14","Vestonice16","GoyetQ116-1",'KremsWA3','Ostuni1',
      "ElMiron","Malta1","Villabruna",'Bichon',
      "Loschbour",'LaBrana1','Koros_Hungary_EN_HG.SG','Motala_HG','Karelia_HG',
      "Stuttgart","Satsurblia","Sardinian","French"]
pdeas=neas+seas+aeas

wantedpops = [i for i in west[::-1] if i not in []] 
mynames=wantedpops[:]
mynames[mynames.index('Koros_Hungary_EN_HG.SG')]='KO1'
myasn="Vestonice16"
wantedpops.remove(myasn)
mynames.remove(myasn)
fh="ind_A_v13_TBH5"
mytwoeurs = [['Chokhopani','Zongri','HDYM1','Boisman_MN','Bbdong','Boshan'],
             ['Linzi','Tibetan_Chamdo','Daur','Japanese','Han_NChina','Dai'],
             ['Maonan','Atayal_Stoneking','LiangDao','Longlin','Kinh_Vietnam_KHV','Vietnam_BA']]
for myeurs in mytwoeurs:
    for out in outs:
        fig = plt.figure(figsize=(20,8))
        colors = ['red','blue','brown','black','orange','purple']
        
        myxmins = [-0.05]*len(myeurs)
        myxmaxs = [0.05]*len(myeurs)
        mylabel = ['A','B','C','D','E']
        if 'Karelia' in myeurs: mylabel = ['F','G','H','I','J']
        mylabellocation = [-0.11]*len(myeurs)

        for mysubplot,myeur in enumerate(myeurs):
            ax1=fig.add_subplot(1,6,mysubplot+1)
            
            #myylabel,mytitle,legendadd = labels[mysubplot]
            myset = "all.ALLEUR_ALLEUR_%s_%s" % (myeur,out)
            mycond = True if 'tp' in myset else False
            myZary,mypops1,mypops2 = pf.mkDZary(pD+fh+".D."+myset+'.Zmat',mycond)
            myDary,mypops1,mypops2 = pf.mkDZary(pD+fh+".D."+myset+'.Dmat',mycond)
            mySEary=myDary/myZary
            goodpops2 = [mypops2.index(i) for i in wantedpops]
            #getsmaller = [5,5,5]

            goodpops1 = mypops1.index(myasn)
            myys = np.array(range(len(goodpops2)))
            tyD = myDary[goodpops1,goodpops2]
            tySE = mySEary[goodpops1,goodpops2]
            ax1.errorbar(tyD,myys,xerr=tySE, color='darkgrey',fmt='o',capthick=0,linewidth=7)
            ax1.errorbar(tyD,myys,xerr=2*tySE, color='darkgrey',fmt='o',capthick=0,linewidth=4)
            ax1.plot(tyD,myys,'o',markersize=10,color=colors[mysubplot])
            
            ax1.set_yticks(myys) #,rotation=45)
            if mysubplot==0:
                ax1.set_yticklabels(mynames,fontsize=17)
                #ax1.set_ylabel("P3",fontsize=20)
                ax1.text(-0.13,15.5,'X',rotation = 0, fontsize=25)
                #ax1.text(-0.195,26.5,'East/Southeast Asians',rotation = 90, fontsize=20)
                #ax1.text(-0.2,6.5,'Native',rotation = 90, fontsize=20)
                #ax1.text(-0.19,7.5,'Americans',rotation = 90, fontsize=20)
            elif mysubplot == len(myeurs)-1:
                print mysubplot
                ax1.set_yticklabels(['']*len(wantedpops),fontsize=17)
                ax2=ax1.twinx()
                ax2.set_ylim(-1,len(goodpops2)) #,rotation=45)
                ax2.set_yticks( myys )
                ax2.set_yticklabels(['']*len(wantedpops),fontsize=17)
                #ax1.text(0.06,20.5,'Vestonice16',rotation = 270, fontsize=20)
                #ax1.text(0.08,16.5,'X',rotation = 0, fontsize=25)
                ax1.text(-0.38,-6,"D(%s,X;P3,Mbuti)" % myasn,fontsize=25)
            else: 
                ax1.set_yticklabels(['']*len(wantedpops),fontsize=15)
                
                
            ax1.set_ylim(-1,len(goodpops2))
            ax1.set_xlim(myxmins[mysubplot],myxmaxs[mysubplot])
    
            xlabel = ax1.get_xticks().tolist()
            ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)
            
            ax1.set_title("P3="+myeur,fontsize=20)
            #ax1.axvline(x=0, ls='solid', c='gray',alpha=0.3)
            ax1.axvline(x=0, ls='dashed', c='black')
            #ax1.axhline(y=15.5, ls='solid', c='black',alpha=0.5)
            ax1.axhline(y=16.5, ls='solid', c='black',alpha=0.5)
            ax1.axhline(y=11.5, ls='solid', c='black',alpha=0.5)
            ax1.axhline(y=10.5, ls='solid', c='black',alpha=0.5)
            ax1.axhline(y=1.5, ls='solid', c='black',alpha=0.5)
            ax1.axhline(y=3.5, ls='solid', c='black',alpha=0.5)
            ax1.axhline(y=5.5, ls='solid', c='black',alpha=0.5)

        fig.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.01, hspace=None)
        plt.tight_layout()
        plt.savefig(pD+fh+'.Dfig.'+'.png',bbox_inches='tight')
# Out:
# 5
# 5
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:56: RuntimeWarning: invalid value encountered in divide
# 5

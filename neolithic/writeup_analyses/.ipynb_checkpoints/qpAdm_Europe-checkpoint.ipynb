# %% [markdown]
# ## qpAdm for comparing LiangDao to Europeans
#
# Combinations I want to consider are: (X, S1, S2)
#
# 1. LiangDao; S. Asns+LL+TY, Europeans
# 2. Europeans;

# %%
# %%writefile /mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/qpwave_inLD.py
import projmodules as pm
from multiprocessing import Pool
import itertools

weas=['Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha','Zongri', 'Chokhopani', 'Mebrak', 'Samdzong']
neas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Daur','Hezhen','Mongola','Ulchi','Xibo']
seas=['Japanese','Korean','Han_NChina','Han_Shandong','Han_HGDP','Dai','Li','Maonan','Miao','She',
       'Zhuang','Ami_Stoneking','Atayal_Stoneking','Kinh_Vietnam_KHV']
seas=seas[::-1]
pubanceas=['Longlin', 'LiangDao']

#left=[[i, j, "Longlin"] for i in seas for j in neas if i != j] #neas+weas+seas+["LiangDao"]
left=[["LiangDao",i, "ElMiron"] for i in ["Tianyuan","Longlin"]+seas+neas+weas]
#left=[["ElMiron","Kostenki14", i] for i in ["LiangDao","Tianyuan","Longlin"]+seas+neas+weas]
left+=[["Longlin",i, "ElMiron"] for i in ["Tianyuan","LiangDao"]+seas+neas+weas]

left=[["LiangDao",i, j] for i in ["Tianyuan","Longlin"]+seas for j in ["Vestonice16","Ostuni1","Villabruna","Loschbour"]]
left=[["Boshan",i, j] for i in ["Tianyuan","Longlin"]+seas for j in ["ElMiron","Vestonice16","Ostuni1","Villabruna","Loschbour"]]
left=[["Linzi",i, j] for i in ["Tianyuan","Longlin"]+seas for j in ["ElMiron","Vestonice16"]]

left=[["Daur",i, j] for i in ["Tianyuan","Longlin"]+seas for j in ["ElMiron","Vestonice16"]]
left=[[j,i, "French"] for i in ["Tianyuan","Longlin","LiangDao"]+seas for j in neas+weas+seas if j !=i ]

def dowork(mytup):
    myleft,myleftid=mytup
    outpD="/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/"
    pD="/mnt/solexa/mel_yang/bronzeage/data/"
    fh="ind_A_v13_TBH5"
    
    outs=[["Yoruba","Ju_hoan_North","Dinka","Mbuti"], #0
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge"], #1
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Kostenki14"], #2
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Kostenki14","UstIshim"], #3
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Kostenki14","Vestonice16","UstIshim"], #4
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Papuan","Kostenki14","Vestonice16","UstIshim"], #5
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","UstIshim"], #6
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Kostenki14","Vestonice16","UstIshim"], #7
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Kostenki14","Vestonice16"], #8
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Papuan","Kostenki14","Vestonice16","UstIshim"], #9
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Papuan","Onge"], #10
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Papuan","Onge","UstIshim"], #11
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Papuan","Kostenki14","Vestonice16","UstIshim","Tianyuan"], #12
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Kostenki14","Vestonice16","UstIshim","Tianyuan"], #13
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Papuan","Kostenki14","Vestonice16","UstIshim","Malta1"], #14
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Papuan","Kostenki14","UstIshim"], #15
          ["Yoruba","Ju_hoan_North","Dinka","Mbuti","Onge","Papuan","Oase1","UstIshim"]] #16
          

    for outid,out in enumerate(outs):
        if outid not in [15,16]: continue #[5,7,12,13]: continue
        bck = 'X_%s_S1_%s_S2_%s_out%i' % tuple(myleft+[outid])
        pm.wave_run(myleft, out, pD, fh, bck, outpd=outpD)
        pm.wave_adm_run(myleft, out, pD, fh, bck, outpd=outpD)
myinputs=[(myleft,ind,) for ind,myleft in enumerate(left)] 
print len(myinputs)
mypool = Pool(14)
results = mypool.map(dowork, myinputs)
# Out:
# Overwriting /mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/qpwave_inLD.py

# %% [markdown]
# Expand to more populations:
# 1. Switch Atayal, LL, LD, BS each in turn as target, others as reference - basically all look same as each other? (need 2 pops to explain 4)

# %% [markdown]
# ## Switch so think about NAsn having something extra that is NOT in Longlin/LiangDao/SAsns (bringing SAsns closer to Longlin/LD)

# %% [markdown]
# ## See results for qpWave

# %%
pd="/mnt/solexa/mel_yang/bronzeage/data/"
pd="/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/"
seas=['Japanese','Korean','Han_NChina','Han_Shandong','Han_HGDP','Dai','Li','Maonan','Miao','She',
       'Zhuang','Ami_Stoneking','Atayal_Stoneking','Kinh_Vietnam_KHV']
#seas=['Han_NChina','Han_Shandong','Han_HGDP','Dai','Li','Maonan','Miao','She',
seas=['Zhuang','Ami_Stoneking','Atayal_Stoneking','Kinh_Vietnam_KHV']
myeas=["Longlin","LiangDao","Atayal_Stoneking","Japanese","Daur"]
neas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Daur','Hezhen','Mongola','Ulchi','Xibo']
weas=['Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha','Zongri', 'Chokhopani', 'Mebrak', 'Samdzong']
X="Boshan"
S1="Daur"
S2="ElMiron"

outids=[5,7,12,13]
outid=11

for S1 in seas:
    print '------------%s--------------' % S1
    myfile=open(pd+"ind_A_v13_TBH5.wave.X_%s_S1_%s_S2_%s_out%i.log" % (X,S1,S2,outid),'r')
    for line in myfile:
        if 'f4rank' not in line: continue
        x=line.split()
        print ' '.join([x[ind] for ind in [0,1,6,7]])
# Out:
# ------------Zhuang--------------
# f4rank: 0 tail: 4.17218537e-66
# f4rank: 1 tail: 0.887586119
# f4rank: 2 tail: 1
# ------------Ami_Stoneking--------------
# f4rank: 0 tail: 7.14205176e-66
# f4rank: 1 tail: 0.818965588
# f4rank: 2 tail: 1
# ------------Atayal_Stoneking--------------
# f4rank: 0 tail: 9.69636726e-60
# f4rank: 1 tail: 0.826873795
# f4rank: 2 tail: 1
# ------------Kinh_Vietnam_KHV--------------
# f4rank: 0 tail: 3.83345637e-63
# f4rank: 1 tail: 0.818730038
# f4rank: 2 tail: 1

# %% [markdown]
# ## Bash script
# This is a good script to copy/paste into terminal to grab relevant information from qpAdm.

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/bronzeage/data/"
# pd="/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/"
# X="Linzi"
# S1="Daur"
# S2="ElMiron"
# myeas="Daur Japanese Atayal_Stoneking Longlin LiangDao Tianyuan"
# #myeas="Atayal_Stoneking Japanese Daur"
# neas="HDYM1 Boisman_MN Bbdong Boshan Linzi Daur Hezhen Mongola Ulchi Xibo"
# seas="Han_NChina Han_Shandong Han_HGDP Dai Li Maonan Miao She Zhuang Ami_Stoneking Atayal_Stoneking Kinh_Vietnam_KHV Tianyuan Longlin"
# #seas="Zhuang Ami_Stoneking Atayal_Stoneking Kinh_Vietnam_KHV Tianyuan Longlin"
# ##Japanese Korean
# outid=11
# for S1 in ${seas}; do
#     myf="${pd}ind_A_v13_TBH5.adm.X_${X}_S1_${S1}_S2_${S2}_out${outid}.log" ;
#     echo "";
#     echo "--------"${myf}"--------";
#     myind=$(grep -n "Jackknife mean:" ${myf} | cut -d":" -f1);
#     step=15;   ##3 popns
#     #step=22;   ##4 popns
#     #step=32;    ##5 popns
#     myind2=$(echo $((${myind}+${step})));
#     head -n ${myind2} ${myf} | tail -n16; ##3 popns
#     #head -n ${myind2} ${myf} | tail -n23;  ##4 popns
#     #head -n ${myind2} ${myf} | tail -n33; ##5 popns
#     done
# Out:
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Linzi_S1_Han_NChina_S2_ElMiron_out11.log--------
# Jackknife mean:      0.961895365     0.038104635
#       std. errors:     0.021     0.021
#
# error covariance (* 1000000)
#        443       -443
#       -443        443
#
#
# summ: Linzi    2      0.115309     0.962     0.038   443  -443   443
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     5     8.847        0.115309     0.962     0.038
#            01  1     6    12.332       0.0549609     1.000    -0.000
#            10  1     6   246.123               0     0.000     1.000
# best pat:           00         0.115309              -  -
# best pat:           01        0.0549609  chi(nested):     3.485 p-value for nested model:       0.0619447
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Linzi_S1_Han_Shandong_S2_ElMiron_out11.log--------
# Jackknife mean:      0.941260013     0.058739987
#       std. errors:     0.020     0.020
#
# error covariance (* 1000000)
#        415       -415
#       -415        415
#
#
# summ: Linzi    2      0.443907     0.941     0.059   415  -415   415
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     5     4.775        0.443907     0.941     0.059
#            01  1     6    13.461       0.0362784     1.000    -0.000
#            10  1     6   244.984               0     0.000     1.000
# best pat:           00         0.443907              -  -
# best pat:           01        0.0362784  chi(nested):     8.685 p-value for nested model:      0.00320808
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Linzi_S1_Han_HGDP_S2_ElMiron_out11.log--------
# Jackknife mean:      0.930555729     0.069444271
#       std. errors:     0.019     0.019
#
# error covariance (* 1000000)
#        372       -372
#       -372        372
#
#
# summ: Linzi    2      0.200369     0.931     0.069   372  -372   372
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     5     7.284        0.200369     0.930     0.070
#            01  1     6    21.299      0.00162079     1.000    -0.000
#            10  1     6   246.123               0     0.000     1.000
# best pat:           00         0.200369              -  -
# best pat:           01       0.00162079  chi(nested):    14.015 p-value for nested model:     0.000181332
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Linzi_S1_Dai_S2_ElMiron_out11.log--------
# Jackknife mean:      0.912599778     0.087400222
#       std. errors:     0.021     0.021
#
# error covariance (* 1000000)
#        441       -441
#       -441        441
#
#
# summ: Linzi    2      0.403100     0.913     0.087   441  -441   441
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     5     5.106          0.4031     0.912     0.088
#            01  1     6    23.572      0.00062595     1.000    -0.000
#            10  1     6   246.123               0     0.000     1.000
# best pat:           00           0.4031              -  -
# best pat:           01       0.00062595  chi(nested):    18.466 p-value for nested model:     1.72971e-05
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Linzi_S1_Li_S2_ElMiron_out11.log--------
# Jackknife mean:      0.933441886     0.066558114
#       std. errors:     0.024     0.024
#
# error covariance (* 1000000)
#        559       -559
#       -559        559
#
#
# summ: Linzi    2      0.143095     0.933     0.067   559  -559   559
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     5     8.248        0.143095     0.933     0.067
#            01  1     6    16.649       0.0106637     1.000    -0.000
#            10  1     6   244.984               0     0.000     1.000
# best pat:           00         0.143095              -  -
# best pat:           01        0.0106637  chi(nested):     8.401 p-value for nested model:       0.0037499
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Linzi_S1_Maonan_S2_ElMiron_out11.log--------
# Jackknife mean:      0.918438456     0.081561544
#       std. errors:     0.021     0.021
#
# error covariance (* 1000000)
#        438       -438
#       -438        438
#
#
# summ: Linzi    2      0.237616     0.918     0.082   438  -438   438
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     5     6.779        0.237616     0.918     0.082
#            01  1     6    23.028     0.000787216     1.000    -0.000
#            10  1     6   244.984               0     0.000     1.000
# best pat:           00         0.237616              -  -
# best pat:           01      0.000787216  chi(nested):    16.249 p-value for nested model:     5.55393e-05
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Linzi_S1_Miao_S2_ElMiron_out11.log--------
# Jackknife mean:      0.931563177     0.068436823
#       std. errors:     0.021     0.021
#
# error covariance (* 1000000)
#        441       -441
#       -441        441
#
#
# summ: Linzi    2      0.084682     0.932     0.068   441  -441   441
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     5     9.685       0.0846823     0.931     0.069
#            01  1     6    20.987      0.00184461     1.000    -0.000
#            10  1     6   246.123               0     0.000     1.000
# best pat:           00        0.0846823              -  -
# best pat:           01       0.00184461  chi(nested):    11.302 p-value for nested model:     0.000774114
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Linzi_S1_She_S2_ElMiron_out11.log--------
# Jackknife mean:      0.938488081     0.061511919
#       std. errors:     0.021     0.021
#
# error covariance (* 1000000)
#        456       -456
#       -456        456
#
#
# summ: Linzi    2      0.253521     0.938     0.062   456  -456   456
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     5     6.583        0.253521     0.938     0.062
#            01  1     6    15.239       0.0184741     1.000    -0.000
#            10  1     6   246.123               0     0.000     1.000
# best pat:           00         0.253521              -  -
# best pat:           01        0.0184741  chi(nested):     8.656 p-value for nested model:      0.00325963
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Linzi_S1_Zhuang_S2_ElMiron_out11.log--------
# Jackknife mean:      0.916749722     0.083250278
#       std. errors:     0.020     0.020
#
# error covariance (* 1000000)
#        418       -418
#       -418        418
#
#
# summ: Linzi    2      0.386826     0.917     0.083   418  -418   418
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     5     5.244        0.386826     0.916     0.084
#            01  1     6    23.185     0.000736806     1.000    -0.000
#            10  1     6   244.984               0     0.000     1.000
# best pat:           00         0.386826              -  -
# best pat:           01      0.000736806  chi(nested):    17.941 p-value for nested model:     2.27859e-05
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Linzi_S1_Ami_Stoneking_S2_ElMiron_out11.log--------
# Jackknife mean:      0.927109503     0.072890497
#       std. errors:     0.022     0.022
#
# error covariance (* 1000000)
#        480       -480
#       -480        480
#
#
# summ: Linzi    2      0.318896     0.927     0.073   480  -480   480
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     5     5.872        0.318896     0.927     0.073
#            01  1     6    17.709      0.00700325     1.000    -0.000
#            10  1     6   246.123               0     0.000     1.000
# best pat:           00         0.318896              -  -
# best pat:           01       0.00700325  chi(nested):    11.837 p-value for nested model:     0.000580712
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Linzi_S1_Atayal_Stoneking_S2_ElMiron_out11.log--------
# Jackknife mean:      0.909948688     0.090051312
#       std. errors:     0.025     0.025
#
# error covariance (* 1000000)
#        604       -604
#       -604        604
#
#
# summ: Linzi    2      0.111326     0.910     0.090   604  -604   604
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     5     8.944        0.111326     0.910     0.090
#            01  1     6    22.797     0.000867507     1.000    -0.000
#            10  1     6   246.123               0     0.000     1.000
# best pat:           00         0.111326              -  -
# best pat:           01      0.000867507  chi(nested):    13.853 p-value for nested model:     0.000197693
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Linzi_S1_Kinh_Vietnam_KHV_S2_ElMiron_out11.log--------
# Jackknife mean:      0.930024971     0.069975029
#       std. errors:     0.022     0.022
#
# error covariance (* 1000000)
#        465       -465
#       -465        465
#
#
# summ: Linzi    2      0.338435     0.930     0.070   465  -465   465
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     5     5.682        0.338435     0.930     0.070
#            01  1     6    16.798       0.0100565     1.000    -0.000
#            10  1     6   246.123               0     0.000     1.000
# best pat:           00         0.338435              -  -
# best pat:           01        0.0100565  chi(nested):    11.116 p-value for nested model:     0.000855884
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Linzi_S1_Tianyuan_S2_ElMiron_out11.log--------
# Jackknife mean:      1.213763772    -0.213763772
#       std. errors:     0.075     0.075
#
# error covariance (* 1000000)
#       5639      -5639
#      -5639       5639
#
#
# summ: Linzi    2      0.013287     1.214    -0.214  5639 -5639  5639
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     5    14.395       0.0132874     1.219    -0.219  infeasible
#            01  1     6    27.392     0.000122266     1.000    -0.000
#            10  1     6   242.574               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01      0.000122266  chi(nested):    12.997 p-value for nested model:     0.000311964
#
# --------/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/ind_A_v13_TBH5.adm.X_Linzi_S1_Longlin_S2_ElMiron_out11.log--------
# Jackknife mean:      1.063963365    -0.063963365
#       std. errors:     0.085     0.085
#
# error covariance (* 1000000)
#       7218      -7218
#      -7218       7218
#
#
# summ: Linzi    2      0.474582     1.064    -0.064  7218 -7218  7218
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     5     4.540        0.474582     1.069    -0.069  infeasible
#            01  1     6     5.329        0.502383     1.000    -0.000
#            10  1     6   117.465     5.55026e-23     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01         0.502383  chi(nested):     0.789 p-value for nested model:        0.374384

# %%
seas=['Japanese','Korean','Han_NChina','Han_Shandong','Han_HGDP','Dai','Li','Maonan','Miao','She',
       'Zhuang','Ami_Stoneking','Atayal_Stoneking','Kinh_Vietnam_KHV']
neas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Daur','Hezhen','Mongola','Ulchi','Xibo']
print ', '.join(neas)

# %% [markdown]
# ## Make table of qpAdm results

# %%
import projmodules as pm

seas=['Japanese','Korean','Han_NChina','Han_Shandong','Han_HGDP','Dai','Li','Maonan','Miao','She',
       'Zhuang','Ami_Stoneking','Atayal_Stoneking','Kinh_Vietnam_KHV']
myeas=["Longlin","LiangDao","Atayal_Stoneking","Japanese","Daur"]
neas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Daur','Hezhen','Mongola','Ulchi','Xibo']
weas=['Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha','Zongri', 'Chokhopani', 'Mebrak', 'Samdzong']

ty=["Tianyuan"]
ll=["Longlin"]
namer=["Mixe"]
#pD="/mnt/solexa/mel_yang/bronzeage/data/"
pD="/mnt/solexa/mel_yang/neolithic/qpwaveadm/"
fh="ind_A_v13_TBH5"

outs = [5]
comboswanted = ['00','10']
header = 'S1\tS2\tTarget\trank1\t%s_p\t%s_f1\t%s_f2\t%s_pnest\t%s_p\t%s_f1\t%s_f2\t%s_pnest\tse\n' % tuple(comboswanted[0:1]*4+comboswanted[1:2]*4)
rankswanted = ['1']
for outnum in outs:
    alldata = ""
    for ind1, i1 in enumerate(myeas):
        for ind2,i2 in enumerate(["Chukchi"]):
            for ind3,i3 in enumerate(neas+weas+seas):
                if i1==i2 or i2==i3 or i1==i3: continue
                s1,s2,target = (i1,i2,i3)
                #s1,s2,target = (i1,i2,i3)
                subset = 'X_%s_S1_%s_S2_%s_out%i' % (target,s1,s2,outnum)
                myinfo = pm.wave_extractAdmdata(pD,fh,subset,(s1,s2),target)
                if myinfo == 'NOFILE': continue              
                ranksprint = '\t'.join([str(myinfo['f4rank'][i]) for i in rankswanted])
                pvalsprint = '\t'.join(['%s\t%s\t%s\t%s' % tuple(myinfo['admix'][i]+myinfo['nestp'][i]) if i in myinfo['nestp'] else '%s\t%s\t%s\tNA' % tuple(myinfo['admix'][i]) for i in comboswanted])
                allprint = ranksprint+'\t'+pvalsprint+'\t'+myinfo['se'][-1]
                
                alldata+='\t'.join([s1,s2,target])+'\t'+allprint+'\n'
    #newname = 'adm_inSEASoutNWEASoutLL_out' + str(outnum)
    #newname = 'adm_inSEASoutNEASoutLD_out' + str(outnum)
    #newname = 'adm_inLLoutNEASoutLD_out' + str(outnum)
    #newname = 'adm_inLLoutWNSCEASoutTY_out' + str(outnum)
    #newname = 'adm_inLLoutSCEASoutDaur_out' + str(outnum)
    #newname = 'adm_inNSCEASoutNSCEASoutMixe_out' + str(outnum)
    #newname = 'adm_inLLoutSEASoutWNEAS_out' + str(outnum)
    newname = 'adm_inWNEASoutSEASoutSurui_out' + str(outnum)
    #newname = 'adm_inNCSEASoutLLoutLos_out' + str(outnum)
    newname = 'adm_inWNEASoutSEASoutLos_out' + str(outnum)
    newname = 'adm_inWNEASoutSEASoutChukchi_out' + str(outnum)
    
    newfile = open(pD+fh+'.'+newname+'.tab','w')
    newfile.writelines(header+alldata)
    newfile.close()

# %%
import projmodules as pm

seas=['Japanese','Korean','Han_NChina','Han_Shandong','Han_HGDP','Dai','Li','Maonan','Miao','She',
       'Zhuang','Ami_Stoneking','Atayal_Stoneking','Kinh_Vietnam_KHV']
myeas=["Longlin","LiangDao","Atayal_Stoneking","Japanese","Daur"]
neas=['HDYM1','Boisman_MN','Bbdong','Boshan','Linzi','Daur','Hezhen','Mongola','Ulchi','Xibo']
weas=['Tibetan_Shannan','Tibetan_Chamdo','Tibetan_Gangcha','Zongri', 'Chokhopani', 'Mebrak', 'Samdzong']
anceur=["Vestonice16","Ostuni1","Villabruna","Loschbour"] #"ElMiron",
ty=["Tianyuan"]
ll=["Longlin"]
namer=["Mixe"]
#pD="/mnt/solexa/mel_yang/bronzeage/data/"
pD="/mnt/solexa/mel_yang/neolithic/qpwaveadm/liangdao/"
fh="ind_A_v13_TBH5"

outs = [15,16]
comboswanted = ['00','01']
header = 'S1\tS2\tTarget\trank1\t%s_p\t%s_f1\t%s_f2\t%s_pnest\t%s_p\t%s_f1\t%s_f2\t%s_pnest\tse\n' % tuple(comboswanted[0:1]*4+comboswanted[1:2]*4)
rankswanted = ['1']
for outnum in outs:
    alldata = ""
    for ind1, i1 in enumerate(["Tianyuan","Longlin"]+seas):
        for ind2,i2 in enumerate(anceur):
            for ind3,i3 in enumerate(["LiangDao"]):
                if i1==i2 or i2==i3 or i1==i3: continue
                s1,s2,target = (i1,i2,i3)
                #s1,s2,target = (i1,i2,i3)
                subset = 'X_%s_S1_%s_S2_%s_out%i' % (target,s1,s2,outnum)
                myinfo = pm.wave_extractAdmdata(pD,fh,subset,(s1,s2),target)
                if myinfo == 'NOFILE': continue              
                ranksprint = '\t'.join([str(myinfo['f4rank'][i]) for i in rankswanted])
                pvalsprint = '\t'.join(['%s\t%s\t%s\t%s' % tuple(myinfo['admix'][i]+myinfo['nestp'][i]) if i in myinfo['nestp'] else '%s\t%s\t%s\tNA' % tuple(myinfo['admix'][i]) for i in comboswanted])
                allprint = ranksprint+'\t'+pvalsprint+'\t'+myinfo['se'][-1]
                
                alldata+='\t'.join([s1,s2,target])+'\t'+allprint+'\n'
    #newname = 'adm_inLDoutNWCSEASoutElM_out' + str(outnum)
    #newname = 'adm_inLLoutNWCSEASoutElM_out' + str(outnum)
    newname = 'adm_inLZoutSEASoutEUR_out' + str(outnum)
    newname = 'adm_inBSoutSEASoutEUR_out' + str(outnum)
    newname = 'adm_inLDoutSEASoutEUR_out' + str(outnum)
    
    newfile = open(pD+fh+'.'+newname+'.tab','w')
    newfile.writelines(header+alldata)
    newfile.close()

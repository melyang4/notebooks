# %% [markdown]
# ## Make excel

# %%
import numpy as np
import plateaumodules as pm

pD="/mnt/solexa/mel_yang/aPlateau/"
fh="aPlateau.dstat.log"

agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
#agq=["Zongri1a","Zongri23","Shangluzhuang","Heodong"]
popA=agq
popB=agq
thirdpops=["Han","Ami","Atayal","Daur","Naxi","Yi","Tibetan","Korean",
           "Japanese","Hezhen","Dai"]
thirdpops=["Sherpa"]
for myind in thirdpops:
    #myind="Shangluzhuang"
    #myind="Hejiatai"
    out="Mbuti"
    mypops1=[popA,myind,popB,out]
    mypops2=[popA,popB,myind,out]
    DorZ="Z"

    newfh1=fh.split(".")[0]+"."+DorZ+"."+"aGQ_%s_aGQ_%s" % (myind,out)
    newfh2=fh.split(".")[0]+"."+DorZ+"."+"aGQ_aGQ_%s_%s" % (myind,out)
    Zary = pm.mkDary(pD,fh,mypops1,(1,3),(0,2),DorZ)    
    print pm.Zmat2xlsx(Zary,pD+newfh1,popA,popB,0,2)

    Zary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),DorZ)    
    print pm.Zmat2xlsx(Zary,pD+newfh2,popA,popB,0,1)
# Out:
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Sherpa_aGQ_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_aGQ_Sherpa_Mbuti!

# %%
import numpy as np
import plateaumodules as pm

pD="/mnt/solexa/mel_yang/aPlateau/"
fh="aPlateau.dstat.log"

agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
#agq=["Zongri1a","Zongri23","Shangluzhuang","Heodong"]
eas=["Ulchi","Oroqen","Daur","Hezhen","Xibo","Tu","Japanese","Korean",
    "Han","Tujia","She","Miao","Ami","Atayal","Dai","Kinh","Lahu",
     "Naxi","Yi","Tibetan","Sherpa"]
popA=agq
popB=eas
thirdpops=agq
for myind in thirdpops:
    #myind="Shangluzhuang"
    #myind="Hejiatai"
    out="Mbuti"
    mypops1=[popA,myind,popB,out]
    #mypops2=[popA,popB,myind,out]
    DorZ="Z"

    newfh1=fh.split(".")[0]+"."+DorZ+"."+"aGQ_%s_EAS_%s" % (myind,out)
    #newfh2=fh.split(".")[0]+"."+DorZ+"."+"aGQ_aGQ_%s_%s" % (myind,out)
    Zary = np.transpose(pm.mkDary(pD,fh,mypops1,(1,3),(0,2),DorZ))
    print pm.Zmat2xlsx(Zary,pD+newfh1,popB,popA,2,0)

    #Zary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),DorZ)    
    #print pm.Zmat2xlsx(Zary,pD+newfh2,popA,popB,0,1)
# Out:
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Zongri1a_EAS_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Zongri23_EAS_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Shangluzhuang_EAS_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Hejiatai_EAS_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Heodong_EAS_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Daxiang_EAS_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Xiahaishi_EAS_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Hupo_EAS_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Sanheyi_EAS_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Qunke_EAS_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Lajigai_EAS_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Wenpuju_EAS_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Jinchankou_EAS_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Qijiaping_EAS_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Wuba_EAS_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Huoshaogou_EAS_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Lierbao_EAS_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Shannashuzha_EAS_Mbuti!

# %%
pm.Zmat2xlsx??

# %% [markdown]
# ## Make figure

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
pD="/mnt/solexa/mel_yang/aPlateau/"
fh="aPlateau.dstat.log"
tv='all'

agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",][::-1]
wantedcolors=["blue"]*len(agq)
myxmin=[-0.08]*2
myxmax=[0.05]*2
mysubplot=0
fig = plt.figure(figsize=(10,5))

popA=agq
popB=["Jinchankou"]
varypop=["Tianyuan",'Vestonice16']
myind="Han"
outs=["Mbuti","Chimp"]
for count,out in enumerate(outs):
    #myind="Shangluzhuang"
    #myind="Hejiatai"
    
    mypops1=[popA,myind,popB,out]
    mypops2=[popA,popB,myind,out]
    DorZ="Z"

    Zary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),'Z')
    Dary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),'D')
    mylabel="D(%s,%s;%s,%s)" % ('aGQ',popB[0],myind,out)

    SEary=Dary/Zary 
    mynames=agq
    
    ax1=fig.add_subplot(1,len(varypop),count+1)
    for ind,i in enumerate(agq):
        #print tyD[i]
        #print Dary[ind][0]
        ax1.errorbar(Dary[ind][0],ind,xerr=SEary[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Dary[ind][0],ind,xerr=3*SEary[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Dary[ind],ind,'.')
    #ax1.set_yticks(len(mynames))
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    if count==0:
        ax1.set_yticklabels(mynames,fontsize=16)
    else: 
        ax1.set_yticklabels([' ']*len(mynames),fontsize=3)

    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[count],myxmax[count])

    xlabel = ax1.get_xticks().tolist()
    ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)

    ax1.set_title(mylabel,fontsize=15)

    ax1.axvline(x=0, ls='dashed', c='black')
    for myline in [3.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)

    ax1.set_xlabel("D, %s" % tv,fontsize=15)
    
plt.tight_layout()
plt.show()

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib


#agq=["Zongri1a","Zongri23",
agq=["Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",][::-1]
wantedcolors=["blue"]*len(agq)
myxmin=[-0.08]*2
myxmax=[0.05]*2
mysubplot=0
fig = plt.figure(figsize=(10,5))

popA=agq
popB=["Zongri1a"]
varypop=["Tianyuan",'Vestonice16']
myind="Zongri23"
outs=["Mbuti","Chimp"]
out="Mbuti"
mypops2s=[[popA,popB,myind,out],[popA,myind,popB,out]]
mylabels=["D(%s,%s;%s,%s)" % ('aGQ',popB[0],myind,out),"D(%s,%s;%s,%s)" % ('aGQ',myind,popB[0],out)]
mytuples=[[(2,3),(0,1)],[(1,3),(0,2)]]
for count,mypops2 in enumerate(mypops2s):
    #print mypops2
    pD="/mnt/solexa/mel_yang/aPlateau/"
    fhall="aPlateau.dstat.log"
    fhtv="aPlateau.tv.dstat.log"
    #tv='all'
    #mypops2=[popA,popB,myind,out]
    Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[count][0],mytuples[count][1],'Z')
    Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[count][0],mytuples[count][1],'D')
    SEaryall=Daryall/Zaryall 
    Zarytv = pm.mkDary(pD,fhtv,mypops2,mytuples[count][0],mytuples[count][1],'Z')
    Darytv = pm.mkDary(pD,fhtv,mypops2,mytuples[count][0],mytuples[count][1],'D')
    SEarytv=Darytv/Zarytv
    
    mylabel=mylabels[count]
    mynames=agq
    
    ax1=fig.add_subplot(1,len(varypop),count+1)
    for ind,i in enumerate(agq):
        #print tyD[i]
        #print Dary[ind][0]
        ax1.errorbar(Darytv[ind][0],ind,xerr=SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[ind][0],ind,xerr=2*SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[ind],ind,'.',alpha=0.05)

        ax1.errorbar(Daryall[ind][0],ind,xerr=SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[ind][0],ind,xerr=2*SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[ind],ind,'.')
        
    #ax1.set_yticks(len(mynames))
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    if count==0:
        ax1.set_yticklabels(mynames,fontsize=16)
    else: 
        ax1.set_yticklabels([' ']*len(mynames),fontsize=3)

    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[count],myxmax[count])

    xlabel = ax1.get_xticks().tolist()
    ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)

    ax1.set_title(mylabel,fontsize=15)

    ax1.axvline(x=0, ls='dashed', c='black')
    #for myline in [9.5]:
    #    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)
    ax1.set_xlabel("D",fontsize=15)
    #ax1.set_xlabel("D, %s" % tv,fontsize=15)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot D(DX Cl, aGQ; DX Cl, Mbuti)

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches
import matplotlib.lines as mlines

pD="/mnt/solexa/mel_yang/aPlateau/"
fhall="aPlateau.tv.dstat.log"

notdx=["Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping","Wuba","Huoshaogou","Lierbao",]
SNSZ=["Shannashuzha"]
SLZ=["Shangluzhuang"]
HP_SHY=["Hupo","Sanheyi"]
ZR=["Zongri1a","Zongri23"]
varypops=[ZR, SLZ, dxcluster, HP_SHY, notdx, SNSZ]
labels=["Zongri","Shangluzhuang","Daxiang Cluster","Hupo/Sanheyi","Younger aGQ", "Shannashuzha"]
dxcluster=["Hejiatai","Heodong","Daxiang","Xiahaishi"]
dxpairs=[(i,j) for indi,i in enumerate(dxcluster) for indj,j in enumerate(dxcluster) if indi<indj]
pairlabels=["%s_%s" % mypair for mypair in dxpairs]
print pairlabels
out="Mbuti"
colors=["blue","brown","red","black","pink","gray","purple"]
markers=["o","v","s","+","D",">"]
print dxpairs

fig = plt.figure(figsize=(9,9))
ax1=fig.add_subplot(1,1,1)
handles1,handles2=[],[]
for ind,mypair in enumerate(dxpairs):
    #ax1.set_title("D(X1, aGQ; X2, Mbuti)")
    ax1.set_ylim((-4,10))
    ax1.set_xlim((-4,10))
    ax1.set_ylabel("Z for D(X2, aGQ; X1, %s)" % out,fontsize=15)
    ax1.set_xlabel("Z for D(X1, aGQ; X2, %s)" % out,fontsize=15)
    ax1.axvline(x=0, ls='dashed', c='black')
    ax1.axhline(y=0, ls='dashed', c='black')
    ax1.axvline(x=2, ls='dashed', c='lightgray')
    ax1.axhline(y=2, ls='dashed', c='lightgray')
    ax1.axvline(x=-2, ls='dashed', c='lightgray')
    ax1.axhline(y=-2, ls='dashed', c='lightgray')
    for ivp,varypop in enumerate(varypops):
        mypops1=[mypair[0],varypop,[mypair[1]],out]
        mypops2=[mypair[1],varypop,[mypair[0]],out]
        Zary1 = pm.mkDary(pD,fhall,mypops1,(0,3),(1,2),'Z')
        Zary2 = pm.mkDary(pD,fhall,mypops2,(0,3),(1,2),'Z')
        Zary=np.transpose(np.vstack((Zary1, Zary2)))[0,:]
        ax1.plot(Zary1,Zary2,markers[ind],color=colors[ivp])
        if ivp==0:
            handles1.append(mlines.Line2D([],[],marker=markers[ind],color='black',label=pairlabels[ind]))
        if ind==0:
            handles2.append(mpatches.Patch(color=colors[ivp], label=labels[ivp]))
        else: pass
#ax1.legend(loc='lower right')
#ax1.legend(handles=handles1+handles2,loc=4,ncol=2,fontsize=12.5)
#ax1.legend(handles=handles1,loc=3)
plt.show()
# Out:
# ['Hejiatai_Heodong', 'Hejiatai_Daxiang', 'Hejiatai_Xiahaishi', 'Heodong_Daxiang', 'Heodong_Xiahaishi', 'Daxiang_Xiahaishi']
# [('Hejiatai', 'Heodong'), ('Hejiatai', 'Daxiang'), ('Hejiatai', 'Xiahaishi'), ('Heodong', 'Daxiang'), ('Heodong', 'Xiahaishi'), ('Daxiang', 'Xiahaishi')]

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
#import matplotlib
import matplotlib.patches as mpatches

pD="/mnt/solexa/mel_yang/aPlateau/"
tv=".tv"
tv=""
fhall="aPlateau%s.dstat.log" % tv

agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]

#eur=["French","Sardinian","Finnish"]
weas=["Sherpa","Tibetan","Naxi","Yi"]
eas=["Han","Dai","Ami","Daur"]
aeur=["Kostenki14","Vestonice16","GoyetQ116-1","ElMiron","Villabruna","Loschbour","LaBrana1","Hungarian.KO1"]
ane=["Malta1"]
ancother=["UstIshim"]
othereas=["Tianyuan"] #,"Papuan","Onge","Oase1"
varypops=[weas,eas, othereas,ancother, aeur, ane]
labels=["WEAS","N/C/SEAS","Tianyuan","Ust'-Ishim","aEUR","Mal'ta1"] #/Papuan/Onge/Oase1
dxcluster=agq
dxpairs=[(i,j) for indi,i in enumerate(dxcluster) for indj,j in enumerate(dxcluster) if indi<indj]
pairlabels=["%s_%s" % mypair for mypair in dxpairs]
#print pairlabels
out="Mbuti"
colors=["blue","brown","red","black","pink","gray","purple"]
markers=["o","v","s","+","D",">"]
print len(dxpairs)

fig = plt.figure(figsize=(9,9))
ax1=fig.add_subplot(1,1,1)
handles1,handles2=[],[]
for ind,mypair in enumerate(dxpairs):
    #ax1.set_title("D(X1, aGQ; X2, Mbuti)")
    #ax1.set_ylim((-4,10))
    #ax1.set_xlim((-4,10))
    ax1.set_ylabel("Z for D(X2, aGQ; X1, %s)" % out,fontsize=15)
    ax1.set_xlabel("Z for D(X1, aGQ; X2, %s)" % out,fontsize=15)
    ax1.axvline(x=0, ls='dashed', c='black')
    ax1.axhline(y=0, ls='dashed', c='black')
    ax1.axvline(x=2, ls='dashed', c='lightgray')
    ax1.axhline(y=2, ls='dashed', c='lightgray')
    ax1.axvline(x=-2, ls='dashed', c='lightgray')
    ax1.axhline(y=-2, ls='dashed', c='lightgray')
    for ivp,varypop in enumerate(varypops):
        mypops1=[mypair[0],varypop,[mypair[1]],out]
        mypops2=[mypair[1],varypop,[mypair[0]],out]
        Zary1 = pm.mkDary(pD,fhall,mypops1,(0,3),(1,2),'Z')
        Zary2 = pm.mkDary(pD,fhall,mypops2,(0,3),(1,2),'Z')
        Zary=np.transpose(np.vstack((Zary1, Zary2)))[0,:]
        ax1.plot(Zary1,Zary2,'o',color=colors[ivp]) #markers[ind],
        #if ivp==0:
        #    handles1.append(mlines.Line2D([],[],marker=markers[ind],color='black',label=pairlabels[ind]))
        if ind==0:
            handles2.append(mpatches.Patch(color=colors[ivp], label=labels[ivp]))
        else: pass
#ax1.legend(loc='lower right')
#ax1.legend(handles=handles1+handles2,loc=4,ncol=2,fontsize=12.5)
ax1.legend(handles=handles2,loc=0)
#plt.show()

#fig.savefig(pD+'agqclade.D%s.relEUR.png' % tv) # save the figure to file
#plt.close(fig)
# Out:
# 1

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
from itertools import chain

pD="/mnt/solexa/mel_yang/aPlateau/"
fhall="aPlateau.dstat.log"


older=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi","Hupo","Sanheyi"]
middle=["Qunke","Lajigai","Wenpuju"]
northern=["Wuba","Huoshaogou"]
southern=["Jinchankou","Qijiaping","Shannashuzha"]
allagq={"older":older,"middle":middle,"northern":northern,"southern":southern}
allagq={"older":older,"younger":middle+southern}
allpops=older+middle+northern+southern
out="Mbuti"

colors=["blue","brown","red","black","pink","gray","purple"]
markers=["o","v","s","+","D",">"]

fig = plt.figure(figsize=(9,9))
ax1=fig.add_subplot(1,1,1)
handles1,handles2=[],[]
ax1.set_ylim((-5,10))
ax1.set_xlim((-5,10))
ax1.set_ylabel("Z for D(X2, Lierbao; X1, %s)" % out,fontsize=15)
ax1.set_xlabel("Z for D(X1, Lierbao; X2, %s)" % out,fontsize=15)
ax1.axvline(x=0, ls='dashed', c='black')
ax1.axhline(y=0, ls='dashed', c='black')
ax1.axvline(x=2, ls='dashed', c='lightgray')
ax1.axhline(y=2, ls='dashed', c='lightgray')
ax1.axvline(x=-2, ls='dashed', c='lightgray')
ax1.axhline(y=-2, ls='dashed', c='lightgray')

count=0
for ind1,group1 in enumerate(allagq):
    color=colors[ind1]
    for ind2,group2 in enumerate(allagq):
        if group1==group2: continue
        marker=markers[ind2]
        #print group1+"_"+group2
        
        mypops1=[allagq[group1],"Lierbao",allagq[group2],out]
        mypops2=[allagq[group2],"Lierbao",allagq[group1],out]
        Zary1 = pm.mkDary(pD,fhall,mypops1,(1,3),(0,2),'Z')
        Zary2 = pm.mkDary(pD,fhall,mypops2,(1,3),(0,2),'Z')
        Zary1=list(chain.from_iterable(Zary1))
        Zary2=list(chain.from_iterable(Zary2))
        print group1+"_"+group2, Zary1, Zary2
        ax1.plot(Zary1,Zary2,marker,color=color)
        handles1.append(mlines.Line2D([],[],marker=marker,color=color,label=group1+"_"+group2))
        count+=1
ax1.legend(handles=handles1,loc=3,ncol=4)
plt.show()
# Out:
# younger_older [4.0780000000000003, 5.2569999999999997, 1.222, 1.796, 3.1179999999999999, 0.97899999999999998, 3.3149999999999999, 2.8279999999999998, 3.4369999999999998, 4.0940000000000003, 3.7869999999999999, 2.3679999999999999, 4.4109999999999996, 3.6970000000000001, 0.70899999999999996, 2.3580000000000001, 2.879, 2.4420000000000002, 2.7410000000000001, 3.363, 0.95499999999999996, 1.988, 3.008, 1.8129999999999999, 2.036, 2.1669999999999998, 3.0750000000000002, 1.744, 5.2590000000000003, 2.843, 3.6160000000000001, 3.2799999999999998, 0.086999999999999994, 2.831, 4.5650000000000004, 3.0030000000000001, 2.2949999999999999, 4.3230000000000004, 0.90600000000000003, 2.8450000000000002, 3.2429999999999999, 0.36699999999999999, 2.593, 3.4169999999999998, 2.9209999999999998, 1.629, 2.8170000000000002, 1.1559999999999999, 2.9820000000000002, 1.2629999999999999, 1.466, 0.59799999999999998, 4.2549999999999999, 2.0139999999999998] [1.9730000000000001, 2.238, -0.012999999999999999, -0.85999999999999999, -2.4809999999999999, -0.32600000000000001, 2.3220000000000001, 0.92200000000000004, 0.114, 0.91400000000000003, -1.744, 1.0580000000000001, 1.6299999999999999, 1.371, -0.81799999999999995, -0.11, -1.74, -0.48299999999999998, 0.56899999999999995, 2.1230000000000002, -0.20200000000000001, 0.31900000000000001, -1.323, 0.80400000000000005, 2.6499999999999999, 2.0840000000000001, 1.0329999999999999, 1.5229999999999999, -0.29199999999999998, 0.112, 1.903, 1.95, 1.085, 0.72499999999999998, -0.97099999999999997, 1.6850000000000001, 2.222, 2.4750000000000001, 1.766, 2.036, 0.74299999999999999, 0.65900000000000003, 2.0640000000000001, 2.633, 0.71199999999999997, 3.5379999999999998, 0.34200000000000003, 2.2749999999999999, 2.008, 0.69599999999999995, 1.4670000000000001, 0.73899999999999999, -0.90500000000000003, 0.35699999999999998]
# older_younger [1.9730000000000001, 2.238, -0.012999999999999999, -0.85999999999999999, -2.4809999999999999, -0.32600000000000001, 2.3220000000000001, 0.92200000000000004, 0.114, 0.91400000000000003, -1.744, 1.0580000000000001, 1.6299999999999999, 1.371, -0.81799999999999995, -0.11, -1.74, -0.48299999999999998, 0.56899999999999995, 2.1230000000000002, -0.20200000000000001, 0.31900000000000001, -1.323, 0.80400000000000005, 2.6499999999999999, 2.0840000000000001, 1.0329999999999999, 1.5229999999999999, -0.29199999999999998, 0.112, 1.903, 1.95, 1.085, 0.72499999999999998, -0.97099999999999997, 1.6850000000000001, 2.222, 2.4750000000000001, 1.766, 2.036, 0.74299999999999999, 0.65900000000000003, 2.0640000000000001, 2.633, 0.71199999999999997, 3.5379999999999998, 0.34200000000000003, 2.2749999999999999, 2.008, 0.69599999999999995, 1.4670000000000001, 0.73899999999999999, -0.90500000000000003, 0.35699999999999998] [4.0780000000000003, 5.2569999999999997, 1.222, 1.796, 3.1179999999999999, 0.97899999999999998, 3.3149999999999999, 2.8279999999999998, 3.4369999999999998, 4.0940000000000003, 3.7869999999999999, 2.3679999999999999, 4.4109999999999996, 3.6970000000000001, 0.70899999999999996, 2.3580000000000001, 2.879, 2.4420000000000002, 2.7410000000000001, 3.363, 0.95499999999999996, 1.988, 3.008, 1.8129999999999999, 2.036, 2.1669999999999998, 3.0750000000000002, 1.744, 5.2590000000000003, 2.843, 3.6160000000000001, 3.2799999999999998, 0.086999999999999994, 2.831, 4.5650000000000004, 3.0030000000000001, 2.2949999999999999, 4.3230000000000004, 0.90600000000000003, 2.8450000000000002, 3.2429999999999999, 0.36699999999999999, 2.593, 3.4169999999999998, 2.9209999999999998, 1.629, 2.8170000000000002, 1.1559999999999999, 2.9820000000000002, 1.2629999999999999, 1.466, 0.59799999999999998, 4.2549999999999999, 2.0139999999999998]

# %%
x={'c':1}
print x
# Out:
# {'c': 1}

# %%
ax1.legend??

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
pD="/mnt/solexa/mel_yang/aPlateau/"
fh="aPlateau.dstat.log"
tv='all'

agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",][::-1]
eas=["Han","Dai","Ami","Daur","Naxi","Yi","Tibetan","Sherpa"][::-1]
wantedcolors=["blue"]*len(agq)
#myxmin=[-0.08]*5
#myxmax=[0.02]*5
myxmin=[-0.02]*5
myxmax=[0.06]*5
mysubplot=0
#fig = plt.figure(figsize=(10,5))
fig = plt.figure(figsize=(9,3))
#popA=['Zongri1a',"Shangluzhuang","Hejiatai","Daxiang"]
popA=["Zongri23","Xiahaishi","Lajigai","Wenpuju"]
popB=eas
mynames=eas
myind="Hejiatai"
outs=["Mbuti","Chimp"]
out="Mbuti"
varypops=popA #outs
ypops=popB
for count,varypop in enumerate(varypops):

    #mypops2=[popA,myind,ypops,varypop]
    mypops2=[[varypop],myind,ypops,out]
    DorZ="Z"
    Zary = np.transpose(pm.mkDary(pD,fh,mypops2,(1,3),(0,2),'Z'))
    Dary = np.transpose(pm.mkDary(pD,fh,mypops2,(1,3),(0,2),'D'))
    mylabel="D(%s,%s;%s,%s)" % (mypops2[0][0],mypops2[1],'EAS',mypops2[3])
    mylabel="P1 = %s" % mypops2[0][0]
    SEary=Dary/Zary 
    
    
    ax1=fig.add_subplot(1,len(varypops),count+1)
    for ind,i in enumerate(ypops):
        ax1.errorbar(Dary[ind][0],ind,xerr=SEary[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=9,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Dary[ind][0],ind,xerr=3*SEary[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=9,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Dary[ind],ind,'.')
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    if count==0:
        #ax1.text("P2=%s\n" % myind,rotation=90,fontsize=16)
        ax1.set_ylabel("P2=%s\n\nP3" % myind,rotation=90,fontsize=13)
        ax1.set_yticklabels(mynames,fontsize=15)
    else: 
        ax1.set_yticklabels([' ']*len(mynames),fontsize=3)
    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[count],myxmax[count])
    #xlabel = ax1.get_xticks().tolist()
    #print xlabel
    #ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)

    ax1.set_title(mylabel,fontsize=13)

    ax1.axvline(x=0, ls='dashed', c='black')
    for myline in [3.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)

    ax1.set_xlabel("D, %s" % tv,fontsize=15)
fig.autofmt_xdate()  
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Heatmap

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.colors
pD="/mnt/solexa/mel_yang/aPlateau/"
fh="aPlateau.dstat.log"
tv='all'
fs=15
agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
wantedcolors=["blue"]*len(agq)
header1,header2=agq,agq
popA=agq
popB=agq
varypop=["Tianyuan",'Vestonice16']
myind="Sherpa"
outs=["Mbuti","Chimp"]
for count,out in enumerate(outs):
    #myind="Shangluzhuang"
    #myind="Hejiatai"
    
    mypops1=[popA,myind,popB,out]
    mypops2=[popA,popB,myind,out]
    DorZ="Z"

    Zary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),'Z')
    Dary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),'D')
    mylabel="D(%s,%s;%s,%s)" % ('P1',"P2",myind,out)
    Zary = np.nan_to_num(Zary)
    
    levels = range(-10,11)
    multiplier=((len(levels)-6)/2)+1
    colors = ['#333399']*multiplier + ['#CCCCFF'] + ['white']*4 + ['#FFEFD5'] + ['orange']*multiplier
    cmap1,norm = matplotlib.colors.from_levels_and_colors(levels, colors,extend='both')
    
    fig,ax = plt.subplots(figsize=(10,10))
    heatmap = ax.pcolor(Zary ,cmap=cmap1, vmin=-10,vmax=10)
    cbar=plt.colorbar(heatmap)
    
    ##LEGEND
    cbar.ax.text(.5, 0.25, '$D<0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.5, '$N.S.$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.75, '$D>0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.get_yaxis().labelpad = 15
    cbar.ax.set_ylabel('Z-score', rotation=270,fontsize=fs)
    
    ax.grid(True)
    ax.set_xticks(np.arange(len(header1)), minor=False)
    ax.set_yticks(np.arange(len(header2)), minor=False)
    
    column_labels = header1
    row_labels = header2
    ax.set_xlim((0,len(header1)))
    ax.set_ylim((0,len(header2)))
    ax.set_xticklabels(column_labels, minor=False,fontsize=fs,rotation=75,ha='left')
    ax.set_yticklabels(row_labels, minor=False,fontsize=fs,va='top')
    ax.invert_yaxis()
    ax.xaxis.tick_top()
    ax.text(-3.5,-0.5,"P1/P2",fontsize=fs+5)
    
plt.show()
print myind
# Out:
# Sherpa

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.colors
pD="/mnt/solexa/mel_yang/aPlateau/"
fh="aPlateau.dstat.log"
tv='all'
fs=15
agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
eas=["Ulchi","Oroqen","Hezhen","Daur","Xibo","Tu","Japanese","Korean","Han","She","Miao","Tujia",
    "Dai","Kinh","Lahu","Ami","Atayal","Naxi","Yi","Tibetan","Sherpa"]
wantedcolors=["blue"]*len(agq)
header1,header2=agq,agq
popA=agq
popB=agq
varypop=["Tianyuan",'Vestonice16']
myind="Han"
outs=["Mbuti","Chimp"]
for count,out in enumerate(outs):
    #myind="Shangluzhuang"
    #myind="Hejiatai"
    
    mypops1=[popA,myind,popB,out]
    mypops2=[popA,popB,myind,out]
    DorZ="Z"

    Zary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),'Z')
    Dary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),'D')
    mylabel="D(%s,%s;%s,%s)" % ('P1',"P2",myind,out)
    Zary = np.nan_to_num(Zary)
    
    levels = range(-10,11)
    multiplier=((len(levels)-6)/2)+1
    colors = ['#333399']*multiplier + ['#CCCCFF'] + ['white']*4 + ['#FFEFD5'] + ['orange']*multiplier
    cmap1,norm = matplotlib.colors.from_levels_and_colors(levels, colors,extend='both')
    
    fig,ax = plt.subplots(figsize=(10,10))
    heatmap = ax.pcolor(Zary ,cmap=cmap1, vmin=-10,vmax=10)
    cbar=plt.colorbar(heatmap)
    
    ##LEGEND
    cbar.ax.text(.5, 0.25, '$D<0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.5, '$N.S.$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.75, '$D>0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.get_yaxis().labelpad = 15
    cbar.ax.set_ylabel('Z-score', rotation=270,fontsize=fs)
    
    ax.grid(True)
    ax.set_xticks(np.arange(len(header1)), minor=False)
    ax.set_yticks(np.arange(len(header2)), minor=False)
    
    column_labels = header1
    row_labels = header2
    ax.set_xlim((0,len(header1)))
    ax.set_ylim((0,len(header2)))
    ax.set_xticklabels(column_labels, minor=False,fontsize=fs,rotation=75,ha='left')
    ax.set_yticklabels(row_labels, minor=False,fontsize=fs,va='top')
    ax.invert_yaxis()
    ax.xaxis.tick_top()
    ax.text(-3.5,-0.5,"P1/P2",fontsize=fs+5)
    
plt.show()
print myind
# Out:
# Han

# %%
! ls
print 'hi'
# Out:
# make_tables.ipynb  plateau_modules.ipynb
# hi

# %% [markdown]
# ## D(EAS, EAS; aGQ, Mbuti)

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.colors
pD="/mnt/solexa/mel_yang/aPlateau/"
fh="aPlateau.dstat.log"
tv='all'
fs=15
agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
eas=["Oroqen","Hezhen","Daur","Xibo","Japanese","Korean","Han","She","Miao","Tujia",
    "Dai","Kinh","Lahu","Ami","Atayal","Naxi","Yi","Tibetan","Sherpa"]
wantedcolors=["blue"]*len(agq)
header1,header2=eas,agq
popA=eas
popB=agq
myind="She"
outs=["Mbuti","Chimp"]
myinds=["Dai","Ami","Daur","Naxi","Yi","Tibetan","Sherpa"] #,"She","Miao","Tujia","Japanese","Korean","Daur"]
myinds=["Atayal"]
out="Mbuti"
for count,myind in enumerate(myinds):
    #myind="Shangluzhuang"
    #myind="Hejiatai"
    
    mypops1=[popA,myind,popB,out]
    DorZ="Z"

    Zary = pm.mkDary(pD,fh,mypops1,(1,3),(0,2),'Z')
    Dary = pm.mkDary(pD,fh,mypops1,(1,3),(0,2),'D')
    Zary = np.nan_to_num(Zary)
    mylabel="D(%s,%s;%s,%s)" % ('X',myind,"Y",out)
    print mylabel
    print Zary.shape
    levels = range(-10,11)
    multiplier=((len(levels)-6)/2)+1
    colors = ['#333399']*multiplier + ['#CCCCFF'] + ['white']*4 + ['#FFEFD5'] + ['orange']*multiplier
    cmap1,norm = matplotlib.colors.from_levels_and_colors(levels, colors,extend='both')
    
    fig,ax = plt.subplots(figsize=(10,10))
    heatmap = ax.pcolor(Zary ,cmap=cmap1, vmin=-10,vmax=10)
    cbar=plt.colorbar(heatmap)
    
    ##LEGEND
    cbar.ax.text(.5, 0.25, '$D<0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.5, '$N.S.$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.75, '$D>0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.get_yaxis().labelpad = 15
    cbar.ax.set_ylabel('Z-score', rotation=270,fontsize=fs)
    
    ax.grid(True)
    ax.set_xticks(np.arange(len(header2)), minor=False)
    ax.set_yticks(np.arange(len(header1)), minor=False)
    
    column_labels = header2
    row_labels = header1
    ax.set_xlim((0,len(header2)))
    ax.set_ylim((0,len(header1)))
    
    ax.set_xticklabels(column_labels, minor=False,fontsize=fs,rotation=75,ha='left')
    ax.set_yticklabels(row_labels, minor=False,fontsize=fs,va='top')
    ax.invert_yaxis()
    ax.xaxis.tick_top()
    ax.text(-3.5,-0.5,"P1/P3",fontsize=fs+5)
    
plt.show()
# Out:
# D(X,Atayal;Y,Mbuti)
# (19, 18)

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.colors
pD="/mnt/solexa/mel_yang/aPlateau/"
fh="aPlateau.dstat.log"
tv='all'
fs=15
agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]

wantedcolors=["blue"]*len(agq)
header1,header2=agq,agq
popA=agq
popB=agq
myind="She"
outs=["Mbuti","Chimp"]
myinds=["Han","She","Miao","Tujia","Japanese","Korean","Daur"]
out="Mbuti"
for count,myind in enumerate(myinds):
    #myind="Shangluzhuang"
    #myind="Hejiatai"
    
    mypops1=[popA,myind,popB,out]
    DorZ="Z"

    Zary = pm.mkDary(pD,fh,mypops1,(1,3),(0,2),'Z')
    Dary = pm.mkDary(pD,fh,mypops1,(1,3),(0,2),'D')
    Zary = np.nan_to_num(Zary)
    mylabel="D(%s,%s;%s,%s)" % ('X',myind,"Y",out)
    print mylabel
    
    levels = range(-10,11)
    multiplier=((len(levels)-6)/2)+1
    colors = ['#333399']*multiplier + ['#CCCCFF'] + ['white']*4 + ['#FFEFD5'] + ['orange']*multiplier
    cmap1,norm = matplotlib.colors.from_levels_and_colors(levels, colors,extend='both')
    
    fig,ax = plt.subplots(figsize=(10,10))
    heatmap = ax.pcolor(Zary ,cmap=cmap1, vmin=-10,vmax=10)
    cbar=plt.colorbar(heatmap)
    
    ##LEGEND
    cbar.ax.text(.5, 0.25, '$D<0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.5, '$N.S.$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.75, '$D>0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.get_yaxis().labelpad = 15
    cbar.ax.set_ylabel('Z-score', rotation=270,fontsize=fs)
    
    ax.grid(True)
    ax.set_xticks(np.arange(len(header1)), minor=False)
    ax.set_yticks(np.arange(len(header2)), minor=False)
    
    column_labels = header1
    row_labels = header2
    ax.set_xlim((0,len(header1)))
    ax.set_ylim((0,len(header2)))
    
    ax.set_xticklabels(column_labels, minor=False,fontsize=fs,rotation=75,ha='left')
    ax.set_yticklabels(row_labels, minor=False,fontsize=fs,va='top')
    ax.invert_yaxis()
    ax.xaxis.tick_top()
    ax.text(-3.5,-0.5,"P1/P3",fontsize=fs+5)
    
plt.show()
# Out:
# D(P1,Han;P3,Mbuti)
# D(P1,She;P3,Mbuti)
# D(P1,Miao;P3,Mbuti)
# D(P1,Tujia;P3,Mbuti)
# D(P1,Japanese;P3,Mbuti)
# D(P1,Korean;P3,Mbuti)
# D(P1,Daur;P3,Mbuti)

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.colors
pD="/mnt/solexa/mel_yang/aPlateau/"
fh,tv=("aPlateau.dstat.log",'all')
fh,tv=("aPlateau.tv.dstat.log",'tv')

fs=15
agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]

wantedcolors=["blue"]*len(agq)
header1,header2=agq,agq
popA=agq
popB=agq
myind="She"
outs=["Mbuti","Chimp"]
myinds=["Shannashuzha"] #agq
out="Mbuti"
for count,myind in enumerate(myinds):
    #myind="Shangluzhuang"
    #myind="Hejiatai"
    
    mypops1=[popA,myind,popB,out]
    newname="D_aGQ_%s_aGQ_%s" % (myind,out)
    DorZ="Z"

    Zary = pm.mkDary(pD,fh,mypops1,(1,3),(0,2),'Z')
    Dary = pm.mkDary(pD,fh,mypops1,(1,3),(0,2),'D')
    Zary = np.nan_to_num(Zary)
    mylabel="D(%s,%s;%s,%s)" % ('X',myind,"Y",out)
    print mylabel
    
    levels = range(-10,11)
    multiplier=((len(levels)-6)/2)+1
    colors = ['#333399']*multiplier + ['#CCCCFF'] + ['white']*4 + ['#FFEFD5'] + ['orange']*multiplier
    cmap1,norm = matplotlib.colors.from_levels_and_colors(levels, colors,extend='both')
    
    fig,ax = plt.subplots(figsize=(10,10))
    heatmap = ax.pcolor(Zary ,cmap=cmap1, vmin=-10,vmax=10)
    cbar=plt.colorbar(heatmap)
    
    ##LEGEND
    cbar.ax.text(.5, 0.25, '$D<0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.5, '$N.S.$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.75, '$D>0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.get_yaxis().labelpad = 15
    cbar.ax.set_ylabel('Z-score', rotation=270,fontsize=fs)
    
    ax.grid(True)
    ax.set_xticks(np.arange(len(header1)), minor=False)
    ax.set_yticks(np.arange(len(header2)), minor=False)
    
    column_labels = header1
    row_labels = header2
    ax.set_xlim((0,len(header1)))
    ax.set_ylim((0,len(header2)))
    
    ax.set_xticklabels(column_labels, minor=False,fontsize=fs,rotation=75,ha='left')
    ax.set_yticklabels(row_labels, minor=False,fontsize=fs,va='top')
    ax.invert_yaxis()
    ax.xaxis.tick_top()
    ax.text(-3.5,-0.5,"P1/P3",fontsize=fs+5)
    newfilename='/mnt/solexa/mel_yang/aPlateau/images/%s_%s_heatmap.png' % (newname,tv)
    print newfilename
    fig.savefig(newfilename)

    
#plt.show()
# Out:
# D(X,Shannashuzha;Y,Mbuti)
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_Shannashuzha_aGQ_Mbuti_tv_heatmap.png

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.colors
pD="/mnt/solexa/mel_yang/aPlateau/"
fh,tv=("aPlateau.dstat.log",'all')
#fh,tv=("aPlateau.tv.dstat.log",'tv')
fs=15
agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
wantedcolors=["blue"]*len(agq)
header1,header2=agq,agq
popA=agq
popB=agq
varypop=["Tianyuan",'Vestonice16']
myind="Sherpa"
myinds=agq
outs=["Mbuti","Chimp"]
out="Mbuti"
for count,myind in enumerate(myinds):
    #myind="Shangluzhuang"
    #myind="Hejiatai"
    
    mypops1=[popA,myind,popB,out]
    mypops2=[popA,popB,myind,out]
    DorZ="Z"
    newname="D_aGQ_aGQ_%s_%s" % (myind,out)
    Zary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),'Z')
    Dary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),'D')
    mylabel="D(%s,%s;%s,%s)" % ('P1',"P2",myind,out)
    Zary = np.nan_to_num(Zary)
    
    levels = range(-10,11)
    multiplier=((len(levels)-6)/2)+1
    colors = ['#333399']*multiplier + ['#CCCCFF'] + ['white']*4 + ['#FFEFD5'] + ['orange']*multiplier
    cmap1,norm = matplotlib.colors.from_levels_and_colors(levels, colors,extend='both')
    
    fig,ax = plt.subplots(figsize=(10,10))
    heatmap = ax.pcolor(Zary ,cmap=cmap1, vmin=-10,vmax=10)
    cbar=plt.colorbar(heatmap)
    
    ##LEGEND
    cbar.ax.text(.5, 0.25, '$D<0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.5, '$N.S.$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.75, '$D>0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.get_yaxis().labelpad = 15
    cbar.ax.set_ylabel('Z-score', rotation=270,fontsize=fs)
    
    ax.grid(True)
    ax.set_xticks(np.arange(len(header1)), minor=False)
    ax.set_yticks(np.arange(len(header2)), minor=False)
    
    column_labels = header1
    row_labels = header2
    ax.set_xlim((0,len(header1)))
    ax.set_ylim((0,len(header2)))
    ax.set_xticklabels(column_labels, minor=False,fontsize=fs,rotation=75,ha='left')
    ax.set_yticklabels(row_labels, minor=False,fontsize=fs,va='top')
    ax.invert_yaxis()
    ax.xaxis.tick_top()
    ax.text(-3.5,-0.5,"P1/P2",fontsize=fs+5)
    newfilename='/mnt/solexa/mel_yang/aPlateau/images/%s_%s_heatmap.png' % (newname,tv)
    print newfilename
    fig.savefig(newfilename)
    
plt.show()
print myind
# Out:
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Zongri1a_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Zongri23_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Shangluzhuang_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Hejiatai_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Heodong_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Daxiang_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Xiahaishi_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Hupo_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Sanheyi_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Qunke_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Lajigai_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Wenpuju_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Jinchankou_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Qijiaping_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Wuba_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Huoshaogou_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Lierbao_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Shannashuzha_Mbuti_all_heatmap.png
# Shannashuzha

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.colors
pD="/mnt/solexa/mel_yang/aPlateau/"
fh,tv=("aPlateau.dstat.log",'all')
fh,tv=("aPlateau.tv.dstat.log",'tv')
fs=15
agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
wantedcolors=["blue"]*len(agq)
header1,header2=agq,agq
popA=agq
popB=agq
varypop=["Tianyuan",'Vestonice16']
myind="Sherpa"
myinds=["Han","Ami","Dai","Daur","Naxi","Yi","Tibetan","Sherpa"]
outs=["Mbuti","Chimp"]
out="Mbuti"
for count,myind in enumerate(myinds):
    #myind="Shangluzhuang"
    #myind="Hejiatai"
    
    mypops1=[popA,myind,popB,out]
    mypops2=[popA,popB,myind,out]
    DorZ="Z"
    newname="D_aGQ_aGQ_%s_%s" % (myind,out)
    Zary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),'Z')
    Dary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),'D')
    mylabel="D(%s,%s;%s,%s)" % ('P1',"P2",myind,out)
    Zary = np.nan_to_num(Zary)
    
    levels = range(-10,11)
    multiplier=((len(levels)-6)/2)+1
    colors = ['#333399']*multiplier + ['#CCCCFF'] + ['white']*4 + ['#FFEFD5'] + ['orange']*multiplier
    cmap1,norm = matplotlib.colors.from_levels_and_colors(levels, colors,extend='both')
    
    fig,ax = plt.subplots(figsize=(10,10))
    heatmap = ax.pcolor(Zary ,cmap=cmap1, vmin=-10,vmax=10)
    cbar=plt.colorbar(heatmap)
    
    ##LEGEND
    cbar.ax.text(.5, 0.25, '$D<0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.5, '$N.S.$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.75, '$D>0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.get_yaxis().labelpad = 15
    cbar.ax.set_ylabel('Z-score', rotation=270,fontsize=fs)
    
    ax.grid(True)
    ax.set_xticks(np.arange(len(header1)), minor=False)
    ax.set_yticks(np.arange(len(header2)), minor=False)
    
    column_labels = header1
    row_labels = header2
    ax.set_xlim((0,len(header1)))
    ax.set_ylim((0,len(header2)))
    ax.set_xticklabels(column_labels, minor=False,fontsize=fs,rotation=75,ha='left')
    ax.set_yticklabels(row_labels, minor=False,fontsize=fs,va='top')
    ax.invert_yaxis()
    ax.xaxis.tick_top()
    ax.text(-3.5,-0.5,"P1/P2",fontsize=fs+5)
    newfilename='/mnt/solexa/mel_yang/aPlateau/images/%s_%s_heatmap.png' % (newname,tv)
    print newfilename
    fig.savefig(newfilename)
    
plt.show()
print myind
# Out:
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Han_Mbuti_tv_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Ami_Mbuti_tv_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Dai_Mbuti_tv_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Daur_Mbuti_tv_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Naxi_Mbuti_tv_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Yi_Mbuti_tv_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Tibetan_Mbuti_tv_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aGQ_aGQ_Sherpa_Mbuti_tv_heatmap.png
# Sherpa

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.colors
pD="/mnt/solexa/mel_yang/aPlateau/"
fh,tv=("aPlateau.dstat.log",'all')
#fh,tv=("aPlateau.tv.dstat.log",'tv')
fs=15
agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
eas=["Ulchi","Oroqen","Daur","Hezhen","Xibo","Tu","Japanese","Korean",
    "Han","Tujia","She","Miao","Ami","Atayal","Dai","Kinh","Lahu",
     "Naxi","Yi","Tibetan","Sherpa"]
wantedcolors=["blue"]*len(agq)
header1,header2=eas,eas
popA=eas
popB=eas
varypop=["Tianyuan",'Vestonice16']
myind="Sherpa"
myinds=agq
outs=["Mbuti","Chimp"]
out="Mbuti"
for count,myind in enumerate(myinds):
    #myind="Shangluzhuang"
    #myind="Hejiatai"
    
    mypops1=[popA,myind,popB,out]
    mypops2=[popA,popB,myind,out]
    DorZ="Z"
    newname="D_EAS_EAS_%s_%s" % (myind,out)
    Zary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),'Z')
    Dary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),'D')
    mylabel="D(%s,%s;%s,%s)" % ('P1',"P2",myind,out)
    Zary = np.nan_to_num(Zary)
    
    levels = range(-10,11)
    multiplier=((len(levels)-6)/2)+1
    colors = ['#333399']*multiplier + ['#CCCCFF'] + ['white']*4 + ['#FFEFD5'] + ['orange']*multiplier
    cmap1,norm = matplotlib.colors.from_levels_and_colors(levels, colors,extend='both')
    
    fig,ax = plt.subplots(figsize=(10,10))
    heatmap = ax.pcolor(Zary ,cmap=cmap1, vmin=-10,vmax=10)
    cbar=plt.colorbar(heatmap)
    
    ##LEGEND
    cbar.ax.text(.5, 0.25, '$D<0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.5, '$N.S.$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.75, '$D>0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.get_yaxis().labelpad = 15
    cbar.ax.set_ylabel('Z-score', rotation=270,fontsize=fs)
    
    ax.grid(True)
    ax.set_xticks(np.arange(len(header1)), minor=False)
    ax.set_yticks(np.arange(len(header2)), minor=False)
    
    column_labels = header1
    row_labels = header2
    ax.set_xlim((0,len(header1)))
    ax.set_ylim((0,len(header2)))
    ax.set_xticklabels(column_labels, minor=False,fontsize=fs,rotation=75,ha='left')
    ax.set_yticklabels(row_labels, minor=False,fontsize=fs,va='top')
    ax.invert_yaxis()
    ax.xaxis.tick_top()
    ax.text(-3.5,-0.5,"P1/P2",fontsize=fs+5)
    newfilename='/mnt/solexa/mel_yang/aPlateau/images/%s_%s_heatmap.png' % (newname,tv)
    print newfilename
    fig.savefig(newfilename)
    
plt.show()
print myind
# Out:
# /mnt/solexa/mel_yang/aPlateau/images/D_EAS_EAS_Zongri1a_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_EAS_EAS_Zongri23_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_EAS_EAS_Shangluzhuang_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_EAS_EAS_Hejiatai_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_EAS_EAS_Heodong_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_EAS_EAS_Daxiang_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_EAS_EAS_Xiahaishi_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_EAS_EAS_Hupo_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_EAS_EAS_Sanheyi_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_EAS_EAS_Qunke_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_EAS_EAS_Lajigai_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_EAS_EAS_Wenpuju_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_EAS_EAS_Jinchankou_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_EAS_EAS_Qijiaping_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_EAS_EAS_Wuba_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_EAS_EAS_Huoshaogou_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_EAS_EAS_Lierbao_Mbuti_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_EAS_EAS_Shannashuzha_Mbuti_all_heatmap.png
# Shannashuzha

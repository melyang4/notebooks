# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib


#agq=["Zongri1a","Zongri23",
agq=["Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao"][::-1]
anx=["Pukagongma","Pukagongma7","Yushu","Redilong","Xiaoenda","Butaxiongqu","Caixiutang",
    "Chokhopani","Mebrak","Samdzong"]
wantedcolors=["blue"]*len(agq)
myxmin=[-0.08]*2
myxmax=[0.05]*2
mysubplot=0
fig = plt.figure(figsize=(10,5))

popA=["Han"]
#popA=popA[::-1]
popB=agq
varypop=['Han']
myind="Pukagongma"
outs=["Mbuti","Chimp"]
out="Mbuti"
mypops2s=[[popB,popA,myind,out],[myind,popA,popB,out]]
mylabels=["D(%s,%s;%s,%s)" % ('aGQ',popA[0],myind,out),"D(%s,%s;%s,%s)" % (myind,popA[0],'aGQ',out)]
mytuples=[[(2,3),(0,1)],[(0,3),(1,2)]]
for count,mypops2 in enumerate(mypops2s):
    #print mypops2
    pD="/mnt/solexa/mel_yang/aPlateau/"
    fhall="aPlateau.dstat.log"
    fhtv="aPlateau.tv.dstat.log"
    #tv='all'
    #mypops2=[popA,popB,myind,out]
    if count == 0:
        Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[count][0],mytuples[count][1],'Z')
        Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[count][0],mytuples[count][1],'D')
        SEaryall=Daryall/Zaryall 
        Zarytv = pm.mkDary(pD,fhtv,mypops2,mytuples[count][0],mytuples[count][1],'Z')
        Darytv = pm.mkDary(pD,fhtv,mypops2,mytuples[count][0],mytuples[count][1],'D')
        SEarytv=Darytv/Zarytv
    else:
        Zaryall = np.transpose(pm.mkDary(pD,fhall,mypops2,mytuples[count][0],mytuples[count][1],'Z'))
        Daryall = np.transpose(pm.mkDary(pD,fhall,mypops2,mytuples[count][0],mytuples[count][1],'D'))
        SEaryall=Daryall/Zaryall 
        Zarytv = np.transpose(pm.mkDary(pD,fhtv,mypops2,mytuples[count][0],mytuples[count][1],'Z'))
        Darytv = np.transpose(pm.mkDary(pD,fhtv,mypops2,mytuples[count][0],mytuples[count][1],'D'))
        SEarytv=Darytv/Zarytv
    
    mylabel=mylabels[count]
    mynames=agq
    
    ax1=fig.add_subplot(1,len(varypop),count+1)
    for ind,i in enumerate(agq):
        #print tyD[i]
        #print Dary[ind][0]
        ax1.errorbar(Darytv[ind][0],ind,xerr=SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[ind][0],ind,xerr=2*SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[ind],ind,'.',alpha=0.05)

        ax1.errorbar(Daryall[ind][0],ind,xerr=SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[ind][0],ind,xerr=2*SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[ind],ind,'.')
        
    #ax1.set_yticks(len(mynames))
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    if count==0:
        ax1.set_yticklabels(mynames,fontsize=16)
    else: 
        ax1.set_yticklabels([' ']*len(mynames),fontsize=3)

    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[count],myxmax[count])

    xlabel = ax1.get_xticks().tolist()
    ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)

    ax1.set_title(mylabel,fontsize=15)

    ax1.axvline(x=0, ls='dashed', c='black')
    #for myline in [9.5]:
    #    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)
    ax1.set_xlabel("D",fontsize=15)
    #ax1.set_xlabel("D, %s" % tv,fontsize=15)
    
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-098db8ad3ae3> in <module>()
#      52     mynames=agq
#      53
# ---> 54     ax1=fig.add_subplot(1,len(varypop),count+1)
#      55     for ind,i in enumerate(agq):
#      56         #print tyD[i]
#
# /home/mel_yang/.local/lib/python2.7/site-packages/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#    1019                     self._axstack.remove(ax)
#    1020
# -> 1021             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1022
#    1023         self._axstack.add(key, a)
#
# /home/mel_yang/.local/lib/python2.7/site-packages/matplotlib/axes/_subplots.pyc in __init__(self, fig, *args, **kwargs)
#      62                     raise ValueError(
#      63                         "num must be 1 <= num <= {maxn}, not {num}".format(
# ---> 64                             maxn=rows*cols, num=num))
#      65                 self._subplotspec = GridSpec(rows, cols)[int(num) - 1]
#      66                 # num - 1 for converting from MATLAB to python indexing
#
# ValueError: num must be 1 <= num <= 1, not 2

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib

agq=["Zongri1a","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Zongri23","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Pukagongma","Pukagongma7","Yushu",
     "Redilong","Xiaoenda","Butaxiongqu","Caixiutang",
    "Chokhopani","Mebrak","Samdzong"][::-1]
wantedcolors=["blue"]*len(agq)
pD="/mnt/solexa/mel_yang/aPlateau/"
fhall="aPlateau.dstat.log"
fhtv="aPlateau.tv.dstat.log"
out="Mbuti"
xlims=(-0.03,0.12)
mypop1="Huoshaogou"
mypops2=[[agq,"Han",[mypop1],out],["Han",[mypop1],agq,out]]
mytuples=[[(1,3),(0,2)],[(0,3),(1,2)]]
mylabels=["D(%s,%s;%s,%s)" % ('aTib',"Han",mypop1,out),"D(%s,%s;%s,%s)" % ("Han",mypop1,'aTib',out)]

fig = plt.figure(figsize=(8,8))

count=0
for count in range(0,2):
    if count==0:
        Zaryall = pm.mkDary(pD,fhall,mypops2[count],mytuples[count][0],mytuples[count][1],'Z')
        Daryall = pm.mkDary(pD,fhall,mypops2[count],mytuples[count][0],mytuples[count][1],'D')
        SEaryall=Daryall/Zaryall 
        Zarytv = pm.mkDary(pD,fhtv,mypops2[count],mytuples[count][0],mytuples[count][1],'Z')
        Darytv = pm.mkDary(pD,fhtv,mypops2[count],mytuples[count][0],mytuples[count][1],'D')
        SEarytv=Darytv/Zarytv
    else:
        Zaryall = np.transpose(pm.mkDary(pD,fhall,mypops2[count],mytuples[count][0],mytuples[count][1],'Z'))
        Daryall = np.transpose(pm.mkDary(pD,fhall,mypops2[count],mytuples[count][0],mytuples[count][1],'D'))
        SEaryall=Daryall/Zaryall 
        Zarytv = np.transpose(pm.mkDary(pD,fhtv,mypops2[count],mytuples[count][0],mytuples[count][1],'Z'))
        Darytv = np.transpose(pm.mkDary(pD,fhtv,mypops2[count],mytuples[count][0],mytuples[count][1],'D'))
        SEarytv=Darytv/Zarytv
    
    mylabel=mylabels[count]
    mynames=agq
    
    ax1=fig.add_subplot(1,len(mypops2),count+1)
    for ind,i in enumerate(agq):
        ax1.errorbar(Darytv[ind][0],ind,xerr=SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[ind][0],ind,xerr=2*SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[ind],ind,'.',alpha=0.05)

        ax1.errorbar(Daryall[ind][0],ind,xerr=SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[ind][0],ind,xerr=2*SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[ind],ind,'.')
        
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    if count==0:
        ax1.set_yticklabels(mynames,fontsize=16)
    else: 
        ax1.set_yticklabels(['']*len(mynames),fontsize=3)

    ax1.set_ylim(-1,len(mynames))
    if count==0: ax1.set_xlim(xlims[0],xlims[1])
    else: ax1.set_xlim(-xlims[1],-xlims[0])
        
    xlabel = ax1.get_xticks().tolist()
    ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)

    ax1.set_title(mylabel,fontsize=13)

    ax1.axvline(x=0, ls='dashed', c='black')
    for myline in [9.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)
    ax1.set_xlabel("D",fontsize=15)
    #ax1.set_xlabel("D, %s" % tv,fontsize=15)
    
plt.tight_layout()
plt.show()

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib

agq=["Zongri1a","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Zongri23","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Pukagongma","Pukagongma7","Yushu",
     "Redilong","Xiaoenda","Butaxiongqu","Caixiutang",
    "Chokhopani","Mebrak","Samdzong"][::-1]
wantedcolors=["blue"]*len(agq)
pD="/mnt/solexa/mel_yang/aPlateau/"
fhall="aPlateau.dstat.log"
fhtv="aPlateau.tv.dstat.log"
out="Mbuti"
xlims=(-0.05,0.08)
mypop1="Pukagongma"
relto="Zongri1a"
mypops2=[[agq,relto,[mypop1],out],[relto,[mypop1],agq,out]]
mytuples=[[(1,3),(0,2)],[(0,3),(1,2)]]
mylabels=["D(%s,%s;%s,%s)" % ('aTib',relto,mypop1,out),"D(%s,%s;%s,%s)" % (relto,mypop1,'aTib',out)]

fig = plt.figure(figsize=(8,8))

count=0
for count in range(0,2):
    if count==0:
        Zaryall = pm.mkDary(pD,fhall,mypops2[count],mytuples[count][0],mytuples[count][1],'Z')
        Daryall = pm.mkDary(pD,fhall,mypops2[count],mytuples[count][0],mytuples[count][1],'D')
        SEaryall=Daryall/Zaryall 
        Zarytv = pm.mkDary(pD,fhtv,mypops2[count],mytuples[count][0],mytuples[count][1],'Z')
        Darytv = pm.mkDary(pD,fhtv,mypops2[count],mytuples[count][0],mytuples[count][1],'D')
        SEarytv=Darytv/Zarytv
    else:
        Zaryall = np.transpose(pm.mkDary(pD,fhall,mypops2[count],mytuples[count][0],mytuples[count][1],'Z'))
        Daryall = np.transpose(pm.mkDary(pD,fhall,mypops2[count],mytuples[count][0],mytuples[count][1],'D'))
        SEaryall=Daryall/Zaryall 
        Zarytv = np.transpose(pm.mkDary(pD,fhtv,mypops2[count],mytuples[count][0],mytuples[count][1],'Z'))
        Darytv = np.transpose(pm.mkDary(pD,fhtv,mypops2[count],mytuples[count][0],mytuples[count][1],'D'))
        SEarytv=Darytv/Zarytv
    
    mylabel=mylabels[count]
    mynames=agq
    
    ax1=fig.add_subplot(1,len(mypops2),count+1)
    for ind,i in enumerate(agq):
        ax1.errorbar(Darytv[ind][0],ind,xerr=SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[ind][0],ind,xerr=2*SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[ind],ind,'.',alpha=0.05)

        ax1.errorbar(Daryall[ind][0],ind,xerr=SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[ind][0],ind,xerr=2*SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[ind],ind,'.')
        
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    if count==0:
        ax1.set_yticklabels(mynames,fontsize=16)
    else: 
        ax1.set_yticklabels(['']*len(mynames),fontsize=3)

    ax1.set_ylim(-1,len(mynames))
    if count==0: ax1.set_xlim(xlims[0],xlims[1])
    else: ax1.set_xlim(-xlims[1],-xlims[0])
        
    xlabel = ax1.get_xticks().tolist()
    ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)

    ax1.set_title(mylabel,fontsize=13)

    ax1.axvline(x=0, ls='dashed', c='black')
    for myline in [9.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)
    ax1.set_xlabel("D",fontsize=15)
    #ax1.set_xlabel("D, %s" % tv,fontsize=15)
    
plt.tight_layout()
plt.show()

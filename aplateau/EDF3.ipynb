# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib

pD="/mnt/solexa/mel_yang/aPlateau/update051518/"
fhall="complete2.dstat.log"
fhtv="complete2.tv.dstat.log"
out,out2=("Mbuti","Mbuti")
low2=["Zongri-b","Zongri-c","ZongriM78","ZongriM40","ZongriM32","Zongri-a",]
low1=["Hejiatai","Hedong6","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Shangluzhuang0","Hupo-a","Lajigai-a"]#"XiahaishiM22",
low4o=["HuoshaogouM117","Wuba","Hupo8","Qunke1","Hupo14"]
low3=["Jinchankou0","Wenpuju03","QijiapingM89-2","QijiapingM108-2","QijiapingM104-2","Lierbao0","Hedong4"]#"Lajigai2",
low=low2+low1+low3+low4o
high1=["PukagongmaM1","PukagongmaM5","PukagongmaM3"] #"PukagongmaM2",
high2=["RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","YushuSGZ-1","CaixiutangJ2-13"]
high3=["Chokhopani","Mebrak","Samdzong"]
high=high1+high2+high3
eas=["Oroqen","Hezhen","Daur","Xibo","Japanese","Korean","Han","She","Miao","Tujia",
    "Dai","Kinh","Lahu","Ami","Atayal","Naxi","Yi","Tu","Tibetan","Sherpa"]
tib=["Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX",
     "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]
sources=["Zongri-a","PukagongmaM5","Hejiatai","QijiapingM104-2",
         "Jinchankou0","Daxiang0","RedilongM3","Chokhopani","Naxi"]
sources=["Han","Tibetan_ChamdoX"]
mycombo=low+high
markers=['o','+','<','D','>','s','v','p','.']
lowhighdict={}
for ind,i in enumerate(low2): lowhighdict[i]=("low2",'blue',markers[ind])
for ind,i in enumerate(low1): lowhighdict[i]=("low1",'red',markers[ind])
for ind,i in enumerate(low3): lowhighdict[i]=("low3",'orange',markers[ind])        
for ind,i in enumerate(low4o): lowhighdict[i]=("low4o",'black',markers[ind])
for ind,i in enumerate(high1): lowhighdict[i]=("high1",'brown',markers[ind])
for ind,i in enumerate(high2): lowhighdict[i]=("high2",'purple',markers[ind])
for ind,i in enumerate(high3): lowhighdict[i]=("high3",'gray',markers[ind])
offset=0.01
mysubplot=0
fig = plt.figure(figsize=(5,5)) #figsize=(18,48))

myind="Tianyuan"
#mycombo.remove(myind)
varypops=[(i,j) for indi,i in enumerate(sources) for indj,j in enumerate(sources) if indj>indi] 
print len(varypops)
mypops1=[mycombo,myind,sources,out]
Daryall = pm.mkDary(pD,fhall,mypops1,(1,3),(0,2),'D')

for count,varypop in enumerate(varypops):
    s1,s2=varypop
    s1ind=sources.index(s1)
    s2ind=sources.index(s2)
    ax1=fig.add_subplot(12,3,count+1)
    handles1,handles2=[],[]
    #ax1.set_xlabel("D(X, %s; %s, %s)" % (myind,varypop[0],out),fontsize=15)
    #ax1.set_ylabel("D(X, %s; %s, %s)" % (myind,varypop[1],out),fontsize=15)
    ax1.set_xlabel("P3=%s" % (varypop[0]),fontsize=15)
    ax1.set_ylabel("P3=%s" % (varypop[1]),fontsize=15)
    ax1.axvline(x=0, ls='solid', c='gray')
    ax1.axhline(y=0, ls='solid', c='gray')
    ax1.plot([-0.1,0.5],[-0.1,0.5], ls='dashed', c='black')
    ax1.set_ylim((0.05,0.15))
    ax1.set_xlim((0.05,0.15))
    for ind,mytest in enumerate(mycombo):
        D1=Daryall[ind][s1ind]
        D2=Daryall[ind][s2ind]
        #print D1, D2
        ax1.plot(D1,D2,marker=lowhighdict[mytest][2], c=lowhighdict[mytest][1],label=mytest,linestyle="None")

ax1.legend(loc=4,ncol=10,fontsize=8,bbox_to_anchor=(0.5, -0.5))
plt.tight_layout()
plt.show()
# Out:
# 1

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib

offset=0.01
mysubplot=0
fig = plt.figure() #figsize=(18,48))

for count,varypop in enumerate(varypops):
    s1,s2=varypop
    s1ind=sources.index(s1)
    s2ind=sources.index(s2)
    ax1=fig.add_subplot(1,1,count+1)
    handles1,handles2=[],[]
    #ax1.set_xlabel("D(X, %s; %s, %s)" % (myind,varypop[0],out),fontsize=15)
    #ax1.set_ylabel("D(X, %s; %s, %s)" % (myind,varypop[1],out),fontsize=15)
    ax1.set_xlabel("P3=%s" % (varypop[0]) ,fontsize=15)
    ax1.set_ylabel("P3=%s" % (varypop[1]) ,fontsize=15)
    ax1.axvline(x=0, ls='solid', c='gray')
    ax1.axhline(y=0, ls='solid', c='gray')
    ax1.plot([-0.1,0.5],[-0.1,0.5], ls='dashed', c='black')
    ax1.set_ylim((0.05,0.15))
    ax1.set_xlim((0.05,0.15))
    for ind,mytest in enumerate(mycombo):
        if mytest == "Zongri-a": mynewlab="ZongriM297"
        elif mytest == "Zongri-b": mynewlab="ZongriM1"
        elif mytest == "Lajigai-a": mynewlab="Lajigai3"
        else: mynewlab=mytest
        D1=Daryall[ind][s1ind]
        D2=Daryall[ind][s2ind]
        #print D1, D2
        ax1.plot(D1,D2,marker=lowhighdict[mytest][2], c=lowhighdict[mytest][1],label=mytest,linestyle="None")

ax1.legend(loc=4,ncol=10,fontsize=8,bbox_to_anchor=(1.8, -0.5))
plt.tight_layout()
plt.show()

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import rcParams
from matplotlib.backends.backend_pdf import PdfPages

rcParams['font.family'] = 'Helvetica-Normal'
rcParams['font.size'] = 12
plt.style.use('seaborn-white')

pD="/mnt/solexa/mel_yang/aPlateau/update051518/"
fhall="complete2.dstat.log"
fhtv="complete2.tv.dstat.log"
out,out2=("Mbuti","Mbuti")
low2=["Zongri-b","Zongri-c","ZongriM78","ZongriM40","ZongriM32","Zongri-a",]
low1=["Hejiatai","Hedong6","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Shangluzhuang0","Hupo-a","Lajigai-a"]#"XiahaishiM22",
low4o=["HuoshaogouM117","Wuba","Hupo8","Qunke1","Hupo14"]
low3=["Jinchankou0","Wenpuju03","QijiapingM89-2","QijiapingM108-2","QijiapingM104-2","Lierbao0","Hedong4"]#"Lajigai2",
low=low2+low1+low3+low4o
high1=["PukagongmaM1","PukagongmaM5","PukagongmaM3"] #"PukagongmaM2",
high2=["RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","YushuSGZ-1","CaixiutangJ2-13"]
high3=["Chokhopani","Mebrak","Samdzong"]
high=high1+high2+high3
eas=["Oroqen","Hezhen","Daur","Xibo","Japanese","Korean","Han","She","Miao","Tujia",
    "Dai","Kinh","Lahu","Ami","Atayal","Naxi","Yi","Tu","Tibetan","Sherpa"]
tib=["Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX",
     "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]
sources=["Zongri-a","PukagongmaM5","Hejiatai","QijiapingM104-2",
         "Jinchankou0","Daxiang0","RedilongM3","Chokhopani","Naxi"]
sources=["Han","Tibetan_ChamdoX"]
#sources=["Naxi","Tibetan_ShannanX"]
sources=["Chokhopani","Zongri-b"]
sources=["Zongri-a","Han"]
mycombo=low+high
markers=['o','+','<','D','>','s','v','p','.']
lowhighdict={}
for ind,i in enumerate(low2): lowhighdict[i]=("low2",'blue',markers[ind])
for ind,i in enumerate(low1): lowhighdict[i]=("low1",'red',markers[ind])
for ind,i in enumerate(low3): lowhighdict[i]=("low3",'orange',markers[ind])        
for ind,i in enumerate(low4o): lowhighdict[i]=("low4o",'black',markers[ind])
for ind,i in enumerate(high1): lowhighdict[i]=("high1",'brown',markers[ind])
for ind,i in enumerate(high2): lowhighdict[i]=("high2",'purple',markers[ind])
for ind,i in enumerate(high3): lowhighdict[i]=("high3",'gray',markers[ind])

pp = PdfPages(pD+'EDF3.pdf')    
offset=0.01
mysubplot=0
fig = plt.figure(figsize=(12,12)) #figsize=(18,48))

myind="Tianyuan"
#mycombo.remove(myind)
varypops=[(i,j) for indi,i in enumerate(sources) for indj,j in enumerate(sources) if indj>indi] 
print len(varypops)

varypops=[("Tibetan_ChamdoX","Han"),
          ("Tibetan_ShannanX","Han"),
          ("Naxi","Han"),
          ("Zongri-a","Han"),
          ("RedilongM3","Han"),
          ("Chokhopani","Han"),
          ("Chokhopani","Zongri-a"),
          ("Chokhopani","QijiapingM89-2"),
          ("Chokhopani","RedilongM3")]
sources=[]
for i in varypops:
    for j in i: 
        if j not in sources: sources.append(j)
mypops1=[mycombo,myind,sources,out]
Daryall = pm.mkDary(pD,fhall,mypops1,(1,3),(0,2),'D')
letter="ABCDEFGHI"
for count,varypop in enumerate(varypops):
    print varypop
    s1,s2=varypop
    s1ind=sources.index(s1)
    s2ind=sources.index(s2)
    ax1=fig.add_subplot(3,3,count+1)
    handles1,handles2=[],[]
    #ax1.set_xlabel("D(X, %s; %s, %s)" % (myind,varypop[0],out),fontsize=15)
    #ax1.set_ylabel("D(X, %s; %s, %s)" % (myind,varypop[1],out),fontsize=15)
    if varypop[0] == "Zongri-a": vp0="ZongriM297"
    elif varypop[0] == "Zongri-b": vp0="ZongriM1"
    elif varypop[0] == "Lajigai-a": vp0="Lajigai3"
    elif varypop[0] == "Daxiang0": vp0="Dazhuang0"
    elif varypop[0] == "CaixiutangJ2-13": vp0="ChaxiutangJ2-13"
    elif varypop[0] == "Hejiatai": vp0="Hejiatai1"
    elif varypop[0][-1]=="X": vp0=varypop[0][:-1]
    else: vp0=varypop[0]
    if varypop[1] == "Zongri-a": vp1="ZongriM297"
    elif varypop[1] == "Zongri-b": vp1="ZongriM1"
    elif varypop[1] == "Lajigai-a": vp1="Lajigai3"
    elif varypop[0] == "Daxiang0": vp0="Dazhuang0"
    elif varypop[0] == "CaixiutangJ2-13": vp0="ChaxiutangJ2-13"
    elif varypop[0] == "Hejiatai": vp0="Hejiatai1"
    elif varypop[1][-1]=="X": vp1=varypop[1][:-1]
    else: vp1=varypop[1]
    ax1.set_xlabel("%s" % (vp0),fontsize=15)
    ax1.set_ylabel("%s" % (vp1),fontsize=15)
    ax1.axvline(x=0, ls='solid', c='gray')
    ax1.axhline(y=0, ls='solid', c='gray')
    ax1.plot([-0.1,0.5],[-0.1,0.5], ls='dashed', c='black',linewidth=0.5)
    ax1.set_ylim((0.06,0.135))
    ax1.set_xlim((0.06,0.135))
    for ind,mytest in enumerate(mycombo):
        if mytest == "Zongri-a": mynewlab="ZongriM297"
        elif mytest == "Zongri-b": mynewlab="ZongriM1"
        elif mytest == "Lajigai-a": mynewlab="Lajigai3"
        elif mytest == "Daxiang0": mynewlab="Dazhuang0"
        elif mytest == "CaixiutangJ2-13": mynewlab="ChaxiutangJ2-13"
        elif mytest == "Hejiatai": mynewlab="Hejiatai1"
        else: mynewlab=mytest
        D1=Daryall[ind][s1ind]
        D2=Daryall[ind][s2ind]
        #print D1, D2
        ax1.plot(D1,D2,marker=lowhighdict[mytest][2], markersize=10,c=lowhighdict[mytest][1],label=mynewlab,linestyle="None")
    ax1.text(0.063, 0.128, letter[count],fontsize=16,fontweight='bold')
ax1.legend(loc=4,ncol=1,fontsize=14,bbox_to_anchor=(1.8, -0.1)) #1.4
plt.tight_layout()
#plt.show()
pp.savefig(bbox_inches = "tight")
pp.close()
# Out:
# 1
# ('Tibetan_ChamdoX', 'Han')
# ('Tibetan_ShannanX', 'Han')
# ('Naxi', 'Han')
# ('Zongri-a', 'Han')
# ('RedilongM3', 'Han')
# ('Chokhopani', 'Han')
# ('Chokhopani', 'Zongri-a')
# ('Chokhopani', 'QijiapingM89-2')
# ('Chokhopani', 'RedilongM3')

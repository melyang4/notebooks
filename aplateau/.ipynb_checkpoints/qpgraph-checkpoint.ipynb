# %%
import projmodules as pm
pD = "/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/"
outpd="/mnt/solexa/mel_yang/data/2.2M/"
fh = 'UPA_all15'
subset = 'A01'
basegraphname = 'baseGraphA01'

baselabels = [['Mbuti','Mbuti'],['Kostenki14','Kostenki14'],['Tianyuan','Tianyuan']]
baseedges = [['rm','R','Mbuti'],['rn','R','NA'],['nk','NA','Kostenki14'],
             ['nt','NA','Tianyuan']]
baseadmixes = []

#pm.graph_par(pD,fh,subset,outpop='Mbuti',outpd="/mnt/solexa/mel_yang/data/2.2M/")
#pm.graph_mkgraph(pD,basegraphname,baselabels,baseedges,baseadmixes,comments='NA')
pm.graph_runfile(basegraphname,pD,fh,subset,outpop='Mbuti',outpd=outpd)
# Out:
# qpGraph -p /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/UPA_all15.graph.A01.par -g /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/baseGraphA01 -o /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/baseGraphA01.UPA_all15.A01.out -d /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/baseGraphA01.UPA_all15.A01.dot
# 'Running qpGraph -p /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/UPA_all15.graph.A01.par -g /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/baseGraphA01 -o /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/baseGraphA01.UPA_all15.A01.out -d /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/baseGraphA01.UPA_all15.A01.dot and making ps/pdf file'

# %%
# %%writefile /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A01_oneattime.py
#import TY_maindata as md
import projmodules as pm
import multiprocessing
from multiprocessing import Pool


def do_work(myvars):
    pD,fh,subset,pop1,basegraphname=myvars
    wanttoadd = [pop1,pop1]
    pm.graph_addnode_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    return "done "+basegraphname

pD = "/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/"
outpd="/mnt/solexa/mel_yang/data/2.2M/"
fh = 'UPA_all15'
subset='mEA'
#basegraphname,pop1,mypool = ('A01','Zongri-a',12)
#basegraphname,pop1,mypool = ('Zongri-a.A01_n3','Han',12)
basegraphname,pop1,mypool = ('Han.Zongri-a.A01_n3_n5','Hejiatai',2)
basegraphname,pop1,mypool = ('Hejiatai.Han.Zongri-a.A01_n3_n5_n6','Zongri-b',8)
basegraphname,pop1,mypool = ('Hejiatai.Han.Zongri-a.A01_n3_n5_f20','Zongri-b',8)
basegraphname,pop1,mypool = ('Zongri-b.Hejiatai.Han.Zongri-a.A01_n3_n5_f20_f39','Daxiang0',4)
#basegraphname,pop1,mypool = ('Zongri-b.Hejiatai.Han.Zongri-a.A01_n3_n5_f20_f40','Daxiang0',4)
#basegraphname,pop1,mypool = ('Zongri-b.Hejiatai.Han.Zongri-a.A01_n3_n5_f20_f41','Daxiang0',4)
basegraphname,pop1,mypool = ('Zongri-b.Hejiatai.Han.Zongri-a.A01_n3_n5_f20_f43','Daxiang0',8)
#basegraphname,pop1,mypool = ('Zongri-b.Hejiatai.Han.Zongri-a.A01_n3_n5_f20_f44','Daxiang0',8)
basegraphname,pop1,mypool = ('Zongri-b.Hejiatai.Han.Zongri-a.A01_n3_n5_n6_f39','Daxiang0',6)
basegraphname,pop1,mypool = ('Zongri-b.Hejiatai.Han.Zongri-a.A01_n3_n5_n6_f40','Daxiang0',6)
basegraphname,pop1,mypool = ('Zongri-b.Hejiatai.Han.Zongri-a.A01_n3_n5_n6_f41','Daxiang0',6)
pm.graph_addnode_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
# Out:
# Overwriting /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A01_oneattime.py

# %%
import projmodules as pm
pD = "/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A02/"
outpd="/mnt/solexa/mel_yang/data/2.2M/"
fh = 'UPA_all15'
subset = 'A02'
basegraphname = 'basegraphA02'

baselabels = [['Mbuti','Mbuti'],['Kostenki14','Kostenki14'],['Tianyuan','Tianyuan'],['Vestonice16','Vestonice16']]
baseedges = [['rm','R','Mbuti'],['rn','R','NA'],['nk','NA','EUR'],
             ['nt','NA','Tianyuan'],['ek','EUR','Kostenki14'],['ev','EUR','Vestonice16']]
baseadmixes = []

#pm.graph_par(pD,fh,subset,outpop='Mbuti',outpd="/mnt/solexa/mel_yang/data/2.2M/")
#pm.graph_mkgraph(pD,basegraphname,baselabels,baseedges,baseadmixes,comments='NA')
pm.graph_runfile(basegraphname,pD,fh,subset,outpop='Mbuti',outpd=outpd)
# Out:
# qpGraph -p /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A02/UPA_all15.graph.A02.par -g /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A02/basegraphA02 -o /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A02/basegraphA02.UPA_all15.A02.out -d /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A02/basegraphA02.UPA_all15.A02.dot
# 'Running qpGraph -p /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A02/UPA_all15.graph.A02.par -g /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A02/basegraphA02 -o /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A02/basegraphA02.UPA_all15.A02.out -d /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A02/basegraphA02.UPA_all15.A02.dot and making ps/pdf file'

# %%
# %%writefile /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A02_oneattime.py
#import TY_maindata as md
import projmodules as pm
import multiprocessing
from multiprocessing import Pool


def do_work(myvars):
    pD,fh,subset,pop1,basegraphname=myvars
    wanttoadd = [pop1,pop1]
    pm.graph_addnode_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    return "done "+basegraphname

pD = "/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A02/"
outpd="/mnt/solexa/mel_yang/data/2.2M/"
fh = 'UPA_all15'
subset='mEA'
basegraphname,pop1,mypool = ('A02','Han',12)
basegraphname,pop1,mypool = ('Han.A02_n3','Onge',3)
#basegraphname,pop1,mypool = ('Han.A02_f6','Onge',3)
basegraphname,pop1,mypool = ('A02','Zongri-a',3)
basegraphname,pop1,mypool = ('Zongri-a.A02_n3','Hejiatai',3)
basegraphname,pop1,mypool = ('Hejiatai.Zongri-a.A02_n3_n7','Chokhopani',4)
basegraphname,pop1,mypool = ('A02','Atayal',3)
#basegraphname,pop1,mypool = ('Zongri-a.A02_n3','Man_Bac',3)
basegraphname,pop1,mypool = ('Atayal.A02_n3','Onge',4)
basegraphname,pop1,mypool = ('Chokhopani.Hejiatai.Zongri-a.A02_n3_n7_n7','PukagongmaM5',4)
basegraphname,pop1,mypool = ('Onge.Atayal.A02_n3_f12','Zongri-a',8)
basegraphname,pop1,mypool = ('Zongri-a.Onge.Atayal.A02_n3_f12_n9','Hejiatai',4)
basegraphname,pop1,mypool = ('Zongri-a.Onge.Atayal.A02_n3_f12_n9','Han',4)
basegraphname,pop1,mypool = ('PukagongmaM5.Chokhopani.Hejiatai.Zongri-a.A02_n3_n7_n7_n7','Han',4)
basegraphname,pop1,mypool = ('Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77','Hejiatai',4)
basegraphname,pop1,mypool = ('Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77','Chokhopani',4)
basegraphname,pop1,mypool = ('Hejiatai.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f56','Han',4)
basegraphname,pop1,mypool = ('Chokhopani.Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77_f116','Hejiatai',4)
basegraphname,pop1,mypool = ('Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77','PukagongmaM5',4)
basegraphname,pop1,mypool = ('Chokhopani.Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77_f116','PukagongmaM5',4)
basegraphname,pop1,mypool = ('Zongri-a.Onge.Atayal.A02_n3_f12_n9','PukagongmaM5',2)
basegraphname,pop1,mypool = ('Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77','QijiapingM104-2',4)
basegraphname,pop1,mypool = ('Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77','Jinchankou0',4)
basegraphname,pop1,mypool = ('Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77','Daxiang0',4)
basegraphname,pop1,mypool = ('Daxiang0.Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77_n14','RedilongM3',12)


pm.graph_addnode_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
# Out:
# Overwriting /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A02_oneattime.py

# %%
import projmodules as pm
pd="/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A02/"  
#pd="/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/" 
subset="mEA"
fh="UPA_all15"

myname="Han.A02"
myname="Zongri-b.Hejiatai.Han.Zongri-a.A01_n3_n5_n6"
myname="Hejiatai.Zongri-a.A02_n3"
myname="Atayal.A02"
myname="PukagongmaM5.Chokhopani.Hejiatai.Zongri-a.A02_n3_n7_n7"
myname="Han.Hejiatai.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f56"
myname="PukagongmaM5.Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77"
myname="QijiapingM104-2.Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77"
#myname="Chokhopani.Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77"
myname="PukagongmaM5.Chokhopani.Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77_f116"
myname="Daxiang0.Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77"

mydat = pm.graph_getidsig(pd,myname,zscorecutoff=3) 
print len(mydat)
for i in mydat: 
    print i[0], i[1]
    if 'n' in i[0]: pm.graph_retrieveinfo(i,pd,subset,fh,myname)
# Out:
# 31
# n12 -2.702
# n14 -2.702
# f25 -2.238
# f11 -2.702
# f27 -2.236
# f13 -2.702
# f40 -2.490
# f50 -2.217
# f52 -2.217
# f38 -2.490
# f61 -2.702
# f73 -2.702
# f63 -2.702
# f80 -2.702
# f88 -2.702
# f82 -2.702
# f90 -2.702
# f71 -2.702
# f97 -2.702
# f112 -2.702
# f95 -2.702
# f106 -2.702
# f114 -2.702
# f101 -2.702
# f115 -2.702
# f116 -2.702
# f108 -2.702
# f103 -2.702
# f117 -2.702
# f110 -2.702
# f119 -2.702

# %% [markdown]
# ## A03

# %%
# %%writefile /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A03_oneattime.py
#import TY_maindata as md
import projmodules as pm
import multiprocessing
from multiprocessing import Pool


def do_work(myvars):
    pD,fh,subset,pop1,basegraphname=myvars
    wanttoadd = [pop1,pop1]
    pm.graph_addnode_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    return "done "+basegraphname

pD = "/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A03/"
outpd="/mnt/solexa/mel_yang/data/2.2M/"
fh = 'UPA_all15'
subset='mEA'


basegraphname,pop1,mypool = ('A02','Han',12)
basegraphname,pop1,mypool = ('Han.A02_n3','Onge',3)
#basegraphname,pop1,mypool = ('Han.A02_f6','Onge',3)
basegraphname,pop1,mypool = ('A02','Zongri-a',3)
basegraphname,pop1,mypool = ('Zongri-a.A02_n3','Hejiatai',3)
basegraphname,pop1,mypool = ('Hejiatai.Zongri-a.A02_n3_n7','Chokhopani',4)
basegraphname,pop1,mypool = ('A02','Atayal',3)
#basegraphname,pop1,mypool = ('Zongri-a.A02_n3','Man_Bac',3)
basegraphname,pop1,mypool = ('Atayal.A02_n3','Onge',4)
basegraphname,pop1,mypool = ('Chokhopani.Hejiatai.Zongri-a.A02_n3_n7_n7','PukagongmaM5',4)
basegraphname,pop1,mypool = ('Onge.Atayal.A02_n3_f12','Zongri-a',8)
basegraphname,pop1,mypool = ('Zongri-a.Onge.Atayal.A02_n3_f12_n9','Hejiatai',4)
basegraphname,pop1,mypool = ('Zongri-a.Onge.Atayal.A02_n3_f12_n9','Han',4)
basegraphname,pop1,mypool = ('PukagongmaM5.Chokhopani.Hejiatai.Zongri-a.A02_n3_n7_n7_n7','Han',4)
basegraphname,pop1,mypool = ('Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77','Hejiatai',4)
basegraphname,pop1,mypool = ('Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77','Chokhopani',4)
basegraphname,pop1,mypool = ('Hejiatai.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f56','Han',4)
basegraphname,pop1,mypool = ('Chokhopani.Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77_f116','Hejiatai',4)
basegraphname,pop1,mypool = ('Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77','PukagongmaM5',4)
basegraphname,pop1,mypool = ('Chokhopani.Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77_f116','PukagongmaM5',4)
basegraphname,pop1,mypool = ('Zongri-a.Onge.Atayal.A02_n3_f12_n9','PukagongmaM5',2)
basegraphname,pop1,mypool = ('Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77','QijiapingM104-2',4)
basegraphname,pop1,mypool = ('Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77','Jinchankou0',4)

basegraphname,pop1,mypool = ('A03','Atayal',4)
pm.graph_addnode_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
# Out:
# Overwriting /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A03_oneattime.py

# %%
import projmodules as pm
pd="/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A03/"  
#pd="/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/" 
subset="mEA"
fh="UPA_all15"

myname="Atayal.A03"

mydat = pm.graph_getidsig(pd,myname,zscorecutoff=4) 
print len(mydat)
for i in mydat: 
    print i[0], i[1]
    if 'n' in i[0]: pm.graph_retrieveinfo(i,pd,subset,fh,myname)
# Out:
# 1
# f13 3.712

# %%
# %%writefile /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A04_oneattime.py
#import TY_maindata as md
import projmodules as pm
import multiprocessing
from multiprocessing import Pool


def do_work(myvars):
    pD,fh,subset,pop1,basegraphname=myvars
    wanttoadd = [pop1,pop1]
    pm.graph_addnode_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    return "done "+basegraphname

pD = "/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A04/"
outpd="/mnt/solexa/mel_yang/data/2.2M/"
fh = 'UPA_all15'
subset='mEA'


basegraphname,pop1,mypool = ('A02','Han',12)
basegraphname,pop1,mypool = ('Han.A02_n3','Onge',3)
#basegraphname,pop1,mypool = ('Han.A02_f6','Onge',3)
basegraphname,pop1,mypool = ('A02','Zongri-a',3)
basegraphname,pop1,mypool = ('Zongri-a.A02_n3','Hejiatai',3)
basegraphname,pop1,mypool = ('Hejiatai.Zongri-a.A02_n3_n7','Chokhopani',4)
basegraphname,pop1,mypool = ('A02','Atayal',3)
#basegraphname,pop1,mypool = ('Zongri-a.A02_n3','Man_Bac',3)
basegraphname,pop1,mypool = ('Atayal.A02_n3','Onge',4)
basegraphname,pop1,mypool = ('Chokhopani.Hejiatai.Zongri-a.A02_n3_n7_n7','PukagongmaM5',4)
basegraphname,pop1,mypool = ('Onge.Atayal.A02_n3_f12','Zongri-a',8)
basegraphname,pop1,mypool = ('Zongri-a.Onge.Atayal.A02_n3_f12_n9','Hejiatai',4)
basegraphname,pop1,mypool = ('Zongri-a.Onge.Atayal.A02_n3_f12_n9','Han',4)
basegraphname,pop1,mypool = ('PukagongmaM5.Chokhopani.Hejiatai.Zongri-a.A02_n3_n7_n7_n7','Han',4)
basegraphname,pop1,mypool = ('Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77','Hejiatai',4)
basegraphname,pop1,mypool = ('Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77','Chokhopani',4)
basegraphname,pop1,mypool = ('Hejiatai.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f56','Han',4)
basegraphname,pop1,mypool = ('Chokhopani.Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77_f116','Hejiatai',4)
basegraphname,pop1,mypool = ('Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77','PukagongmaM5',4)
basegraphname,pop1,mypool = ('Chokhopani.Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77_f116','PukagongmaM5',4)
basegraphname,pop1,mypool = ('Zongri-a.Onge.Atayal.A02_n3_f12_n9','PukagongmaM5',2)
basegraphname,pop1,mypool = ('Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77','QijiapingM104-2',4)
basegraphname,pop1,mypool = ('Han.Zongri-a.Onge.Atayal.A02_n3_f12_n9_f77','Jinchankou0',4)

basegraphname,pop1,mypool = ('A04','Yana_old',4)
basegraphname,pop1,mypool = ('Yana_old.A04_f5','Zongri-a',4)
basegraphname,pop1,mypool = ('Zongri-a.Yana_old.A04_f5_n3','Onge',4)
basegraphname,pop1,mypool = ('Zongri-a.Yana_old.A04_f5_n5','Onge',4)
basegraphname,pop1,mypool = ('Yana_old.A04_f5','Onge',8)
basegraphname,pop1,mypool = ('Onge.Yana_old.A04_f5_n3','Atayal',6)
basegraphname,pop1,mypool = ('Onge.Yana_old.A04_f5_n5','Atayal',6)
basegraphname,pop1,mypool = ('Atayal.Onge.Yana_old.A04_f5_n3_n8','Zongri-a',12)
basegraphname,pop1,mypool = ('Onge.Zongri-a.Yana_old.A04_f5_n5_f14','Hejiatai',4)
#basegraphname,pop1,mypool = ('Onge.Zongri-a.Yana_old.A04_f5_n5_f14','Atayal',4)
#basegraphname,pop1,mypool = ('Onge.Zongri-a.Yana_old.A04_f5_n5_f14','PukagongmaM5',4)
basegraphname,pop1,mypool = ('Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10','Hejiatai',12)
basegraphname,pop1,mypool = ('Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10','Daxiang0',12)
basegraphname,pop1,mypool = ('Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12','Chokhopani',6)
#basegraphname,pop1,mypool = ('Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12','PukagongmaM5',6)
basegraphname,pop1,mypool = ('Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12','RedilongM3',12)
basegraphname,pop1,mypool = ('Chokhopani.Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12_n13','RedilongM3',6)
#basegraphname,pop1,mypool = ('Chokhopani.Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12_n13','PukagongmaM5',6)
#basegraphname,pop1,mypool = ('PukagongmaM5.Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12_n15','Chokhopani',6)
#basegraphname,pop1,mypool = ('PukagongmaM5.Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12_n14','Chokhopani',6)
basegraphname,pop1,mypool = ('Chokhopani.PukagongmaM5.Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12_n15_n13','Han',12)
basegraphname,pop1,mypool = ('PukagongmaM5.Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12_n15','Han',12)
basegraphname,pop1,mypool = ('Han.PukagongmaM5.Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12_n15_f138','Chokhopani',12)
basegraphname,pop1,mypool = ('Han.PukagongmaM5.Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12_n15_f138','RedilongM3',12)
basegraphname,pop1,mypool = ('Chokhopani.Han.PukagongmaM5.Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12_n15_f138_f206','CaixiutangJ2-13',12)
#basegraphname,pop1,mypool = ('RedilongM3.Han.PukagongmaM5.Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12_n15_f138_f199','Chokhopani',12)
basegraphname,pop1,mypool = ('Chokhopani.Han.PukagongmaM5.Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12_n15_f138_f206','Mebrak',12)
basegraphname,pop1,mypool = ('Chokhopani.Han.PukagongmaM5.Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12_n15_f138_f206','Jinchankou0',12)

basegraphname,pop1,mypool = ('PukagongmaM5.Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12_n14','Han',12)
basegraphname,pop1,mypool = ('Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10','Han',12)
basegraphname,pop1,mypool = ('Han.PukagongmaM5.Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12_n14_f139','Chokhopani',12)
basegraphname,pop1,mypool = ('Han.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_f90','PukagongmaM5',12)
basegraphname,pop1,mypool = ('PukagongmaM5.Han.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_f90_n14','Chokhopani',12)
basegraphname,pop1,mypool = ('Zongri-a.Yana_old.A04_f5_n5','Atayal',12)
basegraphname,pop1,mypool = ('Atayal.Zongri-a.Yana_old.A04_f5_n5_n8','PukagongmaM5',12) ##also try f14
basegraphname,pop1,mypool = ('Atayal.Zongri-a.Yana_old.A04_f5_n5_f14','PukagongmaM5',12)
basegraphname,pop1,mypool = ('PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9','Chokhopani',12) #also try Han
basegraphname,pop1,mypool = ('PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9','Han',12) #f72 best
basegraphname,pop1,mypool = ('Han.PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f72','Chokhopani',12)
basegraphname,pop1,mypool = ('Chokhopani.PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_n10','Han',12) #f72 best
basegraphname,pop1,mypool = ('Chokhopani.Han.PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f72_f116','RedilongM3',12)
basegraphname,pop1,mypool = ('Han.Chokhopani.PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_n10_f94','RedilongM3',12)

basegraphname,pop1,mypool = ('RedilongM3.Han.Chokhopani.PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_n10_f94_f124','Jinchankou0',12)
basegraphname,pop1,mypool = ('RedilongM3.Chokhopani.Han.PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f72_f116_f139','Jinchankou0',12)

basegraphname,pop1,mypool = ('RedilongM3.Chokhopani.Han.PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f72_f116_f139','Daxiang0',12)
basegraphname,pop1,mypool = ('Jinchankou0.RedilongM3.Chokhopani.Han.PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f72_f116_f139_f221','CaixiutangJ2-13',12)
basegraphname,pop1,mypool = ('Daxiang0.RedilongM3.Chokhopani.Han.PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f72_f116_f139_n17','Jinchankou0',12)

basegraphname,pop1,mypool = ('Chokhopani.Han.PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f72_f116','Butaxiongqu',12)
basegraphname,pop1,mypool = ('Jinchankou0.RedilongM3.Chokhopani.Han.PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f72_f116_f139_f221','Mixe',6)
basegraphname,pop1,mypool = ('Atayal.Zongri-a.Yana_old.A04_f5_n5_n8','Butaxiongqu',12)
basegraphname,pop1,mypool = ('Butaxiongqu.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9','RedilongM3',12)
basegraphname,pop1,mypool = ('Butaxiongqu.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9','Han',12)
basegraphname,pop1,mypool = ('RedilongM3.Butaxiongqu.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_n12','Daxiang0',12)
basegraphname,pop1,mypool = ('Han.Butaxiongqu.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f74','Daxiang0',12)
basegraphname,pop1,mypool = ('Daxiang0.Han.Butaxiongqu.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f74_n10','Chokhopani',12)
basegraphname,pop1,mypool = ('Daxiang0.RedilongM3.Butaxiongqu.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_n12_n11','Chokhopani',12)
basegraphname,pop1,mypool = ('Chokhopani.Daxiang0.Han.Butaxiongqu.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f74_n10_f121','RedilongM3',4)
#basegraphname,pop1,mypool = ('Chokhopani.Daxiang0.Han.Butaxiongqu.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f74_n10_f121','Jinchankou0',4)
#basegraphname,pop1,mypool = ('Chokhopani.Daxiang0.Han.Butaxiongqu.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f74_n10_f121','Wuba',4)
basegraphname,pop1,mypool = ('Han.Butaxiongqu.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f74','Wuba',7)

pm.graph_addnode_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
# Out:
# Overwriting /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A04_oneattime.py

# %%
import projmodules as pm
pd="/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A04/"  
outpd="/mnt/solexa/mel_yang/data/2.2M/"
subset='mEA'
fh="UPA_all15"

myname="Zongri-a.Atayal.Onge.Yana_old.A04_f5_n3_n8"
myname="Chokhopani.RedilongM3.Han.PukagongmaM5.Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12_n15_f138_f199"
myname="Han.PukagongmaM5.Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12_n14"
myname="PukagongmaM5.Han.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_f90"
myname="Chokhopani.Han.PukagongmaM5.Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12_n14_f139"
myname="Atayal.Zongri-a.Yana_old.A04_f5_n5"
myname="Chokhopani.PukagongmaM5.Han.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_f90_n14"
myname="Han.Chokhopani.PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_n10" 
myname="RedilongM3.Han.Chokhopani.PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_n10_f94" 
myname="Jinchankou0.RedilongM3.Chokhopani.Han.PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f72_f116_f139"
#myname="Jinchankou0.RedilongM3.Han.Chokhopani.PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_n10_f94_f124" 
myname="Daxiang0.RedilongM3.Chokhopani.Han.PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f72_f116_f139"
myname="CaixiutangJ2-13.Jinchankou0.RedilongM3.Chokhopani.Han.PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f72_f116_f139_f221"
myname="Mixe.Jinchankou0.RedilongM3.Chokhopani.Han.PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f72_f116_f139_f221"
#myname="Butaxiongqu.Chokhopani.Han.PukagongmaM5.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f72_f116"
#myname="Butaxiongqu.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8"
myname="Han.Butaxiongqu.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9"
myname="Daxiang0.Han.Butaxiongqu.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f74"
myname="Daxiang0.RedilongM3.Butaxiongqu.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_n12"
myname="Chokhopani.Daxiang0.Han.Butaxiongqu.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f74_n10"
myname="Chokhopani.Daxiang0.RedilongM3.Butaxiongqu.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_n12_n11"
myname="Wuba.Chokhopani.Daxiang0.Han.Butaxiongqu.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f74_n10_f121"
myname="Wuba.Han.Butaxiongqu.Atayal.Zongri-a.Yana_old.A04_f5_n5_n8_n9_f74"


mydat = pm.graph_getidsig(pd,myname,zscorecutoff=3) 
print len(mydat)
for i in mydat: 
    print i[0], i[1]
    if 'n' in i[0]: pm.graph_retrieveinfo(i,pd,subset,fh,myname)
# Out:
# 12
# f100 2.857
# f102 2.892
# f104 2.293
# f105 2.833
# f110 2.626
# f116 2.292
# f107 2.828
# f112 2.668
# f117 2.688
# f109 -2.185
# f119 2.620
# f114 2.631

# %%
# %%writefile /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/mEA_subEAspooled.py
from multiprocessing import Pool
import projmodules as pm
pD="/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A04/"  
outpd="/mnt/solexa/mel_yang/data/2.2M/"
fh = 'UPA_all15'
subset='mEA'

low1=["Hejiatai","Hedong6","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11",
      "Shangluzhuang0","Hupo-a"]#"XiahaishiM22",

def dowork(mytups):
    pd,fh,subset,basegraphname,oldpop,newpop,outpd=mytups
    pm.graph_substitute_uniq(pD,fh,subset,basegraphname,oldpop,newpop,comments='NA',outpop="Mbuti",outpd=outpd)
    
getrid=['Daxiang0']
myhandle="Chokhopani.Han.PukagongmaM5.Daxiang0.Atayal.Onge.Zongri-a.Yana_old.A04_f5_n5_f14_n10_n12_n15_f138_f206"
myinputs = [(pD,fh,subset,myhandle,getrid[0],i,outpd) for i in low1 if i not in getrid]
#for i in myinputs: print i
#print len(eas), len(myinputs)
mypool = Pool(10)
results = mypool.map(dowork, myinputs)
# Out:
# Overwriting /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/mEA_subEAspooled.py

# %%
# %%writefile /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A05_oneattime.py
#import TY_maindata as md
import projmodules as pm
import multiprocessing
from multiprocessing import Pool


def do_work(myvars):
    pD,fh,subset,pop1,basegraphname=myvars
    wanttoadd = [pop1,pop1]
    pm.graph_addnode_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    return "done "+basegraphname

pD = "/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A05/"
outpd="/mnt/solexa/mel_yang/data/2.2M/"
fh = 'UPA_all15'
subset='mEA'

basegraphname,pop1,mypool = ('A05','Zongri-a',6)
basegraphname,pop1,mypool = ('Zongri-a.A05_n2','Atayal',6)
basegraphname,pop1,mypool = ('Atayal.Zongri-a.A05_n2_n5','PukagongmaM5',6)
basegraphname,pop1,mypool = ('PukagongmaM5.Atayal.Zongri-a.A05_n2_n5_n6','Han',6)
basegraphname,pop1,mypool = ('Han.PukagongmaM5.Atayal.Zongri-a.A05_n2_n5_n6_f39','Chokhopani',6)

pm.graph_addnode_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
# Out:
# Overwriting /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A05_oneattime.py

# %%
import projmodules as pm
pd="/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A05/"  
outpd="/mnt/solexa/mel_yang/data/2.2M/"
subset='mEA'
fh="UPA_all15"

myname="Zongri-a.A05"
myname="Han.PukagongmaM5.Atayal.Zongri-a.A05_n2_n5_n6"
mydat = pm.graph_getidsig(pd,myname,zscorecutoff=3) 
print len(mydat)
for i in mydat: 
    print i[0], i[1]
    if 'n' in i[0]: pm.graph_retrieveinfo(i,pd,subset,fh,myname)
# Out:
# 3
# f40 2.072
# f41 -2.932
# f39 2.072

# %%
# %%writefile /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A06_oneattime.py
#import TY_maindata as md
import projmodules as pm
import multiprocessing
from multiprocessing import Pool


def do_work(myvars):
    pD,fh,subset,pop1,basegraphname=myvars
    wanttoadd = [pop1,pop1]
    pm.graph_addnode_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    return "done "+basegraphname

pD = "/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A06/"
outpd="/mnt/solexa/mel_yang/data/2.2M/"
fh = 'UPA_all15'
subset='mEA'

##Came from A04, copied to A06
basegraphname,pop1,mypool = ('A04','Yana_old',4)
basegraphname,pop1,mypool = ('Yana_old.A06_f5','Kolyma_River',4) 
basegraphname,pop1,mypool = ('Kolyma_River.Yana_old.A06_f5_n5','Zongri-a',12)
basegraphname,pop1,mypool = ('Yana_old.A06_f5','Zongri-a',13) 
basegraphname,pop1,mypool = ('Kolyma_River.Yana_old.A06_f5_n5','Atayal',13)
basegraphname,pop1,mypool = ('Yana_old.A06_f5','Atayal',13)
basegraphname,pop1,mypool = ('Atayal.Yana_old.A06_f5_n3','Mixe',7)
#basegraphname,pop1,mypool = ('Atayal.Yana_old.A06_f5_n5','Mixe',6)
basegraphname,pop1,mypool = ('Mixe.Atayal.Yana_old.A06_f5_n5_f32','Zongri-a',13)

basegraphname,pop1,mypool = ('Zongri-a.Yana_old.A06_f5_n3','Daxiang0',7) 
#basegraphname,pop1,mypool = ('Zongri-a.Yana_old.A06_f5_n5','Daxiang0',7)
#basegraphname,pop1,mypool = ('Zongri-a.Yana_old.A06_f5_n3','Han',7) 
#basegraphname,pop1,mypool = ('Zongri-a.Yana_old.A06_f5_n5','Han',7)

basegraphname,pop1,mypool = ('Zongri-a.Yana_old.A06_f5_n3','Atayal',14)
basegraphname,pop1,mypool = ('Zongri-a.Yana_old.A06_f5_n5','Atayal',14)

basegraphname,pop1,mypool = ('Atayal.Zongri-a.Yana_old.A06_f5_n3_n8','Daxiang0',7)
#basegraphname,pop1,mypool = ('Atayal.Zongri-a.Yana_old.A06_f5_n3_n8','Han',7)
basegraphname,pop1,mypool = ('Atayal.Zongri-a.Yana_old.A06_f5_n5_n8','Daxiang0',7)
#basegraphname,pop1,mypool = ('Atayal.Zongri-a.Yana_old.A06_f5_n5_n8','Han',7)
#basegraphname,pop1,mypool = ('Atayal.Yana_old.A06_f5_n3','Zongri-a',3)
#basegraphname,pop1,mypool = ('Atayal.Yana_old.A06_f5_n3','Han',4)

basegraphname,pop1,mypool = ('Daxiang0.Atayal.Zongri-a.Yana_old.A06_f5_n3_n8_n9','Butaxiongqu',7)
#basegraphname,pop1,mypool = ('Daxiang0.Atayal.Zongri-a.Yana_old.A06_f5_n5_n8_n9','Butaxiongqu',7)
basegraphname,pop1,mypool = ('Han.Atayal.Zongri-a.Yana_old.A06_f5_n3_n8_f54','Butaxiongqu',7)
basegraphname,pop1,mypool = ('Han.Atayal.Zongri-a.Yana_old.A06_f5_n5_n8_f54','Butaxiongqu',7)
basegraphname,pop1,mypool = ('Han.Atayal.Yana_old.A06_f5_n3_n8','Zongri-a',7) ##none works
basegraphname,pop1,mypool = ('Han.Atayal.Yana_old.A06_f5_n3_f35','Zongri-a',7)
basegraphname,pop1,mypool = ('Han.Atayal.Zongri-a.Yana_old.A06_f5_n5_n8_f54','Chokhopani',7) 
#basegraphname,pop1,mypool = ('Han.Atayal.Zongri-a.Yana_old.A06_f5_n3_n8_f54','Chokhopani',14)
#basegraphname,pop1,mypool = ('Chokhopani.Han.Atayal.Zongri-a.Yana_old.A06_f5_n3_n8_f54_f84','Butaxiongqu',14)
#basegraphname,pop1,mypool = ('Chokhopani.Han.Atayal.Zongri-a.Yana_old.A06_f5_n3_n8_f54_f84','Daxiang0',14)
basegraphname,pop1,mypool = ('Daxiang0.Chokhopani.Han.Atayal.Zongri-a.Yana_old.A06_f5_n3_n8_f54_f84_n10','Butaxiongqu',14)
basegraphname,pop1,mypool = ('Daxiang0.Chokhopani.Han.Atayal.Zongri-a.Yana_old.A06_f5_n3_n8_f54_f84_n14','Butaxiongqu',14)

basegraphname,pop1,mypool = ('Butaxiongqu.Daxiang0.Chokhopani.Han.Atayal.Zongri-a.Yana_old.A06_f5_n3_n8_f54_f84_n10_n16','RedilongM3',14)
basegraphname,pop1,mypool = ('RedilongM3.Butaxiongqu.Daxiang0.Chokhopani.Han.Atayal.Zongri-a.Yana_old.A06_f5_n3_n8_f54_f84_n10_n16_n20','Wuba',14)
basegraphname,pop1,mypool = ('RedilongM3.Butaxiongqu.Daxiang0.Chokhopani.Han.Atayal.Zongri-a.Yana_old.A06_f5_n3_n8_f54_f84_n10_n16_n20','Jinchankou0',7)
basegraphname,pop1,mypool = ('Wuba.RedilongM3.Butaxiongqu.Daxiang0.Chokhopani.Han.Atayal.Zongri-a.Yana_old.A06_f5_n3_n8_f54_f84_n10_n16_n20_f202','Jinchankou0',14)

pm.graph_addnode_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
# Out:
# Overwriting /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A06_oneattime.py

# %%
import projmodules as pm
pd="/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A06/"  
outpd="/mnt/solexa/mel_yang/data/2.2M/"
subset='mEA'
fh="UPA_all15"

myname="Kolyma_River.Yana_old.A06_f5"
#myname="Zongri-a.Kolyma_River.Yana_old.A06_f5_n5"
myname="Zongri-a.Yana_old.A06_f5"
#myname="Mixe.Atayal.Yana_old.A06_f5_n3"
#myname="Zongri-a.Mixe.Atayal.Yana_old.A06_f5_n5_f32"
myname="Daxiang0.Zongri-a.Yana_old.A06_f5_n3"
myname="Daxiang0.Zongri-a.Yana_old.A06_f5_n5"
#myname="Han.Zongri-a.Yana_old.A06_f5_n3"
#myname="Han.Zongri-a.Yana_old.A06_f5_n5"
myname="Atayal.Zongri-a.Yana_old.A06_f5_n3"
myname="Atayal.Zongri-a.Yana_old.A06_f5_n5"
myname="Han.Atayal.Zongri-a.Yana_old.A06_f5_n3_n8"
myname="Han.Atayal.Yana_old.A06_f5_n3"
myname="Butaxiongqu.Han.Atayal.Zongri-a.Yana_old.A06_f5_n3_n8_f54"
myname="Butaxiongqu.Daxiang0.Atayal.Zongri-a.Yana_old.A06_f5_n3_n8_n9"
myname="Han.Atayal.Zongri-a.Yana_old.A06_f5_n5_n8"
myname="Daxiang0.Chokhopani.Han.Atayal.Zongri-a.Yana_old.A06_f5_n3_n8_f54_f84"
myname="RedilongM3.Butaxiongqu.Daxiang0.Chokhopani.Han.Atayal.Zongri-a.Yana_old.A06_f5_n3_n8_f54_f84_n10_n16"
myname="Wuba.RedilongM3.Butaxiongqu.Daxiang0.Chokhopani.Han.Atayal.Zongri-a.Yana_old.A06_f5_n3_n8_f54_f84_n10_n16_n20"

mydat = pm.graph_getidsig(pd,myname,zscorecutoff=3) 
print len(mydat)
for i in mydat: 
    print i[0], i[1]
    if 'n' in i[0]: pm.graph_retrieveinfo(i,pd,subset,fh,myname)
# Out:
# 3
# f202 2.810
# f226 -2.718
# f219 2.764

# %%
# %%writefile /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A07_oneattime.py
#import TY_maindata as md
import projmodules as pm
import multiprocessing
from multiprocessing import Pool


def do_work(myvars):
    pD,fh,subset,pop1,basegraphname=myvars
    wanttoadd = [pop1,pop1]
    pm.graph_addnode_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    return "done "+basegraphname

pD = "/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A07/"
outpd="/mnt/solexa/mel_yang/data/2.2M/"
fh = 'UPA16'
subset='mEA'

##Came from Yana_old.A06_f5, copied to A07
basegraphname,pop1,mypool = ('A07','La368_G1',14)
basegraphname,pop1,mypool = ('La368_G1.A07_n5','IK002_Jomon',14)
basegraphname,pop1,mypool = ('IK002_Jomon.La368_G1.A07_n5_n8','Atayal',7)
#basegraphname,pop1,mypool = ('IK002_Jomon.La368_G1.A07_n5_n8','Han',7)
basegraphname,pop1,mypool = ('Atayal.IK002_Jomon.La368_G1.A07_n5_n8_n10','Han',14) ##None
#basegraphname,pop1,mypool = ('Han.IK002_Jomon.La368_G1.A07_n5_n8_f51','Zongri-a',14)
#basegraphname,pop1,mypool = ('Han.IK002_Jomon.La368_G1.A07_n5_n8_f51','Atayal',7)
basegraphname,pop1,mypool = ('Atayal.IK002_Jomon.La368_G1.A07_n5_n8_n10','Zongri-a',14) ## None
basegraphname,pop1,mypool = ('Atayal.Han.IK002_Jomon.La368_G1.A07_n5_n8_f51_n13','Zongri-a',14)
basegraphname,pop1,mypool = ('IK002_Jomon.La368_G1.A07_n5_n8','Zongri-a',14)
basegraphname,pop1,mypool = ('La368_G1.A07_n5','Zongri-a',14)
basegraphname,pop1,mypool = ('Zongri-a.La368_G1.A07_n5_n7','Han',14)
basegraphname,pop1,mypool = ('Atayal.IK002_Jomon.La368_G1.A07_n5_n8_f51','Zongri-a',14)

basegraphname,pop1,mypool = ('Han.Zongri-a.La368_G1.A07_n5_n7_f51','Butaxiongqu',7)
#basegraphname,pop1,mypool = ('Han.Zongri-a.La368_G1.A07_n5_n7_f51','PukagongmaM5',7)
#basegraphname,pop1,mypool = ('Han.Zongri-a.La368_G1.A07_n5_n7_f51','Daxiang0',7)

basegraphname,pop1,mypool = ('Butaxiongqu.Han.Zongri-a.La368_G1.A07_n5_n7_f51_n10','Chokhopani',14)
basegraphname,pop1,mypool = ('Butaxiongqu.Han.Zongri-a.La368_G1.A07_n5_n7_f51_n12','Chokhopani',14)
basegraphname,pop1,mypool = ('Butaxiongqu.Han.Zongri-a.La368_G1.A07_n5_n7_f51_n13','Chokhopani',7)
basegraphname,pop1,mypool = ('Han.Zongri-a.La368_G1.A07_n5_n7_f51','',14)
basegraphname,pop1,mypool = ('Butaxiongqu.Han.Zongri-a.La368_G1.A07_n5_n7_f51_n12','Daxiang0',14) #n14,n15
basegraphname,pop1,mypool = ('IK002_Jomon.Han.Zongri-a.La368_G1.A07_n5_n7_f51_f84','Butaxiongqu',14)
basegraphname,pop1,mypool = ('Daxiang0.Butaxiongqu.Han.Zongri-a.La368_G1.A07_n5_n7_f51_n12_n14','Wuba',14)

pm.graph_addnode_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
# Out:
# Overwriting /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A07_oneattime.py

# %%
import projmodules as pm
pd="/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A07/"  
outpd="/mnt/solexa/mel_yang/data/2.2M/"
subset='mEA'
fh="UPA16"

myname="La368_G1.A07"
myname="Atayal.IK002_Jomon.La368_G1.A07_n5_n8"
myname="Zongri-a.Han.IK002_Jomon.La368_G1.A07_n5_n8_f51"
#myname="Han.Atayal.IK002_Jomon.La368_G1.A07_n5_n8_n10"

myname="Zongri-a.Atayal.Han.IK002_Jomon.La368_G1.A07_n5_n8_f51_n13"
myname="Zongri-a.La368_G1.A07_n5"
myname="Zongri-a.IK002_Jomon.La368_G1.A07_n5_n8"
myname="Atayal.IK002_Jomon.La368_G1.A07_n5_n8"
myname="Daxiang0.Butaxiongqu.Han.Zongri-a.La368_G1.A07_n5_n7_f51_n12"
#myname="IK002_Jomon.Han.Zongri-a.La368_G1.A07_n5_n7_f51"
mydat = pm.graph_getidsig(pd,myname,zscorecutoff=3) 
print len(mydat)
for i in mydat: 
    print i[0], i[1]
    if 'n' in i[0]: pm.graph_retrieveinfo(i,pd,subset,fh,myname)
# Out:
# 53
# n10 -2.964
# n13 -2.997
# n14 -2.877
# n15 -2.727
# f27 -2.971
# f36 -2.958
# f39 -2.993
# f40 -2.877
# f13 -2.949
# f28 -2.815
# f14 -2.855
# f41 -2.738
# f48 -2.972
# f63 -2.881
# f69 -2.962
# f72 -2.958
# f78 -2.970
# f81 -2.966
# f73 -2.888
# f64 -2.747
# f52 -2.899
# f82 -2.879
# f91 -2.759
# f62 -2.994
# f53 -2.811
# f59 -2.954
# f83 -2.728
# f74 -2.746
# f90 -2.887
# f93 -2.971
# f96 -2.971
# f99 -2.959
# f102 -2.968
# f105 -2.936
# f108 -2.882
# f111 -2.941
# f114 -2.994
# f117 -2.883
# f97 -2.884
# f118 -2.749
# f106 -2.958
# f115 -2.876
# f112 -2.842
# f109 -2.748
# f103 -2.902
# f98 -2.757
# f116 -2.726
# f113 -2.696
# f107 -2.958
# f119 -2.315
# f86 -2.966
# f89 -2.999
# f104 -2.759

# %%
# %%writefile /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A08_oneattime.py
#import TY_maindata as md
import projmodules as pm
import multiprocessing
from multiprocessing import Pool


def do_work(myvars):
    pD,fh,subset,pop1,basegraphname=myvars
    wanttoadd = [pop1,pop1]
    pm.graph_addnode_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    return "done "+basegraphname

pD = "/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A08/"
outpd="/mnt/solexa/mel_yang/data/2.2M/"
fh = 'UPA16'
subset='mEA'

##Came from A07, copied to A08 and put V16 instead of Yana1
basegraphname,pop1,mypool = ('A08','La368_G1',7)
basegraphname,pop1,mypool = ('La368_G1.A08_n5','Zongri-a',7)
basegraphname,pop1,mypool = ('Zongri-a.La368_G1.A08_n5_n6','Han',14)
basegraphname,pop1,mypool = ('Han.Zongri-a.La368_G1.A08_n5_n6_n9','Zongri-b',14)
basegraphname,pop1,mypool = ('Zongri-b.Han.Zongri-a.La368_G1.A08_n5_n6_n9_f65','Daxiang0',14)
basegraphname,pop1,mypool = ('A08','La368_G1',14)

pm.graph_addnode_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
# Out:
# Overwriting /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A08_oneattime.py

# %%
import projmodules as pm
pd="/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A08/"  
outpd="/mnt/solexa/mel_yang/data/2.2M/"
subset='mEA'
fh="UPA16"

myname="La368_G1.A08"
myname="Zongri-a.La368_G1.A08_n5"
myname="Han.Zongri-a.La368_G1.A08_n5_n6"
myname="Zongri-b.Han.Zongri-a.La368_G1.A08_n5_n6_n9"
myname="Daxiang0.Zongri-b.Han.Zongri-a.La368_G1.A08_n5_n6_n9_f65"
myname="La368_G1.A08"

mydat = pm.graph_getidsig(pd,myname,zscorecutoff=4) 
print len(mydat)
for i in mydat: 
    print i[0], i[1]
    if 'n' in i[0]: pm.graph_retrieveinfo(i,pd,subset,fh,myname)
# Out:
# 6
# n5 1.342
# f4 1.342
# f8 1.342
# f11 1.342
# f13 1.343
# f14 -0.677

# %%
# %%writefile /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A09_oneattime.py
#import TY_maindata as md
import projmodules as pm
import multiprocessing
from multiprocessing import Pool


def do_work(myvars):
    pD,fh,subset,pop1,basegraphname=myvars
    wanttoadd = [pop1,pop1]
    pm.graph_addnode_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    return "done "+basegraphname

pD = "/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A09/"
outpd="/mnt/solexa/mel_yang/data/2.2M/"
fh = 'UPA16'
subset='mEA'

##Came from La368_G1.A08_n5, copied to A09, removed Vestonice16
basegraphname,pop1,mypool = ('A09','Anatolia_N',14)
basegraphname,pop1,mypool = ('A09','Zongri-a',7)
basegraphname,pop1,mypool = ('Zongri-a.A09_n4','Han',14) ##f24, f26 OK
basegraphname,pop1,mypool = ('Han.Zongri-a.A09_n4_n7','Zongri-b',7)
basegraphname,pop1,mypool = ('Han.Zongri-a.A09_n4_n7','Daxiang0',14) #n8, f44, f42, f37,f28 OK
basegraphname,pop1,mypool = ('Daxiang0.Han.Zongri-a.A09_n4_n7_n8','Wuba',14) #n9,10,11,f27,f29,f64,f62 OK
basegraphname,pop1,mypool = ('Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9','Jinchankou0',14) #NA
basegraphname,pop1,mypool = ('Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n11','Jinchankou0',14) #NA
basegraphname,pop1,mypool = ('Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n10','Jinchankou0',1)
basegraphname,pop1,mypool = ('Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_f27','Jinchankou0',1)
basegraphname,pop1,mypool = ('Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_f29','Jinchankou0',1)
#basegraphname,pop1,mypool = ('Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_f64','Jinchankou0',1)
#basegraphname,pop1,mypool = ('Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_f62','Jinchankou0',1)

basegraphname,pop1,mypool = ('Anatolia_N.A09_f5','Zongri-a',7)
basegraphname,pop1,mypool = ('Daxiang0.Han.Zongri-a.A09_n4_n7_f44','Wuba',14) #n12, f41, f32, f71, f77
basegraphname,pop1,mypool = ('Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_f44_n12','Jinchankou0',14) 
basegraphname,pop1,mypool = ('Daxiang0.Han.Zongri-a.A09_n4_n7_f42','Wuba',1)
basegraphname,pop1,mypool = ('Daxiang0.Han.Zongri-a.A09_n4_n7_f37','Wuba',1)
basegraphname,pop1,mypool = ('Daxiang0.Han.Zongri-a.A09_n4_n7_f28','Wuba',1)
#basegraphname,pop1,mypool = ('Han.Zongri-a.A09_n4_f24','Daxiang0',14)
#basegraphname,pop1,mypool = ('Han.Zongri-a.A09_n4_f26','Daxiang0',1)

basegraphname,pop1,mypool = ('Han.Zongri-a.A09_n4_n7','Jinchankou0',14)
basegraphname,pop1,mypool = ('Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_f44_f77','Jinchankou0',14) #NA
basegraphname,pop1,mypool = ('Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_f44_n12','Chokhopani',14) #n8, f54, f53, f86,f93, f101
basegraphname,pop1,mypool = ('Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9','Chokhopani',14)  #n8, f78, f80, f77
basegraphname,pop1,mypool = ('Han.Zongri-a.A09_n4_n7','Sanheyi11',14)

basegraphname,pop1,mypool = ('Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78','RedilongM3',14)
basegraphname,pop1,mypool = ('RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78_f112','Jinchankou0',4)
#basegraphname,pop1,mypool = ('RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78_f112','Zongri-b',4)
#basegraphname,pop1,mypool = ('RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78_f112','QijiapingM89-2',3)
#basegraphname,pop1,mypool = ('RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78_f112','HuoshaogouM117',3)
#basegraphname,pop1,mypool = ('RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78_f112','Butaxiongqu',3)
#basegraphname,pop1,mypool = ('RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78_f112','PukagongmaM5',3)
#basegraphname,pop1,mypool = ('RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78_f112','CaixiutangJ2-13',4)
#basegraphname,pop1,mypool = ('RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78_f112','YushuSGZ-1',4)
basegraphname,pop1,mypool = ('Butaxiongqu.RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78_f112_n19','Zongri-b',14)
basegraphname,pop1,mypool = ('Butaxiongqu.RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78_f112_n19','QijiapingM104-2',14)

basegraphname,pop1,mypool = ('Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_n8','RedilongM3',3)
#basegraphname,pop1,mypool = ('RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78_f112','Sanheyi11',4)
#basegraphname,pop1,mypool = ('Butaxiongqu.RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78_f112_n19','CaixiutangJ2-13',7)
#basegraphname,pop1,mypool = ('Butaxiongqu.RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78_f112_n19','QijiapingM108-2',7)

#basegraphname,pop1,mypool = ('Butaxiongqu.RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78_f112_n19','PukagongmaM5',7)
#basegraphname,pop1,mypool = ('Butaxiongqu.RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78_f112_n19','Jinchankou0',7)

pm.graph_addnode_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
# Out:
# Overwriting /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A09_oneattime.py

# %%
import projmodules as pm
pd="/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A09/"  
outpd="/mnt/solexa/mel_yang/data/2.2M/"
subset='mEA'
fh="UPA16"

myname="Anatolia_N.A09"
#myname="Zongri-a.A09"
myname="Daxiang0.Han.Zongri-a.A09_n4_n7"
myname="Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8"
myname="Jinchankou0.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_f42" #n9,10,11,f27,f29,f64,f62 #None
#myname="Zongri-a.Anatolia_N.A09_f5"
#myname="Han.Zongri-a.A09_n4"
myname="Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_f44" #n8, f44, f42, f37,f28 OK
#myname='Jinchankou0.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_f44_n12'
myname="Jinchankou0.Han.Zongri-a.A09_n4_n7"
myname='Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_f44_n12'
#myname='Jinchankou0.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_f44_f77'
myname="Sanheyi11.Han.Zongri-a.A09_n4_n7"
myname='Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9'
myname='RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78'
myname="Butaxiongqu.RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78_f112"
myname="Jinchankou0.RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78_f112"
myname="CaixiutangJ2-13.Butaxiongqu.RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_f78_f112_n19"
myname='RedilongM3.Chokhopani.Wuba.Daxiang0.Han.Zongri-a.A09_n4_n7_n8_n9_n8'
mydat = pm.graph_getidsig(pd,myname,zscorecutoff=3) 
print len(mydat)
for i in mydat: 
    print i[0], i[1]
    if 'n' in i[0]: pm.graph_retrieveinfo(i,pd,subset,fh,myname)
# Out:
# 70
# f10 -2.666
# n8 -2.667
# n10 -2.971
# n9 -2.667
# n11 -2.667
# n12 -2.971
# f11 -2.971
# f21 -2.574
# f76 -2.572
# f22 -2.558
# f67 -2.543
# f86 -2.971
# f77 -2.571
# f87 -2.504
# f23 -2.971
# f78 -2.971
# f68 -2.524
# f88 -2.971
# f69 -2.971
# f79 -2.572
# f100 -2.655
# f110 -2.669
# f24 -2.574
# f101 -2.655
# f111 -2.572
# f25 -2.971
# f92 -2.666
# f102 -2.416
# f112 -2.599
# f93 -2.572
# f7 -2.666
# f103 -2.429
# f113 2.558
# f8 -2.543
# f94 -2.667
# f104 -2.425
# f114 -2.971
# f95 -2.669
# f9 -2.971
# f105 -2.572
# f115 -2.971
# f96 -2.572
# f50 -2.971
# f106 -2.971
# f116 -2.971
# f97 -2.598
# f107 -2.971
# f98 2.545
# f108 -2.971
# f99 -2.416
# f109 -2.971
# f34 -2.636
# f35 -2.632
# f46 -2.545
# f36 -2.971
# f47 -2.527
# f57 -2.666
# f37 -2.636
# f48 -2.971
# f38 -2.971
# f58 -2.664
# f49 -2.545
# f59 -2.971
# f60 -2.666
# f70 -2.543
# f80 -2.971
# f61 -2.971
# f71 -2.971
# f84 -2.503
# f85 -2.373

# %%
# %%writefile /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A10_oneattime.py
#import TY_maindata as md
import projmodules as pm
import multiprocessing
from multiprocessing import Pool


def do_work(myvars):
    pD,fh,subset,pop1,basegraphname=myvars
    wanttoadd = [pop1,pop1]
    pm.graph_addnode_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    return "done "+basegraphname

pD = "/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A10/"
outpd="/mnt/solexa/mel_yang/data/2.2M/"
fh = 'UPA16'
subset='mEA'

##Came from A10, removed La368_G1
basegraphname,pop1,mypool = ('A10','La368_G1',14)
basegraphname,pop1,mypool = ('La368_G1.A10_n3','Shahr_I_Sokhta_BA2',14)
basegraphname,pop1,mypool = ('Shahr_I_Sokhta_BA2.La368_G1.A10_n3_f11','Zongri-a',14)
basegraphname,pop1,mypool = ('Zongri-a.Shahr_I_Sokhta_BA2.La368_G1.A10_n3_f11_n3','Han',14)
#basegraphname,pop1,mypool = ('Zongri-a.Shahr_I_Sokhta_BA2.La368_G1.A10_n3_f11_f25','Han',14)
basegraphname,pop1,mypool = ('La368_G1.A10_n3','Han',7)
basegraphname,pop1,mypool = ('La368_G1.A10_n3','Ami',7)
basegraphname,pop1,mypool = ('Han.La368_G1.A10_n3_f14','Zongri-a',14) ##n8 f29 f34 OK f35 f20

basegraphname,pop1,mypool = ('Zongri-a.Han.La368_G1.A10_n3_f14_n8',"Daxiang0",14) #n10, f18 (same overlap)
basegraphname,pop1,mypool = ('Zongri-a.Han.La368_G1.A10_n3_f14_f29',"Daxiang0",14) #n11
basegraphname,pop1,mypool = ('Zongri-a.Han.La368_G1.A10_n3_f14_f34',"Daxiang0",7) #n11

basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10',"Wuba",4)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f18',"Wuba",4)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10',"Sanheyi11",3)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f18',"Sanheyi11",3)
basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f29_n11',"Wuba",3)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f29_n11',"Sanheyi11",3)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_n11',"Wuba",2)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_n11',"Sanheyi11",2)
basegraphname,pop1,mypool = ('Sanheyi11.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_n11_n13',"Jinchankou0",7)
#basegraphname,pop1,mypool = ('Sanheyi11.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_n11_n13',"Chokhopani",7)
#basegraphname,pop1,mypool = ('Sanheyi11.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_n12',"Jinchankou0",7)
#basegraphname,pop1,mypool = ('Sanheyi11.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_n12',"Chokhopani",7)

basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f29_n11',"Chokhopani",7)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_n11',"Chokhopani",7)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f18',"Chokhopani",7)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10',"Chokhopani",7)
pm.graph_addnode_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
# Out:
# Overwriting /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A10_oneattime.py

# %%
import projmodules as pm
pd="/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A10/"  
outpd="/mnt/solexa/mel_yang/data/2.2M/"
subset='mEA'
fh="UPA16"

myname="La368_G1.A10"
myname="Shahr_I_Sokhta_BA2.La368_G1.A10_n3"
#myname="Zongri-a.Shahr_I_Sokhta_BA2.La368_G1.A10_n3_f11"
myname="Han.La368_G1.A10_n3"
#myname="Han.Zongri-a.Shahr_I_Sokhta_BA2.La368_G1.A10_n3_f11_f25"
myname="Zongri-a.Han.La368_G1.A10_n3_f14"
myname="Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34"
myname="Wuba.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10"
myname="Wuba.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f18"
myname="Sanheyi11.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f18"
#myname="Sanheyi11.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f18"
#myname="Sanheyi11.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f29_n11" ##0 branch for n13
#myname="Wuba.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f29_n11"
#myname="Sanheyi11.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_n11"
#myname="Wuba.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_n11"

myname="Chokhopani.Sanheyi11.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_n11_n13"
myname="Chokhopani.Sanheyi11.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_n12"
#myname="Jinchankou0.Sanheyi11.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_n12"

myname="Chokhopani.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f29_n11"
mydat = pm.graph_getidsig(pd,myname,zscorecutoff=3) 
print len(mydat)
for i in mydat: 
    print i[0], i[1]
    if 'n' in i[0]: pm.graph_retrieveinfo(i,pd,subset,fh,myname)
# Out:
# 18
# n8 2.170
# n10 2.167
# n11 2.372
# f9 2.193
# f21 2.190
# f10 2.372
# f22 2.373
# f19 2.192
# f7 2.192
# f32 2.161
# f40 2.185
# f52 2.372
# f33 2.372
# f49 2.223
# f30 2.163
# f42 2.182
# f43 2.373
# f51 2.164

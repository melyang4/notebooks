# %%
import numpy as np
import plateaumodules as pm

#out,tv=("Mbuti",".")
out,tv=("Chimp",".")
#out,tv=("Mbuti",".tv.")

pD="/mnt/solexa/mel_yang/aPlateau/"
fh="aPlateau%sdstat.log" % tv

agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
anx=["Pukagongma","Pukagongma7","Yushu","Redilong","Xiaoenda","Butaxiongqu","Caixiutang",
    "Chokhopani","Mebrak","Samdzong"]
#agq=["Zongri1a","Zongri23","Shangluzhuang","Heodong"]
popA=anx
popB=anx
thirdpops=["Han","Ami","Atayal","Daur","Naxi","Yi","Tibetan","Korean",
           "Japanese","Hezhen","Dai","Sherpa","Tianyuan"]
#thirdpops=anx
#thirdpops=["Tianyuan"]
thirdpops=agq
for myind in thirdpops:
    #myind="Shangluzhuang"
    #myind="Hejiatai"
    mypops1=[popA,myind,popB,out]
    mypops2=[popA,popB,myind,out]
    DorZ="Z"

    #newfh1=fh.split(".")[0]+tv+DorZ+"."+"aNX_%s_aNX_%s" % (myind,out)
    #Zary = pm.mkDary(pD,fh,mypops1,(1,3),(0,2),DorZ)    
    #print pm.Zmat2xlsx(Zary,pD+newfh1,popA,popB,0,2)
    
    newfh2=fh.split(".")[0]+tv+DorZ+"."+"aNX_aNX_%s_%s" % (myind,out)
    Zary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),DorZ)    
    print pm.Zmat2xlsx(Zary,pD+newfh2,popA,popB,0,1)
# Out:
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aNX_aNX_Zongri1a_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aNX_aNX_Zongri23_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aNX_aNX_Shangluzhuang_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aNX_aNX_Hejiatai_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aNX_aNX_Heodong_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aNX_aNX_Daxiang_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aNX_aNX_Xiahaishi_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aNX_aNX_Hupo_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aNX_aNX_Sanheyi_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aNX_aNX_Qunke_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aNX_aNX_Lajigai_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aNX_aNX_Wenpuju_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aNX_aNX_Jinchankou_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aNX_aNX_Qijiaping_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aNX_aNX_Wuba_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aNX_aNX_Huoshaogou_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aNX_aNX_Lierbao_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aNX_aNX_Shannashuzha_Chimp!

# %%
import numpy as np
import plateaumodules as pm

pD="/mnt/solexa/mel_yang/aPlateau/"
out,tv=("Mbuti",".")
out,tv=("Chimp",".")
#out,tv=("Mbuti",".tv.")
fh="aPlateau%sdstat.log" % tv

agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
anx=["Pukagongma","Pukagongma7","Yushu","Redilong","Xiaoenda","Butaxiongqu","Caixiutang",
    "Chokhopani","Mebrak","Samdzong"]
#agq=["Zongri1a","Zongri23","Shangluzhuang","Heodong"]
popA=agq
popB=anx
thirdpops=["Han","Ami","Atayal","Daur","Naxi","Yi","Tibetan","Korean",
           "Japanese","Hezhen","Dai","Sherpa"]
#thirdpops=anx
#thirdpops=["Tianyuan"]
#thirdpops=agq
for myind in thirdpops:
    #myind="Shangluzhuang"
    #myind="Hejiatai"
    
    mypops1=[popA,myind,popB,out]
    mypops2=[popA,popB,myind,out]
    DorZ="Z"

    newfh2=fh.split(".")[0]+tv+DorZ+"."+"aGQ_aNX_%s_%s" % (myind,out)
    Zary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),DorZ)    
    print pm.Zmat2xlsx(Zary,pD+newfh2,popA,popB,0,1)
# Out:
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_aNX_Han_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_aNX_Ami_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_aNX_Atayal_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_aNX_Daur_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_aNX_Naxi_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_aNX_Yi_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_aNX_Tibetan_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_aNX_Korean_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_aNX_Japanese_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_aNX_Hezhen_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_aNX_Dai_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_aNX_Sherpa_Chimp!

# %%
import numpy as np
import plateaumodules as pm

out,tv=("Mbuti",".")
out,tv=("Chimp",".")
out,tv=("Mbuti",".tv.")

pD="/mnt/solexa/mel_yang/aPlateau/"
fh="aPlateau%sdstat.log" % tv

agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
anx=["Pukagongma","Pukagongma7","Yushu","Redilong","Xiaoenda","Butaxiongqu","Caixiutang",
    "Chokhopani","Mebrak","Samdzong"]
#agq=["Zongri1a","Zongri23","Shangluzhuang","Heodong"]
popA=anx
popB=agq
thirdpops=["Han","Ami","Atayal","Daur","Naxi","Yi","Tibetan","Korean",
           "Japanese","Hezhen","Dai","Sherpa"]
thirdpops=anx
#thirdpops=["Tianyuan"]
for myind in thirdpops:
    #myind="Shangluzhuang"
    #myind="Hejiatai"
    mypops1=[popA,myind,popB,out]
    mypops2=[popA,popB,myind,out]
    DorZ="Z"

    newfh1=fh.split(".")[0]+tv+DorZ+"."+"aNX_%s_aGQ_%s" % (myind,out)
    #newfh2=fh.split(".")[0]+tv+DorZ+"."+"aNX_aNX_%s_%s" % (myind,out)
    #Zary = pm.mkDary(pD,fh,mypops1,(1,3),(0,2),DorZ)    
    #print pm.Zmat2xlsx(Zary,pD+newfh1,popA,popB,0,2)
    ##Transposed array
    Zary = np.transpose(pm.mkDary(pD,fh,mypops1,(1,3),(0,2),DorZ))    
    print pm.Zmat2xlsx(Zary,pD+newfh1,popB,popA,2,0)

    #Zary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),DorZ)    
    #print pm.Zmat2xlsx(Zary,pD+newfh2,popA,popB,0,1)
# Out:
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.tv.Z.aNX_Pukagongma_aGQ_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.tv.Z.aNX_Pukagongma7_aGQ_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.tv.Z.aNX_Yushu_aGQ_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.tv.Z.aNX_Redilong_aGQ_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.tv.Z.aNX_Xiaoenda_aGQ_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.tv.Z.aNX_Butaxiongqu_aGQ_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.tv.Z.aNX_Caixiutang_aGQ_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.tv.Z.aNX_Chokhopani_aGQ_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.tv.Z.aNX_Mebrak_aGQ_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.tv.Z.aNX_Samdzong_aGQ_Mbuti!

# %%
import numpy as np
import plateaumodules as pm

out,tv=("Mbuti",".")
out,tv=("Chimp",".")
#out,tv=("Mbuti",".tv.")

pD="/mnt/solexa/mel_yang/aPlateau/"
fh="aPlateau%sdstat.log" % tv

agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
anx=["Pukagongma","Pukagongma7","Yushu","Redilong","Xiaoenda","Butaxiongqu","Caixiutang",
    "Chokhopani","Mebrak","Samdzong"]
#agq=["Zongri1a","Zongri23","Shangluzhuang","Heodong"]
popA=agq
popB=anx
thirdpops=["Han","Ami","Atayal","Daur","Naxi","Yi","Tibetan","Korean",
           "Japanese","Hezhen","Dai","Sherpa"]
thirdpops=agq
#thirdpops=["Tianyuan"]
for myind in thirdpops:
    #myind="Shangluzhuang"
    #myind="Hejiatai"

    mypops1=[popA,myind,popB,out]
    mypops2=[popA,popB,myind,out]
    DorZ="Z"

    newfh1=fh.split(".")[0]+tv+DorZ+"."+"aGQ_%s_aNX_%s" % (myind,out)
    #newfh2=fh.split(".")[0]+tv+DorZ+"."+"aNX_aNX_%s_%s" % (myind,out)
    #Zary = pm.mkDary(pD,fh,mypops1,(1,3),(0,2),DorZ)    
    #print pm.Zmat2xlsx(Zary,pD+newfh1,popA,popB,0,2)
    ##Transposed array
    Zary = np.transpose(pm.mkDary(pD,fh,mypops1,(1,3),(0,2),DorZ))    
    print pm.Zmat2xlsx(Zary,pD+newfh1,popB,popA,2,0)

    #Zary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),DorZ)    
    #print pm.Zmat2xlsx(Zary,pD+newfh2,popA,popB,0,1)
# Out:
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Zongri1a_aNX_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Zongri23_aNX_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Shangluzhuang_aNX_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Hejiatai_aNX_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Heodong_aNX_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Daxiang_aNX_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Xiahaishi_aNX_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Hupo_aNX_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Sanheyi_aNX_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Qunke_aNX_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Lajigai_aNX_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Wenpuju_aNX_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Jinchankou_aNX_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Qijiaping_aNX_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Wuba_aNX_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Huoshaogou_aNX_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Lierbao_aNX_Chimp!
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aGQ_Shannashuzha_aNX_Chimp!

# %%
import numpy as np
import plateaumodules as pm

out,tv=("Mbuti",".")
out,tv=("Chimp",".")
#out,tv=("Mbuti",".tv.")

pD="/mnt/solexa/mel_yang/aPlateau/"
fh="aPlateau%sdstat.log" % tv

agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
anx=["Pukagongma","Pukagongma7","Yushu","Redilong","Xiaoenda","Butaxiongqu","Caixiutang",
    "Chokhopani","Mebrak","Samdzong"]
#agq=["Zongri1a","Zongri23","Shangluzhuang","Heodong"]
popA=anx
popB=agq+anx
thirdpops=["Han","Ami","Atayal","Daur","Naxi","Yi","Tibetan","Korean",
           "Japanese","Hezhen","Dai","Sherpa"]
thirdpops=anx
thirdpops=["Tianyuan"]
for myind in thirdpops:
    #myind="Shangluzhuang"
    #myind="Hejiatai"
    mypops1=[popA,myind,popB,out]
    mypops2=[popA,popB,myind,out]
    DorZ="Z"

    #newfh1=fh.split(".")[0]+"."+DorZ+"."+"aNX_%s_aNX_%s" % (myind,out)
    newfh2=fh.split(".")[0]+tv+DorZ+"."+"aNX_aGQ+aNX_%s_%s" % (myind,out)
    #Zary = pm.mkDary(pD,fh,mypops1,(1,3),(0,2),DorZ)    
    #print pm.Zmat2xlsx(Zary,pD+newfh1,popA,popB,0,2)

    Zary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),DorZ)    
    print pm.Zmat2xlsx(Zary,pD+newfh2,popA,popB,0,1)
# Out:
# Made /mnt/solexa/mel_yang/aPlateau/aPlateau.Z.aNX_aGQ+aNX_Tianyuan_Chimp!

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.colors
pD="/mnt/solexa/mel_yang/aPlateau/"
fh,tv=("aPlateau.dstat.log",'all')
#fh,tv=("aPlateau.tv.dstat.log",'tv')
fs=15
agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
anx=["Pukagongma","Pukagongma7","Yushu","Redilong","Xiaoenda","Butaxiongqu","Caixiutang",
    "Chokhopani","Mebrak","Samdzong"]
wantedcolors=["blue"]*len(anx)
header1,header2=anx,anx
popA=anx
popB=anx
varypop=["Tianyuan",'Vestonice16']
myind="Sherpa"
myinds=anx
outs=["Mbuti","Chimp"]
out="Chimp"
for count,myind in enumerate(myinds):
    #myind="Shangluzhuang"
    #myind="Hejiatai"
    
    mypops1=[popA,myind,popB,out]
    mypops2=[popA,popB,myind,out]
    DorZ="Z"
    newname="D_aNX_aNX_%s_%s" % (myind,out)
    Zary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),'Z')
    Dary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),'D')
    mylabel="D(%s,%s;%s,%s)" % ('P1',"P2",myind,out)
    Zary = np.nan_to_num(Zary)
    
    levels = range(-10,11)
    multiplier=((len(levels)-6)/2)+1
    colors = ['#333399']*multiplier + ['#CCCCFF'] + ['white']*4 + ['#FFEFD5'] + ['orange']*multiplier
    cmap1,norm = matplotlib.colors.from_levels_and_colors(levels, colors,extend='both')
    
    fig,ax = plt.subplots(figsize=(5,5))
    heatmap = ax.pcolor(Zary ,cmap=cmap1, vmin=-10,vmax=10)
    cbar=plt.colorbar(heatmap)
    
    ##LEGEND
    cbar.ax.text(.5, 0.25, '$D<0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.5, '$N.S.$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.75, '$D>0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.get_yaxis().labelpad = 15
    cbar.ax.set_ylabel('Z-score', rotation=270,fontsize=fs)
    
    ax.grid(True)
    ax.set_xticks(np.arange(len(header1)), minor=False)
    ax.set_yticks(np.arange(len(header2)), minor=False)
    
    column_labels = header1
    row_labels = header2
    ax.set_xlim((0,len(header1)))
    ax.set_ylim((0,len(header2)))
    ax.set_xticklabels(column_labels, minor=False,fontsize=fs,rotation=75,ha='left')
    ax.set_yticklabels(row_labels, minor=False,fontsize=fs,va='top')
    ax.invert_yaxis()
    ax.xaxis.tick_top()
    ax.text(-3.5,-0.5,"P1/P2",fontsize=fs+5)
    newfilename='/mnt/solexa/mel_yang/aPlateau/images/%s_%s_heatmap.png' % (newname,tv)
    print newfilename
    fig.savefig(newfilename)
    
plt.show()
print myind
# Out:
# /mnt/solexa/mel_yang/aPlateau/images/D_aNX_aNX_Pukagongma_Chimp_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aNX_aNX_Pukagongma7_Chimp_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aNX_aNX_Yushu_Chimp_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aNX_aNX_Redilong_Chimp_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aNX_aNX_Xiaoenda_Chimp_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aNX_aNX_Butaxiongqu_Chimp_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aNX_aNX_Caixiutang_Chimp_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aNX_aNX_Chokhopani_Chimp_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aNX_aNX_Mebrak_Chimp_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/D_aNX_aNX_Samdzong_Chimp_all_heatmap.png
# Samdzong

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
pD="/mnt/solexa/mel_yang/aPlateau/"
fhall="aPlateau.dstat.log"
fhtv="aPlateau.tv.dstat.log"
out,out2=("Mbuti","Mbuti")

#fhtv="aPlateau.dstat.log"
#out,out2=("Mbuti","Chimp")

#agq=["Zongri1a",
agq=["Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",][::-1]
anx=["Pukagongma","Pukagongma7","Yushu","Redilong","Xiaoenda","Butaxiongqu","Caixiutang",
    "Chokhopani","Mebrak","Samdzong"][::-1]
eas=["Han","Dai","Ami","Daur","Naxi","Yi","Tibetan","Sherpa"][::-1]
wantedcolors=["blue"]*len(agq)
myxmin=[-0.04]*8
myxmax=[0.04]*8
#myxmin=[-0.02]*5
#myxmax=[0.06]*5
mysubplot=0
#fig = plt.figure(figsize=(10,5))
fig = plt.figure(figsize=(9,3.2))
#popA=['Zongri1a',"Shangluzhuang","Hejiatai","Daxiang"]
#popA=["Han","Ami","Dai","Daur"] 
popA=["Naxi","Yi","Tibetan","Sherpa"]
popB=anx
mynames=anx
myind="Butaxiongqu"
varypops=popA #outs
ypops=popB
mytuples=[(0,3),(1,2)]
for count,varypop in enumerate(varypops):

    #mypops2=[popA,myind,ypops,varypop]
    mypops2=[myind,ypops,[varypop],out]

    Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
    Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
    SEaryall=Daryall/Zaryall 
    
    mynewpops2=mypops2[:-1]+[out2]
    Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
    Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
    SEarytv=Darytv/Zarytv
    
    mylabel="D(%s,%s;%s,%s)" % (mypops2[0][0],mypops2[1],'EAS',mypops2[3])
    mylabel="P3 = %s" % mypops2[2][0]

    
    
    ax1=fig.add_subplot(1,len(varypops),count+1)
    for ind,i in enumerate(ypops):
        ax1.errorbar(Darytv[ind][0],ind,xerr=SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[ind][0],ind,xerr=2*SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[ind],ind,'.',alpha=0.05)

        ax1.errorbar(Daryall[ind][0],ind,xerr=SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[ind][0],ind,xerr=2*SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[ind],ind,'.')
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    if count==0:
        #ax1.text("P2=%s\n" % myind,rotation=90,fontsize=16)
        ax1.set_ylabel("P1=%s\n\nP2" % mypops2[0],rotation=90,fontsize=13)
        ax1.set_yticklabels(mynames,fontsize=13)
    else: 
        ax1.set_yticklabels([' ']*(len(mynames)),fontsize=1)
    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[count],myxmax[count])
    #xlabel = ax1.get_xticks().tolist()
    #print xlabel
    #ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)

    ax1.set_title(mylabel,fontsize=13)
    #ax1.text(0,len(mynames),mylabel,fontsize=13, horizontalalignment='center', verticalalignment='center',backgroundcolor="white")

    ax1.axvline(x=0, ls='dashed', c='black') #, backgroundcolor="white") 
    #for myline in [3.5]:
    #    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)

    ax1.set_xlabel("D",fontsize=13)
fig.autofmt_xdate()  
plt.tight_layout()
plt.show()

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.colors
pD="/mnt/solexa/mel_yang/aPlateau/"
fh,tv=("aPlateau.dstat.log",'all')
#fh,tv=("aPlateau.tv.dstat.log",'tv')
fs=15
agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
eas=["Ulchi","Oroqen","Daur","Hezhen","Xibo","Tu","Japanese","Korean",
    "Han","Tujia","She","Miao","Ami","Atayal","Dai","Kinh","Lahu",
     "Naxi","Yi","Tibetan","Sherpa"]
anx=["Pukagongma","Pukagongma7","Yushu","Redilong","Xiaoenda","Butaxiongqu","Caixiutang",
    "Chokhopani","Mebrak","Samdzong"]
wantedcolors=["blue"]*len(anx)
header1,header2=eas,eas
popA=eas
popB=eas
varypop=["Tianyuan",'Vestonice16']
myind="Sherpa"
myinds=anx
outs=["Mbuti","Chimp"]
out="Mbuti"
out="Chimp"
for count,myind in enumerate(myinds):
    #myind="Shangluzhuang"
    #myind="Hejiatai"
    
    mypops1=[popA,myind,popB,out]
    mypops2=[popA,popB,myind,out]
    DorZ="Z"
    newname="D_EAS_EAS_%s_%s" % (myind,out)
    Zary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),'Z')
    Dary = pm.mkDary(pD,fh,mypops2,(2,3),(0,1),'D')
    mylabel="D(%s,%s;%s,%s)" % ('P1',"P2",myind,out)
    Zary = np.nan_to_num(Zary)
    
    levels = range(-10,11)
    multiplier=((len(levels)-6)/2)+1
    colors = ['#333399']*multiplier + ['#CCCCFF'] + ['white']*4 + ['#FFEFD5'] + ['orange']*multiplier
    cmap1,norm = matplotlib.colors.from_levels_and_colors(levels, colors,extend='both')
    
    fig,ax = plt.subplots(figsize=(10,10))
    heatmap = ax.pcolor(Zary ,cmap=cmap1, vmin=-10,vmax=10)
    cbar=plt.colorbar(heatmap)
    
    ##LEGEND
    cbar.ax.text(.5, 0.25, '$D<0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.5, '$N.S.$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.text(.5, 0.75, '$D>0$', color='black', ha='center', va='center',fontsize=fs-22)
    cbar.ax.get_yaxis().labelpad = 15
    cbar.ax.set_ylabel('Z-score', rotation=270,fontsize=fs)
    
    ax.grid(True)
    ax.set_xticks(np.arange(len(header1)), minor=False)
    ax.set_yticks(np.arange(len(header2)), minor=False)
    
    column_labels = header1
    row_labels = header2
    ax.set_xlim((0,len(header1)))
    ax.set_ylim((0,len(header2)))
    ax.set_xticklabels(column_labels, minor=False,fontsize=fs,rotation=75,ha='left')
    ax.set_yticklabels(row_labels, minor=False,fontsize=fs,va='top')
    ax.invert_yaxis()
    ax.xaxis.tick_top()
    ax.text(-3.5,-0.5,"P1/P2",fontsize=fs+5)
    newfilename='/mnt/solexa/mel_yang/aPlateau/images/SI_DD/%s_%s_heatmap.png' % (newname,tv)
    print newfilename
    fig.savefig(newfilename)
    
plt.show()
print myind
# Out:
# /mnt/solexa/mel_yang/aPlateau/images/SI_DD/D_EAS_EAS_Pukagongma_Chimp_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/SI_DD/D_EAS_EAS_Pukagongma7_Chimp_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/SI_DD/D_EAS_EAS_Yushu_Chimp_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/SI_DD/D_EAS_EAS_Redilong_Chimp_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/SI_DD/D_EAS_EAS_Xiaoenda_Chimp_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/SI_DD/D_EAS_EAS_Butaxiongqu_Chimp_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/SI_DD/D_EAS_EAS_Caixiutang_Chimp_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/SI_DD/D_EAS_EAS_Chokhopani_Chimp_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/SI_DD/D_EAS_EAS_Mebrak_Chimp_all_heatmap.png
# /mnt/solexa/mel_yang/aPlateau/images/SI_DD/D_EAS_EAS_Samdzong_Chimp_all_heatmap.png
# Samdzong

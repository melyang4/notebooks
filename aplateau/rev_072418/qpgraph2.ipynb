# %%
import projmodules as pm
pd="/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A10/"  
outpd="/mnt/solexa/mel_yang/data/2.2M/"
subset='mEA'
fh="UPA16"

myname="Zongri-a.Han.La368_G1.A10_n3_n4"
myname="Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7"
myname="Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24"
myname="Chokhopani.Zongri-b.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_f62"
myname="Zongri-b.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f29"
myname="Zongri-b.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f43"
myname="Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24"
myname="Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f17"
myname="Zongri-b.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51"
mydat = pm.graph_getidsig(pd,myname,zscorecutoff=2.5) 
print len(mydat)
for i in mydat: 
    print i[0], i[1]
    if 'n' in i[0]: pm.graph_retrieveinfo(i,pd,subset,fh,myname)
# Out:
# 4
# f89 -2.344
# f80 -2.399
# f84 -2.361
# f87 -2.320

# %%
# %%writefile /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A10_oneattime.py
#import TY_maindata as md
import projmodules as pm
import multiprocessing
from multiprocessing import Pool


def do_work(myvars):
    pD,fh,subset,pop1,basegraphname=myvars
    wanttoadd = [pop1,pop1]
    pm.graph_addnode_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    return "done "+basegraphname

pD = "/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A10/"
outpd="/mnt/solexa/mel_yang/data/2.2M/"
fh = 'UPA16'
subset='mEA'

##Came from A10, removed La368_G1

basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f18',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f53',"Jinchankou0",20)
basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_n11',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_f62',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_f55',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_f20',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_f10',"Jinchankou0",20)
basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f20_n11',"Jinchankou0",20)
basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f20_f29',"Jinchankou0",20)
basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f20_f62',"Jinchankou0",15)
basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f20_f37',"Jinchankou0",20)
basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f20_f20',"Jinchankou0",8)
basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f20_f10',"Jinchankou0",7)


basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10',"XiahaishiM9",20)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f18',"XiahaishiM9",20)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f53',"XiahaishiM9",20)
###basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_n11',"XiahaishiM9",20)
###basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_f62',"XiahaishiM9",20)
###basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_f55',"XiahaishiM9",15)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_f20',"XiahaishiM9",20)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_f10',"XiahaishiM9",20)

#basegraphname,pop1,mypool = ('XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f53_n13',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_n12',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f18_n13',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_f32',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_f77',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_f74',"Jinchankou0",20)
basegraphname,pop1,mypool = ('Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f53_n13_f98',"Chokhopani",20)
#basegraphname,pop1,mypool = ('Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f53_n13_n8',"Chokhopani",20)
#basegraphname,pop1,mypool = ('Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_n12_f93',"Chokhopani",20)
#basegraphname,pop1,mypool = ('Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_n12_n9',"Chokhopani",20)
#basegraphname,pop1,mypool = ('Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_f32_f98',"Chokhopani",20)
#basegraphname,pop1,mypool = ('Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_f32_n8',"Chokhopani",20)


basegraphname,pop1,mypool = ('Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_n12_f93_n9',"RedilongM3",20)
basegraphname,pop1,mypool = ('Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_n12_f93_n9',"Butaxiongqu",20)

basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9',"Chokhopani",3)
basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f29',"Chokhopani",3)
basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f43',"Chokhopani",3)
basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51',"Chokhopani",3)
basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f54',"Chokhopani",3)

pm.graph_addnode_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
# Out:
# Overwriting /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A10_oneattime.py

# %%
import projmodules as pm
pd="/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A10/"  
outpd="/mnt/solexa/mel_yang/data/2.2M/"
subset='mEA'
fh="UPA16"

myname="Zongri-a.Han.La368_G1.A10_n3_f14"
myname="Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f20"
myname="Jinchankou0.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f53"
myname="Jinchankou0.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_n11"
#myname="Jinchankou0.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_f62"
#myname="Jinchankou0.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_f55"
#myname="Jinchankou0.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_f20"
#myname="Jinchankou0.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f34_f10"
myname="XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f53"
myname="XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10"
#myname="XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f18"

#myname="Jinchankou0.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f20_n11"
#myname="Jinchankou0.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f20_f29"
#myname="Jinchankou0.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f20_f62"
#myname="Jinchankou0.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f20_f37"
#myname="Jinchankou0.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f20_f20"
#myname="Jinchankou0.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_f20_f10"
myname="Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f53_n13"
myname="Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_n12"
myname="Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_f32"

myname="Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f53_n13_f98"
#myname="Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_f53_n13_n8"

myname="Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_f32_f98"
#myname="Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_f32_n8"
#myname="Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_n12_f93"
#myname="Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_n12"
#myname="Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_f32"
myname="Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_f14_n8_n10_n12_f93_n9"


mydat = pm.graph_getidsig(pd,myname,zscorecutoff=3) 
print len(mydat)
for i in mydat: 
    print i[0], i[1]
    if 'n' in i[0]: pm.graph_retrieveinfo(i,pd,subset,fh,myname)
# Out:
# 118
# n8 -2.355
# n9 2.549
# n10 2.550
# n12 2.761
# n17 -2.347
# n18 -2.357
# n19 -2.360
# f15 -2.451
# f9 2.506
# f18 -2.334
# f27 2.500
# f33 -2.448
# f36 -2.330
# f42 -2.352
# f51 -2.352
# f25 2.382
# f46 2.761
# f58 2.366
# f43 2.534
# f7 2.382
# f16 -2.328
# f34 -2.326
# f52 -2.351
# f26 2.527
# f29 2.762
# f50 2.493
# f11 2.812
# f59 2.514
# f53 -2.354
# f35 -2.342
# f44 2.535
# f17 -2.331
# f8 2.530
# f60 2.479
# f66 -2.421
# f69 -2.335
# f75 2.466
# f81 -2.449
# f84 -2.351
# f87 -2.348
# f96 -2.352
# f102 2.537
# f108 2.460
# f111 -2.366
# f114 2.537
# f73 -2.348
# f67 -2.332
# f88 2.498
# f112 -2.351
# f97 -2.350
# f109 -2.362
# f82 -2.349
# f91 2.761
# f100 -2.359
# f62 2.792
# f74 2.498
# f77 2.761
# f89 2.466
# f68 -2.335
# f113 2.536
# f116 2.759
# f104 2.759
# f83 -2.348
# f110 -2.361
# f98 -2.354
# f101 2.536
# f95 -2.448
# f120 -2.393
# f123 -2.357
# f126 -2.348
# f129 2.644
# f132 -2.341
# f135 2.545
# f138 2.538
# f141 -2.413
# f144 -2.354
# f147 2.547
# ...

# %%
# %%writefile /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A10_oneattime.py
#import TY_maindata as md
import projmodules as pm
import multiprocessing
from multiprocessing import Pool


def do_work(myvars):
    pD,fh,subset,pop1,basegraphname=myvars
    wanttoadd = [pop1,pop1]
    pm.graph_addnode_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,wanttoadd,comments='NA')
    return "done "+basegraphname

pD = "/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A10_n3_n4/"
outpd="/mnt/solexa/mel_yang/data/2.2M/"
fh = 'UPA16'
subset='mEA'

##Came from A10, removed La368_G1
basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9',"XiahaishiM9",20)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f29',"XiahaishiM9",20)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f43',"XiahaishiM9",20)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51',"XiahaishiM9",20)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f54',"XiahaishiM9",20)

basegraphname,pop1,mypool = ('XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51_n13',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51_f87',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51_f35',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11',"Jinchankou0",20)
basegraphname,pop1,mypool = ('XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_f65',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_f29',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f29_n12',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f43_n12',"Jinchankou0",20)
basegraphname,pop1,mypool = ('XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f29_f74',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f29_f67',"Jinchankou0",20)

#basegraphname,pop1,mypool = ('Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51_n13_f113',"Chokhopani",20)
#basegraphname,pop1,mypool = ('Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f79',"Chokhopani",20)
#basegraphname,pop1,mypool = ('Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80',"Chokhopani",20)
basegraphname,pop1,mypool = ('Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51_f87_f120',"Chokhopani",20)
basegraphname,pop1,mypool = ('Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51_f35_f119',"Chokhopani",20)

#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_n10',"XiahaishiM9",8)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51',"XiahaishiM9",7)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f26',"XiahaishiM9",8)
#basegraphname,pop1,mypool = ('Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f54',"XiahaishiM9",7)


basegraphname,pop1,mypool = ('Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80_n8',"Butaxiongqu",20)
#basegraphname,pop1,mypool = ('Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80_n12',"Butaxiongqu",20)
basegraphname,pop1,mypool = ('Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80_f103',"Butaxiongqu",20)
#basegraphname,pop1,mypool = ('Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80_f121',"Butaxiongqu",20)
basegraphname,pop1,mypool = ('Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f79_f103',"Butaxiongqu",20)
#basegraphname,pop1,mypool = ('Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f79_n8',"Butaxiongqu",20)
basegraphname,pop1,mypool = ('Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51_n13_f113_n10',"Butaxiongqu",20)
#basegraphname,pop1,mypool = ('Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51_n13_f113_f126',"Butaxiongqu",20)
basegraphname,pop1,mypool = ('Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51_f87_f120_n12',"Butaxiongqu",10)
#basegraphname,pop1,mypool = ('Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51_f87_f120_n19',"Butaxiongqu",10)

basegraphname,pop1,mypool = ('Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80_n8_n17',"CaixiutangJ2-13",20)
#basegraphname,pop1,mypool = ('Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80_n12_n8',"CaixiutangJ2-13",20)
#basegraphname,pop1,mypool = ('Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80_n12_n16',"CaixiutangJ2-13",20)
#basegraphname,pop1,mypool = ('Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f79_n8_n8',"CaixiutangJ2-13",20)
#basegraphname,pop1,mypool = ('Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f79_f103_n17',"CaixiutangJ2-13",20)


basegraphname,pop1,mypool = ('Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80_n8_n17',"Tibetan_ShannanX",20)
#basegraphname,pop1,mypool = ('Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80_n12_n8',"Tibetan_ShannanX",20)
#basegraphname,pop1,mypool = ('Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80_n12_n16',"Tibetan_ShannanX",20)
#basegraphname,pop1,mypool = ('Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f79_n8_n8',"Tibetan_ShannanX",20)
#basegraphname,pop1,mypool = ('Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f79_f103_n17',"Tibetan_ShannanX",20)


basegraphname,pop1,mypool = ('XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f43_f74',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f29_f74',"Jinchankou0",20)
#basegraphname,pop1,mypool = ('XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f29_f67',"Jinchankou0",20)

basegraphname,pop1,mypool = ('Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f79_f30',"Butaxiongqu",20)
basegraphname,pop1,mypool = ('Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f79_f128',"Butaxiongqu",20)


pm.graph_addnode_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
pm.graph_addadmix_uniq(pD,fh,subset,basegraphname,[pop1,pop1],comments='NA',pool=mypool,outpop="Mbuti",outpd=outpd)
# Out:
# Overwriting /mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A10_oneattime.py

# %%
import projmodules as pm
pd="/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A10_n3_n4/"  
outpd="/mnt/solexa/mel_yang/data/2.2M/"
subset='mEA'
fh="UPA16"

myname="Zongri-a.Han.La368_G1.A10_n3_n4"
myname="Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7"
myname="Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24"
myname="Chokhopani.Zongri-b.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_f62"
myname="Zongri-b.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f29"
myname="Zongri-b.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f43"
myname="Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24"
myname="Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f17"
myname="XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9"
#myname="XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f29"
#myname="XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f43"
#myname="XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51"
#myname="XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f54"

myname="Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51_n13"
myname="Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51_f35"
###myname="Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51_f87"
myname="Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11"
myname="Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f29_n12"
myname="Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f43_n12"

myname="Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f17"

myname="Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80"
myname="Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f79"
myname="Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51_n13_f113"
myname="Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51_f87_f120"
myname="Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51_f35_f119"

myname="Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80_n8"
#myname="Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f79_n8"
myname="Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51_n13_f113_n10"
myname="Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51_n13_f113_f126"

myname="Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80_n12"
myname="Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80_f103"
myname="Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80_f121"
myname="Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f79_f103"
#myname="Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_f24_f51_n13_f113_n19"

#myname="CaixiutangJ2-13.Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80_n8_n17"
#myname="CaixiutangJ2-13.Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80_n12_n8"
#myname="CaixiutangJ2-13.Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80_n12_n16"
#myname="CaixiutangJ2-13.Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f79_n8_n8"
myname="CaixiutangJ2-13.Butaxiongqu.Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f79_f103_n17"

myname="Zongri-a.Han.La368_G1.A10_n3_n4"
myname="Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7"
myname="XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9"
myname="Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11"
myname="Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f79"
mydat = pm.graph_getidsig(pd,myname,zscorecutoff=2.95) 
print len(mydat)
for i in mydat: 
    print i[0], i[1]
    if 'n' in i[0]: pm.graph_retrieveinfo(i,pd,subset,fh,myname)
# Out:
# 61
# f100 -2.858
# f101 -2.857
# f102 -2.858
# f103 -2.859
# f104 -2.858
# f105 -2.859
# f106 -2.858
# f107 -2.862
# f110 -2.862
# f112 -2.862
# f116 -2.860
# f118 -2.860
# f11 -2.842
# f121 -2.861
# f125 -2.861
# f126 -2.861
# f127 -2.861
# f128 -2.861
# f129 -2.864
# f132 -2.861
# f135 -2.861
# f15 -2.779
# f21 -2.837
# f22 -2.839
# f26 -2.842
# f30 -2.783
# f35 -2.856
# f36 -2.858
# f40 -2.861
# f44 2.869
# f48 -2.841
# f49 -2.843
# f53 -2.846
# f57 -2.850
# f60 -2.868
# f61 -2.871
# f65 -2.877
# f69 -2.916
# f6 -2.837
# f71 -2.845
# f72 -2.847
# f76 -2.849
# f7 -2.839
# f80 -2.853
# f81 -2.860
# f82 -2.862
# f86 -2.864
# f90 -2.897
# f91 -2.854
# f92 -2.856
# f93 -2.855
# f94 -2.856
# f95 -2.856
# f96 -2.856
# f97 -2.856
# f98 -2.856
# f99 -2.857
# n12 -2.857
# n16 -2.857
# n7 -2.852
# n8 -2.854

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A10_n3_n4/"
# fh="Zongri-a.Han.La368_G1.A10_n3_n4_f17"
# fh="XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f29_f67"
# fh="Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f80"
# fh="Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f79_f30"
# fh="Han.La368_G1.A10_n3_n4"
# sed -i 's/Zongri_a/ZongriM297/g' ${pd}${fh}.UPA16.mEA.dot
# sed -i 's/La368_G1/La368/g' ${pd}${fh}.UPA16.mEA.dot
# ##Need to vim and backspace fifth line

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/aPlateau/qpgraph/modelA/A10_n3_n4/"
# fh="Zongri-a.Han.La368_G1.A10_n3_n4_f17"
# fh="XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_f29_f67"
# fh="Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f78"
# fh="Chokhopani.Jinchankou0.XiahaishiM9.Daxiang0.Zongri-a.Han.La368_G1.A10_n3_n4_n7_n9_n11_f79_n8"
# fh="Han.La368_G1.A10_n3_n4"
# dot -Tps ${pd}${fh}.UPA16.mEA.dot > ${pd}${fh}.UPA16.mEA.rev.ps
# ps2pdf ${pd}${fh}.UPA16.mEA.rev.ps ${pd}${fh}.UPA16.mEA.rev.pdf
# #pdfcrop ${pd}${fh}.UPA16.mEA.rev.pdf ${pd}${fh}.UPA16.mEA.rev.pdf
# grep numsnps ${pd}${fh}.UPA16.mEA.log
# grep "worst f-stat" ${pd}${fh}.UPA16.mEA.log
# Out:
# before setwt numsnps: 2144502  outpop: Mbuti
# setwt numsnps: 280975
# worst f-stat:       Kos        La3        Tia        Han       0.000000     0.005885     0.005885     0.002589     2.273

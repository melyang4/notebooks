# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
#import matplotlib
import matplotlib.patches as mpatches

agq=["Zongri-a","ZongriM32","Zongri-c","ZongriM78","Zongri-b","ZongriM40","Hedong4",#"XiahaishiM22",
     "Hedong6","Hejiatai","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Hupo-a","Hupo14",
     "Shangluzhuang0","Hupo8","Qunke1","Lajigai-a","Wenpuju03","Jinchankou0",#"Lajigai2",
     "QijiapingM89-2","QijiapingM104-2","QijiapingM108-2","Wuba","HuoshaogouM117","Lierbao0"]
anx=["PukagongmaM1","PukagongmaM3","PukagongmaM5","YushuSGZ-1",#"PukagongmaM2",
     "RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"]
weaklinks=["XiahaishiM22","Lajigai2","PukagongmaM2"]
#eas=["Han","Dai","Ami","Daur","Sherpa","Tibetan","Naxi","Yi"]
aeur=["Loschbour"]
ane=["Malta1"]
namer=["Clovis"]
casia=["Anatolia_N","Iran_N","Andronovo.SG","Afanasievo.SG"]
sasia=["Punjabi","Mala"]
ancother=["Onge"]
anceas=["Tianyuan"] #,"Papuan","Onge","Oase1","Stuttgart",
varypops=[anceas, ancother,namer,sasia,casia,ane,aeur][::-1]
labels=["Tianyuan","Onge","Anzick-1",'ANI/ASI',"NearEast/Steppe","Mal'ta1","Loschbour"][::-1] #/Papuan/Onge/Oase1
dxcluster=agq+anx#+weaklinks
dxpairs=[(i,j) for indi,i in enumerate(dxcluster) for indj,j in enumerate(dxcluster) if indi>indj]
pairlabels=["%s_%s" % mypair for mypair in dxpairs]
#print pairlabels
out="Mbuti"
colors=["blue","brown","red","black","pink","gray","purple"][::-1]
markers=["o","v","s","+","D",">"]

pDin="/mnt/solexa/mel_yang/aPlateau/update051518/"
pDout="/mnt/solexa/mel_yang/aPlateau/update051518/"
fh,tv=("complete2.dstat.log","")
#fh,tv=("complete.tv.dstat.log",".tv")

fig = plt.figure(figsize=(9,9))
ax1=fig.add_subplot(1,1,1)
handles1,handles2=[],[]
for ind,varypop in enumerate(varypops):
    print varypop
    handles2.append(mpatches.Patch(color=colors[ind], label="X="+labels[ind]))
    for myind in varypop:
        mypops1=[dxcluster,myind,dxcluster,out]
        Zary = pm.mkDary(pDin,fh,mypops1,(1,3),(0,2),"Z") 
        #print Zary
        Zaryu=np.triu(Zary)
        Zaryl=np.transpose(np.tril(Zary))
        Zaryu[Zaryu==0]=np.nan
        Zaryl[Zaryl==0]=np.nan
        #print Zaryu,Zaryl
        ax1.plot(Zaryu,Zaryl,markers[0],color=colors[ind])
        

#ax1.set_ylim((-4,10))
#ax1.set_xlim((-4,10))
ax1.set_xlabel("Z for D(aTib, X; aTib, %s)" % out,fontsize=15)
ax1.set_ylabel("Z for D(aTib, X; aTib, %s)" % out,fontsize=15)
ax1.axvline(x=0, ls='dashed', c='black')
ax1.axhline(y=0, ls='dashed', c='black')
ax1.axvline(x=2, ls='dashed', c='lightgray')
ax1.axhline(y=2, ls='dashed', c='lightgray')
ax1.axvline(x=-2, ls='dashed', c='lightgray')
ax1.axhline(y=-2, ls='dashed', c='lightgray')
ax1.legend(loc='lower right')
ax1.legend(handles=handles2,loc=4,ncol=2,fontsize=12.5)
#ax1.legend(handles=handles1,loc=3)
plt.show()
# Out:
# ['Loschbour']
# ['Malta1']
# ['Anatolia_N', 'Iran_N', 'Andronovo.SG', 'Afanasievo.SG']
# ['Punjabi', 'Mala']
# ['Clovis']
# ['Onge']
# ['Tianyuan']
# /home/mel_yang/.local/lib/python2.7/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
#import matplotlib
import matplotlib.patches as mpatches

agq=["Zongri-a","ZongriM32","Zongri-c","ZongriM78","Zongri-b","ZongriM40","Hedong4",#"XiahaishiM22",
     "Hedong6","Hejiatai","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Hupo-a","Hupo14",
     "Shangluzhuang0","Hupo8","Qunke1","Lajigai-a","Wenpuju03","Jinchankou0",#"Lajigai2",
     "QijiapingM89-2","QijiapingM104-2","QijiapingM108-2","Wuba","HuoshaogouM117","Lierbao0"]
anx=["PukagongmaM1","PukagongmaM3","PukagongmaM5","YushuSGZ-1",#"PukagongmaM2",
     "RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"]
weaklinks=["XiahaishiM22","Lajigai2","PukagongmaM2"]
eas=["Han","Dai","Ami","Daur"]
#eas=["Naxi","Yi","Tu","Tibetan","Sherpa"]
eas=["Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX","Tibetan_NyingchiX",
     "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]
mylabel="wEA-X"#"cEA/nEA/sEA" #"wEA"
aeur=["Loschbour"]
ane=["Malta1"]
namer=["Clovis"]
casia=["Anatolia_N","Iran_N","Andronovo.SG","Afanasievo.SG"]
sasia=["Punjabi","Mala"]
ancother=["Onge"]
anceas=["Tianyuan"] #,"Papuan","Onge","Oase1","Stuttgart",
varypops=[anceas, ancother,namer,sasia,casia,ane,aeur][::-1]
labels=["Tianyuan","Onge","Anzick-1",'ANI/ASI',"NearEast/Steppe","Mal'ta1","Loschbour"][::-1] #/Papuan/Onge/Oase1
dxcluster=agq+anx#+weaklinks
#dxpairs=[(i,j) for indi,i in enumerate(dxcluster) for indj,j in enumerate(dxcluster) if indi>indj]
#pairlabels=["%s_%s" % mypair for mypair in dxpairs]
#print pairlabels
out="Mbuti"
colors=["blue","brown","red","black","pink","gray","purple"][::-1]
markers=["o","v","s","+","D",">"]
myset1,myset2=(dxcluster,eas)
pDin="/mnt/solexa/mel_yang/aPlateau/update051518/"
pDout="/mnt/solexa/mel_yang/aPlateau/update051518/"
fh,tv=("complete2.dstat.log","")
#fh,tv=("complete.tv.dstat.log",".tv")

fig = plt.figure(figsize=(9,9))
ax1=fig.add_subplot(1,1,1)
handles1,handles2=[],[]
for ind,varypop in enumerate(varypops):
    print varypop
    handles2.append(mpatches.Patch(color=colors[ind], label="X="+labels[ind]))
    for myind in varypop:
        mypops1=[myset1,myind,myset2,out]
        Zaryu = pm.mkDary(pDin,fh,mypops1,(1,3),(0,2),"Z") 
        mypops2=[myset2,myind,myset1,out]
        Zaryl = np.transpose(pm.mkDary(pDin,fh,mypops2,(1,3),(0,2),"Z"))
        #print Zaryu,Zaryl
        ax1.plot(Zaryu,Zaryl,markers[0],color=colors[ind])
        

#ax1.set_ylim((-4,10))
#ax1.set_xlim((-4,10))
ax1.set_xlabel("Z for D(aTib, X; %s, %s)" % (mylabel,out),fontsize=15)
ax1.set_ylabel("Z for D(%s, X; aTib, %s)" % (mylabel,out),fontsize=15)
ax1.axvline(x=0, ls='dashed', c='black')
ax1.axhline(y=0, ls='dashed', c='black')
ax1.axvline(x=2, ls='dashed', c='lightgray')
ax1.axhline(y=2, ls='dashed', c='lightgray')
ax1.axvline(x=-2, ls='dashed', c='lightgray')
ax1.axhline(y=-2, ls='dashed', c='lightgray')
ax1.legend(loc='lower right')
ax1.legend(handles=handles2,loc=4,ncol=2,fontsize=12.5)
#ax1.legend(handles=handles1,loc=3)
plt.show()
# Out:
# ['Loschbour']
# ['Malta1']
# ['Anatolia_N', 'Iran_N', 'Andronovo.SG', 'Afanasievo.SG']
# ['Punjabi', 'Mala']
# ['Clovis']
# ['Onge']
# ['Tianyuan']

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
#import matplotlib
import matplotlib.patches as mpatches

low2=["Zongri-b","Zongri-c","ZongriM78","ZongriM40","ZongriM32","Zongri-a",]
low1=["Hejiatai","Hedong6","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Shangluzhuang0","Hupo-a"]#"XiahaishiM22",
low4o=["HuoshaogouM117","Wuba","Hupo14","Hupo8","Qunke1","Lajigai-a"]
low3=["Jinchankou0","Wenpuju03","QijiapingM89-2","QijiapingM108-2","QijiapingM104-2"]#"Lierbao0","Hedong4",
low=low2+low1+low3+low4o
high1=["PukagongmaM1","PukagongmaM5","PukagongmaM3"] #"PukagongmaM2",
high23=["RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","YushuSGZ-1"]
high45=["CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"]
high=high23+high45
eas=["Han","Dai","Ami","Daur"]
#eas=["Naxi","Yi","Tu","Tibetan","Sherpa"]
eas=["Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX","Tibetan_NyingchiX",
     "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]
mylabel="aTib" #"wEA-X"#"cEA/nEA/sEA" #"wEA"
cea=["Han"]
sea=["Dai"]
nea=["Daur"]
wea1=["Naxi","Yi"]
tib2=["Tibetan_ShannanX","Tibetan_ChamdoX"]
tib1=["Tibetan"]
sherpa1=["Sherpa"] #,"Papuan","Onge","Oase1","Stuttgart",
varypops=[cea,sea,nea,wea1,tib2,tib1,sherpa1][::-1]
labels=["Han","Dai","Daur",'Naxi/Yi',"Shannan/Chamdo","Tibetan","Sherpa"][::-1] #/Papuan/Onge/Oase1
dxcluster=low1#+weaklinks
#dxpairs=[(i,j) for indi,i in enumerate(dxcluster) for indj,j in enumerate(dxcluster) if indi>indj]
#pairlabels=["%s_%s" % mypair for mypair in dxpairs]
#print pairlabels
out="Mbuti"
colors=["blue","brown","red","black","pink","gray","purple"][::-1]
markers=["o","v","s","+","D",">"]
myset1,myset2=(low1,low3)
mylabel1,mylabel2=("Low1","Low3")
pDin="/mnt/solexa/mel_yang/aPlateau/update051518/"
pDout="/mnt/solexa/mel_yang/aPlateau/update051518/"
fh,tv=("complete2.dstat.log","")
#fh,tv=("complete.tv.dstat.log",".tv")

fig = plt.figure(figsize=(9,9))
ax1=fig.add_subplot(1,1,1)
handles1,handles2=[],[]
for ind,varypop in enumerate(varypops):
    print varypop
    handles2.append(mpatches.Patch(color=colors[ind], label="X="+labels[ind]))
    for myind in varypop:
        mypops1=[myset1,myind,myset2,out]
        Zaryu = pm.mkDary(pDin,fh,mypops1,(1,3),(0,2),"Z") 
        mypops2=[myset2,myind,myset1,out]
        Zaryl = np.transpose(pm.mkDary(pDin,fh,mypops2,(1,3),(0,2),"Z"))
        #print Zaryu,Zaryl
        ax1.plot(Zaryu,Zaryl,markers[0],color=colors[ind])
        

ax1.set_ylim((-15,15))
ax1.set_xlim((-15,15))
ax1.set_xlabel("Z for D(%s, X; %s, %s)" % (mylabel1,mylabel2,out),fontsize=15)
ax1.set_ylabel("Z for D(%s, X; %s, %s)" % (mylabel2,mylabel1,out),fontsize=15)
ax1.axvline(x=0, ls='dashed', c='black')
ax1.axhline(y=0, ls='dashed', c='black')
ax1.axvline(x=2, ls='dashed', c='lightgray')
ax1.axhline(y=2, ls='dashed', c='lightgray')
ax1.axvline(x=-2, ls='dashed', c='lightgray')
ax1.axhline(y=-2, ls='dashed', c='lightgray')
ax1.legend(loc='lower right')
ax1.legend(handles=handles2,loc=4,ncol=2,fontsize=12.5)
#ax1.legend(handles=handles1,loc=3)
plt.show()
# Out:
# ['Sherpa']
# ['Tibetan']
# ['Tibetan_ShannanX', 'Tibetan_ChamdoX']
# ['Naxi', 'Yi']
# ['Daur']
# ['Dai']
# ['Han']

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
#import matplotlib
import matplotlib.patches as mpatches

low2=["Zongri-b","Zongri-c","ZongriM78","ZongriM40","ZongriM32","Zongri-a",]
low1=["Hejiatai","Hedong6","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Shangluzhuang0","Hupo-a"]#"XiahaishiM22",
low4o=["HuoshaogouM117","Wuba","Hupo14","Hupo8","Qunke1","Lajigai-a"]
low3=["Jinchankou0","Wenpuju03","QijiapingM89-2","QijiapingM108-2","QijiapingM104-2"]#"Lierbao0","Hedong4",
low=low2+low1+low3+low4o
high1=["PukagongmaM1","PukagongmaM5","PukagongmaM3"] #"PukagongmaM2",
high23=["RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","YushuSGZ-1"]
high45=["CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"]
high=high23+high45
eas=["Han","Dai","Ami","Daur"]
#eas=["Naxi","Yi","Tu","Tibetan","Sherpa"]
eas=["Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX","Tibetan_NyingchiX",
     "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]
mylabel="aTib" #"wEA-X"#"cEA/nEA/sEA" #"wEA"
cea=["Han"]
sea=["Dai"]
nea=["Daur"]
wea1=["Naxi","Yi"]
tib2=["Tibetan_ShannanX","Tibetan_ChamdoX"]
tib1=["Tibetan"]
sherpa1=["Sherpa"] #,"Papuan","Onge","Oase1","Stuttgart",
varypops=[cea,sea,nea,wea1,tib2,tib1,sherpa1][::-1]
labels=["Han","Dai","Daur",'Naxi/Yi',"Shannan/Chamdo","Tibetan","Sherpa"][::-1] #/Papuan/Onge/Oase1
dxcluster=low1#+weaklinks
#dxpairs=[(i,j) for indi,i in enumerate(dxcluster) for indj,j in enumerate(dxcluster) if indi>indj]
#pairlabels=["%s_%s" % mypair for mypair in dxpairs]
#print pairlabels
out="Mbuti"
colors=["blue","brown","red","black","pink","gray","purple"][::-1]
markers=["o","v","s","+","D",">"]
mytuples=[(i,j) for i in ["Zongri-a","Hejiatai","PukagongmaM5"] for j in ["Jinchankou0","RedilongM3","YushuSGZ-1"]]
pDin="/mnt/solexa/mel_yang/aPlateau/update051518/"
pDout="/mnt/solexa/mel_yang/aPlateau/update051518/"
fh,tv=("complete2.dstat.log","")
#fh,tv=("complete.tv.dstat.log",".tv")

fig = plt.figure(figsize=(27,27))

for indtup,mytup in enumerate(mytuples):
    mylabel1,mylabel2=mytup
    myset1,myset2=[mylabel1],[mylabel2]
    ax1=fig.add_subplot(3,3,indtup+1)
    handles1,handles2=[],[]
    for ind,varypop in enumerate(varypops):
        print varypop
        handles2.append(mpatches.Patch(color=colors[ind], label="X="+labels[ind]))
        for myind in varypop:
            mypops1=[myset1,myind,myset2,out]
            Zaryu = pm.mkDary(pDin,fh,mypops1,(1,3),(0,2),"Z") 
            mypops2=[myset2,myind,myset1,out]
            Zaryl = np.transpose(pm.mkDary(pDin,fh,mypops2,(1,3),(0,2),"Z"))
            #print Zaryu,Zaryl
            ax1.plot(Zaryu,Zaryl,markers[0],color=colors[ind])


    ax1.set_ylim((-10,10))
    ax1.set_xlim((-10,10))
    ax1.set_xlabel("Z for D(%s, X; %s, %s)" % (mylabel1,mylabel2,out),fontsize=15)
    ax1.set_ylabel("Z for D(%s, X; %s, %s)" % (mylabel2,mylabel1,out),fontsize=15)
    ax1.axvline(x=0, ls='dashed', c='black')
    ax1.axhline(y=0, ls='dashed', c='black')
    ax1.axvline(x=2, ls='dashed', c='lightgray')
    ax1.axhline(y=2, ls='dashed', c='lightgray')
    ax1.axvline(x=-2, ls='dashed', c='lightgray')
    ax1.axhline(y=-2, ls='dashed', c='lightgray')
#ax1.legend(loc='lower right')
#ax1.legend(handles=handles2,loc=4,ncol=2,fontsize=12.5)
ax1.legend(handles=handles2,loc=4,ncol=4,fontsize=12.5,bbox_to_anchor=(0.5, -0.5))
#ax1.legend(handles=handles1,loc=3)
plt.show()
# Out:
# ['Sherpa']
# ['Tibetan']
# ['Tibetan_ShannanX', 'Tibetan_ChamdoX']
# ['Naxi', 'Yi']
# ['Daur']
# ['Dai']
# ['Han']
# ['Sherpa']
# ['Tibetan']
# ['Tibetan_ShannanX', 'Tibetan_ChamdoX']
# ['Naxi', 'Yi']
# ['Daur']
# ['Dai']
# ['Han']
# ['Sherpa']
# ['Tibetan']
# ['Tibetan_ShannanX', 'Tibetan_ChamdoX']
# ['Naxi', 'Yi']
# ['Daur']
# ['Dai']
# ['Han']
# ['Sherpa']
# ['Tibetan']
# ['Tibetan_ShannanX', 'Tibetan_ChamdoX']
# ['Naxi', 'Yi']
# ['Daur']
# ['Dai']
# ['Han']
# ['Sherpa']
# ['Tibetan']
# ['Tibetan_ShannanX', 'Tibetan_ChamdoX']
# ['Naxi', 'Yi']
# ['Daur']
# ['Dai']
# ['Han']
# ['Sherpa']
# ['Tibetan']
# ['Tibetan_ShannanX', 'Tibetan_ChamdoX']
# ['Naxi', 'Yi']
# ['Daur']
# ['Dai']
# ['Han']
# ['Sherpa']
# ['Tibetan']
# ['Tibetan_ShannanX', 'Tibetan_ChamdoX']
# ['Naxi', 'Yi']
# ['Daur']
# ['Dai']
# ['Han']
# ['Sherpa']
# ['Tibetan']
# ['Tibetan_ShannanX', 'Tibetan_ChamdoX']
# ['Naxi', 'Yi']
# ['Daur']
# ['Dai']
# ['Han']
# ['Sherpa']
# ['Tibetan']
# ...

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
#import matplotlib
import matplotlib.patches as mpatches

agq=["Zongri-a","ZongriM32","Zongri-c","ZongriM78","Zongri-b","ZongriM40","Hedong4",#"XiahaishiM22",
     "Hedong6","Hejiatai","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Hupo-a","Hupo14",
     "Shangluzhuang0","Hupo8","Qunke1","Lajigai-a","Wenpuju03","Jinchankou0",#"Lajigai2",
     "QijiapingM89-2","QijiapingM104-2","QijiapingM108-2","Wuba","HuoshaogouM117","Lierbao0"]
anx=["PukagongmaM1","PukagongmaM3","PukagongmaM5","YushuSGZ-1",#"PukagongmaM2",
     "RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"]
weaklinks=["XiahaishiM22","Lajigai2","PukagongmaM2"]
eas=["Han","Dai","Ami","Daur"]
#eas=["Naxi","Yi","Tu","Tibetan","Sherpa"]
eas=["Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX","Tibetan_NyingchiX",
     "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]
mylabel="aTib"#"cEA/nEA/sEA" #"wEA"
ceas=["Han","She","Miao","Japanese","Korean"]
seas=["Ami","Dai","Lahu","Kinh"]
neas=["Hezhen","Daur","Oroqen","Xibo"]
weas1=["Tu"]
weas2=["Naxi","Yi"]
weas3=["Tibetan","Sherpa"]
luetal=["Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX","Tibetan_NyingchiX",
     "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]
varypops=[ceas, seas, neas, weas1, weas2, weas3, luetal][::-1]
labels=["cEA","sEA","nEA","Tu",'Naxi/Yi',"Tib/Sherpa","TibX/SherpaX"][::-1] #/Papuan/Onge/Oase1
dxcluster=agq+anx#+weaklinks
#dxpairs=[(i,j) for indi,i in enumerate(dxcluster) for indj,j in enumerate(dxcluster) if indi>indj]
#pairlabels=["%s_%s" % mypair for mypair in dxpairs]
#print pairlabels
out="Mbuti"
colors=["blue","brown","red","black","pink","gray","purple"][::-1]
markers=["o","v","s","+","D",">"]
myset1,myset2=(dxcluster,dxcluster)
pDin="/mnt/solexa/mel_yang/aPlateau/update051518/"
pDout="/mnt/solexa/mel_yang/aPlateau/update051518/"
fh,tv=("complete2.dstat.log","")
#fh,tv=("complete.tv.dstat.log",".tv")

fig = plt.figure(figsize=(9,9))
ax1=fig.add_subplot(1,1,1)
handles1,handles2=[],[]
for ind,varypop in enumerate(varypops):
    print varypop
    handles2.append(mpatches.Patch(color=colors[ind], label="X="+labels[ind]))
    for myind in varypop:
        mypops1=[myset1,myind,myset2,out]
        Zaryu = pm.mkDary(pDin,fh,mypops1,(1,3),(0,2),"Z") 
        mypops2=[myset2,myind,myset1,out]
        Zaryl = np.transpose(pm.mkDary(pDin,fh,mypops2,(1,3),(0,2),"Z"))
        #print Zaryu,Zaryl
        ax1.plot(Zaryu,Zaryl,markers[0],color=colors[ind])
        

#ax1.set_ylim((-4,10))
#ax1.set_xlim((-4,10))
ax1.set_xlabel("Z for D(aTib, X; %s, %s)" % (mylabel,out),fontsize=15)
ax1.set_ylabel("Z for D(%s, X; aTib, %s)" % (mylabel,out),fontsize=15)
ax1.axvline(x=0, ls='dashed', c='black')
ax1.axhline(y=0, ls='dashed', c='black')
ax1.axvline(x=2, ls='dashed', c='lightgray')
ax1.axhline(y=2, ls='dashed', c='lightgray')
ax1.axvline(x=-2, ls='dashed', c='lightgray')
ax1.axhline(y=-2, ls='dashed', c='lightgray')
ax1.legend(loc='lower right')
ax1.legend(handles=handles2,loc=4,ncol=2,fontsize=12.5)
#ax1.legend(handles=handles1,loc=3)
plt.show()
# Out:
# ['Tibetan_ChamdoX', 'Tibetan_LhasaX', 'Tibetan_NagquX', 'Tibetan_NyingchiX', 'Tibetan_ShannanX', 'Tibetan_ShigatseX', 'Sherpa_ShigatseX']
# ['Tibetan', 'Sherpa']
# ['Naxi', 'Yi']
# ['Tu']
# ['Hezhen', 'Daur', 'Oroqen', 'Xibo']
# ['Ami', 'Dai', 'Lahu', 'Kinh']
# ['Han', 'She', 'Miao', 'Japanese', 'Korean']
# /home/mel_yang/.local/lib/python2.7/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
import numpy as np
import plateaumodules as pm

pDin="/mnt/solexa/mel_yang/aPlateau/update051518/"
pDout="/mnt/solexa/mel_yang/aPlateau/update051518/"
fh,tv=("complete2.dstat.log","")
#fh,tv=("complete.tv.dstat.log",".tv")
newfh="aPlateau_update0531"+tv
agq=["Zongri-a","ZongriM32","Zongri-c","ZongriM78","Zongri-b","ZongriM40","Hedong4",#"XiahaishiM22",
     "Hedong6","Hejiatai","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Hupo-a","Hupo14",
     "Shangluzhuang0","Hupo8","Qunke1","Lajigai-a","Wenpuju03","Jinchankou0",#"Lajigai2",
     "QijiapingM89-2","QijiapingM104-2","QijiapingM108-2","Wuba","HuoshaogouM117","Lierbao0"]
anx=["PukagongmaM1","PukagongmaM3","PukagongmaM5","YushuSGZ-1",#"PukagongmaM2",
     "RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"]
eas=["Oroqen","Hezhen","Daur","Xibo","Japanese","Korean","Han","She","Miao","Tujia",
    "Dai","Kinh","Lahu","Ami","Atayal","Naxi","Yi","Tu","Tibetan","Sherpa"]
tib=["Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX","Tibetan_NyingchiX",
     "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]


popA,popB,thirdpops,out=(agq+anx,eas+tib,["Zongri-a","Hejiatai","PukagongmaM5"],"Mbuti")

for myind in thirdpops:
    #mypops1=[popA,myind,popB,out]
    mypops2=[popA,popB,myind,out]
    DorZ="Z"

    #newfh1=pDout+newfh+"."+DorZ+"."+"aGQ_%s_aGQ_%s" % (myind,out)
    newfh2=pDout+newfh+"."+DorZ+"."+"aGQ_EA_%s_%s" % (myind,out)
    #Zary = pm.mkDary(pDin,fh,mypops1,(1,3),(0,2),DorZ)   
    #print pm.Zmat2xlsx(Zary,newfh1,popA,popB,0,2)

    Zary = pm.mkDary(pDin,fh,mypops2,(2,3),(0,1),DorZ)    
    print pm.Zmat2xlsx(Zary,newfh2,popA,popB,0,1)
# Out:
# Made /mnt/solexa/mel_yang/aPlateau/update051518/aPlateau_update0531.Z.aGQ_EA_Zongri-a_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/update051518/aPlateau_update0531.Z.aGQ_EA_Hejiatai_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/update051518/aPlateau_update0531.Z.aGQ_EA_PukagongmaM5_Mbuti!

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
pD="/mnt/solexa/mel_yang/aPlateau/update051518/"
fhall="complete2.dstat.log"
fhtv="complete2.tv.dstat.log"
out,out2=("Mbuti","Mbuti")
agq=["Zongri-c","Zongri-b","ZongriM78","ZongriM40","ZongriM32","Zongri-a","Hejiatai",#"XiahaishiM22",
     "Hedong6","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11", 
     "Shangluzhuang0","Wuba","HuoshaogouM117","Hupo-a","Hupo14","Hupo8","Qunke1","Lajigai-a","Wenpuju03","Jinchankou0",#"Lajigai2",
     "Hedong4","QijiapingM89-2","QijiapingM104-2","QijiapingM108-2","Lierbao0",][::-1]
anx=["PukagongmaM1","PukagongmaM5","PukagongmaM3","YushuSGZ-1",#"PukagongmaM2",
     "RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"][::-1]
eas=["Oroqen","Hezhen","Daur","Xibo","Japanese","Korean","Han","She","Miao","Tujia",
    "Dai","Kinh","Lahu","Ami","Atayal","Naxi","Yi","Tu","Tibetan","Sherpa"]
tib=["Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX",
     "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]

mycombo=anx+agq
wantedcolors=["blue"]*len(mycombo)
myxmin=[-0.1]*len(mycombo)
myxmax=[0.05]*len(mycombo)

mysubplot=0
#fig = plt.figure(figsize=(10,5))
fig = plt.figure(figsize=(11,10))

mynames=mycombo
myind="Chokhopani"
varypops=["Han","Dai","Ami","Daur"] 
varypops=["Naxi","Yi","Tu","Tibetan"]
#varypops=["Tibetan_NyingchiX","Tibetan_ChamdoX","Tibetan_ShannanX","Sherpa_ShigatseX"]
ypops=mycombo
mytuples=[(1,3),(0,2)]
for count,varypop in enumerate(varypops):

    #mypops2=[popA,myind,ypops,varypop]
    mypops2=[[varypop],myind,ypops,out]

    Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
    Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
    SEaryall=Daryall/Zaryall 
    
    mynewpops2=mypops2[:-1]+[out2]
    Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
    Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
    SEarytv=Darytv/Zarytv
    
    mylabel="D(%s,%s;%s,%s)" % ('EA',mypops2[1],mypops2[2],mypops2[3])
    mylabel="P1 = %s" % mypops2[0][0]
    #print Daryall
    ax1=fig.add_subplot(1,len(varypops),count+1)
    for ind,i in enumerate(ypops):
        if i in anx: wantedcolors="red"
        else: wantedcolors="blue"
        ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)

        ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[0][ind],ind,'.')
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    if count==0:
        #ax1.text("P2=%s\n" % myind,rotation=90,fontsize=16)
        ax1.set_ylabel("P2=%s\n\nP3" % mypops2[1],rotation=90,fontsize=13)
        ax1.set_yticklabels(mynames,fontsize=12)
    else: 
         
        ax1.set_yticklabels(['']*(len(mynames)),fontsize=0.1)
    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[count],myxmax[count])
    xlabel = ax1.get_xticks().tolist()
    print 'xlabel',xlabel
    ax1.set_xticklabels([""]+xlabel[1:],fontsize=12)

    ax1.set_title(mylabel,fontsize=12)
    #ax1.text(0,len(mynames),mylabel,fontsize=13, horizontalalignment='center', verticalalignment='center',backgroundcolor="white")

    ax1.axvline(x=0, ls='dashed', c='black') #, backgroundcolor="white") 
    for myline in [2.5,7.5,11.5,18.5,23.5,25.5,32.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)

    ax1.set_xlabel("D",fontsize=13)
fig.autofmt_xdate()  
plt.tight_layout()
plt.subplots_adjust(wspace=0.001) 
plt.show()
# Out:
# xlabel [-0.1, -0.05, 0.0, 0.05000000000000002]
# xlabel [-0.1, -0.05, 0.0, 0.05000000000000002]
# xlabel [-0.1, -0.05, 0.0, 0.05000000000000002]
# xlabel [-0.1, -0.05, 0.0, 0.05000000000000002]

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
pD="/mnt/solexa/mel_yang/aPlateau/update051518/"
fhall="complete2.dstat.log"
fhtv="complete2.tv.dstat.log"
out,out2=("Mbuti","Mbuti")
agq=["Zongri-c","Zongri-b","ZongriM78","ZongriM40","ZongriM32","Zongri-a","Hejiatai",#"XiahaishiM22",
     "Hedong6","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11", 
     "Shangluzhuang0","Wuba","HuoshaogouM117","Hupo-a","Hupo14","Hupo8","Qunke1","Lajigai-a","Wenpuju03","Jinchankou0",#"Lajigai2",
     "Hedong4","QijiapingM89-2","QijiapingM104-2","QijiapingM108-2","Lierbao0",][::-1]
anx=["PukagongmaM1","PukagongmaM5","PukagongmaM3","YushuSGZ-1",#"PukagongmaM2",
     "RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"][::-1]
eas=["Oroqen","Hezhen","Daur","Xibo","Japanese","Korean","Han","She","Miao","Tujia",
    "Dai","Kinh","Lahu","Ami","Atayal","Naxi","Yi","Tu","Tibetan","Sherpa"]
tib=["Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX",
     "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]

mycombo=anx+agq
wantedcolors=["blue"]*len(mycombo)
myxmin=[-0.1]*len(mycombo)
myxmax=[0.05]*len(mycombo)

mysubplot=0
#fig = plt.figure(figsize=(10,5))
fig = plt.figure(figsize=(11,10))

mynames=mycombo
myind="Chokhopani"
varypops=["Han","Dai","Ami","Daur"] 
#varypops=["Naxi","Yi","Tu","Tibetan"]
#varypops=["Tibetan_NyingchiX","Tibetan_ChamdoX","Tibetan_ShannanX","Sherpa_ShigatseX"]
ypops=mycombo
mytuples=[(1,3),(0,2)]
for count,varypop in enumerate(varypops):

    #mypops2=[popA,myind,ypops,varypop]
    mypops2=[[varypop],myind,ypops,out]

    Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
    Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
    SEaryall=Daryall/Zaryall 
    
    mynewpops2=mypops2[:-1]+[out2]
    Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
    Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
    SEarytv=Darytv/Zarytv
    
    mylabel="D(%s,%s;%s,%s)" % ('EA',mypops2[1],mypops2[2],mypops2[3])
    mylabel="P1 = %s" % mypops2[0][0]
    #print Daryall
    ax1=fig.add_subplot(1,len(varypops),count+1)
    for ind,i in enumerate(ypops):
        if i in anx: wantedcolors="red"
        else: wantedcolors="blue"
        ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)

        ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[0][ind],ind,'.')
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    if count==0:
        #ax1.text("P2=%s\n" % myind,rotation=90,fontsize=16)
        ax1.set_ylabel("P2=%s\n\nP3" % mypops2[1],rotation=90,fontsize=13)
        ax1.set_yticklabels(mynames,fontsize=12)
    else: 
         
        ax1.set_yticklabels(['']*(len(mynames)),fontsize=0.1)
    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[count],myxmax[count])
    xlabel = ax1.get_xticks().tolist()
    print 'xlabel',xlabel
    ax1.set_xticklabels([""]+xlabel[1:],fontsize=12)

    ax1.set_title(mylabel,fontsize=12)
    #ax1.text(0,len(mynames),mylabel,fontsize=13, horizontalalignment='center', verticalalignment='center',backgroundcolor="white")

    ax1.axvline(x=0, ls='dashed', c='black') #, backgroundcolor="white") 
    for myline in [2.5,7.5,11.5,18.5,23.5,25.5,32.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)

    ax1.set_xlabel("D",fontsize=13)
fig.autofmt_xdate()  
plt.tight_layout()
plt.subplots_adjust(wspace=0.001) 
plt.show()
# Out:
# xlabel [-0.1, -0.05, 0.0, 0.05000000000000002]
# xlabel [-0.1, -0.05, 0.0, 0.05000000000000002]
# xlabel [-0.1, -0.05, 0.0, 0.05000000000000002]
# xlabel [-0.1, -0.05, 0.0, 0.05000000000000002]

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
pD="/mnt/solexa/mel_yang/aPlateau/update051518/"
fhall="complete2.dstat.log"
fhtv="complete2.tv.dstat.log"
out,out2=("Mbuti","Mbuti")
agq=["Zongri-b","Zongri-c","ZongriM78","ZongriM40","ZongriM32","Zongri-a","Hejiatai",#"XiahaishiM22",
     "Hedong6","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11", 
     "Shangluzhuang0","Wuba","HuoshaogouM117","Hupo-a","Hupo14",
     "Hupo8","Qunke1","Lajigai-a","Lierbao0","Hedong4","Wenpuju03","Jinchankou0",#"Lajigai2",
     "QijiapingM89-2","QijiapingM104-2","QijiapingM108-2",][::-1]
anx=["PukagongmaM1","PukagongmaM5","PukagongmaM3","YushuSGZ-1",#"PukagongmaM2",
     "RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"][::-1]
eas=["Oroqen","Hezhen","Daur","Xibo","Japanese","Korean","Han","She","Miao","Tujia",
    "Dai","Kinh","Lahu","Ami","Atayal","Naxi","Yi","Tu","Tibetan","Sherpa"]
tib=["Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX",
     "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]

mycombo=anx+agq
wantedcolors=["blue"]*len(mycombo)
myxmin=[-0.05]*len(mycombo)
myxmax=[0.05]*len(mycombo)

mysubplot=0
#fig = plt.figure(figsize=(10,5))
fig = plt.figure(figsize=(11,10))

mynames=mycombo
myind="Daxiang0"
varypops=["Han","Dai","Ami","Daur"] 
varypops=["Han","Yi","Tu","Tibetan"] 
#varypops=["Naxi","Yi","Tu","Tibetan"]
#varypops=["Tibetan_NyingchiX","Tibetan_ChamdoX","Tibetan_ShannanX","Sherpa_ShigatseX"]
ypops=mycombo
mytuples=[(1,3),(0,2)]
for count,varypop in enumerate(varypops):

    #mypops2=[popA,myind,ypops,varypop]
    mypops2=[ypops,myind,[varypop],out]

    Zaryall = np.transpose(pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z'))
    Daryall = np.transpose(pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D'))
    SEaryall=Daryall/Zaryall 
    
    mynewpops2=mypops2[:-1]+[out2]
    Zarytv = np.transpose(pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z'))
    Darytv = np.transpose(pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D'))
    SEarytv=Darytv/Zarytv
    
    mylabel="D(%s,%s;%s,%s)" % (mypops2[2],mypops2[1],'EA',mypops2[3])
    mylabel="P3 = %s" % mypops2[2][0]
    #print Daryall
    ax1=fig.add_subplot(1,len(varypops),count+1)
    for ind,i in enumerate(ypops):
        if i in anx: wantedcolors="red"
        else: wantedcolors="blue"
        ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)

        ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[0][ind],ind,'.')
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    if count==0:
        #ax1.text("P2=%s\n" % myind,rotation=90,fontsize=16)
        ax1.set_ylabel("P2=%s\n\nP1" % mypops2[1],rotation=90,fontsize=13)
        ax1.set_yticklabels(mynames,fontsize=12)
    else: 
         
        ax1.set_yticklabels(['']*(len(mynames)),fontsize=0.1)
    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[count],myxmax[count])
    xlabel = ax1.get_xticks().tolist()
    print 'xlabel',xlabel
    #ax1.set_xticklabels(xlabel,fontsize=12) #[""]+xlabel[1:]

    ax1.set_title(mylabel,fontsize=12)
    #ax1.text(0,len(mynames),mylabel,fontsize=13, horizontalalignment='center', verticalalignment='center',backgroundcolor="white")

    ax1.axvline(x=0, ls='dashed', c='black') #, backgroundcolor="white") 
    for myline in [2.5,7.5,11.5,18.5,23.5,25.5,32.5,33.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)

    ax1.set_xlabel("D",fontsize=13)
fig.autofmt_xdate()  
plt.tight_layout()
plt.subplots_adjust(wspace=0.001) 
plt.show()
# Out:
# xlabel [-0.05, -0.025, 0.0, 0.02500000000000001, 0.05]
# xlabel [-0.05, -0.025, 0.0, 0.02500000000000001, 0.05]
# xlabel [-0.05, -0.025, 0.0, 0.02500000000000001, 0.05]
# xlabel [-0.05, -0.025, 0.0, 0.02500000000000001, 0.05]

# %%
import numpy as np
import plateaumodules as pm

pDin="/mnt/solexa/mel_yang/aPlateau/update051518/"
indpd="/mnt/solexa/mel_yang/data/2.2M/individuals/"
pDout="/mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/"
fh,tv,sd=("complete2.dstat.log","","False")
newfh="aPlateau_update051518"+tv
#sgdpfile=open(indpd+"SGDP_ASN.txt",'r')
#sgdp=[line.split()[0] for line in sgdpfile if line[0] !="#"]
#sgdpfile.close()
#sgdpfile=open(indpd+"SGDP_SASNEUR.txt",'r')
#sgdp+=[line.split()[0] for line in sgdpfile if line[0] !="#"]
#sgdpfile.close()
agq=["Hejiatai","Hedong6","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Shangluzhuang0","Hupo-a",
     "Zongri-a","ZongriM40","ZongriM32","Zongri-b","Zongri-c","ZongriM78","Wuba","HuoshaogouM117",
     "Lajigai-a","Hupo14","Hupo8","Qunke1",
     "Wenpuju03","QijiapingM89-2","QijiapingM108-2","QijiapingM104-2","Jinchankou0","Lierbao0","Hedong4",]
anx=["PukagongmaM1","PukagongmaM5","PukagongmaM3",#"PukagongmaM2",
     "RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","YushuSGZ-1",
     "CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"]

popA,popB,thirdpops,out=(agq+anx,agq+anx,["Atayal","Onge","Jomon","MOS4","MOS5","Itelman","Kolyma_River","Boisman_MN","Yakut","Even"],"Mbuti")

for myind in thirdpops:
    print myind
    mypops1=[popA,myind,popB,out]
    mypops2=[popA,popB,myind,out]
    DorZ="Z"

    newfh1=pDout+newfh+"."+DorZ+"."+"aGQaNX_%s_aGQaNX_%s" % (myind,out)
    newfh2=pDout+newfh+"."+DorZ+"."+"aGQaNX_aGQaNX_%s_%s" % (myind,out)
    Zary = pm.mkDary(pDin,fh,mypops1,(1,3),(0,2),DorZ,sd=sd)   
    print pm.Zmat2xlsx(Zary,newfh1,popA,popB,0,2)

    Zary = pm.mkDary(pDin,fh,mypops2,(2,3),(0,1),DorZ,sd=sd)    
    print pm.Zmat2xlsx(Zary,newfh2,popA,popB,0,1)
# Out:
# Atayal
# Made /mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/aPlateau_update051518.Z.aGQaNX_Atayal_aGQaNX_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/aPlateau_update051518.Z.aGQaNX_aGQaNX_Atayal_Mbuti!
# Onge
# Made /mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/aPlateau_update051518.Z.aGQaNX_Onge_aGQaNX_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/aPlateau_update051518.Z.aGQaNX_aGQaNX_Onge_Mbuti!
# Jomon
# Made /mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/aPlateau_update051518.Z.aGQaNX_Jomon_aGQaNX_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/aPlateau_update051518.Z.aGQaNX_aGQaNX_Jomon_Mbuti!
# MOS4
# Made /mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/aPlateau_update051518.Z.aGQaNX_MOS4_aGQaNX_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/aPlateau_update051518.Z.aGQaNX_aGQaNX_MOS4_Mbuti!
# MOS5
# ...

# %%
import numpy as np
import plateaumodules as pm

pDin="/mnt/solexa/mel_yang/aPlateau/update051518/"
#pDin="/mnt/solexa/mel_yang/masterlogfiles/UPA_all15/"
indpd="/mnt/solexa/mel_yang/data/2.2M/individuals/"
pDout="/mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/"
fh,tv,sd=("complete2.dstat.log","","False")
#fh,tv,sd=("UPA_all15.D.External_lipson_narasimhanetal2018-ANCTIB_luetal2016.log","","True")

newfh="aPlateau_update051518"+tv
agq=["Hejiatai","Hedong6","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Shangluzhuang0","Hupo-a",
     "Zongri-a","ZongriM40","ZongriM32","Zongri-b","Zongri-c","ZongriM78","Wuba","HuoshaogouM117",
     "Lajigai-a","Hupo14","Hupo8","Qunke1",
     "Wenpuju03","QijiapingM89-2","QijiapingM108-2","QijiapingM104-2","Jinchankou0","Lierbao0","Hedong4",]
anx=["PukagongmaM1","PukagongmaM5","PukagongmaM3",#"PukagongmaM2",
     "RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","YushuSGZ-1",
     "CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"]
otherasn=["Naxi","Yi","Tibetan_ShannanX","Sherpa_ShigatseX","Tu","Hezhen","Daur",
          "Han","Dai","Ami","Atayal","Onge","Jomon","Boisman_MN","MOS4","MOS5",
          "Kolyma_River","Itelman","Yakut","Even"]
aSEA=["Man_Bac","Nui_Nap","Oakaie1","Ban_Chiang","Vat_Komnou"]
awnx=["Chokhopani","Mebrak","Samdzong"]
popA,popB,thirdpops,out=(agq+anx,aSEA,["Chokhopani","Mebrak","Samdzong"],"Mbuti")
popA,popB,thirdpops,out=(agq+anx,agq+anx,["RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","YushuSGZ-1","Jinchankou0","Lajigai-a","Wenpuju03","QijiapingM108-2"],"Mbuti")
for myind in thirdpops:
    print myind
    mypops1=[myind,popB,popA,out]
    mypops2=[popA,popB,myind,out]
    mypops3=[popA,myind,popB,out]
    DorZ="Z"

    newfh1=pDout+newfh+"."+DorZ+"."+"%s_aGQNX_aGQNX_%s" % (myind,out)
    newfh2=pDout+newfh+"."+DorZ+"."+"aGQNX_aGQNX_%s_%s" % (myind,out)
    newfh3=pDout+newfh+"."+DorZ+"."+"aGQNX_%s_aGQNX_%s" % (myind,out)
    #Zary = np.transpose(pm.mkDary(pDin,fh,mypops1,(0,3),(1,2),DorZ,sd=sd))   
    #print pm.Zmat2xlsx(Zary,newfh1,popA,popB,2,1)

    Zary = pm.mkDary(pDin,fh,mypops2,(2,3),(0,1),DorZ,sd=sd)    
    print pm.Zmat2xlsx(Zary,newfh2,popA,popB,0,1)
    
    #Zary = pm.mkDary(pDin,fh,mypops3,(1,3),(0,2),DorZ,sd=sd)    
    #print pm.Zmat2xlsx(Zary,newfh3,popA,popB,0,2)
# Out:
# RedilongM3
# Made /mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/aPlateau_update051518.Z.aGQNX_aGQNX_RedilongM3_Mbuti!
# XiaoendaM1
# Made /mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/aPlateau_update051518.Z.aGQNX_aGQNX_XiaoendaM1_Mbuti!
# XiaoendaM2
# Made /mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/aPlateau_update051518.Z.aGQNX_aGQNX_XiaoendaM2_Mbuti!
# Butaxiongqu
# Made /mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/aPlateau_update051518.Z.aGQNX_aGQNX_Butaxiongqu_Mbuti!
# YushuSGZ-1
# Made /mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/aPlateau_update051518.Z.aGQNX_aGQNX_YushuSGZ-1_Mbuti!
# Jinchankou0
# Made /mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/aPlateau_update051518.Z.aGQNX_aGQNX_Jinchankou0_Mbuti!
# Lajigai-a
# Made /mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/aPlateau_update051518.Z.aGQNX_aGQNX_Lajigai-a_Mbuti!
# Wenpuju03
# ...

# %%
import numpy as np
import plateaumodules as pm

pDin="/mnt/solexa/mel_yang/aPlateau/update051518/"
indpd="/mnt/solexa/mel_yang/data/2.2M/individuals/"
pDout="/mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/"
fh,tv,sd=("complete2.dstat.log","","False")
newfh="aPlateau_update051518"+tv
sgdpfile=open(indpd+"SGDP_ASN.txt",'r')
sgdp=[line.split()[0] for line in sgdpfile if line[0] !="#"]
sgdpfile.close()
sgdpfile=open(indpd+"SGDP_SASNEUR.txt",'r')
sgdp+=[line.split()[0] for line in sgdpfile if line[0] !="#"]
sgdpfile.close()
agq=["Hejiatai","Hedong6","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Shangluzhuang0","Hupo-a",
     "Zongri-a","ZongriM40","ZongriM32","Zongri-b","Zongri-c","ZongriM78","Wuba","HuoshaogouM117",
     "Lajigai-a","Hupo14","Hupo8","Qunke1",
     "Wenpuju03","QijiapingM89-2","QijiapingM108-2","QijiapingM104-2","Jinchankou0","Lierbao0","Hedong4",]
anx=["PukagongmaM1","PukagongmaM5","PukagongmaM3",#"PukagongmaM2",
     "RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","YushuSGZ-1",
     "CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"]

popA,popB,thirdpops,out=(sgdp,agq+anx,["Han"],"Mbuti")

for myind in thirdpops:
    print myind
    mypops1=[popA,myind,popB,out]
    #mypops2=[popA,popB,myind,out]
    DorZ="Z"

    newfh1=pDout+newfh+"."+DorZ+"."+"SGDP_%s_aGQaNX_%s" % (myind,out)
    #newfh2=pDout+newfh+"."+DorZ+"."+"aGQaNX_aGQaNX_%s_%s" % (myind,out)
    Zary = pm.mkDary(pDin,fh,mypops1,(1,3),(0,2),DorZ,sd=sd)   
    print pm.Zmat2xlsx(Zary,newfh1,popA,popB,0,2)

    #Zary = pm.mkDary(pDin,fh,mypops2,(2,3),(0,1),DorZ,sd=sd)    
    #print pm.Zmat2xlsx(Zary,newfh2,popA,popB,0,1)
# Out:
# Han
# Made /mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/aPlateau_update051518.Z.SGDP_Han_aGQaNX_Mbuti!

# %%
import numpy as np
import plateaumodules as pm

pDin="/mnt/solexa/mel_yang/aPlateau/update051518/"
#indpd="/mnt/solexa/mel_yang/data/2.2M/individuals/"
pDout="/mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/"
fh,tv,sd=("complete2.dstat.log","","False")

#pDin="/mnt/solexa/mel_yang/masterlogfiles/UPA_all15/"
#fh,tv,sd=("UPA_all15.D.External3_lipson_narasimhanetal2018-ANCTIB_luetal2016-SGDP_SASNEUR.log","","True")

newfh="aPlateau_update051518"+tv

agq=["Hejiatai","Hedong6","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Shangluzhuang0","Hupo-a",
     "Zongri-a","ZongriM40","ZongriM32","Zongri-b","Zongri-c","ZongriM78","Wuba","HuoshaogouM117",
     "Lajigai-a","Hupo14","Hupo8","Qunke1",
     "Wenpuju03","QijiapingM89-2","QijiapingM108-2","QijiapingM104-2","Jinchankou0","Lierbao0","Hedong4",]
anx=["PukagongmaM1","PukagongmaM5","PukagongmaM3",#"PukagongmaM2",
     "RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","YushuSGZ-1",
     "CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"]
eas=["Han","Daur","Ami","Dai","Tu","Naxi","Yi","Tibetan","Sherpa"]
tib=["Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX",
     "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]
SArel=["Gonur2_BA","Shahr_I_Sokhta_BA2","Shahr_I_Sokhta_BA3","Srubnaya","Sintashta_MLBA","Petrovka"]

popA,popB,thirdpops,out=(SArel,eas,["Punjabi","Mala"],"Mbuti")

for myind in thirdpops:
    print myind
    mypops1=[popA,myind,popB,out]
    #mypops2=[popA,popB,myind,out]
    DorZ="Z"

    newfh1=pDout+newfh+"."+DorZ+"."+"SArel_%s_EA_%s" % (myind,out)
    #newfh2=pDout+newfh+"."+DorZ+"."+"aGQaNX_aGQaNX_%s_%s" % (myind,out)
    Zary = np.transpose(pm.mkDary(pDin,fh,mypops1,(1,3),(0,2),DorZ,sd=sd)) 
    print pm.Zmat2xlsx(Zary,newfh1,popB,popA,2,0)

    #Zary = pm.mkDary(pDin,fh,mypops2,(2,3),(0,1),DorZ,sd=sd)    
    #print pm.Zmat2xlsx(Zary,newfh2,popA,popB,0,1)
# Out:
# Punjabi
# Made /mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/aPlateau_update051518.Z.Onge_Punjabi_aGQaNX_Mbuti!
# Mala
# Made /mnt/solexa/mel_yang/aPlateau/update051518/maindraft_test/aPlateau_update051518.Z.Onge_Mala_aGQaNX_Mbuti!

# %%
import numpy as np
import plateaumodules as pm

pDin="/mnt/solexa/mel_yang/aPlateau/update051518/"
pDout="/mnt/solexa/mel_yang/aPlateau/update051518/D_aGQ_EAS_aGQ_Out/"
fh,tv,sd=("complete2.dstat.log","","False")
pDin="/mnt/solexa/mel_yang/masterlogfiles/UPA_all15/"
pDout="/mnt/solexa/mel_yang/aPlateau/update051518/D_aTib_SA+SEA/"
#fh,tv,sd=("UPA_all15.D.External_lipson_narasimhanetal2018-ANCTIB_luetal2016.log","","True")
#fh,tv=("complete.tv.dstat.log",".tv")
fh,tv,sd=("UPA_all15.D.External3_lipson_narasimhanetal2018-SGDP_ASN-SGDP_SASNEUR.log","","True")
newfh="aPlateau_update051518"+tv
agq=["Zongri-a","ZongriM32","Zongri-c","ZongriM78","Zongri-b","ZongriM40","Hedong4","XiahaishiM22",
     "Hedong6","Hejiatai","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Hupo-a","Hupo14",
     "Shangluzhuang0","Hupo8","Qunke1","Lajigai-a","Lajigai2","Wenpuju03","Jinchankou0",
     "QijiapingM89-2","QijiapingM104-2","QijiapingM108-2","Wuba","HuoshaogouM117","Lierbao0"]
agq=["Zongri-b","Zongri-c","ZongriM78","ZongriM32","ZongriM40","Zongri-a",
     "Hejiatai","Hedong6","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Shangluzhuang0",
     "Hupo-a","Lajigai-a","HuoshaogouM117","Wuba","Hupo14","Hupo8","Qunke1",
     "Jinchankou0","Wenpuju03","QijiapingM89-2","QijiapingM108-2","QijiapingM104-2","Lierbao0","Hedong4",]
anx=["PukagongmaM1","PukagongmaM5","PukagongmaM3","YushuSGZ-1",#"PukagongmaM2",
     "RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"][::-1]

eas=["Han","Daur","Ami","Dai","Tu","Naxi","Yi","Tibetan","Sherpa"]
tib=["Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX",
     "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]
sa=["Punjabi","Mala"]
aSEA=["Man_Bac","Nui_Nap","Oakaie1","Ban_Chiang","Vat_Komnou"]
aTuran=["Gonur1_BA","Shahr_I_Sokhta_BA1","Gonur1_BA_o2","Gonur1_BA_o"]
IP=["Gonur2_BA","Shahr_I_Sokhta_BA2","Shahr_I_Sokhta_BA3"]
AASI=["Onge"]
steppe=["Srubnaya","Sintashta_MLBA","Petrovka"]

popA,popB,thirdpops,out=(IP+steppe,eas,sa,"Mbuti")

for myind in thirdpops:
    print myind
    mypops1=[popA,myind,popB,out]
    mypops2=[popA,popB,myind,out]
    DorZ="Z"

    newfh1=pDout+newfh+"."+DorZ+"."+"SArel_%s_EA_%s" % (myind,out)
    newfh2=pDout+newfh+"."+DorZ+"."+"SArel_EA_%s_%s" % (myind,out)
    Zary = pm.mkDary(pDin,fh,mypops1,(1,3),(0,2),DorZ,sd=sd)   
    print pm.Zmat2xlsx(Zary,newfh1,popA,popB,0,2)

    Zary = pm.mkDary(pDin,fh,mypops2,(2,3),(0,1),DorZ,sd=sd)    
    print pm.Zmat2xlsx(Zary,newfh2,popA,popB,0,1)
# Out:
# Punjabi
# Made /mnt/solexa/mel_yang/aPlateau/update051518/D_aTib_SA+SEA/aPlateau_update051518.Z.SArel_Punjabi_EA_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/update051518/D_aTib_SA+SEA/aPlateau_update051518.Z.SArel_EA_Punjabi_Mbuti!
# Mala
# Made /mnt/solexa/mel_yang/aPlateau/update051518/D_aTib_SA+SEA/aPlateau_update051518.Z.SArel_Mala_EA_Mbuti!
# Made /mnt/solexa/mel_yang/aPlateau/update051518/D_aTib_SA+SEA/aPlateau_update051518.Z.SArel_EA_Mala_Mbuti!

# %%
import numpy as np
import plateaumodules as pm

pDin="/mnt/solexa/mel_yang/aPlateau/update051518/"
pDout="/mnt/solexa/mel_yang/aPlateau/update051518/D_aGQ_EAS_aGQ_Out/"
fh,tv,sd=("complete2.dstat.log","","False")
pDin="/mnt/solexa/mel_yang/masterlogfiles/UPA_all15/"
pDout="/mnt/solexa/mel_yang/aPlateau/update051518/D_aTib_SA+SEA/"
#fh,tv,sd=("UPA_all15.D.External_lipson_narasimhanetal2018-ANCTIB_luetal2016.log","","True")
#fh,tv=("complete.tv.dstat.log",".tv")
fh,tv,sd=("UPA_all15.D.External3_lipson_narasimhanetal2018-ANCTIB_luetal2016-SGDP_ASN.log","","True")
newfh="aPlateau_update051518"+tv
agq=["Zongri-a","ZongriM32","Zongri-c","ZongriM78","Zongri-b","ZongriM40","Hedong4","XiahaishiM22",
     "Hedong6","Hejiatai","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Hupo-a","Hupo14",
     "Shangluzhuang0","Hupo8","Qunke1","Lajigai-a","Lajigai2","Wenpuju03","Jinchankou0",
     "QijiapingM89-2","QijiapingM104-2","QijiapingM108-2","Wuba","HuoshaogouM117","Lierbao0"]
agq=["Zongri-b","Zongri-c","ZongriM78","ZongriM32","ZongriM40","Zongri-a",
     "Hejiatai","Hedong6","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Shangluzhuang0",
     "Hupo-a","Lajigai-a","HuoshaogouM117","Wuba","Hupo14","Hupo8","Qunke1",
     "Jinchankou0","Wenpuju03","QijiapingM89-2","QijiapingM108-2","QijiapingM104-2","Lierbao0","Hedong4",]
anx=["PukagongmaM1","PukagongmaM5","PukagongmaM3","YushuSGZ-1",#"PukagongmaM2",
     "RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"][::-1]

eas=["Han","Daur","Ami","Dai","Tu","Naxi","Yi","Tibetan","Sherpa"]
tib=["Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX",
     "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]
sa=["Punjabi","Mala"]
aSEA=["Man_Bac","Nui_Nap","Oakaie1","Ban_Chiang","Vat_Komnou"]
aTuran=["Gonur1_BA","Shahr_I_Sokhta_BA1","Gonur1_BA_o2","Gonur1_BA_o"]
IP=["Gonur2_BA","Shahr_I_Sokhta_BA2","Shahr_I_Sokhta_BA3"]
AASI=["Onge"]
steppe=["Srubnaya","Sintashta_MLBA","Petrovka"]

popA,popB,thirdpops,out=(agq+anx,eas+tib,IP+steppe,"Mbuti")

for myind in thirdpops:
    print myind
    mypops1=[popA,myind,popB,out]
    mypops2=[popA,popB,myind,out]
    DorZ="Z"

    #newfh1=pDout+newfh+"."+DorZ+"."+"SArel_%s_EA_%s" % (myind,out)
    newfh2=pDout+newfh+"."+DorZ+"."+"aTib_EA_%s_%s" % (myind,out)
    #Zary = pm.mkDary(pDin,fh,mypops1,(1,3),(0,2),DorZ,sd=sd)   
    #print pm.Zmat2xlsx(Zary,newfh1,popA,popB,0,2)

    Zary = pm.mkDary(pDin,fh,mypops2,(2,3),(0,1),DorZ,sd=sd)    
    print pm.Zmat2xlsx(Zary,newfh2,popA,popB,0,1)
# Out:
# Gonur2_BA
# Made /mnt/solexa/mel_yang/aPlateau/update051518/D_aTib_SA+SEA/aPlateau_update051518.Z.aTib_EA_Gonur2_BA_Mbuti!
# Shahr_I_Sokhta_BA2
# Made /mnt/solexa/mel_yang/aPlateau/update051518/D_aTib_SA+SEA/aPlateau_update051518.Z.aTib_EA_Shahr_I_Sokhta_BA2_Mbuti!
# Shahr_I_Sokhta_BA3
# Made /mnt/solexa/mel_yang/aPlateau/update051518/D_aTib_SA+SEA/aPlateau_update051518.Z.aTib_EA_Shahr_I_Sokhta_BA3_Mbuti!
# Srubnaya
# Made /mnt/solexa/mel_yang/aPlateau/update051518/D_aTib_SA+SEA/aPlateau_update051518.Z.aTib_EA_Srubnaya_Mbuti!
# Sintashta_MLBA
# Made /mnt/solexa/mel_yang/aPlateau/update051518/D_aTib_SA+SEA/aPlateau_update051518.Z.aTib_EA_Sintashta_MLBA_Mbuti!
# Petrovka
# Made /mnt/solexa/mel_yang/aPlateau/update051518/D_aTib_SA+SEA/aPlateau_update051518.Z.aTib_EA_Petrovka_Mbuti!

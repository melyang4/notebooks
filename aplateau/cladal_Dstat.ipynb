# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib


#agq=["Zongri1a","Zongri23",
agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",][::-1]
wantedcolors=["blue"]*len(agq)
myxmin=[-0.2]*2
myxmax=[0.06]*2
mysubplot=0
fig = plt.figure(figsize=(20,5))

pD="/mnt/solexa/mel_yang/aPlateau/"
fhall="aPlateau.dstat.log"
fhtv="aPlateau.tv.dstat.log"
out,out2=("Mbuti","Mbuti")

#fhtv="aPlateau.dstat.log"
#out,out2=("Mbuti","Chimp")

popA=agq
popB=["Xiahaishi"]
myind="Shangluzhuang"
mypops2s=[[popA,popB,myind,out],[popA,myind,popB,out]]
mylabels=["D(%s,%s;%s,%s)" % ('aGQ',popB[0],myind,out),"D(%s,%s;%s,%s)" % ('aGQ',myind,popB[0],out)]
mytuples=[[(2,3),(0,1)],[(1,3),(0,2)]]
for count,mypops2 in enumerate(mypops2s):
    #print mypops2


    #tv='all'
    #mypops2=[popA,popB,myind,out]
    Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[count][0],mytuples[count][1],'Z')
    Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[count][0],mytuples[count][1],'D')
    SEaryall=Daryall/Zaryall 
    
    mynewpops2=mypops2[:-1]+[out2]
    Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[count][0],mytuples[count][1],'Z')
    Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[count][0],mytuples[count][1],'D')
    SEarytv=Darytv/Zarytv
    
    mylabel=mylabels[count]
    mynames=agq
    
    ax1=fig.add_subplot(1,len(mypops2s)*2,count+1)
    for ind,i in enumerate(agq):
        #print tyD[i]
        #print Dary[ind][0]
        ax1.errorbar(Darytv[ind][0],ind,xerr=SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[ind][0],ind,xerr=2*SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[ind],ind,'.',alpha=0.05)

        ax1.errorbar(Daryall[ind][0],ind,xerr=SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[ind][0],ind,xerr=2*SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[ind],ind,'.')
        
    #ax1.set_yticks(len(mynames))
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    if count==0:
        ax1.set_yticklabels(mynames,fontsize=16)
    else: 
        ax1.set_yticklabels([' ']*len(mynames),fontsize=3)

    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[count],myxmax[count])

    xlabel = ax1.get_xticks().tolist()
    ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)

    ax1.set_title(mylabel,fontsize=15)

    ax1.axvline(x=0, ls='dashed', c='black')
    for myline in [10.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)
    ax1.set_xlabel("D",fontsize=15)
    #ax1.set_xlabel("D, %s" % tv,fontsize=15)

wantedcolors=["blue"]*len(agq)
myxmin=[-0.2]*2
myxmax=[0.06]*2
mysubplot=0

popA=agq
popB=["Daxiang"]
myind="Shangluzhuang"
mypops2s=[[popA,popB,myind,out],[popA,myind,popB,out]]
mylabels=["D(%s,%s;%s,%s)" % ('aGQ',popB[0],myind,out),"D(%s,%s;%s,%s)" % ('aGQ',myind,popB[0],out)]
mytuples=[[(2,3),(0,1)],[(1,3),(0,2)]]
for count,mypops2 in enumerate(mypops2s):

    Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[count][0],mytuples[count][1],'Z')
    Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[count][0],mytuples[count][1],'D')
    SEaryall=Daryall/Zaryall 
    
    mynewpops2=mypops2[:-1]+[out2]

    Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[count][0],mytuples[count][1],'Z')
    Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[count][0],mytuples[count][1],'D')
    SEarytv=Darytv/Zarytv
    
    mylabel=mylabels[count]
    mynames=agq
    
    ax1=fig.add_subplot(1,len(mypops2s)*2,count+3)
    for ind,i in enumerate(agq):
        #print tyD[i]
        #print Dary[ind][0]
        ax1.errorbar(Darytv[ind][0],ind,xerr=SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[ind][0],ind,xerr=3*SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[ind],ind,'.',alpha=0.05)

        ax1.errorbar(Daryall[ind][0],ind,xerr=SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[ind][0],ind,xerr=3*SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[ind],ind,'.')
        
    #ax1.set_yticks(len(mynames))
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    #if count==0:
    #    ax1.set_yticklabels(mynames,fontsize=16)
    #else: 
    ax1.set_yticklabels([' ']*len(mynames),fontsize=3)

    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[count],myxmax[count])

    xlabel = ax1.get_xticks().tolist()
    ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)

    ax1.set_title(mylabel,fontsize=15)

    ax1.axvline(x=0, ls='dashed', c='black')
    for myline in [10.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)
    ax1.set_xlabel("D",fontsize=15)
    #ax1.set_xlabel("D, %s" % tv,fontsize=15)    
    
plt.tight_layout()
plt.show()

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib


agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",][::-1]
wantedcolors=["blue"]*len(agq)
myxmin=[-0.07]*2
myxmax=[0.07]*2
mysubplot=0
fig = plt.figure(figsize=(20,5))

pD="/mnt/solexa/mel_yang/aPlateau/"
fhall="aPlateau.dstat.log"
fhtv="aPlateau.tv.dstat.log"
out,out2=("Mbuti","Mbuti")

fhtv="aPlateau.dstat.log"
out,out2=("Mbuti","Chimp")

popA=agq
popB=["Qijiaping"]
myind="Jinchankou"
mypops2s=[[popA,popB,myind,out],[popA,myind,popB,out]]
mylabels=["D(%s,%s;%s,%s)" % ('aGQ',popB[0],myind,out),"D(%s,%s;%s,%s)" % ('aGQ',myind,popB[0],out)]
mytuples=[[(2,3),(0,1)],[(1,3),(0,2)]]
for count,mypops2 in enumerate(mypops2s):
    #print mypops2


    #tv='all'
    #mypops2=[popA,popB,myind,out]
    Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[count][0],mytuples[count][1],'Z')
    Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[count][0],mytuples[count][1],'D')
    SEaryall=Daryall/Zaryall 
    
    mynewpops2=mypops2[:-1]+[out2]
    Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[count][0],mytuples[count][1],'Z')
    Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[count][0],mytuples[count][1],'D')
    SEarytv=Darytv/Zarytv
    
    mylabel=mylabels[count]
    mynames=agq
    
    ax1=fig.add_subplot(1,len(mypops2s)*2,count+1)
    for ind,i in enumerate(agq):
        #print tyD[i]
        #print Dary[ind][0]
        ax1.errorbar(Darytv[ind][0],ind,xerr=SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[ind][0],ind,xerr=2*SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[ind],ind,'.',alpha=0.05)

        ax1.errorbar(Daryall[ind][0],ind,xerr=SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[ind][0],ind,xerr=2*SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[ind],ind,'.')
        
    #ax1.set_yticks(len(mynames))
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    if count==0:
        ax1.set_yticklabels(mynames,fontsize=16)
    else: 
        ax1.set_yticklabels([' ']*len(mynames),fontsize=3)

    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[count],myxmax[count])

    xlabel = ax1.get_xticks().tolist()
    ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)

    ax1.set_title(mylabel,fontsize=15)

    ax1.axvline(x=0, ls='dashed', c='black')
    for myline in [10.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)
    ax1.set_xlabel("D",fontsize=15)
    #ax1.set_xlabel("D, %s" % tv,fontsize=15)

wantedcolors=["blue"]*len(agq)
myxmin=[-0.1]*2
myxmax=[0.1]*2
mysubplot=0

popA=agq
popB=["Qijiaping"]
myind="Shannashuzha"
mypops2s=[[popA,popB,myind,out],[popA,myind,popB,out]]
mylabels=["D(%s,%s;%s,%s)" % ('aGQ',popB[0],myind,out),"D(%s,%s;%s,%s)" % ('aGQ',myind,popB[0],out)]
mytuples=[[(2,3),(0,1)],[(1,3),(0,2)]]
for count,mypops2 in enumerate(mypops2s):

    Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[count][0],mytuples[count][1],'Z')
    Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[count][0],mytuples[count][1],'D')
    SEaryall=Daryall/Zaryall 
    
    mynewpops2=mypops2[:-1]+[out2]

    Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[count][0],mytuples[count][1],'Z')
    Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[count][0],mytuples[count][1],'D')
    SEarytv=Darytv/Zarytv
    
    mylabel=mylabels[count]
    mynames=agq
    
    ax1=fig.add_subplot(1,len(mypops2s)*2,count+3)
    for ind,i in enumerate(agq):
        #print tyD[i]
        #print Dary[ind][0]
        ax1.errorbar(Darytv[ind][0],ind,xerr=SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[ind][0],ind,xerr=2*SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[ind],ind,'.',alpha=0.05)

        ax1.errorbar(Daryall[ind][0],ind,xerr=SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[ind][0],ind,xerr=2*SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[ind],ind,'.')
        
    #ax1.set_yticks(len(mynames))
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    #if count==0:
    #    ax1.set_yticklabels(mynames,fontsize=16)
    #else: 
    ax1.set_yticklabels([' ']*len(mynames),fontsize=3)

    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[count],myxmax[count])

    xlabel = ax1.get_xticks().tolist()
    ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)

    ax1.set_title(mylabel,fontsize=15)

    ax1.axvline(x=0, ls='dashed', c='black')
    for myline in [10.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)
    ax1.set_xlabel("D",fontsize=15)
    #ax1.set_xlabel("D, %s" % tv,fontsize=15)    
    
plt.tight_layout()
plt.show()

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib


agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",][::-1]
wantedcolors=["blue"]*len(agq)
myxmin=[-0.1]*2
myxmax=[0.07]*2
mysubplot=0
fig = plt.figure(figsize=(10,5))

pD="/mnt/solexa/mel_yang/aPlateau/"
fhall="aPlateau.dstat.log"
fhtv="aPlateau.tv.dstat.log"
out,out2=("Mbuti","Mbuti")

#fhtv="aPlateau.dstat.log"
#out,out2=("Mbuti","Chimp")

popA=agq
popB=["Wuba"]
myind="Huoshaogou"
mypops2s=[[popA,popB,myind,out],[popA,myind,popB,out]]
mylabels=["D(%s,%s;%s,%s)" % ('aGQ',popB[0],myind,out),"D(%s,%s;%s,%s)" % ('aGQ',myind,popB[0],out)]
mytuples=[[(2,3),(0,1)],[(1,3),(0,2)]]
for count,mypops2 in enumerate(mypops2s):
    #print mypops2


    #tv='all'
    #mypops2=[popA,popB,myind,out]
    Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[count][0],mytuples[count][1],'Z')
    Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[count][0],mytuples[count][1],'D')
    SEaryall=Daryall/Zaryall 
    
    mynewpops2=mypops2[:-1]+[out2]
    Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[count][0],mytuples[count][1],'Z')
    Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[count][0],mytuples[count][1],'D')
    SEarytv=Darytv/Zarytv
    
    mylabel=mylabels[count]
    mynames=agq
    
    ax1=fig.add_subplot(1,len(mypops2s),count+1)
    for ind,i in enumerate(agq):
        #print tyD[i]
        #print Dary[ind][0]
        ax1.errorbar(Darytv[ind][0],ind,xerr=SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[ind][0],ind,xerr=2*SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[ind],ind,'.',alpha=0.05)

        ax1.errorbar(Daryall[ind][0],ind,xerr=SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[ind][0],ind,xerr=2*SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[ind],ind,'.')
        
    #ax1.set_yticks(len(mynames))
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    if count==0:
        ax1.set_yticklabels(mynames,fontsize=16)
    else: 
        ax1.set_yticklabels([' ']*len(mynames),fontsize=3)

    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[count],myxmax[count])

    xlabel = ax1.get_xticks().tolist()
    ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)

    ax1.set_title(mylabel,fontsize=15)

    ax1.axvline(x=0, ls='dashed', c='black')
    for myline in [10.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)
    ax1.set_xlabel("D",fontsize=15)
    #ax1.set_xlabel("D, %s" % tv,fontsize=15)

    
plt.tight_layout()
plt.show()

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib


agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",][::-1]
wantedcolors=["blue"]*len(agq)
myxmin=[-0.1]*2
myxmax=[0.07]*2
mysubplot=0
fig = plt.figure(figsize=(10,5))

pD="/mnt/solexa/mel_yang/aPlateau/"
fhall="aPlateau.dstat.log"
fhtv="aPlateau.tv.dstat.log"
out,out2=("Mbuti","Mbuti")

#fhtv="aPlateau.dstat.log"
#out,out2=("Mbuti","Chimp")

popA=agq
popB=["Wuba"]
myind="Huoshaogou"
mypops2s=[[popA,popB,myind,out],[popA,myind,popB,out]]
mylabels=["D(%s,%s;%s,%s)" % ('aGQ',popB[0],myind,out),"D(%s,%s;%s,%s)" % ('aGQ',myind,popB[0],out)]
mytuples=[[(2,3),(0,1)],[(1,3),(0,2)]]
for count,mypops2 in enumerate(mypops2s):
    #print mypops2


    #tv='all'
    #mypops2=[popA,popB,myind,out]
    Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[count][0],mytuples[count][1],'Z')
    Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[count][0],mytuples[count][1],'D')
    SEaryall=Daryall/Zaryall 
    
    mynewpops2=mypops2[:-1]+[out2]
    Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[count][0],mytuples[count][1],'Z')
    Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[count][0],mytuples[count][1],'D')
    SEarytv=Darytv/Zarytv
    
    mylabel=mylabels[count]
    mynames=agq
    
    ax1=fig.add_subplot(1,len(mypops2s),count+1)
    for ind,i in enumerate(agq):
        #print tyD[i]
        #print Dary[ind][0]
        ax1.errorbar(Darytv[ind][0],ind,xerr=SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[ind][0],ind,xerr=2*SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[ind],ind,'.',alpha=0.05)

        ax1.errorbar(Daryall[ind][0],ind,xerr=SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[ind][0],ind,xerr=2*SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[ind],ind,'.')
        
    #ax1.set_yticks(len(mynames))
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    if count==0:
        ax1.set_yticklabels(mynames,fontsize=16)
    else: 
        ax1.set_yticklabels([' ']*len(mynames),fontsize=3)

    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[count],myxmax[count])

    xlabel = ax1.get_xticks().tolist()
    ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)

    ax1.set_title(mylabel,fontsize=15)

    ax1.axvline(x=0, ls='dashed', c='black')
    for myline in [10.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)
    ax1.set_xlabel("D",fontsize=15)
    #ax1.set_xlabel("D, %s" % tv,fontsize=15)

    
plt.tight_layout()
plt.show()

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
pD="/mnt/solexa/mel_yang/aPlateau/"
fhall="aPlateau.dstat.log"
fhtv="aPlateau.tv.dstat.log"
out,out2=("Mbuti","Mbuti")

#fhtv="aPlateau.dstat.log"
#out,out2=("Mbuti","Chimp")

agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",][::-1]
eas=["Han","Dai","Ami","Daur","Naxi","Yi","Tibetan","Sherpa"][::-1]
wantedcolors=["blue"]*len(agq)
myxmin=[-0.08]*5
myxmax=[0.03]*5
#myxmin=[-0.02]*5
#myxmax=[0.06]*5
mysubplot=0
#fig = plt.figure(figsize=(10,5))
fig = plt.figure(figsize=(9,3))
popA=['Zongri1a',"Shangluzhuang","Hejiatai","Daxiang"]
#popA=["Zongri23","Xiahaishi","Lajigai","Wenpuju"]
popB=eas
mynames=eas
myind="Wuba"
varypops=popA #outs
ypops=popB
mytuples=[(1,3),(0,2)]
for count,varypop in enumerate(varypops):

    #mypops2=[popA,myind,ypops,varypop]
    mypops2=[[varypop],myind,ypops,out]

    Zaryall = np.transpose(pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z'))
    Daryall = np.transpose(pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D'))
    SEaryall=Daryall/Zaryall 
    
    mynewpops2=mypops2[:-1]+[out2]
    Zarytv = np.transpose(pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z'))
    Darytv = np.transpose(pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D'))
    SEarytv=Darytv/Zarytv
    
    mylabel="D(%s,%s;%s,%s)" % (mypops2[0][0],mypops2[1],'EAS',mypops2[3])
    mylabel="P1 = %s" % mypops2[0][0]

    
    
    ax1=fig.add_subplot(1,len(varypops),count+1)
    for ind,i in enumerate(ypops):
        ax1.errorbar(Darytv[ind][0],ind,xerr=SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[ind][0],ind,xerr=2*SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[ind],ind,'.',alpha=0.05)

        ax1.errorbar(Daryall[ind][0],ind,xerr=SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[ind][0],ind,xerr=2*SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[ind],ind,'.')
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    if count==0:
        #ax1.text("P2=%s\n" % myind,rotation=90,fontsize=16)
        ax1.set_ylabel("P2=%s\n\nP3" % myind,rotation=90,fontsize=13)
        ax1.set_yticklabels(mynames,fontsize=15)
    else: 
        ax1.set_yticklabels([' ']*len(mynames),fontsize=3)
    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[count],myxmax[count])
    #xlabel = ax1.get_xticks().tolist()
    #print xlabel
    #ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)

    ax1.set_title(mylabel,fontsize=13)

    ax1.axvline(x=0, ls='dashed', c='black')
    for myline in [3.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)

    ax1.set_xlabel("D",fontsize=15)
fig.autofmt_xdate()  
plt.tight_layout()
plt.show()

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
pD="/mnt/solexa/mel_yang/aPlateau/"
fhall="aPlateau.dstat.log"
fhtv="aPlateau.tv.dstat.log"
out,out2=("Mbuti","Mbuti")

#fhtv="aPlateau.dstat.log"
#out,out2=("Mbuti","Chimp")

#agq=["Zongri1a",
agq=["Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",][::-1]
eas=["Han","Dai","Ami","Daur","Naxi","Yi","Tibetan","Sherpa"][::-1]
wantedcolors=["blue"]*len(agq)
myxmin=[-0.08]*8
myxmax=[0.03]*8
#myxmin=[-0.02]*5
#myxmax=[0.06]*5
mysubplot=0
#fig = plt.figure(figsize=(10,5))
fig = plt.figure(figsize=(9,4))
#popA=['Zongri1a',"Shangluzhuang","Hejiatai","Daxiang"]
popA=["Han","Ami","Dai","Daur"] 
popA=["Naxi","Yi","Tibetan","Sherpa"]
popB=agq
mynames=agq
myind="Zongri1a"
varypops=popA #outs
ypops=popB
mytuples=[(0,3),(1,2)]
for count,varypop in enumerate(varypops):

    #mypops2=[popA,myind,ypops,varypop]
    mypops2=[myind,ypops,[varypop],out]

    Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
    Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
    SEaryall=Daryall/Zaryall 
    
    mynewpops2=mypops2[:-1]+[out2]
    Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
    Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
    SEarytv=Darytv/Zarytv
    
    mylabel="D(%s,%s;%s,%s)" % (mypops2[0][0],mypops2[1],'EAS',mypops2[3])
    mylabel="P3 = %s" % mypops2[2][0]

    
    
    ax1=fig.add_subplot(1,len(varypops),count+1)
    for ind,i in enumerate(ypops):
        ax1.errorbar(Darytv[ind][0],ind,xerr=SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[ind][0],ind,xerr=2*SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[ind],ind,'.',alpha=0.05)

        ax1.errorbar(Daryall[ind][0],ind,xerr=SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[ind][0],ind,xerr=2*SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[ind],ind,'.')
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    if count==0:
        #ax1.text("P2=%s\n" % myind,rotation=90,fontsize=16)
        ax1.set_ylabel("P1=%s\n\nP2" % mypops2[0],rotation=90,fontsize=13)
        ax1.set_yticklabels(mynames,fontsize=13)
    else: 
        ax1.set_yticklabels([' ']*len(mynames),fontsize=1)
    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[count],myxmax[count])
    #xlabel = ax1.get_xticks().tolist()
    #print xlabel
    #ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)

    ax1.set_title(mylabel,fontsize=13)

    ax1.axvline(x=0, ls='dashed', c='black')
    #for myline in [3.5]:
    #    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)

    ax1.set_xlabel("D",fontsize=13)
fig.autofmt_xdate()  
plt.tight_layout()
plt.show()

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
pD="/mnt/solexa/mel_yang/aPlateau/"
fhall="aPlateau.dstat.log"
fhtv="aPlateau.tv.dstat.log"
out,out2=("Mbuti","Mbuti")

#fhtv="aPlateau.dstat.log"
#out,out2=("Mbuti","Chimp")

#agq=["Zongri1a",
agq=["Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",][::-1]
eas=["Han","Dai","Ami","Daur","Naxi","Yi","Tibetan","Sherpa"][::-1]
wantedcolors=["blue"]*len(agq)
myxmin=[-0.05]*8
myxmax=[0.03]*8
#myxmin=[-0.02]*5
#myxmax=[0.06]*5
mysubplot=0
#fig = plt.figure(figsize=(10,5))
fig = plt.figure(figsize=(9,4))
#popA=['Zongri1a',"Shangluzhuang","Hejiatai","Daxiang"]
popA=["Han","Ami","Dai","Daur"] 
popA=["Naxi","Yi","Tibetan","Sherpa"]
popB=agq
mynames=agq
myind="Lierbao"
varypops=popA #outs
ypops=popB
mytuples=[(0,3),(1,2)]
for count,varypop in enumerate(varypops):

    #mypops2=[popA,myind,ypops,varypop]
    mypops2=[myind,ypops,[varypop],out]

    Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
    Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
    SEaryall=Daryall/Zaryall 
    
    mynewpops2=mypops2[:-1]+[out2]
    Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
    Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
    SEarytv=Darytv/Zarytv
    
    mylabel="D(%s,%s;%s,%s)" % (mypops2[0][0],mypops2[1],'EAS',mypops2[3])
    mylabel="P3 = %s" % mypops2[2][0]

    
    
    ax1=fig.add_subplot(1,len(varypops),count+1)
    for ind,i in enumerate(ypops):
        ax1.errorbar(Darytv[ind][0],ind,xerr=SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[ind][0],ind,xerr=2*SEarytv[ind][0],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[ind],ind,'.',alpha=0.05)

        ax1.errorbar(Daryall[ind][0],ind,xerr=SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[ind][0],ind,xerr=2*SEaryall[ind][0],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[ind],ind,'.')
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    if count==0:
        #ax1.text("P2=%s\n" % myind,rotation=90,fontsize=16)
        ax1.set_ylabel("P1=%s\n\nP2" % mypops2[0],rotation=90,fontsize=13)
        ax1.set_yticklabels(mynames,fontsize=13)
    else: 
        ax1.set_yticklabels([' ']*len(mynames),fontsize=1)
    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[count],myxmax[count])
    #xlabel = ax1.get_xticks().tolist()
    #print xlabel
    #ax1.set_xticklabels(xlabel,rotation=45,fontsize=15)

    ax1.set_title(mylabel,fontsize=13)

    ax1.axvline(x=0, ls='dashed', c='black')
    #for myline in [3.5]:
    #    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)

    ax1.set_xlabel("D",fontsize=13)
fig.autofmt_xdate()  
plt.tight_layout()
plt.show()

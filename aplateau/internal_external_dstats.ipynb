# %% [markdown]
# ## Internal D-stat

# %%
# %%writefile /mnt/solexa/mel_yang/masterlogfiles/UPA_all15/makeInternal_D_log.py
import projmodules as pm
from subprocess import Popen, PIPE
import sys
pd="/mnt/solexa/mel_yang/data/2.2M/"
outpd="/mnt/solexa/mel_yang/masterlogfiles/UPA_all15/"
fh="UPA_all15"
myfilename=sys.argv[1]
outs=["Mbuti","Chimp"]

indfile=open(pd+"individuals/"+myfilename+".txt",'r')
myinds=[line.split()[0] for line in indfile if line[0]!="#"]
indfile.close()
bsf,bsfsubset=(0,'all')
subset="Internal_"+myfilename
pm.Dpopfile_master(myinds,outs,outpd,fh,subset)

##Make qpDstat files
print 'Made popfile, calculating D...'

print pm.Dparfile(pd,fh,subset,bsf,outpd=outpd)

if outpd=='': mypd=pd
else: mypd=outpd
outfile = open(mypd+fh+'.D.'+subset+".log",'w')
mycommand = 'qpDstat -p '+mypd+fh+'.D.'+subset+'.par'
print 'Running command', mycommand

varfile = Popen(mycommand.split(), stdout = outfile)
varfile.communicate()
outfile.close()
# Out:
# Overwriting /mnt/solexa/mel_yang/masterlogfiles/UPA_all15/makeInternal_D_log.py

# %% [markdown]
# ## External Dstat - 2 pop

# %%
# %%writefile /mnt/solexa/mel_yang/masterlogfiles/UPA_all15/makeExternal_D_log.py
import projmodules as pm
from subprocess import Popen, PIPE
import sys
pd="/mnt/solexa/mel_yang/data/2.2M/"
outpd="/mnt/solexa/mel_yang/masterlogfiles/UPA_all15/"
fh="UPA_all15"
myfilename1=sys.argv[1]
myfilename2=sys.argv[2]
outs=["Mbuti","Chimp"]

indfile1=open(pd+"individuals/"+myfilename1+".txt",'r')
myinds1=[line.split()[0] for line in indfile1 if line[0]!="#"]
indfile1.close()

indfile2=open(pd+"individuals/"+myfilename2+".txt",'r')
myinds2=[line.split()[0] for line in indfile2 if line[0]!="#"]
indfile2.close()

bsf,bsfsubset=(0,'all')
subset="External_"+myfilename1+"-"+myfilename2
pm.Dpopfile_external(myinds1,myinds2,outs,outpd,fh,subset)

##Make qpDstat files
print 'Made popfile, calculating D...'

print pm.Dparfile(pd,fh,subset,bsf,outpd=outpd)

if outpd=='': mypd=pd
else: mypd=outpd
outfile = open(mypd+fh+'.D.'+subset+".log",'w')
mycommand = 'qpDstat -p '+mypd+fh+'.D.'+subset+'.par'
print 'Running command', mycommand

varfile = Popen(mycommand.split(), stdout = outfile)
varfile.communicate()
outfile.close()
# Out:
# Overwriting /mnt/solexa/mel_yang/masterlogfiles/UPA_all15/makeExternal_D_log.py

# %% [markdown]
# ## External Dstat - 3 pop

# %%
# %%writefile /mnt/solexa/mel_yang/masterlogfiles/UPA_all15/makeExternal3_D_log.py
import projmodules as pm
from subprocess import Popen, PIPE
import sys
pd="/mnt/solexa/mel_yang/data/2.2M/"
outpd="/mnt/solexa/mel_yang/masterlogfiles/UPA_all15/"
fh="UPA_all15"
myfilename1=sys.argv[1]
myfilename2=sys.argv[2]
myfilename3=sys.argv[3]
outs=["Mbuti","Chimp"]

indfile1=open(pd+"individuals/"+myfilename1+".txt",'r')
myinds1=[line.split()[0] for line in indfile1 if line[0]!="#"]
indfile1.close()

indfile2=open(pd+"individuals/"+myfilename2+".txt",'r')
myinds2=[line.split()[0] for line in indfile2 if line[0]!="#"]
indfile2.close()

indfile3=open(pd+"individuals/"+myfilename3+".txt",'r')
myinds3=[line.split()[0] for line in indfile3 if line[0]!="#"]
indfile3.close()

bsf,bsfsubset=(0,'all')
subset="External3_"+myfilename1+"-"+myfilename2+"-"+myfilename3
pm.Dpopfile_external3(myinds1,myinds2,myinds3,outs,outpd,fh,subset)

##Make qpDstat files
print 'Made popfile, calculating D...'

print pm.Dparfile(pd,fh,subset,bsf,outpd=outpd)

if outpd=='': mypd=pd
else: mypd=outpd
outfile = open(mypd+fh+'.D.'+subset+".log",'w')
mycommand = 'qpDstat -p '+mypd+fh+'.D.'+subset+'.par'
print 'Running command', mycommand

varfile = Popen(mycommand.split(), stdout = outfile)
varfile.communicate()
outfile.close()
# Out:
# Overwriting /mnt/solexa/mel_yang/masterlogfiles/UPA_all15/makeExternal3_D_log.py

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
#import matplotlib
import matplotlib.patches as mpatches

agq=["Zongri-a","ZongriM32","Zongri-c","ZongriM78","Zongri-b","ZongriM40","Hedong4",#"XiahaishiM22",
     "Hedong6","Hejiatai","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Hupo-a","Hupo14",
     "Shangluzhuang0","Hupo8","Qunke1","Lajigai-a","Wenpuju03","Jinchankou0",#"Lajigai2",
     "QijiapingM89-2","QijiapingM104-2","QijiapingM108-2","Wuba","HuoshaogouM117","Lierbao0"]
anx=["PukagongmaM1","PukagongmaM3","PukagongmaM5","YushuSGZ-1",#"PukagongmaM2",
     "RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"]
weaklinks=["XiahaishiM22","Lajigai2","PukagongmaM2"]
eas=["Han","Dai","Ami","Daur"]
seas=["Dai"]
neas=["Daur"]
ceas=["Han"]
weas1=["Naxi"]
weas2=["Tu"]
tib=["Tibetan_ShannanX"]
sherpa=["Sherpa_ShigatseX"] #,"Papuan","Onge","Oase1","Stuttgart",
varypops=[tib,sherpa,weas1,weas2,ceas,neas,seas][::-1]
labels=["Tib_Shannan","Sherpa_Shigatse","Naxi",'Tu',"Han","Daur","Dai"][::-1] #/Papuan/Onge/Oase1
low1=["Zongri-a","Hedong6","Hejiatai"] #,"Daxiang0","XiahaishiM9"
high1=["PukagongmaM5"]
low2=["QijiapingM104-2"]
high6=["Chokhopani","Mebrak","Samdzong"]
mysets=[(low1,high1),(low1,low2),(low1,high6),
       (high1,low2),(high1,high6),(low2,high6)]
mypairs=[("Low1","High1"),("Low1","Low2"),("Low1","High6"),
        ("High1","Low2"),("High1","High6"),("Low2","High6")]
out="Mbuti"
colors=["blue","brown","red","black","pink","gray","purple"][::-1]
markers=["o","v","s","<","D",">"]

pDin="/mnt/solexa/mel_yang/aPlateau/update051518/"
pDout="/mnt/solexa/mel_yang/aPlateau/update051518/"
fh,tv=("complete2.dstat.log","")
#fh,tv=("complete.tv.dstat.log",".tv")
fig = plt.figure(figsize=(18,10))
for ind2,myset in enumerate(mysets):
    myset1,myset2=myset
    ax1=fig.add_subplot(2,3,ind2+1)
    handles1,handles2=[],[]
    ax1.set_xlabel("Z for D(%s, X; %s, %s)" % (mypairs[ind2][0],mypairs[ind2][1],out),fontsize=15)
    ax1.set_ylabel("Z for D(%s, X; %s, %s)" % (mypairs[ind2][1],mypairs[ind2][0],out),fontsize=15)
    ax1.axvline(x=0, ls='dashed', c='black')
    ax1.axhline(y=0, ls='dashed', c='black')
    ax1.axvline(x=2, ls='dashed', c='lightgray')
    ax1.axhline(y=2, ls='dashed', c='lightgray')
    ax1.axvline(x=-2, ls='dashed', c='lightgray')
    ax1.axhline(y=-2, ls='dashed', c='lightgray')
    ax1.set_xlim((-12,12))
    ax1.set_ylim((-12,12))
    for ind,varypop in enumerate(varypops):
        print varypop
        handles2.append(mpatches.Patch(color=colors[ind], label="X="+labels[ind]))
        for myind in varypop:
            mypops1=[myset1,myind,myset2,out]
            Zaryu = pm.mkDary(pDin,fh,mypops1,(1,3),(0,2),"Z") 
            mypops2=[myset2,myind,myset1,out]
            Zaryl = np.transpose(pm.mkDary(pDin,fh,mypops2,(1,3),(0,2),"Z"))
            #print Zaryu,Zaryl
            ax1.plot(Zaryu,Zaryl,markers[ind2],color=colors[ind],markersize=10)




ax1.legend(handles=handles2,loc=4,ncol=7,fontsize=12.5,bbox_to_anchor=(1, -0.5))
    #ax1.legend(handles=handles1,loc=3)
plt.show()
# Out:
# ['Dai']
# ['Daur']
# ['Han']
# ['Tu']
# ['Naxi']
# ['Sherpa_ShigatseX']
# ['Tibetan_ShannanX']
# ['Dai']
# ['Daur']
# ['Han']
# ['Tu']
# ['Naxi']
# ['Sherpa_ShigatseX']
# ['Tibetan_ShannanX']
# ['Dai']
# ['Daur']
# ['Han']
# ['Tu']
# ['Naxi']
# ['Sherpa_ShigatseX']
# ['Tibetan_ShannanX']
# ['Dai']
# ['Daur']
# ['Han']
# ['Tu']
# ['Naxi']
# ['Sherpa_ShigatseX']
# ['Tibetan_ShannanX']
# ['Dai']
# ['Daur']
# ['Han']
# ['Tu']
# ['Naxi']
# ['Sherpa_ShigatseX']
# ['Tibetan_ShannanX']
# ['Dai']
# ['Daur']
# ['Han']
# ['Tu']
# ['Naxi']
# ['Sherpa_ShigatseX']
# ['Tibetan_ShannanX']

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
#import matplotlib
import matplotlib.patches as mpatches

agq=["Zongri-a","ZongriM32","Zongri-c","ZongriM78","Zongri-b","ZongriM40","Hedong4",#"XiahaishiM22",
     "Hedong6","Hejiatai","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Hupo-a","Hupo14",
     "Shangluzhuang0","Hupo8","Qunke1","Lajigai-a","Wenpuju03","Jinchankou0",#"Lajigai2",
     "QijiapingM89-2","QijiapingM104-2","QijiapingM108-2","Wuba","HuoshaogouM117","Lierbao0"]
anx=["PukagongmaM1","PukagongmaM3","PukagongmaM5","YushuSGZ-1",#"PukagongmaM2",
     "RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"]
weaklinks=["XiahaishiM22","Lajigai2","PukagongmaM2"]
eas=["Han","Dai","Ami","Daur"]
seas=["Dai"]
neas=["Daur"]
ceas=["Han"]
weas1=["Naxi"]
weas2=["Tu"]
tib=["Tibetan_ShannanX"]
sherpa=["Sherpa_ShigatseX"] #,"Papuan","Onge","Oase1","Stuttgart",
varypops=[tib,sherpa,weas1,weas2,ceas,neas,seas][::-1]
labels=["Tib_Shannan","Sherpa_Shigatse","Naxi",'Tu',"Han","Daur","Dai"][::-1] #/Papuan/Onge/Oase1
low1a=["Zongri-a"]
low1b=["Hedong6","Hejiatai"] #,"Daxiang0","XiahaishiM9"
low2=["Zongri-b","Zongri-c"]
low3=["QijiapingM104-2","Jinchankou0"]
low4=["HuoshaogouM117"]
high1=["PukagongmaM5","PukagongmaM1"]
high2=["YushuSGZ-1"]
high3=["RedilongM3","XiaoendaM2"]
high4=["Butaxiongqu"]
high5=["CaixiutangJ2-13"]
high6=["Chokhopani","Mebrak","Samdzong"]
allgroups=[low1a,low1b,low2,low3,low4,high1,high2,high3,high4,high5,high6]
allgroupnames=["Low1a","Low1b"]+[ "Low%i" % i for i in range(2,5) ] + [ "High%i" % i for i in range(1,7) ]
mysets=[(i,j) for indi,i in enumerate(allgroups) for indj,j in enumerate(allgroups) if indi<indj]
mypairs=[(i,j) for indi,i in enumerate(allgroupnames) for indj,j in enumerate(allgroupnames) if indi<indj]
print len(mysets), len(mypairs)
#mysets=[(low1,high1),(low1,low2),(low1,high6),(high1,low2),(high1,high6),(low2,high6)]
#mypairs=[("Low1","High1"),("Low1","Low2"),("Low1","High6"),("High1","Low2"),("High1","High6"),("Low2","High6")]
out="Mbuti"
colors=["blue","brown","red","black","pink","gray","purple"][::-1]
markers=["o","v","s","<","D",">"]
markers=["<"]*len(mypairs)

pDin="/mnt/solexa/mel_yang/aPlateau/update051518/"
pDout="/mnt/solexa/mel_yang/aPlateau/update051518/"
fh,tv=("complete2.dstat.log","")
#fh,tv=("complete.tv.dstat.log",".tv")
fig = plt.figure(figsize=(18,95))
for ind2,myset in enumerate(mysets):
    print ind2,myset
    myset1,myset2=myset
    ax1=fig.add_subplot(19,3,ind2+1)
    handles1,handles2=[],[]
    ax1.set_xlabel("Z for D(%s, X; %s, %s)" % (mypairs[ind2][0],mypairs[ind2][1],out),fontsize=15)
    ax1.set_ylabel("Z for D(%s, X; %s, %s)" % (mypairs[ind2][1],mypairs[ind2][0],out),fontsize=15)
    ax1.axvline(x=0, ls='dashed', c='black')
    ax1.axhline(y=0, ls='dashed', c='black')
    ax1.axvline(x=2, ls='dashed', c='lightgray')
    ax1.axhline(y=2, ls='dashed', c='lightgray')
    ax1.axvline(x=-2, ls='dashed', c='lightgray')
    ax1.axhline(y=-2, ls='dashed', c='lightgray')
    ax1.set_xlim((-12,12))
    ax1.set_ylim((-12,12))
    for ind,varypop in enumerate(varypops):
        #print varypop
        handles2.append(mpatches.Patch(color=colors[ind], label="X="+labels[ind]))
        for myind in varypop:
            mypops1=[myset1,myind,myset2,out]
            Zaryu = pm.mkDary(pDin,fh,mypops1,(1,3),(0,2),"Z") 
            mypops2=[myset2,myind,myset1,out]
            Zaryl = np.transpose(pm.mkDary(pDin,fh,mypops2,(1,3),(0,2),"Z"))
            #print Zaryu,Zaryl
            ax1.plot(Zaryu,Zaryl,markers[ind2],color=colors[ind],markersize=10)




ax1.legend(handles=handles2,loc=4,ncol=7,fontsize=12.5,bbox_to_anchor=(0.5, -0.5))
    #ax1.legend(handles=handles1,loc=3)
plt.show()
# Out:
# 55 55
# 0 (['Zongri-a'], ['Hedong6', 'Hejiatai'])
# 1 (['Zongri-a'], ['Zongri-b', 'Zongri-c'])
# 2 (['Zongri-a'], ['QijiapingM104-2', 'Jinchankou0'])
# 3 (['Zongri-a'], ['HuoshaogouM117'])
# 4 (['Zongri-a'], ['PukagongmaM5', 'PukagongmaM1'])
# 5 (['Zongri-a'], ['YushuSGZ-1'])
# 6 (['Zongri-a'], ['RedilongM3', 'XiaoendaM2'])
# 7 (['Zongri-a'], ['Butaxiongqu'])
# 8 (['Zongri-a'], ['CaixiutangJ2-13'])
# 9 (['Zongri-a'], ['Chokhopani', 'Mebrak', 'Samdzong'])
# 10 (['Hedong6', 'Hejiatai'], ['Zongri-b', 'Zongri-c'])
# 11 (['Hedong6', 'Hejiatai'], ['QijiapingM104-2', 'Jinchankou0'])
# 12 (['Hedong6', 'Hejiatai'], ['HuoshaogouM117'])
# 13 (['Hedong6', 'Hejiatai'], ['PukagongmaM5', 'PukagongmaM1'])
# 14 (['Hedong6', 'Hejiatai'], ['YushuSGZ-1'])
# 15 (['Hedong6', 'Hejiatai'], ['RedilongM3', 'XiaoendaM2'])
# 16 (['Hedong6', 'Hejiatai'], ['Butaxiongqu'])
# 17 (['Hedong6', 'Hejiatai'], ['CaixiutangJ2-13'])
# 18 (['Hedong6', 'Hejiatai'], ['Chokhopani', 'Mebrak', 'Samdzong'])
# ...

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
pD="/mnt/solexa/mel_yang/aPlateau/update051518/"
fhall="complete2.dstat.log"
fhtv="complete2.tv.dstat.log"
out,out2=("Mbuti","Mbuti")
agq=["Zongri-b","Zongri-c","ZongriM78","ZongriM40","ZongriM32","Zongri-a","Hejiatai",#"XiahaishiM22",
     "Hedong6","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11", 
     "Shangluzhuang0","HuoshaogouM117","Wuba","Hupo-a","Hupo14",
     "Hupo8","Qunke1","Lajigai-a","Lierbao0","Hedong4","Jinchankou0","Wenpuju03",#"Lajigai2",
     "QijiapingM89-2","QijiapingM108-2","QijiapingM104-2",][::-1]
anx=["PukagongmaM1","PukagongmaM5","PukagongmaM3","YushuSGZ-1",#"PukagongmaM2",
     "RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"][::-1]
eas=["Oroqen","Hezhen","Daur","Xibo","Japanese","Korean","Han","She","Miao","Tujia",
    "Dai","Kinh","Lahu","Ami","Atayal","Naxi","Yi","Tu","Tibetan","Sherpa"]
tib=["Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX",
     "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]

mycombo=anx+agq
wantedcolors=["blue"]*len(mycombo)
myxmin=[-0.05]*len(mycombo)
myxmax=[0.05]*len(mycombo)

mysubplot=0
#fig = plt.figure(figsize=(10,5))
fig = plt.figure(figsize=(13,10))

mynames=mycombo
myind="PukagongmaM5"
varypops=["Han","Yi","Tu","Tibetan","Tibetan_ShannanX"] 
#varypops=["Naxi","Yi","Tu","Tibetan"]
#varypops=["Tibetan_NyingchiX","Tibetan_ChamdoX","Tibetan_ShannanX","Sherpa_ShigatseX"]
ypops=mycombo
mytuples=[(1,3),(0,2)]
for count,varypop in enumerate(varypops):

    #mypops2=[popA,myind,ypops,varypop]
    mypops2=[ypops,myind,[varypop],out]

    Zaryall = np.transpose(pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z'))
    Daryall = np.transpose(pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D'))
    SEaryall=Daryall/Zaryall 
    
    mynewpops2=mypops2[:-1]+[out2]
    Zarytv = np.transpose(pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z'))
    Darytv = np.transpose(pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D'))
    SEarytv=Darytv/Zarytv
    
    mylabel="D(%s,%s;%s,%s)" % (mypops2[2],mypops2[1],'EA',mypops2[3])
    if "Tibetan_" in mypops2[2][0]: mylabel="P3 = %s" % mypops2[2][0].split('_')[1]
    else: mylabel="P3 = %s" % mypops2[2][0]
    #print Daryall
    ax1=fig.add_subplot(1,len(varypops),count+1)
    for ind,i in enumerate(ypops):
        if i in anx: wantedcolors="red"
        else: wantedcolors="blue"
        ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)

        ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[0][ind],ind,'.')
    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    if count==0:
        #ax1.text("P2=%s\n" % myind,rotation=90,fontsize=16)
        ax1.set_ylabel("P2=%s\n\nP1" % mypops2[1],rotation=90,fontsize=13)
        ax1.set_yticklabels(mynames,fontsize=12)
    else: 
         
        ax1.set_yticklabels(['']*(len(mynames)),fontsize=0.1)
    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[count],myxmax[count])
    xlabel = ax1.get_xticks().tolist()
    print 'xlabel',xlabel
    ax1.set_xticklabels([""]+xlabel[1:],fontsize=12) #

    ax1.set_title(mylabel,fontsize=12)
    #ax1.text(0,len(mynames),mylabel,fontsize=13, horizontalalignment='center', verticalalignment='center',backgroundcolor="white")

    ax1.axvline(x=0, ls='dashed', c='black') #, backgroundcolor="white") 
    for myline in [2.5,4.5,7.5,8.5,11.5,18.5,23.5,25.5,32.5,33.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)

    ax1.set_xlabel("D",fontsize=13)
fig.autofmt_xdate()  
plt.tight_layout()
plt.subplots_adjust(wspace=0.001) 
plt.show()
# Out:
# /home/mel_yang/.local/lib/python2.7/site-packages/ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in divide
# xlabel [-0.05, -0.025, 0.0, 0.02500000000000001, 0.05]
# xlabel [-0.05, -0.025, 0.0, 0.02500000000000001, 0.05]
# xlabel [-0.05, -0.025, 0.0, 0.02500000000000001, 0.05]
# xlabel [-0.05, -0.025, 0.0, 0.02500000000000001, 0.05]
# xlabel [-0.05, -0.025, 0.0, 0.02500000000000001, 0.05]

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib

pD="/mnt/solexa/mel_yang/aPlateau/update051518/"
fhall="complete2.dstat.log"
fhtv="complete2.tv.dstat.log"
out,out2=("Mbuti","Mbuti")
agq=["Zongri-b","Zongri-c","ZongriM78","ZongriM40","ZongriM32","Zongri-a","Hejiatai",#"XiahaishiM22",
     "Hedong6","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11", 
     "Shangluzhuang0","HuoshaogouM117","Wuba","Hupo-a","Hupo14",
     "Hupo8","Qunke1","Lajigai-a","Lierbao0","Hedong4","Jinchankou0","Wenpuju03",#"Lajigai2",
     "QijiapingM89-2","QijiapingM108-2","QijiapingM104-2",][::-1]
anx=["PukagongmaM1","PukagongmaM5","PukagongmaM3","YushuSGZ-1",#"PukagongmaM2",
     "RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu","CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"][::-1]
eas=["Oroqen","Hezhen","Daur","Xibo","Japanese","Korean","Han","She","Miao","Tujia",
    "Dai","Kinh","Lahu","Ami","Atayal","Naxi","Yi","Tu","Tibetan","Sherpa"]
tib=["Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX",
     "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]
sources=["Han","Wenpuju03"]
mycombo=anx+agq
wantedcolors=["blue"]*len(mycombo)
myxmin=[-0.05]*len(mycombo)
myxmax=[0.05]*len(mycombo)
offset=0.01
mysubplot=0
#fig = plt.figure(figsize=(10,5))
fig = plt.figure(figsize=(13,10))

mynames=mycombo
myind="PukagongmaM5"
varypops=[(i,j) for indi,i in enumerate(sources) for indj,j in enumerate(sources) if indj>indi] 
ypops=mycombo
mytuples=[(1,3),(0,2)]
for count,varypop in enumerate(varypops):
    ax1=fig.add_subplot(1,1,count+1)
    handles1,handles2=[],[]
    ax1.set_xlabel("D(X, %s; %s, %s)" % (myind,varypop[0],out),fontsize=15)
    ax1.set_ylabel("D(X, %s; %s, %s)" % (myind,varypop[1],out),fontsize=15)
    ax1.axvline(x=0, ls='solid', c='gray')
    ax1.axhline(y=0, ls='solid', c='gray')
    
    ax1.plot([-1,1],[-1,1], ls='dashed', c='black')
    mypops1=[ypops,myind,[varypop[0]],out]
    Daryall1 = pm.mkDary(pD,fhall,mypops1,mytuples[0],mytuples[1],'D')
    mypops2=[ypops,myind,[varypop[1]],out]
    Daryall2 = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
    ax1.plot(Daryall1,Daryall2,'.', c='blue')
    ax1.set_ylim((min(Daryall2)-offset,max(Daryall2)+offset))
    ax1.set_xlim((min(Daryall1)-offset,max(Daryall1)+offset))

plt.show()

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib

pD="/mnt/solexa/mel_yang/aPlateau/update051518/"
fhall="complete2.dstat.log"
fhtv="complete2.tv.dstat.log"
out,out2=("Mbuti","Mbuti")
low2=["Zongri-b","Zongri-c","ZongriM78","ZongriM40","ZongriM32","Zongri-a",]
low1=["Hejiatai","Hedong6","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Shangluzhuang0","Hupo-a","Lajigai-a"]#"XiahaishiM22",
low4o=["HuoshaogouM117","Wuba","Hupo14","Hupo8","Qunke1"]
low3=["Lierbao0","Hedong4","Jinchankou0","Wenpuju03","QijiapingM89-2","QijiapingM108-2","QijiapingM104-2"]#"Lajigai2",
low=low2+low1+low3+low4o
high13=["PukagongmaM1","PukagongmaM5","PukagongmaM3","YushuSGZ-1"] #"PukagongmaM2",
high2=["RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu"]
high45=["CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"]
high=high13+high245
eas=["Oroqen","Hezhen","Daur","Xibo","Japanese","Korean","Han","She","Miao","Tujia",
    "Dai","Kinh","Lahu","Ami","Atayal","Naxi","Yi","Tu","Tibetan","Sherpa"]
tib=["Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX",
     "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]
sources=["QijiapingM104-2","Jinchankou0","Daxiang0","Han","Dai","Tu","Naxi","Yi","Tibetan"]
mycombo=low+high
markers=['o','+','<','D','>','s','v','p','.']
lowhighdict={}
for ind,i in enumerate(low2): lowhighdict[i]=("low2",'blue',markers[ind])
for ind,i in enumerate(low1): lowhighdict[i]=("low1",'red',markers[ind])
for ind,i in enumerate(low3): lowhighdict[i]=("low3",'orange',markers[ind])        
for ind,i in enumerate(low4o): lowhighdict[i]=("low4o",'black',markers[ind])
for ind,i in enumerate(high13): lowhighdict[i]=("high13",'brown',markers[ind])
for ind,i in enumerate(high2): lowhighdict[i]=("high2",'purple',markers[ind])
for ind,i in enumerate(high45): lowhighdict[i]=("high45",'gray',markers[ind])
offset=0.01
mysubplot=0
fig = plt.figure(figsize=(18,48))

myind="Tianyuan"
#mycombo.remove(myind)
varypops=[(i,j) for indi,i in enumerate(sources) for indj,j in enumerate(sources) if indj>indi] 
print len(varypops)
mypops1=[mycombo,myind,sources,out]
#Daryall = pm.mkDary(pD,fhall,mypops1,(1,3),(0,2),'D')

for count,varypop in enumerate(varypops):
    s1,s2=varypop
    s1ind=sources.index(s1)
    s2ind=sources.index(s2)
    ax1=fig.add_subplot(12,3,count+1)
    handles1,handles2=[],[]
    #ax1.set_xlabel("D(X, %s; %s, %s)" % (myind,varypop[0],out),fontsize=15)
    #ax1.set_ylabel("D(X, %s; %s, %s)" % (myind,varypop[1],out),fontsize=15)
    ax1.set_xlabel("P3=%s" % (varypop[0]),fontsize=15)
    ax1.set_ylabel("P3=%s" % (varypop[1]),fontsize=15)
    ax1.axvline(x=0, ls='solid', c='gray')
    ax1.axhline(y=0, ls='solid', c='gray')
    ax1.plot([-0.1,0.5],[-0.1,0.5], ls='dashed', c='black')
    ax1.set_ylim((0.05,0.15))
    ax1.set_xlim((0.05,0.15))
    for ind,mytest in enumerate(mycombo):
        D1=Daryall[ind][s1ind]
        D2=Daryall[ind][s2ind]
        #print D1, D2
        ax1.plot(D1,D2,marker=lowhighdict[mytest][2], c=lowhighdict[mytest][1],label=mytest,linestyle="None")

ax1.legend(loc=4,ncol=10,fontsize=8,bbox_to_anchor=(0.5, -0.5))
plt.tight_layout()
plt.show()
# Out:
# 36

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib

pD="/mnt/solexa/mel_yang/aPlateau/update051518/"
fhall="complete2.dstat.log"
fhtv="complete2.tv.dstat.log"
out,out2=("Mbuti","Mbuti")
low2=["Zongri-b","Zongri-c","ZongriM78","ZongriM40","ZongriM32","Zongri-a",]
low1=["Hejiatai","Hedong6","Daxiang0","LiuwanQH-1","XiahaishiM9","Sanheyi11","Shangluzhuang0","Hupo-a","Lajigai-a"]#"XiahaishiM22",
low4o=["HuoshaogouM117","Wuba","Hupo14","Hupo8","Qunke1"]
low3=["Lierbao0","Hedong4","Jinchankou0","Wenpuju03","QijiapingM89-2","QijiapingM108-2","QijiapingM104-2"]#"Lajigai2",
low=low2+low1+low3+low4o
high13=["PukagongmaM1","PukagongmaM5","PukagongmaM3","YushuSGZ-1"] #"PukagongmaM2",
high2=["RedilongM3","XiaoendaM1","XiaoendaM2","Butaxiongqu"]
high245=["CaixiutangJ2-13","Chokhopani","Mebrak","Samdzong"]
high=high13+high245
eas=["Oroqen","Hezhen","Daur","Xibo","Japanese","Korean","Han","She","Miao","Tujia",
    "Dai","Kinh","Lahu","Ami","Atayal","Naxi","Yi","Tu","Tibetan","Sherpa"]
tib=["Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX",
     "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]
sources=["Zongri-a","PukagongmaM5","Hejiatai","QijiapingM104-2",
         "Jinchankou0","Daxiang0","RedilongM3","Chokhopani","Naxi"]
mycombo=low+high
markers=['o','+','<','D','>','s','v','p','.']
lowhighdict={}
for ind,i in enumerate(low2): lowhighdict[i]=("low2",'blue',markers[ind])
for ind,i in enumerate(low1): lowhighdict[i]=("low1",'red',markers[ind])
for ind,i in enumerate(low3): lowhighdict[i]=("low3",'orange',markers[ind])        
for ind,i in enumerate(low4o): lowhighdict[i]=("low4o",'black',markers[ind])
for ind,i in enumerate(high13): lowhighdict[i]=("high13",'brown',markers[ind])
for ind,i in enumerate(high2): lowhighdict[i]=("high2",'purple',markers[ind])
for ind,i in enumerate(high45): lowhighdict[i]=("high45",'gray',markers[ind])
offset=0.01
mysubplot=0
fig = plt.figure(figsize=(18,48))

myind="Tianyuan"
#mycombo.remove(myind)
varypops=[(i,j) for indi,i in enumerate(sources) for indj,j in enumerate(sources) if indj>indi] 
print len(varypops)
mypops1=[mycombo,myind,sources,out]
Daryall = pm.mkDary(pD,fhall,mypops1,(1,3),(0,2),'D')

for count,varypop in enumerate(varypops):
    s1,s2=varypop
    s1ind=sources.index(s1)
    s2ind=sources.index(s2)
    ax1=fig.add_subplot(12,3,count+1)
    handles1,handles2=[],[]
    #ax1.set_xlabel("D(X, %s; %s, %s)" % (myind,varypop[0],out),fontsize=15)
    #ax1.set_ylabel("D(X, %s; %s, %s)" % (myind,varypop[1],out),fontsize=15)
    ax1.set_xlabel("P3=%s" % (varypop[0]),fontsize=15)
    ax1.set_ylabel("P3=%s" % (varypop[1]),fontsize=15)
    ax1.axvline(x=0, ls='solid', c='gray')
    ax1.axhline(y=0, ls='solid', c='gray')
    ax1.plot([-0.1,0.5],[-0.1,0.5], ls='dashed', c='black')
    ax1.set_ylim((0.05,0.15))
    ax1.set_xlim((0.05,0.15))
    for ind,mytest in enumerate(mycombo):
        D1=Daryall[ind][s1ind]
        D2=Daryall[ind][s2ind]
        #print D1, D2
        ax1.plot(D1,D2,marker=lowhighdict[mytest][2], c=lowhighdict[mytest][1],label=mytest,linestyle="None")

ax1.legend(loc=4,ncol=10,fontsize=8,bbox_to_anchor=(0.5, -0.5))
plt.tight_layout()
plt.show()
# Out:
# 36

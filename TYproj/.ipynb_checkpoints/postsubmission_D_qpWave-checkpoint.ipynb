# %%
# %%writefile /mnt/solexa/mel_yang/allTYstuff/data/noHGDPsnps.py

##HO/2.2M SNPs in HGDP (remove ones not in HGDP)

pD = "/mnt/solexa/mel_yang/allTYstuff/data/"
fh="ind_A_v13_TBH"
fh="UPA_all6"
hgdpfile=open(pD+"HGDP.packed.snp",'r')
hgdppos=[line.split()[3] for line in hgdpfile]
hgdpfile.close()

newfile=open(pD+fh+".noHGDP.snp",'w')

hofile=open(pD+fh+".snp",'r')
for ind,line in enumerate(hofile):
    x=line.split()
    if x[3] not in hgdppos: newfile.write(line)
    else: continue
newfile.close()
# Out:
# Overwriting /mnt/solexa/mel_yang/allTYstuff/data/noHGDPsnps.py

# %%
##HGDP individuals
pD = "/home/melinda_yang/ivpp/bronzeage/"
fh="ind_A_v13_TBH"
hofile=open(pD+fh+".ind",'r')
newfile=open(pD+fh+".hgdplabeled.ind",'w')
for ind,line in enumerate(hofile):
    if ind != 0: newfile.write('\n')
    x=line.split()
    if "HGDP" in x[0]: 
        x[2]+=".HGDP"
        myline='\t'.join(x)
    else: myline='\t'.join(x)
    newfile.write(myline)
hofile.close()
newfile.close()

# %%
# %%writefile /home/melinda_yang/ivpp/allTYstuff/calcD_HGDPinds_NAmer.py
import plotting_funcs as pf

namers=['Mayan.HGDP','Mayan.DG','Piapoco.HGDP','Piapoco.DG','Xavante','Surui',
        'Surui.DG','Surui.HGDP','Mixe','Mixe.DG','Pima.DG','Pima.HGDP', 
        'Karitiana','Karitiana.DG','Karitiana.HGDP','Chane','Chane.DG',
       "Quechua",'Quechua.DG',"Zapotec","Zapotec.DG","Clovis.SG","Aymara",
        "Guarani","Guarani_GN","Guarani_KW","Cabecar","Kaqchikel","Wayuu",
        "Inga","Ticuna","Chilote","Bolivian","Apalai","Arara","UrubuKaapor","Zoro"]

pD = "/home/melinda_yang/ivpp/bronzeage/"
outpd="/home/melinda_yang/ivpp/allTYstuff/"
fhs = ['ind_A_v13_TBH']
myid1 = 'HGDP_NAmer'
myid2 = 'HGDP_NAmer'
p3s = ['Tianyuan','Papuan','Papuan.DG','Papuan.HGDP','Onge','Onge.DG']
p4s = ['Mbuti.HGDP','Mbuti.DG','Chimp','Chimp.DG']
bsf,bsfsubset=(0,'all')

for fh in fhs:
    for myp3 in p3s:
        for myp4 in p4s:
            ##(p1, p2, p3s, p4s)
            p1,p2,p3,p4 = (namers,namers,myp3,myp4)
            subset = bsfsubset+'.'+myid1+'_'+myid2+'_'+p3+'_'+p4
            mytups = [(i,j,p3,p4,'p1_'+i) for ind,i in enumerate(p1) for j in p2 if i != j and p3!=i and p3!=j]
            pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),fixed=(0,0,p3,p4),badsnpfile=bsf,outpd=outpd,indfilename=fh+".hgdplabeled")
# Out:
# Overwriting /home/melinda_yang/ivpp/allTYstuff/calcD_HGDPinds_NAmer.py

# %%
# %%writefile /home/melinda_yang/ivpp/allTYstuff/calcD_HGDPinds_NAmer_admremoved.py
import plotting_funcs as pf

namers=['Piapoco','Piapoco.DG','Xavante','Surui',
        'Surui.DG','Mixe','Mixe.DG','Pima.DG','Pima', 
        'Karitiana','Karitiana.DG','Chane','Chane.DG',
       "Clovis.SG","Guarani","Guarani_GN","Guarani_KW",
        "Cabecar","Kaqchikel","Wayuu",
        "Ticuna","Bolivian","Apalai","Arara","UrubuKaapor","Zoro"]

pD = "/home/melinda_yang/ivpp/bronzeage/"
outpd="/home/melinda_yang/ivpp/allTYstuff/"
fhs = ['ind_A_v13_TBH']
myid1 = 'NoAdm_NAmer'
myid2 = 'NoAdm_NAmer'
p3s = ['Tianyuan','Onge','Onge.DG','Papuan','Papuan.DG']
p4s = ['Mbuti','Mbuti.DG','Chimp','Chimp.DG']
bsf,bsfsubset=(0,'all')

for fh in fhs:
    for myp3 in p3s:
        for myp4 in p4s:
            ##(p1, p2, p3s, p4s)
            p1,p2,p3,p4 = (namers,namers,myp3,myp4)
            subset = bsfsubset+'.'+myid1+'_'+myid2+'_'+p3+'_'+p4
            mytups = [(i,j,p3,p4,'p1_'+i) for ind,i in enumerate(p1) for j in p2 if i != j and p3!=i and p3!=j]
            pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),fixed=(0,0,p3,p4),badsnpfile=bsf,outpd=outpd,indfilename=fh+".admixnamer")
# Out:
# Writing /home/melinda_yang/ivpp/allTYstuff/calcD_HGDPinds_NAmer_admremoved.py

# %%
# %%writefile /home/melinda_yang/ivpp/bronzeage/calcTYD001.py
import plotting_funcs as pf

unadm = ["Surui","Surui.DG","Chane","Chane.DG","Karitiana","Karitiana.DG",
         "Piapoco","Piapoco.DG","UrubuKaapor","Xavante","Zoro","Wayuu","Guarani_KW",
        "Arara","Apalai","Cabecar"]
mixe = ["Mixe0029","Mixe0030","Mixe0015","Mixe0035","Mixe0018","Mixe0026","Mixe0027",
       "Mixe0028","Mixe0007","Mixe0009","Mixe.DG-S3","Mixe.DG-S2","Mixe.DG-B1"]
outs = ["Mbuti","Chimp"]

pD="/home/melinda_yang/ivpp/bronzeage/"
fh="ind_A_v13_TBH"
p3s = ['Tianyuan','Onge','Onge.DG','Papuan','Papuan.DG']
outs=["Yakut","Han_HGDP","Yukagir","Biaka","Yoruba","Dinka","Ju_hoan_North"]
for myp4 in outs:
    for myp3 in p3s: #A
        #A
        p1,p2,p3,p4 = (unadm,mixe,myp3,myp4)
        subset = "UnAdm"+'_'+"13Mixe"+'_'+p3+'_'+p4
        mytups = [(i,j,p3,p4,'p2_'+i) for i in p1 for j in p2]
        pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),
                fixed=(0,0,p3,p4),indfilename=fh+".singMixe")
# Out:
# Overwriting /home/melinda_yang/ivpp/bronzeage/calcTYD001.py

# %%
# %%writefile /home/melinda_yang/ivpp/bronzeage/calcHO_D.py
import plotting_funcs as pf

outs = ["Mbuti","Chimp"]
namers=["Clovis.SG","Pima","Mayan","Mixe","Zapotec","Piapoco",
        "Karitiana","Surui","Quechua","Chane","Xavante","Cabecar","Guarani","Kaqchikel",
       "Pima.DG","Mayan.DG","Mixe.DG","Zapotec.DG","Piapoco.DG",
        "Karitiana.DG","Surui.DG","Quechua.DG","Chane.DG"]
#outs=["Yakut","Han_HGDP","Yukagir","Biaka","Yoruba","Dinka","Ju_hoan_North"]
pD="/home/melinda_yang/ivpp/bronzeage/"
fh="ind_A_v13_TBH"

for myp4 in outs:
    for myp3 in ["Tianyuan","Onge","Papuan"]: #C,D        
        #C
        p1,p2,p3,p4 = (namers,namers,myp3,myp4)
        subset = "NAmer"+'_'+"NAmer"+'_'+p3+'_'+p4
        mytups = [(i,j,p3,p4,'p2_'+i) for i in p1 for j in p2]
        pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),fixed=(0,0,p3,p4))
# Out:
# Overwriting /home/melinda_yang/ivpp/bronzeage/calcHO_D.py

# %%
# %%writefile /home/melinda_yang/ivpp/bronzeage/calcHO_NeandDeni.py
import plotting_funcs as pf

outs = ["Mbuti","Chimp"]
eas=["Han_HGDP","Japanese"]
eur=["French","Sardinian"]
#outs=["Yakut","Han_HGDP","Yukagir","Biaka","Yoruba","Dinka","Ju_hoan_North"]
pD="/home/melinda_yang/ivpp/bronzeage/"
fh="ind_A_v13_TBH"

for myp4 in outs:
    for myp3 in ["Denisovan.DG","Altai.DG"]: #C,D        
        #C
        p1,p2,p3,p4 = (eas,eur,myp3,myp4)
        subset = "EAS"+'_'+"EUR"+'_'+p3+'_'+p4
        mytups = [(i,j,p3,p4,'p2_'+i) for i in p1 for j in p2]
        pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),fixed=(0,0,p3,p4))
# Out:
# Overwriting /home/melinda_yang/ivpp/bronzeage/calcHO_NeandDeni.py

# %%
# %%writefile /home/melinda_yang/ivpp/allTYstuff/calcTYD001.py
import plotting_funcs as pf

unadm = ["Surui","Chane","Karitiana","Piapoco"]
mixe = ["Mixe-S3","Mixe-S2","Mixe-B1","Pima-S1","Pima-S2"]
outs = ["Mbuti","Chimp"]
outs=["Han","Yakut"]
pD="/home/melinda_yang/ivpp/allTYstuff/"
fh="UPA_all6"
p3s = ['TY','Onge','Papuan']
for myp4 in outs:
    for myp3 in p3s: #A
        #A
        p1,p2,p3,p4 = (unadm,mixe,myp3,myp4)
        subset = "UnAdm"+'_'+"IndMixePima"+'_'+p3+'_'+p4
        mytups = [(i,j,p3,p4,'p2_'+i) for i in p1 for j in p2]
        pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),
                fixed=(0,0,p3,p4),indfilename=fh+".singMixe")
# Out:
# Overwriting /home/melinda_yang/ivpp/allTYstuff/calcTYD001.py

# %%
# %%writefile /home/melinda_yang/ivpp/allTYstuff/calcTYD002.py
##Regular NAmer, NAmer
import plotting_funcs as pf

namer = ["Surui","Chane","Karitiana","Piapoco","Quechua","Zapotec","Pima","Mixe","Mayan"]
mixe = ["Mixe-S3","Mixe-S2","Mixe-B1","Pima-S1","Pima-S2"]
outs = ["Mbuti","Chimp"]
outs=["Han"]
pD="/home/melinda_yang/ivpp/allTYstuff/"
fh="UPA_all6"
p3s = ['TY','Onge','Papuan']

for myp4 in outs:
    for myp3 in p3s: #A
        #A
        p1,p2,p3,p4 = (namer,namer,myp3,myp4)
        subset = "NAmer"+'_'+"NAmer"+'_'+p3+'_'+p4
        mytups = [(i,j,p3,p4,'p2_'+i) for i in p1 for j in p2]
        pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),
                fixed=(0,0,p3,p4))
# Out:
# Overwriting /home/melinda_yang/ivpp/allTYstuff/calcTYD002.py

# %%
# %%writefile /home/melinda_yang/ivpp/allTYstuff/getnotHGDPsnps.py
##HGDP SNPs in UPA_all6 data
pD="/home/melinda_yang/ivpp/allTYstuff/"
hgdpsnpfile=open(pD+"HGDP.packed.snp",'r')
hgdpsnps=[i.split()[0] for i in hgdpsnpfile.readlines()]
print hgdpsnps
hgdpsnpfile.close()
num=0
upasnpfile=open(pD+"UPA_all6.snp",'r')
newfile=open(pD+"UPA_all6.notHGDP.snp",'w')
for ind,line in enumerate(upasnpfile):
    if ind%100000==0: print line
    rsid=line.split()[0]
    if rsid in hgdpsnps: num+=1
    else: newfile.write(line)
upasnpfile.close()
print num
# Out:
# Overwriting /home/melinda_yang/ivpp/allTYstuff/getnotHGDPsnps.py

# %%
# %%writefile /home/melinda_yang/ivpp/allTYstuff/calcHGDPUPA_D.py
##Regular NAmer, NAmer
import plotting_funcs as pf

namer = ["Surui","Chane","Karitiana","Piapoco","Quechua","Zapotec","Pima","Mayan","Mixe"]
mixe = ["Mixe0029","Mixe0030","Mixe0015","Mixe0035","Mixe0018","Mixe0026","Mixe0027",
       "Mixe0028","Mixe0007","Mixe0009","Mixe.DG-S3","Mixe.DG-S2","Mixe.DG-B1"]

outs = ["Mbuti","Chimp"]

pD="/home/melinda_yang/ivpp/allTYstuff/"
fh="UPA_all6"
p3s = ['TY',"Onge","Papuan"]
for myp4 in outs:
    for myp3 in p3s: #A
        #A
        p1,p2,p3,p4 = (namer,namer,myp3,myp4)
        subset = "noHGDP.NAmer"+'_'+"NAmer"+'_'+p3+'_'+p4
        #p1,p2,p3,p4 = (namer,mixe,myp3,myp4)
        #subset = "noNAmer"+'_'+"IndMixe"+'_'+p3+'_'+p4
        mytups = [(i,j,p3,p4,'p2_'+i) for i in p1 for j in p2]
        pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),
                fixed=(0,0,p3,p4),badsnpfile="UPA_all6.notHGDP.snp")
# Out:
# Overwriting /home/melinda_yang/ivpp/allTYstuff/calcHGDPUPA_D.py

# %%
# %%writefile /home/melinda_yang/ivpp/allTYstuff/getHOsnps.py
##HGDP SNPs in TY_HO_HG_TY data (no overlap with HO)
pD="/home/melinda_yang/ivpp/allTYstuff/"
hosnpfile=open(pD+"ind_A_v13_TBH.snp",'r')
hosnps=[(i.split()[1],i.split()[3]) for i in hosnpfile.readlines()]
hosnpfile.close()
num=0
upasnpfile=open(pD+"TY_HO_HG_TY.snp",'r')
newfile=open(pD+"TY_HO_HG_TY.HO.snp",'w')
for ind,line in enumerate(upasnpfile):
    if ind%100000==0: print line
    rsid=(line.split()[1],line.split()[3])
    if rsid in hosnps: newfile.write(line)
    else: num+=1
upasnpfile.close()
newfile.close()
print num
# Out:
# Overwriting /home/melinda_yang/ivpp/allTYstuff/getHOsnps.py

# %% [markdown]
# #### %%writefile /home/melinda_yang/ivpp/allTYstuff/getHOonlysnps.py
# ##HGDP SNPs in TY_HO_HG_TY data (can overlap with HO)
# pD="/home/melinda_yang/ivpp/allTYstuff/"
# hosnpfile=open(pD+"HGDP.packed.snp",'r')
# hosnps=[(i.split()[1],i.split()[3]) for i in hosnpfile.readlines()]
# hosnpfile.close()
# num=0
# upasnpfile=open(pD+"TY_HO_HG_TY.snp",'r')
# newfile=open(pD+"TY_HO_HG_TY.HOonly.snp",'w')
# for ind,line in enumerate(upasnpfile):
#     if ind%100000==0: print line
#     rsid=(line.split()[1],line.split()[3])
#     if rsid not in hosnps: newfile.write(line)
#     else: num+=1
# upasnpfile.close()
# newfile.close()
# print num

# %%
# %%writefile /home/melinda_yang/ivpp/allTYstuff/calcHOHGDP_D.py
##Regular NAmer, NAmer
import plotting_funcs as pf

namer = ["Surui","Chane","Karitiana","Piapoco","Quechua","Zapotec","Pima","Mayan","Mixe"]
mixe = ["Mixe0029","Mixe0030","Mixe0015","Mixe0035","Mixe0018","Mixe0026","Mixe0027",
       "Mixe0028","Mixe0007","Mixe0009"]

outs = ["Mbuti","Chimp","Han"]
pD="/home/melinda_yang/ivpp/allTYstuff/"
fh="TY_HO_HG_TY"
p3s = ['TY',"Papuan"]
for myp4 in outs:
    for myp3 in p3s: #A
        #A
        #p1,p2,p3,p4 = (namer,namer,myp3,myp4)
        #subset = "NAmer"+'_'+"NAmer"+'_'+p3+'_'+p4
        p1,p2,p3,p4 = (namer[:-1],mixe,myp3,myp4)
        subset = "NAmer"+'_'+"IndMixe"+'_'+p3+'_'+p4
        mytups = [(i,j,p3,p4,'p2_'+i) for i in p1 for j in p2]
        pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),
                fixed=(0,0,p3,p4),indfilename="TY_HO_HG_TY_singMixe")
                #badsnpfile="ind_A_v13_TBH.snp")
# Out:
# Overwriting /home/melinda_yang/ivpp/allTYstuff/calcHOHGDP_D.py

# %%
# %%writefile /home/melinda_yang/ivpp/allTYstuff/calcHOHGDP_D.py
##Regular NAmer, NAmer
import plotting_funcs as pf

namer = ["Surui","Chane","Karitiana","Piapoco","Quechua","Zapotec","Pima","Mayan","Mixe"]
mixe = ["Mixe0029","Mixe0030","Mixe0015","Mixe0035","Mixe0018","Mixe0026","Mixe0027",
       "Mixe0028","Mixe0007","Mixe0009"]

outs = ["Mbuti","Chimp","Han"]
pD="/home/melinda_yang/ivpp/allTYstuff/"
fh="TY_HO_HG_TY"
p3s = ['TY',"Papuan"]
for myp4 in outs:
    for myp3 in p3s: #A
        #A
        p1,p2,p3,p4 = (namer,namer,myp3,myp4)
        subset = "noHO.NAmer"+'_'+"NAmer"+'_'+p3+'_'+p4
        #p1,p2,p3,p4 = (namer[:-1],mixe,myp3,myp4)
        #subset = "noHO.NAmer"+'_'+"IndMixe"+'_'+p3+'_'+p4
        mytups = [(i,j,p3,p4,'p2_'+i) for i in p1 for j in p2]
        pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),
                fixed=(0,0,p3,p4), #indfilename="TY_HO_HG_TY_singMixe",
                badsnpfile="TY_HO_HG_TY.HO.snp")
# Out:
# Overwriting /home/melinda_yang/ivpp/allTYstuff/calcHOHGDP_D.py

# %%
# %%writefile /home/melinda_yang/ivpp/allTYstuff/calcHGDP_removeHOonly_D.py
##Regular NAmer, NAmer
import plotting_funcs as pf

namer = ["Surui","Chane","Karitiana","Piapoco","Quechua","Zapotec","Pima","Mayan","Mixe"]
mixe = ["Mixe0029","Mixe0030","Mixe0015","Mixe0035","Mixe0018","Mixe0026","Mixe0027",
       "Mixe0028","Mixe0007","Mixe0009"]

outs = ["Mbuti","Chimp","Han"]
pD="/home/melinda_yang/ivpp/allTYstuff/"
fh="TY_HO_HG_TY"
p3s = ['TY',"Papuan"]
for myp4 in outs:
    for myp3 in p3s: #A
        #A
        p1,p2,p3,p4 = (namer,namer,myp3,myp4)
        subset = "noHOonly.NAmer"+'_'+"NAmer"+'_'+p3+'_'+p4
        p1,p2,p3,p4 = (namer[:-1],mixe,myp3,myp4)
        subset = "noHOonly.NAmer"+'_'+"IndMixe"+'_'+p3+'_'+p4
        mytups = [(i,j,p3,p4,'p2_'+i) for i in p1 for j in p2]
        pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),
                fixed=(0,0,p3,p4), indfilename="TY_HO_HG_TY_singMixe",
                badsnpfile="TY_HO_HG_TY.HOonly.snp")
# Out:
# Overwriting /home/melinda_yang/ivpp/allTYstuff/calcHGDP_removeHOonly_D.py

# %%
# %%writefile /mnt/solexa/mel_yang/allTYstuff/postsubmission/calcD_MOS.py
##Table1-4, transv or all
import plotting_funcs as pf

pdeas=['Oroqen', 'Daur', 'Hezhen', 'Uygur', 'Xibo', 'Japanese', 'Korean', 
       'Tu', 'Han', 'Tujia', 'Miao', 'Yi', 'She', 'Naxi', 'Atayal', 'Ami', 
       'Lahu', 'Dai', 'Kinh', 'Burmese', 'Thai', 'Cambodian']

allids = ['MOS'+str(i) for i in range(2,7)]
pD = "/mnt/solexa/mel_yang/allTYstuff/data/"
outpd="/mnt/solexa/mel_yang/allTYstuff/postsubmission/"
fhs = ['UPA_all6']
myid1 = 'EAS'
myid2 = 'MOS'
p3s = ['TY']
p4s = ['Mbuti','Chimp']
bsf,bsfsubset=(0,'all')
bsf,bsfsubset=("/mnt/solexa/mel_yang/allTYstuff/data/UPA_all6.transi.snp",'tv')
for fh in fhs:
    for myp3 in p3s:
        for myp4 in p4s:
            ##(p1, p2, p3s, p4s)
            p1,p2,p3,p4 = (pdeas,allids,myp3,myp4)
            subset = bsfsubset+'.'+myid1+'_'+myid2+'_'+p3+'_'+p4
            mytups = [(i,j,p3,p4,'p1_'+i) for ind,i in enumerate(p1) for j in p2 if i != j and p3!=i and p3!=j]
            pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),fixed=(0,0,p3,p4),badsnpfile=bsf,outpd=outpd)

            ##(p3s, p2, p3, p4s)
            p1,p2,p3,p4 = (myp3,pdeas,allids,myp4)
            subset = bsfsubset+'.'+p1+'_'+myid1+'_'+myid2+'_'+p4
            mytups = [(p1,i,j,p4,'p2_'+i) for ind,i in enumerate(p2) for j in p3 if i != j and p1!=i and p1!=j]
            pf.runD(p2,p3,mytups,pD,fh,subset,(1,2),(0,),fixed=(p1,0,0,p4),badsnpfile=bsf,outpd=outpd)

            ##(p3s, p2, p3, p4s)
            p1,p2,p3,p4 = (myp3,allids,pdeas,myp4)
            subset = bsfsubset+'.'+p1+'_'+myid2+'_'+myid1+'_'+p4
            mytups = [(p1,i,j,p4,'p2_'+i) for ind,i in enumerate(p2) for j in p3 if i != j and p1!=i and p1!=j]
            pf.runD(p3,p2,mytups,pD,fh,subset,(2,1),(0,),fixed=(p1,0,0,p4),badsnpfile=bsf,outpd=outpd)
# Out:
# Overwriting /mnt/solexa/mel_yang/allTYstuff/postsubmission/calcD_MOS.py

# %%
# %%writefile /home/mel_yang/projects/bronzeage/calcTYD001.py
import plotting_funcs as pf

surui = ["Surui"+str(i) for i in range(1,13)]+["Surui.DG"]
mixe = ["Mixe"+str(i) for i in range(1,11)]+["Mixe.DG"]
onge = ["Onge"+str(i) for i in range(1,17)]
outs = ["Mbuti","Chimp"]
namers=["Clovis.SG","Pima","Mayan","Mixe","Zapotec","Piapoco",
        "Karitiana","Surui","Quechua","Chane","Xavante","Cabecar","Guarani","Kaqchikel"]
namersold=["Clovis.SG","Pima.DG","Mayan.DG","Mixe.DG","Zapotec.DG","Piapoco.DG",
        "Karitiana.DG","Surui.DG","Quechua.DG","Chane.DG"]

pD="/home/mel_yang/projects/bronzeage/"
fh="ind_A_v13_TBH"
'''
for myp4 in outs:
    for myp3 in ["Tianyuan"]+onge: #A
        #A
        p1,p2,p3,p4 = (surui,mixe,myp3,myp4)
        subset = "12Surui"+'_'+"10Mixe"+'_'+p3+'_'+p4
        mytups = [(i,j,p3,p4,'p2_'+i) for i in p1 for j in p2]
        pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),fixed=(0,0,p3,p4),indfilename=pD+fh+".single") 
'''

for myp4 in outs:
    for myp3 in ["Tianyuan","Onge","Papuan","Onge.DG","Papuan.DG"]: #C,D        
        #C
        p1,p2,p3,p4 = (namers,namers,myp3,myp4)
        subset = "NAmer"+'_'+"NAmer"+'_'+p3+'_'+p4
        mytups = [(i,j,p3,p4,'p2_'+i) for i in p1 for j in p2]
        pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),fixed=(0,0,p3,p4))   
        ##D - Now merged into #C
        #popn="Xavante"
        #popn="Kaqchikel"
        #p1,p2,p3,p4 = (namers,[popn],myp3,myp4)
        #subset = "NAmer"+'_'+popn+'_'+p3+'_'+p4
        #mytups = [(i,j,p3,p4,'p2_'+i) for i in p1 for j in p2]
        #pf.runD(p1,p2,mytups,pD,fh,subset,(0,1),(0,),fixed=(0,0,p3,p4)) 
'''       
##B
p3s=["Tianyuan"]+onge
for ind,myp3 in enumerate(p3s):
    if ind % 3!=0: continue
    p1,p2,p3,p4 = ("Surui",["Mixe"],p3s[ind:(ind+3)],"Mbuti")
    subset = p1+'_'+"Mixe"+'_'+"TYOnge"+str(ind)+'_'+p4
    mytups = [(p1,i,j,p4,'p2_'+i) for i in p2 for j in p3]
    pf.runD(p3,p2,mytups,pD,fh,subset,(2,1),(0,),fixed=(p1,0,0,p4),indfilename=pD+fh+".singOnge") 

##E
p1,p2,p3,p4 = ("Amaz",["CAmer"],["Tianyuan","Onge"],"Mbuti")
subset = p1+'_'+"CAmer"+'_'+"TYOnge"+'_'+p4
mytups = [(p1,i,j,p4,'p2_'+i) for i in p2 for j in p3]
pf.runD(p2,p3,mytups,pD,fh,subset,(1,2),(0,),fixed=(p1,0,0,p4),indfilename=pD+fh+".mergeCAAmaz") 

'''

# %%
# %%writefile /home/mel_yang/projects/allTYstuff/SOMX2/calcTYD001_HOsub.py

import random
from subprocess import Popen, PIPE
import plotting_funcs as pf
import projmodules as pm

pD="/home/mel_yang/projects/allTYstuff/SOMX2/"
fh="UPA_all2"
reps=100
lab="D"

##randomsnps
snpfile=open(pD+fh+".snp",'r')
snplines=snpfile.readlines()
snpfile.close()
print len(snplines)
for i in range(reps):
    print i
    random.shuffle(snplines)
    badsnps=snplines[:597573]
    badsnpfilename=pD+fh+".r"+str(i)+".snp"
    badsnpfile = open(badsnpfilename,'w')
    badsnpfile.write(''.join(badsnps))
    badsnpfile.close()
    
    myps=["Surui","Mixe","Tianyuan","Mbuti"]
    subset="_".join(myps)+"_rep"+str(i)
    newfile = open(pD+fh+'.'+lab+'.'+subset+".pop",'w')
    newfile.write('\t'.join(myps) + '\n')
    newfile.close()

    pm.Dparfile(pD+fh,subset,badsnpfile=badsnpfilename)
    outfile = open(pD+fh+'.'+lab+'.'+subset+".log",'w')
    mycommand = 'qpDstat -p '+pD+fh+'.'+lab+'.'+subset+'.par'
    print 'Running command', mycommand

    varfile = Popen(mycommand.split(), stdout = outfile)
    varfile.communicate()
    outfile.close()

# %%
# %%writefile /home/mel_yang/projects/bronzeage/randomeffects_D.py
import plotting_funcs as pf
import projmodules as pm
from subprocess import Popen, PIPE

pD="/home/mel_yang/projects/bronzeage/"
fh="ind_A_v13_TBH"

p1,p2,p3="Surui","Mixe","Onge"
p1range,p2range,p3range=14,13,18
p1,p2,p3="Surui","Mixe","Papuan"
p1range,p2range,p3range=14,13,33
p4="Mbuti"

subset=p1+'_'+p2+'_'+p3+'_'+p4
mytuples=[(p1+str(i+1),p2+str(j+1),p3+str(k+1),p4) for i in range(p1range) for j in range(p2range) for k in range(p3range)]

#p1,p2,p3="Surui","Mixe","Tianyuan"
#p1range,p2range,p3range=14,13,1
#subset=p1+'_'+p2+'_'+p3+'_'+p4
#mytuples=[(p1+str(i+1),p2+str(j+1),p3,p4) for i in range(p1range) for j in range(p2range)]


#print mytuples
lab="D"

newfile = open(pD+fh+'.'+lab+'.'+subset+".pop",'w')
for mytup in mytuples: newfile.write('\t'.join([i for i in mytup]) + '\n')
newfile.close()

pm.Dparfile(pD+fh,subset,indfilename=pD+fh+".singleSurMixe")
outfile = open(pD+fh+'.'+lab+'.'+subset+".log",'w')
mycommand = 'qpDstat -p '+pD+fh+'.'+lab+'.'+subset+'.par'
print 'Running command', mycommand

varfile = Popen(mycommand.split(), stdout = outfile)
varfile.communicate()
outfile.close()
# Out:
# Overwriting /home/mel_yang/projects/bronzeage/randomeffects_D.py

# %%
# %%writefile /home/mel_yang/projects/bronzeage/Amaz_calcWave02_pooled.py
import projmodules as pm
from multiprocessing import Pool

namers=["Clovis.SG","Pima","Mayan","Mixe","Zapotec","Piapoco",
        "Karitiana","Surui","Quechua","Chane","Xavante","Cabecar","Guarani"]

pD="/home/mel_yang/projects/bronzeage/"
fh="ind_A_v13_TBH"

def dowork(mytup):
    print mytup
    pD="/home/mel_yang/projects/bronzeage/"
    fh="ind_A_v13_TBH"
    myoutgroups = ['Kostenki14','GoyetQ116-1','UstIshim','Mota','Mbuti','Vestonice16','ElMiron','Villabruna'] ##0 ##REMOVED STUTTGART FRENCH!
    #myoutgroups = ['Kostenki14','GoyetQ116-1','UstIshim','Mota','Mbuti','Vestonice16'] ##1
    myoutgroups = ['Kostenki14','GoyetQ116-1','UstIshim','Mota','Mbuti','Vestonice16','ElMiron','Villabruna','French','Stuttgart'] ##2
    #myoutgroups = ['Kostenki14','GoyetQ116-1','UstIshim','Mota','Mbuti','Vestonice16','ElMiron','Villabruna','Bichon','Loschbour','LaBrana1','Hungarian.KO1'] ##3
    myoutgroups = ['Kostenki14','UstIshim','Mota.SG','Mbuti','Vestonice16','ElMiron','Villabruna','French','Stuttgart'] ##4
    bck = myoutgroups
    i,myp2=mytup
    bck1 = 'new_%s' % myp2
    ind=4
    pm.wave_run([i,myp2,'Tianyuan'], bck, pD, fh, '%s_1A_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_adm_run([i,myp2,'Tianyuan'], bck, pD, fh, '%s_1A_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_run([i,myp2,'Han_HGDP'], bck, pD, fh, '%s_1B_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_adm_run([i,myp2,'Han_HGDP'], bck, pD, fh, '%s_1B_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_run([i,myp2,'Papuan'], bck, pD, fh, '%s_1C_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_adm_run([i,myp2,'Papuan'], bck, pD, fh, '%s_1C_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_run([i,myp2,'Onge'], bck, pD, fh, '%s_1D_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_adm_run([i,myp2,'Onge'], bck, pD, fh, '%s_1D_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_run([i,myp2,'Dai'], bck, pD, fh, '%s_1E_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_adm_run([i,myp2,'Dai'], bck, pD, fh, '%s_1E_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_run([i,myp2,'Ami_Coriell'], bck, pD, fh, '%s_1F_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_adm_run([i,myp2,'Ami_Coriell'], bck, pD, fh, '%s_1F_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_run([i,myp2,'Atayal_Coriell'], bck, pD, fh, '%s_1G_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_adm_run([i,myp2,'Atayal_Coriell'], bck, pD, fh, '%s_1G_t%s_out%s' % (bck1,i,str(ind)))
    #pm.wave_run([i,myp2,'Chokhopani1'], bck, pD, fh, '%s_1H_t%s_out%s' % (bck1,i,str(ind)))
    #pm.wave_adm_run([i,myp2,'Chokhopani1'], bck, pD, fh, '%s_1H_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_run([i,myp2,'She'], bck, pD, fh, '%s_1I_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_adm_run([i,myp2,'She'], bck, pD, fh, '%s_1I_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_run([i,myp2,'Korean'], bck, pD, fh, '%s_1J_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_adm_run([i,myp2,'Korean'], bck, pD, fh, '%s_1J_t%s_out%s' % (bck1,i,str(ind)))
        
myinputs = [(i,j) for i in namers for j in namers if i != j]
#print myinputs
#print len(myinputs)
mypool = Pool(4)
results = mypool.map(dowork, myinputs)

# %%
# %%writefile /home/mel_yang/projects/bronzeage/Amaz_calcWave02_pooled_getsize.py
import projmodules as pm
from multiprocessing import Pool
import os

namers=["Clovis.SG","Pima","Mayan","Mixe","Zapotec","Piapoco",
        "Karitiana","Surui","Quechua","Chane","Xavante","Cabecar","Guarani"]

pD="/home/mel_yang/projects/bronzeage/"
extradir="HO_TY_results/"
fh="ind_A_v13_TBH"

def dowork(mytup):
    #print mytup
    pD="/home/mel_yang/projects/bronzeage/"
    fh="ind_A_v13_TBH"
    myoutgroups = ['Kostenki14','GoyetQ116-1','UstIshim','Mota','Mbuti','Vestonice16','ElMiron','Villabruna'] ##0 ##REMOVED STUTTGART FRENCH!
    #myoutgroups = ['Kostenki14','GoyetQ116-1','UstIshim','Mota','Mbuti','Vestonice16'] ##1
    myoutgroups = ['Kostenki14','GoyetQ116-1','UstIshim','Mota','Mbuti','Vestonice16','ElMiron','Villabruna','French','Stuttgart'] ##2
    #myoutgroups = ['Kostenki14','GoyetQ116-1','UstIshim','Mota','Mbuti','Vestonice16','ElMiron','Villabruna','Bichon','Loschbour','LaBrana1','Hungarian.KO1'] ##3
    myoutgroups = ['Kostenki14','UstIshim','Mota.SG','Mbuti','Vestonice16','ElMiron','Villabruna','French','Stuttgart'] ##4
    bck = myoutgroups
    i,myp2=mytup
    bck1 = 'new_%s' % myp2
    ind=4
    
    letters = "ABCDEFGIJ"
    myother = ['Tianyuan','Han_HGDP','Papuan','Onge','Dai','Ami_Coriell','Atayal_Coriell','She','Korean']
    for indo,letter in enumerate("ABCDEFGIJ"):
        fname="%s%s%s.adm.%s_1%s_t%s_out%s.log" % (pD,extradir,fh,bck1,letter,i,str(ind))
        if os.path.isfile(fname) == True:
            if os.path.getsize(fname) > 4000: print fname, "Did Already!"
            else: 
                pm.wave_run([i,myp2,myother[indo]], bck, pD, fh, '%s_1%s_t%s_out%s' % (bck1,letter,i,str(ind)))
                pm.wave_adm_run([i,myp2,myother[indo]], bck, pD, fh, '%s_1%s_t%s_out%s' % (bck1,letter,i,str(ind)))
        else:
            pm.wave_run([i,myp2,myother[indo]], bck, pD, fh, '%s_1%s_t%s_out%s' % (bck1,letter,i,str(ind)))
            pm.wave_adm_run([i,myp2,myother[indo]], bck, pD, fh, '%s_1%s_t%s_out%s' % (bck1,letter,i,str(ind)))
            
        
    '''
    pm.wave_run([i,myp2,'Tianyuan'], bck, pD, fh, '%s_1A_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_adm_run([i,myp2,'Tianyuan'], bck, pD, fh, '%s_1A_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_run([i,myp2,'Han_HGDP'], bck, pD, fh, '%s_1B_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_adm_run([i,myp2,'Han_HGDP'], bck, pD, fh, '%s_1B_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_run([i,myp2,'Papuan'], bck, pD, fh, '%s_1C_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_adm_run([i,myp2,'Papuan'], bck, pD, fh, '%s_1C_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_run([i,myp2,'Onge'], bck, pD, fh, '%s_1D_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_adm_run([i,myp2,'Onge'], bck, pD, fh, '%s_1D_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_run([i,myp2,'Dai'], bck, pD, fh, '%s_1E_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_adm_run([i,myp2,'Dai'], bck, pD, fh, '%s_1E_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_run([i,myp2,'Ami_Coriell'], bck, pD, fh, '%s_1F_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_adm_run([i,myp2,'Ami_Coriell'], bck, pD, fh, '%s_1F_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_run([i,myp2,'Atayal_Coriell'], bck, pD, fh, '%s_1G_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_adm_run([i,myp2,'Atayal_Coriell'], bck, pD, fh, '%s_1G_t%s_out%s' % (bck1,i,str(ind)))
    #pm.wave_run([i,myp2,'Chokhopani1'], bck, pD, fh, '%s_1H_t%s_out%s' % (bck1,i,str(ind)))
    #pm.wave_adm_run([i,myp2,'Chokhopani1'], bck, pD, fh, '%s_1H_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_run([i,myp2,'She'], bck, pD, fh, '%s_1I_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_adm_run([i,myp2,'She'], bck, pD, fh, '%s_1I_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_run([i,myp2,'Korean'], bck, pD, fh, '%s_1J_t%s_out%s' % (bck1,i,str(ind)))
    pm.wave_adm_run([i,myp2,'Korean'], bck, pD, fh, '%s_1J_t%s_out%s' % (bck1,i,str(ind)))
    '''
        
myinputs = [(i,j) for i in namers for j in namers if i != j]
#print myinputs
#print len(myinputs)
mypool = Pool(16)
results = mypool.map(dowork, myinputs)

# %%
##EXTRACT RELEVANT DATA FROM QPADM
import projmodules as pm

villabrunacluster = ['Chane','Karitiana','Mayan','Mixe','Piapoco','Pima','Quechua','Surui','Zapotec','Clovis']
targets = ['Chane','Karitiana','Mayan','Mixe','Piapoco','Pima','Quechua','Surui','Zapotec','Clovis']
targets=["Clovis.SG","Pima","Mayan","Mixe","Zapotec","Piapoco",
        "Karitiana","Surui","Quechua","Chane"] #,"Xavante","Cabecar","Guarani"]
villabrunacluster=["Clovis.SG","Pima","Mayan","Mixe","Zapotec","Piapoco",
        "Karitiana","Surui","Quechua","Chane"] #,"Xavante","Cabecar","Guarani"]
targets=["Pima","Mayan","Mixe","Zapotec","Piapoco",
        "Karitiana","Surui","Quechua","Chane","Xavante","Cabecar","Guarani"]

villabrunacluster=["Pima","Mayan","Mixe","Zapotec","Piapoco",
        "Karitiana","Surui","Quechua","Chane","Xavante","Cabecar","Guarani"]

pD="/home/mel_yang/projects/bronzeage/HO_TY_results/"
fh="ind_A_v13_TBH"
ids = 'ABCDEFGIJ'
p2s = ['TY','Han_HGDP','Papuan','Onge','Dai','Ami_Coriell','Atayal_Coriell','She','Korean']

newname,myoutind = ('adm_NAmernew2HO',4) 
alldata = ""
for ind0, p2 in enumerate(p2s):
    for ind2,myind2 in enumerate(targets):
        for ind1,myind1 in enumerate(villabrunacluster):
            if myind1==myind2: continue
            s1,s2,target = (myind1,p2,myind2)
            subset = 'new_%s_1%s_t%s_out%.0f' % (s1,ids[ind0],target,myoutind)
            print subset
            if subset == "new_Xavante_1E_tMayan_out4": continue
            myinfo = pm.wave_extractAdmdata(pD,fh,subset,(s1,s2),target)
            #print myinfo
            if myinfo == 'NOFILE': continue
            comboswanted = ['00','01']
            rankswanted = ['1']
            ranksprint = '\t'.join([str(myinfo['f4rank'][i]) for i in rankswanted])
            pvalsprint = '\t'.join(['%s\t%s\t%s\t%s' % tuple(myinfo['admix'][i]+myinfo['nestp'][i]) if i in myinfo['nestp'] else '%s\t%s\t%s\tNA' % tuple(myinfo['admix'][i]) for i in comboswanted])
            allprint = ranksprint+'\t'+pvalsprint
            header = 'S1\tS2\tTarget\trank1\t%s_p\t%s_f1\t%s_f2\t%s_pnest\t%s_p\t%s_f1\t%s_f2\t%s_pnest\tse1\tse2\n' % tuple(comboswanted[0:1]*4+comboswanted[1:2]*4)
    
            alldata+='\t'.join([s1,s2,target])+'\t'+allprint+'\t'+'\t'.join(myinfo['se'])+'\n'
      
newfile = open(pD+fh+'.'+newname+'.out'+str(myoutind)+'.tab','w')
newfile.writelines(header+alldata)
newfile.close()
# Out:
# new_Mayan_1A_tPima_out4
# new_Mixe_1A_tPima_out4
# new_Zapotec_1A_tPima_out4
# new_Piapoco_1A_tPima_out4
# new_Karitiana_1A_tPima_out4
# new_Surui_1A_tPima_out4
# new_Quechua_1A_tPima_out4
# new_Chane_1A_tPima_out4
# new_Xavante_1A_tPima_out4
# new_Cabecar_1A_tPima_out4
# new_Guarani_1A_tPima_out4
# new_Pima_1A_tMayan_out4
# new_Mixe_1A_tMayan_out4
# new_Zapotec_1A_tMayan_out4
# new_Piapoco_1A_tMayan_out4
# new_Karitiana_1A_tMayan_out4
# new_Surui_1A_tMayan_out4
# new_Quechua_1A_tMayan_out4
# new_Chane_1A_tMayan_out4
# new_Xavante_1A_tMayan_out4
# new_Cabecar_1A_tMayan_out4
# new_Guarani_1A_tMayan_out4
# new_Pima_1A_tMixe_out4
# new_Mayan_1A_tMixe_out4
# new_Zapotec_1A_tMixe_out4
# new_Piapoco_1A_tMixe_out4
# new_Karitiana_1A_tMixe_out4
# new_Surui_1A_tMixe_out4
# new_Quechua_1A_tMixe_out4
# new_Chane_1A_tMixe_out4
# new_Xavante_1A_tMixe_out4
# new_Cabecar_1A_tMixe_out4
# new_Guarani_1A_tMixe_out4
# new_Pima_1A_tZapotec_out4
# new_Mayan_1A_tZapotec_out4
# new_Mixe_1A_tZapotec_out4
# ...

# %%
# %%writefile /home/mel_yang/projects/bronzeage/Skog_qpwave.py
import projmodules as pm
from multiprocessing import Pool
import itertools

namers=["Cabecar","Guarani","Karitiana","Mixe","Piapoco",
        "Pima","Surui"]

def dowork(mytup):
    pD="/home/mel_yang/projects/bronzeage/"
    fh="ind_A_v13_TBH"
    
    outs=[["Yoruba","Ju_hoan_North","Dinka","Mbuti"],
          ["Tuvinian","Mongola","Yakut","Kyrgyz"],
          ["Han_HGDP","Uygur","Japanese","Ami_Coriell"],
          ["New_Guinea","Papuan","Australian_WGA","Mamanwa"],
          ["Kusunda","Onge","Kharia","Sindhi_Pakistan"]]
    myoutgroups=list(itertools.chain.from_iterable(outs)) 
    '''
    bck = myoutgroups
    ind=0
    bck1 = 'NAmer01_out'+str(ind)
    pm.wave_run(mytup, bck, pD, fh, bck1)
    
    bck = myoutgroups+["Tianyuan"]
    ind=1
    bck1 = 'NAmer01_out'+str(ind)
    pm.wave_run(mytup, bck, pD, fh, bck1)
    '''
    bck = myoutgroups+["Tianyuan"]
    bck.remove("Onge")
    ind=2
    bck1 = 'NAmer01_out'+str(ind)
    pm.wave_run(mytup, bck, pD, fh, bck1)
    
dowork(namers)

# %%
##MAKE TRANSITION SNP FILE

pD="/home/mel_yang/projects/bronzeage/"
fh="ind_A_v13_TBH"

transversions = ['AC','CA','AT','TA','GC','CG','GT','TG']

snpfile = open(pD+fh+".snp",'r')
newfile = open(pD+fh+".transi.snp",'w')
for line in snpfile:
    x = line.strip().split()
    if x[4]+x[5] not in transversions: newfile.write(line)
snpfile.close()
newfile.close()

# %%
##FILTER FOR ONLY TRANSVERSION DATASET
import projmodules as pm

pD="/home/mel_yang/projects/bronzeage/"
fh="ind_A_v13_TBH"
subsetname = 'transv'
pm.convertf_par(pD+fh,pD+fh+'.'+subsetname,'ANCESTRYMAP',pD+
                'CONVERTF.'+fh+'.'+subsetname+'.par',
                badsnpfile=pD+fh+'.transi.snp')

# %%
import itertools
outs=[["Yoruba","Ju_hoan_North","Dinka","Mbuti"],
          ["Tuvinian","Mongola","Yakut","Kyrgyz"],
          ["Han_HGDP","Uygur","Japanese","Ami_Coriell"],
          ["New_Guinea","Papuan","Australian_WGA","Mamanwa"],
          ["Kusunda","Onge","Kharia","Sindhi_Pakistan"]]
myoutgroups=list(itertools.chain.from_iterable(outs)) 
print ' '.join(myoutgroups)

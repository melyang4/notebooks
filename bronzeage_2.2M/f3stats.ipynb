# %%
# %%writefile /home/melinda_yang/projects/bronzeage/2.2M_analysis/calcoutf3.py

import projmodules as pm
from subprocess import Popen, PIPE
import HOdata
from multiprocessing import Pool

allids=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean","Tu",
        "Han","Tujia","Miao","Yi","She","Naxi","Atayal","Ami",
        "Lahu","Dai","Kinh","Burmese","Thai","Cambodian",
        "Clovis","Pima","Mayan","Mixe","Zapotec","Piapoco",
        "Karitiana","Surui","Quechua","Chane","Tibetan","Uygur"]
otherasia=["Onge","Kusunda","Yakut","Ulchi","Tubular","Tlingit",
           "Mongola","Mansi","Kyrgyz","Itelman","Even",
           "Eskimo_Sireniki","Eskimo_Naukan","Eskimo_Chaplin",
           "Chukchi","Altaian","Aleut","Papuan","Maori","Igorot",
           "Hawaiian","Dusun","Bougainville","Australian"]
ancids=["Tianyuan","Donghuigou","Balikun",'Chokhopani1',
        'Mebrak', 'Samdzong', 'BoshanChineseNeolithic','Bbdong',
        'Boisman_MN','Linzi','HDYM1','HQSDW',
        'Pukagongma','Zongri','LiangDaoChineseNeolithic','Longlin',
        'Longlin_d','Xinyi','Xinyi_d','Yana_old','Yana_old2','Kolyma_River']

eur=["UstIshim","Oase1","Kostenki14","GoyetQ116-1","Vestonice16",
     "Malta1","AfontovaGora3","ElMiron","Villabruna","Bichon",
     "Satsurblia","Kotias","Karelia","Motala12","Loschbour",
     "LaBrana1","Hungarian.KO1","Stuttgart","French","Sardinian"]

def dof3work(Apop):
    #pD = "/mnt/solexa/mel_yang/bronzeage/data/" ##ivpp
    #outpD = "/home/mel_yang/projects/neolithic/f3stats/" ##ivpp
    pD="/home/melinda_yang/data/2.2M/" ##mpi
    outpD="/home/melinda_yang/projects/bronzeage/2.2M_analysis/f3stats/" ##mpi
    fh = 'UPA_all7'
    subset = 'X_Mbuti_S1_%s_S2_EASEUR' % Apop
    
    
    #AB = [(i,j) for i in namer+["Malta1"] for j in neas+weas+seas if i != j ]
    #Xs = neas+weas+seas
    
    AB = [(Apop,i) for i in allids+otherasia+ancids+eur ]
    Xs = ["Mbuti"]
    
    pm.f3popfile(AB, Xs, pD+fh, subset)
    pm.f3parfile(pD,fh,subset,popfh=fh)
    outfile = open(outpD+fh+'.f3.'+subset+".log",'w')
    mycommand1='mv '+pD+fh+'.f3.'+subset+'.par '+outpD+fh+'.f3.'+subset+'.par'
    varfile = Popen(mycommand1.split())
    varfile.communicate()
    mycommand = 'qp3Pop -p '+outpD+fh+'.f3.'+subset+'.par'
    print 'Running command', mycommand

    varfile = Popen(mycommand.split(), stdout = outfile)
    varfile.communicate()
    outfile.close()

ancinds=['Tianyuan',"Longlin","LiangDao","Xinyi"]
ancinds=["LiangDao"]
ancinds=['Yana_old','Yana_old2','Kolyma_River']
#mypool = Pool(3)
#results = mypool.map(dof3work, ancinds)
for i in ancinds: dof3work(i)

# %%
sibamer=["Ulchi","Mongola","Clovis","Pima","Mayan","Mixe","Zapotec",
 "Piapoco","Karitiana","Surui","Quechua","Chane","Chipewyan",
 "Saqqaq","Nahua","Cree","Aleut","Mansi","Chukchi","Tlingit",
 "Tubalar","Kyrgyz","Altaian","Even","Yakut","Itelman",
 "Eskimo_Sireniki","Eskimo_Chaplin","Eskimo_Naukan","Saami",
 "Kolyma_River"]

pdeas=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean",
        "Tu","Han","Tujia","Miao","Yi","She","Naxi","Atayal",
        "Ami","Lahu","Dai","Kinh","Burmese","Thai","Cambodian",
        "Tibetan","Uygur"]

anceas=["Tianyuan","Donghuigou","Balikun",'Chokhopani1','Mebrak',
        'Samdzong','BoshanChineseNeolithic','Bbdong','Boisman_MN',
        'Linzi','HDYM1','HQSDW','Pukagongma','Zongri',
        'LiangDaoChineseNeolithic','Longlin','Longlin_d','Xinyi',
        'Xinyi_d','Yana_old','Yana_old2']

otherasia=["Saami","Sherpa","Onge","Kusunda","Mongola","Papuan","Maori","Igorot",
           "Hawaiian","Dusun","Bougainville","Australian"]

eup=["UstIshim","Oase1","Tianyuan","Kostenki14","GoyetQ116-1",
     "Vestonice16","Malta1",'AfontovaGora3',"ElMiron","Villabruna","Bichon",
     "Satsurblia","Kotias","Karelia","Motala12","Loschbour","LaBrana1",
     "Hungarian.KO1","Stuttgart",'French','Sardinian']

# %%
# %%writefile /home/melinda_yang/projects/bronzeage/2.2M_analysis/calcoutf3.py

import projmodules as pm
from subprocess import Popen, PIPE
import HOdata
from multiprocessing import Pool

sibamer=["Ulchi","Mongola","Clovis","Pima","Mayan","Mixe","Zapotec",
 "Piapoco","Karitiana","Surui","Quechua","Chane","Chipewyan",
 "Saqqaq","Nahua","Cree","Aleut","Mansi","Chukchi","Tlingit",
 "Tubalar","Kyrgyz","Altaian","Even","Yakut","Itelman",
 "Eskimo_Sireniki","Eskimo_Chaplin","Eskimo_Naukan","Saami",
 "Kolyma_River"]

pdeas=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean",
        "Tu","Han","Tujia","Miao","Yi","She","Naxi","Atayal",
        "Ami","Lahu","Dai","Kinh","Burmese","Thai","Cambodian",
        "Tibetan","Uygur"]

anceas=["Tianyuan","Donghuigou","Balikun",'Chokhopani1','Mebrak',
        'Samdzong','BoshanChineseNeolithic','Bbdong','Boisman_MN',
        'Linzi','HDYM1','HQSDW','Pukagongma','Zongri',
        'LiangDaoChineseNeolithic','Longlin','Longlin_d','Xinyi',
        'Xinyi_d','Yana_old','Yana_old2']

otherasia=["Saami","Sherpa","Onge","Kusunda","Mongola","Papuan","Maori","Igorot",
           "Hawaiian","Dusun","Bougainville","Australian"]

eup=["UstIshim","Oase1","Tianyuan","Kostenki14","GoyetQ116-1",
     "Vestonice16","Malta1",'AfontovaGora3',"ElMiron","Villabruna","Bichon",
     "Satsurblia","Kotias","Karelia","Motala12","Loschbour","LaBrana1",
     "Hungarian.KO1","Stuttgart",'French','Sardinian']

allids=sibamer+pdeas+anceas+otherasia+eup

def dof3work(Apop):
    #pD = "/mnt/solexa/mel_yang/bronzeage/data/" ##ivpp
    #outpD = "/home/mel_yang/projects/neolithic/f3stats/" ##ivpp
    pD="/home/melinda_yang/data/2.2M/" ##mpi
    outpD="/home/melinda_yang/projects/bronzeage/2.2M_analysis/f3stats/" ##mpi
    fh = 'UPA_all7'
    subset = 'X_Mbuti_S1_%s_S2_EASEUR' % Apop
    
    
    #AB = [(i,j) for i in namer+["Malta1"] for j in neas+weas+seas if i != j ]
    #Xs = neas+weas+seas
    
    AB = [(Apop,i) for i in allids ]
    Xs = ["Mbuti"]
    
    pm.f3popfile(AB, Xs, pD+fh, subset)
    pm.f3parfile(pD,fh,subset,popfh=fh)
    outfile = open(outpD+fh+'.f3.'+subset+".log",'w')
    mycommand1='mv '+pD+fh+'.f3.'+subset+'.par '+outpD+fh+'.f3.'+subset+'.par'
    varfile = Popen(mycommand1.split())
    varfile.communicate()
    mycommand = 'qp3Pop -p '+outpD+fh+'.f3.'+subset+'.par'
    print 'Running command', mycommand

    varfile = Popen(mycommand.split(), stdout = outfile)
    varfile.communicate()
    outfile.close()

ancinds=['Yana_old','Yana_old2','Kolyma_River','Itelman']
mypool = Pool(4)
results = mypool.map(dof3work, ancinds)
#for i in ancinds: dof3work(i)
# Out:
# Overwriting /home/melinda_yang/projects/bronzeage/2.2M_analysis/calcoutf3.py

# %% [markdown]
# # mtDNA analysis
# ## Defining of different haplogroups and how this was done

# %% [markdown]
# ### From aligned fasta including HGDP individuals, subset HGDP set to wanted countries
# We also add to the HGDP individual name the ethnic group and haplogroup call.

# %%
##Filter for certain HGDP data -- like Asians only?
import bioinformatics as bio
import collections
pD="/mnt/solexa/mel_yang/bronzeage/mtdna/"
hgdpinfo=open(pD+"HGDP_info.txt",'r')
fastafile=open(pD+"Shang+HGDPaligned_manual.fasta")

myids,myseqs=bio.parsefasta(pD+"Shang+HGDPaligned_manual.fasta")
print myids[50]

myloc=collections.defaultdict(list)
myhaps=collections.defaultdict(list)
mydata=[]
myinds=[]
for ind,line in enumerate(hgdpinfo):
    x = line.split('\t')
    myloc[x[3]].append(x[0])
    myhaps[x[3]].append(x[2]+"|"+x[6])
    #mydata.append(x[2]+"|"+x[6])
    #myinds.append(x[0])
    #if ind==10:break
print myloc.keys()
print [len(myloc[i]) for i in myloc.keys()]
wantedids=myloc["China"]+myloc["Japan"]+myloc["Nigeria"] #myinds #myloc["Cambodia"]+myloc["China"]+myloc["Japan"]
wantedhaps=myhaps["China"]+myhaps["Japan"]+myhaps["Nigeria"] #mydata #myhaps["Cambodia"]+myhaps["China"]+myhaps["Japan"]
print len(wantedids)

newids,newseqs=[],[]
for ind,myid in enumerate(myids):
    if myid[1:] in wantedids or "HGDP" not in myid: 
        if myid[1:] in wantedids: 
            newids.append(myid+"|"+wantedhaps[wantedids.index(myid[1:])])
        else: newids.append(myid)
        newseqs.append(myseqs[ind])
    else:
        continue
        
#anno_Shang+HGDPaligned_manual.fasta
#Cambodia_China_Japan_Shang+HGDPaligned_manual.fasta
newfile=open(pD+"Nigeria_China_Japan_Shang+HGDPaligned_manual.fasta",'w') 
for ind,myseq in enumerate(newseqs):
    newfile.write('%s\n' % (newids[ind]))
    for ind2,bp in enumerate(myseq):
        if ind2%70!=0: continue
        newfile.write(myseq[ind2:(ind2+70)]+'\n')
newfile.close()
# Out:
# >HGDP00469
# ['Brazil', 'Italy', 'Israel_(Central)', 'Cambodia', 'Democratic_Republic_of_Congo', 'Bougainville', 'Nigeria', 'Israel_(Negev)', 'Italy_(Bergamo)', 'Orkney_Islands', 'South_Africa', 'China', 'Russia_Caucasus', 'Siberia', 'Israel_(Carmel)', 'Pakistan', 'Country', 'Namibia', 'Kenya', 'France', 'Russia', 'Central_African_Republic', 'Mexico', 'New_Guinea', 'Senegal', 'Colombia', 'Japan', 'Algeria_(Mzab)']
# [45, 36, 48, 11, 15, 22, 25, 49, 14, 16, 8, 184, 17, 25, 48, 198, 1, 7, 12, 53, 25, 36, 50, 17, 24, 13, 31, 29]
# 240

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1057-cfa3b36ce590> in <module>()
# ----> 1 print __version__
#
# NameError: name '__version__' is not defined

# %% [markdown]
# ## List of defining mtDNA for different haplogroups

# %%
L123456="C146T  C182T  T4312C  T10664C  C10915T  A11914G  G13276A  G16230A"
L23456="C152T  A2758G  C2885T  G7146A  T8468C"
L2346="C195T  A247G  A825t  T8655C  A10688G  C10810T  G13105A  T13506C  G15301A  A16129G  T16187C  C16189T"
L346="G4104A  A7521G"
L34="T182C!  T3594C  T7256C  T13650C  T16278C"
L3="A769G  A1018G  C16311T"

N="G8701A  C9540T  G10398A  C10873T  A15301G!"
R=" T12705C  T16223C"

M="T489C  C10400T  T14783C  G15043A"
M80D="C4883T"
D="C5178a  T16362C"
D4="G3010A  C8414T  C14668T"
D5="T16189C! C150T  T1107C  A5301G  A10397G"
D6="T16189C! G709A  G1719A  A3714G  A12654G  T16311C!"

# %% [markdown]
# ### Script for finding unique SNPs in one sequence relative to another
# Needs aligned and rCRS in fasta file, and positions should correspond to rCRS

# %%
import bioinformatics as bio

pD="/mnt/solexa/mel_yang/bronzeage/mtdna/"
myids,myseqs=bio.parsefasta(pD+"aligned_Shang+rCRS+refseqs_manual.fasta") 

ref,myid=("JQ704974","R2062") 
ref,myid=("JQ704974","D5604") 
ref,myid=("KC733262","R2084") 
ref,myid=("JF824906","D5606") 
ref,myid=("R2062","R2055")
refind=[ind for ind,i in enumerate(myids) if ref in i]
myidind=[ind for ind,i in enumerate(myids) if myid in i]

refseq=myseqs[refind[0]]
myseq=myseqs[myidind[0]]
print len(myseqs[0])
missing=0
numcontrol,numcoding=0,0
mystr="\t%s\t%s\t%s\n" % ("Pos","hg",myid)
for pos,i in enumerate(myseq):
    if pos < 576 or pos > 16023: addon="Control"
    else: addon="" #myid
    if refseq[pos] != myseq[pos]: 
        if myseq[pos] in ["N","-"]: missing+=1
        else: 
            if addon=="Control": numcontrol+=1
            else: numcoding+=1
            mystr += "%s\t%i\t%s\t%s\n" % (addon,pos+1,refseq[pos],myseq[pos])
print
print "##ref|hg|ID:%s|%s" % (myids[refind[0]][1:],myid) 
print "##Missing sites:%i" % missing
print "##Number different in Control (16024-576):%i" % numcontrol
print "##Number different in Coding (577-16023):%i" % numcoding
print
print mystr
# Out:
# 16569
#
# ##ref|hg|ID:R2062|XS|R2055
# ##Missing sites:2
# ##Number different in Control (16024-576):2
# ##Number different in Coding (577-16023):0
#
# 	Pos	hg	R2055
# Control	3	N	T
# Control	310	C	T

# %%
import bioinformatics as bio
import collections
pD="/mnt/solexa/mel_yang/bronzeage/mtdna/"

mysites={"XSQ":["D5603","D5602","D5601","D1967","D1962","D1968","D1965","D1960","D1961"],
        "LZ":["R2038","R2039","R2024","R2087",'R2023'],
        "GDM":["D5604","D5605","D5608","D5606","D5607"],
        "YJ":["R2084"],
        "XS":["R2086","R2055","R2062","R2123","R2090"],
        "XHC":["D5611","D5613","D5612"]}
sites,ids=[],[]
for i in mysites:
    sites+=[i]*len(mysites[i])
    ids+=mysites[i]

myids,myseqs=bio.parsefasta(pD+"aligned_pdEAS+rCRS+Shang.fasta")
#myids,myseqs=bio.parsefasta(pD+"Shang.fasta")
#myids,myseqs=bio.parsefasta(pD+"Shang+RSRS_MAF.fasta")
#myids,myseqs=bio.parsefasta(pD+"Shang_rCRS_muscle_haplogrep.fasta")

refind= [ind for ind,i in enumerate(myids) if "012920" in i][0]
refseq=myseqs[refind]

myseqs=myseqs[:refind]+myseqs[(refind+1):]
myids=myids[:refind]+myids[(refind+1):]
#myseqs=[myseqs[ind] for ind,i in enumerate(myids) if "HGDP" not in i]
#myids=[i for ind,i in enumerate(myids) if "HGDP" not in i]
myseqs=[myseqs[ind] for ind,i in enumerate(myids)]
myids=[i for ind,i in enumerate(myids)]

newids=[]
for myid in myids:
    if 'min_cov5' in myid:
        if 'Split' in myid: newids.append(myid[1:].split('|')[0].split('_')[1])
        else: newids.append(myid[1:].split('.')[0])
    else: newids.append(myid)
#newids=[myid[1:].split('|')[0].split('_')[1] if 'Split' in myid else myid[1:].split('.')[0]  for myid in myids ]
badids=['D5612','D1960','R2123','R2090','D5613','R2023'] 
#Id #Missing
#D5612 6891
#D5613 2948
#R2023 2396
#R2123 2007
#R2090 1453
#D1960 1167
#for i in newids: print i
filtseqs=[i for ind,i in enumerate(myseqs) if newids[ind] not in badids]
filtids = [i for ind,i in enumerate(newids) if newids[ind] not in badids]

newbases=['' for i in myseqs]
delpos=[]
num=0
for posind,base in enumerate(refseq): ##posind==position on sequence
    if base == '-': delpos.append(posind); continue
    num+=1
    mybases=[]
    for myind,i in enumerate(myseqs): ##myind==each mtDNA sequence (each individual)
        if num==3107: newbases[myind]+='N' ##3107 deletion in rCRS, artifact?
        elif num==16519: newbases[myind]+='N' ##hotspot
        elif num in range(515,523): newbases[myind]+='N' #AC indels repeats
        elif num in range(16182,16184): newbases[myind]+='N'
        else: newbases[myind]+=i[posind]
        mybases.append(i[posind])
    #if num==10: break

    uniqbases=collections.Counter(mybases)
    #if len(uniqbases.keys())>1:print base, num,uniqbases

newfile=open(pD+"Shang+HGDPaligned_manual.fasta",'w')
for ind,myseq in enumerate(newbases):
    if "HGDP" not in newids[ind]: newfile.write('>%s|%s\n' % (newids[ind],sites[ids.index(newids[ind])]))
    else: newfile.write(newids[ind] + '\n')
    for ind2,bp in enumerate(myseq):
        if ind2%70!=0: continue
        newfile.write(myseq[ind2:(ind2+70)]+'\n')
newfile.close()

# %% [markdown]
# ## Get rCRS aligned fasta file

# %%
import bioinformatics as bio
import collections
pD="/mnt/solexa/mel_yang/bronzeage/mtdna/"

mysites={"XSQ":["D5603","D5602","D5601","D1967","D1962","D1968","D1965","D1960","D1961"],
        "LZ":["R2038","R2039","R2024","R2087",'R2023'],
        "GDM":["D5604","D5605","D5608","D5606","D5607"],
        "YJ":["R2084"],
        "XS":["R2086","R2055","R2062","R2123","R2090"],
        "XHC":["D5611","D5613","D5612"]}
sites,ids=[],[]
for i in mysites:
    sites+=[i]*len(mysites[i])
    ids+=mysites[i]

myids,myseqs=bio.parsefasta(pD+"aligned_Shang+rCRS+refseqs.fasta")

refind= [ind for ind,i in enumerate(myids) if "012920" in i][0]
refseq=myseqs[refind]

myseqs=myseqs[:refind]+myseqs[(refind+1):]
myids=myids[:refind]+myids[(refind+1):]
#myseqs=[myseqs[ind] for ind,i in enumerate(myids) if "HGDP" not in i]
#myids=[i for ind,i in enumerate(myids) if "HGDP" not in i]
myseqs=[myseqs[ind] for ind,i in enumerate(myids)]
myids=[i for ind,i in enumerate(myids)]

newids=[]
for myid in myids:
    if 'min_cov5' in myid:
        if 'Split' in myid: newids.append(myid[1:].split('|')[0].split('_')[1])
        else: newids.append(myid[1:].split('.')[0])
    else: newids.append(myid)

badids=['D5612','D1960','R2123','R2090','D5613','R2023'] 

filtseqs=[i for ind,i in enumerate(myseqs) if newids[ind] not in badids]
filtids = [i for ind,i in enumerate(newids) if newids[ind] not in badids]

newbases=['' for i in myseqs]
delpos=[]
num=0
for posind,base in enumerate(refseq): ##posind==position on sequence
    if base == '-': delpos.append(posind); continue
    num+=1
    mybases=[]
    for myind,i in enumerate(myseqs): ##myind==each mtDNA sequence (each individual)
        if num==3107: newbases[myind]+='N' ##3107 deletion in rCRS, artifact?
        elif num==16519: newbases[myind]+='N' ##hotspot
        elif num in range(515,523): newbases[myind]+='N' #AC indels repeats
        elif num in range(16182,16184): newbases[myind]+='N'
        else: newbases[myind]+=i[posind]
        mybases.append(i[posind])
    #if num==10: break

    uniqbases=collections.Counter(mybases)
    #if len(uniqbases.keys())>1:print base, num,uniqbases

newfile=open(pD+"aligned_Shang+rCRS+refseqs_manual.fasta",'w')
for ind,myseq in enumerate(newbases):
    
    if newids[ind] in ids: newfile.write('>%s|%s\n' % (newids[ind],sites[ids.index(newids[ind])]))
    else: newfile.write(newids[ind] + '\n')
    for ind2,bp in enumerate(myseq):
        if ind2%70!=0: continue
        newfile.write(myseq[ind2:(ind2+70)]+'\n')
newfile.close()

# %% [markdown]
# ## Indicate number of missing sites per individual

# %%
for ind,i in enumerate(myseqs):
    print newids[ind],sum([1 for bp in i if bp in ['-','N']])
# Out:
# D5612 6890
# D5613 2955
# R2023 2404
# R2123 2015
# R2090 1452
# D1960 1173
# D5611 287
# D1961 243
# D1962 73
# D5602 58
# D5607 47
# D1967 35
# R2055 16
# R2062 17
# R2084 12
# R2038 27
# R2039 12
# D5604 16
# R2024 23
# D1968 29
# D1965 40
# D5605 15
# D5603 20
# R2086 15
# R2087 13
# D5601 21
# D5608 14
# D5606 18

# %%
mysites={"XSQ":["D5603","D5602","D5601","D1967","D1962","D1968","D1965","D1960","D1961"],
        "LZ":["R2038","R2039","R2024","R2087",'R2023'],
        "GDM":["D5604","D5605","D5608","D5606","D5607"],
        "YJ":["R2084"],
        "XS":["R2086","R2055","R2062","R2123","R2090"],
        "XHC":["D5611","D5613","D5612"]}
sites,ids=[],[]
for i in mysites:
    sites+=[i]*len(mysites[i])
    ids+=mysites[i]
print sites
print ids
# Out:
# ['XHC', 'XHC', 'XHC', 'YJ', 'XSQ', 'XSQ', 'XSQ', 'XSQ', 'XSQ', 'XSQ', 'XSQ', 'XSQ', 'XSQ', 'XS', 'XS', 'XS', 'XS', 'XS', 'LZ', 'LZ', 'LZ', 'LZ', 'LZ', 'GDM', 'GDM', 'GDM', 'GDM', 'GDM']
# ['D5611', 'D5613', 'D5612', 'R2084', 'D5603', 'D5602', 'D5601', 'D1967', 'D1962', 'D1968', 'D1965', 'D1960', 'D1961', 'R2086', 'R2055', 'R2062', 'R2123', 'R2090', 'R2038', 'R2039', 'R2024', 'R2087', 'R2023', 'D5604', 'D5605', 'D5608', 'D5606', 'D5607']

# %% [markdown]
# ### Test what bases are at a particular site--several lists for haplogroup defining SNPs

# %%
import bioinformatics as bio

pD="/mnt/solexa/mel_yang/bronzeage/mtdna/"
#myids,myseqs=bio.parsefasta(pD+"Shang_HGDPaligned_manual.fasta") 
#myids,myseqs=bio.parsefasta(pD+"Shang_manual.fasta")
myids,myseqs=bio.parsefasta(pD+"aligned_Shang+rCRS+refseqs_manual.fasta") 


L3=[769,1018,16311] ##A769G A1018G C16311T
N=[8701,9540,10398,10873,15301] #G8701A C9540T G10398A C10873T A15301G!
R=[12705,16223] #T12705C T16223C
A13=[3504] #T3504C
A=[235,663,1736,4248,4824,8794,16290,16319] #A235G A663G A1736G T4248C A4824G C8794T C16290T G16319A
Aplus=[152,16362]
A5=[8563,11536]
A10=[5393,7468,9948,10094,16227,16311]
A15=[207,263,8459,14067]
A15a=[11084]
B45=range(8281,8290)
B4=[16217] #T16217C
B4i=[6302] #A6302G
R9=[3970,13928,16304] #C3970T G13928c T16304C
B5=[709,8584,9950,10398,16140]

JT=[11251,15452,16126] #A11251G C15452a T16126C
P=[15607] ##A15607G
F=[249,6392,10310] #A249d T6392C G10310A, from R9
F1=[6962,10609,12406,12882] #G6962A T10609C G12406A C12882T
F1d=[146,1734,5628,7738,15402] #T146C! C1734T T5628C T7738C C15402T
R0=[73,11719] #G73A A11719G
HV=[14766] #T14766C
H=[2706,7028] #G2706A T7028C

R1=[1391,16311] #T1391C T16311C!
R2=[152,4769,7657,8473,9932,10685,12654,14305,16071] #T152C! G4769A T7657C T8473C G9932A G10685A A12654G G14305A C16071T
R2JT=[4216] #T4216C
R12_21=[10398,11404,16295] #A10398G! A11404G C16295T
R5=[8594,10754,14544,16304,16524] #T8594C A10754G G14544A T16304C A16524G
R6=[195,12285,16266,16362] #(T195C!) T12285C (C16266T) T16362C
R7=[13105,16319,16362] #A13105G! G16319A T16362C
R8=[195,2755,3384,7759,9449,13215] # T195C! A2755G A3384G T7759C C9449T T13215C
R9=[3970,13928,16304] #C3970T G13928c T16304C
Rplus=[16189]

R14=[56,182,204,234,573,4002,7022,8860,9128,10172,11321,11560,12612,13281,14002,14800,15394,15458,16187,16288,16304,16362] #A56t C182T!! T204C A234G 573.XC T4002C T7022g G8860A T9128C G10172A A11321G A11560G A12612G T13281C A14002G C14800T T15394C T15458C C16187T! T16288C T16304g T16362C
R22=[152,329,1040,6770,10316,10609,13359,16249,16288,16304] #T152C! G329A T1040C A6770G A10316G T10609C G13359A T16249C T16288C T16304C
R23=[195,634,6216,7007,7158,7388,7822,8614,10987,11914,12151,12459,13885,14687,15412,16256,16290,16465] #T195C! T634a T6216C C7007T A7158G A7388G A7822G T8614C A10987G G11914A! A12151G A12459G C13885a A14687G T15412C C16256T C16290T C16465T
R24=[146,3565,4260,9759,11710,12483,16051,16185,16193] #T146C! A3565G C4260T C9759T C11710T C12483T A16051G C16185T C16193d
R30=[8584] #G8584A
R31=[15884,16362] #G15884A (T16362C)
R32=B45+[152,3816,4820,8464,8743,8784,8887,9116,12771,15712,16145,16185,16239,16311,16325] #T152C! A3816G G4820A 8281-8289d C8464T G8743A A8784G A8887G T9116C G12771A A15712G G16145A C16185T C16239T T16311C! T16325C
U=[11467,12308,12372] #A11467G A12308G G12372A
M=[489,10400,14783,15043] #T489C C10400T T14783C G15043A
M2=[447,1780,11083,15670,16274]
M3=[482,16126]
M5=[1888,16129]
M6=[461,5301,5558,10640,14128,16362]
M7=[6455,9824] #C6455T T9824C
M8=[4715,7196,8584,15487,16298]
M80D=[4883] #C4883T
M10=[573,709,4140,8793,12549,13152,14502,15040,15071,16311]
M11=[215,318,326,1095,6531,7642,8108,9950,11969]
M14=[234,4216,6962]
M15=[64,183,8167,11002,11629,12662,13659,14284,15412,16147,16193,16249,16362]
M17=[930,12973,16209]
M22=[710,4639,6776]
M25=[150,316,869,1406,3511,7954,8776,11734,13144,13350,13708,16129,16189,16223,16290,16368]
M26=[152,5656,9899,11428,11521,12190,13708,13932,14218,14311,15109,15263,16214,16256,16278]
M27=[5375,9201,12358]
M28=[152,195,1719,6281,6374,10245,15067,16148,16362,16468]
M31=[4907,11176,15440,15530]
M36=[239,7271,15110]
M40=[8925,15721,15954,16463]
M44=[146,961,16301]
M47=[16129,16166,16189,16287,16319]
M48=[199,6366,15900,16225,16234,16390]
M49=[3780,16234]
M50=[7226,15663,16263]
M52=[1462,1598,5460,6020,16275]
M58=[3209,5460]
M59=[249,9380,10256,11140,14040,16140,16278]
M60=[7912,8345]
M62_68=[150,4561,7664]
M69=[4392,11365]
M71=[8718,15458,16271]
M72=[1872,14233,15644,15820,16166,16214]
M73_79=[14034,16278]
M76=[513,3753,7521,10325,12406,14341,16189,16223,16293,16362]
M81=[215,4254,6620,13590,16129,16311]
M91=[93,3447,4164,15652,16287,16327]


D=[5178,16362] #C5178a T16362C, from M80D
D4=[3010,8414,14668] #G3010A C8414T C14668T
D4a=[152,3206,8473,14979,16129]
D4b=[8020]
D4d=[3593,5539,6503,7757,9938,12085,13879,16319]
D4h=[3336,3644,5048]
D4h1=[16174]
D4h1c=[152,7181,7673,13914,16311]
D4h1c1=[14470,16317]
D4k=[195,12092,16362]
D4o=[195,10646,16290]
D4p=[195,198,15106]
D4l=[10427,16368]
D4m=[8762,12651]
D4n=[3421,16355]
D4q=[200,16256,16311]
D4s=[199,813,12662]
D4t=[263,15901]
D1=[2092,16325]
D5=[150,1107,5301,10397] #C150T T1107C A5301G A10397G
D5ab=[9180] #A9180G
D5a=[752,11944,12026] #C752T T11944C A12026G
D5a2=[1438,16172] #G1438A T16172C

M9=[4491,16362]
E=[3027,3705,7598,13626,16390]

A3=[2857,8962,9711]
A7=[146,8413,10172,15379,16051,16129,16189]
A9=[6950,7228,8340,10700,15874]
A11=[9650,16293]

A2=[146,152,153,8027,12007,16111]
A6=[654,3687,13287]
A16=[298,2706,6023,11557,14929,16292]
A17=[4113,5514,9126,15217]
A18=[11465]
A19=[199,15436,16311]
A20=[14696]
A21=[14364]
A22=[6378,8393,9123,9128]
A24=[449,9524,15172]
A25=[16179]
A26=[4924,9716,11809,13650,13752,14968,16144]

M7c=[146,4850,11665,12091]
M7c1=[199,5442,16295]
M7c2=[3912,5378,9449,10897,11932,14053,15338,16172,16311]
M7c3=[4856,5460,11527,11875,12950,14118]
M7c1b=[12561]
M7c1b2=[9957,13590]
M7c1b2b=[7337,10861]
R24=[146,3565,4260,9759,11710,12483,16051,16185,16193]

weirddel=range(21,28)

B4bdej=[827,15535]
B4b=[499,4820,13590]
B4b1=[16136]
B4b1bc=[16218]
B4b1b=[152,1391,3981,5585,13934,14569,16298,16362]
B4b1c=[14587]
B4b1c1=[7521,9101,11239,11914]
N2=[189,709,5046,11674,12414]
R9c=[7861,11002,15479]
F1=[6962,10609,12406,12882]
F2=[1005,1824,7828,10535,10586,12338,13708]
F3=[3434,5585,5913,5978,10320,11065,16298,16304,16362]
F4=[5263,12630,15670]
D6=[709,1719,3714,12654,16311]
E=[3027,3705,7598,13626,16390]
N9a=[150,5231,12358,12372,16257,16261]
N9a13=[16129]
N9a1=[4386,12007,16111]
N9a1a=[15095]
D4c=[16245]
D4e=[11215]
D4f=[7270]
D4g=[13104]
D4i=[16294]
D4j=[11696]
D4j12=[7353,8273,15470]
D5c=[151,152,4200,4216,14927,15622,16190]
D5c1=[146,3546,13105,16390]
D5c1a=[182,217,16223]
D5c2=[16311,7129,7669,8580,12810,13984,15737,16316]
D6a=[16274]
D6a1=[6701,7424,7879,13194,16311]
D6a2=[4679,4937,14530,16129,16189,16317]
A8a=[16242,64,146]
A8a1=[152,6962,8865,12777]
F2c2=[761,5978,6156,6570,8152,14133,15418,16067,16271]
D4h1c=[152,7181,7673,13914,16311]
N3=[146,210,571,1005,3357,6366,6806,7897,8653,8937,10586,14634,16086,16172,16187,16189,16217]
N7=[723,6570,11617,13542,14668,15945,16129,16318]
N8=[2760,3027,7885,7961,8188,10398,13710,15211,16263,16274,16311,16343]
N9=[5417]
N10=[750,5581,16172,16362]

N13=[146,152,178,195,2831,5704,6896,10101,11020,13263,16066,16261,16290]
N14=[1598,1888,4917,5291,8251,8269,11491,14384,15040,15884]
N21=[150,337,6752,8701,10583,13437,14560,16193]
N22=[150,942,7158,9254,11365,16168,16249]
O=[6755,9140,16213]
S=[8404]
X=[6221,6371,13966,14470,16189,16278]
N9a=[150,5231,12358,12372,16257,16261]
N9b=[5147,10607,11016,13183,14893,16189]
Y=[8392,10398,14178,14693,16126,16223,16231]
M1=[195,6446,6680,12403,12950,16129,16189,16249,16311]
M20=[152,249,316,3200,3714,4385,4772,7433,8853,9127,9512,10274,10679,11914,12354,14974,15691,16129,16209,16272]
M51=[150,4697,4973,9509,14356,14687,15317,16278]
M4=[6620,7859,16145,16261]
M67=[143,2833,4227,5979,6366,9863,12406,13708,15769,15833,16075,16169]
M18=[12498,13135,16318]
M38=[4099,15314,15487]
M12=[4170,5580,12030,12372,14727,15010,16234,16290]
G=[709,4833,5108,16362]
M80=[249,709,1352,2695,4197,4823,5492,5894,7939,8429,8775,9254,11732,14118,16134,16189,16325]
D4e5=[5021,15106,15184,16274]
R0ab=[58,64,2442,16362]
A5a=[2156,4655,11647,16187]
A5b=[961,965]
A5c=[152,16129,16213]
A5b1=[1709,16126,16235]
A8=[16242]
A8a=[64,146]
mysets=[("D5604",L3+M+M80D+D+D4),
        ("D5605",L3+N+R+R9+F+F1+F1d),
        ("D5608",L3+N+A+A13),
        ("D5606",L3+N+R+B45+B4+B4i),
        ("D5607",L3+M+M80D+D+D5+D5ab+D5a),
        
        ("R2038",L3+M+M80D+D+D4+D4j+D4j12),
        ("R2039",L3+M+M80D+D+D6+D6a),
        ("R2024",L3+M+M80D+D+D4),
        ("R2087",L3+N+A+A5+A5b+A5b1),
        ("R2023",L3+N),
        
        ("D5611",L3+N),
        ("D5613",L3+N+R),
        ("D5612",L3+M),
        
        ("R2086",L3+N+A+A8+A8a),
        ("R2055",L3+M+M80D+D+D5+D5c+D5c2),
        ("R2062",L3+M+M80D+D+D5+D5c+D5c2),
        ("R2123",L3+N+R+R9+F+F2+F2c+[761,14133]),
        ("R2090",L3+M+M80D+D+D5+D5ab+D5a),
        
        ("D5603",L3+N+N9+N9a1),
        ("D5602",L3+N),
        ("D5601",L3+N+A+[152,16362]),
        ("D1967",L3+M+M7+M7c+M7c1+M7c1b+M7c1b2+M7c1b2b),
        ("D1962",L3+M+M80D+D+D4),
        ("D1968",L3+N+R+B45+B4+B4bdej+B4b+B4b1+B4b1bc+B4b1c+B4b1c1),
        ("D1965",L3+N+A+[152,16362]+A15+A15a),
        ("D1960",L3+N+R),
        ("D1961",L3+M+M9+E),
        ("R2084",L3+M+M80D+D+D4+D4h+D4h1+D4h1c)]
mysets=[("D5602",N+M)]
#myid="R2023"
#poses=L3+N+R+B45+B4+B4bdej+B4b+B4b1+B4b1bc+B4b1c+B4b1c1
#L3+M+M80D+D+D6+D6a+D6a2
for myid,poses in mysets:
    poses=[i-1 for i in poses]
    print [i+1 for i in poses]
    for ind,myseq in enumerate(myseqs):
        if 'HGDP' in myids[ind]: continue
        subset=[myseq[pos] for pos in poses]
        if myid in myids[ind]: 
            print myids[ind],'-----',subset,'----'
            #print myid,len([i for i in subset if i not in '-N']), len(subset)
        else: pass #print myids[ind],'\t',subset
    #print [i+1 for i in poses]
# Out:
# [8701, 9540, 10398, 10873, 15301, 489, 10400, 14783, 15043]
# >D5602|XSQ ----- ['N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N'] ----

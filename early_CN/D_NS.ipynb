# %%
##Qihe_d

import fstat_funcs as ff

pD="/mnt/solexa/mel_yang/early_CN/"
outpd="/mnt/solexa/mel_yang/early_CN/D_South/"
fh="F4.list.F4"
fh="F4.list.F4tv"
out="Mbuti"        

panel1=["Tianyuan","NE_20","La368_G1","Onge","Papuan","JomonM","Kolyma_River","Shamanka_EN",
        "ZongriM297","Hejiatai","Chokhopani","Ma912_G2","Man_Bac","Ami","Atayal","Han","Dai",
        "Sherpa_Shigatse","Tibetan_Shannan","Daur","Korean"]

south=["XJS","XJS_F","Dushan","Man_Bac","Nui_Nap",
       "Suogang","Qihe","LiangDaoF","LiangDaoM",
       "Ma555_G6","Ami","Atayal","Dai","Lahu","Kinh","Han"]
south=["Suogang","Qihe","LiangDaoF","LiangDaoM","Xinyi","Dushan",
       "Ma555_G6","Ami","Atayal","Dai","Lahu","Kinh","Han"]
       #"Ma555_G6","Ami","Atayal","Dai","Kinh","Lahu","Han"]
northern=["DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao_d_Fu",
          "HDYM1","ZhaoguoM2","Daxi","Dashuitian",
          "Jiahu_M52_I2_Fu"]
ns=["Han","Qihe","LiangDaoF","LiangDaoM","Suogang","Dushan","Xinyi","Dashuitian",
    "Bbdong","Boshan","XJS","XJS_F","Xiaogao","HDYM1","Shamanka_EN",
   "ZongriM297","Hejiatai","Chokhopani","Daxi","Baojianshan"]
mylst=ns
print mylst
varies=["Boshan","Bbdong","ZongriM297","Hejiatai","Chokhopani","Ma912_G2",
       "Korean","Han","Dai","Miao","She","HDYM1","Shamanka_EN","ZhaoguoM2",
        "Xiaogao","Xiaogao_d","DonghulinM1",
       "Dashuitian","Jiahu_M52_I2_Fu"]#+south
varies=["Tianyuan","La368_G1","Shamanka_EN","ZongriM297","Chokhopani",
        "Longlin","Baojianshan","Ami","Han","Dai","Daur","Papuan","Onge",
        "JomonM","Jomon","Kolyma_River"]
#varies=["Qihe","LiangDaoF","LiangDaoM","Suogang","Dushan","Xinyi","Dashuitian",
#    "Bbdong","Boshan","XJS","XJS_F","Xiaogao","HDYM1","Daxi"]
#varies=["Kolyma_River"]
for myind in varies:
    print myind
    pops=[out,mylst,myind,mylst]
    ff.Dmat2xlsx(ff.Dmkary(pD,fh,pops,"Z"),outpd+"Z.tv.P2_"+myind+".NS_Zall."+fh,ff.Dmklabel(pops),mylst,mylst)

    pops=[out,myind,mylst,mylst]
    ff.Dmat2xlsx(ff.Dmkary(pD,fh,pops,"Z"),outpd+"Z.tv.P3_"+myind+".NS_Zall."+fh,ff.Dmklabel(pops),mylst,mylst)
# Out:
# ['Han', 'Qihe', 'LiangDaoF', 'LiangDaoM', 'Suogang', 'Dushan', 'Xinyi', 'Dashuitian', 'Bbdong', 'Boshan', 'XJS', 'XJS_F', 'Xiaogao', 'HDYM1', 'Shamanka_EN', 'ZongriM297', 'Hejiatai', 'Chokhopani', 'Daxi', 'Baojianshan']
# Kolyma_River

# %%
##Qihe_d

import fstat_funcs as ff

pD="/mnt/solexa/mel_yang/early_CN/"
outpd="/mnt/solexa/mel_yang/early_CN/D_South/"
fh="F4.list.F4"
out="Mbuti"        

panel1=["Tianyuan","NE_20","La368_G1","Onge","Papuan","JomonM","Kolyma_River","Shamanka_EN",
        "ZongriM297","Hejiatai","Chokhopani","Ma912_G2","Man_Bac","Ami","Atayal","Han","Dai",
        "Sherpa_Shigatse","Tibetan_Shannan","Daur","Korean"]

south=["XJS","XJS_F","Dushan","Man_Bac","Nui_Nap",
       "Suogang","Qihe","LiangDaoF","LiangDaoM",
       "Ma555_G6","Ami","Atayal","Dai","Lahu","Kinh","Han"]
south=["Suogang","Qihe","LiangDaoF","LiangDaoM","Xinyi","Dushan",
       "Ma555_G6","Ami","Atayal","Dai","Lahu","Kinh","Han"]
       #"Ma555_G6","Ami","Atayal","Dai","Kinh","Lahu","Han"]
northern=["DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao_d_Fu",
          "HDYM1","ZhaoguoM2","Daxi","Dashuitian",
          "Jiahu_M52_I2_Fu"]
ns1=["Han","Dai","Ami","Ma555_G6","Qihe","LiangDaoF","LiangDaoM","Suogang","Dushan","Xinyi","Dashuitian",
    "Bbdong","Xiaogao","HDYM1","ZongriM297","Chokhopani","Daxi","Baojianshan"]
ns2=["Han","Dai","Ami","Qihe","LiangDaoF","Dushan","Xinyi","Dashuitian",
    "Bbdong","Xiaogao","XJS","XJS_F","Boshan","HDYM1","ZongriM297","Chokhopani","Daxi","Baojianshan"]
mylst=ns1
print mylst

varies=["Qihe","LiangDaoF","LiangDaoM","Suogang","Dushan","Xinyi","Dashuitian",
    "Bbdong","Boshan","XJS","XJS_F","Xiaogao","HDYM1","Daxi"]
varies=["Tianluoshan","Liangzhu_T4620","DonghulinM1","Jiahu_M52_I2_d",
       "Kolyma_River","Boisman_MN","Han_ShandongX","Han_GansuX","Han",
       "Han_HenanX","Han_JiangsuX","Han_SichuanX","Han_GuangdongX"]
varies=["ZongriM297","Hejiatai","Chokhopani"]
for myind in varies:
    print myind
    pops=[out,mylst,myind,mylst]
    ff.Dmat2xlsx(ff.Dmkary(pD,fh,pops,"Z"),outpd+"Z.P2_"+myind+".NS1_ZS."+fh,ff.Dmklabel(pops),mylst,mylst)

    pops=[out,myind,mylst,mylst]
    ff.Dmat2xlsx(ff.Dmkary(pD,fh,pops,"Z"),outpd+"Z.P3_"+myind+".NS1_ZS."+fh,ff.Dmklabel(pops),mylst,mylst)
# Out:
# ['Han', 'Dai', 'Ami', 'Ma555_G6', 'Qihe', 'LiangDaoF', 'LiangDaoM', 'Suogang', 'Dushan', 'Xinyi', 'Dashuitian', 'Bbdong', 'Xiaogao', 'HDYM1', 'ZongriM297', 'Chokhopani', 'Daxi', 'Baojianshan']
# ZongriM297
# Hejiatai
# Chokhopani

# %%
# %%writefile /mnt/solexa/mel_yang/early_CN/makeasymmetry_table.py

import numpy as np
import plateaumodules as pm
#import matplotlib.pyplot as plt
#import matplotlib
#import matplotlib.colors
pD="/mnt/solexa/mel_yang/early_CN/"
fh1,tv1,out1=("F4.list.F4","",'Mbuti')
fh2,tv2,out2=("F4.list.F4tv",".tv",'Mbuti')
fh3,tv3,out3=("F4.list.F4","",'Chimp')
fs=15
panel1=["Tianyuan","NE_20","La368_G1","Onge","Papuan","JomonM","Kolyma_River","Shamanka_EN",
        "ZongriM297","Hejiatai","Chokhopani","Ma912_G2","Man_Bac","Ami","Atayal","Han","Dai",
        "Sherpa_Shigatse","Tibetan_Shannan","Daur","Korean"]

south=["XJS","XJS_F","Dushan","Man_Bac","Nui_Nap",
       "Suogang","Qihe","LiangDaoF","LiangDaoM",
       "Ma555_G6","Ami","Atayal","Dai","Lahu","Kinh","Han"]
south=["Suogang","Qihe","LiangDaoF","LiangDaoM","Xinyi","Dushan",
       "Ma555_G6","Ami","Atayal","Dai","Lahu","Kinh","Han"]
       #"Ma555_G6","Ami","Atayal","Dai","Kinh","Lahu","Han"]
northern=["DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao_d_Fu",
          "HDYM1","ZhaoguoM2","Daxi","Dashuitian",
          "Jiahu_M52_I2_Fu"]
ns=["Han","Qihe","LiangDaoF","LiangDaoM","Suogang","Dushan","Xinyi","Dashuitian",
    "Bbdong","Boshan","XJS","XJS_F","Xiaogao","HDYM1","Shamanka_EN",
   "ZongriM297","Hejiatai","Chokhopani","Daxi","Baojianshan"]
varies=["Boshan","Bbdong","ZongriM297","Hejiatai","Chokhopani","Ma912_G2",
       "Korean","Han","Dai","Miao","She","HDYM1","Shamanka_EN","ZhaoguoM2",
        "Xiaogao","Xiaogao_d","DonghulinM1",
       "Dashuitian","Jiahu_M52_I2_Fu"]#+south
varies=["Tianyuan","La368_G1","Shamanka_EN","ZongriM297","Chokhopani",
        "Longlin","Baojianshan","Ami","Han","Dai","Daur","Papuan","Onge",
        "JomonM","Jomon","Kolyma_River"]
allinds=ns
header1,header2=allinds,allinds
popA=allinds
popB=allinds

myinds=["Tianyuan","La368_G1","Kolyma_River","Onge","Papuan"]
myinds=["JomonM","Jomon","Longlin"]
newfile=open("/mnt/solexa/mel_yang/early_CN/NS2_asymmetric_positive_oMbuti_alltvchimp.txt",'w')
newfile.write("P1\tP2\tP3\tP4\tD1\tZ1\tD2\tZ2\tD3\tZ3\n")
for count,myind in enumerate(myinds):
    print myinds
    mypops1=[popA,popB,myind,out1]
    mypops2=[popA,popB,myind,out2]
    mypops3=[popA,popB,myind,out3]
    DorZ="Z"
    newname="D_EA_EA_%s_%s" % (myind,"MbuChimp")
    Zary1 = pm.mkDary(pD,fh1,mypops1,(2,3),(0,1),'Z')
    Dary1 = pm.mkDary(pD,fh1,mypops1,(2,3),(0,1),'D')
    Zary2 = pm.mkDary(pD,fh2,mypops2,(2,3),(0,1),'Z')
    Dary2 = pm.mkDary(pD,fh2,mypops2,(2,3),(0,1),'D')
    Zary3 = pm.mkDary(pD,fh3,mypops3,(2,3),(0,1),'Z')
    Dary3 = pm.mkDary(pD,fh3,mypops3,(2,3),(0,1),'D')
    for row in range(Zary1.shape[0]):
        for col in range(Zary1.shape[1]):
            if Zary1[row,col]>3: # and Zary2[row,col]>3 and Zary3[row,col]>3:
                newfile.write(popA[row]+'\t'+popB[col]+'\t'+myind+'\t'+"MbuChimp"+"\t%.3f\t%.3f\t%.3f\t%.3f\t%.3f\t%.3f\n" % (Dary1[row,col],Zary1[row,col],Dary2[row,col],Zary2[row,col],Dary3[row,col],Zary3[row,col]))
newfile.close()
# Out:
# Overwriting /mnt/solexa/mel_yang/early_CN/makeasymmetry_table.py

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches

pD="/mnt/solexa/mel_yang/early_CN/"
tv="tv"
tv=""
fhall="F4.list.F4%s" % tv

agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
#agq=["Zongri1a","Zongri23"]
#eur=["French","Sardinian","Finnish"]

ns=["Han","Qihe","LiangDaoF","LiangDaoM","Suogang","Dushan","Xinyi","Dashuitian",
    "Bbdong","Boshan","XJS","XJS_F","Xiaogao","HDYM1","Shamanka_EN",
   "ZongriM297","Hejiatai","Chokhopani","Daxi","Baojianshan"]
ns=["Qihe","LiangDaoF","Suogang","Bbdong","Boshan","XJS_F","Xiaogao","HDYM1","Han"]
#ns=ns[:3]
eas=["Han","Dai","Ami","Daur","Sherpa","Tibetan","Naxi","Yi"]
aeur=["Kostenki14","Vestonice16","GoyetQ116-1","ElMiron","Villabruna","Loschbour"]
ma1=["Malta1"]
weur=["Vestonice16"]
ust=["UstIshim"]
jap=["Jomon","JomonM"]
gx=["Longlin","Baojianshan"]
ong=["Onge"]
hoa=["La368_G1"] #,"Ma911_G1"]
pap=["Papuan"]
ty=["Tianyuan"] #,"Papuan","Onge","Oase1","Stuttgart",
yan=["Yana_old","Yana_old2"]
#varypops=[ty,pap,ong,hoa,gx,jap][::-1]
#labels=["Tianyuan","Papuan","Onge",'La368',"LL/BJS","Jomon","Yana"][::-1] #/Papuan/Onge/Oase1
varypops=[ust,weur,ma1,ty,pap,ong,hoa][::-1]
labels=["UstIshim","Vestonice16","Malta1","Tianyuan","Papuan","Onge",'La368'][::-1] #/Papuan/Onge/Oase1
dxcluster=ns
dxpairs=[(i,j) for indi,i in enumerate(dxcluster) for indj,j in enumerate(dxcluster) if indi>indj]
pairlabels=["%s_%s" % mypair for mypair in dxpairs]
#print pairlabels
out="Mbuti"
colors=["brown","blue","red","black","pink","gray","purple"][::-1]
markers=["o","v","s","+","D",">"]
print len(dxpairs)

fig = plt.figure(figsize=(9,9))
ax1=fig.add_subplot(1,1,1)
handles1,handles2=[],[]
for ind,mypair in enumerate(dxpairs):
    if ind % 10==0: print ind,mypair
    #ax1.set_title("D(X1, aGQ; X2, Mbuti)")
    #ax1.set_ylim((-4,10))
    #ax1.set_xlim((-4,10))
    ax1.set_ylabel("Z for D(aNS, X; aNS, %s)" % out,fontsize=15)
    ax1.set_xlabel("Z for D(aNS, X; aNS, %s)" % out,fontsize=15)
    ax1.axvline(x=0, ls='dashed', c='black')
    ax1.axhline(y=0, ls='dashed', c='black')
    ax1.axvline(x=2, ls='dashed', c='lightgray')
    ax1.axhline(y=2, ls='dashed', c='lightgray')
    ax1.axvline(x=-2, ls='dashed', c='lightgray')
    ax1.axhline(y=-2, ls='dashed', c='lightgray')
    for ivp,varypop in enumerate(varypops):
        mypops1=[out,[mypair[1]],varypop,mypair[0]]
        mypops2=[out,[mypair[0]],varypop,mypair[1]]
        
        Zary1 = pm.mkDary(pD,fhall,mypops1,(0,3),(1,2),'Z')
        Zary2 = pm.mkDary(pD,fhall,mypops2,(0,3),(1,2),'Z')
        Zary=np.transpose(np.vstack((Zary1, Zary2)))[0,:]
        print mypops1,Zary1
        ax1.plot(Zary1,Zary2,'o',color=colors[ivp]) #markers[ind],
        #if ivp==0:
        #    handles1.append(mlines.Line2D([],[],marker=markers[ind],color='black',label=pairlabels[ind]))
        if ind==0:
            handles2.append(mpatches.Patch(color=colors[ivp], label=labels[ivp]))
        else: pass
#ax1.legend(loc='lower right')
#ax1.legend(handles=handles1+handles2,loc=4,ncol=2,fontsize=12.5)
ax1.legend(handles=handles2,loc=0)
plt.show()

#fig.savefig(pD+'aNSclade.D%s.relASN.png' % tv) # save the figure to file
#plt.close(fig)
# Out:
# 36
# 0 ('LiangDaoF', 'Qihe')
# ['Mbuti', ['Qihe'], ['La368_G1'], 'LiangDaoF'] [[12.181]]
# ['Mbuti', ['Qihe'], ['Onge'], 'LiangDaoF'] [[18.103]]
# ['Mbuti', ['Qihe'], ['Papuan'], 'LiangDaoF'] [[22.452]]
# ['Mbuti', ['Qihe'], ['Tianyuan'], 'LiangDaoF'] [[15.744]]
# ['Mbuti', ['Qihe'], ['Malta1'], 'LiangDaoF'] [[20.063]]
# ['Mbuti', ['Qihe'], ['Vestonice16'], 'LiangDaoF'] [[19.677]]
# ['Mbuti', ['Qihe'], ['UstIshim'], 'LiangDaoF'] [[22.442]]
# ['Mbuti', ['Qihe'], ['La368_G1'], 'Suogang'] [[6.397]]
# ['Mbuti', ['Qihe'], ['Onge'], 'Suogang'] [[13.554]]
# ['Mbuti', ['Qihe'], ['Papuan'], 'Suogang'] [[15.799]]
# ['Mbuti', ['Qihe'], ['Tianyuan'], 'Suogang'] [[11.588]]
# ['Mbuti', ['Qihe'], ['Malta1'], 'Suogang'] [[15.086]]
# ['Mbuti', ['Qihe'], ['Vestonice16'], 'Suogang'] [[14.803]]
# ['Mbuti', ['Qihe'], ['UstIshim'], 'Suogang'] [[17.303]]
# ['Mbuti', ['LiangDaoF'], ['La368_G1'], 'Suogang'] [[9.788]]
# ['Mbuti', ['LiangDaoF'], ['Onge'], 'Suogang'] [[14.108]]
# ...

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches

pD="/mnt/solexa/mel_yang/early_CN/"
tv="tv"
tv=""
fhall="F4.list.F4%s" % tv

agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
#agq=["Zongri1a","Zongri23"]
#eur=["French","Sardinian","Finnish"]

ns=["Han","Qihe","LiangDaoF","LiangDaoM","Suogang","Dushan","Xinyi","Dashuitian",
    "Bbdong","Boshan","XJS","XJS_F","Xiaogao","HDYM1","Shamanka_EN",
   "ZongriM297","Hejiatai","Chokhopani","Daxi","Baojianshan"]
ns=["Qihe","LiangDaoF","Suogang","Bbdong","Boshan","XJS_F","Xiaogao","HDYM1","Han"]
ns=ns[:3]
eas=["Han","Dai","Ami","Daur","Sherpa","Tibetan","Naxi","Yi"]
aeur=["Kostenki14","Vestonice16","GoyetQ116-1","ElMiron","Villabruna","Loschbour"]
ma1=["Malta1"]
weur=["Vestonice16"]
ust=["UstIshim"]
jom=["JomonM"]
eplat=["ZongriM297","Hejiatai"]
wplat=["Chokhopani"]
sham=["Shamanka_EN"]
koly=["Kolyma_River"]
devil=["DevilsGate"]
ma55=["Ma555_G6"]
gx=["Longlin","Baojianshan"]
ong=["Onge"]
hoa=["La368_G1"] #,"Ma911_G1"]
pap=["Papuan"]
ty=["Tianyuan"] #,"Papuan","Onge","Oase1","Stuttgart",
yan=["Yana_old","Yana_old2"]
#varypops=[ty,pap,ong,hoa,gx,jap][::-1]
#labels=["Tianyuan","Papuan","Onge",'La368',"LL/BJS","Jomon","Yana"][::-1] #/Papuan/Onge/Oase1
varypops=[ust,weur,ma1,ty,pap,ong,hoa][::-1]
labels=["UstIshim","Vestonice16","Malta1","Tianyuan","Papuan","Onge",'La368'][::-1] #/Papuan/Onge/Oase1
varypops=[jom,gx,eplat,wplat,sham,koly,ma55][::-1]
labels=["Iwakazu","Guangxi","East Plateau","West Plateau","Shamanka_EN","Kolyma_River",'Ma555_G6'][::-1] #/Papuan/Onge/Oase1

dxcluster=ns
dxpairs=[(i,j) for indi,i in enumerate(dxcluster) for indj,j in enumerate(dxcluster) if indi>indj]
pairlabels=["%s_%s" % mypair for mypair in dxpairs]
#print pairlabels
out="Mbuti"
colors=["brown","blue","red","black","pink","gray","purple"][::-1]
markers=["o","v","s","+","D",">"]
print len(dxpairs)

fig = plt.figure(figsize=(9,9))
ax1=fig.add_subplot(1,1,1)
handles1,handles2=[],[]
for ind,mypair in enumerate(dxpairs):
    if ind % 10==0: print ind,mypair
    #ax1.set_title("D(X1, aGQ; X2, Mbuti)")
    #ax1.set_ylim((-4,10))
    #ax1.set_xlim((-4,10))
    ax1.set_ylabel("Z for D(aNS, X; aNS, %s)" % out,fontsize=15)
    ax1.set_xlabel("Z for D(aNS, X; aNS, %s)" % out,fontsize=15)
    ax1.axvline(x=0, ls='dashed', c='black')
    ax1.axhline(y=0, ls='dashed', c='black')
    ax1.axvline(x=2, ls='dashed', c='lightgray')
    ax1.axhline(y=2, ls='dashed', c='lightgray')
    ax1.axvline(x=-2, ls='dashed', c='lightgray')
    ax1.axhline(y=-2, ls='dashed', c='lightgray')
    for ivp,varypop in enumerate(varypops):
        mypops1=[out,[mypair[1]],varypop,mypair[0]]
        mypops2=[out,[mypair[0]],varypop,mypair[1]]
        
        Zary1 = pm.mkDary(pD,fhall,mypops1,(0,3),(1,2),'Z')
        Zary2 = pm.mkDary(pD,fhall,mypops2,(0,3),(1,2),'Z')
        Zary=np.transpose(np.vstack((Zary1, Zary2)))[0,:]
        print mypops1,Zary1
        ax1.plot(Zary1,Zary2,'o',color=colors[ivp]) #markers[ind],
        #if ivp==0:
        #    handles1.append(mlines.Line2D([],[],marker=markers[ind],color='black',label=pairlabels[ind]))
        if ind==0:
            handles2.append(mpatches.Patch(color=colors[ivp], label=labels[ivp]))
        else: pass
#ax1.legend(loc='lower right')
#ax1.legend(handles=handles1+handles2,loc=4,ncol=2,fontsize=12.5)
ax1.legend(handles=handles2,loc=0)
plt.show()

#fig.savefig(pD+'aNSclade.D%s.relASN.png' % tv) # save the figure to file
#plt.close(fig)
# Out:
# 3
# 0 ('LiangDaoF', 'Qihe')
# ['Mbuti', ['Qihe'], ['Ma555_G6'], 'LiangDaoF'] [[1.687]]
# ['Mbuti', ['Qihe'], ['Kolyma_River'], 'LiangDaoF'] [[10.639]]
# ['Mbuti', ['Qihe'], ['Shamanka_EN'], 'LiangDaoF'] [[9.779]]
# ['Mbuti', ['Qihe'], ['Chokhopani'], 'LiangDaoF'] [[8.013]]
# ['Mbuti', ['Qihe'], ['ZongriM297', 'Hejiatai'], 'LiangDaoF'] [[5.518 5.836]]
# ['Mbuti', ['Qihe'], ['Longlin', 'Baojianshan'], 'LiangDaoF'] [[5.833 5.463]]
# ['Mbuti', ['Qihe'], ['JomonM'], 'LiangDaoF'] [[7.433]]
# ['Mbuti', ['Qihe'], ['Ma555_G6'], 'Suogang'] [[0.512]]
# ['Mbuti', ['Qihe'], ['Kolyma_River'], 'Suogang'] [[7.007]]
# ['Mbuti', ['Qihe'], ['Shamanka_EN'], 'Suogang'] [[7.175]]
# ['Mbuti', ['Qihe'], ['Chokhopani'], 'Suogang'] [[4.884]]
# ['Mbuti', ['Qihe'], ['ZongriM297', 'Hejiatai'], 'Suogang'] [[4.78  4.357]]
# ['Mbuti', ['Qihe'], ['Longlin', 'Baojianshan'], 'Suogang'] [[4.933 4.348]]
# ['Mbuti', ['Qihe'], ['JomonM'], 'Suogang'] [[6.133]]
# ['Mbuti', ['LiangDaoF'], ['Ma555_G6'], 'Suogang'] [[0.543]]
# ...

# %%
##Qihe_d

import fstat_funcs as ff

pD="/mnt/solexa/mel_yang/early_CN/"
outpd="/mnt/solexa/mel_yang/early_CN/D_South/"
fh="F4.list.F4"
fh="F4.list.F4tv"
out="Mbuti"        

ns=["Qihe","LiangDaoF","LiangDaoM","Suogang","Dushan","Xinyi","Dashuitian",
    "Bbdong","Boshan","XJS","XJS_F","Xiaogao","HDYM1","Shamanka_EN",
   "ZongriM297","Hejiatai","Chokhopani","Daxi","Baojianshan"]
eeur=["Tianyuan","Papuan","Onge","La368_G1",
      "JomonM","Jomon","Longlin","Baojianshan"]
north=["Kolyma_River","DevilsGate","Boisman_MN","Shamanka_EN","Mixe","Surui"]
cnin=["Bbdong","Boshan","XJS","XJS_F","Xiaogao","HDYM1","ZongriM297","Hejiatai","Chokhopani"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Dushan","Xinyi","Dashuitian","Daxi","Ami","Ma555_G6"]
seasia=["Oakaie1","Man_Bac","Nui_Nap","Ma912_G2","La727_G2","Vt833_G2","Vt880_G2"]
pdeas=["Daur","Hezhen","Xibo","Oroqen","Japanese","Korean","Han","Ami","Atayal",
      "She","Miao","Dai","Lahu","Kinh","Naxi","Yi","Han_ShandongX","Han_GuangdongX","Han_HenanX",
      "Han_JiangsuX","Han_SichuanX","Tibetan","Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX",
      "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]
pdeas=[]
#north=["Mixe","Surui"]
mylst=ns
varies=pdeas
for myind in varies:
    print myind
    pops=[out,mylst,myind,mylst]
    ff.Dmat2xlsx(ff.Dmkary(pD,fh,pops,"Z"),outpd+"Z.P2_"+myind+".NS_ZPDEAS_o%s." % (out)+fh,ff.Dmklabel(pops),mylst,mylst)

    pops=[out,myind,mylst,mylst]
    ff.Dmat2xlsx(ff.Dmkary(pD,fh,pops,"Z"),outpd+"Z.P3_"+myind+".NS_ZPDEAS_o%s." % (out)+fh,ff.Dmklabel(pops),mylst,mylst)
# Out:
# Dai

# %%
import numpy as np
import plateaumodules as pm


south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Dushan","Xinyi","Dashuitian"] #,"Daxi","Ami","Ma555_G6","Dai"
seasia=["Oakaie1","Man_Bac","Nui_Nap","Ban_Chiang",
        "Ma912_G2","La727_G2","Vt833_G2","Vt880_G2",
       "Vt777_G3","Vt719_G3_1"]
pdeas=["Daur","Hezhen","Xibo","Oroqen","Japanese","Korean","Han","She","Miao","Naxi","Yi","Dai",
      "Lahu","Kinh","Ami","Atayal","Han_ShandongX","Han_GuangdongX","Han_HenanX",
      "Han_JiangsuX","Han_SichuanX","Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX",
      "Tibetan_ShannanX","Tibetan_ShigatseX","Tibetan","Sherpa","Sherpa_ShigatseX"]
north=["Shamanka_EN","HDYM1","ZongriM297","Hejiatai","Chokhopani","Boshan","XJS","XJS_F","Xiaogao"]
pD="/mnt/solexa/mel_yang/early_CN/"
fhall="F4.list.F4"
fhtv="F4.list.F4tv"
out="Mbuti"

relto="Bbdong"
vlist=pdeas
mynames=pdeas
wantedcolors=["blue"]*len(vlist)
mypops2=[[out,vlist,relto,south+north]]
#mypops2=[[out,south,relto,seasia]]
mytuples=[[(0,2),(1,3)]]



count=0
Zaryall = pm.mkDary(pD,fhall,mypops2[count],mytuples[count][0],mytuples[count][1],'Z')
Daryall = pm.mkDary(pD,fhall,mypops2[count],mytuples[count][0],mytuples[count][1],'D')
#Zaryall=np.transpose(Zaryall)
#Daryall=np.transpose(Daryall)
SEaryall=Daryall/Zaryall 
Zarytv = pm.mkDary(pD,fhtv,mypops2[count],mytuples[count][0],mytuples[count][1],'Z')
Darytv = pm.mkDary(pD,fhtv,mypops2[count],mytuples[count][0],mytuples[count][1],'D')
#Zarytv=np.transpose(Zarytv)
#Darytv=np.transpose(Darytv)
SEarytv=Darytv/Zarytv
# Out:
# /home/mel_yang/.local/lib/python2.7/site-packages/ipykernel_launcher.py:39: RuntimeWarning: invalid value encountered in divide

# %%
print Daryall
# Out:
# [[-4.666e-03 -3.062e-03 -3.206e-03 -2.627e-03 -4.234e-03 -2.992e-03
#   -1.124e-03 -5.520e-04 -1.640e-04 -2.289e-03 -1.479e-03 -1.945e-03
#    5.360e-04 -1.300e-04 -1.770e-04 -4.870e-04]
#  [-4.675e-03 -3.191e-03 -3.283e-03 -2.032e-03 -4.283e-03 -3.337e-03
#   -1.235e-03 -4.040e-04 -4.930e-04 -2.070e-03 -2.190e-03 -1.894e-03
#    4.290e-04 -3.620e-04 -3.350e-04 -7.990e-04]
#  [-4.211e-03 -3.033e-03 -3.362e-03 -2.522e-03 -4.291e-03 -3.075e-03
#   -8.700e-04 -1.353e-03 -1.109e-03 -2.423e-03 -2.292e-03 -1.974e-03
#    2.400e-05 -2.860e-04 -4.000e-04 -1.100e-03]
#  [-4.336e-03 -3.293e-03 -2.736e-03 -2.888e-03 -4.352e-03 -3.022e-03
#   -8.600e-04  1.218e-03  2.970e-04 -9.780e-04 -1.651e-03 -1.767e-03
#    8.330e-04 -4.830e-04 -1.690e-04 -4.070e-04]
#  [-3.221e-03 -1.656e-03 -1.835e-03 -1.119e-03 -3.435e-03 -2.176e-03
#   -8.900e-05 -1.286e-03 -4.600e-04 -1.840e-03 -1.970e-03 -1.168e-03
#    1.199e-03  8.570e-04  4.630e-04  4.500e-05]
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib

seasia=["Oakaie1","Man_Bac","Nui_Nap","Ban_Chiang",
        "Ma912_G2","La727_G2","Vt833_G2","Vt880_G2",
       "Vt777_G3","Vt719_G3_1"]
pdeas=["Daur","Hezhen","Xibo","Oroqen","Japanese","Korean","Han","She","Miao","Naxi","Yi","Dai",
      "Lahu","Kinh","Ami","Atayal","Han_ShandongX","Han_GuangdongX","Han_HenanX",
      "Han_JiangsuX","Han_SichuanX","Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX",
      "Tibetan_ShannanX","Tibetan_ShigatseX","Tibetan","Sherpa","Sherpa_ShigatseX"]
mynames=pdeas
xlims=(-0.003,0.01)
fig = plt.figure(figsize=(14,24))
for jind,sea in enumerate(south+north):
    ax1=fig.add_subplot(4,4,jind+1)
    vals=[]
    for ind,i in enumerate(vlist):
        vals.extend([Darytv[ind][jind]-2*SEarytv[ind][jind],Darytv[ind][jind]+2*SEarytv[ind][jind]])
        ax1.errorbar(Darytv[ind][jind],ind,xerr=SEarytv[ind][jind],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.errorbar(Darytv[ind][jind],ind,xerr=2*SEarytv[ind][jind],color=wantedcolors[ind],alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        #ax1.plot(Darytv[ind,jind],ind,'.',alpha=0.05)

        ax1.errorbar(Daryall[ind][jind],ind,xerr=SEaryall[ind][jind],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[ind][jind],ind,xerr=2*SEaryall[ind][jind],color=wantedcolors[ind],markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        #ax1.plot(Daryall[ind],ind,'.')

    myys = np.array(range(len(mynames)))
    ax1.set_yticks(myys)
    if count==0:
        ax1.set_yticklabels([""]+mynames[1:],fontsize=13)
    else: 
        ax1.set_yticklabels(['']*len(mynames),fontsize=3)

    ax1.set_ylim(-1,len(mynames))
    if count==0: ax1.set_xlim(min(vals),max(vals))
    else: ax1.set_xlim(-min(vals),-max(vals))

    xlabel = ax1.get_xticks().tolist()
    ax1.set_xticklabels(xlabel,rotation=45,fontsize=13)

    ax1.set_title(sea,fontsize=13)

    ax1.axvline(x=0, ls='dashed', c='black')
    #for myline in [9.5]:
    #    ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5)
    ax1.set_xlabel("D",fontsize=15)
    #ax1.set_xlabel("D, %s" % tv,fontsize=15)
    #print min(vals),max(vals)
plt.tight_layout()
plt.show()

# %%
##Qihe_d

import fstat_funcs as ff

pD="/mnt/solexa/mel_yang/early_CN/"
outpd="/mnt/solexa/mel_yang/early_CN/D_South/"
fh="F4.list.F4"
#fh="F4.list.F4tv"
out="Mbuti"        

ns=["Qihe","LiangDaoF","LiangDaoM","Suogang","Dushan","Xinyi","Dashuitian",
    "Bbdong","Boshan","XJS","XJS_F","Xiaogao","HDYM1","Shamanka_EN",
   "ZongriM297","Hejiatai","Chokhopani","Daxi","Baojianshan"]
eeur=["Tianyuan","Papuan","Onge","La368_G1",
      "JomonM","Jomon","Longlin","Baojianshan"]
north=["Kolyma_River","DevilsGate","Boisman_MN","Shamanka_EN","Mixe","Surui"]
cnin=["Bbdong","Boshan","XJS","XJS_F","Xiaogao","HDYM1","ZongriM297","Hejiatai","Chokhopani"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Dushan","Xinyi","Dashuitian","Daxi","Ami","Ma555_G6"]
seasia=["Oakaie1","Man_Bac","Nui_Nap","Ma912_G2","La727_G2","Vt833_G2","Vt880_G2"]
pdeas=["Daur","Hezhen","Xibo","Oroqen","Japanese","Korean","Han","Ami","Atayal",
      "She","Miao","Dai","Lahu","Kinh","Naxi","Yi","Han_ShandongX","Han_GuangdongX","Han_HenanX",
      "Han_JiangsuX","Han_SichuanX","Tibetan","Tibetan_ChamdoX","Tibetan_LhasaX","Tibetan_NagquX",
      "Tibetan_ShannanX","Tibetan_ShigatseX","Sherpa_ShigatseX"]

#north=["Mixe","Surui"]
mylst=pdeas
varies=ns
for myind in varies:
    print myind
    pops=[out,mylst,myind,mylst]
    ff.Dmat2xlsx(ff.Dmkary(pD,fh,pops,"Z"),outpd+"Z.P2_"+myind+".PDEAS_ZNS_o%s." % (out)+fh,ff.Dmklabel(pops),mylst,mylst)

    pops=[out,myind,mylst,mylst]
    ff.Dmat2xlsx(ff.Dmkary(pD,fh,pops,"Z"),outpd+"Z.P3_"+myind+".PDEAS_ZNS_o%s." % (out)+fh,ff.Dmklabel(pops),mylst,mylst)
# Out:
# Qihe
# LiangDaoF
# LiangDaoM
# Suogang
# Dushan
# Xinyi
# Dashuitian
# Bbdong
# Boshan
# XJS
# XJS_F
# Xiaogao
# HDYM1
# Shamanka_EN
# ZongriM297
# Hejiatai
# Chokhopani
# Daxi
# Baojianshan

# %%
def qpadm_2pop(pd,fh):
    myfile=open(pd+fh+".log",'r')
    msd=[]
    for line in myfile:
        x=line.split()
        if 'Jackknife mean:' in line: msd.extend(x[2:4]); continue
        elif 'std. errors:' in line: msd.extend(x[2:4]); continue
        
        elif ' 00  0 ' in line: msd.extend(x[4:7]); continue
        elif ' 01  1 ' in line: msd.append(x[4]); continue
        elif ' 10  1 ' in line: msd.append(x[4]); continue
        elif 'p-value for nested model:' in line: msd.append(x[2]);msd.append(x[-1]); continue
        else: continue
    myfile.close()
    return msd

pd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"

header="Target\tS1\tS2\tmean1\tmean2\tsd1\tsd2\tp_00\tf1_00\tf2_00\tp_01\tp_10\tbest1\tpnest"
print header

coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
plateau=["Hejiatai","PukagongmaM5","Chokhopani","ZongriM297"]
label,target,s1,s2,out=("WESTtv","Hejiatai","Bbdong","PukagongmaM5",3)
for target in plateau:
    for s1 in coastalnorth+sib:
        if len(list(set([s1,s2,target])))!=3: continue
        fh="UPA19_3.adm.%s_%s_%s_%s_out%i" % (label,target,s1,s2,out)
        mylst='\t'.join([target,s1,s2])+'\t'+'\t'.join(qpadm_2pop(pd,fh))

        print mylst
# Out:
# Target	S1	S2	mean1	mean2	sd1	sd2	p_00	f1_00	f2_00	p_01	p_10	best1	pnest
# Hejiatai	Bbdong	PukagongmaM5	0.484503176	0.515496824	0.997	0.997	0.824023	-0.156	1.156	0.629241	0.878779	10	0.800088
# Hejiatai	Boshan	PukagongmaM5	0.783203336	0.216796664	1.035	1.035	0.827215	0.210	0.790	0.680232	0.876788	10	0.720245
# Hejiatai	Xiaogao	PukagongmaM5	0.509005693	0.490994307	1.541	1.541	0.915247	-1.005	2.005	0.363646	0.782068	10	0.118083
# Hejiatai	XJS	PukagongmaM5	3073.559885581	-3072.559885581	4465.016	4465.016	0.843734	5.394	-4.394	0.890858	0.772386	01	0.735491
# Hejiatai	XJS_F	PukagongmaM5	1.429248093	-0.429248093	0.693	0.693	0.764384	0.623	0.377	0.767055	0.736797	01	0.371663
# Hejiatai	Linzi	PukagongmaM5	36.216251095	-35.216251095	3.467	3.467	0.871571	0.790	0.210	0.9103	0.881614	01	0.699445
# Hejiatai	Boisman_MN	PukagongmaM5	-832.645822034	833.645822034	990.956	990.956	0.929166	-7.004	8.004	0.751972	0.828863	10	0.145283
# ...

# %%
def qpadm_2pop(pd,fh):
    myfile=open(pd+fh+".log",'r')
    msd=[]
    for line in myfile:
        x=line.split()
        if 'Jackknife mean:' in line: msd.extend(x[2:4]); continue
        elif 'std. errors:' in line: msd.extend(x[2:4]); continue
        
        elif ' 00  0 ' in line: msd.extend(x[4:7]); continue
        elif ' 01  1 ' in line: msd.append(x[4]); continue
        elif ' 10  1 ' in line: msd.append(x[4]); continue
        elif 'p-value for nested model:' in line: msd.append(x[2]);msd.append(x[-1]); continue
        else: continue
    myfile.close()
    return msd

pd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"

header="Target\tS1\tS2\tmean1\tmean2\tsd1\tsd2\tp_00\tf1_00\tf2_00\tp_01\tp_10\tbest1\tpnest"
print header

coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","HDYM1","HDYM1","Kolyma_River"]
plateau=["Hejiatai","PukagongmaM5","Chokhopani","ZongriM297"]
label,target,s1,s2,out=("NORTH","Shamanka_EN","ZongriM297","PukagongmaM5",3)
for s1 in plateau:
    for s2 in coastalnorth+sib:
        if len(list(set([s1,s2,target])))!=3: continue
        fh="UPA19_3.adm.%s_%s_%s_%s_out%i" % (label,target,s1,s2,out)
        mylst='\t'.join([target,s1,s2])+'\t'+'\t'.join(qpadm_2pop(pd,fh))

        print mylst
# Out:
# Target	S1	S2	mean1	mean2	sd1	sd2	p_00	f1_00	f2_00	p_01	p_10	best1	pnest
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-21-b992e816d27f> in <module>()
#      30         if len(list(set([s1,s2,target])))!=3: continue
#      31         fh="UPA19_3.adm.%s_%s_%s_%s_out%i" % (label,target,s1,s2,out)
# ---> 32         mylst='\t'.join([target,s1,s2])+'\t'+'\t'.join(qpadm_2pop(pd,fh))
#      33
#      34         print mylst
#
# <ipython-input-21-b992e816d27f> in qpadm_2pop(pd, fh)
#       1
#       2 def qpadm_2pop(pd,fh):
# ----> 3     myfile=open(pd+fh+".log",'r')
#       4     msd=[]
#       5     for line in myfile:
#
# IOError: [Errno 2] No such file or directory: '/mnt/solexa/mel_yang/early_CN/qpadm_north/UPA19_3.adm.NORTH_Shamanka_EN_Hejiatai_Bbdong_out3.log'

# %%
def qpadm_2pop(pd,fh):
    myfile=open(pd+fh+".log",'r')
    msd=[]
    for line in myfile:
        x=line.split()
        if 'Jackknife mean:' in line: msd.extend(x[2:4]); continue
        elif 'std. errors:' in line: msd.extend(x[2:4]); continue
        
        elif ' 00  0 ' in line: msd.extend(x[4:7]); continue
        elif ' 01  1 ' in line: msd.append(x[4]); continue
        elif ' 10  1 ' in line: msd.append(x[4]); continue
        elif 'p-value for nested model:' in line: msd.append(x[2]);msd.append(x[-1]); continue
        else: continue
    myfile.close()
    return msd

pd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"

header="Target\tS1\tS2\tmean1\tmean2\tsd1\tsd2\tp_00\tf1_00\tf2_00\tp_01\tp_10\tbest1\tpnest"
print header

coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
plateau=["Hejiatai","PukagongmaM5","Chokhopani"]
label,target,s1,s2,out=("A","Shamanka_EN","HDYM1","ZongriM297",2)
for s1 in coastalnorth+["HDYM1"]:
    for s2 in sib:
        if len(list(set([s1,s2,target])))!=3: continue
        fh="UPA19_3.adm.%s_%s_%s_%s_out%i" % (label,target,s1,s2,out)
        mylst='\t'.join([target,s1,s2])+'\t'+'\t'.join(qpadm_2pop(pd,fh))

        print mylst
# Out:
# Target	S1	S2	mean1	mean2	sd1	sd2	p_00	f1_00	f2_00	p_01	p_10	best1	pnest
# Shamanka_EN	Bbdong	Boisman_MN	0.085955849	0.914044151	2.524	2.524	0.0197212	-2.468	3.468	2.07648e-06	1.47919e-08	01	4.6808e-07
# Shamanka_EN	Bbdong	DevilsGate	29.459109589	-28.459109589	9.607	9.607	0.457705	-2.445	3.445	0.128383	0.213029	10	0.0356727
# Shamanka_EN	Bbdong	HDYM1	0.344828659	0.655171341	2.978	2.978	0.16791	-2.464	3.464	4.987e-06	0.00335118	10	0.000248895
# Shamanka_EN	Bbdong	Kolyma_River	0.567885208	0.432114792	0.070	0.070	0.0871088	0.569	0.431	1.32981e-06	6.50812e-11	01	2.52896e-08
# Shamanka_EN	Boshan	Boisman_MN	0.082474226	0.917525774	3.090	3.090	0.00801255	-2.883	3.883	2.18926e-08	1.52391e-08	01	6.89619e-09
# Shamanka_EN	Boshan	DevilsGate	0.513974142	0.486025858	0.174	0.174	0.756073	0.514	0.486	0.207046	0.152564	01	0.0062774
# Shamanka_EN	Boshan	HDYM1	0.612855913	0.387144087	2.758	2.758	0.0153083	-2.119	3.119	1.48366e-08	0.000158552	10	0.000189062
# ...

# %%
def qpadm_2pop(pd,fh):
    myfile=open(pd+fh+".log",'r')
    msd=[]
    for line in myfile:
        x=line.split()
        if 'Jackknife mean:' in line: msd.extend(x[2:4]); continue
        elif 'std. errors:' in line: msd.extend(x[2:4]); continue
        
        elif ' 00  0 ' in line: msd.extend(x[4:7]); continue
        elif ' 01  1 ' in line: msd.append(x[4]); continue
        elif ' 10  1 ' in line: msd.append(x[4]); continue
        elif 'p-value for nested model:' in line: msd.append(x[2]);msd.append(x[-1]); continue
        else: continue
    myfile.close()
    return msd

pd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"

header="Target\tS1\tS2\tmean1\tmean2\tsd1\tsd2\tp_00\tf1_00\tf2_00\tp_01\tp_10\tbest1\tpnest"
print header

coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
plateau=["ZongriM297","Hejiatai","PukagongmaM5","Chokhopani"]
label,target,s1,s2,out=("WEST2","Shamanka_EN","HDYM1","ZongriM297",3)
for s1 in sib+coastalnorth:
    for s2 in plateau:
        if len(list(set([s1,s2,target])))!=3: continue
        fh="UPA19_3.adm.%s_%s_%s_%s_out%i" % (label,target,s1,s2,out)
        mylst='\t'.join([target,s1,s2])+'\t'+'\t'.join(qpadm_2pop(pd,fh))

        print mylst
# Out:
# Target	S1	S2	mean1	mean2	sd1	sd2	p_00	f1_00	f2_00	p_01	p_10	best1	pnest
# Shamanka_EN	Boisman_MN	ZongriM297	-0.938152960	1.938152960	3.014	3.014	0.00065616	2.962	-1.962	4.09177e-06	1.36524e-06	01	0.000139779
# Shamanka_EN	Boisman_MN	Hejiatai	0.291298535	0.708701465	0.601	0.601	0.0124576	0.047	0.953	0.000192992	0.0212123	10	-nan
# Shamanka_EN	Boisman_MN	PukagongmaM5	-0.978695600	1.978695600	2.274	2.274	0.00422219	2.276	-1.276	0.000362697	0.00027173	01	0.00417244
# Shamanka_EN	Boisman_MN	Chokhopani	-51.177999074	52.177999074	20.749	20.749	8.08162e-05	7.513	-6.513	3.53355e-10	2.17873e-08	10	3.33359e-06
# Shamanka_EN	DevilsGate	ZongriM297	0.992438178	0.007561822	0.652	0.652	0.114928	0.168	0.832	0.022484	0.157337	10	0.705245
# Shamanka_EN	DevilsGate	Hejiatai	0.408231585	0.591768415	0.151	0.151	0.0803758	0.389	0.611	0.000271866	0.0182876	10	0.0141119
# Shamanka_EN	DevilsGate	PukagongmaM5	0.800088368	0.199911632	1.176	1.176	0.772109	-0.307	1.307	0.409993	0.818815	10	0.593978
# ...

# %%
def qpadm_2pop(pd,fh):
    myfile=open(pd+fh+".log",'r')
    msd=[]
    for line in myfile:
        x=line.split()
        if 'Jackknife mean:' in line: msd.extend(x[2:4]); continue
        elif 'std. errors:' in line: msd.extend(x[2:4]); continue
        
        elif ' 00  0 ' in line: msd.extend(x[4:7]); continue
        elif ' 01  1 ' in line: msd.append(x[4]); continue
        elif ' 10  1 ' in line: msd.append(x[4]); continue
        elif 'p-value for nested model:' in line: msd.append(x[2]);msd.append(x[-1]); continue
        else: continue
    myfile.close()
    return msd

pd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"

header="Target\tS1\tS2\tmean1\tmean2\tsd1\tsd2\tp_00\tf1_00\tf2_00\tp_01\tp_10\tbest1\tpnest"
print header

coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
plateau=["Hejiatai","PukagongmaM5","Chokhopani"]
guangxi=["Longlin","Baojianshan","Dushan"]
label,target,s1,s2,out=("SOUTH","Daxi","Longlin","Xinyi",4)
for target in ["Daxi"]: #guangxi+south:
    for s1 in south:
        if len(list(set([s1,s2,target])))!=3: continue
        fh="UPA19_3.adm.%s_%s_%s_%s_out%i" % (label,target,s1,s2,out)
        mylst='\t'.join([target,s1,s2])+'\t'+'\t'.join(qpadm_2pop(pd,fh))

        print mylst
# Out:
# Target	S1	S2	mean1	mean2	sd1	sd2	p_00	f1_00	f2_00	p_01	p_10	best1	pnest
# Daxi	Qihe	Xinyi	0.937119050	0.062880950	1.008	1.008	0.388399	-0.079	1.079	0.158435	0.477402	10	-nan
# Daxi	LiangDaoF	Xinyi	1.050066460	-0.050066460	2.396	2.396	0.300241	-1.421	2.421	0.00829257	0.105043	10	0.0210869
# Daxi	LiangDaoM	Xinyi	0.006713723	0.993286277	1.179	1.179	0.393909	-0.915	1.915	0.0167625	0.189625	10	0.0381122
# Daxi	Suogang	Xinyi	0.445597993	0.554402007	0.317	0.317	0.968108	0.465	0.535	0.863036	0.868525	10	0.106735
# Daxi	Ami	Xinyi	-0.685694916	1.685694916	1.762	1.762	0.537265	-1.805	2.805	0.00595534	0.12398	10	0.00602884
# Daxi	Ma555_G6	Xinyi	21.731553023	-20.731553023	6.794	6.794	0.243894	-1.324	2.324	0.0552718	0.209375	10	0.180423
# Daxi	Dushan	Xinyi	-0.996591916	1.996591916	1.242	1.242	0.502723	-0.516	1.516	0.130313	0.476961	10	0.255673

# %%
def qpadm_2pop(pd,fh):
    myfile=open(pd+fh+".log",'r')
    msd=[]
    for line in myfile:
        x=line.split()
        if 'Jackknife mean:' in line: msd.extend(x[2:4]); continue
        elif 'std. errors:' in line: msd.extend(x[2:4]); continue
        
        elif ' 00  0 ' in line: msd.extend(x[4:7]); continue
        elif ' 01  1 ' in line: msd.append(x[4]); continue
        elif ' 10  1 ' in line: msd.append(x[4]); continue
        elif 'p-value for nested model:' in line: msd.append(x[2]);msd.append(x[-1]); continue
        else: continue
    myfile.close()
    return msd

pd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"

header="Target\tS1\tS2\tmean1\tmean2\tsd1\tsd2\tp_00\tf1_00\tf2_00\tp_01\tp_10\tbest1\tpnest"
print header

coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
plateau=["Hejiatai","PukagongmaM5","Chokhopani"]
guangxi=["Longlin","Baojianshan","Dushan"]
label,target,s1,s2,out=("SOUTH","Daxi","Longlin","Ma555_G6",4)
for target in south:
    for s1 in south+coastalnorth+["Dai","Han"]:
        if len(list(set([target,s1,s2])))!=3: continue
        fh="UPA19_3.adm.%s_%s_%s_%s_out%i" % (label,target,s1,s2,out)
        mylst='\t'.join([target,s1,s2])+'\t'+'\t'.join(qpadm_2pop(pd,fh))

        print mylst
# Out:
# Target	S1	S2	mean1	mean2	sd1	sd2	p_00	f1_00	f2_00	p_01	p_10	best1	pnest
# Qihe	LiangDaoF	Ma555_G6	1.131527965	-0.131527965	0.925	0.925	0.472953	0.387	0.613	0.400759	0.505582	10	0.423181
# Qihe	LiangDaoM	Ma555_G6	0.583516972	0.416483028	0.498	0.498	0.871656	0.450	0.550	0.737982	0.832909	10	0.256537
# Qihe	Suogang	Ma555_G6	2.308747560	-1.308747560	2.894	2.894	0.500654	-0.764	1.764	0.47968	0.541381	10	0.46104
# Qihe	Ami	Ma555_G6	0.842079620	0.157920380	0.564	0.564	0.567968	0.709	0.291	0.595178	0.471087	01	0.415132
# Qihe	Xinyi	Ma555_G6	0.466992172	0.533007828	0.516	0.516	0.553453	0.417	0.583	0.350832	0.521222	10	0.24955
# Qihe	Dushan	Ma555_G6	0.331809841	0.668190159	0.653	0.653	0.943581	0.082	0.918	0.554262	0.966838	10	0.88703
# Qihe	Bbdong	Ma555_G6	0.169232061	0.830767939	0.364	0.364	0.406818	0.148	0.852	0.0138428	0.470731	10	0.593489
# Qihe	Boshan	Ma555_G6	0.218750896	0.781249104	0.162	0.162	0.501455	0.210	0.790	0.00014653	0.428962	10	0.174258
# ...

# %%
def qpadm_2pop(pd,fh):
    myfile=open(pd+fh+".log",'r')
    msd=[]
    for line in myfile:
        x=line.split()
        if 'Jackknife mean:' in line: msd.extend(x[2:4]); continue
        elif 'std. errors:' in line: msd.extend(x[2:4]); continue
        
        elif ' 00  0 ' in line: msd.extend(x[4:7]); continue
        elif ' 01  1 ' in line: msd.append(x[4]); continue
        elif ' 10  1 ' in line: msd.append(x[4]); continue
        elif 'p-value for nested model:' in line: msd.append(x[2]);msd.append(x[-1]); continue
        else: continue
    myfile.close()
    return msd

pd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"

header="Target\tS1\tS2\tmean1\tmean2\tsd1\tsd2\tp_00\tf1_00\tf2_00\tp_01\tp_10\tbest1\tpnest"
print header

coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
plateau=["Hejiatai","PukagongmaM5","Chokhopani"]
guangxi=["Longlin","Baojianshan","Dushan"]
label,target,s1,s2,out=("SOUTH","Daxi","Xinyi","Xinyi",4)
for target in ["Ami"]+south+guangxi: #+["Daxi"]: #,"Xinyi"]:,"Dai"
    for s1 in south:
        if len(list(set([target,s1,s2])))!=3: continue
        fh="UPA19_3.adm.%s_%s_%s_%s_out%i" % (label,target,s1,s2,out)
        mylst='\t'.join([target,s1,s2])+'\t'+'\t'.join(qpadm_2pop(pd,fh))

        print mylst
# Out:
# Target	S1	S2	mean1	mean2	sd1	sd2	p_00	f1_00	f2_00	p_01	p_10	best1	pnest
# Ami	Qihe	Xinyi	20.686509879	-19.686509879	7.466	7.466	0.337274	-2.217	3.217	0.0974076	0.0823897	01	0.0134802
# Ami	LiangDaoF	Xinyi	1.431761286	-0.431761286	0.544	0.544	0.0519199	0.972	0.028	0.0782351	4.66992e-05	01	-nan
# Ami	LiangDaoM	Xinyi	-51.825643769	52.825643769	17.351	17.351	0.204752	5.041	-4.041	0.0598974	0.00294625	01	0.0168
# Ami	Suogang	Xinyi	-5.501798437	6.501798437	4.893	4.893	0.0828001	1.509	-0.509	0.117363	0.0275295	01	0.816168
# Ami	Ma555_G6	Xinyi	0.588354877	0.411645123	1.865	1.865	0.0804807	2.308	-1.308	0.0250699	0.000411439	01	0.0228736
# Ami	Dushan	Xinyi	-0.858089615	1.858089615	0.884	0.884	0.536567	-1.267	2.267	1.05473e-06	0.00667668	10	3.80931e-05
# Qihe	LiangDaoF	Xinyi	0.541256269	0.458743731	0.264	0.264	0.79013	0.531	0.469	0.565669	0.486109	01	0.0684947
# Qihe	LiangDaoM	Xinyi	242.238550528	-241.238550528	228.095	228.095	0.323434	2.066	-1.066	0.358406	0.312096	01	0.431643
# ...

# %%
def qpadm_2pop(pd,fh):
    myfile=open(pd+fh+".log",'r')
    msd=[]
    for line in myfile:
        x=line.split()
        if 'Jackknife mean:' in line: msd.extend(x[2:4]); continue
        elif 'std. errors:' in line: msd.extend(x[2:4]); continue
        
        elif ' 00  0 ' in line: msd.extend(x[4:7]); continue
        elif ' 01  1 ' in line: msd.append(x[4]); continue
        elif ' 10  1 ' in line: msd.append(x[4]); continue
        elif 'p-value for nested model:' in line: msd.append(x[2]);msd.append(x[-1]); continue
        else: continue
    myfile.close()
    return msd

pd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"

header="Target\tS1\tS2\tmean1\tmean2\tsd1\tsd2\tp_00\tf1_00\tf2_00\tp_01\tp_10\tbest1\tpnest"
print header

coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
plateau=["Hejiatai","PukagongmaM5","Chokhopani"]
guangxi=["Longlin","Baojianshan","Dushan"]
label,target,s1,s2,out=("SOUTH","Daxi","Xinyi","Qihe",4)
for target in south: #+["Daxi"]: #,"Xinyi"]:,"Dai"
    for s1 in south+coastalnorth:
        if len(list(set([target,s1,s2])))!=3: continue
        fh="UPA19_3.adm.%s_%s_%s_%s_out%i" % (label,target,s1,s2,out)
        mylst='\t'.join([target,s1,s2])+'\t'+'\t'.join(qpadm_2pop(pd,fh))

        print mylst
# Out:
# Target	S1	S2	mean1	mean2	sd1	sd2	p_00	f1_00	f2_00	p_01	p_10	best1	pnest
# LiangDaoF	LiangDaoM	Qihe	0.370713832	0.629286168	1.052	1.052	0.476155	1.206	-0.206	0.553724	0.199281	01	0.707339
# LiangDaoF	Suogang	Qihe	12.087011115	-11.087011115	14.673	14.673	0.0598561	-0.227	1.227	0.190019	0.100076	01	-nan
# LiangDaoF	Ami	Qihe	0.733658823	0.266341177	0.548	0.548	0.465846	0.482	0.518	0.316232	0.450106	10	0.272592
# LiangDaoF	Ma555_G6	Qihe	16.012455420	-15.012455420	7.022	7.022	0.482456	-1.631	2.631	0.188208	0.400949	10	0.158782
# LiangDaoF	Xinyi	Qihe	-0.379786203	1.379786203	0.948	0.948	0.795935	-0.894	1.894	0.0440441	0.565932	10	0.0659011
# LiangDaoF	Dushan	Qihe	0.024701701	0.975298299	1.012	1.012	0.581056	-0.193	1.193	0.322518	0.661018	10	0.770521
# LiangDaoF	Bbdong	Qihe	0.048756426	0.951243574	0.326	0.326	0.355068	0.021	0.979	0.0037832	0.444559	10	-nan
# LiangDaoF	Boshan	Qihe	-0.207426418	1.207426418	0.209	0.209	0.537431	-0.229	1.229	5.22991e-09	0.457987	10	0.170146
# ...

# %%
def qpadm_2pop(pd,fh):
    myfile=open(pd+fh+".log",'r')
    msd=[]
    for line in myfile:
        x=line.split()
        if 'Jackknife mean:' in line: msd.extend(x[2:4]); continue
        elif 'std. errors:' in line: msd.extend(x[2:4]); continue
        
        elif ' 00  0 ' in line: msd.extend(x[4:7]); continue
        elif ' 01  1 ' in line: msd.append(x[4]); continue
        elif ' 10  1 ' in line: msd.append(x[4]); continue
        elif 'p-value for nested model:' in line: msd.append(x[2]);msd.append(x[-1]); continue
        else: continue
    myfile.close()
    return msd

pd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"

header="Target\tS1\tS2\tmean1\tmean2\tsd1\tsd2\tp_00\tf1_00\tf2_00\tp_01\tp_10\tbest1\tpnest"
print header

coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
plateau=["Hejiatai","PukagongmaM5","Chokhopani"]
guangxi=["Longlin","Baojianshan","Dushan"]


label,target,s1,s2,out=("COASTN","Bbdong","Xinyi","Boisman_MN",2)
for s2 in coastalnorth:
    for s1 in south: #sib: #+["Daxi"]: #,"Xinyi"]:,"Dai"
        for target in ["HDYM1","Dashuitian"]+coastalnorth:
            if len(list(set([target,s1,s2])))!=3: continue
            fh="UPA19_3.adm.%s_%s_%s_%s_out%i" % (label,target,s1,s2,out)
            mylst='\t'.join([target,s1,s2])+'\t'+'\t'.join(qpadm_2pop(pd,fh))

            print mylst
# Out:
# Target	S1	S2	mean1	mean2	sd1	sd2	p_00	f1_00	f2_00	p_01	p_10	best1	pnest
# HDYM1	Qihe	Bbdong	-0.185753148	1.185753148	0.376	0.376	0.393783	-0.280	1.280	0.00016368	0.380739	10	0.268779
# Dashuitian	Qihe	Bbdong	-0.282616224	1.282616224	0.509	0.509	0.132445	-0.457	1.457	1.09482e-05	0.0808122	10	0.0835676
# Boshan	Qihe	Bbdong	0.179084469	0.820915531	0.759	0.759	0.0526349	-0.029	1.029	0.0113499	0.0810657	10	-nan
# Xiaogao	Qihe	Bbdong	0.114914949	0.885085051	0.319	0.319	0.411795	0.065	0.935	0.00937686	0.501784	10	0.837405
# XJS	Qihe	Bbdong	-0.073887849	1.073887849	1.015	1.015	0.139861	-0.761	1.761	0.000589631	0.0691518	10	0.0541386
# XJS_F	Qihe	Bbdong	0.219144192	0.780855808	0.326	0.326	0.159566	0.107	0.893	0.0014924	0.211105	10	0.687237
# Linzi	Qihe	Bbdong	-0.033103123	1.033103123	0.362	0.362	0.387143	-0.133	1.133	0.000463807	0.455805	10	0.606343
# HDYM1	LiangDaoF	Bbdong	-0.592484210	1.592484210	0.331	0.331	0.979896	-0.664	1.664	3.50642e-09	0.281272	10	0.00203169
# ...

# %%
def qpadm_2pop(pd,fh):
    myfile=open(pd+fh+".log",'r')
    msd=[]
    for line in myfile:
        x=line.split()
        if 'Jackknife mean:' in line: msd.extend(x[2:4]); continue
        elif 'std. errors:' in line: msd.extend(x[2:4]); continue
        
        elif ' 00  0 ' in line: msd.extend(x[4:7]); continue
        elif ' 01  1 ' in line: msd.append(x[4]); continue
        elif ' 10  1 ' in line: msd.append(x[4]); continue
        elif 'p-value for nested model:' in line: msd.append(x[2]);msd.append(x[-1]); continue
        else: continue
    myfile.close()
    return msd

pd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"

header="Target\tS1\tS2\tmean1\tmean2\tsd1\tsd2\tp_00\tf1_00\tf2_00\tp_01\tp_10\tbest1\tpnest"
print header

coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
plateau=["Hejiatai","PukagongmaM5","Chokhopani"]
guangxi=["Longlin","Baojianshan","Dushan"]


label,target,s1,s2,out=("COASTN","Bbdong","Xinyi","Boisman_MN",2)
for s2 in coastalnorth:
    for s1 in sib: #+["Daxi"]: #,"Xinyi"]:,"Dai"
        for target in ["HDYM1","Dashuitian"]+coastalnorth:
            if len(list(set([target,s1,s2])))!=3: continue
            fh="UPA19_3.adm.%s_%s_%s_%s_out%i" % (label,target,s1,s2,out)
            mylst='\t'.join([target,s1,s2])+'\t'+'\t'.join(qpadm_2pop(pd,fh))

            print mylst

# %%
def qpadm_2pop(pd,fh):
    myfile=open(pd+fh+".log",'r')
    msd=[]
    for line in myfile:
        x=line.split()
        if 'Jackknife mean:' in line: msd.extend(x[2:4]); continue
        elif 'std. errors:' in line: msd.extend(x[2:4]); continue
        
        elif ' 00  0 ' in line: msd.extend(x[4:7]); continue
        elif ' 01  1 ' in line: msd.append(x[4]); continue
        elif ' 10  1 ' in line: msd.append(x[4]); continue
        elif 'p-value for nested model:' in line: msd.append(x[2]);msd.append(x[-1]); continue
        else: continue
    myfile.close()
    return msd

pd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"

header="Target\tS1\tS2\tmean1\tmean2\tsd1\tsd2\tp_00\tf1_00\tf2_00\tp_01\tp_10\tbest1\tpnest"
print header

coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
plateau=["Hejiatai","PukagongmaM5","Chokhopani"]
guangxi=["Longlin","Baojianshan","Dushan"]


label,target,s1,s2,out=("COASTN","JomonM","Xinyi","Boisman_MN",5)
for target in coastalnorth+south+sib:
    for s1 in ["Jomon"]: #+["Daxi"]: #,"Xinyi"]:,"Dai"
        for target in ["JomonM"]:
            if len(list(set([target,s1,s2])))!=3: continue
            fh="UPA19_3.adm.%s_%s_%s_%s_out%i" % (label,target,s1,s2,out)
            mylst='\t'.join([target,s1,s2])+'\t'+'\t'.join(qpadm_2pop(pd,fh))

            print mylst
# Out:
# Target	S1	S2	mean1	mean2	sd1	sd2	p_00	f1_00	f2_00	p_01	p_10	best1	pnest
# JomonM	Jomon	Bbdong	0.762959530	0.237040470	0.356	0.356	0.869246	0.844	0.156	0.900096	0.211284	01	0.581674
# JomonM	Jomon	Boshan	0.911168886	0.088831114	0.188	0.188	0.839212	0.934	0.066	0.888331	0.00224784	01	0.711562
# JomonM	Jomon	Xiaogao	0.919859111	0.080140889	0.249	0.249	0.918943	0.950	0.050	0.952395	0.040205	01	0.836657
# JomonM	Jomon	XJS	0.968891099	0.031108901	0.283	0.283	0.936246	1.024	-0.024	0.965479	0.098484	01	0.990144
# JomonM	Jomon	XJS_F	0.815093954	0.184906046	0.309	0.309	0.700363	0.861	0.139	0.75761	0.0742026	01	0.585343
# JomonM	Jomon	Linzi	0.608739822	0.391260178	0.900	0.900	0.738786	1.073	-0.073	0.818285	0.146736	01	0.936915
# JomonM	Jomon	Qihe	0.839453910	0.160546090	0.233	0.233	0.997897	0.848	0.152	0.997286	0.37278	01	0.51257
# JomonM	Jomon	LiangDaoF	0.934657792	0.065342208	0.487	0.487	0.872078	1.143	-0.143	0.910049	0.0721649	01	0.662852
# ...

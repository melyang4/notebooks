# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"
fh="UPA19_3"
name="SOUTHtv"
pt="adm"
out="out4"
south=["Suogang","Qihe","Qihe_d","LiangDaoF","LiangDaoM","Ma555_G6"]
north=["JomonM","ZongriM297","Hejiatai","PukagongmaM5","Chokhopani",
       "Kolyma_River","Shamanka_EN","HDYM1",
       "DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao","XJS","XJS_F" ]        
central=["Longlin","Baojianshan","Dushan",
         "ZhaoguoM2","Daxi","Dashuitian",
         "DonghulinM1","Jiahu_M52_I2","Tianluoshan","Liangzhu_T4620"]
seas=["Ma912_G2","La727_G2","Vt880_G2","Vt833_G2","Man_Bac","Nui_Nap",
      "Vt719_G3_1","Vt777_G3","Th521_G4","Oakaie1"]
pdeas=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean","Han","Tujia","She","Miao",
      "Naxi","Yi","Dai","Kinh","Lahu","Ami","Atayal"]
coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
guangxi=["Longlin","Baojianshan","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
plateau=["Hejiatai","PukagongmaM5","Chokhopani"]
targets=guangxi+south
s1s=south
s2s=guangxi+["Xinyi","Daxi"]
for s2 in s2s:
    for s1 in s1s: 
        for target in targets:
            if s1 == target: continue
            if s2==target: continue
            label="%s_%s_%s_%s_%s" % (name,target,s1,s2,out)
            ff.parfile(pD,fh,pt,label,outpd=outpd,outgroup=fh+"."+out,badsnp="UPA16.transi.snp\n")
            ff.mklst(outpd,fh,pt+"."+label,[target,s1,s2],suffix="leftpop")
        
        mytuple=(fh,pt,"%s_%s_%s_%s_%s" % (name,"${i}",s1,s2,out))
        print "for i in %s; do " % " ".join(targets)+"qpAdm -p {0}.{1}.{2}.par > {0}.{1}.{2}.log; done &".format(*mytuple)
# Out:
# for i in Longlin Baojianshan Dushan Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.SOUTHtv_${i}_Qihe_Longlin_out4.par > UPA19_3.adm.SOUTHtv_${i}_Qihe_Longlin_out4.log; done &
# for i in Longlin Baojianshan Dushan Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.SOUTHtv_${i}_LiangDaoF_Longlin_out4.par > UPA19_3.adm.SOUTHtv_${i}_LiangDaoF_Longlin_out4.log; done &
# for i in Longlin Baojianshan Dushan Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.SOUTHtv_${i}_LiangDaoM_Longlin_out4.par > UPA19_3.adm.SOUTHtv_${i}_LiangDaoM_Longlin_out4.log; done &
# for i in Longlin Baojianshan Dushan Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.SOUTHtv_${i}_Suogang_Longlin_out4.par > UPA19_3.adm.SOUTHtv_${i}_Suogang_Longlin_out4.log; done &
# ...

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"
fh="UPA19_3"
name="NORTHtv"
pt="adm"
out="out2"
south=["Suogang","Qihe","Qihe_d","LiangDaoF","LiangDaoM","Ma555_G6"]
north=["JomonM","ZongriM297","Hejiatai","PukagongmaM5","Chokhopani",
       "Kolyma_River","Shamanka_EN","HDYM1",
       "DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao","XJS","XJS_F" ]        
central=["Longlin","Baojianshan","Dushan",
         "ZhaoguoM2","Daxi","Dashuitian",
         "DonghulinM1","Jiahu_M52_I2","Tianluoshan","Liangzhu_T4620"]
seas=["Ma912_G2","La727_G2","Vt880_G2","Vt833_G2","Man_Bac","Nui_Nap",
      "Vt719_G3_1","Vt777_G3","Th521_G4","Oakaie1"]
pdeas=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean","Han","Tujia","She","Miao",
      "Naxi","Yi","Dai","Kinh","Lahu","Ami","Atayal"]
coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
targets=["HDYM1"]
s1s=coastalnorth
s2s=south+sib
targets=["Shamanka_EN","HDYM1"]
s1s=coastalnorth+sib
s2s=coastalnorth+sib
for s2 in s2s:
    for target in targets:
        for s1 in s1s: 
            if s1 == target: continue
            if s2==target: continue
            if s1==s2: continue
            label="%s_%s_%s_%s_%s" % (name,target,s1,s2,out)
            ff.parfile(pD,fh,pt,label,outpd=outpd,outgroup=fh+"."+out,badsnp="UPA16.transi.snp\n")
            ff.mklst(outpd,fh,pt+"."+label,[target,s1,s2],suffix="leftpop")
        
        mytuple=(fh,pt,"%s_%s_%s_%s_%s" % (name,target,"${i}",s2,out))
        print "for i in %s; do " % " ".join(s1s)+"qpAdm -p {0}.{1}.{2}.par > {0}.{1}.{2}.log; done &".format(*mytuple)
# Out:
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.NORTHtv_Shamanka_EN_${i}_Bbdong_out2.par > UPA19_3.adm.NORTHtv_Shamanka_EN_${i}_Bbdong_out2.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.NORTHtv_HDYM1_${i}_Bbdong_out2.par > UPA19_3.adm.NORTHtv_HDYM1_${i}_Bbdong_out2.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.NORTHtv_Shamanka_EN_${i}_Boshan_out2.par > UPA19_3.adm.NORTHtv_Shamanka_EN_${i}_Boshan_out2.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.NORTHtv_HDYM1_${i}_Boshan_out2.par > UPA19_3.adm.NORTHtv_HDYM1_${i}_Boshan_out2.log; done &
# ...

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"
fh="UPA19_3"
name="WESTtv"
pt="adm"
out="out3"
south=["Suogang","Qihe","Qihe_d","LiangDaoF","LiangDaoM","Ma555_G6"]
north=["JomonM","ZongriM297","Hejiatai","PukagongmaM5","Chokhopani",
       "Kolyma_River","Shamanka_EN","HDYM1",
       "DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao","XJS","XJS_F" ]        
central=["Longlin","Baojianshan","Dushan",
         "ZhaoguoM2","Daxi","Dashuitian",
         "DonghulinM1","Jiahu_M52_I2","Tianluoshan","Liangzhu_T4620"]
seas=["Ma912_G2","La727_G2","Vt880_G2","Vt833_G2","Man_Bac","Nui_Nap",
      "Vt719_G3_1","Vt777_G3","Th521_G4","Oakaie1"]
pdeas=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean","Han","Tujia","She","Miao",
      "Naxi","Yi","Dai","Kinh","Lahu","Ami","Atayal"]
coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
plateau=["Hejiatai","PukagongmaM5","Chokhopani","ZongriM297"]
targets=plateau
s1s=coastalnorth+sib
s2s=plateau
for s2 in s2s:
    for s1 in s1s: 
        for target in targets:
            if s1 == target: continue
            if s2==target: continue
            if s1==s2: continue
            label="%s_%s_%s_%s_%s" % (name,target,s1,s2,out)
            ff.parfile(pD,fh,pt,label,outpd=outpd,outgroup=fh+"."+out,badsnp="UPA16.transi.snp\n")
            ff.mklst(outpd,fh,pt+"."+label,[target,s1,s2],suffix="leftpop")
        
        mytuple=(fh,pt,"%s_%s_%s_%s_%s" % (name,"${i}",s1,s2,out))
        print "for i in %s; do " % " ".join(targets)+"qpAdm -p {0}.{1}.{2}.par > {0}.{1}.{2}.log; done &".format(*mytuple)
# Out:
# for i in Hejiatai PukagongmaM5 Chokhopani ZongriM297; do qpAdm -p UPA19_3.adm.WESTtv_${i}_Bbdong_Hejiatai_out3.par > UPA19_3.adm.WESTtv_${i}_Bbdong_Hejiatai_out3.log; done &
# for i in Hejiatai PukagongmaM5 Chokhopani ZongriM297; do qpAdm -p UPA19_3.adm.WESTtv_${i}_Boshan_Hejiatai_out3.par > UPA19_3.adm.WESTtv_${i}_Boshan_Hejiatai_out3.log; done &
# for i in Hejiatai PukagongmaM5 Chokhopani ZongriM297; do qpAdm -p UPA19_3.adm.WESTtv_${i}_Xiaogao_Hejiatai_out3.par > UPA19_3.adm.WESTtv_${i}_Xiaogao_Hejiatai_out3.log; done &
# for i in Hejiatai PukagongmaM5 Chokhopani ZongriM297; do qpAdm -p UPA19_3.adm.WESTtv_${i}_XJS_Hejiatai_out3.par > UPA19_3.adm.WESTtv_${i}_XJS_Hejiatai_out3.log; done &
# for i in Hejiatai PukagongmaM5 Chokhopani ZongriM297; do qpAdm -p UPA19_3.adm.WESTtv_${i}_XJS_F_Hejiatai_out3.par > UPA19_3.adm.WESTtv_${i}_XJS_F_Hejiatai_out3.log; done &
# ...

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"
fh="UPA19_3"
name="WEST2tv"
pt="adm"
out="out3"
south=["Suogang","Qihe","Qihe_d","LiangDaoF","LiangDaoM","Ma555_G6"]
north=["JomonM","ZongriM297","Hejiatai","PukagongmaM5","Chokhopani",
       "Kolyma_River","Shamanka_EN","HDYM1",
       "DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao","XJS","XJS_F" ]        
central=["Longlin","Baojianshan","Dushan",
         "ZhaoguoM2","Daxi","Dashuitian",
         "DonghulinM1","Jiahu_M52_I2","Tianluoshan","Liangzhu_T4620"]
seas=["Ma912_G2","La727_G2","Vt880_G2","Vt833_G2","Man_Bac","Nui_Nap",
      "Vt719_G3_1","Vt777_G3","Th521_G4","Oakaie1"]
pdeas=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean","Han","Tujia","She","Miao",
      "Naxi","Yi","Dai","Kinh","Lahu","Ami","Atayal"]
coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
plateau=["Hejiatai","PukagongmaM5","Chokhopani","ZongriM297"]
targets=sib[2:4]
s1s=coastalnorth+sib
s2s=plateau
for s2 in s2s:
    for s1 in s1s: 
        for target in targets:
            if s1 == target: continue
            if s2==target: continue
            if s1==s2: continue
            label="%s_%s_%s_%s_%s" % (name,target,s1,s2,out)
            ff.parfile(pD,fh,pt,label,outpd=outpd,outgroup=fh+"."+out,badsnp="UPA16.transi.snp\n")
            ff.mklst(outpd,fh,pt+"."+label,[target,s1,s2],suffix="leftpop")
        
        mytuple=(fh,pt,"%s_%s_%s_%s_%s" % (name,"${i}",s1,s2,out))
        print "for i in %s; do " % " ".join(targets)+"qpAdm -p {0}.{1}.{2}.par > {0}.{1}.{2}.log; done &".format(*mytuple)
# Out:
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2tv_${i}_Bbdong_Hejiatai_out3.par > UPA19_3.adm.WEST2tv_${i}_Bbdong_Hejiatai_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2tv_${i}_Boshan_Hejiatai_out3.par > UPA19_3.adm.WEST2tv_${i}_Boshan_Hejiatai_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2tv_${i}_Xiaogao_Hejiatai_out3.par > UPA19_3.adm.WEST2tv_${i}_Xiaogao_Hejiatai_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2tv_${i}_XJS_Hejiatai_out3.par > UPA19_3.adm.WEST2tv_${i}_XJS_Hejiatai_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2tv_${i}_XJS_F_Hejiatai_out3.par > UPA19_3.adm.WEST2tv_${i}_XJS_F_Hejiatai_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2tv_${i}_Linzi_Hejiatai_out3.par > UPA19_3.adm.WEST2tv_${i}_Linzi_Hejiatai_out3.log; done &
# ...

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"
fh="UPA19_3"
name="SOUTHtv"
pt="adm"
out="out4"
south=["Suogang","Qihe","Qihe_d","LiangDaoF","LiangDaoM","Ma555_G6"]
north=["JomonM","ZongriM297","Hejiatai","PukagongmaM5","Chokhopani",
       "Kolyma_River","Shamanka_EN","HDYM1",
       "DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao","XJS","XJS_F" ]        
central=["Longlin","Baojianshan","Dushan",
         "ZhaoguoM2","Daxi","Dashuitian",
         "DonghulinM1","Jiahu_M52_I2","Tianluoshan","Liangzhu_T4620"]
seas=["Ma912_G2","La727_G2","Vt880_G2","Vt833_G2","Man_Bac","Nui_Nap",
      "Vt719_G3_1","Vt777_G3","Th521_G4","Oakaie1"]
pdeas=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean","Han","Tujia","She","Miao",
      "Naxi","Yi","Dai","Kinh","Lahu","Ami","Atayal"]
coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan","Dai"]
guangxi=["Longlin","Baojianshan","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
plateau=["Hejiatai","PukagongmaM5","Chokhopani"]
targets=south
s1s=coastalnorth+south
s2s=south
for s2 in s2s:
    for s1 in s1s: 
        for target in targets:
            if s1 == target: continue
            if s2==target: continue
            if s1==s2: continue
            label="%s_%s_%s_%s_%s" % (name,target,s1,s2,out)
            ff.parfile(pD,fh,pt,label,outpd=outpd,outgroup=fh+"."+out,badsnp="UPA16.transi.snp\n")
            ff.mklst(outpd,fh,pt+"."+label,[target,s1,s2],suffix="leftpop")
        
    mytuple=(fh,pt,"%s_%s_%s_%s_%s" % (name,"${j}","${i}",s2,out))
    print "for j in %s; " % " ".join(targets)+"do for i in %s; do " % " ".join(s1s)+"qpAdm -p {0}.{1}.{2}.par > {0}.{1}.{2}.log; done; done &".format(*mytuple)
# Out:
# for j in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Dai; do for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Dai; do qpAdm -p UPA19_3.adm.SOUTHtv_${j}_${i}_Qihe_out4.par > UPA19_3.adm.SOUTHtv_${j}_${i}_Qihe_out4.log; done; done &
# for j in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Dai; do for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Dai; do qpAdm -p UPA19_3.adm.SOUTHtv_${j}_${i}_LiangDaoF_out4.par > UPA19_3.adm.SOUTHtv_${j}_${i}_LiangDaoF_out4.log; done; done &
# for j in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Dai; do for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Dai; do qpAdm -p UPA19_3.adm.SOUTHtv_${j}_${i}_LiangDaoM_out4.par > UPA19_3.adm.SOUTHtv_${j}_${i}_LiangDaoM_out4.log; done; done &
# ...

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"
fh="UPA19_3"
name="COASTNtv"
pt="adm"
out="out2"
south=["Suogang","Qihe","Qihe_d","LiangDaoF","LiangDaoM","Ma555_G6"]
north=["JomonM","ZongriM297","Hejiatai","PukagongmaM5","Chokhopani",
       "Kolyma_River","Shamanka_EN","HDYM1",
       "DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao","XJS","XJS_F" ]        
central=["Longlin","Baojianshan","Dushan",
         "ZhaoguoM2","Daxi","Dashuitian",
         "DonghulinM1","Jiahu_M52_I2","Tianluoshan","Liangzhu_T4620"]
seas=["Ma912_G2","La727_G2","Vt880_G2","Vt833_G2","Man_Bac","Nui_Nap",
      "Vt719_G3_1","Vt777_G3","Th521_G4","Oakaie1"]
pdeas=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean","Han","Tujia","She","Miao",
      "Naxi","Yi","Dai","Kinh","Lahu","Ami","Atayal"]
coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
targets=coastalnorth
s1s=south
s2s=["HDYM1","Shamanka_EN","DevilsGate","Boisman_MN"]
for s2 in s2s:
    for target in targets:
        for s1 in s1s: 
            if s1 == target: continue
            if s2==target: continue
            label="%s_%s_%s_%s_%s" % (name,target,s1,s2,out)
            ff.parfile(pD,fh,pt,label,outpd=outpd,outgroup=fh+"."+out,badsnp="UPA16.transi.snp\n")
            ff.mklst(outpd,fh,pt+"."+label,[target,s1,s2],suffix="leftpop")
        
        mytuple=(fh,pt,"%s_%s_%s_%s_%s" % (name,target,"${i}",s2,out))
        print "for i in %s; do " % " ".join(s1s)+"qpAdm -p {0}.{1}.{2}.par > {0}.{1}.{2}.log; done &".format(*mytuple)
# Out:
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTNtv_Bbdong_${i}_HDYM1_out2.par > UPA19_3.adm.COASTNtv_Bbdong_${i}_HDYM1_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTNtv_Boshan_${i}_HDYM1_out2.par > UPA19_3.adm.COASTNtv_Boshan_${i}_HDYM1_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTNtv_Xiaogao_${i}_HDYM1_out2.par > UPA19_3.adm.COASTNtv_Xiaogao_${i}_HDYM1_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTNtv_XJS_${i}_HDYM1_out2.par > UPA19_3.adm.COASTNtv_XJS_${i}_HDYM1_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTNtv_XJS_F_${i}_HDYM1_out2.par > UPA19_3.adm.COASTNtv_XJS_F_${i}_HDYM1_out2.log; done &
# ...

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_3s/"

outgroups=["UstIshim","Papuan","Kostenki14","Onge","Tianyuan",
          "Kolyma","Yana","Group1","Mixe","JomonM"]
fh="UPA19_3"
ff.mklst(pD,fh,"out0",outgroups)
# Out:
# 'Made /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_3s/UPA19_3.out0 file'

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_3s/"
fh="UPA19_3"
name="A_3S"
pt="adm"

out="out0"
innerN=["HDYM1","ZongriM297","Hejiatai","Chokhopani","Shamanka_EN"]
coastN=["Bbdong","Boshan","XJS_F","Xiaogao"] #"XJS",
coastSo=["Qihe","LiangDaoF","LiangDaoM"]
coastSy=["Suogang","Ma555_G6","Ami","Atayal"]
anc=["Tianyuan","La368_G1","JomonM","Kolyma_River","DevilsGate"]
seasia=["Man_Bac","Nui_Nap","Oakaie1","Ban_Chiang","Vt833_G2","Vt880_G2",
        "La727_G2","Ma912_G2","Th521_G4","Vt777_G3"]
others=["Mixe","Surui","Papuan","Onge"]
neas=["Oroqen","Xibo","Daur","Hezhen","Tu","Uygur"]
ceas=["Japanese","Korean","Han","She","Miao","Tujia",
      "Han_ShandongX","Han_GansuX","Han_GuangdongX",
      "Han_HenanX","Han_JiangsuX","Han_SichuanX"]
seas=["Lahu","Dai","Ami","Atayal"]
weas=["Naxi","Yi","Tibetan_ShannanX","Tibetan_LhasaX","Tibetan_NagquX",
       "Tibetan_ShigatseX","Tibetan_ChamdoX","Tibetan","Sherpa","Sherpa_ShigatseX"]
sea=["Kinh","Htin_Mal","Mlabri","Cambodian","Thai","Burmese"]
pdeas=neas+ceas+seas+weas+sea
aeas=anc+innerN+coastN+coastSo+coastSy+seasia+others

targets=pdeas+aeas
s1s=coastN
s2s=coastSo
s3="HDYM1"
for s2 in s2s:
    for s1 in s1s:
        for target in targets:
            if s1 == target: continue
            if s2==target: continue
            label="%s_%s_%s_%s_%s_%s" % (name,target,s1,s2,s3,out)
            ff.parfile(pD,fh,pt,label,outpd=outpd,outgroup=fh+"."+out,indfh='UPA19_3.qpadmmerge1')
            ff.mklst(outpd,fh,pt+"."+label,[target,s1,s2,s3],suffix="leftpop")
        
        mytuple=(fh,pt,"%s_%s_%s_%s_%s_%s" % (name,"${i}",s1,s2,s3,out))
        print "for i in %s; do " % " ".join(targets)+"qpAdm -p {0}.{1}.{2}.par > {0}.{1}.{2}.log; done &".format(*mytuple)
# Out:
# for i in Oroqen Xibo Daur Hezhen Tu Uygur Japanese Korean Han She Miao Tujia Han_ShandongX Han_GansuX Han_GuangdongX Han_HenanX Han_JiangsuX Han_SichuanX Lahu Dai Ami Atayal Naxi Yi Tibetan_ShannanX Tibetan_LhasaX Tibetan_NagquX Tibetan_ShigatseX Tibetan_ChamdoX Tibetan Sherpa Sherpa_ShigatseX Kinh Htin_Mal Mlabri Cambodian Thai Burmese Tianyuan La368_G1 JomonM Kolyma_River DevilsGate HDYM1 ZongriM297 Hejiatai Chokhopani Shamanka_EN Bbdong Boshan XJS_F Xiaogao Qihe LiangDaoF LiangDaoM Suogang Ma555_G6 Ami Atayal Man_Bac Nui_Nap Oakaie1 Ban_Chiang Vt833_G2 Vt880_G2 La727_G2 Ma912_G2 Th521_G4 Vt777_G3 Mixe Surui Papuan Onge; do qpAdm -p UPA19_3.adm.A_3S_${i}_Bbdong_Qihe_HDYM1_out0.par > UPA19_3.adm.A_3S_${i}_Bbdong_Qihe_HDYM1_out0.log; done &
seasia=["Man_Bac","Nui_Nap","Oakaie1","Ban_Chiang","Vt833_G2","Vt880_G2",
        "La727_G2","Ma912_G2","Th521_G4","Vt777_G3"]
others=["Mixe","Surui","Papuan","Onge"]
neas=["Oroqen","Xibo","Daur","Hezhen","Tu","Uygur"]
ceas=["Japanese","Korean","Han","She","Miao","Tujia",
      "Han_ShandongX","Han_GansuX","Han_GuangdongX",
      "Han_HenanX","Han_JiangsuX","Han_SichuanX"]
seas=["Lahu","Dai","Ami","Atayal"]
weas=["Naxi","Yi","Tibetan_ShannanX","Tibetan_LhasaX","Tibetan_NagquX",
       "Tibetan_ShigatseX","Tibetan_ChamdoX","Tibetan","Sherpa","Sherpa_ShigatseX"]
sea=["Kinh","Htin_Mal","Mlabri","Cambodian","Thai","Burmese"]
pdeas=neas+ceas+seas+weas+sea
aeas=anc+innerN+coastN+coastSo+coastSy+seasia+others

targets=pdeas+aeas
s1s=coastN
s2s=coastSo
s3="ZongriM297"
for s2 in s2s:
    for s1 in s1s:
        for target in targets:
            if s1 == target: continue
            if s2==target: continue
            label="%s_%s_%s_%s_%s_%s" % (name,target,s1,s2,s3,out)
            ff.parfile(pD,fh,pt,label,outpd=outpd,outgroup=fh+"."+out,indfh='UPA19_3.qpadmmerge1')
            ff.mklst(outpd,fh,pt+"."+label,[target,s1,s2,s3],suffix="leftpop")
        
        mytuple=(fh,pt,"%s_%s_%s_%s_%s_%s" % (name,"${i}",s1,s2,s3,out))
        print "for i in %s; do " % " ".join(targets)+"qpAdm -p {0}.{1}.{2}.par > {0}.{1}.{2}.log; done &".format(*mytuple)
# Out:
# for i in Oroqen Xibo Daur Hezhen Tu Uygur Japanese Korean Han She Miao Tujia Han_ShandongX Han_GansuX Han_GuangdongX Han_HenanX Han_JiangsuX Han_SichuanX Lahu Dai Ami Atayal Naxi Yi Tibetan_ShannanX Tibetan_LhasaX Tibetan_NagquX Tibetan_ShigatseX Tibetan_ChamdoX Tibetan Sherpa Sherpa_ShigatseX Kinh Htin_Mal Mlabri Cambodian Thai Burmese Tianyuan La368_G1 JomonM Kolyma_River DevilsGate HDYM1 ZongriM297 Hejiatai Chokhopani Shamanka_EN Bbdong Boshan XJS_F Xiaogao Qihe LiangDaoF LiangDaoM Suogang Ma555_G6 Ami Atayal Man_Bac Nui_Nap Oakaie1 Ban_Chiang Vt833_G2 Vt880_G2 La727_G2 Ma912_G2 Th521_G4 Vt777_G3 Mixe Surui Papuan Onge; do qpAdm -p UPA19_3.adm.A_3S_${i}_Bbdong_Qihe_ZongriM297_out0.par > UPA19_3.adm.A_3S_${i}_Bbdong_Qihe_ZongriM297_out0.log; done &
# for i in Oroqen Xibo Daur Hezhen Tu Uygur Japanese Korean Han She Miao Tujia Han_ShandongX Han_GansuX Han_GuangdongX Han_HenanX Han_JiangsuX Han_SichuanX Lahu Dai Ami Atayal Naxi Yi Tibetan_ShannanX Tibetan_LhasaX Tibetan_NagquX Tibetan_ShigatseX Tibetan_ChamdoX Tibetan Sherpa Sherpa_ShigatseX Kinh Htin_Mal
#     numlines=$(wc -l ${pd}${fh}.${label}.log | cut -d" " -f1)
#
#     popind=$(cat ${pd}${fh}.${label}.log | grep -n "left pops:" | cut -d":" -f1)
#     diff1=`expr ${numlines} - ${popind} + 1`
#     tail -n ${diff1} ${pd}${fh}.${label}.log | head -n `expr ${numsource} + 3`
#
#     myind=$(cat ${pd}${fh}.${label}.log | grep -n "std. errors:" | cut -d":" -f1)
#     diff2=`expr ${numlines} - ${myind} + 2`
#     tail -n ${diff2} ${pd}${fh}.${label}.log | head -n2
#
#     tabind1=$(cat ${pd}${fh}.${label}.log | grep -n "summ:" | cut -d":" -f1)
#     tabind2=$(cat ${pd}${fh}.${label}.log | grep -n "coeffs:" | cut -d":" -f1)
#
#     diff3=`expr ${numlines} - ${tabind1}`
#     diff4=`expr ${tabind2} - ${tabind1} - 2`
#     tail -n ${diff3} ${pd}${fh}.${label}.log | head -n ${diff4}
# done
# Out:
# left pops:
# Oroqen
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     15.758929941    -7.089707852    -7.669222090
#       std. errors:    14.213     6.273     8.102
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.946        0.889989    -7.682     3.094     5.588  infeasible
#           001  1     8    10.392        0.238593     2.987    -1.987    -0.000  infeasible
#           010  1     8     7.819        0.451315    -1.959    -0.000     2.959  infeasible
#           100  1     8    19.193         0.01386    -0.000    -0.458     1.458  infeasible
#           011  2     9    60.619     1.01846e-09     1.000    -0.000     0.000
#           101  2     9   102.922     4.02901e-18     0.000     1.000     0.000
#           110  2     9    28.987     0.000651343     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     7.446 p-value for nested model:      0.00635687
# best pat:          110      0.000651343  chi(nested):    18.595 p-value for nested model:     1.61638e-05
# left pops:
# Xibo
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:    233.783773812   -99.933155042  -132.850618770
#       std. errors:    61.827    26.600    35.333
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.294        0.856551   -12.495     5.624     7.871  infeasible
#           001  1     8    10.740        0.216862     1.726    -0.726     0.000  infeasible
#           010  1     8    12.165        0.143995     6.487     0.000    -5.487  infeasible
#           100  1     8    17.573       0.0246616     0.000     0.254     0.746
#           011  2     9    17.659       0.0393363     1.000    -0.000     0.000
#           101  2     9    41.747     3.65577e-06     0.000     1.000     0.000
#           110  2     9    20.812       0.0135141     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100        0.0246616  chi(nested):    14.280 p-value for nested model:     0.000157562
# best pat:          011        0.0393363  chi(nested):     0.086 p-value for nested model:        0.769353
# left pops:
# Daur
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     57.378063350   -24.627426768   -31.750636582
#       std. errors:    27.687    12.003    15.821
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.178        0.868043    -9.808     4.251     6.557  infeasible
#           001  1     8    10.523        0.230221     2.323    -1.323     0.000  infeasible
#           010  1     8    10.265        0.246935    -1.835    -0.000     2.835  infeasible
#           100  1     8    17.399       0.0262148     0.000    -0.109     1.109  infeasible
#           011  2     9    25.973       0.0020639     1.000    -0.000     0.000
#           101  2     9    53.774     2.08443e-08     0.000     1.000     0.000
#           110  2     9    17.837       0.0371117     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     7.345 p-value for nested model:      0.00672585
# best pat:          110        0.0371117  chi(nested):     7.314 p-value for nested model:      0.00684152
# left pops:
# Hezhen
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      3.731044959    -1.587497992    -1.143546968
#       std. errors:     6.171     2.751     3.531
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.684        0.912619    -4.061     1.801     3.259  infeasible
#           001  1     8    10.107        0.257562     2.279    -1.279     0.000  infeasible
#           010  1     8     9.074        0.336074    -1.167    -0.000     2.167  infeasible
#           100  1     8    14.798       0.0632027     0.000    -0.062     1.062  infeasible
#           011  2     9    31.451     0.000247686     1.000    -0.000     0.000
#           101  2     9    61.729     6.21732e-10     0.000     1.000     0.000
#           110  2     9    14.999        0.090962     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     7.424 p-value for nested model:      0.00643766
# best pat:          110         0.090962  chi(nested):     4.892 p-value for nested model:       0.0269884
# left pops:
# Tu
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     -0.051369690     0.551316843     0.500052847
#       std. errors:     2.460     1.094     1.457
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     1.911        0.964611    -2.126     1.428     1.698  infeasible
#           001  1     8    17.984       0.0213499     2.993    -1.993     0.000  infeasible
#           010  1     8    11.210        0.190089     3.424    -0.000    -2.424  infeasible
#           100  1     8    12.748        0.120803     0.000     0.545     0.455
#           011  2     9    21.682      0.00994506     1.000    -0.000     0.000
#           101  2     9    22.971      0.00626083     0.000     1.000     0.000
#           110  2     9    29.923     0.000452087     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.120803  chi(nested):    10.838 p-value for nested model:     0.000994579
# best pat:          011       0.00994506  chi(nested):     8.933 p-value for nested model:      0.00280053
# left pops:
# Uygur
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     38.815440547   -15.385366183   -22.430074363
#       std. errors:    35.603    15.352    20.670
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.016         0.88349   -20.515     9.682    11.833  infeasible
#           001  1     8    16.622        0.034292    -7.499     8.499     0.000  infeasible
#           010  1     8    11.637        0.168128    14.843    -0.000   -13.843  infeasible
#           100  1     8    43.339     7.58428e-07    -0.000     4.279    -3.279  infeasible
#           011  2     9   175.088               0     1.000     0.000     0.000
#           101  2     9   125.143     1.17951e-22     0.000     1.000     0.000
#           110  2     9   197.840               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):    13.606 p-value for nested model:     0.000225471
# best pat:          101      1.17951e-22  chi(nested):   108.521 p-value for nested model:     2.06627e-25
# left pops:
# Japanese
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:   -471.372236141   201.186266042   271.185970099
#       std. errors:   127.374    54.476    73.148
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.293        0.856622    29.412   -11.970   -16.442  infeasible
#           001  1     8    17.439       0.0258508     6.624    -5.624     0.000  infeasible
#           010  1     8    10.630        0.223561     5.464    -0.000    -4.464  infeasible
#           100  1     8    49.092     6.10358e-08     0.000     4.394    -3.394  infeasible
#           011  2     9    62.295     4.83114e-10     1.000    -0.000    -0.000
#           101  2     9    71.872     6.53093e-12     0.000     1.000    -0.000
#           110  2     9    87.766     4.56569e-15     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):    14.146 p-value for nested model:      0.00016919
# best pat:          011      4.83114e-10  chi(nested):    44.856 p-value for nested model:     2.12033e-11
# left pops:
# Korean
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     54.973536238   -23.191265011   -30.782271227
#       std. errors:    22.075     9.527    12.635
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.210        0.864871    -6.840     3.310     4.530  infeasible
#           001  1     8    11.476        0.176143     1.560    -0.560    -0.000  infeasible
#           010  1     8    10.553        0.228321     2.216    -0.000    -1.216  infeasible
#           100  1     8    14.333       0.0734792     0.000     0.324     0.676
#           011  2     9    15.174        0.086256     1.000    -0.000     0.000
#           101  2     9    33.819      9.6074e-05     0.000     1.000     0.000
#           110  2     9    20.103       0.0172879     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100        0.0734792  chi(nested):    11.123 p-value for nested model:      0.00085269
# best pat:          011         0.086256  chi(nested):     0.841 p-value for nested model:        0.359111
# left pops:
# Han
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:    357.781529052  -152.790639499  -203.990889552
#       std. errors:    75.330    32.370    43.036
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.325        0.853372   -11.309     5.176     7.133  infeasible
#           001  1     8     9.503        0.301665     1.459    -0.459    -0.000  infeasible
#           010  1     8    10.132        0.255881     1.804    -0.000    -0.804  infeasible
#           100  1     8    14.408       0.0717387     0.000     0.268     0.732
#           011  2     9    12.856        0.169248     1.000    -0.000     0.000
#           101  2     9    42.378     2.80274e-06     0.000     1.000     0.000
#           110  2     9    18.960       0.0255345     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100        0.0717387  chi(nested):    11.082 p-value for nested model:     0.000871497
# best pat:          011         0.169248  chi(nested):    -1.552 p-value for nested model:            -nan
# left pops:
# She
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:    284.968776207  -121.281182767  -162.687593440
#       std. errors:    67.655    29.005    38.747
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.292        0.856746   -12.685     5.853     7.833  infeasible
#           001  1     8    12.680        0.123343     1.531    -0.531     0.000  infeasible
#           010  1     8    10.095        0.258447     2.294     0.000    -1.294  infeasible
#           100  1     8    16.493       0.0358433     0.000     0.428     0.572
#           011  2     9    15.303       0.0829397     1.000    -0.000     0.000
#           101  2     9    32.018     0.000197716     0.000     1.000     0.000
#           110  2     9    25.539      0.00242904     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100        0.0358433  chi(nested):    13.201 p-value for nested model:     0.000279791
# best pat:          011        0.0829397  chi(nested):    -1.190 p-value for nested model:            -nan
# left pops:
# Miao
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:    105.659021284   -44.446051594   -60.212969691
#       std. errors:    30.150    12.872    17.339
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.258        0.860148    -6.651     3.302     4.349  infeasible
#           001  1     8     8.566        0.380217     1.142    -0.142     0.000  infeasible
#           010  1     8     7.755        0.457758     1.440    -0.000    -0.440  infeasible
#           100  1     8     9.488        0.302801     0.000     0.436     0.564
#           011  2     9     8.903        0.446239     1.000    -0.000     0.000
#           101  2     9    27.379       0.0012106     0.000     1.000     0.000
#           110  2     9    20.051       0.0176022     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.302801  chi(nested):     6.230 p-value for nested model:       0.0125596
# best pat:          011         0.446239  chi(nested):    -0.585 p-value for nested model:            -nan
# left pops:
# Tujia
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     95.258071393   -40.260702135   -53.997369259
#       std. errors:    27.862    11.953    15.969
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.288        0.857138    -6.279     3.102     4.176  infeasible
#           001  1     8     8.499        0.386334     1.205    -0.205     0.000  infeasible
#           010  1     8     8.434        0.392278     1.384    -0.000    -0.384  infeasible
#           100  1     8     9.261        0.320786     0.000     0.415     0.585
#           011  2     9     9.229         0.41637     1.000    -0.000     0.000
#           101  2     9    30.599     0.000346794     0.000     1.000     0.000
#           110  2     9    20.228       0.0165577     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.320786  chi(nested):     5.973 p-value for nested model:       0.0145298
# best pat:          011          0.41637  chi(nested):    -0.031 p-value for nested model:            -nan
# left pops:
# Han_ShandongX
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      9.254440874    -3.750740291    -4.503700582
#       std. errors:     7.001     3.081     3.983
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.971        0.887637    -3.135     1.630     2.506  infeasible
#           001  1     8     8.986        0.343453     1.512    -0.512    -0.000  infeasible
#           010  1     8    12.115        0.146127     3.649    -0.000    -2.649  infeasible
#           100  1     8     8.944        0.347031     0.000     0.251     0.749
#           011  2     9    13.572        0.138381     1.000    -0.000     0.000
#           101  2     9    44.201     1.29441e-06     0.000     1.000     0.000
#           110  2     9    13.719        0.132684     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.347031  chi(nested):     5.973 p-value for nested model:       0.0145286
# best pat:          011         0.138381  chi(nested):     4.628 p-value for nested model:       0.0314549
# left pops:
# Han_GansuX
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     84.694726056   -35.875830986   -47.818895070
#       std. errors:    27.467    11.806    15.732
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.251        0.860891    -6.875     3.306     4.569  infeasible
#           001  1     8     8.941        0.347335     1.364    -0.364     0.000  infeasible
#           010  1     8     9.997        0.265207     1.588    -0.000    -0.588  infeasible
#           100  1     8    10.949        0.204591     0.000     0.346     0.654
#           011  2     9    11.193        0.262713     1.000    -0.000     0.000
#           101  2     9    36.249     3.58137e-05     0.000     1.000     0.000
#           110  2     9    18.682       0.0280323     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.204591  chi(nested):     7.699 p-value for nested model:      0.00552622
# best pat:          011         0.262713  chi(nested):     0.244 p-value for nested model:        0.621532
# left pops:
# Han_GuangdongX
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:    201.403434144   -85.880349001  -114.523085143
#       std. errors:    56.225    24.197    32.135
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.266        0.859383   -11.951     5.530     7.421  infeasible
#           001  1     8    13.210        0.104834     1.575    -0.575    -0.000  infeasible
#           010  1     8    10.330        0.242643     2.470    -0.000    -1.470  infeasible
#           100  1     8    15.945        0.043174     0.000     0.368     0.632
#           011  2     9    15.335       0.0821238     1.000    -0.000     0.000
#           101  2     9    31.921     0.000205447     0.000     1.000     0.000
#           110  2     9    22.504      0.00741302     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.043174  chi(nested):    12.679 p-value for nested model:     0.000369726
# best pat:          011        0.0821238  chi(nested):    -0.610 p-value for nested model:            -nan
# left pops:
# Han_HenanX
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      4.649710814    -1.615709908    -2.034000906
#       std. errors:     4.779     2.087     2.752
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.849        0.898627    -2.450     1.427     2.023  infeasible
#           001  1     8    10.050        0.261502     1.373    -0.373    -0.000  infeasible
#           010  1     8    10.745        0.216576     1.776    -0.000    -0.776  infeasible
#           100  1     8     8.876        0.352867     0.000     0.363     0.637
#           011  2     9    12.557        0.183678     1.000    -0.000     0.000
#           101  2     9    36.706     2.96992e-05     0.000     1.000     0.000
#           110  2     9    19.177       0.0237318     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.352867  chi(nested):     6.027 p-value for nested model:       0.0140874
# best pat:          011         0.183678  chi(nested):     3.681 p-value for nested model:       0.0550223
# left pops:
# Han_JiangsuX
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      3.280141635    -1.077031900    -1.203109735
#       std. errors:     5.357     2.371     3.085
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.719        0.909719    -3.480     1.837     2.642  infeasible
#           001  1     8    13.020        0.111149     1.822    -0.822     0.000  infeasible
#           010  1     8    12.329        0.137125    11.816    -0.000   -10.816  infeasible
#           100  1     8    16.483       0.0359691     0.000     0.278     0.722
#           011  2     9    20.615       0.0144738     1.000    -0.000     0.000
#           101  2     9    42.015     3.26563e-06     0.000     1.000     0.000
#           110  2     9    20.964       0.0128119     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100        0.0359691  chi(nested):    13.764 p-value for nested model:     0.000207304
# best pat:          011        0.0144738  chi(nested):     4.132 p-value for nested model:       0.0420722
# left pops:
# Han_SichuanX
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     27.031108347   -11.095149217   -14.935959130
#       std. errors:    12.650     5.438     7.272
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.168        0.869007    -4.263     2.260     3.003  infeasible
#           001  1     8     9.567        0.296715     1.196    -0.196     0.000  infeasible
#           010  1     8     8.527        0.383766     1.528    -0.000    -0.528  infeasible
#           100  1     8    10.045        0.261886     0.000     0.420     0.580
#           011  2     9    10.287         0.32773     1.000    -0.000     0.000
#           101  2     9    32.357     0.000172695     0.000     1.000     0.000
#           110  2     9    23.238      0.00568336     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.261886  chi(nested):     6.877 p-value for nested model:      0.00873304
# best pat:          011          0.32773  chi(nested):     0.242 p-value for nested model:        0.622499
# left pops:
# Lahu
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      2.397839726    -0.247493510    -1.150346217
#       std. errors:     3.974     1.728     2.319
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.583        0.920738    -2.479     1.808     1.671  infeasible
#           001  1     8    11.774        0.161553     0.122     0.878     0.000
#           010  1     8     6.793        0.559097     2.351    -0.000    -1.351  infeasible
#           100  1     8     9.390        0.310493    -0.000     0.784     0.216
#           011  2     9    21.845      0.00938353     1.000    -0.000     0.000
#           101  2     9    11.903        0.218854     0.000     1.000     0.000
#           110  2     9    43.535     1.71676e-06     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.310493  chi(nested):     6.807 p-value for nested model:      0.00908023
# best pat:          101         0.218854  chi(nested):     2.513 p-value for nested model:        0.112918
# left pops:
# Dai
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     16.424391238    -6.167325184    -9.257066054
#       std. errors:     8.678     3.692     5.033
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.076        0.877917    -3.010     1.981     2.028  infeasible
#           001  1     8     9.967        0.267385     0.501     0.499     0.000
#           010  1     8     5.562        0.696187     1.923    -0.000    -0.923  infeasible
#           100  1     8     7.325        0.502052     0.000     0.688     0.312
#           011  2     9    14.822       0.0959499     1.000    -0.000     0.000
#           101  2     9    13.607        0.137024     0.000     1.000     0.000
#           110  2     9    41.303     4.40449e-06     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.502052  chi(nested):     4.249 p-value for nested model:       0.0392752
# best pat:          101         0.137024  chi(nested):     6.282 p-value for nested model:       0.0121969
# left pops:
# Ami
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:    176.267925652   -74.576265598  -100.691660054
#       std. errors:    42.629    18.255    24.438
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.274        0.858507    -7.962     4.084     4.878  infeasible
#           001  1     8    13.285        0.102416     0.715     0.285     0.000
#           010  1     8     6.192        0.625712     1.967    -0.000    -0.967  infeasible
#           100  1     8    10.933        0.205498     0.000     0.728     0.272
#           011  2     9    13.803         0.12952     1.000    -0.000     0.000
#           101  2     9    14.599        0.102549     0.000     1.000     0.000
#           110  2     9    37.633     2.02845e-05     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.205498  chi(nested):     7.659 p-value for nested model:       0.0056489
# best pat:          011          0.12952  chi(nested):     2.869 p-value for nested model:       0.0902891
# left pops:
# Atayal
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:   -134.550553424    58.345621076    77.204932347
#       std. errors:    31.350    13.487    17.900
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.253        0.860657     5.526    -1.676    -2.850  infeasible
#           001  1     8     6.291        0.614644     0.572     0.428     0.000
#           010  1     8     3.847        0.870634     1.718    -0.000    -0.718  infeasible
#           100  1     8     7.077        0.528333     0.000     0.718     0.282
#           011  2     9     8.719        0.463622     1.000    -0.000     0.000
#           101  2     9    10.977        0.277259     0.000     1.000     0.000
#           110  2     9    31.048     0.000290437     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001         0.614644  chi(nested):     3.038 p-value for nested model:       0.0813222
# best pat:          011         0.463622  chi(nested):     2.428 p-value for nested model:        0.119215
# left pops:
# Naxi
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      1.742511312    -0.207132732    -0.535378580
#       std. errors:     2.941     1.289     1.706
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.569        0.921844    -1.731     1.271     1.460  infeasible
#           001  1     8    11.292        0.185673     0.934     0.066    -0.000
#           010  1     8     7.752        0.458101     1.684    -0.000    -0.684  infeasible
#           100  1     8     7.218        0.513263     0.000     0.517     0.483
#           011  2     9    11.340        0.253137     1.000    -0.000     0.000
#           101  2     9    21.714      0.00983269     0.000     1.000     0.000
#           110  2     9    27.323      0.00123681     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.513263  chi(nested):     4.650 p-value for nested model:       0.0310569
# best pat:          011         0.253137  chi(nested):     4.121 p-value for nested model:       0.0423449
# left pops:
# Yi
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     -0.239456716     0.604131621     0.635325095
#       std. errors:     0.851     0.392     0.515
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     0.742        0.997989    -0.731     0.820     0.911  infeasible
#           001  1     8    10.984          0.2026     0.771     0.229     0.000
#           010  1     8     8.707        0.367636     1.646    -0.000    -0.646  infeasible
#           100  1     8     3.211        0.920395     0.000     0.524     0.476
#           011  2     9    11.446         0.24637     1.000    -0.000     0.000
#           101  2     9    18.068       0.0343973     0.000     1.000     0.000
#           110  2     9    23.227      0.00570604     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.920395  chi(nested):     2.469 p-value for nested model:          0.1161
# best pat:          011          0.24637  chi(nested):     8.235 p-value for nested model:      0.00411001
# left pops:
# Tibetan_ShannanX
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     -0.046467561     0.540897227     0.505570334
#       std. errors:     1.348     0.608     0.797
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     1.683        0.975287    -1.115     0.992     1.123  infeasible
#           001  1     8    12.748        0.120828     1.002    -0.002     0.000  infeasible
#           010  1     8     8.721        0.366338     1.797    -0.000    -0.797  infeasible
#           100  1     8     6.583        0.582271     0.000     0.513     0.487
#           011  2     9    12.746        0.174434     1.000    -0.000     0.000
#           101  2     9    23.482      0.00519904     0.000     1.000     0.000
#           110  2     9    29.094     0.000624877     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.582271  chi(nested):     4.899 p-value for nested model:       0.0268657
# best pat:          011         0.174434  chi(nested):     6.164 p-value for nested model:       0.0130403
# left pops:
# Tibetan_LhasaX
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     -0.546775425     0.806475778     0.740299647
#       std. errors:     1.083     0.506     0.656
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     0.792        0.997521    -1.193     1.082     1.111  infeasible
#           001  1     8    17.851       0.0223707     0.340     0.660     0.000
#           010  1     8     9.910        0.271427     2.397    -0.000    -1.397  infeasible
#           100  1     8     8.089        0.424782     0.000     0.600     0.400
#           011  2     9    18.388       0.0309311     1.000    -0.000     0.000
#           101  2     9    17.715       0.0386289     0.000     1.000     0.000
#           110  2     9    32.486     0.000164044     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.424782  chi(nested):     7.297 p-value for nested model:      0.00690667
# best pat:          101        0.0386289  chi(nested):     9.625 p-value for nested model:      0.00191898
# left pops:
# Tibetan_NagquX
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     -0.029250841     0.527459576     0.501791265
#       std. errors:     1.310     0.590     0.774
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     1.539        0.980944    -1.005     0.941     1.064  infeasible
#           001  1     8    11.750        0.162716     0.930     0.070     0.000
#           010  1     8     8.753        0.363543     1.718    -0.000    -0.718  infeasible
#           100  1     8     4.945        0.763402     0.000     0.516     0.484
#           011  2     9    11.791        0.225346     1.000    -0.000     0.000
#           101  2     9    21.084       0.0122806     0.000     1.000     0.000
#           110  2     9    25.116      0.00284569     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.763402  chi(nested):     3.407 p-value for nested model:       0.0649296
# best pat:          011         0.225346  chi(nested):     6.846 p-value for nested model:      0.00888536
# left pops:
# Tibetan_ShigatseX
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      1.018966901     0.099973155    -0.118940056
#       std. errors:     2.863     1.258     1.670
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.461        0.929969    -1.990     1.371     1.619  infeasible
#           001  1     8    14.746       0.0642858     1.307    -0.307     0.000  infeasible
#           010  1     8     9.044        0.338604     2.033     0.000    -1.033  infeasible
#           100  1     8    10.786          0.2141     0.000     0.521     0.479
#           011  2     9    15.457       0.0791189     1.000     0.000     0.000
#           101  2     9    25.806      0.00219782     0.000     1.000     0.000
#           110  2     9    32.895     0.000139267     0.000     0.000     1.000
# best pat:          000                0              -  -
# best pat:          100           0.2141  chi(nested):     8.325 p-value for nested model:      0.00391058
# best pat:          011        0.0791189  chi(nested):     4.671 p-value for nested model:        0.030679
# left pops:
# Tibetan_ChamdoX
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      0.380121464     0.285738168     0.334140368
#       std. errors:     1.505     0.678     0.876
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.033         0.95799    -1.014     0.879     1.135  infeasible
#           001  1     8     9.527        0.299811     1.086    -0.086     0.000  infeasible
#           010  1     8     8.423        0.393304     1.405    -0.000    -0.405  infeasible
#           100  1     8     5.315        0.723403    -0.000     0.436     0.564
#           011  2     9     9.671        0.377735     1.000    -0.000     0.000
#           101  2     9    28.777     0.000706671     0.000     1.000     0.000
#           110  2     9    20.996       0.0126674     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.723403  chi(nested):     3.282 p-value for nested model:       0.0700307
# best pat:          011         0.377735  chi(nested):     4.356 p-value for nested model:        0.036877
# left pops:
# Tibetan
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     -0.257423562     0.720483366     0.536940196
#       std. errors:     1.401     0.631     0.839
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     1.385        0.986015    -1.257     1.143     1.114  infeasible
#           001  1     8    13.899       0.0844372     0.554     0.446     0.000
#           010  1     8     8.791        0.360251     2.130    -0.000    -1.130  infeasible
#           100  1     8     6.470        0.594772     0.000     0.616     0.384
#           011  2     9    15.156       0.0867508     1.000    -0.000     0.000
#           101  2     9    15.074       0.0889198     0.000     1.000     0.000
#           110  2     9    33.234     0.000121606     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.594772  chi(nested):     5.084 p-value for nested model:       0.0241432
# best pat:          101        0.0889198  chi(nested):     8.604 p-value for nested model:      0.00335344
# left pops:
# Sherpa
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      2.052403030    -0.412219758    -0.640183272
#       std. errors:     3.722     1.630     2.169
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.513        0.926134    -2.451     1.495     1.956  infeasible
#           001  1     8    13.501         0.09575     1.313    -0.313     0.000  infeasible
#           010  1     8    10.422        0.236666     2.125    -0.000    -1.125  infeasible
#           100  1     8    10.709        0.218712     0.000     0.457     0.543
#           011  2     9    14.326         0.11119     1.000    -0.000     0.000
#           101  2     9    25.904      0.00211793     0.000     1.000     0.000
#           110  2     9    24.095      0.00415436     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.218712  chi(nested):     8.197 p-value for nested model:      0.00419665
# best pat:          011          0.11119  chi(nested):     3.617 p-value for nested model:       0.0572047
# left pops:
# Sherpa_ShigatseX
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     -0.202993154     0.778165883     0.424827271
#       std. errors:     2.515     1.116     1.496
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.025        0.958469    -2.349     1.682     1.667  infeasible
#           001  1     8    16.289       0.0384287    -0.696     1.696     0.000  infeasible
#           010  1     8     9.126        0.331765     2.727    -0.000    -1.727  infeasible
#           100  1     8    14.862       0.0618774     0.000     0.772     0.228
#           011  2     9    25.240      0.00271725     1.000     0.000     0.000
#           101  2     9    17.701       0.0388022     0.000     1.000     0.000
#           110  2     9    55.552     9.55842e-09     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100        0.0618774  chi(nested):    12.838 p-value for nested model:     0.000339683
# best pat:          101        0.0388022  chi(nested):     2.839 p-value for nested model:       0.0920093
# left pops:
# Kinh
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      4.327232687    -1.188774082    -2.138458606
#       std. errors:     5.030     2.176     2.926
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.754        0.906771    -2.801     1.824     1.977  infeasible
#           001  1     8    16.159       0.0401567     0.516     0.484     0.000
#           010  1     8     7.686        0.464708     2.115    -0.000    -1.115  infeasible
#           100  1     8    10.970        0.203384    -0.000     0.650     0.350
#           011  2     9    16.803       0.0518902     1.000    -0.000     0.000
#           101  2     9    16.941       0.0496427     0.000     1.000     0.000
#           110  2     9    33.208     0.000122862     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.203384  chi(nested):     8.216 p-value for nested model:      0.00415194
# best pat:          011        0.0518902  chi(nested):     5.833 p-value for nested model:       0.0157306
# left pops:
# Htin_Mal
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      2.454122977    -0.304793321    -1.149329656
#       std. errors:     4.251     2.337     2.013
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.519        0.925674    -2.502     2.382     1.120  infeasible
#           001  1     8     5.202        0.735834    -0.558     1.558     0.000  infeasible
#           010  1     8     7.001        0.536493     2.307    -0.000    -1.307  infeasible
#           100  1     8     7.253         0.50956    -0.000     1.099    -0.099  infeasible
#           011  2     9    28.343     0.000835702     1.000    -0.000     0.000
#           101  2     9     7.717        0.562878     0.000     1.000     0.000
#           110  2     9    66.421     7.63009e-11     0.000     0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     2.683 p-value for nested model:        0.101441
# best pat:          101         0.562878  chi(nested):     2.516 p-value for nested model:        0.112721
# left pops:
# Mlabri
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      4.954338582    -1.434260271    -2.520078311
#       std. errors:     5.378     2.926     2.541
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.551        0.923179    -2.708     2.657     1.051  infeasible
#           001  1     8     4.095        0.848426    -0.766     1.766     0.000  infeasible
#           010  1     8     6.642        0.575693     2.578    -0.000    -1.578  infeasible
#           100  1     8     6.859        0.551917    -0.000     1.232    -0.232  infeasible
#           011  2     9    33.065     0.000130091     1.000    -0.000     0.000
#           101  2     9     9.371        0.403746     0.000     1.000     0.000
#           110  2     9    69.234     2.15111e-11     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     1.544 p-value for nested model:        0.214037
# best pat:          101         0.403746  chi(nested):     5.276 p-value for nested model:       0.0216234
# left pops:
# Cambodian
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      3.273678389    -0.155231042    -2.118447347
#       std. errors:     5.825     2.497     3.437
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.584        0.920676    -3.982     2.878     2.103  infeasible
#           001  1     8     6.927        0.544506    -0.768     1.768     0.000  infeasible
#           010  1     8     6.307        0.612838     3.582    -0.000    -2.582  infeasible
#           100  1     8    10.661        0.221666     0.000     1.332    -0.332  infeasible
#           011  2     9    64.646     1.69086e-10     1.000     0.000     0.000
#           101  2     9    17.263       0.0447552     0.000     1.000     0.000
#           110  2     9   108.447     3.04349e-19     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     4.344 p-value for nested model:       0.0371467
# best pat:          101        0.0447552  chi(nested):    10.336 p-value for nested model:      0.00130485
# left pops:
# Thai
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      1.338424351     0.284646023    -0.623070374
#       std. errors:     2.841     1.214     1.683
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.325        0.939671    -1.696     1.560     1.136  infeasible
#           001  1     8     6.840        0.553966     0.039     0.961     0.000
#           010  1     8     6.216        0.623053     2.385     0.000    -1.385  infeasible
#           100  1     8     5.917        0.656504     0.000     0.878     0.122
#           011  2     9    23.565      0.00504462     1.000    -0.000     0.000
#           101  2     9     6.861         0.65163     0.000     1.000     0.000
#           110  2     9    54.987     1.22518e-08     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.656504  chi(nested):     3.592 p-value for nested model:       0.0580598
# best pat:          101          0.65163  chi(nested):     0.943 p-value for nested model:        0.331409
# left pops:
# Burmese
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      1.361399312     0.337948031    -0.699347343
#       std. errors:     3.094     1.312     1.847
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.336        0.938913    -1.967     1.719     1.248  infeasible
#           001  1     8     6.391        0.603557    -0.069     1.069     0.000  infeasible
#           010  1     8     6.324        0.611026     2.548    -0.000    -1.548  infeasible
#           100  1     8     6.311        0.612403    -0.000     0.945     0.055
#           011  2     9    28.250     0.000866391     1.000    -0.000     0.000
#           101  2     9     6.486        0.690416     0.000     1.000     0.000
#           110  2     9    61.533     6.78467e-10     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.612403  chi(nested):     3.975 p-value for nested model:       0.0461793
# best pat:          101         0.690416  chi(nested):     0.175 p-value for nested model:        0.675594
# left pops:
# Tianyuan
# Bbdong
# LiangDaoF
# HDYM1
#
# ##PARAMETER NAME: VALUE
# genotypename: /mnt/solexa/mel_yang/data/2.2M/UPA19_3.geno
# left pops:
# La368_G1
# Bbdong
# LiangDaoF
# HDYM1
#
# ##PARAMETER NAME: VALUE
# genotypename: /mnt/solexa/mel_yang/data/2.2M/UPA19_3.geno
# left pops:
# JomonM
# Bbdong
# LiangDaoF
# HDYM1
#
# ##PARAMETER NAME: VALUE
# genotypename: /mnt/solexa/mel_yang/data/2.2M/UPA19_3.geno
# left pops:
# Kolyma_River
# Bbdong
# LiangDaoF
# HDYM1
#
# ##PARAMETER NAME: VALUE
# genotypename: /mnt/solexa/mel_yang/data/2.2M/UPA19_3.geno
# left pops:
# DevilsGate
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:    -58.454920040     8.154534971    51.300385069
#       std. errors:    13.413     2.161    11.397
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.311         0.85482     2.049    -0.700    -0.350  infeasible
#           001  1     8     3.327        0.912229     1.634    -0.634    -0.000  infeasible
#           010  1     8     3.952         0.86145    -7.795    -0.000     8.795  infeasible
#           100  1     8     4.802         0.77852     0.000    -0.290     1.290  infeasible
#           011  2     9     6.133        0.726564     1.000    -0.000    -0.000
#           101  2     9    21.391       0.0110225     0.000     1.000    -0.000
#           110  2     9     5.778        0.761902     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     0.016 p-value for nested model:         0.90086
# best pat:          110         0.761902  chi(nested):     2.452 p-value for nested model:        0.117404
# ### THE INPUT PARAMETERS
# ##PARAMETER NAME: VALUE
# genotypename: /mnt/solexa/mel_yang/data/2.2M/UPA19_3.geno
# snpname: /mnt/solexa/mel_yang/data/2.2M/UPA19_3.snp
# indivname: /mnt/solexa/mel_yang/data/2.2M/UPA19_3.qpadmmerge1.ind
# popleft: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_3s/UPA19_3.adm.A_3S_HDYM1_Bbdong_LiangDaoF_HDYM1_out0.leftpop
# ##PARAMETER NAME: VALUE
# genotypename: /mnt/solexa/mel_yang/data/2.2M/UPA19_3.geno
# left pops:
# ZongriM297
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:    301.339108443  -120.164001218  -180.175107225
#       std. errors:    80.075    32.155    48.120
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.870        0.896799   -15.927     6.767    10.161  infeasible
#           001  1     8    12.019        0.150342     2.563    -1.563     0.000  infeasible
#           010  1     8     8.533        0.383221     7.536     0.000    -6.536  infeasible
#           100  1     8    19.417       0.0127827     0.000     0.240     0.760
#           011  2     9    18.006        0.035109     1.000     0.000     0.000
#           101  2     9    28.340     0.000836569     0.000     1.000     0.000
#           110  2     9    20.770       0.0137139     0.000     0.000     1.000
# best pat:          000                0              -  -
# best pat:          100        0.0127827  chi(nested):    16.547 p-value for nested model:     4.74536e-05
# best pat:          011         0.035109  chi(nested):    -1.411 p-value for nested model:            -nan
# left pops:
# Hejiatai
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:   8478.041547474 -4267.121615312 -4209.919932161
#       std. errors:  7377.693  3657.956  3720.794
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     1.461        0.983641   -52.462    26.537    26.925  infeasible
#           001  1     8     6.793        0.559082     2.221    -1.221     0.000  infeasible
#           010  1     8     8.172        0.416843     2.236     0.000    -1.236  infeasible
#           100  1     8    13.657       0.0911644     0.000     0.398     0.602
#           011  2     9    10.666         0.29933     1.000    -0.000     0.000
#           101  2     9    20.568       0.0147155     0.000     1.000     0.000
#           110  2     9    16.837       0.0513287     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100        0.0911644  chi(nested):    12.196 p-value for nested model:     0.000478906
# best pat:          011          0.29933  chi(nested):    -2.991 p-value for nested model:            -nan
# left pops:
# Chokhopani
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     -0.591550851     0.793357987     0.798192864
#       std. errors:     1.859     0.856     1.107
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     1.323        0.987821    -1.940     1.380     1.560  infeasible
#           001  1     8    14.881        0.061498     0.572     0.428     0.000
#           010  1     8     9.890        0.272825     2.418    -0.000    -1.418  infeasible
#           100  1     8     9.846        0.275996     0.000     0.604     0.396
#           011  2     9    15.269        0.083799     1.000    -0.000     0.000
#           101  2     9    14.982       0.0914374     0.000     1.000     0.000
#           110  2     9    24.450      0.00364406     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.275996  chi(nested):     8.523 p-value for nested model:      0.00350622
# best pat:          101        0.0914374  chi(nested):     5.136 p-value for nested model:       0.0234384
# left pops:
# Shamanka_EN
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      2.883805964    -1.546408639    -0.337397325
#       std. errors:     6.257     2.955     3.428
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.389        0.935221    -4.530     1.867     3.664  infeasible
#           001  1     8     9.176        0.327631     2.897    -1.897     0.000  infeasible
#           010  1     8     6.590        0.581433    -1.291    -0.000     2.291  infeasible
#           100  1     8    15.373       0.0522778     0.000    -0.366     1.366  infeasible
#           011  2     9    63.875     2.38703e-10     1.000    -0.000     0.000
#           101  2     9   112.569     4.40637e-20     0.000     1.000     0.000
#           110  2     9    24.249      0.00392468     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     6.787 p-value for nested model:      0.00918015
# best pat:          110       0.00392468  chi(nested):    15.072 p-value for nested model:     0.000103462
# qpAdm: parameter file: UPA19_3.adm.A_3S_Bbdong_Bbdong_LiangDaoF_HDYM1_out0.par
# left pops:
# Boshan
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      2.054170423    -0.477752675    -0.576417748
#       std. errors:     5.761     2.479     3.421
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.348        0.938112    -4.337     2.182     3.155  infeasible
#           001  1     8    15.758       0.0459723     2.308    -1.308     0.000  infeasible
#           010  1     8    11.537        0.173084   -68.482    -0.000    69.482  infeasible
#           100  1     8    18.499       0.0177835     0.000     0.294     0.706
#           011  2     9    23.223      0.00571541     1.000    -0.000     0.000
#           101  2     9    33.722     9.99081e-05     0.000     1.000     0.000
#           110  2     9    21.674      0.00997215     0.000    -0.000     1.000
# best pat:          000                0              -  -
# ...
# left pops:
# Atayal
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:   -134.550553424    58.345621076    77.204932347
#       std. errors:    31.350    13.487    17.900
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.253        0.860657     5.526    -1.676    -2.850  infeasible
#           001  1     8     6.291        0.614644     0.572     0.428     0.000
#           010  1     8     3.847        0.870634     1.718    -0.000    -0.718  infeasible
#           100  1     8     7.077        0.528333     0.000     0.718     0.282
#           011  2     9     8.719        0.463622     1.000    -0.000     0.000
#           101  2     9    10.977        0.277259     0.000     1.000     0.000
#           110  2     9    31.048     0.000290437     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001         0.614644  chi(nested):     3.038 p-value for nested model:       0.0813222
# best pat:          011         0.463622  chi(nested):     2.428 p-value for nested model:        0.119215
# left pops:
# Man_Bac
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      0.605849856     0.723961279    -0.329811136
#       std. errors:     3.968     2.209     1.903
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.724        0.909299     4.384    -1.297    -2.087  infeasible
#           001  1     8    12.056        0.148727    -4.160     5.160     0.000  infeasible
#           010  1     8     4.273        0.831659     2.338    -0.000    -1.338  infeasible
#           100  1     8    16.877       0.0314173    -0.000     1.567    -0.567  infeasible
#           011  2     9    33.565     0.000106418     1.000    -0.000     0.000
#           101  2     9    25.505      0.00246065     0.000     1.000     0.000
#           110  2     9    87.916     4.26081e-15     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     9.332 p-value for nested model:       0.0022521
# best pat:          101       0.00246065  chi(nested):    13.449 p-value for nested model:     0.000245146
# left pops:
# Nui_Nap
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     38.923705212    -8.525779041   -29.397926171
#       std. errors:    19.096     4.502    14.768
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     2.043        0.957442    -7.137     1.964     6.174  infeasible
#           001  1     8    13.332        0.100912     1.030    -0.030     0.000  infeasible
#           010  1     8     4.345        0.824703     9.767    -0.000    -8.767  infeasible
#           100  1     8    13.458       0.0970193     0.000     0.370     0.630
#           011  2     9    13.345         0.14762     1.000    -0.000     0.000
#           101  2     9    27.330      0.00123308     0.000     1.000     0.000
#           110  2     9    17.482       0.0416883     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100        0.0970193  chi(nested):    11.416 p-value for nested model:     0.000728221
# best pat:          011          0.14762  chi(nested):    -0.114 p-value for nested model:            -nan
# left pops:
# Oakaie1
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     -0.545109472     1.003267905     0.541841567
#       std. errors:     1.010     0.604     0.534
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     4.154        0.761886    -1.077     1.310     0.767  infeasible
#           001  1     8    10.129        0.256095    -0.181     1.181     0.000  infeasible
#           010  1     8    15.021       0.0587469     2.711    -0.000    -1.711  infeasible
#           100  1     8     8.569        0.379931     0.000     0.785     0.215
#           011  2     9    19.005        0.025151     1.000    -0.000     0.000
#           101  2     9    10.313        0.325742     0.000     1.000     0.000
#           110  2     9    27.648      0.00109196     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.379931  chi(nested):     4.415 p-value for nested model:       0.0356192
# best pat:          101         0.325742  chi(nested):     1.744 p-value for nested model:         0.18665
# left pops:
# Ban_Chiang
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:  19900.375374726 -12030.471203293 -7868.904171432
#       std. errors: 15591.118  9522.177  6071.695
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     7.615        0.367758    35.263   -20.978   -13.286  infeasible
#           001  1     8     9.836        0.276694     4.069    -3.069    -0.000  infeasible
#           010  1     8    14.489       0.0698795     4.975    -0.000    -3.975  infeasible
#           100  1     8    22.383      0.00425323     0.000     0.908     0.092
#           011  2     9    19.310       0.0226817     1.000    -0.000     0.000
#           101  2     9    22.447      0.00756426     0.000     1.000     0.000
#           110  2     9    24.415      0.00369093     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100       0.00425323  chi(nested):    14.768 p-value for nested model:     0.000121568
# best pat:          011        0.0226817  chi(nested):    -3.073 p-value for nested model:            -nan
# left pops:
# Vt833_G2
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:   -189.493425415   125.127465544    65.365959871
#       std. errors:    63.017    41.334    22.183
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     5.183        0.637661    16.223    -9.586    -5.637  infeasible
#           001  1     8     7.661        0.467225    17.186   -16.186     0.000  infeasible
#           010  1     8    10.058        0.261007     3.165    -0.000    -2.165  infeasible
#           100  1     8    19.287        0.013397    -0.000     2.713    -1.713  infeasible
#           011  2     9    27.974     0.000963299     1.000    -0.000     0.000
#           101  2     9    31.503     0.000242638     0.000     1.000     0.000
#           110  2     9    45.801     6.55728e-07     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     2.479 p-value for nested model:        0.115409
# best pat:          011      0.000963299  chi(nested):    20.313 p-value for nested model:     6.57512e-06
# left pops:
# Vt880_G2
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      2.391117044    -0.975555590    -0.415561454
#       std. errors:     3.968     2.725     1.699
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     4.278        0.747244    -2.637     2.410     1.227  infeasible
#           001  1     8     6.110        0.634918    -2.699     3.699     0.000  infeasible
#           010  1     8    10.615        0.224472     2.501     0.000    -1.501  infeasible
#           100  1     8    10.902        0.207286    -0.000     0.973     0.027
#           011  2     9    13.744         0.13173     1.000     0.000     0.000
#           101  2     9    10.904        0.282313     0.000     1.000     0.000
#           110  2     9    18.770       0.0272231     0.000     0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.207286  chi(nested):     6.624 p-value for nested model:       0.0100593
# best pat:          101         0.282313  chi(nested):     0.002 p-value for nested model:        0.964355
# left pops:
# La727_G2
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:    -98.109719909    35.800607507    63.309112402
#       std. errors:    15.484     5.752     9.757
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.928        0.788014    -0.588     1.247     0.341  infeasible
#           001  1     8     4.049        0.852641    -0.032     1.032     0.000  infeasible
#           010  1     8     4.120        0.846155     2.701    -0.000    -1.701  infeasible
#           100  1     8     4.059        0.851763    -0.000     1.003    -0.003  infeasible
#           011  2     9    13.049        0.160379     1.000     0.000     0.000
#           101  2     9     4.056        0.907709     0.000     1.000     0.000
#           110  2     9    22.607      0.00714124     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     0.121 p-value for nested model:        0.727709
# best pat:          101         0.907709  chi(nested):     0.006 p-value for nested model:        0.936735
# left pops:
# Ma912_G2
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:      8.471168378    -2.588181573    -4.882986805
#       std. errors:    11.111     5.117     6.214
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.479        0.837445    -6.898     4.360     3.538  infeasible
#           001  1     8     9.100        0.333908    -1.810     2.810     0.000  infeasible
#           010  1     8     9.219        0.324123     4.544    -0.000    -3.544  infeasible
#           100  1     8    18.275       0.0192548     0.000     1.626    -0.626  infeasible
#           011  2     9    48.562     2.00523e-07     1.000    -0.000     0.000
#           101  2     9    27.332      0.00123254     0.000     1.000     0.000
#           110  2     9    65.398     1.20712e-10     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     5.621 p-value for nested model:       0.0177438
# best pat:          101       0.00123254  chi(nested):    18.231 p-value for nested model:     1.95633e-05
# left pops:
# Th521_G4
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     39.189188989   -16.041550280   -22.147638709
#       std. errors:    19.755     8.769    11.246
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     8.908        0.259341    -7.667     4.288     4.380  infeasible
#           001  1     8    17.315       0.0269895    -3.529     4.529     0.000  infeasible
#           010  1     8    12.732        0.121413     3.952    -0.000    -2.952  infeasible
#           100  1     8    20.223      0.00952586     0.000     1.081    -0.081  infeasible
#           011  2     9    29.468     0.000540094     1.000     0.000     0.000
#           101  2     9    20.351       0.0158645     0.000     1.000     0.000
#           110  2     9    40.285     6.74593e-06     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     8.407 p-value for nested model:      0.00373709
# best pat:          101        0.0158645  chi(nested):     3.036 p-value for nested model:       0.0814353
# left pops:
# Vt777_G3
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:     -7.485792886    -2.695712941    11.181505827
#       std. errors:     4.315     3.422     7.663
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     8.296        0.307238     0.344     0.950    -0.294  infeasible
#           001  1     8     8.216        0.412692     0.177     0.823    -0.000
#           010  1     8     8.476        0.388449    -0.450    -0.000     1.450  infeasible
#           100  1     8     8.200        0.414227     0.000     0.625     0.375
#           011  2     9    15.419       0.0800617     1.000     0.000     0.000
#           101  2     9     8.574        0.477486     0.000     1.000     0.000
#           110  2     9     9.347        0.405869     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          100         0.414227  chi(nested):    -0.096 p-value for nested model:            -nan
# best pat:          101         0.477486  chi(nested):     0.375 p-value for nested model:        0.540557
# left pops:
# Mixe
# Bbdong
# LiangDaoF
# HDYM1
#
# ##PARAMETER NAME: VALUE
# genotypename: /mnt/solexa/mel_yang/data/2.2M/UPA19_3.geno
# left pops:
# Surui
# Bbdong
# LiangDaoF
# HDYM1
#
# Jackknife mean:  981452.242980777 -418857.785425458 -562593.457555317
#       std. errors: 1336647.506 569255.717 767397.160
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     7     3.398         0.84595  1005.907  -430.332  -574.575  infeasible
#           001  1     8     9.458         0.30516    13.862   -12.862     0.000  infeasible
#           010  1     8     7.282         0.50653   -16.956    -0.000    17.956  infeasible
#           100  1     8    21.088      0.00691779     0.000    -6.863     7.863  infeasible
#           011  2     9  1359.105               0     1.000    -0.000     0.000
#           101  2     9  1524.797               0     0.000     1.000     0.000
#           110  2     9  1300.763               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     6.060 p-value for nested model:       0.0138263
# best pat:          110     2.11714e-274  chi(nested):  1291.305 p-value for nested model:    8.77251e-283
# left pops:
# Papuan
# Bbdong
# LiangDaoF
# HDYM1
#
# ##PARAMETER NAME: VALUE
# genotypename: /mnt/solexa/mel_yang/data/2.2M/UPA19_3.geno
# left pops:
# Onge
# Bbdong
# LiangDaoF
# HDYM1
#
# ##PARAMETER NAME: VALUE
# genotypename: /mnt/solexa/mel_yang/data/2.2M/UPA19_3.geno
# expr: syntax error
# expr: non-numeric argument
# tail: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_3s/UPA19_3.adm.A_3S_Tianyuan_Bbdong_LiangDaoF_HDYM1_out0.log: invalid number of lines
# head: option requires an argument -- 'n'
# Try `head --help' for more information.
# expr: syntax error
# expr: non-numeric argument
# tail: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_3s/UPA19_3.adm.A_3S_La368_G1_Bbdong_LiangDaoF_HDYM1_out0.log: invalid number of lines
# head: option requires an argument -- 'n'
# Try `head --help' for more information.
# expr: syntax error
# expr: non-numeric argument
# tail: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_3s/UPA19_3.adm.A_3S_JomonM_Bbdong_LiangDaoF_HDYM1_out0.log: invalid number of lines
# head: option requires an argument -- 'n'
# Try `head --help' for more information.
# expr: syntax error
# expr: non-numeric argument
# tail: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_3s/UPA19_3.adm.A_3S_Kolyma_River_Bbdong_LiangDaoF_HDYM1_out0.log: invalid number of lines
# head: option requires an argument -- 'n'
# Try `head --help' for more information.
# expr: syntax error
# expr: non-numeric argument
# tail: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_3s/UPA19_3.adm.A_3S_HDYM1_Bbdong_LiangDaoF_HDYM1_out0.log: invalid number of lines
# head: option requires an argument -- 'n'
# Try `head --help' for more information.
# expr: syntax error
# expr: non-numeric argument
# tail: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_3s/UPA19_3.adm.A_3S_Bbdong_Bbdong_LiangDaoF_HDYM1_out0.log: invalid number of lines
# head: option requires an argument -- 'n'
# Try `head --help' for more information.
# expr: syntax error
# expr: non-numeric argument
# tail: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_3s/UPA19_3.adm.A_3S_LiangDaoF_Bbdong_LiangDaoF_HDYM1_out0.log: invalid number of lines
# head: option requires an argument -- 'n'
# Try `head --help' for more information.
# expr: syntax error
# expr: non-numeric argument
# tail: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_3s/UPA19_3.adm.A_3S_Mixe_Bbdong_LiangDaoF_HDYM1_out0.log: invalid number of lines
# head: option requires an argument -- 'n'
# Try `head --help' for more information.
# expr: syntax error
# expr: non-numeric argument
# tail: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_3s/UPA19_3.adm.A_3S_Papuan_Bbdong_LiangDaoF_HDYM1_out0.log: invalid number of lines
# head: option requires an argument -- 'n'
# Try `head --help' for more information.
# expr: syntax error
# expr: non-numeric argument
# tail: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_3s/UPA19_3.adm.A_3S_Onge_Bbdong_LiangDaoF_HDYM1_out0.log: invalid number of lines
# head: option requires an argument -- 'n'
# Try `head --help' for more information.

# %% [markdown]
# ## qpAdm(Inner North; Coastal Sib+Siberian, Plateau)

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"
fh="UPA19_3"
name="WEST2"
pt="adm"
out="out3"
south=["Suogang","Qihe","Qihe_d","LiangDaoF","LiangDaoM","Ma555_G6"]
north=["JomonM","ZongriM297","Hejiatai","PukagongmaM5","Chokhopani",
       "Kolyma_River","Shamanka_EN","HDYM1",
       "DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao","XJS","XJS_F" ]        
central=["Longlin","Baojianshan","Dushan",
         "ZhaoguoM2","Daxi","Dashuitian",
         "DonghulinM1","Jiahu_M52_I2","Tianluoshan","Liangzhu_T4620"]
seas=["Ma912_G2","La727_G2","Vt880_G2","Vt833_G2","Man_Bac","Nui_Nap",
      "Vt719_G3_1","Vt777_G3","Th521_G4","Oakaie1"]
pdeas=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean","Han","Tujia","She","Miao",
      "Naxi","Yi","Dai","Kinh","Lahu","Ami","Atayal"]
coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
plateau=["Hejiatai","PukagongmaM5","Chokhopani","ZongriM297"]
targets=sib[2:4]
s1s=coastalnorth+sib
s2s=plateau
for s2 in s2s:
    for s1 in s1s: 
        for target in targets:
            if s1 == target: continue
            if s2==target: continue
            if s1==s2: continue
            label="%s_%s_%s_%s_%s" % (name,target,s1,s2,out)
            ff.parfile(pD,fh,pt,label,outpd=outpd,outgroup=fh+"."+out)
            ff.mklst(outpd,fh,pt+"."+label,[target,s1,s2],suffix="leftpop")
        
        mytuple=(fh,pt,"%s_%s_%s_%s_%s" % (name,"${i}",s1,s2,out))
        print "for i in %s; do " % " ".join(targets)+"qpAdm -p {0}.{1}.{2}.par > {0}.{1}.{2}.log; done &".format(*mytuple)
# Out:
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Bbdong_Hejiatai_out3.par > UPA19_3.adm.WEST2_${i}_Bbdong_Hejiatai_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Boshan_Hejiatai_out3.par > UPA19_3.adm.WEST2_${i}_Boshan_Hejiatai_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Xiaogao_Hejiatai_out3.par > UPA19_3.adm.WEST2_${i}_Xiaogao_Hejiatai_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_XJS_Hejiatai_out3.par > UPA19_3.adm.WEST2_${i}_XJS_Hejiatai_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_XJS_F_Hejiatai_out3.par > UPA19_3.adm.WEST2_${i}_XJS_F_Hejiatai_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Linzi_Hejiatai_out3.par > UPA19_3.adm.WEST2_${i}_Linzi_Hejiatai_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Boisman_MN_Hejiatai_out3.par > UPA19_3.adm.WEST2_${i}_Boisman_MN_Hejiatai_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_DevilsGate_Hejiatai_out3.par > UPA19_3.adm.WEST2_${i}_DevilsGate_Hejiatai_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Shamanka_EN_Hejiatai_out3.par > UPA19_3.adm.WEST2_${i}_Shamanka_EN_Hejiatai_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_HDYM1_Hejiatai_out3.par > UPA19_3.adm.WEST2_${i}_HDYM1_Hejiatai_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Kolyma_River_Hejiatai_out3.par > UPA19_3.adm.WEST2_${i}_Kolyma_River_Hejiatai_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Bbdong_PukagongmaM5_out3.par > UPA19_3.adm.WEST2_${i}_Bbdong_PukagongmaM5_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Boshan_PukagongmaM5_out3.par > UPA19_3.adm.WEST2_${i}_Boshan_PukagongmaM5_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Xiaogao_PukagongmaM5_out3.par > UPA19_3.adm.WEST2_${i}_Xiaogao_PukagongmaM5_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_XJS_PukagongmaM5_out3.par > UPA19_3.adm.WEST2_${i}_XJS_PukagongmaM5_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_XJS_F_PukagongmaM5_out3.par > UPA19_3.adm.WEST2_${i}_XJS_F_PukagongmaM5_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Linzi_PukagongmaM5_out3.par > UPA19_3.adm.WEST2_${i}_Linzi_PukagongmaM5_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Boisman_MN_PukagongmaM5_out3.par > UPA19_3.adm.WEST2_${i}_Boisman_MN_PukagongmaM5_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_DevilsGate_PukagongmaM5_out3.par > UPA19_3.adm.WEST2_${i}_DevilsGate_PukagongmaM5_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Shamanka_EN_PukagongmaM5_out3.par > UPA19_3.adm.WEST2_${i}_Shamanka_EN_PukagongmaM5_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_HDYM1_PukagongmaM5_out3.par > UPA19_3.adm.WEST2_${i}_HDYM1_PukagongmaM5_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Kolyma_River_PukagongmaM5_out3.par > UPA19_3.adm.WEST2_${i}_Kolyma_River_PukagongmaM5_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Bbdong_Chokhopani_out3.par > UPA19_3.adm.WEST2_${i}_Bbdong_Chokhopani_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Boshan_Chokhopani_out3.par > UPA19_3.adm.WEST2_${i}_Boshan_Chokhopani_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Xiaogao_Chokhopani_out3.par > UPA19_3.adm.WEST2_${i}_Xiaogao_Chokhopani_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_XJS_Chokhopani_out3.par > UPA19_3.adm.WEST2_${i}_XJS_Chokhopani_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_XJS_F_Chokhopani_out3.par > UPA19_3.adm.WEST2_${i}_XJS_F_Chokhopani_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Linzi_Chokhopani_out3.par > UPA19_3.adm.WEST2_${i}_Linzi_Chokhopani_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Boisman_MN_Chokhopani_out3.par > UPA19_3.adm.WEST2_${i}_Boisman_MN_Chokhopani_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_DevilsGate_Chokhopani_out3.par > UPA19_3.adm.WEST2_${i}_DevilsGate_Chokhopani_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Shamanka_EN_Chokhopani_out3.par > UPA19_3.adm.WEST2_${i}_Shamanka_EN_Chokhopani_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_HDYM1_Chokhopani_out3.par > UPA19_3.adm.WEST2_${i}_HDYM1_Chokhopani_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Kolyma_River_Chokhopani_out3.par > UPA19_3.adm.WEST2_${i}_Kolyma_River_Chokhopani_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Bbdong_ZongriM297_out3.par > UPA19_3.adm.WEST2_${i}_Bbdong_ZongriM297_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Boshan_ZongriM297_out3.par > UPA19_3.adm.WEST2_${i}_Boshan_ZongriM297_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Xiaogao_ZongriM297_out3.par > UPA19_3.adm.WEST2_${i}_Xiaogao_ZongriM297_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_XJS_ZongriM297_out3.par > UPA19_3.adm.WEST2_${i}_XJS_ZongriM297_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_XJS_F_ZongriM297_out3.par > UPA19_3.adm.WEST2_${i}_XJS_F_ZongriM297_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Linzi_ZongriM297_out3.par > UPA19_3.adm.WEST2_${i}_Linzi_ZongriM297_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Boisman_MN_ZongriM297_out3.par > UPA19_3.adm.WEST2_${i}_Boisman_MN_ZongriM297_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_DevilsGate_ZongriM297_out3.par > UPA19_3.adm.WEST2_${i}_DevilsGate_ZongriM297_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Shamanka_EN_ZongriM297_out3.par > UPA19_3.adm.WEST2_${i}_Shamanka_EN_ZongriM297_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_HDYM1_ZongriM297_out3.par > UPA19_3.adm.WEST2_${i}_HDYM1_ZongriM297_out3.log; done &
# for i in Shamanka_EN HDYM1; do qpAdm -p UPA19_3.adm.WEST2_${i}_Kolyma_River_ZongriM297_out3.par > UPA19_3.adm.WEST2_${i}_Kolyma_River_ZongriM297_out3.log; done &

# %%
print ' '.join(coastalnorth+sib)
# Out:
# Bbdong Boshan Xiaogao XJS XJS_F Linzi Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"
# fh="UPA19_3"
# out="out3"
# numsource=2
# #for i in Han Korean Bbdong Boshan Boisman_MN Ami Dai; do
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do
#     label="adm.WEST_Hejiatai_${i}_ZongriM297_${out}"
#
#     numlines=$(wc -l ${pd}${fh}.${label}.log | cut -d" " -f1)
#
#     popind=$(cat ${pd}${fh}.${label}.log | grep -n "left pops:" | cut -d":" -f1)
#     diff1=`expr ${numlines} - ${popind} + 1`
#     tail -n ${diff1} ${pd}${fh}.${label}.log | head -n `expr ${numsource} + 3`
#
#     myind=$(cat ${pd}${fh}.${label}.log | grep -n "std. errors:" | cut -d":" -f1)
#     diff2=`expr ${numlines} - ${myind} + 2`
#     tail -n ${diff2} ${pd}${fh}.${label}.log | head -n2
#
#     tabind1=$(cat ${pd}${fh}.${label}.log | grep -n "summ:" | cut -d":" -f1)
#     tabind2=$(cat ${pd}${fh}.${label}.log | grep -n "coeffs:" | cut -d":" -f1)
#
#     diff3=`expr ${numlines} - ${tabind1}`
#     diff4=`expr ${tabind2} - ${tabind1} - 2`
#     tail -n ${diff3} ${pd}${fh}.${label}.log | head -n ${diff4}
# done
# Out:
# left pops:
# Hejiatai
# Bbdong
# ZongriM297
#
# Jackknife mean:    -27.633487162    28.633487162
#       std. errors:     5.663     5.663
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     9    10.040        0.347294     1.747    -0.747  infeasible
#            01  1    10    10.700         0.38135     1.000    -0.000
#            10  1    10    14.229        0.162804     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01          0.38135  chi(nested):     0.661 p-value for nested model:        0.416338
# left pops:
# Hejiatai
# Boshan
# ZongriM297
#
# Jackknife mean:    358.827984343  -357.827984343
#       std. errors:   274.880   274.880
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     9    12.245        0.199823     0.699     0.301
#            01  1    10    12.806        0.234696     1.000    -0.000
#            10  1    10    12.706        0.240577     0.000     1.000
# best pat:           00         0.199823              -  -
# best pat:           10         0.240577  chi(nested):     0.461 p-value for nested model:        0.497367
# left pops:
# Hejiatai
# Xiaogao
# ZongriM297
#
# Jackknife mean:      0.141970442     0.858029558
#       std. errors:     1.008     1.008
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     9    12.230        0.200647    -0.354     1.354  infeasible
#            01  1    10    25.766      0.00406842     1.000    -0.000
#            10  1    10    12.851        0.232107     0.000     1.000
# best pat:           00                0              -  -
# best pat:           10         0.232107  chi(nested):     0.621 p-value for nested model:        0.430604
# left pops:
# Hejiatai
# XJS
# ZongriM297
#
# Jackknife mean:      0.277490035     0.722509965
#       std. errors:     0.771     0.771
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     9    13.157        0.155648    -0.167     1.167  infeasible
#            01  1    10    21.432       0.0182765     1.000    -0.000
#            10  1    10    13.296        0.207613     0.000     1.000
# best pat:           00                0              -  -
# best pat:           10         0.207613  chi(nested):     0.139 p-value for nested model:          0.7093
# left pops:
# Hejiatai
# XJS_F
# ZongriM297
#
# Jackknife mean:      0.082678810     0.917321190
#       std. errors:     0.348     0.348
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     9    14.029        0.121314     0.034     0.966
#            01  1    10    29.641     0.000980307     1.000    -0.000
#            10  1    10    13.997        0.173114     0.000     1.000
# best pat:           00         0.121314              -  -
# best pat:           10         0.173114  chi(nested):    -0.031 p-value for nested model:            -nan
# left pops:
# Hejiatai
# Linzi
# ZongriM297
#
# Jackknife mean:      0.316109248     0.683890752
#       std. errors:     0.383     0.383
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     9    11.797        0.224987     0.247     0.753
#            01  1    10    19.990       0.0293432     1.000    -0.000
#            10  1    10    12.501        0.252921     0.000     1.000
# best pat:           00         0.224987              -  -
# best pat:           10         0.252921  chi(nested):     0.704 p-value for nested model:        0.401486
# left pops:
# Hejiatai
# Boisman_MN
# ZongriM297
#
# Jackknife mean:      0.317434842     0.682565158
#       std. errors:     0.403     0.403
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     9    12.402        0.191581     0.269     0.731
#            01  1    10    20.994       0.0211382     1.000    -0.000
#            10  1    10    13.199        0.212784     0.000     1.000
# best pat:           00         0.191581              -  -
# best pat:           10         0.212784  chi(nested):     0.796 p-value for nested model:        0.372153
# left pops:
# Hejiatai
# DevilsGate
# ZongriM297
#
# Jackknife mean:      0.761813628     0.238186372
#       std. errors:     2.363     2.363
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     9    24.439      0.00365912    -1.187     2.187  infeasible
#            01  1    10    35.312     0.000110452     1.000    -0.000
#            10  1    10    27.632      0.00206728     0.000     1.000
# best pat:           00                0              -  -
# best pat:           10       0.00206728  chi(nested):     3.193 p-value for nested model:       0.0739584
# left pops:
# Hejiatai
# Shamanka_EN
# ZongriM297
#
# Jackknife mean:      0.572268974     0.427731026
#       std. errors:     0.247     0.247
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     9     9.067        0.431151     0.558     0.442
#            01  1    10    14.278        0.160676     1.000    -0.000
#            10  1    10    14.473        0.152507     0.000     1.000
# best pat:           00         0.431151              -  -
# best pat:           01         0.160676  chi(nested):     5.212 p-value for nested model:       0.0224366
# left pops:
# Hejiatai
# HDYM1
# ZongriM297
#
# Jackknife mean:    183.174942590  -182.174942590
#       std. errors:    79.698    79.698
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     9    13.565        0.138652    -0.635     1.635  infeasible
#            01  1    10    13.955        0.175068     1.000    -0.000
#            10  1    10    13.615        0.191276     0.000     1.000
# best pat:           00                0              -  -
# best pat:           10         0.191276  chi(nested):     0.050 p-value for nested model:        0.823112
# left pops:
# Hejiatai
# Kolyma_River
# ZongriM297
#
# Jackknife mean:      0.219141282     0.780858718
#       std. errors:     0.125     0.125
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0     9     9.533        0.389589     0.214     0.786
#            01  1    10    47.207     8.65791e-07     1.000    -0.000
#            10  1    10    12.699        0.240963     0.000     1.000
# best pat:           00         0.389589              -  -
# best pat:           10         0.240963  chi(nested):     3.166 p-value for nested model:       0.0751679

# %% [markdown]
# ## qpAdm(Guangxi/South; South, Guangxi)

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"
fh="UPA19_3"
name="SOUTH"
pt="adm"
out="out4"
south=["Suogang","Qihe","Qihe_d","LiangDaoF","LiangDaoM","Ma555_G6"]
north=["JomonM","ZongriM297","Hejiatai","PukagongmaM5","Chokhopani",
       "Kolyma_River","Shamanka_EN","HDYM1",
       "DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao","XJS","XJS_F" ]        
central=["Longlin","Baojianshan","Dushan",
         "ZhaoguoM2","Daxi","Dashuitian",
         "DonghulinM1","Jiahu_M52_I2","Tianluoshan","Liangzhu_T4620"]
seas=["Ma912_G2","La727_G2","Vt880_G2","Vt833_G2","Man_Bac","Nui_Nap",
      "Vt719_G3_1","Vt777_G3","Th521_G4","Oakaie1"]
pdeas=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean","Han","Tujia","She","Miao",
      "Naxi","Yi","Dai","Kinh","Lahu","Ami","Atayal"]
coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
guangxi=["Longlin","Baojianshan","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
plateau=["Hejiatai","PukagongmaM5","Chokhopani"]
targets=guangxi+south
s1s=["Dashuitian","Daxi"] #coastalnorth+south+["Dai","Han"]
#s1s=guangxi+south[:-1]+["Dai","Han"]
s1s=south
s2s=["Daxi"]
s2s=south
s2s=["Xinyi"]
for s2 in s2s:
    for s1 in s1s: 
        for target in targets:
            if s1 == target: continue
            if s2==target: continue
            label="%s_%s_%s_%s_%s" % (name,target,s1,s2,out)
            ff.parfile(pD,fh,pt,label,outpd=outpd,outgroup=fh+"."+out)
            ff.mklst(outpd,fh,pt+"."+label,[target,s1,s2],suffix="leftpop")
        
        mytuple=(fh,pt,"%s_%s_%s_%s_%s" % (name,"${i}",s1,s2,out))
        print "for i in %s; do " % " ".join(targets)+"qpAdm -p {0}.{1}.{2}.par > {0}.{1}.{2}.log; done &".format(*mytuple)
# Out:
# for i in Longlin Baojianshan Dushan Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.SOUTH_${i}_Qihe_Xinyi_out4.par > UPA19_3.adm.SOUTH_${i}_Qihe_Xinyi_out4.log; done &
# for i in Longlin Baojianshan Dushan Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.SOUTH_${i}_LiangDaoF_Xinyi_out4.par > UPA19_3.adm.SOUTH_${i}_LiangDaoF_Xinyi_out4.log; done &
# for i in Longlin Baojianshan Dushan Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.SOUTH_${i}_LiangDaoM_Xinyi_out4.par > UPA19_3.adm.SOUTH_${i}_LiangDaoM_Xinyi_out4.log; done &
# for i in Longlin Baojianshan Dushan Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.SOUTH_${i}_Suogang_Xinyi_out4.par > UPA19_3.adm.SOUTH_${i}_Suogang_Xinyi_out4.log; done &
# for i in Longlin Baojianshan Dushan Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.SOUTH_${i}_Ami_Xinyi_out4.par > UPA19_3.adm.SOUTH_${i}_Ami_Xinyi_out4.log; done &
# for i in Longlin Baojianshan Dushan Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.SOUTH_${i}_Ma555_G6_Xinyi_out4.par > UPA19_3.adm.SOUTH_${i}_Ma555_G6_Xinyi_out4.log; done &
# for i in Longlin Baojianshan Dushan Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.SOUTH_${i}_Xinyi_Xinyi_out4.par > UPA19_3.adm.SOUTH_${i}_Xinyi_Xinyi_out4.log; done &
# for i in Longlin Baojianshan Dushan Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.SOUTH_${i}_Dushan_Xinyi_out4.par > UPA19_3.adm.SOUTH_${i}_Dushan_Xinyi_out4.log; done &

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"
fh="UPA19_3"
name="SOUTH"
pt="adm"
out="out4"
south=["Suogang","Qihe","Qihe_d","LiangDaoF","LiangDaoM","Ma555_G6"]
north=["JomonM","ZongriM297","Hejiatai","PukagongmaM5","Chokhopani",
       "Kolyma_River","Shamanka_EN","HDYM1",
       "DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao","XJS","XJS_F" ]        
central=["Longlin","Baojianshan","Dushan",
         "ZhaoguoM2","Daxi","Dashuitian",
         "DonghulinM1","Jiahu_M52_I2","Tianluoshan","Liangzhu_T4620"]
seas=["Ma912_G2","La727_G2","Vt880_G2","Vt833_G2","Man_Bac","Nui_Nap",
      "Vt719_G3_1","Vt777_G3","Th521_G4","Oakaie1"]
pdeas=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean","Han","Tujia","She","Miao",
      "Naxi","Yi","Dai","Kinh","Lahu","Ami","Atayal"]
coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
guangxi=["Longlin","Baojianshan","Dushan"]
targets=["Daxi","Xinyi"]
s1s=guangxi+south[:-1]+["Dai","Han"]
s2s=guangxi
targets=["Daxi"]
s1s=south
s2s=["Xinyi"]
for s1 in s1s:
    for target in targets:
        for s2 in s2s: 
            if s1 == target: continue
            if s2==target: continue
            label="%s_%s_%s_%s_%s" % (name,target,s1,s2,out)
            ff.parfile(pD,fh,pt,label,outpd=outpd,outgroup=fh+"."+out)
            ff.mklst(outpd,fh,pt+"."+label,[target,s1,s2],suffix="leftpop")
        
        mytuple=(fh,pt,"%s_%s_%s_%s_%s" % (name,target,s1,"${i}",out))
        print "for i in %s; do " % " ".join(s2s)+"qpAdm -p {0}.{1}.{2}.par > {0}.{1}.{2}.log; done &".format(*mytuple)
# Out:
# for i in Xinyi; do qpAdm -p UPA19_3.adm.SOUTH_Daxi_Qihe_${i}_out4.par > UPA19_3.adm.SOUTH_Daxi_Qihe_${i}_out4.log; done &
# for i in Xinyi; do qpAdm -p UPA19_3.adm.SOUTH_Daxi_LiangDaoF_${i}_out4.par > UPA19_3.adm.SOUTH_Daxi_LiangDaoF_${i}_out4.log; done &
# for i in Xinyi; do qpAdm -p UPA19_3.adm.SOUTH_Daxi_LiangDaoM_${i}_out4.par > UPA19_3.adm.SOUTH_Daxi_LiangDaoM_${i}_out4.log; done &
# for i in Xinyi; do qpAdm -p UPA19_3.adm.SOUTH_Daxi_Suogang_${i}_out4.par > UPA19_3.adm.SOUTH_Daxi_Suogang_${i}_out4.log; done &
# for i in Xinyi; do qpAdm -p UPA19_3.adm.SOUTH_Daxi_Ami_${i}_out4.par > UPA19_3.adm.SOUTH_Daxi_Ami_${i}_out4.log; done &
# for i in Xinyi; do qpAdm -p UPA19_3.adm.SOUTH_Daxi_Ma555_G6_${i}_out4.par > UPA19_3.adm.SOUTH_Daxi_Ma555_G6_${i}_out4.log; done &
# for i in Xinyi; do qpAdm -p UPA19_3.adm.SOUTH_Daxi_Xinyi_${i}_out4.par > UPA19_3.adm.SOUTH_Daxi_Xinyi_${i}_out4.log; done &
# for i in Xinyi; do qpAdm -p UPA19_3.adm.SOUTH_Daxi_Dushan_${i}_out4.par > UPA19_3.adm.SOUTH_Daxi_Dushan_${i}_out4.log; done &

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"
fh="UPA19_3"
name="COASTN"
pt="adm"
out="out2"
south=["Suogang","Qihe","Qihe_d","LiangDaoF","LiangDaoM","Ma555_G6"]
north=["JomonM","ZongriM297","Hejiatai","PukagongmaM5","Chokhopani",
       "Kolyma_River","Shamanka_EN","HDYM1",
       "DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao","XJS","XJS_F" ]        
central=["Longlin","Baojianshan","Dushan",
         "ZhaoguoM2","Daxi","Dashuitian",
         "DonghulinM1","Jiahu_M52_I2","Tianluoshan","Liangzhu_T4620"]
seas=["Ma912_G2","La727_G2","Vt880_G2","Vt833_G2","Man_Bac","Nui_Nap",
      "Vt719_G3_1","Vt777_G3","Th521_G4","Oakaie1"]
pdeas=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean","Han","Tujia","She","Miao",
      "Naxi","Yi","Dai","Kinh","Lahu","Ami","Atayal"]
coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
targets=["HDYM1"] #coastalnorth
s1s=south
s2s=["HDYM1","Shamanka_EN","DevilsGate","Boisman_MN"]
for s2 in s2s:
    for target in targets:
        for s1 in s1s: 
            if s1 == target: continue
            if s2==target: continue
            label="%s_%s_%s_%s_%s" % (name,target,s1,s2,out)
            ff.parfile(pD,fh,pt,label,outpd=outpd,outgroup=fh+"."+out)
            ff.mklst(outpd,fh,pt+"."+label,[target,s1,s2],suffix="leftpop")
        
        mytuple=(fh,pt,"%s_%s_%s_%s_%s" % (name,target,"${i}",s2,out))
        print "for i in %s; do " % " ".join(s1s)+"qpAdm -p {0}.{1}.{2}.par > {0}.{1}.{2}.log; done &".format(*mytuple)
# Out:
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_HDYM1_${i}_HDYM1_out2.par > UPA19_3.adm.COASTN_HDYM1_${i}_HDYM1_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_HDYM1_${i}_Shamanka_EN_out2.par > UPA19_3.adm.COASTN_HDYM1_${i}_Shamanka_EN_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_HDYM1_${i}_DevilsGate_out2.par > UPA19_3.adm.COASTN_HDYM1_${i}_DevilsGate_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_HDYM1_${i}_Boisman_MN_out2.par > UPA19_3.adm.COASTN_HDYM1_${i}_Boisman_MN_out2.log; done &

# %% [markdown]
# ## qpAdm(Coastal North; South, Coastal North)

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"
fh="UPA19_3"
name="COASTN"
pt="adm"
out="out2"
south=["Suogang","Qihe","Qihe_d","LiangDaoF","LiangDaoM","Ma555_G6"]
north=["JomonM","ZongriM297","Hejiatai","PukagongmaM5","Chokhopani",
       "Kolyma_River","Shamanka_EN","HDYM1",
       "DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao","XJS","XJS_F" ]        
central=["Longlin","Baojianshan","Dushan",
         "ZhaoguoM2","Daxi","Dashuitian",
         "DonghulinM1","Jiahu_M52_I2","Tianluoshan","Liangzhu_T4620"]
seas=["Ma912_G2","La727_G2","Vt880_G2","Vt833_G2","Man_Bac","Nui_Nap",
      "Vt719_G3_1","Vt777_G3","Th521_G4","Oakaie1"]
pdeas=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean","Han","Tujia","She","Miao",
      "Naxi","Yi","Dai","Kinh","Lahu","Ami","Atayal"]
coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
targets=coastalnorth+["HDYM1","Dashuitian"]
s1s=south
s2s=coastalnorth #sib[:-1]
for s2 in s2s:
    for target in targets:
        for s1 in s1s: 
            if s1 == target: continue
            if s2==target: continue
            if s1==s2: continue
            label="%s_%s_%s_%s_%s" % (name,target,s1,s2,out)
            ff.parfile(pD,fh,pt,label,outpd=outpd,outgroup=fh+"."+out)
            ff.mklst(outpd,fh,pt+"."+label,[target,s1,s2],suffix="leftpop")
        
        mytuple=(fh,pt,"%s_%s_%s_%s_%s" % (name,target,"${i}",s2,out))
        print "for i in %s; do " % " ".join(s1s)+"qpAdm -p {0}.{1}.{2}.par > {0}.{1}.{2}.log; done &".format(*mytuple)
# Out:
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Bbdong_${i}_Bbdong_out2.par > UPA19_3.adm.COASTN_Bbdong_${i}_Bbdong_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Boshan_${i}_Bbdong_out2.par > UPA19_3.adm.COASTN_Boshan_${i}_Bbdong_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Xiaogao_${i}_Bbdong_out2.par > UPA19_3.adm.COASTN_Xiaogao_${i}_Bbdong_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_XJS_${i}_Bbdong_out2.par > UPA19_3.adm.COASTN_XJS_${i}_Bbdong_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_XJS_F_${i}_Bbdong_out2.par > UPA19_3.adm.COASTN_XJS_F_${i}_Bbdong_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Linzi_${i}_Bbdong_out2.par > UPA19_3.adm.COASTN_Linzi_${i}_Bbdong_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_HDYM1_${i}_Bbdong_out2.par > UPA19_3.adm.COASTN_HDYM1_${i}_Bbdong_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Dashuitian_${i}_Bbdong_out2.par > UPA19_3.adm.COASTN_Dashuitian_${i}_Bbdong_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Bbdong_${i}_Boshan_out2.par > UPA19_3.adm.COASTN_Bbdong_${i}_Boshan_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Boshan_${i}_Boshan_out2.par > UPA19_3.adm.COASTN_Boshan_${i}_Boshan_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Xiaogao_${i}_Boshan_out2.par > UPA19_3.adm.COASTN_Xiaogao_${i}_Boshan_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_XJS_${i}_Boshan_out2.par > UPA19_3.adm.COASTN_XJS_${i}_Boshan_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_XJS_F_${i}_Boshan_out2.par > UPA19_3.adm.COASTN_XJS_F_${i}_Boshan_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Linzi_${i}_Boshan_out2.par > UPA19_3.adm.COASTN_Linzi_${i}_Boshan_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_HDYM1_${i}_Boshan_out2.par > UPA19_3.adm.COASTN_HDYM1_${i}_Boshan_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Dashuitian_${i}_Boshan_out2.par > UPA19_3.adm.COASTN_Dashuitian_${i}_Boshan_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Bbdong_${i}_Xiaogao_out2.par > UPA19_3.adm.COASTN_Bbdong_${i}_Xiaogao_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Boshan_${i}_Xiaogao_out2.par > UPA19_3.adm.COASTN_Boshan_${i}_Xiaogao_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Xiaogao_${i}_Xiaogao_out2.par > UPA19_3.adm.COASTN_Xiaogao_${i}_Xiaogao_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_XJS_${i}_Xiaogao_out2.par > UPA19_3.adm.COASTN_XJS_${i}_Xiaogao_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_XJS_F_${i}_Xiaogao_out2.par > UPA19_3.adm.COASTN_XJS_F_${i}_Xiaogao_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Linzi_${i}_Xiaogao_out2.par > UPA19_3.adm.COASTN_Linzi_${i}_Xiaogao_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_HDYM1_${i}_Xiaogao_out2.par > UPA19_3.adm.COASTN_HDYM1_${i}_Xiaogao_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Dashuitian_${i}_Xiaogao_out2.par > UPA19_3.adm.COASTN_Dashuitian_${i}_Xiaogao_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Bbdong_${i}_XJS_out2.par > UPA19_3.adm.COASTN_Bbdong_${i}_XJS_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Boshan_${i}_XJS_out2.par > UPA19_3.adm.COASTN_Boshan_${i}_XJS_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Xiaogao_${i}_XJS_out2.par > UPA19_3.adm.COASTN_Xiaogao_${i}_XJS_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_XJS_${i}_XJS_out2.par > UPA19_3.adm.COASTN_XJS_${i}_XJS_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_XJS_F_${i}_XJS_out2.par > UPA19_3.adm.COASTN_XJS_F_${i}_XJS_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Linzi_${i}_XJS_out2.par > UPA19_3.adm.COASTN_Linzi_${i}_XJS_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_HDYM1_${i}_XJS_out2.par > UPA19_3.adm.COASTN_HDYM1_${i}_XJS_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Dashuitian_${i}_XJS_out2.par > UPA19_3.adm.COASTN_Dashuitian_${i}_XJS_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Bbdong_${i}_XJS_F_out2.par > UPA19_3.adm.COASTN_Bbdong_${i}_XJS_F_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Boshan_${i}_XJS_F_out2.par > UPA19_3.adm.COASTN_Boshan_${i}_XJS_F_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Xiaogao_${i}_XJS_F_out2.par > UPA19_3.adm.COASTN_Xiaogao_${i}_XJS_F_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_XJS_${i}_XJS_F_out2.par > UPA19_3.adm.COASTN_XJS_${i}_XJS_F_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_XJS_F_${i}_XJS_F_out2.par > UPA19_3.adm.COASTN_XJS_F_${i}_XJS_F_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Linzi_${i}_XJS_F_out2.par > UPA19_3.adm.COASTN_Linzi_${i}_XJS_F_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_HDYM1_${i}_XJS_F_out2.par > UPA19_3.adm.COASTN_HDYM1_${i}_XJS_F_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Dashuitian_${i}_XJS_F_out2.par > UPA19_3.adm.COASTN_Dashuitian_${i}_XJS_F_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Bbdong_${i}_Linzi_out2.par > UPA19_3.adm.COASTN_Bbdong_${i}_Linzi_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Boshan_${i}_Linzi_out2.par > UPA19_3.adm.COASTN_Boshan_${i}_Linzi_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Xiaogao_${i}_Linzi_out2.par > UPA19_3.adm.COASTN_Xiaogao_${i}_Linzi_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_XJS_${i}_Linzi_out2.par > UPA19_3.adm.COASTN_XJS_${i}_Linzi_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_XJS_F_${i}_Linzi_out2.par > UPA19_3.adm.COASTN_XJS_F_${i}_Linzi_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Linzi_${i}_Linzi_out2.par > UPA19_3.adm.COASTN_Linzi_${i}_Linzi_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_HDYM1_${i}_Linzi_out2.par > UPA19_3.adm.COASTN_HDYM1_${i}_Linzi_out2.log; done &
# for i in Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan; do qpAdm -p UPA19_3.adm.COASTN_Dashuitian_${i}_Linzi_out2.par > UPA19_3.adm.COASTN_Dashuitian_${i}_Linzi_out2.log; done &

# %% [markdown]
# ## qpAdm(Coastal North; Siberian, Coastal North)

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"
fh="UPA19_3"
name="COASTN"
pt="adm"
out="out2"
south=["Suogang","Qihe","Qihe_d","LiangDaoF","LiangDaoM","Ma555_G6"]
north=["JomonM","ZongriM297","Hejiatai","PukagongmaM5","Chokhopani",
       "Kolyma_River","Shamanka_EN","HDYM1",
       "DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao","XJS","XJS_F" ]        
central=["Longlin","Baojianshan","Dushan",
         "ZhaoguoM2","Daxi","Dashuitian",
         "DonghulinM1","Jiahu_M52_I2","Tianluoshan","Liangzhu_T4620"]
seas=["Ma912_G2","La727_G2","Vt880_G2","Vt833_G2","Man_Bac","Nui_Nap",
      "Vt719_G3_1","Vt777_G3","Th521_G4","Oakaie1"]
pdeas=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean","Han","Tujia","She","Miao",
      "Naxi","Yi","Dai","Kinh","Lahu","Ami","Atayal"]
coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
targets=coastalnorth+["HDYM1","Dashuitian"]
s1s=sib
s2s=coastalnorth #sib[:-1]
for s2 in s2s:
    for target in targets:
        for s1 in s1s: 
            if s1 == target: continue
            if s2==target: continue
            if s1==s2: continue
            label="%s_%s_%s_%s_%s" % (name,target,s1,s2,out)
            ff.parfile(pD,fh,pt,label,outpd=outpd,outgroup=fh+"."+out)
            ff.mklst(outpd,fh,pt+"."+label,[target,s1,s2],suffix="leftpop")
        
        mytuple=(fh,pt,"%s_%s_%s_%s_%s" % (name,target,"${i}",s2,out))
        print "for i in %s; do " % " ".join(s1s)+"qpAdm -p {0}.{1}.{2}.par > {0}.{1}.{2}.log; done &".format(*mytuple)
# Out:
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Bbdong_${i}_Bbdong_out2.par > UPA19_3.adm.COASTN_Bbdong_${i}_Bbdong_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Boshan_${i}_Bbdong_out2.par > UPA19_3.adm.COASTN_Boshan_${i}_Bbdong_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Xiaogao_${i}_Bbdong_out2.par > UPA19_3.adm.COASTN_Xiaogao_${i}_Bbdong_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_XJS_${i}_Bbdong_out2.par > UPA19_3.adm.COASTN_XJS_${i}_Bbdong_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_XJS_F_${i}_Bbdong_out2.par > UPA19_3.adm.COASTN_XJS_F_${i}_Bbdong_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Linzi_${i}_Bbdong_out2.par > UPA19_3.adm.COASTN_Linzi_${i}_Bbdong_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_HDYM1_${i}_Bbdong_out2.par > UPA19_3.adm.COASTN_HDYM1_${i}_Bbdong_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Dashuitian_${i}_Bbdong_out2.par > UPA19_3.adm.COASTN_Dashuitian_${i}_Bbdong_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Bbdong_${i}_Boshan_out2.par > UPA19_3.adm.COASTN_Bbdong_${i}_Boshan_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Boshan_${i}_Boshan_out2.par > UPA19_3.adm.COASTN_Boshan_${i}_Boshan_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Xiaogao_${i}_Boshan_out2.par > UPA19_3.adm.COASTN_Xiaogao_${i}_Boshan_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_XJS_${i}_Boshan_out2.par > UPA19_3.adm.COASTN_XJS_${i}_Boshan_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_XJS_F_${i}_Boshan_out2.par > UPA19_3.adm.COASTN_XJS_F_${i}_Boshan_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Linzi_${i}_Boshan_out2.par > UPA19_3.adm.COASTN_Linzi_${i}_Boshan_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_HDYM1_${i}_Boshan_out2.par > UPA19_3.adm.COASTN_HDYM1_${i}_Boshan_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Dashuitian_${i}_Boshan_out2.par > UPA19_3.adm.COASTN_Dashuitian_${i}_Boshan_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Bbdong_${i}_Xiaogao_out2.par > UPA19_3.adm.COASTN_Bbdong_${i}_Xiaogao_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Boshan_${i}_Xiaogao_out2.par > UPA19_3.adm.COASTN_Boshan_${i}_Xiaogao_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Xiaogao_${i}_Xiaogao_out2.par > UPA19_3.adm.COASTN_Xiaogao_${i}_Xiaogao_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_XJS_${i}_Xiaogao_out2.par > UPA19_3.adm.COASTN_XJS_${i}_Xiaogao_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_XJS_F_${i}_Xiaogao_out2.par > UPA19_3.adm.COASTN_XJS_F_${i}_Xiaogao_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Linzi_${i}_Xiaogao_out2.par > UPA19_3.adm.COASTN_Linzi_${i}_Xiaogao_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_HDYM1_${i}_Xiaogao_out2.par > UPA19_3.adm.COASTN_HDYM1_${i}_Xiaogao_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Dashuitian_${i}_Xiaogao_out2.par > UPA19_3.adm.COASTN_Dashuitian_${i}_Xiaogao_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Bbdong_${i}_XJS_out2.par > UPA19_3.adm.COASTN_Bbdong_${i}_XJS_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Boshan_${i}_XJS_out2.par > UPA19_3.adm.COASTN_Boshan_${i}_XJS_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Xiaogao_${i}_XJS_out2.par > UPA19_3.adm.COASTN_Xiaogao_${i}_XJS_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_XJS_${i}_XJS_out2.par > UPA19_3.adm.COASTN_XJS_${i}_XJS_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_XJS_F_${i}_XJS_out2.par > UPA19_3.adm.COASTN_XJS_F_${i}_XJS_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Linzi_${i}_XJS_out2.par > UPA19_3.adm.COASTN_Linzi_${i}_XJS_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_HDYM1_${i}_XJS_out2.par > UPA19_3.adm.COASTN_HDYM1_${i}_XJS_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Dashuitian_${i}_XJS_out2.par > UPA19_3.adm.COASTN_Dashuitian_${i}_XJS_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Bbdong_${i}_XJS_F_out2.par > UPA19_3.adm.COASTN_Bbdong_${i}_XJS_F_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Boshan_${i}_XJS_F_out2.par > UPA19_3.adm.COASTN_Boshan_${i}_XJS_F_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Xiaogao_${i}_XJS_F_out2.par > UPA19_3.adm.COASTN_Xiaogao_${i}_XJS_F_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_XJS_${i}_XJS_F_out2.par > UPA19_3.adm.COASTN_XJS_${i}_XJS_F_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_XJS_F_${i}_XJS_F_out2.par > UPA19_3.adm.COASTN_XJS_F_${i}_XJS_F_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Linzi_${i}_XJS_F_out2.par > UPA19_3.adm.COASTN_Linzi_${i}_XJS_F_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_HDYM1_${i}_XJS_F_out2.par > UPA19_3.adm.COASTN_HDYM1_${i}_XJS_F_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Dashuitian_${i}_XJS_F_out2.par > UPA19_3.adm.COASTN_Dashuitian_${i}_XJS_F_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Bbdong_${i}_Linzi_out2.par > UPA19_3.adm.COASTN_Bbdong_${i}_Linzi_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Boshan_${i}_Linzi_out2.par > UPA19_3.adm.COASTN_Boshan_${i}_Linzi_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Xiaogao_${i}_Linzi_out2.par > UPA19_3.adm.COASTN_Xiaogao_${i}_Linzi_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_XJS_${i}_Linzi_out2.par > UPA19_3.adm.COASTN_XJS_${i}_Linzi_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_XJS_F_${i}_Linzi_out2.par > UPA19_3.adm.COASTN_XJS_F_${i}_Linzi_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Linzi_${i}_Linzi_out2.par > UPA19_3.adm.COASTN_Linzi_${i}_Linzi_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_HDYM1_${i}_Linzi_out2.par > UPA19_3.adm.COASTN_HDYM1_${i}_Linzi_out2.log; done &
# for i in Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Dashuitian_${i}_Linzi_out2.par > UPA19_3.adm.COASTN_Dashuitian_${i}_Linzi_out2.log; done &

# %% [markdown]
# ## qpAdm(Jomon; Jomon, CN/CS) and qpAdm(CS/CN; IN/IS, Jomon)

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"
fh="UPA19_3"
name="COASTN"
pt="adm"
out="out5"
south=["Suogang","Qihe","Qihe_d","LiangDaoF","LiangDaoM","Ma555_G6"]
north=["JomonM","ZongriM297","Hejiatai","PukagongmaM5","Chokhopani",
       "Kolyma_River","Shamanka_EN","HDYM1",
       "DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao","XJS","XJS_F" ]        
central=["Longlin","Baojianshan","Dushan",
         "ZhaoguoM2","Daxi","Dashuitian",
         "DonghulinM1","Jiahu_M52_I2","Tianluoshan","Liangzhu_T4620"]
seas=["Ma912_G2","La727_G2","Vt880_G2","Vt833_G2","Man_Bac","Nui_Nap",
      "Vt719_G3_1","Vt777_G3","Th521_G4","Oakaie1"]
pdeas=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean","Han","Tujia","She","Miao",
      "Naxi","Yi","Dai","Kinh","Lahu","Ami","Atayal"]
coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
aJapan=["JomonM","Jomon"]
targets=["JomonM"]
s1s=["Jomon"]
s2s=coastalnorth+south+sib
for s2 in s2s:
    for target in targets:
        for s1 in s1s: 
            if s1 == target: continue
            if s2==target: continue
            if s1==s2: continue
            label="%s_%s_%s_%s_%s" % (name,target,s1,s2,out)
            ff.parfile(pD,fh,pt,label,outpd=outpd,outgroup=fh+"."+out)
            ff.mklst(outpd,fh,pt+"."+label,[target,s1,s2],suffix="leftpop")
        
        mytuple=(fh,pt,"%s_%s_%s_%s_%s" % (name,target,"${i}",s2,out))
        print "for i in %s; do " % " ".join(s1s)+"qpAdm -p {0}.{1}.{2}.par > {0}.{1}.{2}.log; done &".format(*mytuple)
# Out:
# for i in Jomon; do qpAdm -p UPA19_3.adm.COASTN_JomonM_${i}_Bbdong_out5.par > UPA19_3.adm.COASTN_JomonM_${i}_Bbdong_out5.log; done &
# for i in Jomon; do qpAdm -p UPA19_3.adm.COASTN_JomonM_${i}_Boshan_out5.par > UPA19_3.adm.COASTN_JomonM_${i}_Boshan_out5.log; done &
# for i in Jomon; do qpAdm -p UPA19_3.adm.COASTN_JomonM_${i}_Xiaogao_out5.par > UPA19_3.adm.COASTN_JomonM_${i}_Xiaogao_out5.log; done &
# for i in Jomon; do qpAdm -p UPA19_3.adm.COASTN_JomonM_${i}_XJS_out5.par > UPA19_3.adm.COASTN_JomonM_${i}_XJS_out5.log; done &
# for i in Jomon; do qpAdm -p UPA19_3.adm.COASTN_JomonM_${i}_XJS_F_out5.par > UPA19_3.adm.COASTN_JomonM_${i}_XJS_F_out5.log; done &
# for i in Jomon; do qpAdm -p UPA19_3.adm.COASTN_JomonM_${i}_Linzi_out5.par > UPA19_3.adm.COASTN_JomonM_${i}_Linzi_out5.log; done &
# for i in Jomon; do qpAdm -p UPA19_3.adm.COASTN_JomonM_${i}_Qihe_out5.par > UPA19_3.adm.COASTN_JomonM_${i}_Qihe_out5.log; done &
# for i in Jomon; do qpAdm -p UPA19_3.adm.COASTN_JomonM_${i}_LiangDaoF_out5.par > UPA19_3.adm.COASTN_JomonM_${i}_LiangDaoF_out5.log; done &
# for i in Jomon; do qpAdm -p UPA19_3.adm.COASTN_JomonM_${i}_LiangDaoM_out5.par > UPA19_3.adm.COASTN_JomonM_${i}_LiangDaoM_out5.log; done &
# for i in Jomon; do qpAdm -p UPA19_3.adm.COASTN_JomonM_${i}_Suogang_out5.par > UPA19_3.adm.COASTN_JomonM_${i}_Suogang_out5.log; done &
# for i in Jomon; do qpAdm -p UPA19_3.adm.COASTN_JomonM_${i}_Ami_out5.par > UPA19_3.adm.COASTN_JomonM_${i}_Ami_out5.log; done &
# for i in Jomon; do qpAdm -p UPA19_3.adm.COASTN_JomonM_${i}_Ma555_G6_out5.par > UPA19_3.adm.COASTN_JomonM_${i}_Ma555_G6_out5.log; done &
# for i in Jomon; do qpAdm -p UPA19_3.adm.COASTN_JomonM_${i}_Xinyi_out5.par > UPA19_3.adm.COASTN_JomonM_${i}_Xinyi_out5.log; done &
# for i in Jomon; do qpAdm -p UPA19_3.adm.COASTN_JomonM_${i}_Dushan_out5.par > UPA19_3.adm.COASTN_JomonM_${i}_Dushan_out5.log; done &
# for i in Jomon; do qpAdm -p UPA19_3.adm.COASTN_JomonM_${i}_Boisman_MN_out5.par > UPA19_3.adm.COASTN_JomonM_${i}_Boisman_MN_out5.log; done &
# for i in Jomon; do qpAdm -p UPA19_3.adm.COASTN_JomonM_${i}_DevilsGate_out5.par > UPA19_3.adm.COASTN_JomonM_${i}_DevilsGate_out5.log; done &
# for i in Jomon; do qpAdm -p UPA19_3.adm.COASTN_JomonM_${i}_Shamanka_EN_out5.par > UPA19_3.adm.COASTN_JomonM_${i}_Shamanka_EN_out5.log; done &
# for i in Jomon; do qpAdm -p UPA19_3.adm.COASTN_JomonM_${i}_HDYM1_out5.par > UPA19_3.adm.COASTN_JomonM_${i}_HDYM1_out5.log; done &
# for i in Jomon; do qpAdm -p UPA19_3.adm.COASTN_JomonM_${i}_Kolyma_River_out5.par > UPA19_3.adm.COASTN_JomonM_${i}_Kolyma_River_out5.log; done &

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/qpadm_north/"
fh="UPA19_3"
name="COASTN"
pt="adm"
out="out5"
south=["Suogang","Qihe","Qihe_d","LiangDaoF","LiangDaoM","Ma555_G6"]
north=["JomonM","ZongriM297","Hejiatai","PukagongmaM5","Chokhopani",
       "Kolyma_River","Shamanka_EN","HDYM1",
       "DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao","XJS","XJS_F" ]        
central=["Longlin","Baojianshan","Dushan",
         "ZhaoguoM2","Daxi","Dashuitian",
         "DonghulinM1","Jiahu_M52_I2","Tianluoshan","Liangzhu_T4620"]
seas=["Ma912_G2","La727_G2","Vt880_G2","Vt833_G2","Man_Bac","Nui_Nap",
      "Vt719_G3_1","Vt777_G3","Th521_G4","Oakaie1"]
pdeas=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean","Han","Tujia","She","Miao",
      "Naxi","Yi","Dai","Kinh","Lahu","Ami","Atayal"]
coastalnorth=["Bbdong","Boshan","Xiaogao","XJS","XJS_F","Linzi"]
south=["Qihe","LiangDaoF","LiangDaoM","Suogang","Ami","Ma555_G6","Xinyi","Dushan"]
sib=["Boisman_MN","DevilsGate","Shamanka_EN","HDYM1","Kolyma_River"]
aJapan=["JomonM","Jomon"]
targets=coastalnorth+south+sib
s1s=coastalnorth+south+sib
s2s=["JomonM"]
for s2 in s2s:
    for target in targets:
        for s1 in s1s: 
            if s1 == target: continue
            if s2==target: continue
            if s1==s2: continue
            label="%s_%s_%s_%s_%s" % (name,target,s1,s2,out)
            ff.parfile(pD,fh,pt,label,outpd=outpd,outgroup=fh+"."+out)
            ff.mklst(outpd,fh,pt+"."+label,[target,s1,s2],suffix="leftpop")
        
        mytuple=(fh,pt,"%s_%s_%s_%s_%s" % (name,target,"${i}",s2,out))
        print "for i in %s; do " % " ".join(s1s)+"qpAdm -p {0}.{1}.{2}.par > {0}.{1}.{2}.log; done &".format(*mytuple)
# Out:
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Bbdong_${i}_JomonM_out5.par > UPA19_3.adm.COASTN_Bbdong_${i}_JomonM_out5.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Boshan_${i}_JomonM_out5.par > UPA19_3.adm.COASTN_Boshan_${i}_JomonM_out5.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Xiaogao_${i}_JomonM_out5.par > UPA19_3.adm.COASTN_Xiaogao_${i}_JomonM_out5.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_XJS_${i}_JomonM_out5.par > UPA19_3.adm.COASTN_XJS_${i}_JomonM_out5.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_XJS_F_${i}_JomonM_out5.par > UPA19_3.adm.COASTN_XJS_F_${i}_JomonM_out5.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Linzi_${i}_JomonM_out5.par > UPA19_3.adm.COASTN_Linzi_${i}_JomonM_out5.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Qihe_${i}_JomonM_out5.par > UPA19_3.adm.COASTN_Qihe_${i}_JomonM_out5.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_LiangDaoF_${i}_JomonM_out5.par > UPA19_3.adm.COASTN_LiangDaoF_${i}_JomonM_out5.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_LiangDaoM_${i}_JomonM_out5.par > UPA19_3.adm.COASTN_LiangDaoM_${i}_JomonM_out5.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Suogang_${i}_JomonM_out5.par > UPA19_3.adm.COASTN_Suogang_${i}_JomonM_out5.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Ami_${i}_JomonM_out5.par > UPA19_3.adm.COASTN_Ami_${i}_JomonM_out5.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Ma555_G6_${i}_JomonM_out5.par > UPA19_3.adm.COASTN_Ma555_G6_${i}_JomonM_out5.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Xinyi_${i}_JomonM_out5.par > UPA19_3.adm.COASTN_Xinyi_${i}_JomonM_out5.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Dushan_${i}_JomonM_out5.par > UPA19_3.adm.COASTN_Dushan_${i}_JomonM_out5.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Boisman_MN_${i}_JomonM_out5.par > UPA19_3.adm.COASTN_Boisman_MN_${i}_JomonM_out5.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_DevilsGate_${i}_JomonM_out5.par > UPA19_3.adm.COASTN_DevilsGate_${i}_JomonM_out5.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Shamanka_EN_${i}_JomonM_out5.par > UPA19_3.adm.COASTN_Shamanka_EN_${i}_JomonM_out5.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_HDYM1_${i}_JomonM_out5.par > UPA19_3.adm.COASTN_HDYM1_${i}_JomonM_out5.log; done &
# for i in Bbdong Boshan Xiaogao XJS XJS_F Linzi Qihe LiangDaoF LiangDaoM Suogang Ami Ma555_G6 Xinyi Dushan Boisman_MN DevilsGate Shamanka_EN HDYM1 Kolyma_River; do qpAdm -p UPA19_3.adm.COASTN_Kolyma_River_${i}_JomonM_out5.par > UPA19_3.adm.COASTN_Kolyma_River_${i}_JomonM_out5.log; done &

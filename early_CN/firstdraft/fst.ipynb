# %%
import numpy as np
import matplotlib.pyplot as plt

def txt2ary(pd,fh,rownames=True,colnames=True):
    myfile=open(pd+fh,'r')
    rn=[]
    for ind,line in enumerate(myfile):
        x=line.split()
        if ind==0:
            ncols=len(x) if colnames==False else len(x)-1
            nrows=0 if rownames==False else 1
            myary=np.zeros((1,ncols))
            cn=x[1:]
            continue
        myrow=np.array([float(i) for i in x[nrows:]])
        myary=np.vstack((myary,myrow))
        rn.append(x[0])
    return (myary[1:,:],rn,cn)
pd="/mnt/solexa/mel_yang/early_CN/firstdraft/fst/"
ids0=['CLEG', 'WLE', 'EHE', 'NLE', 'WHE', 'Hezhen', 'Han', 'Ulchi', 'CHE', 
      'HLE', 'CLEL', 'HHE', 'Han_HenanX', 'Han_GansuX', 'Shamanka_EN']
wanted=["Han","Han_HenanX","Han_GansuX","Shamanka_EN"]
fstary,rnf,cnf=txt2ary(pd,"fst.comb0.txt")
seary,rns,cns=txt2ary(pd,"se.comb0.txt")
fstary=fstary/1000
seary=seary/1000000
fstary[fstary==0]=np.nan
seary[seary==0]=np.nan
print rnf, cnf
colors=["red","blue","purple","brown"]
labels=["WHE","EHE","CLEG"]
offsets=[-0.1,0,0.1]
fig = plt.figure()
ax1=fig.add_subplot(1,1,1)
colind=0
for row,myid in enumerate(fstary):
    if rnf[row] not in labels: continue
    for ind1,myid2 in enumerate(wanted):
        col=rnf.index(myid2)
        #print myid2
        #print col, ind1, myid2
        if ind1==0:
            ax1.errorbar(ind1+offsets[colind],fstary[row,col],yerr=2*seary[row,col],color=colors[colind],markeredgecolor="black",markersize=10,fmt='o',label=labels[colind])
        else:
            ax1.errorbar(ind1+offsets[colind],fstary[row,col],yerr=2*seary[row,col],color=colors[colind],markeredgecolor="black",markersize=10,fmt='o')
    colind+=1
    myys = np.array(range(len(wanted)))
    ax1.set_xticks(myys)
    #ax1.set_xlabel("X",fontsize=15,rotation=90)
    ax1.set_xticklabels(wanted,rotation=45)
plt.legend(loc="upper left")
plt.show()
# Out:
# ['CLEG', 'WLE', 'EHE', 'NLE', 'WHE', 'Hezhen', 'Han', 'Ulchi', 'CHE', 'HLE', 'CLEL', 'HHE', 'Han_HenanX', 'Han_GansuX', 'Shamanka_EN'] ['CLEG', 'WLE', 'EHE', 'NLE', 'WHE', 'Hezhen', 'Han', 'Ulchi', 'CHE', 'HLE', 'CLEL', 'HHE', 'Han_HenanX', 'Han_GansuX', 'Shamanka_EN']

# %%
import numpy as np
import matplotlib.pyplot as plt

def txt2ary(pd,fh,rownames=True,colnames=True):
    myfile=open(pd+fh,'r')
    rn=[]
    for ind,line in enumerate(myfile):
        x=line.split()
        if ind==0:
            ncols=len(x) if colnames==False else len(x)-1
            nrows=0 if rownames==False else 1
            myary=np.zeros((1,ncols))
            cn=x[1:]
            continue
        myrow=np.array([float(i) for i in x[nrows:]])
        myary=np.vstack((myary,myrow))
        rn.append(x[0])
    return (myary[1:,:],rn,cn)
pd="/mnt/solexa/mel_yang/early_CN/firstdraft/fst/"

wanted=["Han","Han_HenanX","Han_GansuX","Shamanka_EN","Hezhen","Ulchi","CLEL"]
wantedlabels=["Han_SGDP","Han_Henan","Han_Gansu","Shamanka_EN","Hezhen","Ulchi","GQ<3900BP"]
fstary,rnf,cnf=txt2ary(pd,"fst.comb1.txt")
seary,rns,cns=txt2ary(pd,"se.comb1.txt")
fstary=fstary/1000
seary=seary/1000000
fstary[fstary==0]=np.nan
seary[seary==0]=np.nan
#print rnf, cnf
colors=["red","blue","purple","brown"]
labels=["WHE","CHE","CLEG","WLE"]
newlabels=["West Plateau","East Plateau","GQ>3900BP","Zongri"]
offsets=[-0.3,-0.1,0.1,0.3]
fig = plt.figure()
ax1=fig.add_subplot(1,1,1)
colind=0
for ind1,myid in enumerate(labels):
    row=rnf.index(myid)
    for ind2,myid2 in enumerate(wanted):
        col=rnf.index(myid2)
        #print myid2
        #print col, ind1, myid2
        #print rnf[row], rnf[col], fstary[row,col]
        if ind2==0:
            ax1.errorbar(ind2+offsets[colind],fstary[row,col],yerr=2*seary[row,col],color=colors[colind],markeredgecolor="black",markersize=8,fmt='o',label=newlabels[colind])
        else:
            ax1.errorbar(ind2+offsets[colind],fstary[row,col],yerr=2*seary[row,col],color=colors[colind],markeredgecolor="black",markersize=8,fmt='o')
    colind+=1
    myys = np.array(range(len(wanted)))
    ax1.set_xticks(myys)
    #ax1.set_xlabel("X",fontsize=15,rotation=90)
    ax1.set_xticklabels(wantedlabels,rotation=45)
plt.legend(loc="lower left")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def txt2ary(pd,fh,rownames=True,colnames=True):
    myfile=open(pd+fh,'r')
    rn=[]
    for ind,line in enumerate(myfile):
        x=line.split()
        if ind==0:
            ncols=len(x) if colnames==False else len(x)-1
            nrows=0 if rownames==False else 1
            myary=np.zeros((1,ncols))
            cn=x[1:]
            continue
        myrow=np.array([float(i) for i in x[nrows:]])
        myary=np.vstack((myary,myrow))
        rn.append(x[0])
    return (myary[1:,:],rn,cn)
pd="/mnt/solexa/mel_yang/aPlateau/fst/"

wanted=["Han","Han_HenanX","Han_GansuX","Shamanka_EN.SG","Hezhen","Ulchi","Tibetan_ShannanX","Tibetan_ChamdoX","Tibetan_NagquX"] #,"CLEL"]
wantedlabels=["Han_SGDP","Han_Henan","Han_Gansu","Shamanka_EN","Hezhen","Ulchi","T_Shannan","T_Chamdo","T_Nagqu"] #,"GQ<3900BP"]


fstary,rnf,cnf=txt2ary(pd,"fst.comb0eurtib.txt")
seary,rns,cns=txt2ary(pd,"se.comb0eurtib.txt")
fstary=fstary/1000
seary=seary/1000000
fstary[fstary==0]=np.nan
seary[seary==0]=np.nan
#print rnf, cnf
colors=["red","blue","purple","brown","gray","orange"]
labels=["WHE","CHE","CLEG","EHE","WLE","CLEL"]
newlabels=["western aTQ","eastern aTQ_1","eastern aTQ_2","aGQ>3900BP_1","aGQ>3900BP_2","aGQ<3900BP_1"]
offsets=[-0.3,-0.2,-0.1,0,0.1,0.2]
fig = plt.figure(figsize=(13,4))
ax1=fig.add_subplot(1,1,1)
colind=0
for ind1,myid in enumerate(labels):
    row=rnf.index(myid)
    for ind2,myid2 in enumerate(wanted):
        col=rnf.index(myid2)
        #print myid2
        #print col, ind1, myid2
        #print rnf[row], rnf[col], fstary[row,col]
        if ind2==0:
            ax1.errorbar(ind2+offsets[colind],fstary[row,col],yerr=2*seary[row,col],color=colors[colind],markeredgecolor="black",markersize=8,fmt='o',label=newlabels[colind])
        else:
            ax1.errorbar(ind2+offsets[colind],fstary[row,col],yerr=2*seary[row,col],color=colors[colind],markeredgecolor="black",markersize=8,fmt='o')
    colind+=1
    myys = np.array(range(len(wanted)))
    ax1.set_xticks(myys)
    ax1.set_ylabel("Fst",fontsize=15)
    ax1.set_xticklabels(wantedlabels,rotation=45)
    ax1.set_ylim((0,0.06))
plt.legend(loc="upper left",ncol=2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def txt2ary(pd,fh,rownames=True,colnames=True):
    myfile=open(pd+fh,'r')
    rn=[]
    for ind,line in enumerate(myfile):
        x=line.split()
        if ind==0:
            ncols=len(x) if colnames==False else len(x)-1
            nrows=0 if rownames==False else 1
            myary=np.zeros((1,ncols))
            cn=x[1:]
            continue
        myrow=np.array([float(i) for i in x[nrows:]])
        myary=np.vstack((myary,myrow))
        rn.append(x[0])
    return (myary[1:,:],rn,cn)
pd="/mnt/solexa/mel_yang/aPlateau/fst/"

wanted=["EHE","CHE","WLE","CLEG","NLE","CLEL"]
wantedlabels=["Pukagongma","Central Tibet","Zongri","eastern aGQ>3900BP","Wuba/Huoshaogou","aGQ<3900BP"]
fstary,rnf,cnf=txt2ary(pd,"fst.comb0eurtib.txt")
seary,rns,cns=txt2ary(pd,"se.comb0eurtib.txt")
fstary=fstary/1000
seary=seary/1000000
fstary[fstary==0]=np.nan
seary[seary==0]=np.nan
#print rnf, cnf
colors=["red","blue","purple","brown","gray","black"]
labels=["WHE","CHE","CLEG","WLE","Tibetan_ShannanX","Tibetan_NagquX"]
newlabels=["western aTQ","eastern aTQ","eastern aGQ>3900BP","Zongri","T_Shannan","T_Nagqu"]
offsets=[-0.24,-0.16,-0.08,0.08,0.16,0.24]
fig = plt.figure(figsize=(9,4))
ax1=fig.add_subplot(1,1,1)
colind=0
for ind1,myid in enumerate(labels):
    row=rnf.index(myid)
    for ind2,myid2 in enumerate(wanted):
        col=rnf.index(myid2)
        #print myid2
        #print col, ind1, myid2
        #print rnf[row], rnf[col], fstary[row,col]
        if ind2==0:
            ax1.errorbar(ind2+offsets[colind],fstary[row,col],yerr=2*seary[row,col],color=colors[colind],markeredgecolor="black",markersize=8,fmt='o',label=newlabels[colind])
        else:
            ax1.errorbar(ind2+offsets[colind],fstary[row,col],yerr=2*seary[row,col],color=colors[colind],markeredgecolor="black",markersize=8,fmt='o')
    colind+=1
    myys = np.array(range(len(wanted)))
    ax1.set_xticks(myys)
    ax1.set_ylabel("Fst",fontsize=15)
    ax1.set_ylim((0,0.06))
    ax1.set_xticklabels(wantedlabels,rotation=45)
plt.legend(loc="upper left",ncol=2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def txt2ary(pd,fh,rownames=True,colnames=True):
    myfile=open(pd+fh,'r')
    rn=[]
    for ind,line in enumerate(myfile):
        x=line.split()
        if ind==0:
            ncols=len(x) if colnames==False else len(x)-1
            nrows=0 if rownames==False else 1
            myary=np.zeros((1,ncols))
            cn=x[1:]
            continue
        myrow=np.array([float(i) for i in x[nrows:]])
        myary=np.vstack((myary,myrow))
        rn.append(x[0])
    return (myary[1:,:],rn,cn)
pd="/mnt/solexa/mel_yang/aPlateau/fst/"

wanted=["EHE","CHE","WLE","CLEG","NLE","CLEL"]
wantedlabels=["Pukagongma","Central Tibet","Zongri","eastern aGQ>3900BP","N. Gansu","aGQ<3900BP"]
fstary,rnf,cnf=txt2ary(pd,"fst.comb0eurtib.txt")
seary,rns,cns=txt2ary(pd,"se.comb0eurtib.txt")
fstary=fstary/1000
seary=seary/1000000
fstary[fstary==0]=np.nan
seary[seary==0]=np.nan
#print rnf, cnf
colors=["red","blue","purple","brown","gray","black"]
labels=["CHE","EHE","WHE"]
newlabels=["eastern aTQ (Central Tibet)",'eastern aTQ (Pukagongma)',"western aTQ"]
offsets=[-0.24,-0.16,-0.08,0.08,0.16,0.24]
fig = plt.figure(figsize=(9,4))
ax1=fig.add_subplot(1,1,1)
colind=0
for ind1,myid in enumerate(labels):
    row=rnf.index(myid)
    for ind2,myid2 in enumerate(wanted):
        col=rnf.index(myid2)
        #print myid2
        #print col, ind1, myid2
        #print rnf[row], rnf[col], fstary[row,col]
        if ind2==0:
            ax1.errorbar(ind2+offsets[colind],fstary[row,col],yerr=2*seary[row,col],color=colors[colind],markeredgecolor="black",markersize=8,fmt='o',label=newlabels[colind])
        else:
            ax1.errorbar(ind2+offsets[colind],fstary[row,col],yerr=2*seary[row,col],color=colors[colind],markeredgecolor="black",markersize=8,fmt='o')
    colind+=1
    myys = np.array(range(len(wanted)))
    ax1.set_xticks(myys)
    ax1.set_ylabel("Fst",fontsize=15)
    ax1.set_ylim((0,0.065))
    ax1.set_xticklabels(wantedlabels,rotation=45)
plt.legend(loc="upper left",ncol=2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def txt2ary(pd,fh,rownames=True,colnames=True):
    myfile=open(pd+fh,'r')
    rn=[]
    for ind,line in enumerate(myfile):
        x=line.split()
        if ind==0:
            ncols=len(x) if colnames==False else len(x)-1
            nrows=0 if rownames==False else 1
            myary=np.zeros((1,ncols))
            cn=x[1:]
            continue
        myrow=np.array([float(i) for i in x[nrows:]])
        myary=np.vstack((myary,myrow))
        rn.append(x[0])
    return (myary[1:,:],rn,cn)
pd="/mnt/solexa/mel_yang/aPlateau/fst/"

wanted=["EHE","CHE","WLE","CLEG","NLE","CLEL"]
wantedlabels=["Pukagongma","Central Tibet","Zongri","eastern aGQ>3900BP","N. Gansu","aGQ<3900BP"]
fstary,rnf,cnf=txt2ary(pd,"fst.comb0eurtib.txt")
seary,rns,cns=txt2ary(pd,"se.comb0eurtib.txt")
fstary=fstary/1000
seary=seary/1000000
fstary[fstary==0]=np.nan
seary[seary==0]=np.nan
#print rnf, cnf
colors=["black","gray","orange","green"]
labels=["WLE","CLEG","NLE","CLEL"]
newlabels=["aGQ>3900BP (Zongri)",'aGQ>3900BP (eastern)',"aGQ<3900BP (N. Gansu)","aGQ<3900BP (others)"]
offsets=[-0.16,-0.08,0.08,0.16]
fig = plt.figure(figsize=(9,4))
ax1=fig.add_subplot(1,1,1)
colind=0
for ind1,myid in enumerate(labels):
    row=rnf.index(myid)
    for ind2,myid2 in enumerate(wanted):
        col=rnf.index(myid2)
        #print myid2
        #print col, ind1, myid2
        #print rnf[row], rnf[col], fstary[row,col]
        if ind2==0:
            ax1.errorbar(ind2+offsets[colind],fstary[row,col],yerr=2*seary[row,col],color=colors[colind],markeredgecolor="black",markersize=8,fmt='o',label=newlabels[colind])
        else:
            ax1.errorbar(ind2+offsets[colind],fstary[row,col],yerr=2*seary[row,col],color=colors[colind],markeredgecolor="black",markersize=8,fmt='o')
    colind+=1
    myys = np.array(range(len(wanted)))
    ax1.set_xticks(myys)
    ax1.set_ylabel("Fst",fontsize=15)
    ax1.set_ylim((0,0.065))
    ax1.set_xticklabels(wantedlabels,rotation=45)
plt.legend(loc="upper left",ncol=2)
plt.show()

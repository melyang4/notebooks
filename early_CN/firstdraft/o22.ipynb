# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"
# name="B1" #
# name="PDEASB1"
# target="Shamanka_EN"
# suffix="_SS"
# out="o22+LBHCZ"
# #for target in Samdzong Mebrak Chokhopani Hejiatai PukagongmaM5 RedilongM3 Butaxiongqu Shamanka_EN Qihe Man_Bac Suogang Boshan XJS_F Xiaogao LG2 Vt833_G2 Vt880_G2 Nui_Nap Ban_Chiang Oakaie1 MG6 Phl534_G6; do
# #for target in Han Ami Dai Atayal Lahu Daur Hezhen Tibetan_ShannanX Tibetan_ChamdoX Miao She Korean Japanese Tujia Naxi Yi; do
# #for target in Ulchi Oroqen Xibo Uygur Sherpa_ShigatseX Tibetan_ShigatseX Tibetan_LhasaX Tibetan_NagquX Tibetan Sherpa Han_HenanX Han_GansuX Han_XinjiangX Han_HenanX Han_ShandongX Han_JiangsuX Han_AnhuiX Han_SichuanX Han_HubeiX Han_GuangdongX Han_ChongqingX Kinh; do
# for target in Oroqen; do
#     grep "f4rank: 0" ${pd}${name}/UPA19_3.adm.${name}${suffix}_${target}_*_${out}.log | awk '{ if ($8>0.05) print $1,$8}' | cut -d'/' -f9 | cut -d':' -f1,3
#     done
# Out:
# UPA19_3.adm.PDEASB1_SS_Oroqen_Kostenki14_o22+LBHCZ.log: 3.59885038e-312

# %% [markdown]
# Do DS for Shamanka_EN, Suogang, Boshan, Vt833_G2, Nui_Nap, MG6
# Do DS for Han Ami Dai Atayal Lahu Hezhen Sherpa_ShigatseX Miao She Korean Japanese Tujia Naxi Kinh Ulchi Oroqen Xibo Uygur
#
# ```
# python generalDS.py 20 B1 o22+LBHCZ Shamanka_EN 0 &
#
# for i in Naxi Kinh Ulchi Oroqen Xibo Uygur; do python generalDS.py 20 PDEASB1 o22+LBHCZ ${i} 0; done &
#
# for i in Han_HenanX Han_JiangsuX Han_SichuanX Han_HubeiX Han_GuangdongX Han_ChongqingX; do python generalDS.py 20 PDEASB1 o22+LBHCZ ${i} 0; done &
# ```
#
# Trying all DS for the above. Check these when done and do TS as needed. Need to return to think about if any of the outgroup are mixtures of each other!

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"
# name="PDEAS" #
# name="B1" #
# name="PDEASB1"
# target="Han_GuangdongX"
# suffix="_DS"
# out="o22+LBHCZ"
# for target in ${target}; do
#     grep "f4rank: 1" ${pd}${name}/UPA19_3.adm.${name}${suffix}_${target}_*_${out}.log | awk '{ if ($8>0.05) print $1,$8}' | cut -d'/' -f9 | cut -d':' -f1,3
#     myfile=$(grep "f4rank: 1" ${pd}${name}/UPA19_3.adm.${name}${suffix}_${target}_*_${out}.log | awk '{ if ($8>0.05) print $1,$8}' | cut -d'/' -f9 | cut -d':' -f1)
#     for i in ${myfile}; do
#         echo " ~~~~~~~~~~~~~~~~~~~~~~~ "
#         echo ${i}
#         tail -n236 ${pd}${name}/${i} | head -n8
#         done
#     done
# Out:
# grep: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/PDEASB1/UPA19_3.adm.PDEASB1_DS_Han_GuangdongX_*_o22+LBHCZ.log: No such file or directory
# grep: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/PDEASB1/UPA19_3.adm.PDEASB1_DS_Han_GuangdongX_*_o22+LBHCZ.log: No such file or directory

# %% [markdown]
# Do TS for Shamanka, Vt833, MG6
# Do TS for Han Ami Dai Atayal Lahu Hezhen Miao Korean Japanese Tujia Naxi Ulchi Uygur
#
# for i in Han Ami Dai Atayal Lahu Hezhen; do python generalTS.py 20 B1 o22+LBHCZ ${i} 12; done &
#
# for i in Miao Korean Japanese Tujia Naxi Ulchi Uygur; do python generalTS.py 20 B1 o22+LBHCZ ${i} 12; done &

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"
# name="PDEAS" #
# name="B1" #
# #name="PDEASB1"
# target="MG6"
# suffix="_TS"
# out="o22+LBHCZ"
# for target in ${target}; do
#     grep "f4rank: 2" ${pd}${name}/UPA19_3.adm.${name}${suffix}_${target}_*_${out}.log | awk '{ if ($8>0.05) print $1,$8}' | cut -d'/' -f9 | cut -d':' -f1,3
#     myfile=$(grep "f4rank: 2" ${pd}${name}/UPA19_3.adm.${name}${suffix}_${target}_*_${out}.log | awk '{ if ($8>0.05) print $1,$8}' | cut -d'/' -f9 | cut -d':' -f1)
#     for i in ${myfile}; do
#         echo " ~~~~~~~~~~~~~~~~~~~~~~~ "
#         echo ${i}
#         tail -n236 ${pd}${name}/${i} | head -n13
#         done
#     done
# Out:
# UPA19_3.adm.B1_TS_MG6_Bbdong_Chokhopani_IndusPeriphery_o22+LBHCZ.log: 0.37616364
# UPA19_3.adm.B1_TS_MG6_Bbdong_Chokhopani_Iran_N_o22+LBHCZ.log: 0.400544018
# UPA19_3.adm.B1_TS_MG6_Bbdong_Chokhopani_Kostenki14_o22+LBHCZ.log: 0.39738082
# UPA19_3.adm.B1_TS_MG6_Bbdong_Chokhopani_Mota_o22+LBHCZ.log: 0.343741618
# UPA19_3.adm.B1_TS_MG6_Bbdong_Chokhopani_Okunevo_EMBA_o22+LBHCZ.log: 0.237354257
# UPA19_3.adm.B1_TS_MG6_Bbdong_Chokhopani_UstIshim_o22+LBHCZ.log: 0.420282371
# UPA19_3.adm.B1_TS_MG6_Bbdong_Chokhopani_Yana_o22+LBHCZ.log: 0.285780836
# UPA19_3.adm.B1_TS_MG6_Bbdong_HDYM1_Iran_N_o22+LBHCZ.log: 0.0576205392
# UPA19_3.adm.B1_TS_MG6_Bbdong_HDYM1_Okunevo_EMBA_o22+LBHCZ.log: 0.10089377
# UPA19_3.adm.B1_TS_MG6_Bbdong_HDYM1_UstIshim_o22+LBHCZ.log: 0.0621352889
# UPA19_3.adm.B1_TS_MG6_Bbdong_IndusPeriphery_Ma912_G2_o22+LBHCZ.log: 0.0639054925
# UPA19_3.adm.B1_TS_MG6_Bbdong_IndusPeriphery_ZongriM297_o22+LBHCZ.log: 0.518164406
# ...

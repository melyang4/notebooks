# %%
##Qihe_d

import fstat_funcs as ff

pD="/mnt/solexa/mel_yang/early_CN/"
outpd="/mnt/solexa/mel_yang/early_CN/firstdraft/InnerNorth/"
fh="F4.list.F4"
#fh="F4.list.F4tv"
out="Mbuti"        
low=["ZongriM297","ZongriM1","Zongri-c","ZongriM32","ZongriM40",#"ZongriM78", #
     "Dazhuang0","Hedong6","Hejiatai","LiuwanQH-1","XiahaishiM9",# #"XiahaishiM22",
     "Hupo-a","Sanheyi11",  #"Hupo14","Shangluzhuang0", #
     "Wuba","HuoshaogouM117",
     "Jinchankou0","QijiapingM108-2","QijiapingM89-2","QijiapingM104-2", # #"Wenpuju03",
     "Lajigai3","Lierbao0","Hedong4"] #"Qunke1","Hupo8", #"Lajigai2",
high=["PukagongmaM1","PukagongmaM5", #"PukagongmaM3", #"PukagongmaM2",
     "Butaxiongqu","RedilongM3","XiaoendaM2", #"XiaoendaM1", #
     "Chokhopani","Mebrak","Samdzong","ChaxiutangJ2-13","YushuSGZ-1"]
ns=["Qihe","LiangDaoF","LiangDaoM","Suogang","Bbdong","Boshan","XJS","XJS_F","Xiaogao","HDYM1"]
eeur=["Tianyuan","Papuan","Onge","La368_G1","JomonM","Jomon","Kolyma_River","DevilsGate",
      "Longlin","Baojianshan","Dushan","Shamanka_EN","ZongriM297","Hejiatai","Chokhopani"]
innerN=["HDYM1","ZongriM297","Hejiatai","Chokhopani","Shamanka_EN"]
coastN=["Bbdong","Boshan","XJS","XJS_F","Xiaogao"]
coastSo=["Qihe","LiangDaoF","LiangDaoM"]
coastSy=["Suogang","Ma555_G6","Ami","Atayal"]
mylst1=low+high
mylst2=[innerN[-1]]+coastN+coastSo+coastSy
out="Mbuti"
for myind in ["HDYM1"]:
    print myind
    pops=[out,mylst1,myind,mylst2]
    ff.Dmat2xlsx(ff.Dmkary(pD,fh,pops,"Z"),outpd+"Z.P2a_"+myind+".NSvPlat_HDYM1_o%s." % out+fh,ff.Dmklabel(pops),mylst1,mylst2)
    
    pops=[out,mylst2,myind,mylst1]
    ff.Dmat2xlsx(ff.Dmkary(pD,fh,pops,"Z"),outpd+"Z.P2b_"+myind+".NSvPlat_HDYM1_o%s." % out+fh,ff.Dmklabel(pops),mylst2,mylst1)

    pops=[out,myind,mylst1,mylst2]
    ff.Dmat2xlsx(ff.Dmkary(pD,fh,pops,"Z"),outpd+"Z.P3_"+myind+".NSvEEUR_Han_o%s." % out+fh,ff.Dmklabel(pops),mylst1,mylst2)
# Out:
# HDYM1

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import rcParams
import matplotlib
#plt.style.use('classic')
#rcParams['font.family'] = 'Helvetica'
rcParams['font.family'] = 'Helvetica-Normal'
plt.style.use('fivethirtyeight')
plt.style.use('seaborn-white')
#matplotlib.rc('font', family='sans-serif') 
#matplotlib.rc('font', serif='Helvetica') 

pD="/mnt/solexa/mel_yang/early_CN/"
fhall="F4.list.F4"
fhtv="F4.list.F4tv"
out,out2=("Mbuti","Mbuti")

innerN=["HDYM1","ZongriM297","Hejiatai","Chokhopani","Shamanka_EN"]
coastN=["Bbdong","Boshan","XJS_F","Xiaogao"] #"XJS",
coastSo=["Qihe","LiangDaoF","LiangDaoM"]
coastSy=["Suogang","Ma555_G6","Ami","Atayal"]
anc=["Tianyuan","La368_G1","JomonM","DevilsGate"] #,"Kolyma_River"
seasia=["Man_Bac","Nui_Nap","Oakaie1","Ban_Chiang","Vt833_G2","Vt880_G2",
        "La727_G2","Ma912_G2","Th521_G4","Vt777_G3"]
others=["Mixe","Surui","Papuan","Onge"]
aeas=anc+innerN+coastN+coastSo+coastSy+seasia+others
mycombo=aeas
mynames=mycombo[:]
#mynames[mynames.index("Zongri-a")]="ZongriM297"

wantedcolors=["blue"]*len(mycombo)
myxmin=[-0.01]*len(mycombo)
myxmax=[0.01]*len(mycombo)

fig = plt.figure(figsize=(11,10))
newfile=open(pD+"collecteddat.txt",'w')
myancsets=[("Qihe","Bbdong"),("Qihe","HDYM1"),("Bbdong","HDYM1")]
for indpair,mypair in enumerate(myancsets):
    newfile.write("Qihe v Bbdong\n")
    ax1=fig.add_subplot(1,3,indpair+1)
    myind=mypair[0]
    varypop=mypair[1]
    ypops=mycombo
    mytuples=[(0,3),(1,2)]
    #mypops2=[myind,[varypop],ypops,out]
    mypops2=[out,ypops,[varypop],myind]
    Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
    Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
    Zaryall=np.transpose(Zaryall)
    Daryall=np.transpose(Daryall)
    SEaryall=Daryall/Zaryall 
    mynewpops2=mypops2[:-1]+[out2]
    Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
    Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
    Zarytv=np.transpose(Zarytv)
    Darytv=np.transpose(Darytv)
    SEarytv=Darytv/Zarytv

    mylabel="D(%s,%s;%s,%s)\n%s              %s" % (mypops2[3],mypops2[2][0],'X',mypops2[0],mypair[0],mypair[1]) #mypops2[1][0],mypops2[0])
    mylabel="%s                       %s" % (mypair[1],mypair[0]) #mypops2[1][0],mypops2[0])
    mec="black"
    for ind,i in enumerate(ypops):
        if i in innerN: wantedcolors="red"
        elif i in coastN: wantedcolors="blue"
        elif i in coastSo+coastSy: wantedcolors="yellow"
        elif i in anc: wantedcolors="gray"
        elif i in seasia: wantedcolors="brown"
        elif i in others: wantedcolors="purple"
        else: wantedcolors="orange"
        #if i in innerN+coastN+coastSo+coastSy: wantedcolors="#fff06d" #"#fffacd" #"red"
        #else: wantedcolors="#84cdeb"#"#c9e9f6" #"blue"
        ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.5,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.5,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[0][ind],ind,'.',alpha=0.5)
        print mypair[0],mypair[1], i, Daryall[0][ind], SEaryall[0][ind]
        ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[0][ind],ind,'.')
    myys = np.array(range(len(mynames)))
    if indpair==0:
        ax1.set_yticks(myys)
        ax1.set_ylabel("X",fontsize=15,rotation=90)
        ax1.set_yticklabels(mynames)#,fontsize=12)
    else: ax1.set_yticklabels(['' for i in mynames])

    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[0],myxmax[0])
    xlabel = ax1.get_xticks().tolist()
    ax1.set_title(mylabel,fontsize=15,weight='bold')
    ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
    for myline in [3.5,12.5,19.5,29.5,31.5]: #[4.5,13.5,20.5,30.5,32.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)

    ax1.set_xlabel("D") #,fontsize=13)

fig.autofmt_xdate()
plt.tight_layout()
plt.subplots_adjust(wspace=0.15) 
plt.show()
# Out:
# Qihe Bbdong Tianyuan -0.001891 0.0006305435145048349
# Qihe Bbdong La368_G1 0.001575 0.0008711283185840708
# Qihe Bbdong JomonM 9.5e-05 0.0006884057971014493
# Qihe Bbdong DevilsGate -0.00833 0.0017507356031946197
# Qihe Bbdong HDYM1 -0.003928 0.000677007928300586
# Qihe Bbdong ZongriM297 -0.001457 0.0007065955383123182
# Qihe Bbdong Hejiatai -0.003232 0.0007333787156796007
# Qihe Bbdong Chokhopani -0.00308 0.0006608024029178288
# Qihe Bbdong Shamanka_EN -0.004123 0.00047516422726748877
# Qihe Bbdong Bbdong nan nan
# Qihe Bbdong Boshan -0.006387 0.000693485342019544
# Qihe Bbdong XJS_F -0.004875 0.0006205448065173116
# Qihe Bbdong Xiaogao -0.005401 0.000688639551192146
# Qihe Bbdong Qihe nan nan
# Qihe Bbdong LiangDaoF 0.001467 0.0006659101225601453
# Qihe Bbdong LiangDaoM 0.001025 0.0007672155688622754
# Qihe Bbdong Suogang 0.001688 0.0011141914191419144
# Qihe Bbdong Ma555_G6 -0.000685 0.0008616352201257861
# Qihe Bbdong Ami -0.001001 0.0005407887628309022
# ...

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import rcParams
import matplotlib
#plt.style.use('classic')
#rcParams['font.family'] = 'Helvetica'
rcParams['font.family'] = 'Helvetica-Normal'
plt.style.use('fivethirtyeight')
plt.style.use('seaborn-white')
#matplotlib.rc('font', family='sans-serif') 
#matplotlib.rc('font', serif='Helvetica') 

pD="/mnt/solexa/mel_yang/early_CN/"
fhall="F4.list.F4"
fhtv="F4.list.F4tv"
out,out2=("Mbuti","Mbuti")

innerN=["HDYM1","ZongriM297","Hejiatai","Chokhopani","Shamanka_EN"]
coastN=["Bbdong","Boshan","XJS_F","Xiaogao"] #"XJS",
coastSo=["Qihe","LiangDaoF","LiangDaoM"]
coastSy=["Suogang","Ma555_G6","Ami","Atayal"]
anc=["Tianyuan","La368_G1","JomonM","Kolyma_River","DevilsGate"]
seasia=["Man_Bac","Nui_Nap","Oakaie1","Ban_Chiang","Vt833_G2","Vt880_G2",
        "La727_G2","Ma912_G2","Th521_G4","Vt777_G3"]
others=["Mixe","Surui","Papuan","Onge"]
neas=["Oroqen","Xibo","Daur","Hezhen","Tu","Uygur"]
ceas=["Japanese","Korean","Han","She","Miao","Tujia",
      "Han_ShandongX","Han_GansuX","Han_GuangdongX",
      "Han_HenanX","Han_JiangsuX","Han_SichuanX"]
seas=["Lahu","Dai","Ami","Atayal"]
weas=["Naxi","Yi","Tibetan_ShannanX","Tibetan_LhasaX","Tibetan_NagquX",
       "Tibetan_ShigatseX","Tibetan_ChamdoX","Tibetan","Sherpa","Sherpa_ShigatseX"]
sea=["Kinh","Htin_Mal","Mlabri","Cambodian","Thai","Burmese"]
pdeas=neas+ceas+seas+weas+sea
aeas=anc+innerN+coastN+coastSo+coastSy+seasia+others
mycombo=pdeas
mynames=mycombo[:]
#mynames[mynames.index("Zongri-a")]="ZongriM297"

wantedcolors=["blue"]*len(mycombo)
myxmin=[-0.007]*len(mycombo)
myxmax=[0.007]*len(mycombo)

fig = plt.figure(figsize=(11,10))
#newfile=open(pD+"collecteddatpd.txt",'w')
myancsets=[("Qihe","Bbdong"),("Qihe","HDYM1"),("Bbdong","HDYM1")]
for indpair,mypair in enumerate(myancsets):
    #newfile.write("Qihe v Bbdong\n")
    ax1=fig.add_subplot(1,3,indpair+1)
    myind=mypair[0]
    varypop=mypair[1]
    ypops=mycombo
    mytuples=[(0,3),(1,2)]
    #mypops2=[myind,[varypop],ypops,out]
    mypops2=[out,ypops,[varypop],myind]
    Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
    Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
    Zaryall=np.transpose(Zaryall)
    Daryall=np.transpose(Daryall)
    SEaryall=Daryall/Zaryall 
    mynewpops2=mypops2[:-1]+[out2]
    Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
    Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
    Zarytv=np.transpose(Zarytv)
    Darytv=np.transpose(Darytv)
    SEarytv=Darytv/Zarytv

    mylabel="D(%s,%s;%s,%s)\n%s              %s" % (mypops2[3],mypops2[2][0],'X',mypops2[0],mypair[0],mypair[1]) #mypops2[1][0],mypops2[0])
    mylabel="%s                       %s" % (mypair[1],mypair[0]) #mypops2[1][0],mypops2[0])
    mec="black"
    for ind,i in enumerate(ypops):
        neas+ceas+seas+weas+sea
        if i in neas: wantedcolors="red"
        elif i in ceas: wantedcolors="blue"
        elif i in seas: wantedcolors="yellow"
        elif i in weas: wantedcolors="gray"
        elif i in sea: wantedcolors="brown"
        else: wantedcolors="orange"
        #if i in neas+seas+sea: wantedcolors="#fff06d" #"#fffacd" #"red"
        #else: wantedcolors="#84cdeb"#"#c9e9f6" #"blue"
        ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
        print mypair[0],mypair[1], i, Daryall[0][ind], SEaryall[0][ind]
        ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[0][ind],ind,'.')
    myys = np.array(range(len(mynames)))
    if indpair==0:
        ax1.set_yticks(myys)
        ax1.set_ylabel("X",fontsize=15,rotation=90)
        ax1.set_yticklabels(mynames)#,fontsize=12)
    else: ax1.set_yticklabels(['' for i in mynames])

    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[0],myxmax[0])
    xlabel = ax1.get_xticks().tolist()
    ax1.set_title(mylabel,fontsize=15,weight='bold')
    ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
    for myline in [5.5,11.5,17.5,21.5,23.5,31.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)

    ax1.set_xlabel("D") #,fontsize=13)

fig.autofmt_xdate()
plt.tight_layout()
plt.subplots_adjust(wspace=0.15) 
plt.show()
# Out:
# Qihe Bbdong Oroqen -0.004336 0.0005168673262605793
# Qihe Bbdong Xibo -0.004211 0.0005090051976308474
# Qihe Bbdong Daur -0.004666 0.0006092179135657397
# Qihe Bbdong Hezhen -0.004675 0.0005167458826130209
# Qihe Bbdong Tu -0.003923 0.0004887255512644825
# Qihe Bbdong Uygur -0.00256 0.00045944005743000723
# Qihe Bbdong Japanese -0.003221 0.0004857487558437641
# Qihe Bbdong Korean -0.004248 0.0005112528583463714
# Qihe Bbdong Han -0.002912 0.00048187986099619394
# Qihe Bbdong She -0.002957 0.0005432665809296344
# Qihe Bbdong Miao -0.002578 0.0005284952849528495
# Qihe Bbdong Tujia -0.003004 0.0005184673800483259
# Qihe Bbdong Han_ShandongX -0.004182 0.00047179602888086636
# Qihe Bbdong Han_GansuX -0.00368 0.00045460160592958614
# Qihe Bbdong Han_GuangdongX -0.003356 0.0005947191210349106
# Qihe Bbdong Han_HenanX -0.003915 0.0004307404554956541
# Qihe Bbdong Han_JiangsuX -0.003949 0.00047606992163954195
# Qihe Bbdong Han_SichuanX -0.003256 0.00046381766381766386
# ...

# %% [markdown]
# ## D(Qihe, X; Plateau, Mbuti)

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import rcParams
import matplotlib
#plt.style.use('classic')
#rcParams['font.family'] = 'Helvetica'
rcParams['font.family'] = 'Helvetica-Normal'
plt.style.use('fivethirtyeight')
plt.style.use('seaborn-white')
#matplotlib.rc('font', family='sans-serif') 
#matplotlib.rc('font', serif='Helvetica') 

pD="/mnt/solexa/mel_yang/early_CN/"
fhall="F4.list.F4"
fhtv="F4.list.F4tv"
out,out2=("Mbuti","Mbuti")

innerN=["HDYM1","ZongriM297","Hejiatai","Chokhopani","Shamanka_EN"]
coastN=["Bbdong","Boshan","XJS_F","Xiaogao"] #"XJS",
coastSo=["Qihe","LiangDaoF","LiangDaoM"]
coastSy=["Suogang","Ma555_G6","Ami","Atayal"]
anc=["Tianyuan","La368_G1","JomonM","Kolyma_River","DevilsGate"]
seasia=["Man_Bac","Nui_Nap","Oakaie1","Ban_Chiang","Vt833_G2","Vt880_G2",
        "La727_G2","Ma912_G2","Th521_G4","Vt777_G3"]
others=["Mixe","Surui","Papuan","Onge"]
aeas=anc+innerN+coastN+coastSo+coastSy+seasia+others
mycombo=aeas
mynames=mycombo[:]
#mynames[mynames.index("Zongri-a")]="ZongriM297"

wantedcolors=["blue"]*len(mycombo)
myxmin=[-0.01]*len(mycombo)
myxmax=[0.01]*len(mycombo)

fig = plt.figure(figsize=(11,10))
newfile=open(pD+"collecteddat2.txt",'w')
myancsets=[("Qihe","ZongriM297"),("Qihe","Hejiatai"),("Qihe","Chokhopani")]
for indpair,mypair in enumerate(myancsets):
    #newfile.write("Qihe v Bbdong\n")
    ax1=fig.add_subplot(1,3,indpair+1)
    myind=mypair[0]
    varypop=mypair[1]
    ypops=mycombo
    mytuples=[(0,3),(1,2)]
    #mypops2=[myind,[varypop],ypops,out]
    mypops2=[out,[varypop],ypops,myind] #transpose when y-axis in front of other varying
    Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
    Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
    #Zaryall=np.transpose(Zaryall)
    #Daryall=np.transpose(Daryall)
    SEaryall=Daryall/Zaryall 
    mynewpops2=mypops2[:-1]+[out2]
    Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
    Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
    #Zarytv=np.transpose(Zarytv)
    #Darytv=np.transpose(Darytv)
    SEarytv=Darytv/Zarytv

    mylabel="D(%s,%s;%s,%s)\n%s              %s" % (mypops2[3],mypops2[2][0],'X',mypops2[0],mypair[0],mypair[1]) #mypops2[1][0],mypops2[0])
    mylabel="%s                       %s" % (mypair[1],mypair[0]) #mypops2[1][0],mypops2[0])
    mec="black"
    for ind,i in enumerate(ypops):
        if i in innerN: wantedcolors="red"
        elif i in coastN: wantedcolors="blue"
        elif i in coastSo+coastSy: wantedcolors="yellow"
        elif i in anc: wantedcolors="gray"
        elif i in seasia: wantedcolors="brown"
        elif i in others: wantedcolors="purple"
        else: wantedcolors="orange"
        #if i in innerN+coastN+coastSo+coastSy: wantedcolors="#fff06d" #"#fffacd" #"red"
        #else: wantedcolors="#84cdeb"#"#c9e9f6" #"blue"
        ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.5,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.5,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[0][ind],ind,'.',alpha=0.5)
        print mypair[0],mypair[1], i, Daryall[0][ind], SEaryall[0][ind]
        ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[0][ind],ind,'.')
    myys = np.array(range(len(mynames)))
    if indpair==0:
        ax1.set_yticks(myys)
        ax1.set_ylabel("X",fontsize=15,rotation=90)
        ax1.set_yticklabels(mynames)#,fontsize=12)
    else: ax1.set_yticklabels(['' for i in mynames])

    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[0],myxmax[0])
    xlabel = ax1.get_xticks().tolist()
    #ax1.set_title(mylabel,fontsize=15,weight='bold')
    ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
    for myline in [4.5,13.5,20.5,30.5,32.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)

    ax1.set_xlabel("D") #,fontsize=13)

fig.autofmt_xdate()
plt.tight_layout()
plt.subplots_adjust(wspace=0.15) 
plt.show()
# Out:
# Qihe ZongriM297 Tianyuan 0.006673 0.0007464205816554811
# Qihe ZongriM297 La368_G1 0.007967 0.0009706384015594542
# Qihe ZongriM297 JomonM 0.003383 0.0007436799296548692
# Qihe ZongriM297 Kolyma_River 0.001025 0.0007064093728463129
# Qihe ZongriM297 DevilsGate -0.003247 0.001907755581668625
# Qihe ZongriM297 HDYM1 -0.002857 0.0007482975379779989
# Qihe ZongriM297 ZongriM297 nan nan
# Qihe ZongriM297 Hejiatai -0.005617 0.0007431860280497486
# Qihe ZongriM297 Chokhopani -0.002188 0.000687401822180333
# Qihe ZongriM297 Shamanka_EN -0.001518 0.0005847457627118644
# Qihe ZongriM297 Bbdong -0.001457 0.0007065955383123182
# Qihe ZongriM297 Boshan -0.002616 0.0007074094104921579
# Qihe ZongriM297 XJS_F -0.002784 0.0007406225059856345
# Qihe ZongriM297 Xiaogao -0.001943 0.0006989208633093526
# Qihe ZongriM297 Qihe nan nan
# Qihe ZongriM297 LiangDaoF 0.000179 0.0006964980544747081
# Qihe ZongriM297 LiangDaoM -0.000405 0.0007743785850860419
# ...

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import rcParams
import matplotlib
#plt.style.use('classic')
#rcParams['font.family'] = 'Helvetica'
rcParams['font.family'] = 'Helvetica-Normal'
plt.style.use('fivethirtyeight')
plt.style.use('seaborn-white')
#matplotlib.rc('font', family='sans-serif') 
#matplotlib.rc('font', serif='Helvetica') 

pD="/mnt/solexa/mel_yang/early_CN/"
fhall="F4.list.F4"
fhtv="F4.list.F4tv"
out,out2=("Mbuti","Mbuti")

innerN=["HDYM1","ZongriM297","Hejiatai","Chokhopani","Shamanka_EN"]
coastN=["Bbdong","Boshan","XJS_F","Xiaogao"] #"XJS",
coastSo=["Qihe","LiangDaoF","LiangDaoM"]
coastSy=["Suogang","Ma555_G6","Ami","Atayal"]
anc=["Tianyuan","La368_G1","JomonM","Kolyma_River","DevilsGate"]
seasia=["Man_Bac","Nui_Nap","Oakaie1","Ban_Chiang","Vt833_G2","Vt880_G2",
        "La727_G2","Ma912_G2","Th521_G4","Vt777_G3"]
others=["Mixe","Surui","Papuan","Onge"]
aeas=anc+innerN+coastN+coastSo+coastSy+seasia+others
mycombo=aeas
mynames=mycombo[:]
#mynames[mynames.index("Zongri-a")]="ZongriM297"

wantedcolors=["blue"]*len(mycombo)
myxmin=[-0.01]*len(mycombo)
myxmax=[0.01]*len(mycombo)

fig = plt.figure(figsize=(11,10))
newfile=open(pD+"collecteddat2.txt",'w')
myancsets=[("Qihe","Bbdong"),("LiangDaoF","Bbdong"),("LiangDaoM","Bbdong")]
for indpair,mypair in enumerate(myancsets):
    #newfile.write("Qihe v Bbdong\n")
    ax1=fig.add_subplot(1,3,indpair+1)
    myind=mypair[0]
    varypop=mypair[1]
    ypops=mycombo
    mytuples=[(0,3),(1,2)]
    #mypops2=[myind,[varypop],ypops,out]
    mypops2=[out,[varypop],ypops,myind] #transpose when y-axis in front of other varying
    Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
    Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
    #Zaryall=np.transpose(Zaryall)
    #Daryall=np.transpose(Daryall)
    SEaryall=Daryall/Zaryall 
    mynewpops2=mypops2[:-1]+[out2]
    Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
    Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
    #Zarytv=np.transpose(Zarytv)
    #Darytv=np.transpose(Darytv)
    SEarytv=Darytv/Zarytv

    mylabel="D(%s,%s;%s,%s)\n%s              %s" % (mypops2[3],mypops2[2][0],'X',mypops2[0],mypair[0],mypair[1]) #mypops2[1][0],mypops2[0])
    mylabel="%s                       %s" % (mypair[1],mypair[0]) #mypops2[1][0],mypops2[0])
    mec="black"
    for ind,i in enumerate(ypops):
        if i in innerN: wantedcolors="red"
        elif i in coastN: wantedcolors="blue"
        elif i in coastSo+coastSy: wantedcolors="yellow"
        elif i in anc: wantedcolors="gray"
        elif i in seasia: wantedcolors="brown"
        elif i in others: wantedcolors="purple"
        else: wantedcolors="orange"
        #if i in innerN+coastN+coastSo+coastSy: wantedcolors="#fff06d" #"#fffacd" #"red"
        #else: wantedcolors="#84cdeb"#"#c9e9f6" #"blue"
        ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.5,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.5,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[0][ind],ind,'.',alpha=0.5)
        print mypair[0],mypair[1], i, Daryall[0][ind], SEaryall[0][ind]
        ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[0][ind],ind,'.')
    myys = np.array(range(len(mynames)))
    if indpair==0:
        ax1.set_yticks(myys)
        ax1.set_ylabel("X",fontsize=15,rotation=90)
        ax1.set_yticklabels(mynames)#,fontsize=12)
    else: ax1.set_yticklabels(['' for i in mynames])

    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[0],myxmax[0])
    xlabel = ax1.get_xticks().tolist()
    #ax1.set_title(mylabel,fontsize=15,weight='bold')
    ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
    for myline in [4.5,13.5,20.5,30.5,32.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)

    ax1.set_xlabel("D") #,fontsize=13)

fig.autofmt_xdate()
plt.tight_layout()
plt.subplots_adjust(wspace=0.15) 
plt.show()
# Out:
# Qihe Bbdong Tianyuan 0.007306 0.0007122246051861962
# Qihe Bbdong La368_G1 0.009538 0.0009517062462582319
# Qihe Bbdong JomonM 0.003428 0.0006933656957928803
# Qihe Bbdong Kolyma_River 0.002733 0.0007152577859199162
# Qihe Bbdong DevilsGate -0.003665 0.001827930174563591
# Qihe Bbdong HDYM1 -0.001759 0.0007010761259465923
# Qihe Bbdong ZongriM297 0.000418 0.0007244367417677644
# Qihe Bbdong Hejiatai -0.000884 0.0007693646649260226
# Qihe Bbdong Chokhopani -0.000115 0.0006460674157303372
# Qihe Bbdong Shamanka_EN -0.000912 0.000535525543159131
# Qihe Bbdong Bbdong nan nan
# Qihe Bbdong Boshan -0.0056 0.0007023705004389816
# Qihe Bbdong XJS_F -0.005998 0.0006809718437783833
# Qihe Bbdong Xiaogao -0.00507 0.0007126792240652235
# Qihe Bbdong Qihe nan nan
# Qihe Bbdong LiangDaoF -0.000716 0.000651501364877161
# Qihe Bbdong LiangDaoM -0.001391 0.000782779966235228
# Qihe Bbdong Suogang -0.001656 0.0010520965692503177
# Qihe Bbdong Ma555_G6 -0.000935 0.0008754681647940074
# ...

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import rcParams
import matplotlib
#plt.style.use('classic')
#rcParams['font.family'] = 'Helvetica'
rcParams['font.family'] = 'Helvetica-Normal'
plt.style.use('fivethirtyeight')
plt.style.use('seaborn-white')
#matplotlib.rc('font', family='sans-serif') 
#matplotlib.rc('font', serif='Helvetica') 

pD="/mnt/solexa/mel_yang/early_CN/"
fhall="F4.list.F4"
fhtv="F4.list.F4tv"
out,out2=("Mbuti","Mbuti")

innerN=["HDYM1","ZongriM297","Hejiatai","Chokhopani","Shamanka_EN"]
coastN=["Bbdong","Boshan","XJS_F","Xiaogao"] #"XJS",
coastSo=["Qihe","LiangDaoF","LiangDaoM"]
coastSy=["Suogang","Ma555_G6","Ami","Atayal"]
anc=["Tianyuan","La368_G1","JomonM","Kolyma_River","DevilsGate"]
seasia=["Man_Bac","Nui_Nap","Oakaie1","Ban_Chiang","Vt833_G2","Vt880_G2",
        "La727_G2","Ma912_G2","Th521_G4","Vt777_G3"]
others=["Mixe","Surui","Papuan","Onge"]
aeas=anc+innerN+coastN+coastSo+coastSy+seasia+others
mycombo=aeas
mynames=mycombo[:]
#mynames[mynames.index("Zongri-a")]="ZongriM297"

wantedcolors=["blue"]*len(mycombo)
myxmin=[-0.01]*len(mycombo)
myxmax=[0.01]*len(mycombo)

fig = plt.figure(figsize=(11,10))
newfile=open(pD+"collecteddat.txt",'w')
myancsets=[("Chokhopani","ZongriM297"),("Chokhopani","HDYM1"),("ZongriM297","HDYM1")]
for indpair,mypair in enumerate(myancsets):
    newfile.write("Qihe v Bbdong\n")
    ax1=fig.add_subplot(1,3,indpair+1)
    myind=mypair[0]
    varypop=mypair[1]
    ypops=mycombo
    mytuples=[(0,3),(1,2)]
    #mypops2=[myind,[varypop],ypops,out]
    mypops2=[out,ypops,[varypop],myind]
    Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
    Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
    Zaryall=np.transpose(Zaryall)
    Daryall=np.transpose(Daryall)
    SEaryall=Daryall/Zaryall 
    mynewpops2=mypops2[:-1]+[out2]
    Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
    Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
    Zarytv=np.transpose(Zarytv)
    Darytv=np.transpose(Darytv)
    SEarytv=Darytv/Zarytv

    mylabel="D(%s,%s;%s,%s)\n%s              %s" % (mypops2[3],mypops2[2][0],'X',mypops2[0],mypair[0],mypair[1]) #mypops2[1][0],mypops2[0])
    mylabel="%s                %s" % (mypair[1],mypair[0]) #mypops2[1][0],mypops2[0])
    mec="black"
    for ind,i in enumerate(ypops):
        if i in innerN: wantedcolors="red"
        elif i in coastN: wantedcolors="blue"
        elif i in coastSo+coastSy: wantedcolors="yellow"
        elif i in anc: wantedcolors="gray"
        elif i in seasia: wantedcolors="brown"
        elif i in others: wantedcolors="purple"
        else: wantedcolors="orange"
        #if i in innerN+coastN+coastSo+coastSy: wantedcolors="#fff06d" #"#fffacd" #"red"
        #else: wantedcolors="#84cdeb"#"#c9e9f6" #"blue"
        ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.5,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.5,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[0][ind],ind,'.',alpha=0.5)
        print mypair[0],mypair[1], i, Daryall[0][ind], SEaryall[0][ind]
        ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[0][ind],ind,'.')
    myys = np.array(range(len(mynames)))
    if indpair==0:
        ax1.set_yticks(myys)
        ax1.set_ylabel("X",fontsize=15,rotation=90)
        ax1.set_yticklabels(mynames)#,fontsize=12)
    else: ax1.set_yticklabels(['' for i in mynames])

    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[0],myxmax[0])
    xlabel = ax1.get_xticks().tolist()
    ax1.set_title(mylabel,fontsize=15,weight='bold')
    ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
    for myline in [4.5,13.5,20.5,30.5,32.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)

    ax1.set_xlabel("D") #,fontsize=13)

fig.autofmt_xdate()
plt.tight_layout()
plt.subplots_adjust(wspace=0.15) 
plt.show()
# Out:
# Chokhopani ZongriM297 Tianyuan -0.000964 0.0005896024464831804
# Chokhopani ZongriM297 La368_G1 0.000638 0.0007453271028037383
# Chokhopani ZongriM297 JomonM 0.001342 0.0006158788435061956
# Chokhopani ZongriM297 Kolyma_River -0.000369 0.0005980551053484603
# Chokhopani ZongriM297 DevilsGate 0.000836 0.0012921174652241114
# Chokhopani ZongriM297 HDYM1 -0.001805 0.0006643356643356643
# Chokhopani ZongriM297 ZongriM297 nan nan
# Chokhopani ZongriM297 Hejiatai -0.003726 0.0006971000935453696
# Chokhopani ZongriM297 Chokhopani nan nan
# Chokhopani ZongriM297 Shamanka_EN -0.000502 0.00046055045871559627
# Chokhopani ZongriM297 Bbdong -0.000309 0.0005930902111324376
# Chokhopani ZongriM297 Boshan -0.000636 0.0006253687315634219
# Chokhopani ZongriM297 XJS_F -0.000581 0.0006135163674762408
# Chokhopani ZongriM297 Xiaogao -0.000714 0.000639212175470009
# Chokhopani ZongriM297 Qihe -0.000765 0.0006617647058823529
# Chokhopani ZongriM297 LiangDaoF 0.000151 0.000569811320754717
# ...

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import rcParams
import matplotlib
#plt.style.use('classic')
#rcParams['font.family'] = 'Helvetica'
rcParams['font.family'] = 'Helvetica-Normal'
plt.style.use('fivethirtyeight')
plt.style.use('seaborn-white')
#matplotlib.rc('font', family='sans-serif') 
#matplotlib.rc('font', serif='Helvetica') 

pD="/mnt/solexa/mel_yang/early_CN/"
fhall="F4.list.F4"
fhtv="F4.list.F4tv"
out,out2=("Mbuti","Mbuti")

innerN=["HDYM1","ZongriM297","Hejiatai","Chokhopani","Shamanka_EN"]
coastN=["Bbdong","Boshan","XJS_F","Xiaogao"] #"XJS",
coastSo=["Qihe","LiangDaoF","LiangDaoM"]
coastSy=["Suogang","Ma555_G6","Ami","Atayal"]
anc=["Tianyuan","La368_G1","JomonM","Kolyma_River","DevilsGate"]
seasia=["Man_Bac","Nui_Nap","Oakaie1","Ban_Chiang","Vt833_G2","Vt880_G2",
        "La727_G2","Ma912_G2","Th521_G4","Vt777_G3"]
others=["Mixe","Surui","Papuan","Onge"]
neas=["Oroqen","Xibo","Daur","Hezhen","Tu","Uygur"]
ceas=["Japanese","Korean","Han","She","Miao","Tujia",
      "Han_ShandongX","Han_GansuX","Han_GuangdongX",
      "Han_HenanX","Han_JiangsuX","Han_SichuanX"]
seas=["Lahu","Dai","Ami","Atayal"]
weas=["Naxi","Yi","Tibetan_ShannanX","Tibetan_LhasaX","Tibetan_NagquX",
       "Tibetan_ShigatseX","Tibetan_ChamdoX","Tibetan","Sherpa","Sherpa_ShigatseX"]
sea=["Kinh","Htin_Mal","Mlabri","Cambodian","Thai","Burmese"]
pdeas=neas+ceas+seas+weas+sea
aeas=anc+innerN+coastN+coastSo+coastSy+seasia+others
mycombo=pdeas
mynames=mycombo[:]
#mynames[mynames.index("Zongri-a")]="ZongriM297"

wantedcolors=["blue"]*len(mycombo)
myxmin=[-0.007]*len(mycombo)
myxmax=[0.007]*len(mycombo)

fig = plt.figure(figsize=(11,10))
#newfile=open(pD+"collecteddatpd.txt",'w')
myancsets=[("Chokhopani","ZongriM297"),("Chokhopani","HDYM1"),("ZongriM297","HDYM1")]
for indpair,mypair in enumerate(myancsets):
    #newfile.write("Qihe v Bbdong\n")
    ax1=fig.add_subplot(1,3,indpair+1)
    myind=mypair[0]
    varypop=mypair[1]
    ypops=mycombo
    mytuples=[(0,3),(1,2)]
    #mypops2=[myind,[varypop],ypops,out]
    mypops2=[out,ypops,[varypop],myind]
    Zaryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'Z')
    Daryall = pm.mkDary(pD,fhall,mypops2,mytuples[0],mytuples[1],'D')
    Zaryall=np.transpose(Zaryall)
    Daryall=np.transpose(Daryall)
    SEaryall=Daryall/Zaryall 
    mynewpops2=mypops2[:-1]+[out2]
    Zarytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'Z')
    Darytv = pm.mkDary(pD,fhtv,mynewpops2,mytuples[0],mytuples[1],'D')
    Zarytv=np.transpose(Zarytv)
    Darytv=np.transpose(Darytv)
    SEarytv=Darytv/Zarytv

    mylabel="D(%s,%s;%s,%s)\n%s              %s" % (mypops2[3],mypops2[2][0],'X',mypops2[0],mypair[0],mypair[1]) #mypops2[1][0],mypops2[0])
    mylabel="%s               %s" % (mypair[1],mypair[0]) #mypops2[1][0],mypops2[0])
    mec="black"
    for ind,i in enumerate(ypops):
        neas+ceas+seas+weas+sea
        if i in neas: wantedcolors="red"
        elif i in ceas: wantedcolors="blue"
        elif i in seas: wantedcolors="yellow"
        elif i in weas: wantedcolors="gray"
        elif i in sea: wantedcolors="brown"
        else: wantedcolors="orange"
        #if i in neas+seas+sea: wantedcolors="#fff06d" #"#fffacd" #"red"
        #else: wantedcolors="#84cdeb"#"#c9e9f6" #"blue"
        ax1.errorbar(Darytv[0][ind],ind,xerr=SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Darytv[0][ind],ind,xerr=2*SEarytv[0][ind],color=wantedcolors,alpha=0.1,markeredgecolor="black",markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Darytv[0][ind],ind,'.',alpha=0.05)
        print mypair[0],mypair[1], i, Daryall[0][ind], SEaryall[0][ind]
        ax1.errorbar(Daryall[0][ind],ind,xerr=SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=7)
        ax1.errorbar(Daryall[0][ind],ind,xerr=2*SEaryall[0][ind],color=wantedcolors,markeredgecolor=mec,markersize=10,ecolor='darkgrey',fmt='o',capthick=0,linewidth=4)
        ax1.plot(Daryall[0][ind],ind,'.')
    myys = np.array(range(len(mynames)))
    if indpair==0:
        ax1.set_yticks(myys)
        ax1.set_ylabel("X",fontsize=15,rotation=90)
        ax1.set_yticklabels(mynames)#,fontsize=12)
    else: ax1.set_yticklabels(['' for i in mynames])

    ax1.set_ylim(-1,len(mynames))
    ax1.set_xlim(myxmin[0],myxmax[0])
    xlabel = ax1.get_xticks().tolist()
    ax1.set_title(mylabel,fontsize=15,weight='bold')
    ax1.axvline(x=0, ls='dashed', c='black',alpha=0.5,linewidth=0.5) #, backgroundcolor="white") 
    for myline in [5.5,11.5,17.5,21.5,23.5,31.5]:
        ax1.axhline(y=myline, ls='solid', c='black',alpha=0.5,linewidth=0.5)

    ax1.set_xlabel("D") #,fontsize=13)

fig.autofmt_xdate()
plt.tight_layout()
plt.subplots_adjust(wspace=0.15) 
plt.show()
# Out:
# Chokhopani ZongriM297 Oroqen -0.00062 0.0005132450331125828
# Chokhopani ZongriM297 Xibo 0.000464 0.0004553483807654564
# Chokhopani ZongriM297 Daur 0.000319 0.0005821167883211678
# Chokhopani ZongriM297 Hezhen 0.000217 0.000492063492063492
# Chokhopani ZongriM297 Tu 0.000823 0.0004519494783086216
# Chokhopani ZongriM297 Uygur 0.000475 0.0004460093896713615
# Chokhopani ZongriM297 Japanese 0.000987 0.0004599254426840634
# Chokhopani ZongriM297 Korean 0.000974 0.0004758182706399609
# Chokhopani ZongriM297 Han 0.001156 0.00044998053717399766
# Chokhopani ZongriM297 She 0.001331 0.0005013182674199623
# Chokhopani ZongriM297 Miao 0.001049 0.0004973921289710764
# Chokhopani ZongriM297 Tujia 0.000679 0.0005151745068285281
# Chokhopani ZongriM297 Han_ShandongX 0.0014 0.0004364089775561097
# Chokhopani ZongriM297 Han_GansuX 0.001098 0.0004213353798925557
# Chokhopani ZongriM297 Han_GuangdongX 0.000566 0.0005920502092050209
# Chokhopani ZongriM297 Han_HenanX 0.001193 0.0004125172890733057
# ...

# %%
##Qihe_d

import fstat_funcs as ff

pD="/mnt/solexa/mel_yang/early_CN/"
outpd="/mnt/solexa/mel_yang/early_CN/firstdraft/D_AA/"
fh="F4.list.F4"
fh="F4.list.F4tv"
out="Mbuti"        

ns=["Qihe","LiangDaoF","LiangDaoM","Suogang","Bbdong","Boshan","XJS","XJS_F","Xiaogao","HDYM1"]
eeur=["Tianyuan","Papuan","Onge","La368_G1","JomonM","Jomon","Kolyma_River","DevilsGate",
      "Longlin","Baojianshan","Dushan","Shamanka_EN","ZongriM297","Hejiatai","Chokhopani"]
mylst1=ns
mylst2=eeur
out="Mbuti"
for myind in ["Han"]:
    print myind
    pops=[out,mylst1,myind,mylst2]
    ff.Dmat2xlsx(ff.Dmkary(pD,fh,pops,"Z"),outpd+"Z.P2a_"+myind+".NSvEEUR_Han_o%s." % out+fh,ff.Dmklabel(pops),mylst1,mylst2)
    
    pops=[out,mylst2,myind,mylst1]
    ff.Dmat2xlsx(ff.Dmkary(pD,fh,pops,"Z"),outpd+"Z.P2b_"+myind+".NSvEEUR_Han_o%s." % out+fh,ff.Dmklabel(pops),mylst2,mylst1)

    pops=[out,myind,mylst1,mylst2]
    ff.Dmat2xlsx(ff.Dmkary(pD,fh,pops,"Z"),outpd+"Z.P3_"+myind+".NSvEEUR_Han_o%s." % out+fh,ff.Dmklabel(pops),mylst1,mylst2)
# Out:
# Han

# %%
import fstat_funcs as ff

pd="/mnt/solexa/mel_yang/data/2.2M/"
outpd="/mnt/solexa/mel_yang/early_CN/"
fh="UPA19_3"
label="tv.early_CN+EA"
target=["Mbuti"]

panel1=["JomonM","Kolyma_River"]
panel1=["Shamanka_EN","ZongriM297","Hejiatai","Chokhopani","Man_Bac"] #"Ma912_G2","Sherpa_ShigatseX","JomonM","Kolyma_River",
panel2=["Ma555_G6","Nui_Nap"] #"Phl534_G6","Longlin","Baojianshan","Dushan",

southern=["Qihe","LiangDaoF","LiangDaoM","Suogang"]
#"Jiahu_M52_I2_d","Jiahu_M38_I2","DonghulinM1","Jiahu_M52_I2","Tianluoshan",
#"Liangzhu_T2733","Qihe_d","Liangzhu_T4620"
northern=["Bbdong","Boshan","XJS_F","XJS","Xiaogao","HDYM1"]
 #"ZhaoguoM2","DevilsGate","Boisman_MN",
mylst=panel1+panel2+southern+northern
pops=[mylst,mylst,"Mbuti"]
f3ary=ff.f3mkary(outpd,"%s.f3.%s.log" % (fh,label),pops,forZ="f")
ff.f3mkcsv(f3ary,outpd,"%s.%s.ANC4+XY.outMbuti" % (fh, label),pops[0],pops[1])
# Out:
# 'Made /mnt/solexa/mel_yang/early_CN/UPA19_3.tv.early_CN+EA.ANC4+XY.outMbuti.csv'

# %%
import fstat_funcs as ff

pd="/mnt/solexa/mel_yang/data/2.2M/"
outpd="/mnt/solexa/mel_yang/early_CN/"
fh="UPA19_3"
label="tv.early_CN+EA"
target=["Mbuti"]

panel1=["JomonM","Kolyma_River"]
panel1=["Shamanka_EN","ZongriM297","Hejiatai","Chokhopani","Man_Bac"] #"Ma912_G2","Sherpa_ShigatseX","JomonM","Kolyma_River",
panel2=["Ma555_G6","Nui_Nap"] #"Phl534_G6","Longlin","Baojianshan","Dushan",

southern=["Qihe","LiangDaoF","Suogang"]
#"Jiahu_M52_I2_d","Jiahu_M38_I2","DonghulinM1","Jiahu_M52_I2","Tianluoshan",
#"Liangzhu_T2733","Qihe_d","Liangzhu_T4620"
northern=["Bbdong","Boshan","XJS_F","Xiaogao","HDYM1"]
 #"ZhaoguoM2","DevilsGate","Boisman_MN",
mylst=panel1+panel2+southern+northern
pops=[mylst,mylst,"Mbuti"]
f3ary=ff.f3mkary(outpd,"%s.f3.%s.log" % (fh,label),pops,forZ="f")
ff.f3mkcsv(f3ary,outpd,"%s.%s.ANC5+XY.outMbuti" % (fh, label),pops[0],pops[1])
# Out:
# 'Made /mnt/solexa/mel_yang/early_CN/UPA19_3.tv.early_CN+EA.ANC5+XY.outMbuti.csv'

# %%
import fstat_funcs as ff

pd="/mnt/solexa/mel_yang/data/2.2M/"
outpd="/mnt/solexa/mel_yang/early_CN/"
fh="UPA19_3"
label="tv.early_CN+EA"
target=["Mbuti"]

panel1=["JomonM","Kolyma_River"]
panel1=["Shamanka_EN","ZongriM297","Hejiatai","Chokhopani","Man_Bac"] #"Ma912_G2","Sherpa_ShigatseX","JomonM","Kolyma_River",
panel2=["Ma555_G6","Nui_Nap"] #"Phl534_G6","Longlin","Baojianshan","Dushan",

southern=["Qihe","LiangDaoF","LiangDaoM","Suogang"]
#"Jiahu_M52_I2_d","Jiahu_M38_I2","DonghulinM1","Jiahu_M52_I2","Tianluoshan",
#"Liangzhu_T2733","Qihe_d","Liangzhu_T4620"
northern=["Bbdong","Boshan","XJS_F","Xiaogao","HDYM1"]
 #"ZhaoguoM2","DevilsGate","Boisman_MN",
mylst=panel1+panel2+southern+northern
pops=[mylst,mylst,"Mbuti"]
f3ary=ff.f3mkary(outpd,"%s.f3.%s.log" % (fh,label),pops,forZ="f")
ff.f3mkcsv(f3ary,outpd,"%s.%s.ANC6+XY.outMbuti" % (fh, label),pops[0],pops[1])
# Out:
# 'Made /mnt/solexa/mel_yang/early_CN/UPA19_3.tv.early_CN+EA.ANC6+XY.outMbuti.csv'

# %%
import fstat_funcs as ff

pd="/mnt/solexa/mel_yang/data/2.2M/"
outpd="/mnt/solexa/mel_yang/early_CN/"
fh="UPA19_3"
label="early_CN+EA"
target=["Mbuti"]

panel1=["JomonM","Kolyma_River"]
panel1=["Shamanka_EN","ZongriM297","Hejiatai","Chokhopani","Man_Bac"] #"Ma912_G2","Sherpa_ShigatseX","JomonM","Kolyma_River",
panel2=["Ma555_G6","Nui_Nap","Vt833_G2","Vt880_G2","La727_G2","Ma912_G2","Oakaie1"] #"Phl534_G6","Longlin","Baojianshan","Dushan",

southern=["Qihe","LiangDaoF","LiangDaoM","Suogang"]
#"Jiahu_M52_I2_d","Jiahu_M38_I2","DonghulinM1","Jiahu_M52_I2","Tianluoshan",
#"Liangzhu_T2733","Qihe_d","Liangzhu_T4620"
northern=["Bbdong","Boshan","XJS_F","Xiaogao","HDYM1"]
 #"ZhaoguoM2","DevilsGate","Boisman_MN",
mylst=panel1+panel2+southern+northern
pops=[mylst,mylst,"Mbuti"]
f3ary=ff.f3mkary(outpd,"%s.f3.%s.log" % (fh,label),pops,forZ="f")
ff.f3mkcsv(f3ary,outpd,"%s.%s.ANC7+XY.outMbuti" % (fh, label),pops[0],pops[1])
# Out:
# 'Made /mnt/solexa/mel_yang/early_CN/UPA19_3.early_CN+EA.ANC7+XY.outMbuti.csv'

# %%
import fstat_funcs as ff

pd="/mnt/solexa/mel_yang/data/2.2M/"
outpd="/mnt/solexa/mel_yang/early_CN/"
fh="UPA19_3"
label="early_CN+EA"
target=["Mbuti"]

panel1=["JomonM","Kolyma_River"]
panel1=["Shamanka_EN","ZongriM297","Hejiatai","Chokhopani","Man_Bac"] #"Ma912_G2","Sherpa_ShigatseX","JomonM","Kolyma_River",
panel2=["Ma555_G6","Nui_Nap","Vt833_G2","Vt880_G2","La727_G2","Ma912_G2","Oakaie1"] #"Phl534_G6","Longlin","Baojianshan","Dushan",

southern=["Qihe","LiangDaoF","LiangDaoM","Suogang"]
#"Jiahu_M52_I2_d","Jiahu_M38_I2","DonghulinM1","Jiahu_M52_I2","Tianluoshan",
#"Liangzhu_T2733","Qihe_d","Liangzhu_T4620"
northern=["Bbdong","Boshan","XJS_F","XJS","Xiaogao","HDYM1"]
 #"ZhaoguoM2","DevilsGate","Boisman_MN",
mylst=panel1+panel2+southern+northern
pops=[mylst,mylst,"Mbuti"]
f3ary=ff.f3mkary(outpd,"%s.f3.%s.log" % (fh,label),pops,forZ="f")
seary=ff.f3mkary(outpd,"%s.f3.%s.log" % (fh,label),pops,forZ="se")
ff.f3mkcsv(f3ary,outpd,"%s.%s.ANC8+XY.outMbuti" % (fh, label),pops[0],pops[1])
# Out:
# 'Made /mnt/solexa/mel_yang/early_CN/UPA19_3.early_CN+EA.ANC8+XY.outMbuti.csv'

# %%
import fstat_funcs as ff

pd="/mnt/solexa/mel_yang/data/2.2M/"
outpd="/mnt/solexa/mel_yang/early_CN/"
fh="UPA19_3"
label="tv.mXJS.early_CN+EA"
target=["Mbuti"]

panel1=["JomonM","Kolyma_River"]
panel1=["Shamanka_EN","ZongriM297","Hejiatai","Chokhopani","Man_Bac"] #"Ma912_G2","Sherpa_ShigatseX","JomonM","Kolyma_River",
panel2=["Ma555_G6","Nui_Nap","Vt833_G2","Vt880_G2","La727_G2","Ma912_G2","Oakaie1"] #"Phl534_G6","Longlin","Baojianshan","Dushan",

southern=["Qihe","LiangDaoF","LiangDaoM","Suogang"]
#"Jiahu_M52_I2_d","Jiahu_M38_I2","DonghulinM1","Jiahu_M52_I2","Tianluoshan",
#"Liangzhu_T2733","Qihe_d","Liangzhu_T4620"
northern=["Bbdong","Boshan","XJS_merge","Xiaogao","HDYM1"]
 #"ZhaoguoM2","DevilsGate","Boisman_MN",
mylst=panel1+panel2+southern+northern
pops=[mylst,mylst,"Mbuti"]
f3ary=ff.f3mkary(outpd,"%s.f3.%s.log" % (fh,label),pops,forZ="f")
seary=ff.f3mkary(outpd,"%s.f3.%s.log" % (fh,label),pops,forZ="se")
ff.f3mkcsv(f3ary,outpd,"%s.%s.ANC1+XY.outMbuti" % (fh, label),pops[0],pops[1])
# Out:
# 'Made /mnt/solexa/mel_yang/early_CN/UPA19_3.tv.mXJS.early_CN+EA.ANC1+XY.outMbuti.csv'

# %%
def f3mklst(pD,fh,pops,forZ="f"): 
    import numpy as np
    
    if forZ=="Z":    forZind=5 
    elif forZ=="f": forZind=3
    elif forZ=="se": forZind=4
    else: return "Not Z or f or se!"
    
    stable = [ind for ind,i in enumerate(pops) if type(i)==str]
    vary = [ind for ind,i in enumerate(pops) if type(i)==list]
    stabpop=pops[stable[0]]
    varypop1,varypop2=(pops[vary[0]],pops[vary[1]])
    
    myary=[] #np.zeros((len(varypop1),len(varypop2)))
    #myary[myary==0]=np.nan
    myDs={}
    dfile=open(pD+fh,'r')
    for line in dfile:
        if 'result' not in line: continue
        x=line.split()[1:]
        a,b,c=x[:3]
        if stabpop not in [a,b,c]: continue
        f3={}
        f3[(a,b,c)]=float(x[forZind])
        f3[(b,a,c)]=float(x[forZind])
        for dset in f3:
            if dset[vary[0]] in varypop1 and dset[vary[1]] in varypop2 and dset[stable[0]]==stabpop :
                p1ind,p2ind=(varypop1.index(dset[vary[0]]),varypop2.index(dset[vary[1]]))
                print dset[vary[0]], dset[vary[1]], f3[dset]
                #myary[p1ind,p2ind]=f3[dset]
    dfile.close()
    return None

f3mklst(outpd,"%s.f3.%s.log" % (fh,label),pops,forZ="se")
# Out:
# LiangDaoM LiangDaoF 0.003877
# LiangDaoF LiangDaoM 0.003877
# LiangDaoF Vt833_G2 0.004627
# Vt833_G2 LiangDaoF 0.004627
# La727_G2 LiangDaoF 0.003743
# LiangDaoF La727_G2 0.003743
# LiangDaoF Vt880_G2 0.004574
# Vt880_G2 LiangDaoF 0.004574
# Shamanka_EN LiangDaoF 0.003204
# LiangDaoF Shamanka_EN 0.003204
# Qihe LiangDaoF 0.003886
# LiangDaoF Qihe 0.003886
# Xiaogao LiangDaoF 0.003581
# LiangDaoF Xiaogao 0.003581
# LiangDaoF Suogang 0.004666
# Suogang LiangDaoF 0.004666
# LiangDaoF Man_Bac 0.003571
# Man_Bac LiangDaoF 0.003571
# Nui_Nap LiangDaoF 0.00395
# LiangDaoF Nui_Nap 0.00395
# LiangDaoF Oakaie1 0.004243
# Oakaie1 LiangDaoF 0.004243
# LiangDaoF Ma912_G2 0.003433
# Ma912_G2 LiangDaoF 0.003433
# Ma555_G6 LiangDaoF 0.003746
# LiangDaoF Ma555_G6 0.003746
# LiangDaoF Bbdong 0.003772
# Bbdong LiangDaoF 0.003772
# Boshan LiangDaoF 0.003504
# LiangDaoF Boshan 0.003504
# LiangDaoF XJS 0.003863
# XJS LiangDaoF 0.003863
# XJS_F LiangDaoF 0.0036
# LiangDaoF XJS_F 0.0036
# ...

# %%
import fstat_funcs as ff

pd="/mnt/solexa/mel_yang/data/2.2M/"
outpd="/mnt/solexa/mel_yang/early_CN/"
fh="UPA19_3"
label="tv.mXJS.early_CN+EA"
label="mXJS.early_CN+EA"

panel1=["JomonM","Kolyma_River"]
panel1=["Shamanka_EN","ZongriM297","Hejiatai","Chokhopani","Man_Bac"] #"Ma912_G2","Sherpa_ShigatseX","JomonM","Kolyma_River",
panel2=["Ma555_G6","Nui_Nap","Vt833_G2","Vt880_G2","La727_G2","Ma912_G2","Oakaie1"] #"Phl534_G6","Longlin","Baojianshan","Dushan",

southern=["Qihe","LiangDaoF","LiangDaoM","Suogang"]
#"Jiahu_M52_I2_d","Jiahu_M38_I2","DonghulinM1","Jiahu_M52_I2","Tianluoshan",
#"Liangzhu_T2733","Qihe_d","Liangzhu_T4620"
northern=["Bbdong","Boshan","XJS_merge","Xiaogao","HDYM1"]
 #"ZhaoguoM2","DevilsGate","Boisman_MN",
mylst=panel1+panel2+southern+northern

target=["Mbuti"]
#mylst=[line.strip() for line in open(outpd+"list3","r")]
ff.f3pop(pd,fh,label,target,mylst,mylst,outpd=outpd,r_repeat=False)
ff.parfile(pd,fh,"f3",label,outpd=outpd,indfh="mod_UPA19_3") #,badsnp="UPA_all15.transi.snp")
# Out:
# 'Made f3 PAR file /mnt/solexa/mel_yang/early_CN/UPA19_3.f3.mXJS.early_CN+EA.par'

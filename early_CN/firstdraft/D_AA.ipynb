# %%
##Qihe_d

import fstat_funcs as ff

pD="/mnt/solexa/mel_yang/early_CN/"
outpd="/mnt/solexa/mel_yang/early_CN/firstdraft/D_AA/"
fh="F4.list.F4"
#fh="F4.list.F4tv"
out="Mbuti"        

ns=["Qihe","LiangDaoF","LiangDaoM","Suogang","Bbdong","Boshan","XJS","XJS_F","Xiaogao","HDYM1"]
eeur=["Tianyuan","Papuan","Onge","La368_G1","JomonM","Jomon","Kolyma_River","DevilsGate",
      "Longlin","Baojianshan","Dushan","Shamanka_EN","ZongriM297","Hejiatai","Chokhopani","Han"]
eeur=["Yana_old","Yana_old2"]
mylst1=ns
mylst2=eeur
out="Mbuti"
for myind in ns:
    print myind
    pops=[out,mylst1,myind,mylst2]
    ff.Dmat2xlsx(ff.Dmkary(pD,fh,pops,"Z"),outpd+"Z.P2a_"+myind+".NS_yEEUR_o%s." % out+fh,ff.Dmklabel(pops),mylst1,mylst2)
    
    pops=[out,mylst2,myind,mylst1]
    ff.Dmat2xlsx(ff.Dmkary(pD,fh,pops,"Z"),outpd+"Z.P2b_"+myind+".NS_yEEUR_o%s." % out+fh,ff.Dmklabel(pops),mylst2,mylst1)

    pops=[out,myind,mylst1,mylst2]
    ff.Dmat2xlsx(ff.Dmkary(pD,fh,pops,"Z"),outpd+"Z.P3_"+myind+".NS_yEEUR_o%s." % out+fh,ff.Dmklabel(pops),mylst1,mylst2)

# %%
import fstat_funcs as ff

pD="/mnt/solexa/mel_yang/early_CN/"
outpd="/mnt/solexa/mel_yang/early_CN/firstdraft/D_AA/"
fh="F4.list.F4"
fh="F4.list.F4tv"
out="Mbuti"        

ns=["Qihe","LiangDaoF","LiangDaoM","Suogang","Bbdong","Boshan","XJS","XJS_F","Xiaogao","HDYM1","Han"]
eeur=["Tianyuan","Papuan","Onge","La368_G1","JomonM","Jomon","Kolyma_River","DevilsGate",
      "Longlin","Baojianshan","Dushan"] #"Shamanka_EN","ZongriM297","Hejiatai","Chokhopani","Han","Mixe","Surui"]
innerN=["HDYM1","ZongriM297","Hejiatai","Chokhopani","Shamanka_EN"]
coastN=["Bbdong","Boshan","XJS","XJS_F","Xiaogao"]
coastSo=["Qihe","LiangDaoF","LiangDaoM"]
coastSy=["Suogang","Ma555_G6","Ami","Atayal"]
mylst=innerN+coastN+coastSo+coastSy
varies=mylst+["Han","Daur","Hezhen","Korean","She","Miao","Kolyma_River","Dai","Lahu"]
varies=["Mixe","Surui","Tibetan_ShannanX","Tibetan_ChamdoX"]+eeur
for myind in varies:
    print myind
    pops=[out,mylst,myind,mylst]
    ff.Dmat2xlsx(ff.Dmkary(pD,fh,pops,"Z"),outpd+"Z.P2_"+myind+".NS_Zall_o%s." % (out)+fh,ff.Dmklabel(pops),mylst,mylst)

    pops=[out,myind,mylst,mylst]
    ff.Dmat2xlsx(ff.Dmkary(pD,fh,pops,"Z"),outpd+"Z.P3_"+myind+".NS_Zall_o%s." % (out)+fh,ff.Dmklabel(pops),mylst,mylst)
# Out:
# Mixe
# Surui
# Tibetan_ShannanX
# Tibetan_ChamdoX
# Tianyuan
# Papuan
# Onge
# La368_G1
# JomonM
# Jomon
# Kolyma_River
# DevilsGate
# Longlin
# Baojianshan
# Dushan

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches

pD="/mnt/solexa/mel_yang/early_CN/"
tv="tv"
tv=""
fhall="F4.list.F4%s" % tv

agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
#agq=["Zongri1a","Zongri23"]
#eur=["French","Sardinian","Finnish"]

ns=["Han","Qihe","LiangDaoF","LiangDaoM","Suogang","Dushan","Xinyi","Dashuitian",
    "Bbdong","Boshan","XJS","XJS_F","Xiaogao","HDYM1","Shamanka_EN",
   "ZongriM297","Hejiatai","Chokhopani","Daxi","Baojianshan"]
ns=["Qihe","LiangDaoF","Suogang","Bbdong","Boshan","XJS_F","Xiaogao","HDYM1"]

eas=["Han","Dai","Ami","Daur","Sherpa","Tibetan","Naxi","Yi"]
aeur=["Kostenki14","Vestonice16","GoyetQ116-1","ElMiron","Villabruna","Loschbour"]
jap=["Jomon","JomonM"]
gx=["Longlin","Baojianshan"]
ong=["Onge"]
hoa=["La368_G1"] #,"Ma911_G1"]
pap=["Papuan"]
ty=["Tianyuan"] #,"Papuan","Onge","Oase1","Stuttgart",
yan=["Yana_old","Yana_old2"]
varypops=[ty,pap,ong,hoa,gx,jap][::-1]
labels=["Tianyuan","Papuan","Onge",'La368',"LL/BJS","Jomon"][::-1] #/Papuan/Onge/Oase1
dxcluster=ns
dxpairs=[(i,j) for indi,i in enumerate(dxcluster) for indj,j in enumerate(dxcluster) if indi>indj]
dxpairs=[(i,"Han") for indi,i in enumerate(dxcluster) if i!="Han"]
pairlabels=["%s_%s" % mypair for mypair in dxpairs]
#print pairlabels
out="Mbuti"
colors=["blue","brown","red","black","pink","gray","purple"][::-1]
markers=["o","v","s","+","D",">","<","v"]
print len(dxpairs)

fig = plt.figure(figsize=(9,9))
ax1=fig.add_subplot(1,1,1)
handles1,handles2=[],[]
for ind,mypair in enumerate(dxpairs):
    if ind % 10==0: print ind,mypair
    #ax1.set_title("D(X1, aGQ; X2, Mbuti)")
    #ax1.set_ylim((-4,10))
    #ax1.set_xlim((-4,10))
    ax1.set_ylabel("Z for D(Han, X; aNS, %s)" % out,fontsize=15)
    ax1.set_xlabel("Z for D(aNS, X; Han, %s)" % out,fontsize=15)
    ax1.axvline(x=0, ls='dashed', c='black')
    ax1.axhline(y=0, ls='dashed', c='black')
    ax1.axvline(x=2, ls='dashed', c='lightgray')
    ax1.axhline(y=2, ls='dashed', c='lightgray')
    ax1.axvline(x=-2, ls='dashed', c='lightgray')
    ax1.axhline(y=-2, ls='dashed', c='lightgray')
    for ivp,varypop in enumerate(varypops):
        mypops1=[out,[mypair[1]],varypop,mypair[0]]
        mypops2=[out,[mypair[0]],varypop,mypair[1]]
        
        Zary1 = pm.mkDary(pD,fhall,mypops1,(0,3),(1,2),'Z')
        Zary2 = pm.mkDary(pD,fhall,mypops2,(0,3),(1,2),'Z')
        Zary=np.transpose(np.vstack((Zary1, Zary2)))[0,:]
        ax1.plot(Zary1,Zary2,'o',color=colors[ivp]) #markers[ind],
        #if ivp==0:
        #    handles1.append(mlines.Line2D([],[],marker=markers[ind],color='black',label=pairlabels[ind]))
        if ind==0:
            handles2.append(mpatches.Patch(color=colors[ivp], label=labels[ivp]))
        else: pass
#ax1.legend(loc='lower right')
#ax1.legend(handles=handles1+handles2,loc=4,ncol=2,fontsize=12.5)
ax1.legend(handles=handles2,loc=0)
plt.show()

#fig.savefig(pD+'aNSclade.D%s.relASN.png' % tv) # save the figure to file
#plt.close(fig)

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches

pD="/mnt/solexa/mel_yang/early_CN/"
tv="tv"
tv=""
fhall="F4.list.F4%s" % tv

agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
#agq=["Zongri1a","Zongri23"]
#eur=["French","Sardinian","Finnish"]

ns=["Han","Qihe","LiangDaoF","LiangDaoM","Suogang","Dushan","Xinyi","Dashuitian",
    "Bbdong","Boshan","XJS","XJS_F","Xiaogao","HDYM1","Shamanka_EN",
   "ZongriM297","Hejiatai","Chokhopani","Daxi","Baojianshan"]
ns=["Qihe","LiangDaoF","LiangDaoM","Suogang","Bbdong","Boshan","XJS_F","XJS","Xiaogao","HDYM1"]

eas=["Han","Dai","Ami","Daur","Sherpa","Tibetan","Naxi","Yi"]
aeur=["Kostenki14","Vestonice16","GoyetQ116-1","ElMiron","Villabruna","Loschbour"]
ma1=["Malta1"]
weur=["Vestonice16"]
ust=["UstIshim"]
gx=["Longlin","Baojianshan"]
ong=["Onge"]
hoa=["La368_G1"] #,"Ma911_G1"]
pap=["Papuan"]
ty=["Tianyuan"] #,"Papuan","Onge","Oase1","Stuttgart",
yan=["Yana_old","Yana_old2"]
varypops=[ust,weur,ma1,ty,pap,ong,hoa][::-1]
labels=["UstIshim","Vestonice16","Malta1","Tianyuan","Papuan","Onge",'La368'][::-1] #/Papuan/Onge/Oase1
dxcluster=ns
dxpairs=[(i,j) for indi,i in enumerate(dxcluster) for indj,j in enumerate(dxcluster) if indi>indj]
dxpairs=[(i,"Han") for indi,i in enumerate(dxcluster) if i!="Han"]
pairlabels=["%s_%s" % mypair for mypair in dxpairs]
#print pairlabels
out="Mbuti"
colors=["blue","brown","red","black","pink","gray","purple"][::-1]
markers=["o","v","s","+","D",">","<","v"]
print len(dxpairs)

fig = plt.figure(figsize=(9,9))
ax1=fig.add_subplot(1,1,1)
handles1,handles2=[],[]
for ind,mypair in enumerate(dxpairs):
    if ind % 10==0: print ind,mypair
    #ax1.set_title("D(X1, aGQ; X2, Mbuti)")
    #ax1.set_ylim((-4,10))
    #ax1.set_xlim((-4,10))
    ax1.set_ylabel("Z for D(Han, X; aNS, %s)" % out,fontsize=15)
    ax1.set_xlabel("Z for D(aNS, X; Han, %s)" % out,fontsize=15)
    ax1.axvline(x=0, ls='dashed', c='black')
    ax1.axhline(y=0, ls='dashed', c='black')
    ax1.axvline(x=2, ls='dashed', c='lightgray')
    ax1.axhline(y=2, ls='dashed', c='lightgray')
    ax1.axvline(x=-2, ls='dashed', c='lightgray')
    ax1.axhline(y=-2, ls='dashed', c='lightgray')
    for ivp,varypop in enumerate(varypops):
        mypops1=[out,[mypair[1]],varypop,mypair[0]]
        mypops2=[out,[mypair[0]],varypop,mypair[1]]
        
        Zary1 = pm.mkDary(pD,fhall,mypops1,(0,3),(1,2),'Z')
        Zary2 = pm.mkDary(pD,fhall,mypops2,(0,3),(1,2),'Z')
        Zary=np.transpose(np.vstack((Zary1, Zary2)))[0,:]
        ax1.plot(Zary1,Zary2,'o',color=colors[ivp]) #markers[ind],
        #if ivp==0:
        #    handles1.append(mlines.Line2D([],[],marker=markers[ind],color='black',label=pairlabels[ind]))
        if ind==0:
            handles2.append(mpatches.Patch(color=colors[ivp], label=labels[ivp]))
        else: pass
#ax1.legend(loc='lower right')
#ax1.legend(handles=handles1+handles2,loc=4,ncol=2,fontsize=12.5)
ax1.legend(handles=handles2,loc=0)
plt.show()

#fig.savefig(pD+'aNSclade.D%s.relASN.png' % tv) # save the figure to file
#plt.close(fig)
# Out:
# 10
# 0 ('Qihe', 'Han')

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches
import matplotlib.lines as mlines

pD="/mnt/solexa/mel_yang/early_CN/"
tv="tv"
tv=""
fhall="F4.list.F4%s" % tv

agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
#agq=["Zongri1a","Zongri23"]
#eur=["French","Sardinian","Finnish"]

ns=["Han","Qihe","LiangDaoF","LiangDaoM","Suogang","Dushan","Xinyi","Dashuitian",
    "Bbdong","Boshan","XJS","XJS_F","Xiaogao","HDYM1","Shamanka_EN",
   "ZongriM297","Hejiatai","Chokhopani","Daxi","Baojianshan"]
ns=["Qihe","LiangDaoF","LiangDaoM","Suogang","Bbdong","Boshan","XJS_F","XJS","Xiaogao","HDYM1"]

eas=["Han","Dai","Ami","Daur","Sherpa","Tibetan","Naxi","Yi"]
aeur=["Kostenki14","Vestonice16","GoyetQ116-1","ElMiron","Villabruna","Loschbour"]
ma1=["Malta1"]
jom=["JomonM"]
eplat=["ZongriM297"] #,"Hejiatai"
wplat=["Chokhopani"]
sham=["Shamanka_EN"]
koly=["Kolyma_River"]
devil=["DevilsGate"]
ma55=["Ma555_G6"]
weur=["Vestonice16"]
ust=["UstIshim"]
gx=["Longlin"] #,"Baojianshan"
ong=["Onge"]
hoa=["La368_G1"] #,"Ma911_G1"]
pap=["Papuan"]
ty=["Tianyuan"] #,"Papuan","Onge","Oase1","Stuttgart",
yan=["Yana_old","Yana_old2"]
varypops=[jom,gx,eplat,wplat,sham,koly,ma55][::-1]
labels=["Iwakazu","Guangxi","East Plateau","West Plateau","Shamanka_EN","Kolyma_River",'Ma555_G6'][::-1] #/Papuan/Onge/Oase1
dxcluster=ns
dxpairs=[(i,j) for indi,i in enumerate(dxcluster) for indj,j in enumerate(dxcluster) if indi>indj]
dxpairs=[(i,"Han") for indi,i in enumerate(dxcluster) if i!="Han"]
print len(dxpairs)
#dxpairs=dxpairs[:3]
pairlabels=["%s_%s" % mypair for mypair in dxpairs]
#print pairlabels
out="Mbuti"
colors=["blue","brown","red","black","pink","gray","purple"][::-1]
markers=["o","v","s","+","D",">","<","^",'x','p','h']
print len(dxpairs)

fig = plt.figure(figsize=(9,9))
ax1=fig.add_subplot(1,1,1)
handles1,handles2=[],[]
for ind,mypair in enumerate(dxpairs):
    if ind % 10==0: print ind,mypair
    #ax1.set_title("D(X1, aGQ; X2, Mbuti)")
    #ax1.set_ylim((-4,10))
    #ax1.set_xlim((-4,10))
    ax1.set_ylabel("Z for D(Han, X; aNS, %s)" % out,fontsize=15)
    ax1.set_xlabel("Z for D(aNS, X; Han, %s)" % out,fontsize=15)
    ax1.axvline(x=0, ls='dashed', c='black')
    ax1.axhline(y=0, ls='dashed', c='black')
    ax1.axvline(x=2, ls='dashed', c='lightgray')
    ax1.axhline(y=2, ls='dashed', c='lightgray')
    ax1.axvline(x=-2, ls='dashed', c='lightgray')
    ax1.axhline(y=-2, ls='dashed', c='lightgray')
    for ivp,varypop in enumerate(varypops):
        mypops1=[out,[mypair[1]],varypop,mypair[0]]
        mypops2=[out,[mypair[0]],varypop,mypair[1]]
        
        Zary1 = pm.mkDary(pD,fhall,mypops1,(0,3),(1,2),'Z')
        Zary2 = pm.mkDary(pD,fhall,mypops2,(0,3),(1,2),'Z')
        #Zary=np.transpose(np.vstack((Zary1, Zary2)))[0,:]
        #print Zary1, Zary2
        ax1.plot(Zary1,Zary2,'o',color=colors[ivp],marker=markers[ind])
        if ivp==0:
            handles1.append(mlines.Line2D([],[],marker=markers[ind],color='black',label=pairlabels[ind],linestyle=""))
        if ind==0:
            handles2.append(mpatches.Patch(color=colors[ivp], label=labels[ivp]))
        else: pass
#ax1.legend(loc='lower right')
ax1.legend(handles=handles1+handles2,loc=4,ncol=2)
#ax1.legend(handles=handles1,loc=4,ncol=2)
#ax1.legend(handles=handles2,loc=0)
plt.show()

#fig.savefig(pD+'aNSclade.D%s.relASN.png' % tv) # save the figure to file
#plt.close(fig)
# Out:
# 10
# 10
# 0 ('Qihe', 'Han')

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches
import matplotlib.lines as mlines

pD="/mnt/solexa/mel_yang/early_CN/"
tv="tv"
tv=""
fhall="F4.list.F4%s" % tv

agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
#agq=["Zongri1a","Zongri23"]
#eur=["French","Sardinian","Finnish"]

ns=["Han","Qihe","LiangDaoF","LiangDaoM","Suogang","Dushan","Xinyi","Dashuitian",
    "Bbdong","Boshan","XJS","XJS_F","Xiaogao","HDYM1","Shamanka_EN",
   "ZongriM297","Hejiatai","Chokhopani","Daxi","Baojianshan"]
ns=["Qihe","LiangDaoF","LiangDaoM","Suogang","Bbdong","Boshan","XJS_F","XJS","Xiaogao","HDYM1"]

eas=["Han","Dai","Ami","Daur","Sherpa","Tibetan","Naxi","Yi"]
aeur=["Kostenki14","Vestonice16","GoyetQ116-1","ElMiron","Villabruna","Loschbour"]
ma1=["Malta1"]
jom=["JomonM"]
eplat=["ZongriM297"] #,"Hejiatai"
wplat=["Chokhopani"]
sham=["Shamanka_EN"]
koly=["Kolyma_River"]
devil=["DevilsGate"]
ma55=["Ma555_G6"]
weur=["Vestonice16"]
ust=["UstIshim"]
gx=["Longlin"] #,"Baojianshan"
ong=["Onge"]
hoa=["La368_G1"] #,"Ma911_G1"]
pap=["Papuan"]
ty=["Tianyuan"] #,"Papuan","Onge","Oase1","Stuttgart",
yan=["Yana_old","Yana_old2"]
varypops=[jom,gx,eplat,wplat,sham,koly,ma55][::-1]
labels=["Iwakazu","Guangxi","East Plateau","West Plateau","Shamanka_EN","Kolyma_River",'Ma555_G6'][::-1] #/Papuan/Onge/Oase1
dxcluster=ns
dxpairs=[(i,j) for indi,i in enumerate(dxcluster) for indj,j in enumerate(dxcluster) if indi>indj]
dxpairs=[(i,"Han") for indi,i in enumerate(dxcluster) if i!="Han"]
print len(dxpairs)
#dxpairs=dxpairs[:3]
pairlabels=["%s_%s" % mypair for mypair in dxpairs]
#print pairlabels
out="Mbuti"
colors=["blue","brown","red","black","pink","gray","purple"][::-1]
markers=["o","v","s","+","D",">","<","^",'x','p','h']
print len(dxpairs)

fig = plt.figure(figsize=(15,7))
axs = [ fig.add_subplot(2,4,ind+1) for ind,i in enumerate(varypops) ]
handles1,handles2=[],[]
for ind,mypair in enumerate(dxpairs):
    if ind % 10==0: print ind,mypair
    #ax1.set_title("D(X1, aGQ; X2, Mbuti)")

    for ivp,varypop in enumerate(varypops):
        if ind==0:
            axs[ivp].set_ylim((-7,13.5))
            axs[ivp].set_xlim((-7,13.5))
            axs[ivp].set_ylabel("P1=Han; P3=aNS",fontsize=12)
            axs[ivp].set_xlabel("P1=aNS; P3=Han",fontsize=12)
            axs[ivp].set_title("Z for D(P1, %s; P3, %s)" % (labels[ivp],out),fontsize=12)
            axs[ivp].axvline(x=0, ls='dashed', c='black')
            axs[ivp].axhline(y=0, ls='dashed', c='black')
            axs[ivp].axvline(x=2, ls='dashed', c='lightgray')
            axs[ivp].axhline(y=2, ls='dashed', c='lightgray')
            axs[ivp].axvline(x=-2, ls='dashed', c='lightgray')
            axs[ivp].axhline(y=-2, ls='dashed', c='lightgray')
        mypops1=[out,[mypair[1]],varypop,mypair[0]]
        mypops2=[out,[mypair[0]],varypop,mypair[1]]
        
        Zary1 = pm.mkDary(pD,fhall,mypops1,(0,3),(1,2),'Z')
        Zary2 = pm.mkDary(pD,fhall,mypops2,(0,3),(1,2),'Z')
        #Zary=np.transpose(np.vstack((Zary1, Zary2)))[0,:]
        #print Zary1, Zary2
        axs[ivp].plot(Zary1,Zary2,'o',color=colors[ivp],marker=markers[ind])
        if ivp==0:
            handles1.append(mlines.Line2D([],[],marker=markers[ind],color='black',label=mypair[0],linestyle=""))
        #if ind==0:
        #    handles2.append(mpatches.Patch(color=colors[ivp], label=labels[ivp]))
        else: pass
#ax1.legend(loc='lower right')
axs.append(fig.add_subplot(2,4,8))
#ax1.legend(handles=handles1+handles2,loc=4,ncol=2)
axs[-1].legend(handles=handles1,loc=4,ncol=1)
#ax1.legend(handles=handles2,loc=0)
plt.tight_layout()
plt.show()

#fig.savefig(pD+'aNSclade.D%s.relASN.png' % tv) # save the figure to file
#plt.close(fig)
# Out:
# 10
# 10
# 0 ('Qihe', 'Han')

# %%
import numpy as np
import plateaumodules as pm
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.patches as mpatches
import matplotlib.lines as mlines

pD="/mnt/solexa/mel_yang/early_CN/"
tv="tv"
#tv=""
fhall="F4.list.F4%s" % tv

agq=["Zongri1a","Zongri23","Shangluzhuang","Hejiatai","Heodong","Daxiang","Xiahaishi",
     "Hupo","Sanheyi","Qunke","Lajigai","Wenpuju","Jinchankou","Qijiaping",
     "Wuba","Huoshaogou","Lierbao","Shannashuzha",]
#agq=["Zongri1a","Zongri23"]
#eur=["French","Sardinian","Finnish"]

ns=["Han","Qihe","LiangDaoF","LiangDaoM","Suogang","Dushan","Xinyi","Dashuitian",
    "Bbdong","Boshan","XJS","XJS_F","Xiaogao","HDYM1","Shamanka_EN",
   "ZongriM297","Hejiatai","Chokhopani","Daxi","Baojianshan"]
ns=["Qihe","LiangDaoF","LiangDaoM","Suogang","Bbdong","Boshan","XJS_F","XJS","Xiaogao","HDYM1"]

eas=["Han","Dai","Ami","Daur","Sherpa","Tibetan","Naxi","Yi"]
aeur=["Kostenki14","Vestonice16","GoyetQ116-1","ElMiron","Villabruna","Loschbour"]
ma1=["Malta1"]
jom=["JomonM"]
eplat=["ZongriM297"] #,"Hejiatai"
wplat=["Chokhopani"]
sham=["Shamanka_EN"]
koly=["Kolyma_River"]
devil=["DevilsGate"]
ma55=["Ma555_G6"]
weur=["Vestonice16"]
ust=["UstIshim"]
gx=["Longlin"] #,"Baojianshan"
ong=["Onge"]
hoa=["La368_G1"] #,"Ma911_G1"]
pap=["Papuan"]
ty=["Tianyuan"] #,"Papuan","Onge","Oase1","Stuttgart",
yan=["Yana_old","Yana_old2"]
varypops=[jom,gx,eplat,wplat,sham,koly,ma55][::-1]
labels=["Iwakazu","Guangxi","East Plateau","West Plateau","Shamanka_EN","Kolyma_River",'Ma555_G6'][::-1] #/Papuan/Onge/Oase1
dxcluster=ns
dxpairs=[(i,j) for indi,i in enumerate(dxcluster) for indj,j in enumerate(dxcluster) if indi>indj]
dxpairs=[(i,"Han") for indi,i in enumerate(dxcluster) if i!="Han"]
print len(dxpairs)
#dxpairs=dxpairs[:3]
pairlabels=["%s_%s" % mypair for mypair in dxpairs]
#print pairlabels
out="Mbuti"
colors=["blue","brown","red","black","pink","gray","purple"][::-1]
markers=["o","v","s","+","D",">","<","^",'x','p','h']
print len(dxpairs)

fig = plt.figure(figsize=(15,7))
axs = [ fig.add_subplot(2,4,ind+1) for ind,i in enumerate(varypops) ]
handles1,handles2=[],[]
for ind,mypair in enumerate(dxpairs):
    if ind % 10==0: print ind,mypair
    #ax1.set_title("D(X1, aGQ; X2, Mbuti)")

    for ivp,varypop in enumerate(varypops):
        if ind==0:
            axs[ivp].set_ylim((-7,13.5))
            axs[ivp].set_xlim((-7,13.5))
            axs[ivp].set_ylabel("P1=Han; P3=aNS",fontsize=12)
            axs[ivp].set_xlabel("P1=aNS; P3=Han",fontsize=12)
            axs[ivp].set_title("Z for D(P1, %s; P3, %s)" % (labels[ivp],out),fontsize=12)
            axs[ivp].axvline(x=0, ls='dashed', c='black')
            axs[ivp].axhline(y=0, ls='dashed', c='black')
            axs[ivp].axvline(x=2, ls='dashed', c='lightgray')
            axs[ivp].axhline(y=2, ls='dashed', c='lightgray')
            axs[ivp].axvline(x=-2, ls='dashed', c='lightgray')
            axs[ivp].axhline(y=-2, ls='dashed', c='lightgray')
        mypops1=[out,[mypair[1]],varypop,mypair[0]]
        mypops2=[out,[mypair[0]],varypop,mypair[1]]
        
        Zary1 = pm.mkDary(pD,fhall,mypops1,(0,3),(1,2),'Z')
        Zary2 = pm.mkDary(pD,fhall,mypops2,(0,3),(1,2),'Z')
        #Zary=np.transpose(np.vstack((Zary1, Zary2)))[0,:]
        #print Zary1, Zary2
        axs[ivp].plot(Zary1,Zary2,'o',color=colors[ivp],marker=markers[ind])
        if ivp==0:
            handles1.append(mlines.Line2D([],[],marker=markers[ind],color='black',label=mypair[0],linestyle=""))
        #if ind==0:
        #    handles2.append(mpatches.Patch(color=colors[ivp], label=labels[ivp]))
        else: pass
#ax1.legend(loc='lower right')
axs.append(fig.add_subplot(2,4,8))
#ax1.legend(handles=handles1+handles2,loc=4,ncol=2)
axs[-1].legend(handles=handles1,loc=4,ncol=1)
#ax1.legend(handles=handles2,loc=0)
plt.tight_layout()
plt.show()

#fig.savefig(pD+'aNSclade.D%s.relASN.png' % tv) # save the figure to file
#plt.close(fig)
# Out:
# 10
# 10
# 0 ('Qihe', 'Han')

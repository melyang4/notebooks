# %% [markdown]
# ## All

# %%
# %%writefile /mnt/solexa/mel_yang/early_CN/treemix/maketreemixfile_ALL_A.py
from projmodules import treemix_mkinput

pd="/mnt/solexa/mel_yang/data/2.2M/"
outpD="/mnt/solexa/mel_yang/early_CN/treemix/"
fh="UPA19_3"
subset='ALL_A'
setstotry=[['Tianyuan','UstIshim','Kolyma_River','Vestonice16','Yana_old','JomonM','Shamanka_EN',
            'La368_G1','Bbdong','Boshan','Qihe','LiangDaoF','LiangDaoM','HDYM1','ZongriM297',
            'Hejiatai','Chokhopani','Mbuti'], ##1693
           ['Tianyuan','UstIshim','Kolyma_River','Yana_old','JomonM','Shamanka_EN',
            'La368_G1','Bbdong','Qihe','LiangDaoF',
            'HDYM1','ZongriM297','Chokhopani','Mbuti'],  ##3362
           ['Tianyuan','UstIshim','Kolyma_River','Vestonice16','Yana_old','JomonM','Shamanka_EN',
            'La368_G1','Onge','Bbdong','Boshan','Qihe','LiangDaoF','LiangDaoM','HDYM1','ZongriM297',
            'Hejiatai','Chokhopani','Mbuti'], ##1693
           ['Tianyuan','UstIshim','Kolyma_River','Vestonice16','Yana_old','JomonM','Shamanka_EN',
            'La368_G1','Bbdong','Boshan','Qihe','LiangDaoF','LiangDaoM','HDYM1','ZongriM297',
            'Hejiatai','Chokhopani','Mbuti','Ami','Mixe','Dai','Daur','Han'], ##1691
           ['UstIshim','Kolyma_River','Yana_old','JomonM','Shamanka_EN',
            'Bbdong','Boshan','Qihe','LiangDaoF','HDYM1','ZongriM297',
            'Chokhopani','Mbuti','Ma555_G6'], ##3325
           ['UstIshim','Kolyma_River','Yana_old','JomonM','Shamanka_EN',
            'Bbdong','Boshan','LiangDaoF','HDYM1','ZongriM297',
            'Chokhopani','Mbuti','Ma555_G6'], ##5868
           ['UstIshim','Kolyma_River','Yana_old','JomonM','Shamanka_EN',
            'Bbdong','Boshan','LiangDaoF','HDYM1','Hejiatai',
            'Chokhopani','Mbuti','Ma555_G6'], ##
           ] 
for ind,i in enumerate(setstotry):
    print ind,i
    if ind!=6: continue
    treemix_mkinput(pd,fh,subset+str(ind),setstotry[ind])
# Out:
# Overwriting /mnt/solexa/mel_yang/early_CN/treemix/maketreemixfile_ALL_A.py

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/data/2.2M/"
# outpD="/mnt/solexa/mel_yang/early_CN/treemix/"
# fh="UPA19_3"
# subset='ALL_A'
# for i in 6; do
#     mv ${pd}${fh}.${subset}${i}.treemix.txt ${outpD}
# done

# %%
# %%writefile /mnt/solexa/mel_yang/early_CN/treemix/maketreemixgraphALL_A.sh
# pd="/mnt/solexa/mel_yang/early_CN/treemix/"
# tv=""
# fh="UPA19_3"
# k="500"
# myk="_k"${k}
# for j in 6; do #`seq 0 5`; do
#     subset="ALL_A"${j}
#     gzip ${pd}${fh}.${subset}.treemix.txt
#     for i in `seq 0 5`; do
#         treemix -i ${pd}${fh}.${subset}.treemix.txt.gz -root Mbuti -o ${pd}${tv}${subset}_m${i}${myk} -k ${k} -m ${i} > \
#             ${pd}${tv}${subset}_m${i}${myk}.log
#     done
# done
# Out:
# Overwriting /mnt/solexa/mel_yang/early_CN/treemix/maketreemixgraphALL_A.sh

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/treemix/"
# tv=""
# fh="UPA19_3"
# k="500"
# myk="_k"${k}
# for j in 6; do #`seq 0 5`; do
#     subset="ALL_A"${j}
#     zcat ${pd}${fh}.${subset}.treemix.txt.gz | head -n1 | tr ' ' '\n' > ${pd}${tv}${subset}.popns.txt
# done
# Out:
# gzip: /mnt/solexa/mel_yang/early_CN/treemix/UPA19_3.ALL_A6.treemix.txt.gz: No such file or directory

# %%
# %%writefile /mnt/solexa/mel_yang/early_CN/treemix/Rcodeimage.R
# args=commandArgs(TRUE)
# MYPD = as.character(args[1]) ##project directory
# PREFIX = as.character(args[2]) ##subset name of file
# MYID = as.numeric(args[3])  ##ID Number
# MYMIG = as.numeric(args[4])  ##Mig Number
# setwd(MYPD)
# source("plotting_funcs_MY.R")
# tv=""
# fh=PREFIX ##LLA
# k=500
# #for (id in c(0,1,2,3,4,5,6)) {
# for (myid in c(MYID)) {
# for (m in c(MYMIG)) {
#     #pdf(paste(tv,fh,id,'.m',m,'.pdf',sep=''))
#     png(paste(MYPD,'imagefiles/',tv,fh,myid,'_m',m,'_k',k,'.png',sep=''),width=580,height=580)
#     par(mfrow=c(2,1))
#     plot_tree(paste(MYPD,tv,fh,myid,"_m",m,"_k",k,sep=""),cex=1,plus=0.05,ybar=0.15,xmin=-0.015)
#     plot_resid(paste(MYPD,tv,fh,myid,"_m",m,"_k",k,sep=""),paste(fh,myid,".popns.txt",sep=""),cex=1)
#     #plot_resid(paste(tv,fh,myid,"_m",m,sep=""),paste(fh,id,".popns.txt",sep=""),cex=1,usemax=F,min=-0.001,max=0.001)
#     dev.off()
#     }
# }
# Out:
# Writing /mnt/solexa/mel_yang/early_CN/treemix/Rcodeimage.R

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/treemix/"
# id=6
# for mig in 0 1 2 3 4 5; do
#     Rscript ${pd}Rcodeimage.R /mnt/solexa/mel_yang/early_CN/treemix/ ALL_A ${id} ${mig}
# done
# Out:
# Error in open.connection(file, "rt") : cannot open the connection
# Calls: plot_tree -> read.table -> open -> open.connection
# In addition: Warning message:
# In open.connection(file, "rt") :
#   cannot open compressed file '/mnt/solexa/mel_yang/early_CN/treemix/ALL_A6_m0_k500.vertices.gz', probable reason 'No such file or directory'
# Execution halted
# Error in open.connection(file, "rt") : cannot open the connection
# Calls: plot_tree -> read.table -> open -> open.connection
# In addition: Warning message:
# In open.connection(file, "rt") :
#   cannot open compressed file '/mnt/solexa/mel_yang/early_CN/treemix/ALL_A6_m1_k500.vertices.gz', probable reason 'No such file or directory'
# Execution halted
# Error in open.connection(file, "rt") : cannot open the connection
# Calls: plot_tree -> read.table -> open -> open.connection
# In addition: Warning message:
# In open.connection(file, "rt") :
# ...

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/treemix/"
# id=3
# for mig in 0 1 2 3 4 5; do
#     Rscript ${pd}Rcodeimage.R /mnt/solexa/mel_yang/early_CN/treemix/ ALL_B ${id} ${mig}
# done
# Out:
#     V1          V2       V3      V4      V5  V6  V7 V8  V9 V10
# 1    0        <NA> NOT_ROOT NOT_MIG NOT_TIP 136 212  2 255   1
# 2    1    UstIshim NOT_ROOT NOT_MIG     TIP  52  NA NA  NA  NA
# 3    2        <NA> NOT_ROOT NOT_MIG NOT_TIP  76  15  1  32   7
# 4    3    LiangDao NOT_ROOT NOT_MIG     TIP  32  NA NA  NA  NA
# 5    4      aNepal NOT_ROOT NOT_MIG     TIP  16  NA NA  NA  NA
# 6   15     Guangxi NOT_ROOT NOT_MIG     TIP   2  NA NA  NA  NA
# 7   16        <NA> NOT_ROOT NOT_MIG NOT_TIP 136  31  1   4   1
# 8   31      Zongri NOT_ROOT NOT_MIG     TIP  16  NA NA  NA  NA
# 9   32        <NA> NOT_ROOT NOT_MIG NOT_TIP   2   3  1 104   6
# 10  51       Mbuti NOT_ROOT NOT_MIG     TIP 257  NA NA  NA  NA
# 11  52        <NA> NOT_ROOT NOT_MIG NOT_TIP 257   1  1 172  10
# 12  75      Kolyma NOT_ROOT NOT_MIG     TIP 104  NA NA  NA  NA
# 13  76        <NA> NOT_ROOT NOT_MIG NOT_TIP 172 103  1   2   8
# 14 103      JomonM NOT_ROOT NOT_MIG     TIP  76  NA NA  NA  NA
# ...

# %% [markdown]
# ## Merge populations

# %%
# %%writefile /mnt/solexa/mel_yang/early_CN/treemix/makenewtreemix_ALL_B.py

def treemix_mkinput(pd,myfilename,subset,popnsiwant,indfilename="NA",includemissing=False):
    ##pd=project Directory
    ##myfilename==fh before the '.ind' (needs to be from an eigenstrat format
    ##subset==name to add on (and final name of files)
    ##popnsiwant==list of popns to include in treemix file
    ##if indfilename!="NA" then it needs to specify name of indfile, 
    ##which can be different from geno/snp file (but make sure it lines up correctly)
    ##Currently discards site if any missing data
    import numpy as np
    import random
    
    if indfilename == "NA": myindfile = open(pd+myfilename+'.ind', 'r')
    else: myindfile = open(pd+indfilename+'.ind', 'r')
    popindex=[[] for i in popnsiwant]
    for ind,line in enumerate(myindfile):
        mypop = line.strip().split()[2]
        if mypop in popnsiwant: 
            popindex[popnsiwant.index(mypop)].append(ind)
    myindfile.close()

    treemixindfile = open(pd+subset+'.popns.txt','w')
    treemixindfile.write('\n'.join(popnsiwant)+'\n')
    treemixindfile.close()
    
    myfile = open(pd+myfilename+'.geno','r')
    
    newfile = open(pd+myfilename+'.'+subset+'.treemix.txt','w')
    newfile.write(' '.join(popnsiwant)+'\n')
    
    if includemissing==False:
        popindexmerge = [item for sublist in popindex for item in sublist]
        num=0
        for ind,line in enumerate(myfile):
            tempary = np.array([int(i) for i in line.strip()])
            tempary1 = tempary[popindexmerge]
            #tempary2 = tempary1[tempary1!=9]
            #if 9 in tempary1: continue
            totmiss=False
            newline = ''
            for ind2,myset in enumerate(popindex):
                myarys=tempary[myset]
                myarys=myarys[myarys!=9]
                if myarys.shape[0]==0: totmiss=True; break
                snp1 = np.sum(myarys)
                snp2 = (2*myarys.shape[0])-snp1
                newline += '%d,%d ' % (snp1,snp2)
            if totmiss==True: continue
            newfile.write( newline[:-1] + '\n')
            ##if num == 1: break
            num+=1
    if includemissing==True:
        for ind,line in enumerate(myfile):
            #if ind>5: break 
            newline=''
            for ind2,myset in enumerate(popindex):
                mygenos=sum([int(line[pos]) for pos in myset if line[pos]!='9'])
                mycounts=sum([2 for pos in myset if line[pos]!='9'])
                #print popnsiwant[ind2], mygenos, mycounts, [line[pos] for pos in myset]
                if mycounts==0: newline='pleasecontinue'; break
                else: newline += '%d,%d ' % (mygenos,mycounts-mygenos)
                #elif mycounts==2: 
                #    if mygenos==0: newline += '%d,%d ' % (0,2)
                #    elif mygenos==1: newline += '%d,%d ' % (1,1)
                #    elif mygenos==2: newline += '%d,%d ' % (2,0)
                #    else: print mygenos, 'wha???'
                #else: 
                #    fullset=['a']*mygenos+['b']*(mycounts-mygenos)
                #    sampledalleles=''.join(random.sample(fullset,2))
                #    if sampledalleles == 'aa': newline += '%d,%d ' % (2,0)
                #    elif sampledalleles == 'bb': newline += '%d,%d ' % (0,2)
                #    elif sampledalleles in ['ab','ba']: newline += '%d,%d ' % (1,1)
                #    else: print 'whaaa?', sampledalleles
                
            if newline=='pleasecontinue': continue
            #print newline
            newfile.write( newline[:-1] + '\n')
               
    newfile.close()
    myfile.close()
    return "Made Treemix file! GZip it!"


pd="/mnt/solexa/mel_yang/data/2.2M/"
outpD="/mnt/solexa/mel_yang/early_CN/treemix/"
fh="UPA19_3"
subset='ALL_B'
setstotry=[['UstIshim','Kolyma','Yana','JomonM','Shamanka_EN','Shandong','Qihe','LiangDao','HDYM1','Zongri',
            'GansuQinghai','aNepal','Mbuti'], ##
           ['UstIshim','Kolyma','Yana','JomonM','Shamanka_EN','Shandong','LiangDao','HDYM1','Zongri',
            'GansuQinghai','aNepal','Mbuti'], ##
           ['UstIshim','Kolyma','Yana','JomonM','Shamanka_EN','Shandong','LiangDao','HDYM1','Zongri',
            'aNepal','Mbuti'], ##
           ['UstIshim','Kolyma','Yana','JomonM','Shamanka_EN','Shandong','LiangDao','HDYM1','Zongri',
            'aNepal','Guangxi','Mbuti'], ##
           ['UstIshim','Kolyma','Yana','JomonM','Shamanka_EN','Shandong','Qihe','LiangDao','HDYM1','Zongri',
            'GansuQinghai','aNepal','Mbuti',"Austronesian"], ##
           ['UstIshim','Kolyma','Yana','JomonM','Shamanka_EN','Shandong','Qihe','LiangDao','HDYM1','Zongri',
            'GansuQinghai','aNepal','Mbuti',"Austronesian","Loschbour"], ##
           ['UstIshim','Kolyma','Yana','JomonM','Shamanka_EN','Shandong','Qihe','LiangDao','HDYM1','Zongri',
            'GansuQinghai','aNepal','Mbuti',"Austronesian","Loschbour","Ami","Mixe","Surui"], ##
           ['UstIshim','Kolyma','Yana','JomonM','Shamanka_EN','Shandong','LiangDao','HDYM1','Zongri',
            'aNepal','Mbuti',"Group6","Ami","La368_G1"], ##
           ['UstIshim','Kolyma','Yana','JomonM','Shamanka_EN','Shandong','LiangDao','HDYM1','Zongri',
            'aNepal','Mbuti',"Group6","Ami","La368_G1","Qihe"], ##
           ['UstIshim','Kolyma','Yana','JomonM','Shamanka_EN','Shandong','LiangDao','HDYM1','Zongri',
            'aNepal','Mbuti',"Group6","Ami","Onge"], ##
           ['UstIshim','Kolyma','Yana','JomonM','Shamanka_EN','Shandong','LiangDao','HDYM1','Zongri',
            'aNepal','Mbuti',"Group6","Ami","La368_G1","Onge"], ##10
           ['UstIshim','Kolyma','Yana','JomonM','Shamanka_EN','Shandong','Qihe','LiangDao','HDYM1','Zongri',
            'GansuQinghai','aNepal','Mbuti',"Group6","Ami","La368_G1","Tianyuan"], ##
           ['UstIshim','Kolyma','Yana','JomonM','Shamanka_EN','Shandong','LiangDao','HDYM1',
            'GansuQinghai','aNepal','Mbuti',"Group6","La368_G1","Tianyuan"], ##12
           ['UstIshim','Yana','JomonM','Shandong','LiangDao','HDYM1',"Man_Bac","Ban_Chiang","Nui_Nap","Qihe","Suogang",
            'Mbuti',"Ami","Group6","La368_G1","Tianyuan"], ##13, 1200 SNPs
           ['UstIshim','Yana','JomonM','Shandong','LiangDao','HDYM1',"Qihe","Suogang",
            'Mbuti',"Group6","La368_G1","Tianyuan"], ##14
           ['UstIshim','Yana','JomonM','Shandong','LiangDao','HDYM1',"Qihe",
            "Vt_G2","La_G2","Ma912_G2","Th_G4",'Mbuti',"Group6","La368_G1","Tianyuan"], ##15, 5182 SNPs
           ['UstIshim','Kolyma','Yana','JomonM','Shamanka_EN','Shandong','LiangDao','HDYM1',
            'GansuQinghai','aNepal','Mbuti',"Group6","Tianyuan"], ##16 216607 ***USING
           ['UstIshim','Kolyma','Yana','JomonM','Shamanka_EN','Shandong','LiangDao','HDYM1',
            'GansuQinghai','aNepal','Mbuti',"Group6","Group1","Tianyuan"], ##17 94430
           ['UstIshim','Yana','JomonM','Shandong','LiangDao','HDYM1',"Man_Bac","Ban_Chiang","Nui_Nap","Qihe","Suogang",
            'Mbuti',"Ami","Group6","Group1","Tianyuan"], ##18 1323
           ['UstIshim','Yana','JomonM','Shandong','LiangDao','HDYM1',"Qihe","Suogang",
            'Mbuti',"Group6","Group1","Tianyuan"], ##19 13637
           ['UstIshim','Yana','JomonM','Shandong','LiangDao','HDYM1',"Qihe",
            "Vt_G2","La_G2","Ma912_G2","Th_G4",'Mbuti',"Group6","Group1","Tianyuan"], ##20 5806
           ['UstIshim','Kolyma','Yana','JomonM','Shamanka_EN','Shandong','LiangDao','HDYM1',
            'GansuQinghai','aNepal','Mbuti',"Group6","Onge","Tianyuan"], ##21 216586
           ['UstIshim','Yana','JomonM','Shandong','LiangDao','HDYM1',"Man_Bac","Ban_Chiang","Nui_Nap","Qihe","Suogang",
            'Mbuti',"Ami","Group6","Onge","Tianyuan"], ##22 2379
           ['UstIshim','Yana','JomonM','Shandong','LiangDao','HDYM1',"Qihe","Suogang",
            'Mbuti',"Group6","Onge","Tianyuan"], ##23 29226
           ['UstIshim','Yana','JomonM','Shandong','LiangDao','HDYM1',"Qihe",
            "Vt_G2","La_G2","Ma912_G2","Th_G4",'Mbuti',"Group6","Onge","Tianyuan"], ##24 10853
           ['UstIshim','Kolyma','Yana','JomonM','Shandong','LiangDao','HDYM1',
            'aNepal','Mbuti',"Group6","Ami","Qihe"], ##25
           ['UstIshim','Kolyma','Yana','JomonM','Shandong','LiangDao','HDYM1','Shamanka_EN',
            'aNepal','Mbuti',"Group6","Ami","Qihe"], ##26
           ['UstIshim','Kolyma','Yana','JomonM','Shamanka_EN','Shandong','LiangDao','HDYM1',
            'GansuQinghai','aNepal','Mbuti',"Group6","Tianyuan","Qihe"], ##27
           ['UstIshim','Kolyma','Yana','JomonM','Shamanka_EN','Shandong','LiangDao','HDYM1',
            'GansuQinghai','aNepal','Mbuti',"Group6","Tianyuan","Qihe","Ami"], ##28 ***
           ['UstIshim','Itelman','Kostenki14','JomonM','Shamanka_EN','Shandong','LiangDao','HDYM1',
            'GansuQinghai','aNepal','Mbuti',"Group6","Tianyuan","Qihe","Ami"], ##29
          ]
for ind,i in enumerate(setstotry):
    print ind,i
    if ind<=28: continue
    treemix_mkinput(pd,fh,subset+str(ind),setstotry[ind],indfilename="UPA19_3.treemixmerge1")
# Out:
# Overwriting /mnt/solexa/mel_yang/early_CN/treemix/makenewtreemix_ALL_B.py

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/data/2.2M/"
# outpD="/mnt/solexa/mel_yang/early_CN/treemix/"
# fh="UPA19_3"
# subset='ALL_B'
# for i in 29; do
#     mv ${pd}${fh}.${subset}${i}.treemix.txt ${outpD}
# done

# %%
# %%writefile /mnt/solexa/mel_yang/early_CN/treemix/maketreemixgraphALL_B.sh
# pd="/mnt/solexa/mel_yang/early_CN/treemix/"
# tv=""
# fh="UPA19_3"
# k="500"
# myk="_k"${k}
# for j in 29; do #`seq 0 5`; do
#     subset="ALL_B"${j}
#     echo ${j}
#     gzip ${pd}${fh}.${subset}.treemix.txt
#     for i in `seq 0 5`; do
#         treemix -i ${pd}${fh}.${subset}.treemix.txt.gz -root Mbuti -o ${pd}${tv}${subset}_m${i}${myk} -k ${k} -m ${i} > \
#             ${pd}${tv}${subset}_m${i}${myk}.log
#     done
# done
# Out:
# Overwriting /mnt/solexa/mel_yang/early_CN/treemix/maketreemixgraphALL_B.sh

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/treemix/"
# tv=""
# fh="UPA19_3"
# k="500"
# myk="_k"${k}
# for j in 29 ; do #`seq 0 5`; do
#     subset="ALL_B"${j}
#     zcat ${pd}${fh}.${subset}.treemix.txt.gz | head -n1 | tr ' ' '\n' > ${pd}${tv}${subset}.popns.txt
# done
# Out:
# gzip: stdout: Broken pipe

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/treemix/"
# id=29
# for mig in 0 1 2 3 4 5; do
#     Rscript ${pd}Rcodeimage.R /mnt/solexa/mel_yang/early_CN/treemix/ ALL_B ${id} ${mig}
# done
# Out:
#     V1           V2       V3      V4      V5  V6  V7 V8  V9 V10
# 1    0         <NA> NOT_ROOT NOT_MIG NOT_TIP 412  75  1   4   1
# 2    1          Ami NOT_ROOT NOT_MIG     TIP 256  NA NA  NA  NA
# 3    2         <NA> NOT_ROOT NOT_MIG NOT_TIP  16   3  1 172   5
# 4    3       aNepal NOT_ROOT NOT_MIG     TIP   2  NA NA  NA  NA
# 5    4   Kostenki14 NOT_ROOT NOT_MIG     TIP   0  NA NA  NA  NA
# 6   15        HDYM1 NOT_ROOT NOT_MIG     TIP  52  NA NA  NA  NA
# 7   16         <NA> NOT_ROOT NOT_MIG NOT_TIP  32   2  6 304   4
# 8   31       JomonM NOT_ROOT NOT_MIG     TIP  32  NA NA  NA  NA
# 9   32         <NA> NOT_ROOT NOT_MIG NOT_TIP 104  16 10  31   1
# 10  51      Itelman NOT_ROOT NOT_MIG     TIP 136  NA NA  NA  NA
# 11  52         <NA> NOT_ROOT NOT_MIG NOT_TIP 212  15  1 211   1
# 12  75     UstIshim NOT_ROOT NOT_MIG     TIP   0  NA NA  NA  NA
# 13 103     Tianyuan NOT_ROOT NOT_MIG     TIP 104  NA NA  NA  NA
# 14 104         <NA> NOT_ROOT NOT_MIG NOT_TIP 412 103  1  32  11
# ...

# %%
# Out:
# Overwriting /mnt/solexa/mel_yang/early_CN/treemix/makenewtreemix_ALL_B.py

# %%
import numpy as np
x=np.array([9,9,9])
y=x[x!=9]
print y.shape
# Out:
# (0,)

# %%
# %%writefile /mnt/solexa/mel_yang/early_CN/treemix/makenewtreemix_ALL_C.py

def treemix_mkinput(pd,myfilename,subset,popnsiwant,indfilename="NA",includemissing=False):
    ##pd=project Directory
    ##myfilename==fh before the '.ind' (needs to be from an eigenstrat format
    ##subset==name to add on (and final name of files)
    ##popnsiwant==list of popns to include in treemix file
    ##if indfilename!="NA" then it needs to specify name of indfile, 
    ##which can be different from geno/snp file (but make sure it lines up correctly)
    ##Currently discards site if any missing data
    import numpy as np
    import random
    
    if indfilename == "NA": myindfile = open(pd+myfilename+'.ind', 'r')
    else: myindfile = open(pd+indfilename+'.ind', 'r')
    popindex=[[] for i in popnsiwant]
    for ind,line in enumerate(myindfile):
        mypop = line.strip().split()[2]
        if mypop in popnsiwant: 
            popindex[popnsiwant.index(mypop)].append(ind)
    myindfile.close()

    treemixindfile = open(pd+subset+'.popns.txt','w')
    treemixindfile.write('\n'.join(popnsiwant)+'\n')
    treemixindfile.close()
    
    myfile = open(pd+myfilename+'.geno','r')
    
    newfile = open(pd+myfilename+'.'+subset+'.treemix.txt','w')
    newfile.write(' '.join(popnsiwant)+'\n')
    
    if includemissing==False:
        popindexmerge = [item for sublist in popindex for item in sublist]
        num=0
        for ind,line in enumerate(myfile):
            tempary = np.array([int(i) for i in line.strip()])
            tempary1 = tempary[popindexmerge]
            #tempary2 = tempary1[tempary1!=9]
            #if 9 in tempary1: continue
            totmiss=False
            newline = ''
            for ind2,myset in enumerate(popindex):
                myarys=tempary[myset]
                myarys=myarys[myarys!=9]
                if myarys.shape[0]==0: totmiss=True; break
                snp1 = np.sum(myarys)
                snp2 = (2*myarys.shape[0])-snp1
                newline += '%d,%d ' % (snp1,snp2)
            if totmiss==True: continue
            newfile.write( newline[:-1] + '\n')
            ##if num == 1: break
            num+=1
    if includemissing==True:
        for ind,line in enumerate(myfile):
            #if ind>5: break 
            newline=''
            for ind2,myset in enumerate(popindex):
                mygenos=sum([int(line[pos]) for pos in myset if line[pos]!='9'])
                mycounts=sum([2 for pos in myset if line[pos]!='9'])
                #print popnsiwant[ind2], mygenos, mycounts, [line[pos] for pos in myset]
                if mycounts==0: newline='pleasecontinue'; break
                else: newline += '%d,%d ' % (mygenos,mycounts-mygenos)
                #elif mycounts==2: 
                #    if mygenos==0: newline += '%d,%d ' % (0,2)
                #    elif mygenos==1: newline += '%d,%d ' % (1,1)
                #    elif mygenos==2: newline += '%d,%d ' % (2,0)
                #    else: print mygenos, 'wha???'
                #else: 
                #    fullset=['a']*mygenos+['b']*(mycounts-mygenos)
                #    sampledalleles=''.join(random.sample(fullset,2))
                #    if sampledalleles == 'aa': newline += '%d,%d ' % (2,0)
                #    elif sampledalleles == 'bb': newline += '%d,%d ' % (0,2)
                #    elif sampledalleles in ['ab','ba']: newline += '%d,%d ' % (1,1)
                #    else: print 'whaaa?', sampledalleles
                
            if newline=='pleasecontinue': continue
            #print newline
            newfile.write( newline[:-1] + '\n')
               
    newfile.close()
    myfile.close()
    return "Made Treemix file! GZip it!"


pd="/mnt/solexa/mel_yang/data/2.2M/"
outpD="/mnt/solexa/mel_yang/early_CN/treemix/"
fh="UPA19_3"
subset='ALL_C'
setstotry=[['Tianyuan','UstIshim','Kolyma_River','Vestonice16','Yana_old','JomonM','Shamanka_EN',
            'La368_G1','Bbdong','Boshan','Qihe','LiangDaoF','LiangDaoM','HDYM1','ZongriM297',
            'Hejiatai','Chokhopani','Mbuti'], ##1693
           ['Tianyuan','UstIshim','Kolyma_River','Yana_old','JomonM','Shamanka_EN',
            'La368_G1','Bbdong','Qihe','LiangDaoF',
            'HDYM1','ZongriM297','Chokhopani','Mbuti'],  ##3362
           ['Tianyuan','UstIshim','Kolyma_River','Vestonice16','Yana_old','JomonM','Shamanka_EN',
            'La368_G1','Onge','Bbdong','Boshan','Qihe','LiangDaoF','LiangDaoM','HDYM1','ZongriM297',
            'Hejiatai','Chokhopani','Mbuti'], ##1693
           ['Tianyuan','UstIshim','Kolyma_River','Vestonice16','Yana_old','JomonM','Shamanka_EN',
            'La368_G1','Bbdong','Boshan','Qihe','LiangDaoF','LiangDaoM','HDYM1','ZongriM297',
            'Hejiatai','Chokhopani','Mbuti','Ami','Mixe','Dai','Daur','Han'], ##1691
           ['UstIshim','Kolyma_River','Yana_old','JomonM','Shamanka_EN',
            'Bbdong','Boshan','Qihe','LiangDaoF','HDYM1','ZongriM297',
            'Chokhopani','Mbuti','Ma555_G6'], ##3325
           ['UstIshim','Kolyma_River','Yana_old','JomonM','Shamanka_EN',
            'Bbdong','Boshan','LiangDaoF','HDYM1','ZongriM297',
            'Chokhopani','Mbuti','Ma555_G6'], ##5868
           ['UstIshim','Kolyma_River','Yana_old','JomonM','Shamanka_EN',
            'Bbdong','Boshan','LiangDaoF','HDYM1','Hejiatai',
            'Chokhopani','Mbuti','Ma555_G6'], ##
           ] 
for ind,i in enumerate(setstotry):
    print ind,i
    #if ind!=6: continue
    treemix_mkinput(pd,fh,subset+str(ind),setstotry[ind])
# Out:
# Writing /mnt/solexa/mel_yang/early_CN/treemix/makenewtreemix_ALL_C.py

# %%
# %%writefile /mnt/solexa/mel_yang/early_CN/treemix/maketreemixgraphALL_C.sh
# pd="/mnt/solexa/mel_yang/early_CN/treemix/"
# tv=""
# fh="UPA19_3"
# k="500"
# myk="_k"${k}
# for j in 0 1 2 3 4 5 6; do #`seq 0 5`; do
#     subset="ALL_C"${j}
#     echo ${j}
#     gzip ${pd}${fh}.${subset}.treemix.txt
#     for i in `seq 0 5`; do
#         treemix -i ${pd}${fh}.${subset}.treemix.txt.gz -root Mbuti -o ${pd}${tv}${subset}_m${i}${myk} -k ${k} -m ${i} > \
#             ${pd}${tv}${subset}_m${i}${myk}.log
#     done
# done
# Out:
# Writing /mnt/solexa/mel_yang/early_CN/treemix/maketreemixgraphALL_C.sh

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/treemix/"
# tv=""
# fh="UPA19_3"
# k="500"
# myk="_k"${k}
# for j in 0 1 2 3 4; do #`seq 0 5`; do
#     subset="ALL_C"${j}
#     zcat ${pd}${fh}.${subset}.treemix.txt.gz | head -n1 | tr ' ' '\n' > ${pd}${tv}${subset}.popns.txt
# done

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/treemix/"
# id=11
# for id in 0 1 2 3 4; do
# for mig in 0 1 2 3 4 5; do
#     Rscript ${pd}Rcodeimage.R /mnt/solexa/mel_yang/early_CN/treemix/ ALL_B ${id} ${mig}
# done
# done
# Out:
#     V1           V2       V3      V4      V5  V6  V7 V8  V9 V10
# 1    0         <NA> NOT_ROOT NOT_MIG NOT_TIP 304   3  1 172   9
# 2    1       aNepal NOT_ROOT NOT_MIG     TIP 136  NA NA  NA  NA
# 3    2         <NA> NOT_ROOT NOT_MIG NOT_TIP 172  16  6 256   2
# 4    3       JomonM NOT_ROOT NOT_MIG     TIP   0  NA NA  NA  NA
# 5    4       Kolyma NOT_ROOT NOT_MIG     TIP 172  NA NA  NA  NA
# 6   15 GansuQinghai NOT_ROOT NOT_MIG     TIP  76  NA NA  NA  NA
# 7   16         <NA> NOT_ROOT NOT_MIG NOT_TIP   2 136  5 135   1
# 8   31        HDYM1 NOT_ROOT NOT_MIG     TIP  76  NA NA  NA  NA
# 9   32         <NA> NOT_ROOT NOT_MIG NOT_TIP 212  76  2  75   1
# 10  52         <NA>     ROOT NOT_MIG NOT_TIP  52 103  1 104  12
# 11  51     UstIshim NOT_ROOT NOT_MIG     TIP 104  NA NA  NA  NA
# 12  75       Zongri NOT_ROOT NOT_MIG     TIP  32  NA NA  NA  NA
# 13  76         <NA> NOT_ROOT NOT_MIG NOT_TIP  32  15  1  31   1
# 14 103        Mbuti NOT_ROOT NOT_MIG     TIP  52  NA NA  NA  NA
# ...

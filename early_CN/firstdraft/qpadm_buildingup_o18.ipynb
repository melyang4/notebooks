# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"

base=["Mota","UstIshim","Kostenki14","Iran_N",
      "Yana","Karelia","Okunevo_EMBA","IndusPeriphery",
      "Natufian","Papuan","Onge","Clovis", ##no USR
      "Tianyuan","Ma912_G2"] 
fh="UPA19_3"
ff.mklst(pD,fh,"o18",base)
# Out:
# 'Made /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/UPA19_3.o18 file'

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"

fh="UPA19_3"
ff.mklst(outpd,fh,"wave.o183EAS.leftpop",["Kolyma","Qihe","Bbdong"])
ff.parfile(pD,fh,"wave","o183EAS",outpd=outpd,outgroup=fh+".o18",indfh='UPA19_3.qpadmmerge1')

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"

fh="UPA19_3"
ff.mklst(outpd,fh,"wave.o183aEAS.leftpop",["Kolyma","LiangDao","Bbdong"])
ff.parfile(pD,fh,"wave","o183aEAS",outpd=outpd,outgroup=fh+".o18",indfh='UPA19_3.qpadmmerge1')
# Out:
# 'Made wave PAR file /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/UPA19_3.wave.o183aEAS.par'

# %% [markdown]
# Using o18, we find that Kolyma, Qihe, and Bbdong require three streams of ancestry. We treat them as potential source populations in o18+KQB

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"

base=["Mota","UstIshim","Iran_N",
      "Karelia","Okunevo_EMBA","IndusPeriphery",
      "Natufian","Papuan","Onge","Kostenki14","Yana","Clovis", ##no USR
      "Tianyuan","Ma912_G2","Kolyma","Qihe","Bbdong"] 
fh="UPA19_3"
ff.mklst(pD,fh,"o18+KQB",base)
# Out:
# 'Made /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/UPA19_3.o18+KQB file'

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"

base=["Mota","UstIshim","Iran_N",
      "Karelia","Okunevo_EMBA","IndusPeriphery",
      "Natufian","Papuan","Onge","Kostenki14","Yana","Clovis", ##no USR
      "Tianyuan","Ma912_G2","Kolyma","LiangDao","Bbdong"] 
fh="UPA19_3"
ff.mklst(pD,fh,"o18+KLB",base)
# Out:
# 'Made /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/UPA19_3.o18+KLB file'

# %% [markdown]
# ## Code run
#
# Run one source for all ANCASN (B1) and PDASN (PDEASB1).
# ```
# for i in MG6 Phl534_G6 Samdzong Mebrak ZongriM297 Hejiatai HDYM1 Chokhopani JomonM Shamanka_EN LiangDao Man_Bac Suogang Boshan XJS_F Xiaogao LG2 Vt833_G2 Vt880_G2 Nui_Nap Ban_Chiang Oakaie1; do python generalSS.py 20 B1 o18+KLB ${i}; done
#
# for i in Qihe; do python generalSS.py 20 B1 o18+KLB ${i}; done
#
# for i in MG6 Phl534_G6; do python generalSS.py 20 B1 o18+KQB ${i}; done
#
# for i in Han Ami Dai Atayal Lahu Daur Hezhen Tibetan_ShannanX Tibetan_ChamdoX Miao She Korean Japanese Tujia Naxi Yi Kinh ; do python generalSS.py 20 PDEASB1 o18+KLB ${i}; done
#
# for i in Sherpa_ShigatseX Tibetan_ShigatseX Tibetan_LhasaX Tibetan_NagquX Ulchi Oroqen Xibo Uygur Tibetan Sherpa Han_HenanX Han_GansuX Han_XinjiangX Han_ShandongX Han_JiangsuX Han_AnhuiX Han_SichuanX Han_HubeiX Han_GuangdongX Han_ChongqingX; do python generalSS.py 20 PDEASB1 o18+KLB ${i}; done
# ```
#
# Mebrak, ZongriM297, Hejiatai, HDYM1, Chokhopani, XJS_F, Xiaogao can all be treated as one source with Bbdong.
# LiangDao, Suogang (mayeb MG6 and Phl534_G6) are treated as one source with Qihe.
# LG2 treated as source with Ma912_G2, Vt833_G2 as Ma912_G2 or Qihe, and Vt880_G2 and Ban_Chiang as those two or Bbdong. The highest p is always for Ma912_G2, followed by Qihe.
# Oakaie1 is always Ma912_G2 or Qihe.
#
#
# Tried DS for Boshan, Samdzong, JomonM, Shamanka_EN.
# python generalDS.py 20 B1 o18+KQB Boshan 0 &

# %% [markdown]
# ## ANC

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"
# name="A1" #
# name="B1"
# target="Shamanka_EN"
# suffix="_SS"
# out="o18+KLB"
# ancset1="Hejiatai Shamanka_EN LiangDao Man_Bac Suogang Boshan XJS_F Xiaogao Ma912_G2 Vt833_G2 Vt880_G2"
# ancset2="Hejiatai Shamanka_EN Qihe Man_Bac Suogang Boshan XJS_F Xiaogao Ma912_G2 Vt833_G2 Vt880_G2"
# ancset9="Samdzong Mebrak ZongriM297 Hejiatai Shamanka_EN Qihe Man_Bac Suogang Boshan XJS_F Xiaogao LG2 Vt833_G2 Vt880_G2"
# ancset10="Samdzong Mebrak ZongriM297 Hejiatai Shamanka_EN Qihe Man_Bac Suogang Boshan XJS_F Xiaogao Ma912_G2 Vt833_G2 Vt880_G2"
# pdeas="Ulchi Oroqen Xibo Uygur Sherpa_ShigatseX Tibetan_ShigatseX Tibetan_LhasaX Tibetan_NagquX Tibetan Sherpa Han_HenanX Han_GansuX Han_XinjiangX Han_HenanX Han_ShandongX Han_JiangsuX Han_AnhuiX Han_SichuanX Han_HubeiX Han_GuangdongX Han_ChongqingX Kinh"
# for target in Qihe MG6 Phl534_G6 Samdzong Mebrak ZongriM297 Hejiatai HDYM1 Chokhopani JomonM Shamanka_EN LiangDao Man_Bac Suogang Boshan XJS_F Xiaogao LG2 Vt833_G2 Vt880_G2 Nui_Nap Ban_Chiang Oakaie1; do
# #for target in Han Ami Dai Atayal Lahu Daur Hezhen Tibetan_ShannanX Tibetan_ChamdoX Miao She Korean Japanese Tujia Naxi Yi; do
# #for target in Ulchi Oroqen Xibo Uygur Sherpa_ShigatseX Tibetan_ShigatseX Tibetan_LhasaX Tibetan_NagquX Tibetan Sherpa Han_HenanX Han_GansuX Han_XinjiangX Han_HenanX Han_ShandongX Han_JiangsuX Han_AnhuiX Han_SichuanX Han_HubeiX Han_GuangdongX Han_ChongqingX Kinh; do
#     grep "f4rank: 0" ${pd}${name}/UPA19_3.adm.${name}${suffix}_${target}_*_${out}.log | awk '{ if ($8>0.05) print $1,$8}' | cut -d'/' -f9 | cut -d':' -f1,3
#
#
# done
# Out:
# UPA19_3.adm.B1_SS_Qihe_LiangDao_o18+KLB.log: 0.14657232
# UPA19_3.adm.B1_SS_Phl534_G6_Bbdong_o18+KLB.log: 0.487408957
# UPA19_3.adm.B1_SS_Phl534_G6_Clovis_o18+KLB.log: 0.141693152
# UPA19_3.adm.B1_SS_Phl534_G6_Kolyma_o18+KLB.log: 0.072099725
# UPA19_3.adm.B1_SS_Phl534_G6_LiangDao_o18+KLB.log: 0.612767645
# UPA19_3.adm.B1_SS_Hejiatai_Bbdong_o18+KLB.log: 0.0540105511
# UPA19_3.adm.B1_SS_JomonM_Ma912_G2_o18+KLB.log: 0.208232614
# UPA19_3.adm.B1_SS_Shamanka_EN_Karelia_o18+KLB.log: 3.20154539e-321
# UPA19_3.adm.B1_SS_Shamanka_EN_Mota_o18+KLB.log: 1.48219694e-323
# UPA19_3.adm.B1_SS_Man_Bac_Ma912_G2_o18+KLB.log: 0.0638436145
# UPA19_3.adm.B1_SS_Suogang_LiangDao_o18+KLB.log: 0.15757297
# UPA19_3.adm.B1_SS_XJS_F_Bbdong_o18+KLB.log: 0.12209466
# UPA19_3.adm.B1_SS_XJS_F_IndusPeriphery_o18+KLB.log: 6.8872751e-321
# UPA19_3.adm.B1_SS_XJS_F_Karelia_o18+KLB.log: 4.94065646e-324
# UPA19_3.adm.B1_SS_Xiaogao_Bbdong_o18+KLB.log: 0.75488952
# UPA19_3.adm.B1_SS_LG2_Ma912_G2_o18+KLB.log: 0.597625088
# UPA19_3.adm.B1_SS_Vt833_G2_Ma912_G2_o18+KLB.log: 0.165498165
# UPA19_3.adm.B1_SS_Vt880_G2_LiangDao_o18+KLB.log: 0.827295941
# UPA19_3.adm.B1_SS_Vt880_G2_Ma912_G2_o18+KLB.log: 0.944393887
# UPA19_3.adm.B1_SS_Ban_Chiang_LiangDao_o18+KLB.log: 0.757145435
# UPA19_3.adm.B1_SS_Ban_Chiang_Ma912_G2_o18+KLB.log: 0.267846434
# UPA19_3.adm.B1_SS_Oakaie1_LiangDao_o18+KLB.log: 0.297002067
# UPA19_3.adm.B1_SS_Oakaie1_Ma912_G2_o18+KLB.log: 0.616015285

# %%
import fstat_funcs as ff
import numpy as np

pd="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"

name="PDEASB1"
name="B1"
fh="UPA19_3"
anc=["JomonM","Kolyma","Chokhopani","Samdzong","Mebrak","ZongriM297","Hejiatai","HDYM1",
         "Shamanka_EN","Bbdong","Boshan","XJS_F","Xiaogao",
         "Qihe","LiangDao","Suogang","Man_Bac","LG2",
         "Vt833_G2","Vt880_G2","Nui_Nap","Ban_Chiang","Oakaie1"]
pdeas=["Han_JiangsuX","Han_AnhuiX","Han_SichuanX","Han_HubeiX","Han_GuangdongX","Han_ChongqingX",
         "Han","Han_HenanX","Han_GansuX","Han_XinjiangX","Han_ShandongX",
         "Ami","Atayal","Dai","Lahu","Kinh",
         "She","Miao","Tujia","Naxi","Yi",
         "Japanese","Korean","Daur","Hezhen","Xibo","Uygur",
        "Sherpa","Sherpa_ShigatseX","Tibetan","Tibetan_ShannanX",
         "Tibetan_ChamdoX","Tibetan_ShigatseX","Tibetan_LhasaX","Tibetan_NagquX","Ulchi","Oroqen"]
targets=anc
out="o18+KQB"
#out="o22+LBH"

myoutfile=open(pd+fh+"."+out,'r')
myouts = [line.strip() for line in myoutfile]
myoutfile

for ind,target in enumerate(targets):
    myp=[0 for i in myouts]
    for myout in myouts: 
        try:
            myfile=open(pd+name+"/"+fh+".adm."+name+"_SS_"+target+"_"+myout+"_"+out+".log",'r')
            for line in myfile:
                if "f4rank: 0" not in line: continue
                f4rank1=float(line.split()[7])
                myp[myouts.index(myout)]=f4rank1
            myfile.close()  
        except IOError: 
            myp=[np.nan for i in myouts]
    if ind==0: myary=np.array(myp)
    else: myary=np.vstack((myary,np.array(myp)))
#print myary
        #break

ff.Dmat2xlsx(myary,pd+name+"/"+fh+".adm."+name+"_SS_f4rank0_"+out,out,targets,myouts)
# Out:
# 'Made /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/B1/UPA19_3.adm.B1_SS_f4rank0_o18+KQB!'

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"
# name="PDEAS" #
# name="B1" #
# target="Samdzong"
# suffix="_DS"
# out="o18+KLB"
# for target in ${target}; do
#     grep "f4rank: 1" ${pd}${name}/UPA19_3.adm.${name}${suffix}_${target}_*_${out}.log | awk '{ if ($8>0.05) print $1,$8}' | cut -d'/' -f9 | cut -d':' -f1,3
#     myfile=$(grep "f4rank: 1" ${pd}${name}/UPA19_3.adm.${name}${suffix}_${target}_*_${out}.log | awk '{ if ($8>0.05) print $1,$8}' | cut -d'/' -f9 | cut -d':' -f1)
#     for i in ${myfile}; do
#         echo " ~~~~~~~~~~~~~~~~~~~~~~~ "
#         echo ${i}
#         tail -n176 ${pd}${name}/${i} | head -n8
#         done
#     done
# Out:
# grep: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/B1/UPA19_3.adm.B1_DS_Samdzong_*_o18+KLB.log: No such file or directory
# grep: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/B1/UPA19_3.adm.B1_DS_Samdzong_*_o18+KLB.log: No such file or directory

# %% [markdown]
# Boshan: Bbdong+Kolyma/Clovis
#
# JomonM: Bbdong+Onge, Ma912_G2+Natufian/Papuan/UstIshim
#
# Samdzong: Bbdong+Tianyuan
#
# Shamanka_EN: none - try triple source
#
# python generalTS.py 20 B1 o18+KQB Shamanka_EN 0 &

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"
# name="PDEAS" #
# name="B1" #
# target="Shamanka_EN"
# suffix="_TS"
# out="o18+KQB"
# for target in ${target}; do
#     grep "f4rank: 2" ${pd}${name}/UPA19_3.adm.${name}${suffix}_${target}_*_${out}.log | awk '{ if ($8>0.05) print $1,$8}' | cut -d'/' -f9 | cut -d':' -f1,3
#     myfile=$(grep "f4rank: 2" ${pd}${name}/UPA19_3.adm.${name}${suffix}_${target}_*_${out}.log | awk '{ if ($8>0.05) print $1,$8}' | cut -d'/' -f9 | cut -d':' -f1)
#     for i in ${myfile}; do
#         echo " ~~~~~~~~~~~~~~~~~~~~~~~ "
#         echo ${i}
#         tail -n71 ${pd}${name}/${i} | head -n13
#         done
#     done
# Out:
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Clovis_Kolyma_o18+KQB.log: 0.639206
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Clovis_Onge_o18+KQB.log: 0.132448608
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Clovis_Yana_o18+KQB.log: 0.0652872495
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Kolyma_Ma912_G2_o18+KQB.log: 0.339391995
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Kolyma_Onge_o18+KQB.log: 0.6528945
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Kolyma_Papuan_o18+KQB.log: 0.140312765
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Kolyma_Qihe_o18+KQB.log: 0.0524363494
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Kolyma_Tianyuan_o18+KQB.log: 0.162989702
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Kolyma_Yana_o18+KQB.log: 0.0501774388
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Kostenki14_Qihe_o18+KQB.log: 0.0716803584
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Ma912_G2_Onge_o18+KQB.log: 0.0734130954
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Ma912_G2_Tianyuan_o18+KQB.log: 0.163346544
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Onge_Papuan_o18+KQB.log: 0.654998455
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Qihe_Tianyuan_o18+KQB.log: 0.411389487
# UPA19_3.adm.B1_TS_Shamanka_EN_Clovis_Kolyma_Kostenki14_o18+KQB.log: 0.938025484
# UPA19_3.adm.B1_TS_Shamanka_EN_Clovis_Kolyma_Ma912_G2_o18+KQB.log: 0.936518416
# UPA19_3.adm.B1_TS_Shamanka_EN_Clovis_Kolyma_Onge_o18+KQB.log: 0.555619843
# UPA19_3.adm.B1_TS_Shamanka_EN_Clovis_Kolyma_Papuan_o18+KQB.log: 0.611916105
# UPA19_3.adm.B1_TS_Shamanka_EN_Clovis_Kolyma_Qihe_o18+KQB.log: 0.802181219
# UPA19_3.adm.B1_TS_Shamanka_EN_Clovis_Kolyma_Tianyuan_o18+KQB.log: 0.540711191
# UPA19_3.adm.B1_TS_Shamanka_EN_Clovis_Kolyma_Yana_o18+KQB.log: 0.811522073
# UPA19_3.adm.B1_TS_Shamanka_EN_Clovis_Onge_Papuan_o18+KQB.log: 0.677119246
# UPA19_3.adm.B1_TS_Shamanka_EN_Kolyma_Onge_Papuan_o18+KQB.log: 0.612952459
# UPA19_3.adm.B1_TS_Shamanka_EN_Kostenki14_Ma912_G2_Yana_o18+KQB.log: 0.4708257
# UPA19_3.adm.B1_TS_Shamanka_EN_Kostenki14_Onge_Papuan_o18+KQB.log: 0.615225174
# UPA19_3.adm.B1_TS_Shamanka_EN_Kostenki14_Onge_Tianyuan_o18+KQB.log: 0.147657417
# UPA19_3.adm.B1_TS_Shamanka_EN_Kostenki14_Papuan_Tianyuan_o18+KQB.log: 0.0939889614
# UPA19_3.adm.B1_TS_Shamanka_EN_Kostenki14_Qihe_Yana_o18+KQB.log: 0.145569884
# UPA19_3.adm.B1_TS_Shamanka_EN_Kostenki14_Tianyuan_Yana_o18+KQB.log: 0.209531647
# UPA19_3.adm.B1_TS_Shamanka_EN_Ma912_G2_Onge_Papuan_o18+KQB.log: 0.907123648
# UPA19_3.adm.B1_TS_Shamanka_EN_Onge_Papuan_Qihe_o18+KQB.log: 0.71101423
# UPA19_3.adm.B1_TS_Shamanka_EN_Onge_Papuan_Tianyuan_o18+KQB.log: 0.716852838
# UPA19_3.adm.B1_TS_Shamanka_EN_Onge_Papuan_Yana_o18+KQB.log: 0.722155543
# UPA19_3.adm.B1_TS_Shamanka_EN_Onge_Tianyuan_Yana_o18+KQB.log: 0.274285136
# UPA19_3.adm.B1_TS_Shamanka_EN_Papuan_Tianyuan_Yana_o18+KQB.log: 0.290263893
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Clovis_Kolyma_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     2.530        0.639206     0.208    -1.726     2.518  infeasible
#           001  1     5    12.672        0.026652     0.595     0.405     0.000
#           010  1     5    10.430       0.0639356     0.504    -0.000     0.496
#           100  1     5     2.607        0.760306     0.000    -2.714     3.714  infeasible
#           011  2     6    52.516     1.46863e-09     1.000    -0.000     0.000
#           101  2     6   100.349      2.1217e-19     0.000     1.000     0.000
#           110  2     6    47.328      1.6097e-08     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          010        0.0639356  chi(nested):     7.899 p-value for nested model:      0.00494526
# best pat:          110       1.6097e-08  chi(nested):    36.898 p-value for nested model:     1.24481e-09
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Clovis_Onge_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     7.066        0.132449     0.556     0.459    -0.015  infeasible
#           001  1     5     7.273        0.201137     0.550     0.450    -0.000
#           010  1     5    86.994     2.87362e-17     0.983    -0.000     0.017
#           100  1     5   101.144     3.03295e-20    -0.000     1.123    -0.123  infeasible
#           011  2     6    87.152     1.18162e-16     1.000     0.000    -0.000
#           101  2     6   104.991     2.27683e-20     0.000     1.000    -0.000
#           110  2     6   567.769               0     0.000     0.000     1.000
# best pat:          000                0              -  -
# best pat:          001         0.201137  chi(nested):     0.207 p-value for nested model:        0.649257
# best pat:          011      1.18162e-16  chi(nested):    79.880 p-value for nested model:       3.979e-19
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Clovis_Yana_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     8.838       0.0652872     0.499     0.549    -0.048  infeasible
#           001  1     5    11.101       0.0494198     0.522     0.478    -0.000
#           010  1     5    71.097      6.0585e-14     0.892    -0.000     0.108
#           100  1     5    50.044     1.35748e-09    -0.000     1.232    -0.232  infeasible
#           011  2     6    85.164     3.05329e-16     1.000    -0.000    -0.000
#           101  2     6    77.331     1.27009e-14     0.000     1.000    -0.000
#           110  2     6   798.633               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001        0.0494198  chi(nested):     2.263 p-value for nested model:        0.132496
# best pat:          101      1.27009e-14  chi(nested):    66.230 p-value for nested model:     4.01173e-16
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Kolyma_Ma912_G2_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     4.527        0.339392     0.259     0.476     0.265
#           001  1     5    10.407       0.0644965     0.553     0.447    -0.000
#           010  1     5    29.753     1.64982e-05     2.449    -0.000    -1.449  infeasible
#           100  1     5     8.148        0.148282    -0.000     0.528     0.472
#           011  2     6    63.327     9.46643e-12     1.000     0.000    -0.000
#           101  2     6    72.678     1.15293e-13     0.000     1.000    -0.000
#           110  2     6   130.840      8.5548e-26     0.000     0.000     1.000
# best pat:          000         0.339392              -  -
# best pat:          100         0.148282  chi(nested):     3.621 p-value for nested model:       0.0570554
# best pat:          011      9.46643e-12  chi(nested):    55.179 p-value for nested model:     1.10012e-13
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Kolyma_Onge_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     2.454        0.652895     0.498     0.454     0.048
#           001  1     5     4.610        0.465337     0.529     0.471    -0.000
#           010  1     5    69.686      1.1911e-13     0.951    -0.000     0.049
#           100  1     5    67.226     3.86828e-13     0.000     0.916     0.084
#           011  2     6    71.126     2.40241e-13     1.000     0.000    -0.000
#           101  2     6    70.397     3.38958e-13     0.000     1.000    -0.000
#           110  2     6   550.327               0     0.000     0.000     1.000
# best pat:          000         0.652895              -  -
# best pat:          001         0.465337  chi(nested):     2.156 p-value for nested model:        0.142037
# best pat:          101      3.38958e-13  chi(nested):    65.787 p-value for nested model:     5.02289e-16
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Kolyma_Papuan_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     6.917        0.140313     0.498     0.434     0.068
#           001  1     5    10.550       0.0610786     0.537     0.463    -0.000
#           010  1     5    67.769     2.98287e-13     0.915    -0.000     0.085
#           100  1     5    71.489     5.01934e-14     0.000     0.913     0.087
#           011  2     6    71.484     2.02823e-13     1.000     0.000    -0.000
#           101  2     6    74.227     5.53572e-14     0.000     1.000    -0.000
#           110  2     6   527.835               0     0.000     0.000     1.000
# best pat:          000         0.140313              -  -
# best pat:          001        0.0610786  chi(nested):     3.632 p-value for nested model:       0.0566751
# best pat:          011      2.02823e-13  chi(nested):    60.934 p-value for nested model:     5.90165e-15
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Kolyma_Qihe_o18+KQB.log
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     9.372       0.0524363     0.315     0.483     0.202
#           001  1     5    10.574       0.0605094     0.565     0.435     0.000
#           010  1     5    17.927      0.00303933     2.181     0.000    -1.181  infeasible
#           100  1     5    10.984       0.0516916     0.000     0.552     0.448
#           011  2     6    42.719     1.32582e-07     1.000     0.000    -0.000
#           101  2     6    59.037      7.0591e-11     0.000     1.000    -0.000
#           110  2     6   105.829     1.52061e-20     0.000     0.000     1.000
# best pat:          000        0.0524363              -  -
# best pat:          001        0.0605094  chi(nested):     1.202 p-value for nested model:        0.272979
# best pat:          011      1.32582e-07  chi(nested):    32.145 p-value for nested model:     1.43106e-08
#
# coeffs:     0.315     0.483     0.202
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Kolyma_Tianyuan_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     6.529         0.16299     0.527     0.412     0.061
#           001  1     5     8.895        0.113321     0.558     0.442    -0.000
#           010  1     5    61.934     4.83951e-12     0.876    -0.000     0.124
#           100  1     5    74.157     1.39476e-14     0.000     0.978     0.022
#           011  2     6    67.598      1.2697e-12     1.000     0.000    -0.000
#           101  2     6    74.235     5.51579e-14     0.000     1.000    -0.000
#           110  2     6   259.780               0     0.000     0.000     1.000
# best pat:          000          0.16299              -  -
# best pat:          001         0.113321  chi(nested):     2.366 p-value for nested model:        0.123973
# best pat:          011       1.2697e-12  chi(nested):    58.703 p-value for nested model:     1.83353e-14
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Kolyma_Yana_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     9.479       0.0501774     0.520     0.461     0.019
#           001  1     5     9.879       0.0787377     0.510     0.490    -0.000
#           010  1     5    49.379     1.85656e-09     0.872     0.000     0.128
#           100  1     5    51.248     7.69517e-10    -0.000     1.102    -0.102  infeasible
#           011  2     6    68.706     7.53132e-13     1.000     0.000    -0.000
#           101  2     6    57.873     1.21585e-10     0.000     1.000    -0.000
#           110  2     6   691.886               0     0.000    -0.000     1.000
# best pat:          000        0.0501774              -  -
# best pat:          001        0.0787377  chi(nested):     0.400 p-value for nested model:        0.527175
# best pat:          101      1.21585e-10  chi(nested):    47.994 p-value for nested model:     4.27507e-12
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Kostenki14_Qihe_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     8.608       0.0716804     2.049     0.103    -1.153  infeasible
#           001  1     5    59.771     1.35516e-11     0.994     0.006    -0.000
#           010  1     5    11.312       0.0455275     2.189     0.000    -1.189  infeasible
#           100  1     5   183.954               0     0.000    -0.069     1.069  infeasible
#           011  2     6    59.782     4.98431e-11     1.000    -0.000    -0.000
#           101  2     6   724.534               0     0.000     1.000    -0.000
#           110  2     6   188.952               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001      1.35516e-11  chi(nested):    51.163 p-value for nested model:     8.49919e-13
# best pat:          011      4.98431e-11  chi(nested):     0.011 p-value for nested model:         0.91794
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Ma912_G2_Onge_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     8.549       0.0734131     3.573    -3.425     0.852  infeasible
#           001  1     5    25.299     0.000121977     2.778    -1.778    -0.000  infeasible
#           010  1     5    82.246     2.84297e-16     1.084    -0.000    -0.084  infeasible
#           100  1     5    87.071     2.76922e-17     0.000     1.639    -0.639  infeasible
#           011  2     6    86.256     1.81293e-16     1.000    -0.000    -0.000
#           101  2     6   167.101               0     0.000     1.000    -0.000
#           110  2     6   733.129               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):    16.750 p-value for nested model:     4.26435e-05
# best pat:          011      1.81293e-16  chi(nested):    60.957 p-value for nested model:     5.83378e-15
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Ma912_G2_Tianyuan_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     6.523        0.163347     2.368    -1.907     0.540  infeasible
#           001  1     5    20.514      0.00100032     2.347    -1.347    -0.000  infeasible
#           010  1     5    74.446     1.21394e-14     1.087    -0.000    -0.087  infeasible
#           100  1     5    91.999     2.55418e-18    -0.000     1.984    -0.984  infeasible
#           011  2     6    76.959     1.51565e-14     1.000    -0.000    -0.000
#           101  2     6   175.708               0     0.000     1.000    -0.000
#           110  2     6   346.709               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):    13.991 p-value for nested model:     0.000183663
# best pat:          011      1.51565e-14  chi(nested):    56.445 p-value for nested model:     5.78064e-14
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Onge_Papuan_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     2.442        0.654998    -1.396    18.913   -16.517  infeasible
#           001  1     5    96.774     2.52666e-19     1.100    -0.100    -0.000  infeasible
#           010  1     5    97.799     1.53775e-19     1.072    -0.000    -0.072  infeasible
#           100  1     5     3.090        0.686096     0.000     8.628    -7.628  infeasible
#           011  2     6    99.306     3.50164e-19     1.000    -0.000    -0.000
#           101  2     6   387.423               0     0.000     1.000    -0.000
#           110  2     6   519.347               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):    94.332 p-value for nested model:     2.66781e-22
# best pat:          011      3.50164e-19  chi(nested):     2.532 p-value for nested model:        0.111572
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Bbdong_Qihe_Tianyuan_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     3.960        0.411389     2.025    -1.285     0.260  infeasible
#           001  1     5     7.639        0.177289     2.018    -1.018    -0.000  infeasible
#           010  1     5    42.366     4.96613e-08     1.184    -0.000    -0.184  infeasible
#           100  1     5   102.537      1.5419e-20     0.000     2.289    -1.289  infeasible
#           011  2     6    52.165     1.72798e-09     1.000    -0.000    -0.000
#           101  2     6   193.118               0     0.000     1.000    -0.000
#           110  2     6   321.886               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     3.679 p-value for nested model:       0.0551175
# best pat:          011      1.72798e-09  chi(nested):    44.526 p-value for nested model:     2.51049e-11
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Clovis_Kolyma_Kostenki14_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     0.803        0.938025     3.339    -1.747    -0.592  infeasible
#           001  1     5     3.272        0.658146    -3.901     4.901    -0.000  infeasible
#           010  1     5     3.867        0.568728     1.410     0.000    -0.410  infeasible
#           100  1     5     9.162        0.102775     0.000     1.289    -0.289  infeasible
#           011  2     6   113.714     3.39705e-22     1.000    -0.000    -0.000
#           101  2     6    74.660     4.50871e-14     0.000     1.000    -0.000
#           110  2     6   844.793               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     2.469 p-value for nested model:         0.11613
# best pat:          101      4.50871e-14  chi(nested):    71.388 p-value for nested model:      2.9338e-17
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Clovis_Kolyma_Ma912_G2_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     0.814        0.936518    -4.743     5.912    -0.170  infeasible
#           001  1     5     0.865        0.972704    -4.067     5.067    -0.000  infeasible
#           010  1     5    75.265     8.19071e-15     0.176    -0.000     0.824
#           100  1     5    69.206     1.49887e-13     0.000     0.393     0.607
#           011  2     6   124.506     1.84146e-24     1.000    -0.000    -0.000
#           101  2     6    80.314     3.07759e-15     0.000     1.000    -0.000
#           110  2     6    77.662     1.08523e-14     0.000     0.000     1.000
# best pat:          000                0              -  -
# best pat:          100      1.49887e-13  chi(nested):    68.392 p-value for nested model:      1.3402e-16
# best pat:          110      1.08523e-14  chi(nested):     8.456 p-value for nested model:      0.00363832
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Clovis_Kolyma_Onge_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     3.013         0.55562    -3.921     4.907     0.014  infeasible
#           001  1     5     3.018        0.697161    -3.876     4.876    -0.000  infeasible
#           010  1     5    70.324     8.77613e-14     1.622     0.000    -0.622  infeasible
#           100  1     5    48.280     3.11366e-09     0.000     1.365    -0.365  infeasible
#           011  2     6   128.245     3.00973e-25     1.000    -0.000    -0.000
#           101  2     6    79.329     4.91498e-15     0.000     1.000    -0.000
#           110  2     6   590.998               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     0.005 p-value for nested model:        0.942905
# best pat:          101      4.91498e-15  chi(nested):    76.311 p-value for nested model:      2.4233e-18
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Clovis_Kolyma_Papuan_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     2.685        0.611916    -3.302     4.497    -0.194  infeasible
#           001  1     5     3.057        0.691183    -3.798     4.798    -0.000  infeasible
#           010  1     5    70.398     8.47003e-14     1.620     0.000    -0.620  infeasible
#           100  1     5    40.219     1.34872e-07     0.000     1.455    -0.455  infeasible
#           011  2     6   129.888     1.35683e-25     1.000    -0.000    -0.000
#           101  2     6    80.634     2.64234e-15     0.000     1.000    -0.000
#           110  2     6   680.966               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     0.373 p-value for nested model:        0.541634
# best pat:          101      2.64234e-15  chi(nested):    77.577 p-value for nested model:     1.27641e-18
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Clovis_Kolyma_Qihe_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     1.637        0.802181  -117.470   152.365   -33.895  infeasible
#           001  1     5     2.978        0.703352    -3.447     4.447    -0.000  infeasible
#           010  1     5    42.185     5.40498e-08     0.115     0.000     0.885
#           100  1     5    43.914     2.41105e-08     0.000     0.013     0.987
#           011  2     6   119.561      2.0152e-23     1.000     0.000    -0.000
#           101  2     6    74.871     4.08119e-14     0.000     1.000    -0.000
#           110  2     6    43.916     7.68016e-08     0.000     0.000     1.000
# best pat:          000                0              -  -
# best pat:          010      5.40498e-08  chi(nested):    40.548 p-value for nested model:     1.91859e-10
# best pat:          110      7.68016e-08  chi(nested):     1.732 p-value for nested model:        0.188192
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Clovis_Kolyma_Tianyuan_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     3.103        0.540711    -4.049     4.878     0.171  infeasible
#           001  1     5     3.198        0.669453    -3.699     4.699    -0.000  infeasible
#           010  1     5    32.648     4.42012e-06     2.702     0.000    -1.702  infeasible
#           100  1     5    28.942     2.38048e-05     0.000     1.867    -0.867  infeasible
#           011  2     6   131.613     5.87874e-26     1.000    -0.000    -0.000
#           101  2     6    80.199     3.25078e-15     0.000     1.000    -0.000
#           110  2     6   259.268               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     0.095 p-value for nested model:        0.757825
# best pat:          101      3.25078e-15  chi(nested):    77.000 p-value for nested model:     1.70925e-18
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Clovis_Kolyma_Yana_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     1.585        0.811522     3.096    -1.545    -0.551  infeasible
#           001  1     5     3.356        0.645308    -4.153     5.153     0.000  infeasible
#           010  1     5     3.489        0.624989     1.405     0.000    -0.405  infeasible
#           100  1     5     7.850        0.164725     0.000     1.286    -0.286  infeasible
#           011  2     6    79.585     4.35149e-15     1.000    -0.000    -0.000
#           101  2     6    55.808     3.18296e-10     0.000     1.000    -0.000
#           110  2     6   885.532               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     1.771 p-value for nested model:        0.183256
# best pat:          101      3.18296e-10  chi(nested):    52.452 p-value for nested model:      4.4083e-13
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Clovis_Onge_Papuan_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     2.320        0.677119     0.099     7.874    -6.972  infeasible
#           001  1     5   102.233     1.78767e-20     1.571    -0.571     0.000  infeasible
#           010  1     5   103.410     1.00916e-20     1.457    -0.000    -0.457  infeasible
#           100  1     5     2.411        0.789802     0.000     8.501    -7.501  infeasible
#           011  2     6   142.074     3.65685e-28     1.000    -0.000    -0.000
#           101  2     6   497.454               0     0.000     1.000    -0.000
#           110  2     6   678.121               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):    99.913 p-value for nested model:     1.59251e-23
# best pat:          011      3.65685e-28  chi(nested):    39.841 p-value for nested model:     2.75437e-10
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Kolyma_Onge_Papuan_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     2.679        0.612952     0.361     6.885    -6.245  infeasible
#           001  1     5    97.756     1.56971e-19     1.339    -0.339    -0.000  infeasible
#           010  1     5    93.275     1.37729e-18     1.322    -0.000    -0.322  infeasible
#           100  1     5     3.100        0.684568     0.000     9.487    -8.487  infeasible
#           011  2     6   113.073     4.62924e-22     1.000    -0.000    -0.000
#           101  2     6   421.245               0     0.000     1.000    -0.000
#           110  2     6   637.946               0     0.000     0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):    95.077 p-value for nested model:     1.83079e-22
# best pat:          011      4.62924e-22  chi(nested):    15.317 p-value for nested model:     9.09039e-05
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Kostenki14_Ma912_G2_Yana_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     3.547        0.470826    -3.200     0.971     3.230  infeasible
#           001  1     5    96.495      2.8927e-19    -0.763     1.763     0.000  infeasible
#           010  1     5    10.828        0.054901    -7.753     0.000     8.753  infeasible
#           100  1     5   137.122     7.31789e-28     0.000     1.557    -0.557  infeasible
#           011  2     6   455.866               0     1.000    -0.000    -0.000
#           101  2     6   191.197               0     0.000     1.000    -0.000
#           110  2     6   516.081               0     0.000     0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):    92.949 p-value for nested model:     5.36658e-22
# best pat:          101      1.41609e-38  chi(nested):    94.701 p-value for nested model:     2.21377e-22
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Kostenki14_Onge_Papuan_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     2.666        0.615225     0.166    10.974   -10.140  infeasible
#           001  1     5   137.200     7.04187e-28    -0.747     1.747     0.000  infeasible
#           010  1     5   182.405               0    -1.123     0.000     2.123  infeasible
#           100  1     5     2.793        0.731876     0.000     9.950    -8.950  infeasible
#           011  2     6   907.875               0     1.000    -0.000    -0.000
#           101  2     6   467.463               0     0.000     1.000    -0.000
#           110  2     6   652.407               0     0.000     0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):   134.534 p-value for nested model:     4.17431e-31
# best pat:          101      8.54574e-98  chi(nested):   330.263 p-value for nested model:     8.42282e-74
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Kostenki14_Onge_Tianyuan_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     6.786        0.147657    -0.819    -2.801     4.621  infeasible
#           001  1     5   354.912               0    -1.513     2.513    -0.000  infeasible
#           010  1     5    83.077     1.90363e-16    -1.028    -0.000     2.028  infeasible
#           100  1     5    21.725     0.000590581     0.000    -4.778     5.778  infeasible
#           011  2     6   970.726               0     1.000    -0.000    -0.000
#           101  2     6   872.870               0     0.000     1.000    -0.000
#           110  2     6   390.931               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):   348.127 p-value for nested model:     1.08409e-77
# best pat:          110      2.48902e-81  chi(nested):    36.018 p-value for nested model:     1.95476e-09
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Kostenki14_Papuan_Tianyuan_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     7.935        0.093989    -0.628    -1.639     3.267  infeasible
#           001  1     5   350.802               0    -1.713     2.713    -0.000  infeasible
#           010  1     5    58.997     1.95876e-11    -0.911    -0.000     1.911  infeasible
#           100  1     5    25.908      9.2989e-05    -0.000    -2.694     3.694  infeasible
#           011  2     6   943.963               0     1.000    -0.000    -0.000
#           101  2     6   816.091               0     0.000     1.000    -0.000
#           110  2     6   319.467               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):   342.867 p-value for nested model:     1.51503e-76
# best pat:          110      5.49266e-66  chi(nested):   -31.335 p-value for nested model:            -nan
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Kostenki14_Qihe_Yana_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     6.823         0.14557    -5.377     0.113     6.264  infeasible
#           001  1     5   154.681               0    -0.319     1.319     0.000  infeasible
#           010  1     5     6.874        0.230159    -5.879     0.000     6.879  infeasible
#           100  1     5   161.030               0     0.000     1.354    -0.354  infeasible
#           011  2     6   473.709               0     1.000    -0.000    -0.000
#           101  2     6   189.674               0     0.000     1.000    -0.000
#           110  2     6   507.940               0     0.000     0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):   147.858 p-value for nested model:     5.09464e-34
# best pat:          101      2.98401e-38  chi(nested):    34.994 p-value for nested model:     3.30778e-09
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Kostenki14_Tianyuan_Yana_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     5.864        0.209532    -4.928     0.944     4.984  infeasible
#           001  1     5    33.777     2.63665e-06    -4.330     5.330     0.000  infeasible
#           010  1     5     7.272        0.201212    -5.305    -0.000     6.305  infeasible
#           100  1     5    45.073     1.40201e-08     0.000    13.160   -12.160  infeasible
#           011  2     6   452.511               0     1.000    -0.000    -0.000
#           101  2     6   333.686               0     0.000     1.000    -0.000
#           110  2     6   483.989               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):    27.913 p-value for nested model:      1.2687e-07
# best pat:          101      4.89515e-69  chi(nested):   299.909 p-value for nested model:     3.44876e-67
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Ma912_G2_Onge_Papuan_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     1.018        0.907124    -1.008    15.231   -13.223  infeasible
#           001  1     5    86.188     4.24212e-17     1.405    -0.405    -0.000  infeasible
#           010  1     5    88.974     1.10369e-17     1.313    -0.000    -0.313  infeasible
#           100  1     5     1.521        0.910679    -0.000     8.873    -7.873  infeasible
#           011  2     6   118.729     3.01232e-23     1.000    -0.000    -0.000
#           101  2     6   525.799               0     0.000     1.000    -0.000
#           110  2     6   727.458               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):    85.170 p-value for nested model:     2.73757e-20
# best pat:          011      3.01232e-23  chi(nested):    32.542 p-value for nested model:     1.16667e-08
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Onge_Papuan_Qihe_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     2.135        0.711014    18.929   -16.354    -1.576  infeasible
#           001  1     5     3.048        0.692562     9.240    -8.240    -0.000  infeasible
#           010  1     5   109.822     4.46733e-22    -0.600    -0.000     1.600  infeasible
#           100  1     5   117.279     1.18251e-23    -0.000    -0.458     1.458  infeasible
#           011  2     6   531.003               0     1.000    -0.000    -0.000
#           101  2     6   749.063               0     0.000     1.000    -0.000
#           110  2     6   165.377               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     0.914 p-value for nested model:        0.339181
# best pat:          110      4.29821e-33  chi(nested):   162.328 p-value for nested model:     3.50696e-37
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Onge_Papuan_Tianyuan_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     2.103        0.716853     9.000    -8.801     0.801  infeasible
#           001  1     5     2.315         0.80412    10.417    -9.417    -0.000  infeasible
#           010  1     5    14.230       0.0142118   -15.486    -0.000    16.486  infeasible
#           100  1     5    13.879       0.0163987     0.000    -5.057     6.057  infeasible
#           011  2     6   463.365               0     1.000    -0.000    -0.000
#           101  2     6   600.347               0     0.000     1.000    -0.000
#           110  2     6   273.271               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     0.212 p-value for nested model:        0.645381
# best pat:          110      4.32881e-56  chi(nested):   270.957 p-value for nested model:     7.02142e-61
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Onge_Papuan_Yana_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     2.074        0.722156    10.059    -9.569     0.510  infeasible
#           001  1     5     2.907        0.714324     8.520    -7.520    -0.000  infeasible
#           010  1     5   123.992     4.47627e-25     2.043     0.000    -1.043  infeasible
#           100  1     5   167.521               0    -0.000     2.884    -1.884  infeasible
#           011  2     6   438.979               0     1.000    -0.000    -0.000
#           101  2     6   641.477               0     0.000     1.000    -0.000
#           110  2     6   940.961               0     0.000    -0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     0.833 p-value for nested model:        0.361404
# best pat:          011      1.15542e-91  chi(nested):   436.072 p-value for nested model:     7.76941e-97
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Onge_Tianyuan_Yana_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     5.129        0.274285    -3.053     4.415    -0.362  infeasible
#           001  1     5     7.699        0.173652    -3.402     4.402     0.000  infeasible
#           010  1     5   379.110               0     3.898    -0.000    -2.898  infeasible
#           100  1     5   124.314     3.82535e-25     0.000     2.015    -1.015  infeasible
#           011  2     6   842.561               0     1.000    -0.000    -0.000
#           101  2     6   325.781               0     0.000     1.000    -0.000
#           110  2     6   975.238               0     0.000     0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     2.569 p-value for nested model:        0.108962
# best pat:          101      2.42964e-67  chi(nested):   318.083 p-value for nested model:     3.78857e-71
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.B1_TS_Shamanka_EN_Papuan_Tianyuan_Yana_o18+KQB.log
#
#     fixed pat  wt  dof     chisq       tail prob
#           000  0     4     4.971        0.290264    -1.744     2.992    -0.248  infeasible
#           001  1     5     7.535        0.183807    -1.945     2.945     0.000  infeasible
#           010  1     5   357.436               0     4.066     0.000    -3.066  infeasible
#           100  1     5    84.847     8.10531e-17     0.000     1.824    -0.824  infeasible
#           011  2     6   839.183               0     1.000    -0.000    -0.000
#           101  2     6   248.203               0     0.000     1.000    -0.000
#           110  2     6   953.668               0     0.000     0.000     1.000
# best pat:          000                0              -  -
# best pat:          001                0  chi(nested):     2.564 p-value for nested model:        0.109351
# best pat:          101      9.92797e-51  chi(nested):   240.669 p-value for nested model:      2.8115e-54

# %% [markdown]
# ## PDEAS

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"
# name="A1" #
# name="PDEASB1"
# target="Shamanka_EN"
# suffix="_SS"
# out="o18+KQB"
# ancset1="Hejiatai Shamanka_EN LiangDao Man_Bac Suogang Boshan XJS_F Xiaogao Ma912_G2 Vt833_G2 Vt880_G2"
# ancset2="Hejiatai Shamanka_EN Qihe Man_Bac Suogang Boshan XJS_F Xiaogao Ma912_G2 Vt833_G2 Vt880_G2"
# ancset9="Samdzong Mebrak ZongriM297 Hejiatai Shamanka_EN Qihe Man_Bac Suogang Boshan XJS_F Xiaogao LG2 Vt833_G2 Vt880_G2"
# ancset10="Samdzong Mebrak ZongriM297 Hejiatai Shamanka_EN Qihe Man_Bac Suogang Boshan XJS_F Xiaogao Ma912_G2 Vt833_G2 Vt880_G2"
# pdeas="Ulchi Oroqen Xibo Uygur Sherpa_ShigatseX Tibetan_ShigatseX Tibetan_LhasaX Tibetan_NagquX Tibetan Sherpa Han_HenanX Han_GansuX Han_XinjiangX Han_HenanX Han_ShandongX Han_JiangsuX Han_AnhuiX Han_SichuanX Han_HubeiX Han_GuangdongX Han_ChongqingX Kinh"
# #for target in Nui_Nap Ban_Chiang Oakaie1 Samdzong Mebrak ZongriM297 Hejiatai Shamanka_EN Qihe Man_Bac Suogang Boshan XJS_F Xiaogao LG2 Vt833_G2 Vt880_G2; do
# #for target in Han Ami Dai Atayal Lahu Daur Hezhen Tibetan_ShannanX Tibetan_ChamdoX Miao She Korean Japanese Tujia Naxi Yi; do
# for target in Ulchi Oroqen Xibo Uygur Sherpa_ShigatseX Tibetan_ShigatseX Tibetan_LhasaX Tibetan_NagquX Tibetan Sherpa Han_HenanX Han_GansuX Han_XinjiangX Han_HenanX Han_ShandongX Han_JiangsuX Han_AnhuiX Han_SichuanX Han_HubeiX Han_GuangdongX Han_ChongqingX Kinh; do
#     grep "f4rank: 0" ${pd}${name}/UPA19_3.adm.${name}${suffix}_${target}_*_${out}.log | awk '{ if ($8>0.05) print $1,$8}' | cut -d'/' -f9 | cut -d':' -f1,3
#     done
# Out:
# UPA19_3.adm.PDEASB1_SS_Tibetan_ShigatseX_Natufian_o18+KQB.log: 3.46089828e-316
# UPA19_3.adm.PDEASB1_SS_Tibetan_ShigatseX_Okunevo_EMBA_o18+KQB.log: 6.26877092e-311
# UPA19_3.adm.PDEASB1_SS_Tibetan_ShannanX_IndusPeriphery_o18+KQB.log: 1.18526348e-319
# UPA19_3.adm.PDEASB1_SS_Tibetan_ShigatseX_Natufian_o18+KQB.log: 3.46089828e-316
# UPA19_3.adm.PDEASB1_SS_Tibetan_ShigatseX_Okunevo_EMBA_o18+KQB.log: 6.26877092e-311
# grep: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/PDEASB1/UPA19_3.adm.PDEASB1_SS_Han_GansuX_*_o18+KQB.log: No such file or directory
# grep: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/PDEASB1/UPA19_3.adm.PDEASB1_SS_Han_XinjiangX_*_o18+KQB.log: No such file or directory
# grep: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/PDEASB1/UPA19_3.adm.PDEASB1_SS_Han_ShandongX_*_o18+KQB.log: No such file or directory
# grep: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/PDEASB1/UPA19_3.adm.PDEASB1_SS_Han_JiangsuX_*_o18+KQB.log: No such file or directory
# grep: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/PDEASB1/UPA19_3.adm.PDEASB1_SS_Han_AnhuiX_*_o18+KQB.log: No such file or directory
# grep: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/PDEASB1/UPA19_3.adm.PDEASB1_SS_Han_SichuanX_*_o18+KQB.log: No such file or directory
# grep: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/PDEASB1/UPA19_3.adm.PDEASB1_SS_Han_HubeiX_*_o18+KQB.log: No such file or directory
# grep: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/PDEASB1/UPA19_3.adm.PDEASB1_SS_Han_GuangdongX_*_o18+KQB.log: No such file or directory
# grep: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/PDEASB1/UPA19_3.adm.PDEASB1_SS_Han_ChongqingX_*_o18+KQB.log: No such file or directory
# grep: /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/PDEASB1/UPA19_3.adm.PDEASB1_SS_Kinh_*_o18+KQB.log: No such file or directory

# %% [markdown]
# ## Qihe as source

# %%
south=["Suogang","Qihe","LiangDaoF","LiangDaoM","Ma555_G6"]
north=["JomonM","ZongriM297","Hejiatai","PukagongmaM5","Chokhopani",
       "Kolyma_River","Shamanka_EN","HDYM1",
       "DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao","XJS","XJS_F" ]        
central=["Longlin","Baojianshan","Dushan",
         "ZhaoguoM2","Daxi","Dashuitian",
         "DonghulinM1","Jiahu_M52_I2","Tianluoshan","Liangzhu_T4620"]
seas=["Ma912_G2","La727_G2","Vt880_G2","Vt833_G2","Man_Bac","Nui_Nap",
      "Vt719_G3_1","Vt777_G3","Th521_G4","Oakaie1"]
pdeas=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean","Han","Tujia","She","Miao",
      "Naxi","Yi","Dai","Kinh","Lahu","Ami","Atayal"]

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/early_CN/qpadm_south/"

outgroups=["UstIshim","Mbuti","Ju_hoan_North","Papuan","Kostenki14","Onge","Tianyuan","Malta1","Natufian",
          "Kolyma_River","Yana_old","Yana_old2","Shamanka_EN","La368_G1"]
fh="UPA19_3"
ff.mklst(pD,fh,"out0",outgroups)
# Out:
# 'Made /mnt/solexa/mel_yang/early_CN/qpadm_south/UPA19_3.out0 file'

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/early_CN/qpadm_south/"

outgroups=["UstIshim","Mbuti","Ju_hoan_North","Papuan","Kostenki14","Onge","Tianyuan","Malta1","Natufian",
          "Kolyma_River","Yana_old","Yana_old2","JomonM","La368_G1"]
fh="UPA19_3"
ff.mklst(pD,fh,"out1",outgroups)
# Out:
# 'Made /mnt/solexa/mel_yang/early_CN/qpadm_south/UPA19_3.out1 file'

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/early_CN/qpadm_south/"

outgroups=["UstIshim","Ju_hoan_North","Papuan","Kostenki14","Onge","Tianyuan","Natufian",
          "Kolyma_River","Yana_old","Yana_old2","JomonM","La368_G1","Shamanka_EN","Mixe","Surui"]
fh="UPA19_3"
ff.mklst(pD,fh,"out2",outgroups)
# Out:
# 'Made /mnt/solexa/mel_yang/early_CN/qpadm_south/UPA19_3.out2 file'

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/qpadm_south/"
fh="UPA19_3"
name="A"
pt="adm"
label="S_CS"
out="out2"
south=["Suogang","Qihe","Qihe_d","LiangDaoF","LiangDaoM","Ma555_G6"]
north=["JomonM","ZongriM297","Hejiatai","PukagongmaM5","Chokhopani",
       "Kolyma_River","Shamanka_EN","HDYM1",
       "DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao","XJS","XJS_F" ]        
central=["Longlin","Baojianshan","Dushan",
         "ZhaoguoM2","Daxi","Dashuitian",
         "DonghulinM1","Jiahu_M52_I2","Tianluoshan","Liangzhu_T4620"]
seas=["Ma912_G2","La727_G2","Vt880_G2","Vt833_G2","Man_Bac","Nui_Nap",
      "Vt719_G3_1","Vt777_G3","Th521_G4","Oakaie1"]
pdeas=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean","Han","Tujia","She","Miao",
      "Naxi","Yi","Dai","Kinh","Lahu","Ami","Atayal"]

targets=south+pdeas
s1s=south+pdeas
s2s=["Han","Bbdong","HDYM1","ZongriM297","Dashuitian","DonghulinM1","Boshan"]
s2s=["Han"] #,"HDYM1"]
targets=south+["Ami","Atayal"]
s1s=south+["Ami","Atayal"]
s1s=["Ami"]
s1s=["Qihe"]
for s2 in s2s:
    for target in targets:
        for s1 in s1s: 
            if s1 == target: continue
            label="%s_%s_%s_%s_%s" % (name,target,s1,s2,out)
            ff.parfile(pD,fh,pt,label,outpd=outpd,outgroup=fh+"."+out)
            ff.mklst(outpd,fh,pt+"."+label,[target,s1,s2],suffix="leftpop")
        if s1==target: continue
        mytuple=(fh,pt,"%s_%s_%s_%s_%s" % (name,target,"${i}",s2,out))
        print "for i in %s; do " % " ".join(s1s)+"qpAdm -p {0}.{1}.{2}.par > {0}.{1}.{2}.log; done &".format(*mytuple)
# Out:
# for i in Qihe; do qpAdm -p UPA19_3.adm.A_Suogang_${i}_Han_out2.par > UPA19_3.adm.A_Suogang_${i}_Han_out2.log; done &
# for i in Qihe; do qpAdm -p UPA19_3.adm.A_Qihe_d_${i}_Han_out2.par > UPA19_3.adm.A_Qihe_d_${i}_Han_out2.log; done &
# for i in Qihe; do qpAdm -p UPA19_3.adm.A_LiangDaoF_${i}_Han_out2.par > UPA19_3.adm.A_LiangDaoF_${i}_Han_out2.log; done &
# for i in Qihe; do qpAdm -p UPA19_3.adm.A_LiangDaoM_${i}_Han_out2.par > UPA19_3.adm.A_LiangDaoM_${i}_Han_out2.log; done &
# for i in Qihe; do qpAdm -p UPA19_3.adm.A_Ma555_G6_${i}_Han_out2.par > UPA19_3.adm.A_Ma555_G6_${i}_Han_out2.log; done &
# for i in Qihe; do qpAdm -p UPA19_3.adm.A_Ami_${i}_Han_out2.par > UPA19_3.adm.A_Ami_${i}_Han_out2.log; done &
# for i in Qihe; do qpAdm -p UPA19_3.adm.A_Atayal_${i}_Han_out2.par > UPA19_3.adm.A_Atayal_${i}_Han_out2.log; done &

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/qpadm_south/"
fh="UPA19_3"
name="B"
pt="adm"
out="out1"
south=["Suogang","Qihe","Qihe_d","LiangDaoF","LiangDaoM","Ma555_G6"]
north=["JomonM","ZongriM297","Hejiatai","PukagongmaM5","Chokhopani",
       "Kolyma_River","Shamanka_EN","HDYM1",
       "DevilsGate","Boisman_MN","Bbdong","Boshan","Xiaogao","XJS","XJS_F" ]        
central=["Longlin","Baojianshan","Dushan",
         "ZhaoguoM2","Daxi","Dashuitian",
         "DonghulinM1","Jiahu_M52_I2","Tianluoshan","Liangzhu_T4620"]
seas=["Ma912_G2","La727_G2","Vt880_G2","Vt833_G2","Man_Bac","Nui_Nap",
      "Vt719_G3_1","Vt777_G3","Th521_G4","Oakaie1"]
pdeas=["Oroqen","Daur","Hezhen","Xibo","Japanese","Korean","Han","Tujia","She","Miao",
      "Naxi","Yi","Dai","Kinh","Lahu","Ami","Atayal"]

targets=south+pdeas
s1s=south+pdeas
s2s=["Han","Bbdong","HDYM1","ZongriM297","Dashuitian","DonghulinM1","Boshan"]
s2s=["Han"]
targets=south+["Ami","Atayal","Dai","Xinyi","Tianluoshan","Liangzhu_T4620","DonghulinM1","Dushan","Bbdong","Boshan"]
s1s=south+["Ami","Atayal"]
for s2 in s2s:
    for target in targets:
        for s1 in s1s: 
            if s1 == target: continue
            label="%s_%s_%s_%s_%s" % (name,target,s1,s2,out)
            ff.parfile(pD,fh,pt,label,outpd=outpd,outgroup=fh+"."+out)
            ff.mklst(outpd,fh,pt+"."+label,[target,s1,s2],suffix="leftpop")
        if s1 == target: continue
        if s2==target: continue
        mytuple=(fh,pt,"%s_%s_%s_%s_%s" % (name,target,"${i}",s2,out))
        print "for i in %s; do " % " ".join(s1s)+"qpAdm -p {0}.{1}.{2}.par > {0}.{1}.{2}.log; done &".format(*mytuple)
# Out:
# for i in Suogang Qihe Qihe_d LiangDaoF LiangDaoM Ma555_G6 Ami Atayal; do qpAdm -p UPA19_3.adm.B_Suogang_${i}_Han_out1.par > UPA19_3.adm.B_Suogang_${i}_Han_out1.log; done &
# for i in Suogang Qihe Qihe_d LiangDaoF LiangDaoM Ma555_G6 Ami Atayal; do qpAdm -p UPA19_3.adm.B_Qihe_${i}_Han_out1.par > UPA19_3.adm.B_Qihe_${i}_Han_out1.log; done &
# for i in Suogang Qihe Qihe_d LiangDaoF LiangDaoM Ma555_G6 Ami Atayal; do qpAdm -p UPA19_3.adm.B_Qihe_d_${i}_Han_out1.par > UPA19_3.adm.B_Qihe_d_${i}_Han_out1.log; done &
# for i in Suogang Qihe Qihe_d LiangDaoF LiangDaoM Ma555_G6 Ami Atayal; do qpAdm -p UPA19_3.adm.B_LiangDaoF_${i}_Han_out1.par > UPA19_3.adm.B_LiangDaoF_${i}_Han_out1.log; done &
# for i in Suogang Qihe Qihe_d LiangDaoF LiangDaoM Ma555_G6 Ami Atayal; do qpAdm -p UPA19_3.adm.B_LiangDaoM_${i}_Han_out1.par > UPA19_3.adm.B_LiangDaoM_${i}_Han_out1.log; done &
# for i in Suogang Qihe Qihe_d LiangDaoF LiangDaoM Ma555_G6 Ami Atayal; do qpAdm -p UPA19_3.adm.B_Ma555_G6_${i}_Han_out1.par > UPA19_3.adm.B_Ma555_G6_${i}_Han_out1.log; done &
# for i in Suogang Qihe Qihe_d LiangDaoF LiangDaoM Ma555_G6 Ami Atayal; do qpAdm -p UPA19_3.adm.B_Ami_${i}_Han_out1.par > UPA19_3.adm.B_Ami_${i}_Han_out1.log; done &
# for i in Suogang Qihe Qihe_d LiangDaoF LiangDaoM Ma555_G6 Ami Atayal; do qpAdm -p UPA19_3.adm.B_Dai_${i}_Han_out1.par > UPA19_3.adm.B_Dai_${i}_Han_out1.log; done &
# for i in Suogang Qihe Qihe_d LiangDaoF LiangDaoM Ma555_G6 Ami Atayal; do qpAdm -p UPA19_3.adm.B_Xinyi_${i}_Han_out1.par > UPA19_3.adm.B_Xinyi_${i}_Han_out1.log; done &
# for i in Suogang Qihe Qihe_d LiangDaoF LiangDaoM Ma555_G6 Ami Atayal; do qpAdm -p UPA19_3.adm.B_Tianluoshan_${i}_Han_out1.par > UPA19_3.adm.B_Tianluoshan_${i}_Han_out1.log; done &
# for i in Suogang Qihe Qihe_d LiangDaoF LiangDaoM Ma555_G6 Ami Atayal; do qpAdm -p UPA19_3.adm.B_Liangzhu_T4620_${i}_Han_out1.par > UPA19_3.adm.B_Liangzhu_T4620_${i}_Han_out1.log; done &
# for i in Suogang Qihe Qihe_d LiangDaoF LiangDaoM Ma555_G6 Ami Atayal; do qpAdm -p UPA19_3.adm.B_DonghulinM1_${i}_Han_out1.par > UPA19_3.adm.B_DonghulinM1_${i}_Han_out1.log; done &
# for i in Suogang Qihe Qihe_d LiangDaoF LiangDaoM Ma555_G6 Ami Atayal; do qpAdm -p UPA19_3.adm.B_Dushan_${i}_Han_out1.par > UPA19_3.adm.B_Dushan_${i}_Han_out1.log; done &
# for i in Suogang Qihe Qihe_d LiangDaoF LiangDaoM Ma555_G6 Ami Atayal; do qpAdm -p UPA19_3.adm.B_Bbdong_${i}_Han_out1.par > UPA19_3.adm.B_Bbdong_${i}_Han_out1.log; done &
# for i in Suogang Qihe Qihe_d LiangDaoF LiangDaoM Ma555_G6 Ami Atayal; do qpAdm -p UPA19_3.adm.B_Boshan_${i}_Han_out1.par > UPA19_3.adm.B_Boshan_${i}_Han_out1.log; done &

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/qpadm_south/"
# fh="UPA19_3"
# out="out2"
# numsource=2
# #for i in Han Korean Bbdong Boshan Boisman_MN Ami Dai; do
# for i in Qihe Qihe_d LiangDaoF LiangDaoM Suogang Ma555_G6 Ami Atayal Xinyi Bbdong Dai DonghulinM1 Boshan Liangzhu_T4620 Dushan; do
#     label="adm.B_${i}_LiangDaoF_Dashuitian_${out}"
#
#     numlines=$(wc -l ${pd}${fh}.${label}.log | cut -d" " -f1)
#
#     popind=$(cat ${pd}${fh}.${label}.log | grep -n "left pops:" | cut -d":" -f1)
#     diff1=`expr ${numlines} - ${popind} + 1`
#     tail -n ${diff1} ${pd}${fh}.${label}.log | head -n `expr ${numsource} + 3`
#
#     myind=$(cat ${pd}${fh}.${label}.log | grep -n "std. errors:" | cut -d":" -f1)
#     diff2=`expr ${numlines} - ${myind} + 2`
#     tail -n ${diff2} ${pd}${fh}.${label}.log | head -n2
#
#     tabind1=$(cat ${pd}${fh}.${label}.log | grep -n "summ:" | cut -d":" -f1)
#     tabind2=$(cat ${pd}${fh}.${label}.log | grep -n "coeffs:" | cut -d":" -f1)
#
#     diff3=`expr ${numlines} - ${tabind1}`
#     diff4=`expr ${tabind2} - ${tabind1} - 2`
#     tail -n ${diff3} ${pd}${fh}.${label}.log | head -n ${diff4}
# done
# Out:
# left pops:
# Qihe
# LiangDaoF
# Dashuitian
#
# Jackknife mean:      0.964378129     0.035621871
#       std. errors:     0.254     0.254
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    13     7.989        0.844292     1.013    -0.013  infeasible
#            01  1    14     7.948        0.892035     1.000     0.000
#            10  1    14    34.768      0.00159052     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01         0.892035  chi(nested):    -0.042 p-value for nested model:            -nan
# left pops:
# Qihe_d
# LiangDaoF
# Dashuitian
#
# Jackknife mean:    -17.573959127    18.573959127
#       std. errors:     9.821     9.821
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    13    14.125        0.365123     4.113    -3.113  infeasible
#            01  1    14    19.971         0.13107     1.000     0.000
#            10  1    14    29.878      0.00793328     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01          0.13107  chi(nested):     5.846 p-value for nested model:       0.0156127
# qpAdm: parameter file: UPA19_3.adm.B_LiangDaoF_LiangDaoF_Dashuitian_out2.par
# left pops:
# LiangDaoM
# LiangDaoF
# Dashuitian
#
# Jackknife mean:      1.142656236    -0.142656236
#       std. errors:     0.465     0.465
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    13    14.435        0.343965     1.277    -0.277  infeasible
#            01  1    14    15.302        0.357852     1.000     0.000
#            10  1    14    44.542     4.83883e-05     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01         0.357852  chi(nested):     0.867 p-value for nested model:        0.351779
# left pops:
# Suogang
# LiangDaoF
# Dashuitian
#
# Jackknife mean:      0.316158755     0.683841245
#       std. errors:     0.333     0.333
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    13     8.104        0.836744     0.281     0.719
#            01  1    14    15.364        0.353715     1.000     0.000
#            10  1    14     9.309         0.81075     0.000     1.000
# best pat:           00         0.836744              -  -
# best pat:           10          0.81075  chi(nested):     1.205 p-value for nested model:        0.272336
# left pops:
# Ma555_G6
# LiangDaoF
# Dashuitian
#
# Jackknife mean:      1.253638752    -0.253638752
#       std. errors:     0.647     0.647
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    13    15.771        0.261731     1.468    -0.468  infeasible
#            01  1    14    17.742        0.218788     1.000     0.000
#            10  1    14    43.741     6.51683e-05     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01         0.218788  chi(nested):     1.971 p-value for nested model:        0.160322
# left pops:
# Ami
# LiangDaoF
# Dashuitian
#
# Jackknife mean:      0.851769149     0.148230851
#       std. errors:     0.283     0.283
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    13    20.137       0.0918573     0.921     0.079
#            01  1    14    20.203        0.123857     1.000     0.000
#            10  1    14    56.019     5.78191e-07     0.000     1.000
# best pat:           00        0.0918573              -  -
# best pat:           01         0.123857  chi(nested):     0.067 p-value for nested model:        0.795949
# left pops:
# Xinyi
# LiangDaoF
# Dashuitian
#
# Jackknife mean:      0.620074056     0.379925944
#       std. errors:     0.333     0.333
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    13    18.583        0.136612     0.791     0.209
#            01  1    14    19.211        0.157046     1.000     0.000
#            10  1    14    46.491      2.3298e-05     0.000     1.000
# best pat:           00         0.136612              -  -
# best pat:           01         0.157046  chi(nested):     0.628 p-value for nested model:        0.428115
# left pops:
# Bbdong
# LiangDaoF
# Dashuitian
#
# Jackknife mean:     -0.501272011     1.501272011
#       std. errors:     0.244     0.244
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    13    12.328        0.500959    -0.543     1.543  infeasible
#            01  1    14    67.986     4.45948e-09     1.000     0.000
#            10  1    14    23.741       0.0492334     0.000     1.000
# best pat:           00                0              -  -
# best pat:           10        0.0492334  chi(nested):    11.413 p-value for nested model:     0.000729342
# left pops:
# Dai
# LiangDaoF
# Dashuitian
#
# Jackknife mean:      1.017991347    -0.017991347
#       std. errors:     0.685     0.685
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    13    33.116      0.00163672     1.274    -0.274  infeasible
#            01  1    14    33.772      0.00222629     1.000     0.000
#            10  1    14    67.898     4.62607e-09     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01       0.00222629  chi(nested):     0.656 p-value for nested model:        0.417982
# left pops:
# DonghulinM1
# LiangDaoF
# Dashuitian
#
# Jackknife mean:     -0.242799435     1.242799435
#       std. errors:     0.294     0.294
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    13     7.237        0.889513    -0.296     1.296  infeasible
#            01  1    14    27.077       0.0188135     1.000    -0.000
#            10  1    14     9.077        0.826076     0.000     1.000
# best pat:           00                0              -  -
# best pat:           10         0.826076  chi(nested):     1.840 p-value for nested model:        0.174964
# left pops:
# Boshan
# LiangDaoF
# Dashuitian
#
# Jackknife mean:     -0.889692959     1.889692959
#       std. errors:     0.492     0.492
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    13    25.539       0.0195936    -1.030     2.030  infeasible
#            01  1    14    80.347     2.43975e-11     1.000     0.000
#            10  1    14    48.960     9.10756e-06     0.000     1.000
# best pat:           00                0              -  -
# best pat:           10      9.10756e-06  chi(nested):    23.421 p-value for nested model:     1.30125e-06
# left pops:
# Liangzhu_T4620
# LiangDaoF
# Dashuitian
#
# Jackknife mean:     -1.208426427     2.208426427
#       std. errors:     2.332     2.332
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    13    13.107        0.439555     2.074    -1.074  infeasible
#            01  1    14    15.690        0.332662     1.000    -0.000
#            10  1    14    24.960       0.0349626     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01         0.332662  chi(nested):     2.583 p-value for nested model:        0.108032
# left pops:
# Dushan
# LiangDaoF
# Dashuitian
#
# Jackknife mean:      1.215787149    -0.215787149
#       std. errors:     0.324     0.324
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    13    15.704        0.265479     1.290    -0.290  infeasible
#            01  1    14    17.333        0.238859     1.000     0.000
#            10  1    14    46.736     2.12354e-05     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01         0.238859  chi(nested):     1.629 p-value for nested model:        0.201833
# expr: syntax error
# expr: non-numeric argument
# head: option requires an argument -- 'n'
# Try `head --help' for more information.
# tail: /mnt/solexa/mel_yang/early_CN/qpadm_south/UPA19_3.adm.B_LiangDaoF_LiangDaoF_Dashuitian_out2.log: invalid number of lines
# wc: /mnt/solexa/mel_yang/early_CN/qpadm_south/UPA19_3.adm.B_Atayal_LiangDaoF_Dashuitian_out2.log: No such file or directory
# cat: /mnt/solexa/mel_yang/early_CN/qpadm_south/UPA19_3.adm.B_Atayal_LiangDaoF_Dashuitian_out2.log: No such file or directory
# expr: non-numeric argument
# tail: /mnt/solexa/mel_yang/early_CN/qpadm_south/UPA19_3.adm.B_Atayal_LiangDaoF_Dashuitian_out2.log: invalid number of lines
# cat: /mnt/solexa/mel_yang/early_CN/qpadm_south/UPA19_3.adm.B_Atayal_LiangDaoF_Dashuitian_out2.log: No such file or directory
# expr: non-numeric argument
# tail: /mnt/solexa/mel_yang/early_CN/qpadm_south/UPA19_3.adm.B_Atayal_LiangDaoF_Dashuitian_out2.log: invalid number of lines
# cat: /mnt/solexa/mel_yang/early_CN/qpadm_south/UPA19_3.adm.B_Atayal_LiangDaoF_Dashuitian_out2.log: No such file or directory
# cat: /mnt/solexa/mel_yang/early_CN/qpadm_south/UPA19_3.adm.B_Atayal_LiangDaoF_Dashuitian_out2.log: No such file or directory
# expr: non-numeric argument
# tail: : invalid number of lines
# head: option requires an argument -- 'n'
# Try `head --help' for more information.
# tail: write error: Broken pipe

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/qpadm_south/"
# fh="UPA19_3"
# out="out2"
# numsource=2
# #for i in Han Korean Bbdong Boshan Boisman_MN Ami Dai; do
# for i in Dashuitian Han HDYM1 Linzi Tianluoshan; do
#     label="adm.B_Qihe_LiangDaoF_${i}_${out}"
#
#     numlines=$(wc -l ${pd}${fh}.${label}.log | cut -d" " -f1)
#
#     popind=$(cat ${pd}${fh}.${label}.log | grep -n "left pops:" | cut -d":" -f1)
#     diff1=`expr ${numlines} - ${popind} + 1`
#     tail -n ${diff1} ${pd}${fh}.${label}.log | head -n `expr ${numsource} + 3`
#
#     myind=$(cat ${pd}${fh}.${label}.log | grep -n "std. errors:" | cut -d":" -f1)
#     diff2=`expr ${numlines} - ${myind} + 2`
#     tail -n ${diff2} ${pd}${fh}.${label}.log | head -n2
#
#     tabind1=$(cat ${pd}${fh}.${label}.log | grep -n "summ:" | cut -d":" -f1)
#     tabind2=$(cat ${pd}${fh}.${label}.log | grep -n "coeffs:" | cut -d":" -f1)
#
#     diff3=`expr ${numlines} - ${tabind1}`
#     diff4=`expr ${tabind2} - ${tabind1} - 2`
#     tail -n ${diff3} ${pd}${fh}.${label}.log | head -n ${diff4}
# done
# Out:
# left pops:
# Qihe
# LiangDaoF
# Dashuitian
#
# Jackknife mean:      0.964378129     0.035621871
#       std. errors:     0.254     0.254
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    13     7.989        0.844292     1.013    -0.013  infeasible
#            01  1    14     7.948        0.892035     1.000     0.000
#            10  1    14    34.768      0.00159052     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01         0.892035  chi(nested):    -0.042 p-value for nested model:            -nan
# left pops:
# Qihe
# LiangDaoF
# Han
#
# Jackknife mean:      1.038993272    -0.038993272
#       std. errors:     0.341     0.341
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    13    11.598         0.56082     1.108    -0.108  infeasible
#            01  1    14    11.715        0.629151     1.000     0.000
#            10  1    14    41.417     0.000152883     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01         0.629151  chi(nested):     0.117 p-value for nested model:        0.732335
# left pops:
# Qihe
# LiangDaoF
# HDYM1
#
# Jackknife mean:      0.985027056     0.014972944
#       std. errors:     0.112     0.112
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    13    10.483        0.654066     0.992     0.008
#            01  1    14    10.431        0.730024     1.000     0.000
#            10  1    14    88.640     6.85288e-13     0.000     1.000
# best pat:           00         0.654066              -  -
# best pat:           01         0.730024  chi(nested):    -0.051 p-value for nested model:            -nan
# left pops:
# Qihe
# LiangDaoF
# Linzi
#
# Jackknife mean:      0.906594365     0.093405635
#       std. errors:     0.231     0.231
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    13     9.701        0.718216     0.940     0.060
#            01  1    14     9.735        0.781324     1.000     0.000
#            10  1    14    38.132     0.000495966     0.000     1.000
# best pat:           00         0.718216              -  -
# best pat:           01         0.781324  chi(nested):     0.034 p-value for nested model:        0.853848
# left pops:
# Qihe
# LiangDaoF
# Tianluoshan
#
# Jackknife mean:   2385.311055391 -2384.311055391
#       std. errors:  2171.234  2171.234
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    13     6.018         0.94549    -8.190     9.190  infeasible
#            01  1    14    10.421        0.730827     1.000    -0.000
#            10  1    14    10.213        0.746473     0.000     1.000
# best pat:           00                0              -  -
# best pat:           10         0.746473  chi(nested):     4.195 p-value for nested model:       0.0405538
# tail: write error: Broken pipe

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"

base=["Mota","UstIshim","Kostenki14","Iran_N",
      "Yana","Karelia","Okunevo_EMBA","IndusPeriphery",
      "Natufian","Papuan","Onge","Clovis", ##no USR
      "Tianyuan","Group1","Kolyma","HDYM1","Shamanka_EN","Chokhopani"] 
fh="UPA19_3"
ff.mklst(pD,fh,"o26",base)
# Out:
# 'Made /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/UPA19_3.o26 file'

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"

base=["Mota","UstIshim","Kostenki14","Iran_N",
      "Yana","Karelia","Okunevo_EMBA","IndusPeriphery",
      "Natufian","Papuan","Onge","Clovis", ##no USR
      "Tianyuan","Group1","Kolyma","HDYM1","Bbdong"] 
fh="UPA19_3"
ff.mklst(pD,fh,"o261",base)
# Out:
# 'Made /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/UPA19_3.o261 file'

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"

fh="UPA19_3"
ff.mklst(outpd,fh,"wave.o264aEAS.leftpop",["Qihe","LiangDao","Suogang","MG6"])
ff.parfile(pD,fh,"wave","o264aEAS",outpd=outpd,outgroup=fh+".o26",indfh='UPA19_3.qpadmmerge1')
# Out:
# 'Made wave PAR file /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/UPA19_3.wave.o264aEAS.par'

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"

fh="UPA19_3"
ff.mklst(outpd,fh,"wave.o2613aEAS.leftpop",["Qihe","LiangDao","Suogang"])
ff.parfile(pD,fh,"wave","o2613aEAS",outpd=outpd,outgroup=fh+".o261",indfh='UPA19_3.qpadmmerge1')
# Out:
# 'Made wave PAR file /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/UPA19_3.wave.o2613aEAS.par'

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"

fh="UPA19_3"
outnum="o2612"
popns=["Qihe","LiangDao","Suogang"]
pairs=[[i,j] for ind,i in enumerate(popns) for j in popns[ind+1:]]
letters="abcdefgh"
for ind,pair in enumerate(pairs):
    ff.mklst(outpd,fh,"wave.%s%sEAS.leftpop" % (outnum,letters[ind]),pair)
    ff.parfile(pD,fh,"wave","%s%sEAS" % (outnum,letters[ind]),outpd=outpd,outgroup=fh+"."+outnum[:-1],indfh='UPA19_3.qpadmmerge1')
    print "qpWave -p %s.wave.%s%sEAS.par > %s.wave.%s%sEAS.log &" % (fh,outnum,letters[ind],fh,outnum,letters[ind])
# Out:
# qpWave -p UPA19_3.wave.o2612aEAS.par > UPA19_3.wave.o2612aEAS.log &
# qpWave -p UPA19_3.wave.o2612bEAS.par > UPA19_3.wave.o2612bEAS.log &
# qpWave -p UPA19_3.wave.o2612cEAS.par > UPA19_3.wave.o2612cEAS.log &

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/data/2.2M/" 
outpd="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"

fh="UPA19_3"
outnum="o263"
popns=["LiangDao","Suogang","Ami","Atayal","MG6"]
pairs=[[i,"Bbdong","Qihe"] for ind,i in enumerate(popns)]
letters="abcdefgh"
for ind,pair in enumerate(pairs):
    ff.mklst(outpd,fh,"wave.%s%sEAS.leftpop" % (outnum,letters[ind]),pair)
    ff.parfile(pD,fh,"wave","%s%sEAS" % (outnum,letters[ind]),outpd=outpd,outgroup=fh+"."+outnum[:-1],indfh='UPA19_3.qpadmmerge1')
    print "qpWave -p %s.wave.%s%sEAS.par > %s.wave.%s%sEAS.log &" % (fh,outnum,letters[ind],fh,outnum,letters[ind])
# Out:
# qpWave -p UPA19_3.wave.o263aEAS.par > UPA19_3.wave.o263aEAS.log &
# qpWave -p UPA19_3.wave.o263bEAS.par > UPA19_3.wave.o263bEAS.log &
# qpWave -p UPA19_3.wave.o263cEAS.par > UPA19_3.wave.o263cEAS.log &
# qpWave -p UPA19_3.wave.o263dEAS.par > UPA19_3.wave.o263dEAS.log &
# qpWave -p UPA19_3.wave.o263eEAS.par > UPA19_3.wave.o263eEAS.log &

# %%
import fstats_funcs as ff

pD="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"

base=["Mota","UstIshim","Kostenki14","Iran_N",
      "Yana","Karelia","Okunevo_EMBA","IndusPeriphery",
      "Natufian","Papuan","Onge","Clovis", ##no USR
      "Tianyuan","Group1","Kolyma","HDYM1","Bbdong","Qihe","LiangDao"] 
fh="UPA19_3"
ff.mklst(pD,fh,"o262+L",base)
# Out:
# 'Made /mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/UPA19_3.o262+L file'

# %%
for i in Suogang Ami MG6; do python generalSS.py 5 IN o262+L ${i}; done
for i in Suogang Ami MG6; do python generalDS.py 5 IN o262+L ${i} 0; done

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"
# name="A1" #
# name="IN"
# suffix="_SS"
# out="o262+L"
# ancset1="Hejiatai Shamanka_EN LiangDao Man_Bac Suogang Boshan XJS_F Xiaogao Ma912_G2 Vt833_G2 Vt880_G2"
# ancset2="Hejiatai Shamanka_EN Qihe Man_Bac Suogang Boshan XJS_F Xiaogao Ma912_G2 Vt833_G2 Vt880_G2"
# ancset9="Samdzong Mebrak ZongriM297 Hejiatai Shamanka_EN Qihe Man_Bac Suogang Boshan XJS_F Xiaogao LG2 Vt833_G2 Vt880_G2"
# ancset10="Samdzong Mebrak ZongriM297 Hejiatai Shamanka_EN Qihe Man_Bac Suogang Boshan XJS_F Xiaogao Ma912_G2 Vt833_G2 Vt880_G2"
# pdeas="Ulchi Oroqen Xibo Uygur Sherpa_ShigatseX Tibetan_ShigatseX Tibetan_LhasaX Tibetan_NagquX Tibetan Sherpa Han_HenanX Han_GansuX Han_XinjiangX Han_HenanX Han_ShandongX Han_JiangsuX Han_AnhuiX Han_SichuanX Han_HubeiX Han_GuangdongX Han_ChongqingX Kinh"
# #for target in Qihe MG6 Samdzong Mebrak ZongriM297 Hejiatai Chokhopani JomonM HDYM1 Man_Bac Suogang Boshan XJS_F Xiaogao LG2 Ma912_G2 Vt833_G2 Vt880_G2 Nui_Nap Ban_Chiang Oakaie1; do
# #for target in Han Ami Dai Atayal Lahu Daur Hezhen Tibetan_ShannanX Tibetan_ChamdoX Miao She Korean Japanese Tujia Naxi Yi; do
# for target in Suogang Ami MG6; do
#     grep "f4rank: 0" ${pd}${name}/UPA19_3.adm.${name}${suffix}_${target}_*_${out}.log | awk '{ if ($8>0.05) print $1,$8}' | cut -d'/' -f9 | cut -d':' -f1,3
#
#
# done
# Out:
# UPA19_3.adm.IN_SS_Ami_LiangDao_o262+L.log: 0.100900021
# UPA19_3.adm.IN_SS_Ami_Qihe_o262+L.log: 0.0871860252
# UPA19_3.adm.IN_SS_MG6_LiangDao_o262+L.log: 0.151056834
# UPA19_3.adm.IN_SS_MG6_Qihe_o262+L.log: 0.167405104

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"
# name="PDEAS" #
# name="IN" #
# target="Suogang"
# suffix="_DS"
# out="o262+L"
# for target in ${target}; do
#     grep "f4rank: 1" ${pd}${name}/UPA19_3.adm.${name}${suffix}_${target}_*_${out}.log | awk '{ if ($8>0.05) print $1,$8}' | cut -d'/' -f9 | cut -d':' -f1,3
#     myfile=$(grep "f4rank: 1" ${pd}${name}/UPA19_3.adm.${name}${suffix}_${target}_*_${out}.log | awk '{ if ($8>0.05) print $1,$8}' | cut -d'/' -f9 | cut -d':' -f1)
#     for i in ${myfile}; do
#         echo " ~~~~~~~~~~~~~~~~~~~~~~~ "
#         echo ${i}
#         tail -n215 ${pd}${name}/${i} | head -n8
#         done
#     done
# Out:
# UPA19_3.adm.IN_DS_Suogang_Bbdong_HDYM1_o262+L.log: 0.278538518
# UPA19_3.adm.IN_DS_Suogang_Group1_Onge_o262+L.log: 0.3223823
# UPA19_3.adm.IN_DS_Suogang_Group1_Papuan_o262+L.log: 0.554587216
# UPA19_3.adm.IN_DS_Suogang_Group1_Tianyuan_o262+L.log: 0.259606313
# UPA19_3.adm.IN_DS_Suogang_HDYM1_Clovis_o262+L.log: 0.110285267
# UPA19_3.adm.IN_DS_Suogang_HDYM1_Kolyma_o262+L.log: 0.077384154
# UPA19_3.adm.IN_DS_Suogang_Kolyma_Clovis_o262+L.log: 0.594787327
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Bbdong_o262+L.log: 0.218902943
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Clovis_o262+L.log: 0.0616807834
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Group1_o262+L.log: 0.113259374
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Kolyma_o262+L.log: 0.0811007969
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Mota_o262+L.log: 0.0632917376
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Natufian_o262+L.log: 0.081143472
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Onge_o262+L.log: 0.0532771612
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Papuan_o262+L.log: 0.0873145371
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Qihe_o262+L.log: 0.285318176
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Tianyuan_o262+L.log: 0.304518645
# UPA19_3.adm.IN_DS_Suogang_LiangDao_UstIshim_o262+L.log: 0.133220932
# UPA19_3.adm.IN_DS_Suogang_Qihe_Bbdong_o262+L.log: 0.135897817
# UPA19_3.adm.IN_DS_Suogang_Qihe_Clovis_o262+L.log: 0.152450707
# UPA19_3.adm.IN_DS_Suogang_Qihe_Group1_o262+L.log: 0.12714304
# UPA19_3.adm.IN_DS_Suogang_Qihe_HDYM1_o262+L.log: 0.246954433
# UPA19_3.adm.IN_DS_Suogang_Qihe_IndusPeriphery_o262+L.log: 0.129027561
# UPA19_3.adm.IN_DS_Suogang_Qihe_Iran_N_o262+L.log: 0.125823762
# UPA19_3.adm.IN_DS_Suogang_Qihe_Karelia_o262+L.log: 0.0989902952
# UPA19_3.adm.IN_DS_Suogang_Qihe_Kolyma_o262+L.log: 0.0871658356
# UPA19_3.adm.IN_DS_Suogang_Qihe_Kostenki14_o262+L.log: 0.199516166
# UPA19_3.adm.IN_DS_Suogang_Qihe_Mota_o262+L.log: 0.404557946
# UPA19_3.adm.IN_DS_Suogang_Qihe_Natufian_o262+L.log: 0.134543849
# UPA19_3.adm.IN_DS_Suogang_Qihe_Okunevo_EMBA_o262+L.log: 0.149413791
# UPA19_3.adm.IN_DS_Suogang_Qihe_Onge_o262+L.log: 0.852193631
# UPA19_3.adm.IN_DS_Suogang_Qihe_Papuan_o262+L.log: 0.11780274
# UPA19_3.adm.IN_DS_Suogang_Qihe_Tianyuan_o262+L.log: 0.443815432
# UPA19_3.adm.IN_DS_Suogang_Qihe_UstIshim_o262+L.log: 0.220777817
# UPA19_3.adm.IN_DS_Suogang_Qihe_Yana_o262+L.log: 0.175320087
# UPA19_3.adm.IN_DS_Suogang_Tianyuan_Onge_o262+L.log: 0.838973327
# UPA19_3.adm.IN_DS_Suogang_Tianyuan_Papuan_o262+L.log: 0.220559733
# UPA19_3.adm.IN_DS_Suogang_Tianyuan_UstIshim_o262+L.log: 0.102149094
# UPA19_3.adm.IN_DS_Suogang_Yana_Kostenki14_o262+L.log: 0.179949767
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Bbdong_HDYM1_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    17.704        0.278539     6.670    -5.670  infeasible
#            01  1    16    41.390     0.000486153     1.000     0.000
#            10  1    16    48.417     4.08444e-05     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01      0.000486153  chi(nested):    23.686 p-value for nested model:     1.13389e-06
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Group1_Onge_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    16.941        0.322382    12.779   -11.779  infeasible
#            01  1    16   137.052     2.71661e-21     1.000    -0.000
#            10  1    16   198.707               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01      2.71661e-21  chi(nested):   120.111 p-value for nested model:     5.98153e-28
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Group1_Papuan_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    13.619        0.554587   -26.853    27.853  infeasible
#            01  1    16   147.881     2.04338e-23     1.000    -0.000
#            10  1    16   209.554               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01      2.04338e-23  chi(nested):   134.262 p-value for nested model:      4.7887e-31
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Group1_Tianyuan_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    18.058        0.259606    -4.403     5.403  infeasible
#            01  1    16   146.656     3.55968e-23     1.000     0.000
#            10  1    16   100.149     3.24827e-14     0.000     1.000
# best pat:           00                0              -  -
# best pat:           10      3.24827e-14  chi(nested):    82.091 p-value for nested model:     1.29992e-19
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_HDYM1_Clovis_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    21.906        0.110285     1.641    -0.641  infeasible
#            01  1    16    45.571     0.000113394     1.000    -0.000
#            10  1    16   164.921     8.65446e-27     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01      0.000113394  chi(nested):    23.665 p-value for nested model:      1.1466e-06
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_HDYM1_Kolyma_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    23.330       0.0773842     2.137    -1.137  infeasible
#            01  1    16    43.483     0.000236237     1.000     0.000
#            10  1    16    94.696     3.38368e-13     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01      0.000236237  chi(nested):    20.154 p-value for nested model:     7.14654e-06
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Kolyma_Clovis_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    13.097        0.594787     3.619    -2.619  infeasible
#            01  1    16    92.903     7.27812e-13     1.000     0.000
#            10  1    16   158.184     1.88357e-25     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01      7.27812e-13  chi(nested):    79.806 p-value for nested model:     4.13073e-19
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Bbdong_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    18.887        0.218903 13218.169 -13217.169  infeasible
#            01  1    16    28.796       0.0253501     1.000     0.000
#            10  1    16    29.422       0.0212389     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0253501  chi(nested):     9.909 p-value for nested model:      0.00164487
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Clovis_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    24.206       0.0616808     0.939     0.061
#            01  1    16    24.516       0.0788155     1.000     0.000
#            10  1    16   132.228      2.3686e-20     0.000     1.000
# best pat:           00        0.0616808              -  -
# best pat:           01        0.0788155  chi(nested):     0.311 p-value for nested model:        0.577243
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Group1_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    21.796        0.113259     1.344    -0.344  infeasible
#            01  1    16    28.391       0.0283786     1.000    -0.000
#            10  1    16   103.596     7.30678e-15     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0283786  chi(nested):     6.595 p-value for nested model:        0.010226
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Kolyma_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    23.145       0.0811008     0.816     0.184
#            01  1    16    25.728       0.0579819     1.000     0.000
#            10  1    16    70.912     6.90357e-09     0.000     1.000
# best pat:           00        0.0811008              -  -
# best pat:           01        0.0579819  chi(nested):     2.582 p-value for nested model:        0.108065
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Mota_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    24.107       0.0632917     1.136    -0.136  infeasible
#            01  1    16    28.627       0.0265773     1.000    -0.000
#            10  1    16   237.834               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0265773  chi(nested):     4.519 p-value for nested model:       0.0335123
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Natufian_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    23.143       0.0811435     1.065    -0.065  infeasible
#            01  1    16    24.320       0.0827518     1.000    -0.000
#            10  1    16   269.317               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0827518  chi(nested):     1.176 p-value for nested model:         0.27811
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Onge_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    24.759       0.0532772     1.196    -0.196  infeasible
#            01  1    16    28.797       0.0253413     1.000    -0.000
#            10  1    16   182.878     2.22984e-30     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0253413  chi(nested):     4.038 p-value for nested model:       0.0444825
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Papuan_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    22.853       0.0873145     1.281    -0.281  infeasible
#            01  1    16    28.657       0.0263515     1.000    -0.000
#            10  1    16   164.021     1.30682e-26     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0263515  chi(nested):     5.805 p-value for nested model:        0.015985
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Qihe_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    17.581        0.285318    -0.597     1.597  infeasible
#            01  1    16    26.630       0.0457827     1.000     0.000
#            10  1    16    18.412        0.300351     0.000     1.000
# best pat:           00                0              -  -
# best pat:           10         0.300351  chi(nested):     0.830 p-value for nested model:        0.362179
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_LiangDao_Tianyuan_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    17.243        0.304519     1.417    -0.417  infeasible
#            01  1    16    25.205       0.0662996     1.000    -0.000
#            10  1    16    76.100      8.3292e-10     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0662996  chi(nested):     7.961 p-value for nested model:      0.00477941
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_LiangDao_UstIshim_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    21.114        0.133221     1.237    -0.237  infeasible
#            01  1    16    28.436       0.0280303     1.000    -0.000
#            10  1    16   178.813     1.45677e-29     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0280303  chi(nested):     7.322 p-value for nested model:      0.00681308
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Qihe_Bbdong_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    21.029        0.135898     3.563    -2.563  infeasible
#            01  1    16    27.134       0.0400199     1.000    -0.000
#            10  1    16    39.503     0.000919762     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0400199  chi(nested):     6.105 p-value for nested model:       0.0134834
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Qihe_Clovis_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    20.532        0.152451     1.208    -0.208  infeasible
#            01  1    16    24.723       0.0748626     1.000    -0.000
#            10  1    16   158.284     1.79968e-25     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0748626  chi(nested):     4.191 p-value for nested model:       0.0406491
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Qihe_Group1_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    21.312        0.127143     1.167    -0.167  infeasible
#            01  1    16    23.936       0.0909184     1.000    -0.000
#            10  1    16   136.860     2.96255e-21     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0909184  chi(nested):     2.623 p-value for nested model:        0.105302
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Qihe_HDYM1_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    18.305        0.246954     2.331    -1.331  infeasible
#            01  1    16    26.951       0.0420341     1.000     0.000
#            10  1    16    45.611     0.000111798     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0420341  chi(nested):     8.645 p-value for nested model:      0.00327886
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Qihe_IndusPeriphery_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    21.250        0.129028     1.183    -0.183  infeasible
#            01  1    16    27.051       0.0409159     1.000    -0.000
#            10  1    16   291.628               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0409159  chi(nested):     5.801 p-value for nested model:       0.0160146
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Qihe_Iran_N_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    21.356        0.125824     1.159    -0.159  infeasible
#            01  1    16    26.182       0.0515146     1.000    -0.000
#            10  1    16   302.963               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0515146  chi(nested):     4.826 p-value for nested model:       0.0280327
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Qihe_Karelia_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    22.348       0.0989903     1.137    -0.137  infeasible
#            01  1    16    27.087       0.0405281     1.000    -0.000
#            10  1    16   297.966               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0405281  chi(nested):     4.738 p-value for nested model:       0.0294949
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Qihe_Kolyma_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    22.860       0.0871658     1.297    -0.297  infeasible
#            01  1    16    25.715       0.0581775     1.000     0.000
#            10  1    16    78.562     3.01937e-10     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0581775  chi(nested):     2.855 p-value for nested model:       0.0910883
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Qihe_Kostenki14_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    19.322        0.199516     1.188    -0.188  infeasible
#            01  1    16    27.128       0.0400813     1.000    -0.000
#            10  1    16   261.266               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0400813  chi(nested):     7.806 p-value for nested model:      0.00520676
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Qihe_Mota_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    15.666        0.404558     1.241    -0.241  infeasible
#            01  1    16    25.469       0.0619749     1.000    -0.000
#            10  1    16   233.412               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0619749  chi(nested):     9.802 p-value for nested model:      0.00174284
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Qihe_Natufian_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    21.072        0.134544     1.162    -0.162  infeasible
#            01  1    16    26.751       0.0443336     1.000    -0.000
#            10  1    16   271.184               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0443336  chi(nested):     5.679 p-value for nested model:       0.0171682
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Qihe_Okunevo_EMBA_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    20.620        0.149414     1.271    -0.271  infeasible
#            01  1    16    26.984       0.0416617     1.000    -0.000
#            10  1    16   224.838               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0416617  chi(nested):     6.364 p-value for nested model:       0.0116465
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Qihe_Onge_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15     9.461        0.852194     1.397    -0.397  infeasible
#            01  1    16    21.910        0.146127     1.000    -0.000
#            10  1    16   185.800               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01         0.146127  chi(nested):    12.449 p-value for nested model:     0.000418304
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Qihe_Papuan_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    21.633        0.117803     1.225    -0.225  infeasible
#            01  1    16    26.294       0.0500227     1.000    -0.000
#            10  1    16   197.723               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0500227  chi(nested):     4.662 p-value for nested model:       0.0308409
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Qihe_Tianyuan_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    15.106        0.443815     1.625    -0.625  infeasible
#            01  1    16    27.010       0.0413733     1.000    -0.000
#            10  1    16    87.126     8.43657e-12     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0413733  chi(nested):    11.904 p-value for nested model:      0.00056014
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Qihe_UstIshim_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    18.846        0.220778     1.237    -0.237  infeasible
#            01  1    16    26.160        0.051818     1.000    -0.000
#            10  1    16   216.182               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01         0.051818  chi(nested):     7.314 p-value for nested model:      0.00684354
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Qihe_Yana_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    19.912         0.17532     1.186    -0.186  infeasible
#            01  1    16    24.994       0.0699375     1.000    -0.000
#            10  1    16   219.317               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01        0.0699375  chi(nested):     5.081 p-value for nested model:       0.0241856
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Tianyuan_Onge_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15     9.687        0.838973     4.693    -3.693  infeasible
#            01  1    16   110.123     4.25031e-16     1.000    -0.000
#            10  1    16   222.668               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01      4.25031e-16  chi(nested):   100.436 p-value for nested model:     1.22272e-23
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Tianyuan_Papuan_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    18.851         0.22056     5.913    -4.913  infeasible
#            01  1    16   106.534      2.0369e-15     1.000    -0.000
#            10  1    16   216.339               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01       2.0369e-15  chi(nested):    87.683 p-value for nested model:     7.68207e-21
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Tianyuan_UstIshim_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    22.221        0.102149     2.824    -1.824  infeasible
#            01  1    16   105.075      3.8435e-15     1.000    -0.000
#            10  1    16   235.022               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01       3.8435e-15  chi(nested):    82.855 p-value for nested model:      8.8304e-20
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.IN_DS_Suogang_Yana_Kostenki14_o262+L.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    15    19.795         0.17995     8.506    -7.506  infeasible
#            01  1    16   221.308               0     1.000    -0.000
#            10  1    16   252.752               0     0.000     1.000
# best pat:           00                0              -  -
# best pat:           01       3.7752e-38  chi(nested):   201.514 p-value for nested model:     9.76155e-46
# tail: write error: Broken pipe

# %%
python sp_qpadm_3s_s1.py 20 CS o26 Bbdong CS_popns.txt &

# %%
# %%bash
# pd="/mnt/solexa/mel_yang/early_CN/firstdraft/qpadm_Laz2017/"
# name="PDEAS" #
# name="CS" #
# target="Qihe"
# suffix="_DS"
# out="o26"
# for target in ${target}; do
#     grep "f4rank: 1" ${pd}${name}/UPA19_3.adm.${name}${suffix}_${target}_*_${out}.log | awk '{ if ($8>0.05) print $1,$8}' | cut -d'/' -f9 | cut -d':' -f1,3
#     myfile=$(grep "f4rank: 1" ${pd}${name}/UPA19_3.adm.${name}${suffix}_${target}_*_${out}.log | awk '{ if ($8>0.05) print $1,$8}' | cut -d'/' -f9 | cut -d':' -f1)
#     for i in ${myfile}; do
#         echo " ~~~~~~~~~~~~~~~~~~~~~~~ "
#         echo ${i}
#         tail -n236 ${pd}${name}/${i} | head -n8
#         done
#     done
# Out:
# UPA19_3.adm.CS_DS_Qihe_Bbdong_Ami_o26.log: 0.559291347
# UPA19_3.adm.CS_DS_Qihe_Bbdong_Atayal_o26.log: 0.0873028957
# UPA19_3.adm.CS_DS_Qihe_Bbdong_LiangDao_o26.log: 0.39025102
# UPA19_3.adm.CS_DS_Qihe_Bbdong_MG6_o26.log: 0.226868958
# UPA19_3.adm.CS_DS_Qihe_Bbdong_Suogang_o26.log: 0.0828312861
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.CS_DS_Qihe_Bbdong_Ami_o26.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    16    14.530        0.559291    -0.594     1.594  infeasible
#            01  1    17    72.187     9.03394e-09     1.000    -0.000
#            10  1    17    27.404       0.0524042     0.000     1.000
# best pat:           00                0              -  -
# best pat:           10        0.0524042  chi(nested):    12.874 p-value for nested model:     0.000333203
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.CS_DS_Qihe_Bbdong_Atayal_o26.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    16    24.102       0.0873029    -0.564     1.564  infeasible
#            01  1    17    72.532     7.86837e-09     1.000     0.000
#            10  1    17    31.744       0.0161889     0.000     1.000
# best pat:           00                0              -  -
# best pat:           10        0.0161889  chi(nested):     7.642 p-value for nested model:      0.00570254
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.CS_DS_Qihe_Bbdong_LiangDao_o26.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    16    16.928        0.390251    -0.007     1.007  infeasible
#            01  1    17    70.447     1.80595e-08     1.000    -0.000
#            10  1    17    16.675        0.476585     0.000     1.000
# best pat:           00                0              -  -
# best pat:           10         0.476585  chi(nested):    -0.253 p-value for nested model:            -nan
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.CS_DS_Qihe_Bbdong_MG6_o26.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    16    19.854        0.226869     0.293     0.707
#            01  1    17    36.725      0.00366629     1.000    -0.000
#            10  1    17    22.902         0.15247     0.000     1.000
# best pat:           00         0.226869              -  -
# best pat:           10          0.15247  chi(nested):     3.048 p-value for nested model:       0.0808391
#
#  ~~~~~~~~~~~~~~~~~~~~~~~
# UPA19_3.adm.CS_DS_Qihe_Bbdong_Suogang_o26.log
#
#     fixed pat  wt  dof     chisq       tail prob
#            00  0    16    24.316       0.0828313    -0.519     1.519  infeasible
#            01  1    17    34.939      0.00633642     1.000    -0.000
#            10  1    17    25.963       0.0751411     0.000     1.000
# best pat:           00                0              -  -
# best pat:           10        0.0751411  chi(nested):     1.647 p-value for nested model:        0.199363
